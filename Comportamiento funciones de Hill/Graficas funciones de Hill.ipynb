# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import pickle

for i in range (0, 10):
    #constantes
    a1=random.randint(0,10)
    a2=random.randint(0,10)
    b1=random.randint(-10,10)
    b2=random.randint(-10,10)
    d1=random.randint(0,10)
    d2=random.randint(0,10)
    n=random.randint(0,5)
    
    def f(y):
        
        #asignar a cada ODE a un elemento de vector
    
        #definimos cada ODE
        #dX_dt=a1/(1+Y**n)-d1*X+b1
        #dY_dt=a2/(1+X**n)-d2*Y+b2
        dy_dt=a1/(1+y**n)-d1*y+b1
    
        return a1/(1+y**n)-d1*y+b1

    #Declaramos el vector de tiempo
    t_span=[0,20]
    times=np.linspace(t_span[0], t_span[1], 7000)
    
    varfci2 = []
    for i_ci in range (0,1):
        #Definimos las condiciones iniciales
        y0=np.array([random.randint(0,10),random.randint(0,10)])
        
    plt.plot(times, [f(i) for i in times])
