# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_39204\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos con ruido/Campo 50 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 50, 50)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (2000, 2, 50, 50)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (1000, 2, 50, 50)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 50, 50), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creamos función de costo

# %%
def custom_loss(y_true, y_pred):
    campvec = []
    # constantes
    a1 = tf.cast(y_true[:, 0], tf.float64)
    #tf.print(a1)
    a1 = tf.reshape(a1, shape=(-1, 1, 1))

    a2 = tf.cast(y_true[:, 1], tf.float64)
    a2 = tf.reshape(a2, shape=(-1, 1, 1))
    
    b1 = tf.cast(y_true[:, 2], tf.float64)
    b1 = tf.reshape(b1,shape = (-1,1,1))
    
    b2 = tf.cast(y_true[:, 3], tf.float64)
    b2 = tf.reshape(b2,shape = (-1,1,1))

    d1 = tf.cast(y_true[:, 4], tf.float64)
    d1 = tf.reshape(d1, shape=(-1, 1, 1))

    d2 = tf.cast(y_true[:, 5], tf.float64)
    d2 = tf.reshape(d2, shape=(-1, 1, 1))

    n = tf.cast(y_true[:, 6], tf.float64)
    n = tf.reshape(n, shape=(-1, 1, 1))

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        X = tf.cast(X, tf.float64)
        X = tf.reshape(X, shape=(1, 50,50))
        Y = y[1]
        Y = tf.cast(Y, tf.float64)
        Y = tf.reshape(Y, shape=(1, 50,50))
        
        # definimos cada ODE
        dX_dt = tf.divide(a1,(1 + tf.math.pow(Y, n)+1e-5)) - tf.multiply(d1,X) + b1
        dY_dt = tf.divide(a2,(1 + tf.math.pow(X, n)+1e-7)) - tf.multiply(d2,Y) + b2
        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 20
    y_range_neg = 0
    y_range_pos = 20
    y1 = tf.linspace(x_range_neg, x_range_pos, 50)
    y2 = tf.linspace(y_range_neg, y_range_pos, 50)
    Y1, Y2 = tf.meshgrid(y1, y2)
    t = 0
    u, v = tf.zeros(Y1.shape), tf.zeros(Y2.shape)
    u, v = f(t, [Y1, Y2])
    #M = tf.sqrt(tf.square(u) + tf.square(v))
    #u /= M
    #v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = tf.cast(y_pred[:, 0], tf.float64)
    a12 = tf.reshape(a12, shape=(-1, 1, 1))

    a22 = tf.cast(y_pred[:, 1], tf.float64)
    a22 = tf.reshape(a22, shape=(-1, 1, 1))
    
    b12 = tf.cast(y_pred[:, 2], tf.float64)
    b12 = tf.reshape(b12,shape = (-1,1,1))
    
    b22 = tf.cast(y_pred[:, 3], tf.float64)
    b22 = tf.reshape(b22,shape = (-1,1,1))

    d12 = tf.cast(y_pred[:, 4], tf.float64)
    d12 = tf.reshape(d12, shape=(-1, 1, 1))

    d22 = tf.cast(y_pred[:, 5], tf.float64)
    d22 = tf.reshape(d22, shape=(-1, 1, 1))

    n2 = tf.cast(y_pred[:, 6], tf.float64)
    n2 = tf.reshape(n2, shape=(-1, 1, 1))
    
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        X2 = tf.cast(X2, tf.float64)
        X2 = tf.reshape(X2, shape=(1, 50,50))
        Y2 = ye2[1]
        Y2 = tf.cast(Y2, tf.float64)
        Y2 = tf.reshape(Y2, shape=(1, 50,50))

        # definimos cada ODE
        dX2_dt = tf.divide(a12,(1 + tf.math.pow(Y2, n2)+1e-8)) - tf.multiply(d12,X2) + b12
        dY2_dt = tf.divide(a22,(1 + tf.math.pow(X2, n2)+1e-8)) - tf.multiply(d22,Y2) + b22
        return [dX2_dt, dY2_dt]

    y12 = tf.linspace(x_range_neg, x_range_pos, 50)
    y22 = tf.linspace(y_range_neg, y_range_pos, 50)
    Y12, Y22 = tf.meshgrid(y12, y22)
    u2, v2 = tf.zeros(Y12.shape), tf.zeros(Y22.shape)
    u2, v2 = f2(t, [Y12, Y22])
    #M2 = tf.sqrt(tf.square(u2) + tf.square(v2))
    #u2 /= M2
    #v2 /= M2
    campvecx = tf.abs(tf.subtract(u,u2))
    campvecy = tf.abs(tf.subtract(v,v2))
    campvec_magnitude = tf.add(campvecx,campvecy)
    loss = tf.reduce_mean(campvec_magnitude)
    #tf.print(y_pred)
    return loss

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
model.add(Flatten(input_shape=(2,50,50)))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))

model.add(Dense(7, activation= custom_activation))

# %%
model = Sequential()
model.add(Flatten(input_shape=(2,50,50)))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))

model.add(Dense(7, activation= custom_activation))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 5000)              0
#
#  batch_normalization (BatchN  (None, 5000)             20000
#  ormalization)
#
#  dense (Dense)               (None, 128)               640128
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 701,991
# Trainable params: 691,991
# Non-trainable params: 10,000
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= custom_loss,
              metrics=metrics)

# %%
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 1000,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 70/70 [==============================] - 3s 24ms/step - loss: 46.4269 - a_1: 3.0373 - a_2: 3.0438 - b_1: 3.0694 - b_2: 3.1272 - d_1: 1.5971 - d_2: 1.5593 - n: 3.0558 - mean_metric: 0.6080 - val_loss: 43.0578 - val_a_1: 3.0822 - val_a_2: 2.9343 - val_b_1: 2.8104 - val_b_2: 3.3170 - val_d_1: 1.2362 - val_d_2: 1.6476 - val_n: 3.1916 - val_mean_metric: 0.5910 - lr: 0.0010
# Epoch 2/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 41.7175 - a_1: 2.9973 - a_2: 3.1144 - b_1: 2.9782 - b_2: 3.1325 - d_1: 1.3915 - d_2: 1.3800 - n: 3.4159 - mean_metric: 0.6055 - val_loss: 36.7004 - val_a_1: 2.9919 - val_a_2: 2.9758 - val_b_1: 2.8874 - val_b_2: 3.1687 - val_d_1: 1.1678 - val_d_2: 1.1590 - val_n: 3.3237 - val_mean_metric: 0.5733 - lr: 0.0010
# Epoch 3/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 38.9952 - a_1: 2.9496 - a_2: 3.1734 - b_1: 2.9259 - b_2: 3.0751 - d_1: 1.2985 - d_2: 1.3088 - n: 3.3349 - mean_metric: 0.5942 - val_loss: 33.9312 - val_a_1: 2.9391 - val_a_2: 3.1604 - val_b_1: 2.6713 - val_b_2: 2.9544 - val_d_1: 1.0653 - val_d_2: 1.1235 - val_n: 3.6474 - val_mean_metric: 0.5696 - lr: 0.0010
# Epoch 4/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 37.1393 - a_1: 2.9357 - a_2: 3.2513 - b_1: 2.8153 - b_2: 2.9951 - d_1: 1.2514 - d_2: 1.2637 - n: 3.4141 - mean_metric: 0.5896 - val_loss: 32.3832 - val_a_1: 3.0405 - val_a_2: 3.0373 - val_b_1: 2.6968 - val_b_2: 2.8458 - val_d_1: 1.0563 - val_d_2: 1.0874 - val_n: 3.1207 - val_mean_metric: 0.5477 - lr: 0.0010
# Epoch 5/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 35.2233 - a_1: 2.9644 - a_2: 3.0499 - b_1: 2.8681 - b_2: 2.9461 - d_1: 1.1930 - d_2: 1.2121 - n: 3.1471 - mean_metric: 0.5717 - val_loss: 31.0349 - val_a_1: 3.1076 - val_a_2: 2.9062 - val_b_1: 2.8266 - val_b_2: 2.7407 - val_d_1: 1.0658 - val_d_2: 1.0427 - val_n: 3.1094 - val_mean_metric: 0.5448 - lr: 0.0010
# Epoch 6/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 34.1190 - a_1: 3.0007 - a_2: 3.0593 - b_1: 2.9192 - b_2: 2.8971 - d_1: 1.1715 - d_2: 1.1933 - n: 3.4105 - mean_metric: 0.5805 - val_loss: 29.9629 - val_a_1: 3.0727 - val_a_2: 2.9508 - val_b_1: 2.7760 - val_b_2: 3.0132 - val_d_1: 1.0489 - val_d_2: 1.0272 - val_n: 3.5571 - val_mean_metric: 0.5657 - lr: 0.0010
# Epoch 7/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 32.6061 - a_1: 3.0056 - a_2: 3.1044 - b_1: 2.8192 - b_2: 2.9523 - d_1: 1.1367 - d_2: 1.1647 - n: 3.4123 - mean_metric: 0.5787 - val_loss: 28.6631 - val_a_1: 3.0884 - val_a_2: 2.9876 - val_b_1: 2.6100 - val_b_2: 2.8837 - val_d_1: 1.0241 - val_d_2: 0.9624 - val_n: 3.3375 - val_mean_metric: 0.5479 - lr: 0.0010
# Epoch 8/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 31.3876 - a_1: 2.9786 - a_2: 3.0854 - b_1: 2.7644 - b_2: 2.8967 - d_1: 1.1150 - d_2: 1.1333 - n: 3.2078 - mean_metric: 0.5650 - val_loss: 27.8621 - val_a_1: 3.0178 - val_a_2: 2.8697 - val_b_1: 2.6427 - val_b_2: 2.8759 - val_d_1: 0.9872 - val_d_2: 0.9683 - val_n: 3.5131 - val_mean_metric: 0.5473 - lr: 0.0010
# Epoch 9/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 30.8774 - a_1: 2.9380 - a_2: 2.9661 - b_1: 2.7909 - b_2: 2.8327 - d_1: 1.1147 - d_2: 1.1340 - n: 3.4180 - mean_metric: 0.5654 - val_loss: 26.8446 - val_a_1: 3.0527 - val_a_2: 2.8172 - val_b_1: 2.6372 - val_b_2: 2.7867 - val_d_1: 0.9724 - val_d_2: 0.9603 - val_n: 3.3909 - val_mean_metric: 0.5390 - lr: 0.0010
# Epoch 10/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 30.3232 - a_1: 2.9695 - a_2: 2.9443 - b_1: 2.8094 - b_2: 2.8035 - d_1: 1.1143 - d_2: 1.1184 - n: 3.5518 - mean_metric: 0.5694 - val_loss: 27.5883 - val_a_1: 3.0847 - val_a_2: 2.8845 - val_b_1: 2.7288 - val_b_2: 2.7659 - val_d_1: 1.0182 - val_d_2: 1.0259 - val_n: 3.7512 - val_mean_metric: 0.5598 - lr: 0.0010
# Epoch 11/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 29.6543 - a_1: 2.9322 - a_2: 2.9496 - b_1: 2.7986 - b_2: 2.8267 - d_1: 1.1016 - d_2: 1.1159 - n: 3.3944 - mean_metric: 0.5629 - val_loss: 26.6918 - val_a_1: 2.9900 - val_a_2: 2.8422 - val_b_1: 2.6272 - val_b_2: 2.7351 - val_d_1: 0.9524 - val_d_2: 1.0059 - val_n: 3.4689 - val_mean_metric: 0.5390 - lr: 0.0010
# Epoch 12/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 29.2188 - a_1: 2.9159 - a_2: 2.9376 - b_1: 2.7662 - b_2: 2.7836 - d_1: 1.0978 - d_2: 1.0943 - n: 3.3079 - mean_metric: 0.5560 - val_loss: 26.4661 - val_a_1: 3.0633 - val_a_2: 2.7566 - val_b_1: 2.6616 - val_b_2: 2.7049 - val_d_1: 0.9736 - val_d_2: 0.9850 - val_n: 3.3631 - val_mean_metric: 0.5354 - lr: 0.0010
# Epoch 13/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 28.8519 - a_1: 2.9175 - a_2: 2.9257 - b_1: 2.7547 - b_2: 2.7730 - d_1: 1.0953 - d_2: 1.0913 - n: 3.2208 - mean_metric: 0.5518 - val_loss: 25.1314 - val_a_1: 2.9348 - val_a_2: 2.8612 - val_b_1: 2.6251 - val_b_2: 2.7640 - val_d_1: 0.9504 - val_d_2: 0.8988 - val_n: 3.2565 - val_mean_metric: 0.5283 - lr: 0.0010
# Epoch 14/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 28.8092 - a_1: 2.9312 - a_2: 2.9621 - b_1: 2.7351 - b_2: 2.7970 - d_1: 1.0854 - d_2: 1.1013 - n: 3.0348 - mean_metric: 0.5475 - val_loss: 25.5718 - val_a_1: 2.9690 - val_a_2: 2.7851 - val_b_1: 2.6585 - val_b_2: 2.7901 - val_d_1: 0.9655 - val_d_2: 0.9513 - val_n: 2.7692 - val_mean_metric: 0.5153 - lr: 0.0010
# Epoch 15/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 28.6642 - a_1: 2.8818 - a_2: 2.9001 - b_1: 2.7364 - b_2: 2.7930 - d_1: 1.0910 - d_2: 1.0963 - n: 2.7972 - mean_metric: 0.5360 - val_loss: 25.2380 - val_a_1: 2.9040 - val_a_2: 2.7122 - val_b_1: 2.7168 - val_b_2: 2.7488 - val_d_1: 0.9828 - val_d_2: 0.9198 - val_n: 2.5724 - val_mean_metric: 0.5045 - lr: 0.0010
# Epoch 16/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 28.0824 - a_1: 2.8765 - a_2: 2.8751 - b_1: 2.7267 - b_2: 2.7463 - d_1: 1.0663 - d_2: 1.0818 - n: 2.6837 - mean_metric: 0.5280 - val_loss: 24.7484 - val_a_1: 2.9769 - val_a_2: 2.8769 - val_b_1: 2.6117 - val_b_2: 2.7390 - val_d_1: 0.9376 - val_d_2: 0.9028 - val_n: 2.8471 - val_mean_metric: 0.5154 - lr: 0.0010
# Epoch 17/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.7251 - a_1: 2.8602 - a_2: 2.9257 - b_1: 2.7143 - b_2: 2.7542 - d_1: 1.0578 - d_2: 1.0591 - n: 2.8067 - mean_metric: 0.5321 - val_loss: 24.4835 - val_a_1: 2.9525 - val_a_2: 2.8731 - val_b_1: 2.6790 - val_b_2: 2.6485 - val_d_1: 0.9164 - val_d_2: 0.9279 - val_n: 2.7157 - val_mean_metric: 0.5096 - lr: 0.0010
# Epoch 18/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.9997 - a_1: 2.8619 - a_2: 2.9208 - b_1: 2.7313 - b_2: 2.7550 - d_1: 1.0565 - d_2: 1.0971 - n: 2.7313 - mean_metric: 0.5312 - val_loss: 25.4478 - val_a_1: 2.9325 - val_a_2: 2.7745 - val_b_1: 2.7276 - val_b_2: 2.7781 - val_d_1: 0.9475 - val_d_2: 0.9692 - val_n: 2.6403 - val_mean_metric: 0.5115 - lr: 0.0010
# Epoch 19/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 28.0191 - a_1: 2.8355 - a_2: 2.9130 - b_1: 2.7618 - b_2: 2.7910 - d_1: 1.0715 - d_2: 1.0803 - n: 2.7059 - mean_metric: 0.5315 - val_loss: 25.3461 - val_a_1: 2.9897 - val_a_2: 2.8209 - val_b_1: 2.6818 - val_b_2: 2.6083 - val_d_1: 0.9702 - val_d_2: 0.9404 - val_n: 2.6603 - val_mean_metric: 0.5082 - lr: 0.0010
# Epoch 20/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.8001 - a_1: 2.8223 - a_2: 2.8981 - b_1: 2.7453 - b_2: 2.7648 - d_1: 1.0844 - d_2: 1.0590 - n: 2.4096 - mean_metric: 0.5191 - val_loss: 24.8141 - val_a_1: 2.9278 - val_a_2: 2.7952 - val_b_1: 2.6720 - val_b_2: 2.6154 - val_d_1: 0.9036 - val_d_2: 0.9760 - val_n: 2.2847 - val_mean_metric: 0.4921 - lr: 0.0010
# Epoch 21/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.6395 - a_1: 2.8666 - a_2: 2.8953 - b_1: 2.7518 - b_2: 2.7389 - d_1: 1.0640 - d_2: 1.0522 - n: 2.4702 - mean_metric: 0.5209 - val_loss: 24.0642 - val_a_1: 2.9600 - val_a_2: 2.7589 - val_b_1: 2.6393 - val_b_2: 2.6292 - val_d_1: 0.8955 - val_d_2: 0.9093 - val_n: 2.4376 - val_mean_metric: 0.4939 - lr: 0.0010
# Epoch 22/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.1500 - a_1: 2.8704 - a_2: 2.8818 - b_1: 2.7153 - b_2: 2.7066 - d_1: 1.0429 - d_2: 1.0330 - n: 2.4285 - mean_metric: 0.5156 - val_loss: 24.9991 - val_a_1: 2.9266 - val_a_2: 2.7445 - val_b_1: 2.5554 - val_b_2: 2.7002 - val_d_1: 0.9702 - val_d_2: 0.9556 - val_n: 2.3097 - val_mean_metric: 0.4917 - lr: 0.0010
# Epoch 23/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.1260 - a_1: 2.8540 - a_2: 2.8701 - b_1: 2.7428 - b_2: 2.7508 - d_1: 1.0344 - d_2: 1.0444 - n: 2.2962 - mean_metric: 0.5128 - val_loss: 24.3969 - val_a_1: 2.9926 - val_a_2: 2.7938 - val_b_1: 2.6216 - val_b_2: 2.7178 - val_d_1: 0.9231 - val_d_2: 0.9237 - val_n: 2.2442 - val_mean_metric: 0.4935 - lr: 0.0010
# Epoch 24/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.0138 - a_1: 2.8349 - a_2: 2.8960 - b_1: 2.7153 - b_2: 2.7140 - d_1: 1.0430 - d_2: 1.0396 - n: 2.2305 - mean_metric: 0.5088 - val_loss: 24.6399 - val_a_1: 2.9270 - val_a_2: 2.7733 - val_b_1: 2.6162 - val_b_2: 2.6474 - val_d_1: 0.9240 - val_d_2: 0.9620 - val_n: 2.0615 - val_mean_metric: 0.4837 - lr: 0.0010
# Epoch 25/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 27.2349 - a_1: 2.7927 - a_2: 2.8409 - b_1: 2.7179 - b_2: 2.7237 - d_1: 1.0466 - d_2: 1.0619 - n: 2.1445 - mean_metric: 0.5042 - val_loss: 24.7301 - val_a_1: 2.9255 - val_a_2: 2.7473 - val_b_1: 2.5914 - val_b_2: 2.6295 - val_d_1: 0.9214 - val_d_2: 0.9552 - val_n: 2.2387 - val_mean_metric: 0.4868 - lr: 0.0010
# Epoch 26/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.5697 - a_1: 2.7989 - a_2: 2.8830 - b_1: 2.7035 - b_2: 2.6985 - d_1: 1.0245 - d_2: 1.0232 - n: 2.3598 - mean_metric: 0.5094 - val_loss: 23.8600 - val_a_1: 2.9086 - val_a_2: 2.7699 - val_b_1: 2.5747 - val_b_2: 2.6228 - val_d_1: 0.9077 - val_d_2: 0.9041 - val_n: 2.3051 - val_mean_metric: 0.4862 - lr: 0.0010
# Epoch 27/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.7436 - a_1: 2.8221 - a_2: 2.8713 - b_1: 2.7004 - b_2: 2.7157 - d_1: 1.0383 - d_2: 1.0175 - n: 2.4307 - mean_metric: 0.5129 - val_loss: 24.1096 - val_a_1: 2.9752 - val_a_2: 2.7821 - val_b_1: 2.6299 - val_b_2: 2.7150 - val_d_1: 0.8954 - val_d_2: 0.9531 - val_n: 2.4503 - val_mean_metric: 0.4995 - lr: 0.0010
# Epoch 28/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.7385 - a_1: 2.8610 - a_2: 2.8752 - b_1: 2.7418 - b_2: 2.7087 - d_1: 1.0319 - d_2: 1.0380 - n: 2.4894 - mean_metric: 0.5179 - val_loss: 24.4219 - val_a_1: 2.8995 - val_a_2: 2.7930 - val_b_1: 2.5561 - val_b_2: 2.6755 - val_d_1: 0.9722 - val_d_2: 0.9111 - val_n: 2.4913 - val_mean_metric: 0.4962 - lr: 0.0010
# Epoch 29/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.6071 - a_1: 2.8351 - a_2: 2.8977 - b_1: 2.7074 - b_2: 2.7288 - d_1: 1.0239 - d_2: 1.0346 - n: 2.5353 - mean_metric: 0.5184 - val_loss: 24.4790 - val_a_1: 2.9609 - val_a_2: 2.8307 - val_b_1: 2.6165 - val_b_2: 2.6283 - val_d_1: 0.9631 - val_d_2: 0.9172 - val_n: 2.3790 - val_mean_metric: 0.4961 - lr: 0.0010
# Epoch 30/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.4576 - a_1: 2.8159 - a_2: 2.9094 - b_1: 2.7327 - b_2: 2.6763 - d_1: 1.0428 - d_2: 1.0056 - n: 2.5679 - mean_metric: 0.5181 - val_loss: 24.0717 - val_a_1: 2.8812 - val_a_2: 2.7735 - val_b_1: 2.6076 - val_b_2: 2.6632 - val_d_1: 0.9463 - val_d_2: 0.8771 - val_n: 2.4815 - val_mean_metric: 0.4939 - lr: 0.0010
# Epoch 31/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.2378 - a_1: 2.8005 - a_2: 2.8565 - b_1: 2.7033 - b_2: 2.6756 - d_1: 0.9964 - d_2: 1.0289 - n: 2.4915 - mean_metric: 0.5115 - val_loss: 23.9039 - val_a_1: 2.8870 - val_a_2: 2.8093 - val_b_1: 2.6329 - val_b_2: 2.6134 - val_d_1: 0.8995 - val_d_2: 0.9215 - val_n: 2.3770 - val_mean_metric: 0.4910 - lr: 0.0010
# Epoch 32/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.2104 - a_1: 2.8144 - a_2: 2.8966 - b_1: 2.7359 - b_2: 2.7093 - d_1: 1.0054 - d_2: 1.0256 - n: 2.4482 - mean_metric: 0.5142 - val_loss: 23.6764 - val_a_1: 2.8817 - val_a_2: 2.7923 - val_b_1: 2.6974 - val_b_2: 2.6769 - val_d_1: 0.9441 - val_d_2: 0.8734 - val_n: 2.2542 - val_mean_metric: 0.4904 - lr: 0.0010
# Epoch 33/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 25.7726 - a_1: 2.8006 - a_2: 2.8855 - b_1: 2.7301 - b_2: 2.6950 - d_1: 0.9967 - d_2: 0.9976 - n: 2.4916 - mean_metric: 0.5129 - val_loss: 23.8595 - val_a_1: 2.8772 - val_a_2: 2.8336 - val_b_1: 2.6230 - val_b_2: 2.6281 - val_d_1: 0.9195 - val_d_2: 0.8809 - val_n: 2.5622 - val_mean_metric: 0.4970 - lr: 0.0010
# Epoch 34/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 25.8454 - a_1: 2.8124 - a_2: 2.9141 - b_1: 2.7125 - b_2: 2.7010 - d_1: 0.9930 - d_2: 0.9941 - n: 2.7361 - mean_metric: 0.5217 - val_loss: 23.2097 - val_a_1: 2.9009 - val_a_2: 2.8107 - val_b_1: 2.6025 - val_b_2: 2.6515 - val_d_1: 0.8991 - val_d_2: 0.8588 - val_n: 2.7974 - val_mean_metric: 0.5034 - lr: 0.0010
# Epoch 35/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 26.1555 - a_1: 2.7941 - a_2: 2.8765 - b_1: 2.7085 - b_2: 2.6700 - d_1: 1.0038 - d_2: 1.0238 - n: 2.8262 - mean_metric: 0.5230 - val_loss: 23.5050 - val_a_1: 2.8980 - val_a_2: 2.7592 - val_b_1: 2.6314 - val_b_2: 2.5841 - val_d_1: 0.9042 - val_d_2: 0.8959 - val_n: 2.6494 - val_mean_metric: 0.4969 - lr: 0.0010
# Epoch 36/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 25.5951 - a_1: 2.8114 - a_2: 2.8677 - b_1: 2.7210 - b_2: 2.6861 - d_1: 0.9876 - d_2: 0.9941 - n: 2.7347 - mean_metric: 0.5197 - val_loss: 23.1081 - val_a_1: 2.8893 - val_a_2: 2.7415 - val_b_1: 2.6378 - val_b_2: 2.6717 - val_d_1: 0.8820 - val_d_2: 0.8659 - val_n: 2.5013 - val_mean_metric: 0.4926 - lr: 0.0010
# Epoch 37/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 25.9028 - a_1: 2.8221 - a_2: 2.9110 - b_1: 2.7062 - b_2: 2.6980 - d_1: 1.0044 - d_2: 1.0039 - n: 2.6349 - mean_metric: 0.5190 - val_loss: 23.6019 - val_a_1: 2.9213 - val_a_2: 2.7925 - val_b_1: 2.6055 - val_b_2: 2.6803 - val_d_1: 0.9103 - val_d_2: 0.9015 - val_n: 2.6251 - val_mean_metric: 0.5006 - lr: 0.0010
# Epoch 38/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 25.5132 - a_1: 2.8045 - a_2: 2.8787 - b_1: 2.7061 - b_2: 2.6663 - d_1: 1.0000 - d_2: 0.9847 - n: 2.5502 - mean_metric: 0.5128 - val_loss: 23.8856 - val_a_1: 2.8574 - val_a_2: 2.7141 - val_b_1: 2.6836 - val_b_2: 2.6652 - val_d_1: 0.9101 - val_d_2: 0.9124 - val_n: 2.2803 - val_mean_metric: 0.4872 - lr: 0.0010
# Epoch 39/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 25.5561 - a_1: 2.7989 - a_2: 2.8687 - b_1: 2.7251 - b_2: 2.6528 - d_1: 0.9945 - d_2: 0.9867 - n: 2.3581 - mean_metric: 0.5060 - val_loss: 23.1160 - val_a_1: 2.9217 - val_a_2: 2.7564 - val_b_1: 2.5949 - val_b_2: 2.6438 - val_d_1: 0.8804 - val_d_2: 0.8769 - val_n: 2.2965 - val_mean_metric: 0.4855 - lr: 0.0010
# Epoch 40/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 25.3830 - a_1: 2.7940 - a_2: 2.8818 - b_1: 2.7142 - b_2: 2.6520 - d_1: 0.9853 - d_2: 0.9895 - n: 2.2875 - mean_metric: 0.5033 - val_loss: 23.6195 - val_a_1: 2.8839 - val_a_2: 2.7843 - val_b_1: 2.6631 - val_b_2: 2.6267 - val_d_1: 0.9696 - val_d_2: 0.8571 - val_n: 2.2548 - val_mean_metric: 0.4878 - lr: 0.0010
# Epoch 41/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 25.4707 - a_1: 2.7900 - a_2: 2.8578 - b_1: 2.6974 - b_2: 2.6874 - d_1: 1.0009 - d_2: 0.9855 - n: 2.2523 - mean_metric: 0.5023 - val_loss: 23.0186 - val_a_1: 2.9089 - val_a_2: 2.7461 - val_b_1: 2.5914 - val_b_2: 2.6768 - val_d_1: 0.9125 - val_d_2: 0.8762 - val_n: 2.1950 - val_mean_metric: 0.4835 - lr: 0.0010
# Epoch 42/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 25.5938 - a_1: 2.8059 - a_2: 2.8613 - b_1: 2.7168 - b_2: 2.6821 - d_1: 1.0032 - d_2: 0.9924 - n: 2.2767 - mean_metric: 0.5045 - val_loss: 23.4358 - val_a_1: 2.9839 - val_a_2: 2.7507 - val_b_1: 2.6390 - val_b_2: 2.6968 - val_d_1: 0.9192 - val_d_2: 0.8933 - val_n: 2.2706 - val_mean_metric: 0.4915 - lr: 0.0010
# Epoch 43/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 25.2621 - a_1: 2.8057 - a_2: 2.8748 - b_1: 2.6548 - b_2: 2.6724 - d_1: 0.9826 - d_2: 0.9890 - n: 2.3189 - mean_metric: 0.5031 - val_loss: 22.3791 - val_a_1: 2.8904 - val_a_2: 2.7951 - val_b_1: 2.5657 - val_b_2: 2.6736 - val_d_1: 0.8584 - val_d_2: 0.8421 - val_n: 2.2744 - val_mean_metric: 0.4832 - lr: 0.0010
# Epoch 44/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 25.0099 - a_1: 2.7792 - a_2: 2.8646 - b_1: 2.7008 - b_2: 2.6916 - d_1: 0.9816 - d_2: 0.9667 - n: 2.2292 - mean_metric: 0.5003 - val_loss: 22.9226 - val_a_1: 2.8612 - val_a_2: 2.7500 - val_b_1: 2.6515 - val_b_2: 2.6042 - val_d_1: 0.8715 - val_d_2: 0.8775 - val_n: 2.0851 - val_mean_metric: 0.4768 - lr: 0.0010
# Epoch 45/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 25.0117 - a_1: 2.7809 - a_2: 2.8817 - b_1: 2.6956 - b_2: 2.6640 - d_1: 0.9716 - d_2: 0.9867 - n: 2.1285 - mean_metric: 0.4969 - val_loss: 23.2677 - val_a_1: 2.8691 - val_a_2: 2.7535 - val_b_1: 2.6486 - val_b_2: 2.6301 - val_d_1: 0.9028 - val_d_2: 0.8959 - val_n: 2.0991 - val_mean_metric: 0.4800 - lr: 0.0010
# Epoch 46/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.9045 - a_1: 2.7781 - a_2: 2.8542 - b_1: 2.6945 - b_2: 2.6638 - d_1: 0.9675 - d_2: 0.9820 - n: 2.0622 - mean_metric: 0.4934 - val_loss: 22.4622 - val_a_1: 2.8644 - val_a_2: 2.7432 - val_b_1: 2.5997 - val_b_2: 2.6023 - val_d_1: 0.8618 - val_d_2: 0.8703 - val_n: 2.0753 - val_mean_metric: 0.4740 - lr: 0.0010
# Epoch 47/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.7521 - a_1: 2.7912 - a_2: 2.8441 - b_1: 2.6652 - b_2: 2.6593 - d_1: 0.9813 - d_2: 0.9655 - n: 2.0834 - mean_metric: 0.4930 - val_loss: 22.4330 - val_a_1: 2.8898 - val_a_2: 2.7544 - val_b_1: 2.6581 - val_b_2: 2.5911 - val_d_1: 0.9141 - val_d_2: 0.8539 - val_n: 2.1393 - val_mean_metric: 0.4800 - lr: 0.0010
# Epoch 48/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.6328 - a_1: 2.7704 - a_2: 2.8591 - b_1: 2.6992 - b_2: 2.6381 - d_1: 0.9653 - d_2: 0.9684 - n: 2.0803 - mean_metric: 0.4927 - val_loss: 22.4231 - val_a_1: 2.9013 - val_a_2: 2.7629 - val_b_1: 2.6497 - val_b_2: 2.6015 - val_d_1: 0.8853 - val_d_2: 0.8597 - val_n: 2.0963 - val_mean_metric: 0.4786 - lr: 0.0010
# Epoch 49/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.6988 - a_1: 2.8098 - a_2: 2.8479 - b_1: 2.6966 - b_2: 2.6596 - d_1: 0.9661 - d_2: 0.9770 - n: 2.1481 - mean_metric: 0.4969 - val_loss: 22.2265 - val_a_1: 2.9280 - val_a_2: 2.7352 - val_b_1: 2.7045 - val_b_2: 2.6964 - val_d_1: 0.8684 - val_d_2: 0.8593 - val_n: 2.0784 - val_mean_metric: 0.4823 - lr: 0.0010
# Epoch 50/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 24.4254 - a_1: 2.7848 - a_2: 2.8687 - b_1: 2.6814 - b_2: 2.6688 - d_1: 0.9528 - d_2: 0.9631 - n: 2.2020 - mean_metric: 0.4973 - val_loss: 21.9249 - val_a_1: 2.8571 - val_a_2: 2.7651 - val_b_1: 2.6692 - val_b_2: 2.5927 - val_d_1: 0.8624 - val_d_2: 0.8467 - val_n: 2.1906 - val_mean_metric: 0.4794 - lr: 0.0010
# Epoch 51/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.6678 - a_1: 2.7709 - a_2: 2.8578 - b_1: 2.6833 - b_2: 2.6232 - d_1: 0.9712 - d_2: 0.9756 - n: 2.1844 - mean_metric: 0.4955 - val_loss: 22.8590 - val_a_1: 2.9181 - val_a_2: 2.7431 - val_b_1: 2.6553 - val_b_2: 2.6220 - val_d_1: 0.8848 - val_d_2: 0.8986 - val_n: 2.1224 - val_mean_metric: 0.4814 - lr: 0.0010
# Epoch 52/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.4566 - a_1: 2.7934 - a_2: 2.8493 - b_1: 2.6766 - b_2: 2.6605 - d_1: 0.9580 - d_2: 0.9732 - n: 2.1151 - mean_metric: 0.4942 - val_loss: 22.3405 - val_a_1: 2.9098 - val_a_2: 2.7579 - val_b_1: 2.5956 - val_b_2: 2.6161 - val_d_1: 0.8439 - val_d_2: 0.8888 - val_n: 2.0039 - val_mean_metric: 0.4740 - lr: 0.0010
# Epoch 53/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.3441 - a_1: 2.7826 - a_2: 2.8442 - b_1: 2.7004 - b_2: 2.6353 - d_1: 0.9661 - d_2: 0.9589 - n: 2.0384 - mean_metric: 0.4909 - val_loss: 22.5855 - val_a_1: 2.8812 - val_a_2: 2.7229 - val_b_1: 2.6089 - val_b_2: 2.7263 - val_d_1: 0.9126 - val_d_2: 0.8601 - val_n: 2.0578 - val_mean_metric: 0.4790 - lr: 0.0010
# Epoch 54/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.0374 - a_1: 2.7648 - a_2: 2.8218 - b_1: 2.6703 - b_2: 2.6595 - d_1: 0.9402 - d_2: 0.9524 - n: 2.0591 - mean_metric: 0.4890 - val_loss: 22.4217 - val_a_1: 2.8959 - val_a_2: 2.8005 - val_b_1: 2.5819 - val_b_2: 2.6189 - val_d_1: 0.8816 - val_d_2: 0.8927 - val_n: 2.0938 - val_mean_metric: 0.4789 - lr: 0.0010
# Epoch 55/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.1245 - a_1: 2.8050 - a_2: 2.8473 - b_1: 2.6573 - b_2: 2.6433 - d_1: 0.9455 - d_2: 0.9623 - n: 2.0638 - mean_metric: 0.4908 - val_loss: 21.8716 - val_a_1: 2.8877 - val_a_2: 2.7876 - val_b_1: 2.5681 - val_b_2: 2.6454 - val_d_1: 0.8713 - val_d_2: 0.8509 - val_n: 2.0670 - val_mean_metric: 0.4761 - lr: 0.0010
# Epoch 56/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 24.2367 - a_1: 2.7698 - a_2: 2.8484 - b_1: 2.6388 - b_2: 2.6846 - d_1: 0.9507 - d_2: 0.9617 - n: 1.9894 - mean_metric: 0.4882 - val_loss: 21.8885 - val_a_1: 2.9062 - val_a_2: 2.7142 - val_b_1: 2.5217 - val_b_2: 2.6370 - val_d_1: 0.8414 - val_d_2: 0.8606 - val_n: 1.9352 - val_mean_metric: 0.4675 - lr: 0.0010
# Epoch 57/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 23.9624 - a_1: 2.7806 - a_2: 2.8494 - b_1: 2.6546 - b_2: 2.6298 - d_1: 0.9412 - d_2: 0.9509 - n: 1.9799 - mean_metric: 0.4863 - val_loss: 21.4078 - val_a_1: 2.8893 - val_a_2: 2.7954 - val_b_1: 2.5741 - val_b_2: 2.6472 - val_d_1: 0.8369 - val_d_2: 0.8474 - val_n: 1.9249 - val_mean_metric: 0.4708 - lr: 0.0010
# Epoch 58/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 23.6099 - a_1: 2.7581 - a_2: 2.8467 - b_1: 2.6606 - b_2: 2.6690 - d_1: 0.9322 - d_2: 0.9414 - n: 1.9443 - mean_metric: 0.4852 - val_loss: 21.5540 - val_a_1: 2.8960 - val_a_2: 2.7404 - val_b_1: 2.6297 - val_b_2: 2.6639 - val_d_1: 0.8304 - val_d_2: 0.8423 - val_n: 2.0145 - val_mean_metric: 0.4740 - lr: 0.0010
# Epoch 59/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 23.6126 - a_1: 2.7868 - a_2: 2.8522 - b_1: 2.6282 - b_2: 2.6406 - d_1: 0.9289 - d_2: 0.9474 - n: 2.0092 - mean_metric: 0.4866 - val_loss: 21.1737 - val_a_1: 2.8876 - val_a_2: 2.7481 - val_b_1: 2.6215 - val_b_2: 2.5946 - val_d_1: 0.8409 - val_d_2: 0.8269 - val_n: 2.0118 - val_mean_metric: 0.4713 - lr: 0.0010
# Epoch 60/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 23.7302 - a_1: 2.7853 - a_2: 2.8520 - b_1: 2.6725 - b_2: 2.6160 - d_1: 0.9493 - d_2: 0.9432 - n: 1.9536 - mean_metric: 0.4859 - val_loss: 21.5813 - val_a_1: 2.9293 - val_a_2: 2.7325 - val_b_1: 2.5977 - val_b_2: 2.6389 - val_d_1: 0.8596 - val_d_2: 0.8453 - val_n: 1.9074 - val_mean_metric: 0.4706 - lr: 0.0010
# Epoch 61/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 23.5899 - a_1: 2.7717 - a_2: 2.8388 - b_1: 2.6485 - b_2: 2.6260 - d_1: 0.9372 - d_2: 0.9408 - n: 1.9167 - mean_metric: 0.4827 - val_loss: 21.1530 - val_a_1: 2.8863 - val_a_2: 2.7347 - val_b_1: 2.5711 - val_b_2: 2.6338 - val_d_1: 0.8435 - val_d_2: 0.8090 - val_n: 1.9996 - val_mean_metric: 0.4695 - lr: 0.0010
# Epoch 62/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 23.3300 - a_1: 2.7535 - a_2: 2.8452 - b_1: 2.6079 - b_2: 2.6374 - d_1: 0.9307 - d_2: 0.9291 - n: 1.9661 - mean_metric: 0.4825 - val_loss: 21.3388 - val_a_1: 2.8623 - val_a_2: 2.7723 - val_b_1: 2.5738 - val_b_2: 2.6584 - val_d_1: 0.8555 - val_d_2: 0.8549 - val_n: 2.0002 - val_mean_metric: 0.4728 - lr: 0.0010
# Epoch 63/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 23.1477 - a_1: 2.7438 - a_2: 2.8413 - b_1: 2.6320 - b_2: 2.6329 - d_1: 0.9210 - d_2: 0.9302 - n: 1.9715 - mean_metric: 0.4826 - val_loss: 20.9444 - val_a_1: 2.8754 - val_a_2: 2.7921 - val_b_1: 2.6294 - val_b_2: 2.5727 - val_d_1: 0.8319 - val_d_2: 0.8300 - val_n: 1.9724 - val_mean_metric: 0.4704 - lr: 0.0010
# Epoch 64/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 23.2787 - a_1: 2.7638 - a_2: 2.8622 - b_1: 2.6347 - b_2: 2.6015 - d_1: 0.9243 - d_2: 0.9439 - n: 1.9774 - mean_metric: 0.4838 - val_loss: 21.2944 - val_a_1: 2.8936 - val_a_2: 2.7276 - val_b_1: 2.5293 - val_b_2: 2.6342 - val_d_1: 0.8552 - val_d_2: 0.8482 - val_n: 1.9423 - val_mean_metric: 0.4680 - lr: 0.0010
# Epoch 65/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 23.0339 - a_1: 2.7617 - a_2: 2.8404 - b_1: 2.6371 - b_2: 2.5915 - d_1: 0.9279 - d_2: 0.9288 - n: 1.9840 - mean_metric: 0.4825 - val_loss: 20.5152 - val_a_1: 2.8306 - val_a_2: 2.7303 - val_b_1: 2.6340 - val_b_2: 2.6197 - val_d_1: 0.8058 - val_d_2: 0.8177 - val_n: 1.9330 - val_mean_metric: 0.4661 - lr: 0.0010
# Epoch 66/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 23.1547 - a_1: 2.7422 - a_2: 2.8224 - b_1: 2.6278 - b_2: 2.6080 - d_1: 0.9383 - d_2: 0.9213 - n: 1.8834 - mean_metric: 0.4782 - val_loss: 21.3999 - val_a_1: 2.8502 - val_a_2: 2.7598 - val_b_1: 2.6328 - val_b_2: 2.6183 - val_d_1: 0.8550 - val_d_2: 0.8563 - val_n: 1.8813 - val_mean_metric: 0.4688 - lr: 0.0010
# Epoch 67/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 22.8589 - a_1: 2.7606 - a_2: 2.8656 - b_1: 2.6619 - b_2: 2.6035 - d_1: 0.9144 - d_2: 0.9187 - n: 1.9135 - mean_metric: 0.4814 - val_loss: 20.7525 - val_a_1: 2.8799 - val_a_2: 2.7487 - val_b_1: 2.6320 - val_b_2: 2.5984 - val_d_1: 0.8504 - val_d_2: 0.8109 - val_n: 1.8635 - val_mean_metric: 0.4665 - lr: 0.0010
# Epoch 68/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 23.0044 - a_1: 2.7553 - a_2: 2.8152 - b_1: 2.6404 - b_2: 2.6267 - d_1: 0.9366 - d_2: 0.9235 - n: 1.8736 - mean_metric: 0.4793 - val_loss: 21.2502 - val_a_1: 2.8832 - val_a_2: 2.7071 - val_b_1: 2.5210 - val_b_2: 2.6424 - val_d_1: 0.8663 - val_d_2: 0.8347 - val_n: 1.8689 - val_mean_metric: 0.4645 - lr: 0.0010
# Epoch 69/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 23.0597 - a_1: 2.7594 - a_2: 2.8263 - b_1: 2.6511 - b_2: 2.6433 - d_1: 0.9297 - d_2: 0.9336 - n: 1.8171 - mean_metric: 0.4789 - val_loss: 20.8324 - val_a_1: 2.8376 - val_a_2: 2.7627 - val_b_1: 2.6021 - val_b_2: 2.5967 - val_d_1: 0.8427 - val_d_2: 0.8377 - val_n: 1.7904 - val_mean_metric: 0.4628 - lr: 0.0010
# Epoch 70/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 22.8898 - a_1: 2.7386 - a_2: 2.8306 - b_1: 2.6591 - b_2: 2.5734 - d_1: 0.9278 - d_2: 0.9313 - n: 1.7911 - mean_metric: 0.4753 - val_loss: 21.2353 - val_a_1: 2.8805 - val_a_2: 2.7329 - val_b_1: 2.5453 - val_b_2: 2.6094 - val_d_1: 0.8717 - val_d_2: 0.8514 - val_n: 1.8734 - val_mean_metric: 0.4659 - lr: 0.0010
# Epoch 71/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 22.9008 - a_1: 2.7433 - a_2: 2.8246 - b_1: 2.6570 - b_2: 2.6348 - d_1: 0.9201 - d_2: 0.9365 - n: 1.8281 - mean_metric: 0.4783 - val_loss: 21.1306 - val_a_1: 2.8513 - val_a_2: 2.7211 - val_b_1: 2.6518 - val_b_2: 2.7307 - val_d_1: 0.8672 - val_d_2: 0.8551 - val_n: 1.8604 - val_mean_metric: 0.4715 - lr: 0.0010
# Epoch 72/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 22.8009 - a_1: 2.7617 - a_2: 2.8430 - b_1: 2.6379 - b_2: 2.6610 - d_1: 0.9316 - d_2: 0.9182 - n: 1.8424 - mean_metric: 0.4801 - val_loss: 20.7621 - val_a_1: 2.8527 - val_a_2: 2.7023 - val_b_1: 2.5930 - val_b_2: 2.6141 - val_d_1: 0.8388 - val_d_2: 0.8122 - val_n: 1.8166 - val_mean_metric: 0.4615 - lr: 0.0010
# Epoch 73/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 22.5907 - a_1: 2.7329 - a_2: 2.8368 - b_1: 2.6834 - b_2: 2.5912 - d_1: 0.9100 - d_2: 0.9202 - n: 1.7878 - mean_metric: 0.4757 - val_loss: 20.4295 - val_a_1: 2.8123 - val_a_2: 2.7790 - val_b_1: 2.6329 - val_b_2: 2.6213 - val_d_1: 0.8382 - val_d_2: 0.8262 - val_n: 1.8150 - val_mean_metric: 0.4646 - lr: 0.0010
# Epoch 74/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 22.3653 - a_1: 2.7370 - a_2: 2.8491 - b_1: 2.6575 - b_2: 2.6012 - d_1: 0.9111 - d_2: 0.9123 - n: 1.8379 - mean_metric: 0.4770 - val_loss: 20.5665 - val_a_1: 2.8542 - val_a_2: 2.7383 - val_b_1: 2.6306 - val_b_2: 2.6504 - val_d_1: 0.8307 - val_d_2: 0.8396 - val_n: 1.7583 - val_mean_metric: 0.4639 - lr: 0.0010
# Epoch 75/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 22.3689 - a_1: 2.7314 - a_2: 2.8408 - b_1: 2.6683 - b_2: 2.6087 - d_1: 0.9074 - d_2: 0.9177 - n: 1.7548 - mean_metric: 0.4746 - val_loss: 20.5637 - val_a_1: 2.8243 - val_a_2: 2.7768 - val_b_1: 2.7361 - val_b_2: 2.6533 - val_d_1: 0.8430 - val_d_2: 0.8165 - val_n: 1.6943 - val_mean_metric: 0.4652 - lr: 0.0010
# Epoch 76/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 22.3109 - a_1: 2.7405 - a_2: 2.8459 - b_1: 2.6680 - b_2: 2.6189 - d_1: 0.9175 - d_2: 0.9093 - n: 1.7689 - mean_metric: 0.4757 - val_loss: 20.0921 - val_a_1: 2.7976 - val_a_2: 2.7599 - val_b_1: 2.6409 - val_b_2: 2.6528 - val_d_1: 0.8404 - val_d_2: 0.7988 - val_n: 1.7255 - val_mean_metric: 0.4610 - lr: 0.0010
# Epoch 77/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 22.3186 - a_1: 2.7225 - a_2: 2.8192 - b_1: 2.6440 - b_2: 2.6144 - d_1: 0.9123 - d_2: 0.9182 - n: 1.7473 - mean_metric: 0.4728 - val_loss: 20.1811 - val_a_1: 2.8090 - val_a_2: 2.7326 - val_b_1: 2.6186 - val_b_2: 2.6323 - val_d_1: 0.8556 - val_d_2: 0.7979 - val_n: 1.7073 - val_mean_metric: 0.4590 - lr: 0.0010
# Epoch 78/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 22.2656 - a_1: 2.7319 - a_2: 2.7946 - b_1: 2.6360 - b_2: 2.6019 - d_1: 0.9106 - d_2: 0.9216 - n: 1.7346 - mean_metric: 0.4713 - val_loss: 20.0130 - val_a_1: 2.8493 - val_a_2: 2.6855 - val_b_1: 2.5751 - val_b_2: 2.6571 - val_d_1: 0.8108 - val_d_2: 0.8226 - val_n: 1.7941 - val_mean_metric: 0.4603 - lr: 0.0010
# Epoch 79/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 21.8921 - a_1: 2.7289 - a_2: 2.8110 - b_1: 2.6447 - b_2: 2.6375 - d_1: 0.8986 - d_2: 0.9003 - n: 1.7566 - mean_metric: 0.4729 - val_loss: 20.4751 - val_a_1: 2.8426 - val_a_2: 2.7623 - val_b_1: 2.5632 - val_b_2: 2.6355 - val_d_1: 0.8420 - val_d_2: 0.8406 - val_n: 1.7493 - val_mean_metric: 0.4617 - lr: 0.0010
# Epoch 80/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 21.8280 - a_1: 2.7415 - a_2: 2.8190 - b_1: 2.6207 - b_2: 2.6398 - d_1: 0.8917 - d_2: 0.9038 - n: 1.7796 - mean_metric: 0.4735 - val_loss: 20.7222 - val_a_1: 2.8652 - val_a_2: 2.7276 - val_b_1: 2.6284 - val_b_2: 2.6242 - val_d_1: 0.8537 - val_d_2: 0.8577 - val_n: 1.7575 - val_mean_metric: 0.4643 - lr: 0.0010
# Epoch 81/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.8018 - a_1: 2.7449 - a_2: 2.8402 - b_1: 2.6686 - b_2: 2.6380 - d_1: 0.9003 - d_2: 0.8994 - n: 1.7453 - mean_metric: 0.4748 - val_loss: 20.1194 - val_a_1: 2.8585 - val_a_2: 2.7228 - val_b_1: 2.6250 - val_b_2: 2.6202 - val_d_1: 0.8429 - val_d_2: 0.8175 - val_n: 1.7858 - val_mean_metric: 0.4629 - lr: 0.0010
# Epoch 82/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.9539 - a_1: 2.7474 - a_2: 2.8096 - b_1: 2.6770 - b_2: 2.6142 - d_1: 0.8977 - d_2: 0.9137 - n: 1.7699 - mean_metric: 0.4746 - val_loss: 19.6985 - val_a_1: 2.8592 - val_a_2: 2.7262 - val_b_1: 2.6207 - val_b_2: 2.6618 - val_d_1: 0.8201 - val_d_2: 0.7932 - val_n: 1.7846 - val_mean_metric: 0.4627 - lr: 0.0010
# Epoch 83/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.6614 - a_1: 2.7160 - a_2: 2.8208 - b_1: 2.6484 - b_2: 2.6187 - d_1: 0.8937 - d_2: 0.8962 - n: 1.7610 - mean_metric: 0.4721 - val_loss: 20.3283 - val_a_1: 2.8155 - val_a_2: 2.6973 - val_b_1: 2.6212 - val_b_2: 2.6177 - val_d_1: 0.8509 - val_d_2: 0.8257 - val_n: 1.7520 - val_mean_metric: 0.4599 - lr: 0.0010
# Epoch 84/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.7162 - a_1: 2.7494 - a_2: 2.8015 - b_1: 2.6543 - b_2: 2.6199 - d_1: 0.9065 - d_2: 0.8946 - n: 1.7094 - mean_metric: 0.4715 - val_loss: 20.0742 - val_a_1: 2.9024 - val_a_2: 2.7450 - val_b_1: 2.6181 - val_b_2: 2.6330 - val_d_1: 0.8553 - val_d_2: 0.8138 - val_n: 1.7288 - val_mean_metric: 0.4637 - lr: 0.0010
# Epoch 85/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.5992 - a_1: 2.7152 - a_2: 2.8241 - b_1: 2.6454 - b_2: 2.6070 - d_1: 0.8966 - d_2: 0.8961 - n: 1.7069 - mean_metric: 0.4701 - val_loss: 20.0576 - val_a_1: 2.8243 - val_a_2: 2.7461 - val_b_1: 2.6405 - val_b_2: 2.6183 - val_d_1: 0.8301 - val_d_2: 0.8033 - val_n: 1.7120 - val_mean_metric: 0.4597 - lr: 0.0010
# Epoch 86/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.3710 - a_1: 2.7202 - a_2: 2.8239 - b_1: 2.6411 - b_2: 2.6203 - d_1: 0.8892 - d_2: 0.8862 - n: 1.7159 - mean_metric: 0.4702 - val_loss: 19.9160 - val_a_1: 2.8196 - val_a_2: 2.6976 - val_b_1: 2.5876 - val_b_2: 2.6785 - val_d_1: 0.8284 - val_d_2: 0.8268 - val_n: 1.7244 - val_mean_metric: 0.4593 - lr: 0.0010
# Epoch 87/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.5906 - a_1: 2.7077 - a_2: 2.8246 - b_1: 2.6228 - b_2: 2.6024 - d_1: 0.8992 - d_2: 0.9023 - n: 1.7738 - mean_metric: 0.4714 - val_loss: 19.8301 - val_a_1: 2.8321 - val_a_2: 2.7476 - val_b_1: 2.5812 - val_b_2: 2.6720 - val_d_1: 0.8383 - val_d_2: 0.8127 - val_n: 1.7882 - val_mean_metric: 0.4629 - lr: 0.0010
# Epoch 88/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.4894 - a_1: 2.7224 - a_2: 2.8174 - b_1: 2.6395 - b_2: 2.5948 - d_1: 0.8907 - d_2: 0.9009 - n: 1.7647 - mean_metric: 0.4714 - val_loss: 19.7339 - val_a_1: 2.7966 - val_a_2: 2.7155 - val_b_1: 2.6072 - val_b_2: 2.6309 - val_d_1: 0.8165 - val_d_2: 0.7996 - val_n: 1.7797 - val_mean_metric: 0.4588 - lr: 0.0010
# Epoch 89/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.3904 - a_1: 2.7090 - a_2: 2.8112 - b_1: 2.6303 - b_2: 2.6309 - d_1: 0.8847 - d_2: 0.8991 - n: 1.7980 - mean_metric: 0.4723 - val_loss: 19.9298 - val_a_1: 2.8194 - val_a_2: 2.7500 - val_b_1: 2.6062 - val_b_2: 2.6725 - val_d_1: 0.8374 - val_d_2: 0.8430 - val_n: 1.8246 - val_mean_metric: 0.4655 - lr: 0.0010
# Epoch 90/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.3279 - a_1: 2.7292 - a_2: 2.8299 - b_1: 2.6379 - b_2: 2.6251 - d_1: 0.8988 - d_2: 0.8902 - n: 1.8504 - mean_metric: 0.4756 - val_loss: 19.8285 - val_a_1: 2.8134 - val_a_2: 2.7493 - val_b_1: 2.6275 - val_b_2: 2.6615 - val_d_1: 0.8767 - val_d_2: 0.8066 - val_n: 1.8208 - val_mean_metric: 0.4656 - lr: 0.0010
# Epoch 91/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.3956 - a_1: 2.7212 - a_2: 2.8452 - b_1: 2.6553 - b_2: 2.6266 - d_1: 0.9075 - d_2: 0.8880 - n: 1.8162 - mean_metric: 0.4756 - val_loss: 19.4409 - val_a_1: 2.8040 - val_a_2: 2.7486 - val_b_1: 2.6093 - val_b_2: 2.6428 - val_d_1: 0.8204 - val_d_2: 0.7900 - val_n: 1.7968 - val_mean_metric: 0.4609 - lr: 0.0010
# Epoch 92/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.1977 - a_1: 2.7109 - a_2: 2.8317 - b_1: 2.6516 - b_2: 2.6063 - d_1: 0.8879 - d_2: 0.8879 - n: 1.7735 - mean_metric: 0.4719 - val_loss: 19.7395 - val_a_1: 2.8212 - val_a_2: 2.7413 - val_b_1: 2.6180 - val_b_2: 2.6331 - val_d_1: 0.8350 - val_d_2: 0.8126 - val_n: 1.7910 - val_mean_metric: 0.4622 - lr: 0.0010
# Epoch 93/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.0923 - a_1: 2.7231 - a_2: 2.8219 - b_1: 2.6348 - b_2: 2.5997 - d_1: 0.8817 - d_2: 0.8912 - n: 1.7764 - mean_metric: 0.4712 - val_loss: 19.3161 - val_a_1: 2.8375 - val_a_2: 2.6899 - val_b_1: 2.5630 - val_b_2: 2.5999 - val_d_1: 0.8228 - val_d_2: 0.8140 - val_n: 1.7733 - val_mean_metric: 0.4573 - lr: 0.0010
# Epoch 94/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 21.0820 - a_1: 2.7063 - a_2: 2.7990 - b_1: 2.6424 - b_2: 2.6238 - d_1: 0.8781 - d_2: 0.8850 - n: 1.7460 - mean_metric: 0.4696 - val_loss: 19.1226 - val_a_1: 2.7834 - val_a_2: 2.7451 - val_b_1: 2.6560 - val_b_2: 2.6339 - val_d_1: 0.8044 - val_d_2: 0.8075 - val_n: 1.7702 - val_mean_metric: 0.4605 - lr: 0.0010
# Epoch 95/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 20.8696 - a_1: 2.7295 - a_2: 2.8191 - b_1: 2.6453 - b_2: 2.5928 - d_1: 0.8664 - d_2: 0.8828 - n: 1.7580 - mean_metric: 0.4701 - val_loss: 19.4352 - val_a_1: 2.8492 - val_a_2: 2.7261 - val_b_1: 2.5764 - val_b_2: 2.6970 - val_d_1: 0.8247 - val_d_2: 0.8104 - val_n: 1.7773 - val_mean_metric: 0.4625 - lr: 0.0010
# Epoch 96/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 20.8858 - a_1: 2.7169 - a_2: 2.8119 - b_1: 2.6616 - b_2: 2.6157 - d_1: 0.8768 - d_2: 0.8868 - n: 1.7419 - mean_metric: 0.4706 - val_loss: 19.4843 - val_a_1: 2.8500 - val_a_2: 2.7064 - val_b_1: 2.6287 - val_b_2: 2.6384 - val_d_1: 0.8223 - val_d_2: 0.8215 - val_n: 1.7573 - val_mean_metric: 0.4613 - lr: 0.0010
# Epoch 97/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 20.9864 - a_1: 2.7240 - a_2: 2.8133 - b_1: 2.6530 - b_2: 2.6060 - d_1: 0.8861 - d_2: 0.8804 - n: 1.7235 - mean_metric: 0.4698 - val_loss: 19.5130 - val_a_1: 2.8044 - val_a_2: 2.7243 - val_b_1: 2.6339 - val_b_2: 2.6564 - val_d_1: 0.8334 - val_d_2: 0.8093 - val_n: 1.6831 - val_mean_metric: 0.4588 - lr: 0.0010
# Epoch 98/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.6852 - a_1: 2.7394 - a_2: 2.8130 - b_1: 2.6586 - b_2: 2.6367 - d_1: 0.8771 - d_2: 0.8708 - n: 1.7309 - mean_metric: 0.4712 - val_loss: 19.3348 - val_a_1: 2.8642 - val_a_2: 2.7175 - val_b_1: 2.6241 - val_b_2: 2.6235 - val_d_1: 0.8196 - val_d_2: 0.8219 - val_n: 1.7074 - val_mean_metric: 0.4598 - lr: 0.0010
# Epoch 99/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.8461 - a_1: 2.7304 - a_2: 2.8047 - b_1: 2.6561 - b_2: 2.6168 - d_1: 0.8689 - d_2: 0.8912 - n: 1.7201 - mean_metric: 0.4699 - val_loss: 18.8720 - val_a_1: 2.8227 - val_a_2: 2.7060 - val_b_1: 2.5996 - val_b_2: 2.6599 - val_d_1: 0.7913 - val_d_2: 0.8013 - val_n: 1.7433 - val_mean_metric: 0.4581 - lr: 0.0010
# Epoch 100/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.4498 - a_1: 2.7403 - a_2: 2.8014 - b_1: 2.6598 - b_2: 2.5897 - d_1: 0.8697 - d_2: 0.8711 - n: 1.7478 - mean_metric: 0.4696 - val_loss: 18.5856 - val_a_1: 2.8358 - val_a_2: 2.7170 - val_b_1: 2.6074 - val_b_2: 2.6106 - val_d_1: 0.7837 - val_d_2: 0.7989 - val_n: 1.7747 - val_mean_metric: 0.4582 - lr: 0.0010
# Epoch 101/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.6502 - a_1: 2.7147 - a_2: 2.8225 - b_1: 2.6536 - b_2: 2.5949 - d_1: 0.8677 - d_2: 0.8864 - n: 1.7823 - mean_metric: 0.4710 - val_loss: 18.9838 - val_a_1: 2.7935 - val_a_2: 2.7474 - val_b_1: 2.6406 - val_b_2: 2.7094 - val_d_1: 0.8397 - val_d_2: 0.8007 - val_n: 1.7588 - val_mean_metric: 0.4635 - lr: 0.0010
# Epoch 102/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.7909 - a_1: 2.7099 - a_2: 2.8265 - b_1: 2.6441 - b_2: 2.6194 - d_1: 0.8710 - d_2: 0.8938 - n: 1.7774 - mean_metric: 0.4717 - val_loss: 18.5918 - val_a_1: 2.8030 - val_a_2: 2.7477 - val_b_1: 2.6266 - val_b_2: 2.6214 - val_d_1: 0.7943 - val_d_2: 0.7887 - val_n: 1.7644 - val_mean_metric: 0.4588 - lr: 0.0010
# Epoch 103/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.2912 - a_1: 2.7307 - a_2: 2.8331 - b_1: 2.6421 - b_2: 2.5886 - d_1: 0.8677 - d_2: 0.8579 - n: 1.8114 - mean_metric: 0.4715 - val_loss: 19.1044 - val_a_1: 2.8251 - val_a_2: 2.7437 - val_b_1: 2.6520 - val_b_2: 2.5968 - val_d_1: 0.8249 - val_d_2: 0.8095 - val_n: 1.7968 - val_mean_metric: 0.4621 - lr: 0.0010
# Epoch 104/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 20.4221 - a_1: 2.7094 - a_2: 2.8158 - b_1: 2.6312 - b_2: 2.5924 - d_1: 0.8749 - d_2: 0.8632 - n: 1.8389 - mean_metric: 0.4712 - val_loss: 18.8395 - val_a_1: 2.7965 - val_a_2: 2.7190 - val_b_1: 2.6364 - val_b_2: 2.5883 - val_d_1: 0.7953 - val_d_2: 0.8135 - val_n: 1.7565 - val_mean_metric: 0.4575 - lr: 0.0010
# Epoch 105/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.4326 - a_1: 2.7162 - a_2: 2.8181 - b_1: 2.6526 - b_2: 2.6013 - d_1: 0.8750 - d_2: 0.8699 - n: 1.7775 - mean_metric: 0.4707 - val_loss: 18.9393 - val_a_1: 2.8022 - val_a_2: 2.7573 - val_b_1: 2.6416 - val_b_2: 2.6174 - val_d_1: 0.8205 - val_d_2: 0.7873 - val_n: 1.7623 - val_mean_metric: 0.4602 - lr: 0.0010
# Epoch 106/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.4471 - a_1: 2.7153 - a_2: 2.8117 - b_1: 2.6399 - b_2: 2.6065 - d_1: 0.8592 - d_2: 0.8832 - n: 1.7603 - mean_metric: 0.4695 - val_loss: 18.6925 - val_a_1: 2.8279 - val_a_2: 2.7370 - val_b_1: 2.6144 - val_b_2: 2.5980 - val_d_1: 0.7988 - val_d_2: 0.7996 - val_n: 1.8229 - val_mean_metric: 0.4605 - lr: 0.0010
# Epoch 107/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 20.2524 - a_1: 2.6998 - a_2: 2.8144 - b_1: 2.6317 - b_2: 2.6191 - d_1: 0.8631 - d_2: 0.8650 - n: 1.7588 - mean_metric: 0.4687 - val_loss: 19.0550 - val_a_1: 2.8119 - val_a_2: 2.7541 - val_b_1: 2.5769 - val_b_2: 2.6044 - val_d_1: 0.8190 - val_d_2: 0.8126 - val_n: 1.7470 - val_mean_metric: 0.4581 - lr: 0.0010
# Epoch 108/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 20.2152 - a_1: 2.7164 - a_2: 2.8151 - b_1: 2.6332 - b_2: 2.5874 - d_1: 0.8678 - d_2: 0.8630 - n: 1.7807 - mean_metric: 0.4690 - val_loss: 18.3952 - val_a_1: 2.8328 - val_a_2: 2.7320 - val_b_1: 2.6180 - val_b_2: 2.5946 - val_d_1: 0.8022 - val_d_2: 0.7841 - val_n: 1.7831 - val_mean_metric: 0.4588 - lr: 0.0010
# Epoch 109/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 19.9662 - a_1: 2.7225 - a_2: 2.8172 - b_1: 2.6302 - b_2: 2.5807 - d_1: 0.8519 - d_2: 0.8594 - n: 1.7800 - mean_metric: 0.4684 - val_loss: 18.4847 - val_a_1: 2.8225 - val_a_2: 2.7484 - val_b_1: 2.6103 - val_b_2: 2.6144 - val_d_1: 0.8034 - val_d_2: 0.7809 - val_n: 1.8350 - val_mean_metric: 0.4610 - lr: 0.0010
# Epoch 110/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 20.0156 - a_1: 2.7284 - a_2: 2.8184 - b_1: 2.6110 - b_2: 2.6164 - d_1: 0.8477 - d_2: 0.8639 - n: 1.8042 - mean_metric: 0.4699 - val_loss: 18.4622 - val_a_1: 2.8357 - val_a_2: 2.7303 - val_b_1: 2.5675 - val_b_2: 2.6685 - val_d_1: 0.8038 - val_d_2: 0.7910 - val_n: 1.8211 - val_mean_metric: 0.4611 - lr: 0.0010
# Epoch 111/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 19.9007 - a_1: 2.7112 - a_2: 2.8163 - b_1: 2.6095 - b_2: 2.5844 - d_1: 0.8560 - d_2: 0.8544 - n: 1.7844 - mean_metric: 0.4676 - val_loss: 18.5361 - val_a_1: 2.8079 - val_a_2: 2.7508 - val_b_1: 2.5753 - val_b_2: 2.6038 - val_d_1: 0.8125 - val_d_2: 0.7902 - val_n: 1.8063 - val_mean_metric: 0.4588 - lr: 0.0010
# Epoch 112/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 20.0239 - a_1: 2.7114 - a_2: 2.8045 - b_1: 2.6263 - b_2: 2.5801 - d_1: 0.8579 - d_2: 0.8653 - n: 1.8321 - mean_metric: 0.4695 - val_loss: 18.7192 - val_a_1: 2.8377 - val_a_2: 2.7259 - val_b_1: 2.6137 - val_b_2: 2.5847 - val_d_1: 0.8135 - val_d_2: 0.8091 - val_n: 1.8304 - val_mean_metric: 0.4610 - lr: 0.0010
# Epoch 113/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 19.9036 - a_1: 2.7012 - a_2: 2.8004 - b_1: 2.6331 - b_2: 2.6087 - d_1: 0.8617 - d_2: 0.8524 - n: 1.8122 - mean_metric: 0.4693 - val_loss: 18.2834 - val_a_1: 2.8062 - val_a_2: 2.7145 - val_b_1: 2.6349 - val_b_2: 2.5906 - val_d_1: 0.7908 - val_d_2: 0.8082 - val_n: 1.8046 - val_mean_metric: 0.4589 - lr: 0.0010
# Epoch 114/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 19.8030 - a_1: 2.7249 - a_2: 2.7913 - b_1: 2.6342 - b_2: 2.6005 - d_1: 0.8512 - d_2: 0.8548 - n: 1.8152 - mean_metric: 0.4694 - val_loss: 18.2069 - val_a_1: 2.8352 - val_a_2: 2.7229 - val_b_1: 2.5876 - val_b_2: 2.6534 - val_d_1: 0.7880 - val_d_2: 0.7832 - val_n: 1.8019 - val_mean_metric: 0.4596 - lr: 0.0010
# Epoch 115/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 19.7895 - a_1: 2.6925 - a_2: 2.8060 - b_1: 2.6314 - b_2: 2.5981 - d_1: 0.8542 - d_2: 0.8506 - n: 1.7904 - mean_metric: 0.4678 - val_loss: 18.6559 - val_a_1: 2.8218 - val_a_2: 2.7399 - val_b_1: 2.6201 - val_b_2: 2.5754 - val_d_1: 0.8206 - val_d_2: 0.8153 - val_n: 1.8095 - val_mean_metric: 0.4606 - lr: 0.0010
# Epoch 116/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 19.7701 - a_1: 2.7268 - a_2: 2.8089 - b_1: 2.6392 - b_2: 2.5856 - d_1: 0.8465 - d_2: 0.8609 - n: 1.7674 - mean_metric: 0.4681 - val_loss: 18.2789 - val_a_1: 2.8225 - val_a_2: 2.7239 - val_b_1: 2.6162 - val_b_2: 2.6905 - val_d_1: 0.8203 - val_d_2: 0.7618 - val_n: 1.8001 - val_mean_metric: 0.4617 - lr: 0.0010
# Epoch 117/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 19.7682 - a_1: 2.7215 - a_2: 2.8092 - b_1: 2.6425 - b_2: 2.6022 - d_1: 0.8551 - d_2: 0.8564 - n: 1.8320 - mean_metric: 0.4709 - val_loss: 18.0190 - val_a_1: 2.8235 - val_a_2: 2.7427 - val_b_1: 2.6044 - val_b_2: 2.5782 - val_d_1: 0.7888 - val_d_2: 0.7837 - val_n: 1.8773 - val_mean_metric: 0.4605 - lr: 0.0010
# Epoch 118/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 19.5296 - a_1: 2.7290 - a_2: 2.8053 - b_1: 2.6352 - b_2: 2.5938 - d_1: 0.8478 - d_2: 0.8412 - n: 1.8633 - mean_metric: 0.4708 - val_loss: 18.1778 - val_a_1: 2.8114 - val_a_2: 2.7612 - val_b_1: 2.5711 - val_b_2: 2.6232 - val_d_1: 0.8026 - val_d_2: 0.7752 - val_n: 1.8678 - val_mean_metric: 0.4609 - lr: 0.0010
# Epoch 119/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 19.5234 - a_1: 2.7139 - a_2: 2.8059 - b_1: 2.6225 - b_2: 2.6231 - d_1: 0.8462 - d_2: 0.8492 - n: 1.8732 - mean_metric: 0.4715 - val_loss: 18.1477 - val_a_1: 2.8255 - val_a_2: 2.7133 - val_b_1: 2.5855 - val_b_2: 2.6416 - val_d_1: 0.7880 - val_d_2: 0.7972 - val_n: 1.8901 - val_mean_metric: 0.4619 - lr: 0.0010
# Epoch 120/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 19.3680 - a_1: 2.7076 - a_2: 2.8066 - b_1: 2.6286 - b_2: 2.6011 - d_1: 0.8453 - d_2: 0.8329 - n: 1.8772 - mean_metric: 0.4702 - val_loss: 18.2696 - val_a_1: 2.7963 - val_a_2: 2.7517 - val_b_1: 2.6257 - val_b_2: 2.6338 - val_d_1: 0.7924 - val_d_2: 0.7915 - val_n: 1.9094 - val_mean_metric: 0.4638 - lr: 0.0010
# Epoch 121/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 19.4879 - a_1: 2.7184 - a_2: 2.8165 - b_1: 2.6389 - b_2: 2.6030 - d_1: 0.8423 - d_2: 0.8456 - n: 1.8462 - mean_metric: 0.4707 - val_loss: 18.1462 - val_a_1: 2.8253 - val_a_2: 2.7428 - val_b_1: 2.5921 - val_b_2: 2.5981 - val_d_1: 0.8077 - val_d_2: 0.7860 - val_n: 1.8514 - val_mean_metric: 0.4606 - lr: 0.0010
# Epoch 122/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 19.1984 - a_1: 2.7122 - a_2: 2.8175 - b_1: 2.6283 - b_2: 2.5939 - d_1: 0.8393 - d_2: 0.8307 - n: 1.8740 - mean_metric: 0.4702 - val_loss: 17.9241 - val_a_1: 2.8065 - val_a_2: 2.7599 - val_b_1: 2.6183 - val_b_2: 2.5807 - val_d_1: 0.7820 - val_d_2: 0.7681 - val_n: 1.8354 - val_mean_metric: 0.4589 - lr: 0.0010
# Epoch 123/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 19.3671 - a_1: 2.7143 - a_2: 2.8231 - b_1: 2.6212 - b_2: 2.5687 - d_1: 0.8457 - d_2: 0.8353 - n: 1.8380 - mean_metric: 0.4685 - val_loss: 17.9999 - val_a_1: 2.7943 - val_a_2: 2.7215 - val_b_1: 2.6465 - val_b_2: 2.5446 - val_d_1: 0.7789 - val_d_2: 0.8029 - val_n: 1.7838 - val_mean_metric: 0.4564 - lr: 0.0010
# Epoch 124/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 19.3398 - a_1: 2.7087 - a_2: 2.8082 - b_1: 2.6362 - b_2: 2.5789 - d_1: 0.8420 - d_2: 0.8406 - n: 1.7864 - mean_metric: 0.4671 - val_loss: 17.8033 - val_a_1: 2.8312 - val_a_2: 2.7494 - val_b_1: 2.6076 - val_b_2: 2.5890 - val_d_1: 0.8008 - val_d_2: 0.7709 - val_n: 1.7188 - val_mean_metric: 0.4563 - lr: 0.0010
# Epoch 125/1000
# ...
# Epoch 960/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2607 - a_1: 2.7212 - a_2: 2.8181 - b_1: 1.4717 - b_2: 1.4687 - d_1: 0.5485 - d_2: 0.5424 - n: 1.4705 - mean_metric: 0.3631 - val_loss: 16.6831 - val_a_1: 2.8797 - val_a_2: 2.7485 - val_b_1: 1.2843 - val_b_2: 1.1822 - val_d_1: 0.7754 - val_d_2: 0.7570 - val_n: 1.4431 - val_mean_metric: 0.3591 - lr: 7.7650e-05
# Epoch 961/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2117 - a_1: 2.7112 - a_2: 2.8136 - b_1: 1.4679 - b_2: 1.4712 - d_1: 0.5418 - d_2: 0.5434 - n: 1.4819 - mean_metric: 0.3627 - val_loss: 16.5589 - val_a_1: 2.8759 - val_a_2: 2.7447 - val_b_1: 1.2812 - val_b_2: 1.1835 - val_d_1: 0.7652 - val_d_2: 0.7542 - val_n: 1.4470 - val_mean_metric: 0.3585 - lr: 7.6000e-05
# Epoch 962/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.3571 - a_1: 2.7107 - a_2: 2.8088 - b_1: 1.4999 - b_2: 1.4725 - d_1: 0.5540 - d_2: 0.5495 - n: 1.4703 - mean_metric: 0.3639 - val_loss: 16.5694 - val_a_1: 2.8662 - val_a_2: 2.7422 - val_b_1: 1.2850 - val_b_2: 1.1791 - val_d_1: 0.7723 - val_d_2: 0.7474 - val_n: 1.4430 - val_mean_metric: 0.3580 - lr: 7.4350e-05
# Epoch 963/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2381 - a_1: 2.7213 - a_2: 2.8098 - b_1: 1.4649 - b_2: 1.4829 - d_1: 0.5415 - d_2: 0.5420 - n: 1.4804 - mean_metric: 0.3632 - val_loss: 16.6865 - val_a_1: 2.8706 - val_a_2: 2.7403 - val_b_1: 1.2885 - val_b_2: 1.1789 - val_d_1: 0.7832 - val_d_2: 0.7477 - val_n: 1.4456 - val_mean_metric: 0.3586 - lr: 7.2700e-05
# Epoch 964/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2583 - a_1: 2.7036 - a_2: 2.8103 - b_1: 1.4725 - b_2: 1.4734 - d_1: 0.5414 - d_2: 0.5487 - n: 1.4779 - mean_metric: 0.3627 - val_loss: 16.4892 - val_a_1: 2.8704 - val_a_2: 2.7506 - val_b_1: 1.3091 - val_b_2: 1.1738 - val_d_1: 0.7702 - val_d_2: 0.7425 - val_n: 1.4440 - val_mean_metric: 0.3588 - lr: 7.1050e-05
# Epoch 965/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.3282 - a_1: 2.7112 - a_2: 2.8160 - b_1: 1.5037 - b_2: 1.4689 - d_1: 0.5442 - d_2: 0.5506 - n: 1.4749 - mean_metric: 0.3641 - val_loss: 16.4873 - val_a_1: 2.8687 - val_a_2: 2.7471 - val_b_1: 1.2918 - val_b_2: 1.1619 - val_d_1: 0.7642 - val_d_2: 0.7451 - val_n: 1.4430 - val_mean_metric: 0.3575 - lr: 6.9400e-05
# Epoch 966/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 12.2737 - a_1: 2.7139 - a_2: 2.8179 - b_1: 1.4693 - b_2: 1.4637 - d_1: 0.5418 - d_2: 0.5473 - n: 1.4718 - mean_metric: 0.3626 - val_loss: 16.5611 - val_a_1: 2.8701 - val_a_2: 2.7504 - val_b_1: 1.2954 - val_b_2: 1.1574 - val_d_1: 0.7708 - val_d_2: 0.7471 - val_n: 1.4465 - val_mean_metric: 0.3581 - lr: 6.7750e-05
# Epoch 967/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 12.3138 - a_1: 2.7132 - a_2: 2.8096 - b_1: 1.4945 - b_2: 1.4611 - d_1: 0.5475 - d_2: 0.5432 - n: 1.4718 - mean_metric: 0.3630 - val_loss: 16.6515 - val_a_1: 2.8713 - val_a_2: 2.7429 - val_b_1: 1.2853 - val_b_2: 1.1625 - val_d_1: 0.7807 - val_d_2: 0.7451 - val_n: 1.4460 - val_mean_metric: 0.3579 - lr: 6.6100e-05
# Epoch 968/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.3071 - a_1: 2.7152 - a_2: 2.8078 - b_1: 1.4992 - b_2: 1.4506 - d_1: 0.5430 - d_2: 0.5504 - n: 1.4787 - mean_metric: 0.3632 - val_loss: 16.5249 - val_a_1: 2.8677 - val_a_2: 2.7502 - val_b_1: 1.2843 - val_b_2: 1.1677 - val_d_1: 0.7679 - val_d_2: 0.7453 - val_n: 1.4414 - val_mean_metric: 0.3576 - lr: 6.4450e-05
# Epoch 969/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2069 - a_1: 2.7088 - a_2: 2.8104 - b_1: 1.4698 - b_2: 1.4588 - d_1: 0.5401 - d_2: 0.5439 - n: 1.4772 - mean_metric: 0.3620 - val_loss: 16.4477 - val_a_1: 2.8706 - val_a_2: 2.7429 - val_b_1: 1.2841 - val_b_2: 1.1711 - val_d_1: 0.7600 - val_d_2: 0.7451 - val_n: 1.4426 - val_mean_metric: 0.3574 - lr: 6.2800e-05
# Epoch 970/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1646 - a_1: 2.7203 - a_2: 2.8140 - b_1: 1.4939 - b_2: 1.4533 - d_1: 0.5398 - d_2: 0.5409 - n: 1.4758 - mean_metric: 0.3631 - val_loss: 16.4980 - val_a_1: 2.8748 - val_a_2: 2.7393 - val_b_1: 1.2939 - val_b_2: 1.1650 - val_d_1: 0.7706 - val_d_2: 0.7418 - val_n: 1.4432 - val_mean_metric: 0.3578 - lr: 6.1150e-05
# Epoch 971/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.3085 - a_1: 2.7173 - a_2: 2.8088 - b_1: 1.4828 - b_2: 1.4590 - d_1: 0.5506 - d_2: 0.5462 - n: 1.4794 - mean_metric: 0.3632 - val_loss: 16.4334 - val_a_1: 2.8760 - val_a_2: 2.7414 - val_b_1: 1.2862 - val_b_2: 1.1692 - val_d_1: 0.7628 - val_d_2: 0.7426 - val_n: 1.4448 - val_mean_metric: 0.3576 - lr: 5.9500e-05
# Epoch 972/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2509 - a_1: 2.7278 - a_2: 2.8156 - b_1: 1.4682 - b_2: 1.4839 - d_1: 0.5430 - d_2: 0.5432 - n: 1.4761 - mean_metric: 0.3637 - val_loss: 16.4405 - val_a_1: 2.8737 - val_a_2: 2.7457 - val_b_1: 1.2750 - val_b_2: 1.1662 - val_d_1: 0.7610 - val_d_2: 0.7440 - val_n: 1.4435 - val_mean_metric: 0.3571 - lr: 5.7850e-05
# Epoch 973/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1160 - a_1: 2.7215 - a_2: 2.8065 - b_1: 1.4619 - b_2: 1.4614 - d_1: 0.5328 - d_2: 0.5390 - n: 1.4638 - mean_metric: 0.3614 - val_loss: 16.5562 - val_a_1: 2.8737 - val_a_2: 2.7344 - val_b_1: 1.2746 - val_b_2: 1.1619 - val_d_1: 0.7711 - val_d_2: 0.7450 - val_n: 1.4492 - val_mean_metric: 0.3572 - lr: 5.6200e-05
# Epoch 974/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2041 - a_1: 2.7261 - a_2: 2.8034 - b_1: 1.4586 - b_2: 1.4647 - d_1: 0.5441 - d_2: 0.5374 - n: 1.4712 - mean_metric: 0.3619 - val_loss: 16.4170 - val_a_1: 2.8803 - val_a_2: 2.7361 - val_b_1: 1.3029 - val_b_2: 1.1632 - val_d_1: 0.7688 - val_d_2: 0.7383 - val_n: 1.4504 - val_mean_metric: 0.3581 - lr: 5.4550e-05
# Epoch 975/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1169 - a_1: 2.7216 - a_2: 2.8042 - b_1: 1.5036 - b_2: 1.4589 - d_1: 0.5418 - d_2: 0.5336 - n: 1.4724 - mean_metric: 0.3630 - val_loss: 16.6204 - val_a_1: 2.8794 - val_a_2: 2.7349 - val_b_1: 1.2971 - val_b_2: 1.1549 - val_d_1: 0.7712 - val_d_2: 0.7509 - val_n: 1.4475 - val_mean_metric: 0.3580 - lr: 5.2900e-05
# Epoch 976/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1557 - a_1: 2.7143 - a_2: 2.8025 - b_1: 1.4792 - b_2: 1.4827 - d_1: 0.5404 - d_2: 0.5367 - n: 1.4747 - mean_metric: 0.3628 - val_loss: 16.6216 - val_a_1: 2.8731 - val_a_2: 2.7366 - val_b_1: 1.2984 - val_b_2: 1.1614 - val_d_1: 0.7687 - val_d_2: 0.7529 - val_n: 1.4442 - val_mean_metric: 0.3580 - lr: 5.1250e-05
# Epoch 977/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2044 - a_1: 2.7133 - a_2: 2.8111 - b_1: 1.4917 - b_2: 1.4583 - d_1: 0.5368 - d_2: 0.5446 - n: 1.4787 - mean_metric: 0.3628 - val_loss: 16.6902 - val_a_1: 2.8796 - val_a_2: 2.7370 - val_b_1: 1.2948 - val_b_2: 1.1576 - val_d_1: 0.7750 - val_d_2: 0.7552 - val_n: 1.4475 - val_mean_metric: 0.3583 - lr: 4.9600e-05
# Epoch 978/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1776 - a_1: 2.7206 - a_2: 2.8022 - b_1: 1.4921 - b_2: 1.4531 - d_1: 0.5413 - d_2: 0.5394 - n: 1.4817 - mean_metric: 0.3628 - val_loss: 16.4741 - val_a_1: 2.8735 - val_a_2: 2.7359 - val_b_1: 1.2868 - val_b_2: 1.1600 - val_d_1: 0.7654 - val_d_2: 0.7449 - val_n: 1.4436 - val_mean_metric: 0.3572 - lr: 4.7950e-05
# Epoch 979/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2599 - a_1: 2.7128 - a_2: 2.8005 - b_1: 1.4892 - b_2: 1.4626 - d_1: 0.5452 - d_2: 0.5440 - n: 1.4833 - mean_metric: 0.3630 - val_loss: 16.3291 - val_a_1: 2.8761 - val_a_2: 2.7423 - val_b_1: 1.2770 - val_b_2: 1.1651 - val_d_1: 0.7568 - val_d_2: 0.7393 - val_n: 1.4448 - val_mean_metric: 0.3569 - lr: 4.6300e-05
# Epoch 980/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2529 - a_1: 2.7158 - a_2: 2.8180 - b_1: 1.4886 - b_2: 1.4451 - d_1: 0.5411 - d_2: 0.5458 - n: 1.4773 - mean_metric: 0.3629 - val_loss: 16.4353 - val_a_1: 2.8769 - val_a_2: 2.7385 - val_b_1: 1.2942 - val_b_2: 1.1656 - val_d_1: 0.7640 - val_d_2: 0.7424 - val_n: 1.4492 - val_mean_metric: 0.3578 - lr: 4.4650e-05
# Epoch 981/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2726 - a_1: 2.7180 - a_2: 2.8128 - b_1: 1.4943 - b_2: 1.4408 - d_1: 0.5440 - d_2: 0.5462 - n: 1.4909 - mean_metric: 0.3633 - val_loss: 16.4591 - val_a_1: 2.8768 - val_a_2: 2.7368 - val_b_1: 1.2806 - val_b_2: 1.1591 - val_d_1: 0.7575 - val_d_2: 0.7486 - val_n: 1.4458 - val_mean_metric: 0.3570 - lr: 4.3000e-05
# Epoch 982/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.3420 - a_1: 2.7176 - a_2: 2.8065 - b_1: 1.4810 - b_2: 1.4807 - d_1: 0.5447 - d_2: 0.5521 - n: 1.4746 - mean_metric: 0.3637 - val_loss: 16.4874 - val_a_1: 2.8736 - val_a_2: 2.7365 - val_b_1: 1.2798 - val_b_2: 1.1614 - val_d_1: 0.7702 - val_d_2: 0.7412 - val_n: 1.4460 - val_mean_metric: 0.3571 - lr: 4.1350e-05
# Epoch 983/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1622 - a_1: 2.7142 - a_2: 2.8071 - b_1: 1.4870 - b_2: 1.4674 - d_1: 0.5388 - d_2: 0.5381 - n: 1.4802 - mean_metric: 0.3629 - val_loss: 16.4480 - val_a_1: 2.8702 - val_a_2: 2.7366 - val_b_1: 1.2858 - val_b_2: 1.1717 - val_d_1: 0.7639 - val_d_2: 0.7442 - val_n: 1.4431 - val_mean_metric: 0.3573 - lr: 3.9700e-05
# Epoch 984/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 12.2207 - a_1: 2.7217 - a_2: 2.8041 - b_1: 1.5056 - b_2: 1.4560 - d_1: 0.5412 - d_2: 0.5471 - n: 1.4744 - mean_metric: 0.3634 - val_loss: 16.3911 - val_a_1: 2.8737 - val_a_2: 2.7397 - val_b_1: 1.2813 - val_b_2: 1.1813 - val_d_1: 0.7575 - val_d_2: 0.7461 - val_n: 1.4427 - val_mean_metric: 0.3576 - lr: 3.8050e-05
# Epoch 985/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 12.3006 - a_1: 2.7174 - a_2: 2.8089 - b_1: 1.4905 - b_2: 1.4613 - d_1: 0.5445 - d_2: 0.5487 - n: 1.4724 - mean_metric: 0.3632 - val_loss: 16.3737 - val_a_1: 2.8732 - val_a_2: 2.7391 - val_b_1: 1.2826 - val_b_2: 1.1775 - val_d_1: 0.7555 - val_d_2: 0.7455 - val_n: 1.4422 - val_mean_metric: 0.3573 - lr: 3.6400e-05
# Epoch 986/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 12.1444 - a_1: 2.7182 - a_2: 2.8091 - b_1: 1.4735 - b_2: 1.4882 - d_1: 0.5377 - d_2: 0.5389 - n: 1.4728 - mean_metric: 0.3631 - val_loss: 16.5072 - val_a_1: 2.8689 - val_a_2: 2.7368 - val_b_1: 1.2870 - val_b_2: 1.1659 - val_d_1: 0.7664 - val_d_2: 0.7464 - val_n: 1.4443 - val_mean_metric: 0.3573 - lr: 3.4750e-05
# Epoch 987/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2298 - a_1: 2.7171 - a_2: 2.8069 - b_1: 1.4580 - b_2: 1.4721 - d_1: 0.5478 - d_2: 0.5409 - n: 1.4726 - mean_metric: 0.3622 - val_loss: 16.5582 - val_a_1: 2.8710 - val_a_2: 2.7386 - val_b_1: 1.2762 - val_b_2: 1.1662 - val_d_1: 0.7708 - val_d_2: 0.7476 - val_n: 1.4436 - val_mean_metric: 0.3573 - lr: 3.3100e-05
# Epoch 988/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.3469 - a_1: 2.7205 - a_2: 2.8073 - b_1: 1.4650 - b_2: 1.4740 - d_1: 0.5500 - d_2: 0.5488 - n: 1.4797 - mean_metric: 0.3633 - val_loss: 16.3955 - val_a_1: 2.8718 - val_a_2: 2.7368 - val_b_1: 1.2766 - val_b_2: 1.1541 - val_d_1: 0.7593 - val_d_2: 0.7425 - val_n: 1.4460 - val_mean_metric: 0.3564 - lr: 3.1450e-05
# Epoch 989/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1320 - a_1: 2.7184 - a_2: 2.8020 - b_1: 1.4977 - b_2: 1.4706 - d_1: 0.5387 - d_2: 0.5381 - n: 1.4742 - mean_metric: 0.3630 - val_loss: 16.4444 - val_a_1: 2.8734 - val_a_2: 2.7338 - val_b_1: 1.2797 - val_b_2: 1.1578 - val_d_1: 0.7654 - val_d_2: 0.7420 - val_n: 1.4444 - val_mean_metric: 0.3567 - lr: 2.9800e-05
# Epoch 990/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.0398 - a_1: 2.7236 - a_2: 2.8004 - b_1: 1.4871 - b_2: 1.4609 - d_1: 0.5304 - d_2: 0.5360 - n: 1.4758 - mean_metric: 0.3622 - val_loss: 16.4623 - val_a_1: 2.8759 - val_a_2: 2.7374 - val_b_1: 1.2746 - val_b_2: 1.1568 - val_d_1: 0.7604 - val_d_2: 0.7470 - val_n: 1.4447 - val_mean_metric: 0.3567 - lr: 2.8150e-05
# Epoch 991/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1582 - a_1: 2.7118 - a_2: 2.8125 - b_1: 1.4848 - b_2: 1.4721 - d_1: 0.5397 - d_2: 0.5411 - n: 1.4706 - mean_metric: 0.3628 - val_loss: 16.4438 - val_a_1: 2.8735 - val_a_2: 2.7373 - val_b_1: 1.2810 - val_b_2: 1.1539 - val_d_1: 0.7600 - val_d_2: 0.7447 - val_n: 1.4466 - val_mean_metric: 0.3567 - lr: 2.6500e-05
# Epoch 992/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.2138 - a_1: 2.7146 - a_2: 2.8131 - b_1: 1.4900 - b_2: 1.4504 - d_1: 0.5420 - d_2: 0.5452 - n: 1.4719 - mean_metric: 0.3627 - val_loss: 16.4545 - val_a_1: 2.8724 - val_a_2: 2.7373 - val_b_1: 1.2766 - val_b_2: 1.1540 - val_d_1: 0.7609 - val_d_2: 0.7453 - val_n: 1.4471 - val_mean_metric: 0.3566 - lr: 2.4850e-05
# Epoch 993/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1408 - a_1: 2.7097 - a_2: 2.8072 - b_1: 1.4763 - b_2: 1.4632 - d_1: 0.5371 - d_2: 0.5415 - n: 1.4809 - mean_metric: 0.3623 - val_loss: 16.4410 - val_a_1: 2.8682 - val_a_2: 2.7359 - val_b_1: 1.2720 - val_b_2: 1.1537 - val_d_1: 0.7666 - val_d_2: 0.7387 - val_n: 1.4476 - val_mean_metric: 0.3563 - lr: 2.3200e-05
# Epoch 994/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1592 - a_1: 2.7144 - a_2: 2.8009 - b_1: 1.4681 - b_2: 1.4689 - d_1: 0.5384 - d_2: 0.5419 - n: 1.4791 - mean_metric: 0.3621 - val_loss: 16.4277 - val_a_1: 2.8738 - val_a_2: 2.7369 - val_b_1: 1.2701 - val_b_2: 1.1541 - val_d_1: 0.7608 - val_d_2: 0.7435 - val_n: 1.4479 - val_mean_metric: 0.3564 - lr: 2.1550e-05
# Epoch 995/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 12.1802 - a_1: 2.7270 - a_2: 2.8124 - b_1: 1.4781 - b_2: 1.4693 - d_1: 0.5410 - d_2: 0.5426 - n: 1.4723 - mean_metric: 0.3631 - val_loss: 16.4071 - val_a_1: 2.8737 - val_a_2: 2.7357 - val_b_1: 1.2720 - val_b_2: 1.1572 - val_d_1: 0.7584 - val_d_2: 0.7439 - val_n: 1.4481 - val_mean_metric: 0.3565 - lr: 1.9900e-05
# Epoch 996/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 12.1804 - a_1: 2.7161 - a_2: 2.8105 - b_1: 1.4836 - b_2: 1.4367 - d_1: 0.5424 - d_2: 0.5421 - n: 1.4767 - mean_metric: 0.3619 - val_loss: 16.4065 - val_a_1: 2.8752 - val_a_2: 2.7363 - val_b_1: 1.2712 - val_b_2: 1.1619 - val_d_1: 0.7590 - val_d_2: 0.7436 - val_n: 1.4473 - val_mean_metric: 0.3567 - lr: 1.8250e-05
# Epoch 997/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1190 - a_1: 2.7130 - a_2: 2.8038 - b_1: 1.4610 - b_2: 1.4631 - d_1: 0.5404 - d_2: 0.5381 - n: 1.4794 - mean_metric: 0.3617 - val_loss: 16.3891 - val_a_1: 2.8746 - val_a_2: 2.7339 - val_b_1: 1.2726 - val_b_2: 1.1595 - val_d_1: 0.7605 - val_d_2: 0.7406 - val_n: 1.4459 - val_mean_metric: 0.3564 - lr: 1.6600e-05
# Epoch 998/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1994 - a_1: 2.7095 - a_2: 2.8077 - b_1: 1.4743 - b_2: 1.4850 - d_1: 0.5407 - d_2: 0.5447 - n: 1.4726 - mean_metric: 0.3629 - val_loss: 16.4097 - val_a_1: 2.8743 - val_a_2: 2.7340 - val_b_1: 1.2736 - val_b_2: 1.1585 - val_d_1: 0.7610 - val_d_2: 0.7416 - val_n: 1.4449 - val_mean_metric: 0.3564 - lr: 1.4950e-05
# Epoch 999/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.1640 - a_1: 2.7209 - a_2: 2.8020 - b_1: 1.4801 - b_2: 1.4614 - d_1: 0.5384 - d_2: 0.5417 - n: 1.4803 - mean_metric: 0.3626 - val_loss: 16.4432 - val_a_1: 2.8720 - val_a_2: 2.7364 - val_b_1: 1.2735 - val_b_2: 1.1581 - val_d_1: 0.7601 - val_d_2: 0.7450 - val_n: 1.4447 - val_mean_metric: 0.3565 - lr: 1.3300e-05
# Epoch 1000/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 12.0706 - a_1: 2.7132 - a_2: 2.8017 - b_1: 1.4617 - b_2: 1.4700 - d_1: 0.5405 - d_2: 0.5335 - n: 1.4758 - mean_metric: 0.3617 - val_loss: 16.4701 - val_a_1: 2.8736 - val_a_2: 2.7378 - val_b_1: 1.2763 - val_b_2: 1.1582 - val_d_1: 0.7643 - val_d_2: 0.7450 - val_n: 1.4447 - val_mean_metric: 0.3568 - lr: 1.1650e-05

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(val_epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    campvectest, coefcampvectest)
# Out:
# 63/63 [==============================] - 1s 2ms/step - loss: 15.9953 - a_1: 2.7346 - a_2: 2.7019 - b_1: 1.2302 - b_2: 1.2081 - d_1: 0.7551 - d_2: 0.7212 - n: 1.4359 - mean_metric: 0.3566

# %%
predictions = model.predict(campvectest)
# Out:
# 63/63 [==============================] - 0s 871us/step

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefcampvectest, predictions)

# Calcula la desviación estándar del error
error = coefcampvectest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 1.5406369328307254, Desviación estándar del error: 2.0935506434366125, Error absoluto máximo: 8.429428100585938

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefcampvectest - predictions)

# Calcula el error para cada dato
error = coefcampvectest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefcampvectest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.36084502305508964
# Desviación estándar del error relativo: 0.2715641351392562
# Error absoluto máximo relativo: 1.983124321157282

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales con ruido/History 50,100/historycampvec50costo.csv', index = False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos con ruido/Modelos 50,100'

# %%
model.save(path_to_save + '/campovectorial50funcioncosto.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_loss':custom_loss,'custom_activation':custom_activation,'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)
new_model = keras.models.load_model('../../../Modelos con ruido/Modelos 50,100/campovectorial50funcioncosto.h5', 
                                    custom_objects=custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 50)
    y2 = np.linspace(y_range_neg, y_range_pos, 50)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [9, 1, 1, 1, 1, 5, 3]

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# [[3. 3. 5. 6. 1. 5. 7.]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 50)
y2 = np.linspace(0, 10, 50)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 20])
plt.ylim([0, 20])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1 = np.linspace(x_range_neg, x_range_pos, 50)
y2 = np.linspace(y_range_neg, y_range_pos, 50)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
