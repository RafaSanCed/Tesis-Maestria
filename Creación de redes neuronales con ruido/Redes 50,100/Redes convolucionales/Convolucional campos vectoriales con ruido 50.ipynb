# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_40556\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos con ruido/Campo 50 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')
campvectrain = np.transpose(campvectrain, (0,2,3,1))

# %%
np.shape(campvectrain)
# Out:
# (7000, 50, 50, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')
campvectest = np.transpose(campvectest, (0,2,3,1))

# %%
np.shape(campvectest)
# Out:
# (2000, 50, 50, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')
campvecval = np.transpose(campvecval, (0,2,3,1))

# %%
np.shape(campvecval)
# Out:
# (1000, 50, 50, 2)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(50, 50, 2), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
# Primera capa convolucional
model.add(Conv2D(50, (5, 5), activation='tanh', input_shape=(50, 50, 2),kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Segunda capa convolucional
model.add(Conv2D(11, (5, 5), activation='tanh',kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001) ))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Tercera capa convolucional
model.add(Conv2D(9, (5, 5), activation='tanh',kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))

#Cuarta capa convolucional
model.add(Conv2D(50, (5, 5), activation='tanh',kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))


model.add(Flatten())

model.add(Dense(50, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(25, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(10,activation = 'relu', kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(7, activation= custom_activation))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 50)        2550
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 50)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 19, 19, 11)        13761
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 11)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 9)           2484
#
#  conv2d_3 (Conv2D)           (None, 1, 1, 50)          11300
#
#  flatten (Flatten)           (None, 50)                0
#
#  dense (Dense)               (None, 50)                2550
#
#  dense_1 (Dense)             (None, 25)                1275
#
#  dense_2 (Dense)             (None, 10)                260
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_3 (Dense)             (None, 7)                 77
#
# =================================================================
# Total params: 34,257
# Trainable params: 34,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= 'mean_squared_error',
              metrics=metrics)

# %%
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 1000,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 70/70 [==============================] - 2s 20ms/step - loss: 10.1654 - a_1: 2.7233 - a_2: 2.8051 - b_1: 2.7209 - b_2: 2.5888 - d_1: 2.2101 - d_2: 2.2659 - n: 2.1534 - mean_metric: 0.5745 - val_loss: 8.8259 - val_a_1: 2.8359 - val_a_2: 2.6723 - val_b_1: 2.5994 - val_b_2: 2.1520 - val_d_1: 1.8789 - val_d_2: 1.8876 - val_n: 2.0135 - val_mean_metric: 0.5203 - lr: 0.0010
# Epoch 2/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 8.9555 - a_1: 2.7233 - a_2: 2.7847 - b_1: 2.5799 - b_2: 2.1004 - d_1: 1.8293 - d_2: 1.9830 - n: 2.0431 - mean_metric: 0.5276 - val_loss: 7.5671 - val_a_1: 2.7904 - val_a_2: 2.6049 - val_b_1: 2.2997 - val_b_2: 1.6756 - val_d_1: 1.6877 - val_d_2: 1.6631 - val_n: 1.8037 - val_mean_metric: 0.4712 - lr: 0.0010
# Epoch 3/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 8.0867 - a_1: 2.6877 - a_2: 2.7396 - b_1: 2.2753 - b_2: 1.9158 - d_1: 1.7576 - d_2: 1.7720 - n: 1.8518 - mean_metric: 0.4934 - val_loss: 6.7061 - val_a_1: 2.7380 - val_a_2: 2.5598 - val_b_1: 2.0468 - val_b_2: 1.5208 - val_d_1: 1.4134 - val_d_2: 1.4163 - val_n: 1.6671 - val_mean_metric: 0.4334 - lr: 0.0010
# Epoch 4/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 7.6261 - a_1: 2.6406 - a_2: 2.6856 - b_1: 2.1513 - b_2: 1.8639 - d_1: 1.7055 - d_2: 1.6596 - n: 1.7331 - mean_metric: 0.4749 - val_loss: 6.3607 - val_a_1: 2.6771 - val_a_2: 2.4877 - val_b_1: 1.9900 - val_b_2: 1.6142 - val_d_1: 1.3892 - val_d_2: 1.2443 - val_n: 1.5812 - val_mean_metric: 0.4212 - lr: 0.0010
# Epoch 5/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 7.2882 - a_1: 2.5613 - a_2: 2.5929 - b_1: 2.1045 - b_2: 1.8757 - d_1: 1.6583 - d_2: 1.6193 - n: 1.6769 - mean_metric: 0.4634 - val_loss: 6.0579 - val_a_1: 2.5903 - val_a_2: 2.4091 - val_b_1: 1.9344 - val_b_2: 1.5347 - val_d_1: 1.4167 - val_d_2: 1.2698 - val_n: 1.5272 - val_mean_metric: 0.4114 - lr: 0.0010
# Epoch 6/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 7.0016 - a_1: 2.4818 - a_2: 2.4931 - b_1: 2.0375 - b_2: 1.8602 - d_1: 1.6302 - d_2: 1.6223 - n: 1.6194 - mean_metric: 0.4521 - val_loss: 5.6739 - val_a_1: 2.4919 - val_a_2: 2.2707 - val_b_1: 1.8625 - val_b_2: 1.5400 - val_d_1: 1.4043 - val_d_2: 1.1939 - val_n: 1.4366 - val_mean_metric: 0.3957 - lr: 0.0010
# Epoch 7/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 6.7165 - a_1: 2.4207 - a_2: 2.3107 - b_1: 2.0228 - b_2: 1.8885 - d_1: 1.6179 - d_2: 1.6092 - n: 1.5656 - mean_metric: 0.4419 - val_loss: 5.3115 - val_a_1: 2.4109 - val_a_2: 2.1297 - val_b_1: 1.8197 - val_b_2: 1.5251 - val_d_1: 1.2729 - val_d_2: 1.1563 - val_n: 1.3709 - val_mean_metric: 0.3791 - lr: 0.0010
# Epoch 8/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 6.4967 - a_1: 2.3894 - a_2: 2.2579 - b_1: 1.9823 - b_2: 1.8621 - d_1: 1.6115 - d_2: 1.5729 - n: 1.4901 - mean_metric: 0.4331 - val_loss: 5.1321 - val_a_1: 2.3655 - val_a_2: 2.0941 - val_b_1: 1.7528 - val_b_2: 1.5340 - val_d_1: 1.2399 - val_d_2: 1.1560 - val_n: 1.3304 - val_mean_metric: 0.3721 - lr: 0.0010
# Epoch 9/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 6.3445 - a_1: 2.3730 - a_2: 2.2364 - b_1: 1.9351 - b_2: 1.8635 - d_1: 1.5751 - d_2: 1.5611 - n: 1.4448 - mean_metric: 0.4272 - val_loss: 4.9860 - val_a_1: 2.3611 - val_a_2: 2.0676 - val_b_1: 1.7159 - val_b_2: 1.4730 - val_d_1: 1.2361 - val_d_2: 1.1251 - val_n: 1.3152 - val_mean_metric: 0.3664 - lr: 0.0010
# Epoch 10/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 6.2096 - a_1: 2.3476 - a_2: 2.2092 - b_1: 1.9158 - b_2: 1.8140 - d_1: 1.5785 - d_2: 1.5588 - n: 1.4068 - mean_metric: 0.4219 - val_loss: 4.9539 - val_a_1: 2.3410 - val_a_2: 2.0475 - val_b_1: 1.7472 - val_b_2: 1.4789 - val_d_1: 1.2127 - val_d_2: 1.1241 - val_n: 1.3091 - val_mean_metric: 0.3653 - lr: 0.0010
# Epoch 11/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 6.1674 - a_1: 2.3312 - a_2: 2.1900 - b_1: 1.9214 - b_2: 1.8367 - d_1: 1.5878 - d_2: 1.5549 - n: 1.3939 - mean_metric: 0.4215 - val_loss: 4.8062 - val_a_1: 2.3002 - val_a_2: 1.9885 - val_b_1: 1.6875 - val_b_2: 1.4522 - val_d_1: 1.1970 - val_d_2: 1.2014 - val_n: 1.2914 - val_mean_metric: 0.3607 - lr: 0.0010
# Epoch 12/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 6.0740 - a_1: 2.3139 - a_2: 2.1781 - b_1: 1.8955 - b_2: 1.8264 - d_1: 1.5585 - d_2: 1.5708 - n: 1.3788 - mean_metric: 0.4184 - val_loss: 4.8027 - val_a_1: 2.3155 - val_a_2: 1.9966 - val_b_1: 1.7756 - val_b_2: 1.4543 - val_d_1: 1.1744 - val_d_2: 1.1139 - val_n: 1.2914 - val_mean_metric: 0.3608 - lr: 0.0010
# Epoch 13/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.9602 - a_1: 2.3029 - a_2: 2.1608 - b_1: 1.8612 - b_2: 1.8102 - d_1: 1.5493 - d_2: 1.5377 - n: 1.3780 - mean_metric: 0.4144 - val_loss: 4.5951 - val_a_1: 2.2992 - val_a_2: 1.9304 - val_b_1: 1.6353 - val_b_2: 1.4303 - val_d_1: 1.1930 - val_d_2: 1.1065 - val_n: 1.2887 - val_mean_metric: 0.3530 - lr: 0.0010
# Epoch 14/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.9141 - a_1: 2.2729 - a_2: 2.1396 - b_1: 1.8326 - b_2: 1.8310 - d_1: 1.5663 - d_2: 1.5597 - n: 1.3633 - mean_metric: 0.4132 - val_loss: 4.5908 - val_a_1: 2.2630 - val_a_2: 2.0563 - val_b_1: 1.5600 - val_b_2: 1.4528 - val_d_1: 1.1020 - val_d_2: 1.1245 - val_n: 1.2910 - val_mean_metric: 0.3520 - lr: 0.0010
# Epoch 15/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.8402 - a_1: 2.2753 - a_2: 2.1405 - b_1: 1.8343 - b_2: 1.8128 - d_1: 1.5254 - d_2: 1.5274 - n: 1.3571 - mean_metric: 0.4103 - val_loss: 4.4803 - val_a_1: 2.2828 - val_a_2: 1.8660 - val_b_1: 1.5827 - val_b_2: 1.4867 - val_d_1: 1.1846 - val_d_2: 1.1290 - val_n: 1.2919 - val_mean_metric: 0.3511 - lr: 0.0010
# Epoch 16/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.8130 - a_1: 2.2693 - a_2: 2.1248 - b_1: 1.8158 - b_2: 1.8066 - d_1: 1.5588 - d_2: 1.5310 - n: 1.3490 - mean_metric: 0.4096 - val_loss: 4.4118 - val_a_1: 2.2426 - val_a_2: 1.9447 - val_b_1: 1.5680 - val_b_2: 1.4368 - val_d_1: 1.1214 - val_d_2: 1.1067 - val_n: 1.2968 - val_mean_metric: 0.3477 - lr: 0.0010
# Epoch 17/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.7411 - a_1: 2.2382 - a_2: 2.1013 - b_1: 1.8315 - b_2: 1.8236 - d_1: 1.5236 - d_2: 1.5189 - n: 1.3532 - mean_metric: 0.4076 - val_loss: 4.3306 - val_a_1: 2.2159 - val_a_2: 1.8923 - val_b_1: 1.5516 - val_b_2: 1.4388 - val_d_1: 1.0816 - val_d_2: 1.1234 - val_n: 1.3007 - val_mean_metric: 0.3440 - lr: 0.0010
# Epoch 18/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.6180 - a_1: 2.2120 - a_2: 2.0957 - b_1: 1.7921 - b_2: 1.7543 - d_1: 1.5318 - d_2: 1.5026 - n: 1.3532 - mean_metric: 0.4026 - val_loss: 4.2903 - val_a_1: 2.1781 - val_a_2: 1.9280 - val_b_1: 1.5268 - val_b_2: 1.3870 - val_d_1: 1.0958 - val_d_2: 1.1642 - val_n: 1.2989 - val_mean_metric: 0.3432 - lr: 0.0010
# Epoch 19/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.6574 - a_1: 2.2084 - a_2: 2.0768 - b_1: 1.8098 - b_2: 1.7733 - d_1: 1.5531 - d_2: 1.5403 - n: 1.3509 - mean_metric: 0.4050 - val_loss: 4.3216 - val_a_1: 2.2119 - val_a_2: 1.8225 - val_b_1: 1.5989 - val_b_2: 1.4652 - val_d_1: 1.1533 - val_d_2: 1.1515 - val_n: 1.3200 - val_mean_metric: 0.3479 - lr: 0.0010
# Epoch 20/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.6079 - a_1: 2.1707 - a_2: 2.0880 - b_1: 1.7919 - b_2: 1.7648 - d_1: 1.5507 - d_2: 1.5229 - n: 1.3426 - mean_metric: 0.4024 - val_loss: 4.1697 - val_a_1: 2.1587 - val_a_2: 1.8044 - val_b_1: 1.5419 - val_b_2: 1.4039 - val_d_1: 1.1580 - val_d_2: 1.1121 - val_n: 1.3020 - val_mean_metric: 0.3400 - lr: 0.0010
# Epoch 21/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.5647 - a_1: 2.1653 - a_2: 2.0812 - b_1: 1.7976 - b_2: 1.7436 - d_1: 1.5241 - d_2: 1.5200 - n: 1.3652 - mean_metric: 0.4011 - val_loss: 4.2091 - val_a_1: 2.1793 - val_a_2: 1.8535 - val_b_1: 1.5270 - val_b_2: 1.3917 - val_d_1: 1.1190 - val_d_2: 1.0998 - val_n: 1.3269 - val_mean_metric: 0.3406 - lr: 0.0010
# Epoch 22/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.5366 - a_1: 2.1642 - a_2: 2.0649 - b_1: 1.7641 - b_2: 1.7856 - d_1: 1.5421 - d_2: 1.5131 - n: 1.3617 - mean_metric: 0.4012 - val_loss: 4.1433 - val_a_1: 2.1155 - val_a_2: 1.8511 - val_b_1: 1.5283 - val_b_2: 1.4016 - val_d_1: 1.1406 - val_d_2: 1.0904 - val_n: 1.3254 - val_mean_metric: 0.3391 - lr: 0.0010
# Epoch 23/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.4643 - a_1: 2.1269 - a_2: 2.0611 - b_1: 1.7497 - b_2: 1.7646 - d_1: 1.5277 - d_2: 1.5223 - n: 1.3590 - mean_metric: 0.3983 - val_loss: 4.0564 - val_a_1: 2.0804 - val_a_2: 1.7984 - val_b_1: 1.5182 - val_b_2: 1.4427 - val_d_1: 1.0932 - val_d_2: 1.1201 - val_n: 1.3220 - val_mean_metric: 0.3366 - lr: 0.0010
# Epoch 24/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.4611 - a_1: 2.1260 - a_2: 2.0433 - b_1: 1.7649 - b_2: 1.7616 - d_1: 1.5120 - d_2: 1.5368 - n: 1.3668 - mean_metric: 0.3984 - val_loss: 4.1018 - val_a_1: 2.1211 - val_a_2: 1.8219 - val_b_1: 1.4750 - val_b_2: 1.4139 - val_d_1: 1.1283 - val_d_2: 1.1690 - val_n: 1.3458 - val_mean_metric: 0.3398 - lr: 0.0010
# Epoch 25/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.3974 - a_1: 2.0987 - a_2: 2.0600 - b_1: 1.7389 - b_2: 1.7670 - d_1: 1.4821 - d_2: 1.5039 - n: 1.3613 - mean_metric: 0.3951 - val_loss: 3.9693 - val_a_1: 2.0358 - val_a_2: 1.7699 - val_b_1: 1.4488 - val_b_2: 1.4636 - val_d_1: 1.1089 - val_d_2: 1.0962 - val_n: 1.3274 - val_mean_metric: 0.3326 - lr: 0.0010
# Epoch 26/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.3888 - a_1: 2.1062 - a_2: 2.0471 - b_1: 1.7297 - b_2: 1.7541 - d_1: 1.5126 - d_2: 1.5046 - n: 1.3695 - mean_metric: 0.3954 - val_loss: 3.9221 - val_a_1: 2.0312 - val_a_2: 1.7706 - val_b_1: 1.4922 - val_b_2: 1.3664 - val_d_1: 1.1042 - val_d_2: 1.1170 - val_n: 1.3317 - val_mean_metric: 0.3314 - lr: 0.0010
# Epoch 27/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.3005 - a_1: 2.0604 - a_2: 2.0381 - b_1: 1.7294 - b_2: 1.7621 - d_1: 1.4731 - d_2: 1.4939 - n: 1.3689 - mean_metric: 0.3923 - val_loss: 3.9039 - val_a_1: 1.9964 - val_a_2: 1.8050 - val_b_1: 1.4458 - val_b_2: 1.4019 - val_d_1: 1.0695 - val_d_2: 1.1230 - val_n: 1.3479 - val_mean_metric: 0.3306 - lr: 0.0010
# Epoch 28/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.3488 - a_1: 2.0589 - a_2: 2.0342 - b_1: 1.7282 - b_2: 1.7706 - d_1: 1.4988 - d_2: 1.5149 - n: 1.3777 - mean_metric: 0.3942 - val_loss: 3.8627 - val_a_1: 2.0010 - val_a_2: 1.7561 - val_b_1: 1.4770 - val_b_2: 1.4250 - val_d_1: 1.0627 - val_d_2: 1.0686 - val_n: 1.3474 - val_mean_metric: 0.3289 - lr: 0.0010
# Epoch 29/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.3467 - a_1: 2.0635 - a_2: 2.0513 - b_1: 1.7378 - b_2: 1.7559 - d_1: 1.4735 - d_2: 1.5258 - n: 1.3870 - mean_metric: 0.3945 - val_loss: 3.8802 - val_a_1: 2.0143 - val_a_2: 1.7800 - val_b_1: 1.4612 - val_b_2: 1.3952 - val_d_1: 1.0941 - val_d_2: 1.1216 - val_n: 1.3584 - val_mean_metric: 0.3317 - lr: 0.0010
# Epoch 30/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.2925 - a_1: 2.0375 - a_2: 2.0665 - b_1: 1.7451 - b_2: 1.7402 - d_1: 1.4795 - d_2: 1.4846 - n: 1.3717 - mean_metric: 0.3922 - val_loss: 3.8370 - val_a_1: 1.9852 - val_a_2: 1.7857 - val_b_1: 1.4553 - val_b_2: 1.4131 - val_d_1: 1.0694 - val_d_2: 1.0552 - val_n: 1.3682 - val_mean_metric: 0.3287 - lr: 0.0010
# Epoch 31/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.3279 - a_1: 2.0251 - a_2: 2.0721 - b_1: 1.7584 - b_2: 1.7615 - d_1: 1.4793 - d_2: 1.5078 - n: 1.3811 - mean_metric: 0.3943 - val_loss: 3.8148 - val_a_1: 1.9696 - val_a_2: 1.7928 - val_b_1: 1.4506 - val_b_2: 1.4321 - val_d_1: 1.0302 - val_d_2: 1.0630 - val_n: 1.3609 - val_mean_metric: 0.3277 - lr: 0.0010
# Epoch 32/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.2193 - a_1: 2.0321 - a_2: 2.0145 - b_1: 1.7244 - b_2: 1.7415 - d_1: 1.4840 - d_2: 1.4835 - n: 1.3745 - mean_metric: 0.3898 - val_loss: 3.7786 - val_a_1: 1.9649 - val_a_2: 1.7793 - val_b_1: 1.4604 - val_b_2: 1.4057 - val_d_1: 1.0134 - val_d_2: 1.0658 - val_n: 1.3711 - val_mean_metric: 0.3264 - lr: 0.0010
# Epoch 33/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.2499 - a_1: 2.0378 - a_2: 2.0217 - b_1: 1.7219 - b_2: 1.7563 - d_1: 1.4791 - d_2: 1.4991 - n: 1.3843 - mean_metric: 0.3914 - val_loss: 3.7860 - val_a_1: 1.9365 - val_a_2: 1.8017 - val_b_1: 1.4550 - val_b_2: 1.3840 - val_d_1: 1.0387 - val_d_2: 1.0803 - val_n: 1.3736 - val_mean_metric: 0.3267 - lr: 0.0010
# Epoch 34/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1870 - a_1: 2.0028 - a_2: 2.0143 - b_1: 1.7040 - b_2: 1.7406 - d_1: 1.4968 - d_2: 1.4668 - n: 1.3812 - mean_metric: 0.3882 - val_loss: 3.8416 - val_a_1: 1.9892 - val_a_2: 1.8984 - val_b_1: 1.4455 - val_b_2: 1.3526 - val_d_1: 1.0310 - val_d_2: 1.0376 - val_n: 1.3854 - val_mean_metric: 0.3290 - lr: 0.0010
# Epoch 35/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.2328 - a_1: 2.0120 - a_2: 2.0579 - b_1: 1.7120 - b_2: 1.7524 - d_1: 1.4837 - d_2: 1.4933 - n: 1.3884 - mean_metric: 0.3914 - val_loss: 3.7824 - val_a_1: 1.9584 - val_a_2: 1.8284 - val_b_1: 1.4410 - val_b_2: 1.3389 - val_d_1: 1.1015 - val_d_2: 1.0761 - val_n: 1.3830 - val_mean_metric: 0.3286 - lr: 0.0010
# Epoch 36/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1787 - a_1: 1.9908 - a_2: 2.0478 - b_1: 1.7224 - b_2: 1.7212 - d_1: 1.4743 - d_2: 1.4788 - n: 1.3773 - mean_metric: 0.3886 - val_loss: 3.7514 - val_a_1: 1.9366 - val_a_2: 1.7742 - val_b_1: 1.4821 - val_b_2: 1.3582 - val_d_1: 1.0971 - val_d_2: 1.0813 - val_n: 1.3830 - val_mean_metric: 0.3281 - lr: 0.0010
# Epoch 37/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.2226 - a_1: 2.0348 - a_2: 2.0277 - b_1: 1.7293 - b_2: 1.7327 - d_1: 1.5031 - d_2: 1.4756 - n: 1.3812 - mean_metric: 0.3911 - val_loss: 3.6930 - val_a_1: 1.9462 - val_a_2: 1.6913 - val_b_1: 1.4513 - val_b_2: 1.3645 - val_d_1: 1.0773 - val_d_2: 1.1058 - val_n: 1.3795 - val_mean_metric: 0.3250 - lr: 0.0010
# Epoch 38/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1569 - a_1: 1.9996 - a_2: 2.0305 - b_1: 1.7110 - b_2: 1.7380 - d_1: 1.4729 - d_2: 1.4676 - n: 1.3957 - mean_metric: 0.3886 - val_loss: 3.6406 - val_a_1: 1.9280 - val_a_2: 1.7026 - val_b_1: 1.3884 - val_b_2: 1.4192 - val_d_1: 1.0353 - val_d_2: 1.0351 - val_n: 1.3841 - val_mean_metric: 0.3210 - lr: 0.0010
# Epoch 39/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1571 - a_1: 2.0161 - a_2: 2.0368 - b_1: 1.7113 - b_2: 1.7422 - d_1: 1.4610 - d_2: 1.4629 - n: 1.3764 - mean_metric: 0.3883 - val_loss: 3.7221 - val_a_1: 1.9721 - val_a_2: 1.7877 - val_b_1: 1.4312 - val_b_2: 1.3471 - val_d_1: 1.0369 - val_d_2: 1.0851 - val_n: 1.3923 - val_mean_metric: 0.3261 - lr: 0.0010
# Epoch 40/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1445 - a_1: 1.9850 - a_2: 2.0210 - b_1: 1.7064 - b_2: 1.7440 - d_1: 1.4618 - d_2: 1.4913 - n: 1.3940 - mean_metric: 0.3882 - val_loss: 3.7516 - val_a_1: 1.9393 - val_a_2: 1.8143 - val_b_1: 1.4252 - val_b_2: 1.3737 - val_d_1: 1.0932 - val_d_2: 1.0794 - val_n: 1.3965 - val_mean_metric: 0.3284 - lr: 0.0010
# Epoch 41/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1234 - a_1: 2.0184 - a_2: 2.0116 - b_1: 1.6837 - b_2: 1.7378 - d_1: 1.4793 - d_2: 1.4739 - n: 1.3808 - mean_metric: 0.3876 - val_loss: 3.5864 - val_a_1: 1.8960 - val_a_2: 1.6918 - val_b_1: 1.4027 - val_b_2: 1.3613 - val_d_1: 1.0451 - val_d_2: 1.0660 - val_n: 1.3857 - val_mean_metric: 0.3195 - lr: 0.0010
# Epoch 42/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1097 - a_1: 2.0148 - a_2: 2.0059 - b_1: 1.6877 - b_2: 1.7291 - d_1: 1.4539 - d_2: 1.4721 - n: 1.3863 - mean_metric: 0.3864 - val_loss: 3.6767 - val_a_1: 1.9583 - val_a_2: 1.7257 - val_b_1: 1.4036 - val_b_2: 1.4099 - val_d_1: 1.0759 - val_d_2: 1.1004 - val_n: 1.3900 - val_mean_metric: 0.3265 - lr: 0.0010
# Epoch 43/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.1414 - a_1: 2.0144 - a_2: 2.0098 - b_1: 1.7224 - b_2: 1.7411 - d_1: 1.4691 - d_2: 1.4728 - n: 1.3939 - mean_metric: 0.3889 - val_loss: 3.5814 - val_a_1: 1.9206 - val_a_2: 1.6932 - val_b_1: 1.4187 - val_b_2: 1.3706 - val_d_1: 1.0380 - val_d_2: 1.0432 - val_n: 1.3860 - val_mean_metric: 0.3202 - lr: 0.0010
# Epoch 44/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.0812 - a_1: 2.0074 - a_2: 2.0224 - b_1: 1.6900 - b_2: 1.7330 - d_1: 1.4462 - d_2: 1.4689 - n: 1.3908 - mean_metric: 0.3869 - val_loss: 3.6471 - val_a_1: 2.0056 - val_a_2: 1.6966 - val_b_1: 1.4356 - val_b_2: 1.3377 - val_d_1: 1.0607 - val_d_2: 1.1003 - val_n: 1.3878 - val_mean_metric: 0.3252 - lr: 0.0010
# Epoch 45/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.0862 - a_1: 1.9782 - a_2: 2.0225 - b_1: 1.6865 - b_2: 1.7364 - d_1: 1.4673 - d_2: 1.4815 - n: 1.3873 - mean_metric: 0.3868 - val_loss: 3.6115 - val_a_1: 1.9678 - val_a_2: 1.7168 - val_b_1: 1.4049 - val_b_2: 1.2906 - val_d_1: 1.0750 - val_d_2: 1.1062 - val_n: 1.3986 - val_mean_metric: 0.3231 - lr: 0.0010
# Epoch 46/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.0608 - a_1: 1.9690 - a_2: 2.0019 - b_1: 1.7064 - b_2: 1.7258 - d_1: 1.4715 - d_2: 1.4640 - n: 1.3887 - mean_metric: 0.3857 - val_loss: 3.6377 - val_a_1: 1.9377 - val_a_2: 1.7469 - val_b_1: 1.4169 - val_b_2: 1.3881 - val_d_1: 1.0598 - val_d_2: 1.1071 - val_n: 1.3880 - val_mean_metric: 0.3259 - lr: 0.0010
# Epoch 47/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.0162 - a_1: 1.9575 - a_2: 2.0120 - b_1: 1.6669 - b_2: 1.7295 - d_1: 1.4626 - d_2: 1.4786 - n: 1.3965 - mean_metric: 0.3849 - val_loss: 3.5435 - val_a_1: 1.8859 - val_a_2: 1.7038 - val_b_1: 1.4201 - val_b_2: 1.3483 - val_d_1: 1.0569 - val_d_2: 1.0314 - val_n: 1.3877 - val_mean_metric: 0.3190 - lr: 0.0010
# Epoch 48/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.0091 - a_1: 1.9722 - a_2: 1.9960 - b_1: 1.6923 - b_2: 1.7259 - d_1: 1.4484 - d_2: 1.4465 - n: 1.3949 - mean_metric: 0.3840 - val_loss: 3.5265 - val_a_1: 1.8859 - val_a_2: 1.6526 - val_b_1: 1.4380 - val_b_2: 1.3829 - val_d_1: 1.0315 - val_d_2: 1.0669 - val_n: 1.3877 - val_mean_metric: 0.3194 - lr: 0.0010
# Epoch 49/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9735 - a_1: 1.9762 - a_2: 1.9972 - b_1: 1.6779 - b_2: 1.7056 - d_1: 1.4556 - d_2: 1.4369 - n: 1.3927 - mean_metric: 0.3829 - val_loss: 3.5120 - val_a_1: 1.9491 - val_a_2: 1.6734 - val_b_1: 1.3870 - val_b_2: 1.3359 - val_d_1: 1.0347 - val_d_2: 1.0082 - val_n: 1.3903 - val_mean_metric: 0.3173 - lr: 0.0010
# Epoch 50/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.0017 - a_1: 1.9747 - a_2: 1.9909 - b_1: 1.6802 - b_2: 1.7131 - d_1: 1.4626 - d_2: 1.4762 - n: 1.3948 - mean_metric: 0.3846 - val_loss: 3.5618 - val_a_1: 1.9599 - val_a_2: 1.7257 - val_b_1: 1.3768 - val_b_2: 1.3038 - val_d_1: 1.0620 - val_d_2: 1.0545 - val_n: 1.4074 - val_mean_metric: 0.3209 - lr: 0.0010
# Epoch 51/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 5.0514 - a_1: 1.9681 - a_2: 2.0360 - b_1: 1.6947 - b_2: 1.7218 - d_1: 1.4655 - d_2: 1.4648 - n: 1.3997 - mean_metric: 0.3864 - val_loss: 3.5735 - val_a_1: 1.9285 - val_a_2: 1.7071 - val_b_1: 1.3792 - val_b_2: 1.3794 - val_d_1: 1.1246 - val_d_2: 1.0377 - val_n: 1.4045 - val_mean_metric: 0.3232 - lr: 0.0010
# Epoch 52/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9956 - a_1: 1.9517 - a_2: 2.0010 - b_1: 1.6824 - b_2: 1.7204 - d_1: 1.4714 - d_2: 1.4635 - n: 1.3994 - mean_metric: 0.3845 - val_loss: 3.4115 - val_a_1: 1.8342 - val_a_2: 1.6615 - val_b_1: 1.3841 - val_b_2: 1.3546 - val_d_1: 0.9985 - val_d_2: 1.0075 - val_n: 1.3962 - val_mean_metric: 0.3126 - lr: 0.0010
# Epoch 53/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9953 - a_1: 1.9715 - a_2: 1.9816 - b_1: 1.6727 - b_2: 1.7280 - d_1: 1.4600 - d_2: 1.4729 - n: 1.4077 - mean_metric: 0.3846 - val_loss: 3.5136 - val_a_1: 1.9621 - val_a_2: 1.6590 - val_b_1: 1.3850 - val_b_2: 1.2810 - val_d_1: 1.0585 - val_d_2: 1.0620 - val_n: 1.4080 - val_mean_metric: 0.3184 - lr: 0.0010
# Epoch 54/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9572 - a_1: 1.9735 - a_2: 1.9791 - b_1: 1.6934 - b_2: 1.6878 - d_1: 1.4692 - d_2: 1.4377 - n: 1.3972 - mean_metric: 0.3828 - val_loss: 3.4832 - val_a_1: 1.8873 - val_a_2: 1.6764 - val_b_1: 1.4263 - val_b_2: 1.3399 - val_d_1: 1.0731 - val_d_2: 1.0328 - val_n: 1.3975 - val_mean_metric: 0.3190 - lr: 0.0010
# Epoch 55/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9454 - a_1: 1.9699 - a_2: 1.9979 - b_1: 1.6905 - b_2: 1.6729 - d_1: 1.4463 - d_2: 1.4662 - n: 1.4014 - mean_metric: 0.3830 - val_loss: 3.4602 - val_a_1: 1.9123 - val_a_2: 1.6782 - val_b_1: 1.3690 - val_b_2: 1.3044 - val_d_1: 1.0286 - val_d_2: 1.0616 - val_n: 1.4011 - val_mean_metric: 0.3165 - lr: 0.0010
# Epoch 56/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9517 - a_1: 1.9385 - a_2: 1.9821 - b_1: 1.6765 - b_2: 1.7099 - d_1: 1.4529 - d_2: 1.4782 - n: 1.4047 - mean_metric: 0.3828 - val_loss: 3.4946 - val_a_1: 1.9308 - val_a_2: 1.7168 - val_b_1: 1.3544 - val_b_2: 1.3254 - val_d_1: 1.0213 - val_d_2: 1.0160 - val_n: 1.4141 - val_mean_metric: 0.3172 - lr: 0.0010
# Epoch 57/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9435 - a_1: 1.9572 - a_2: 1.9945 - b_1: 1.6767 - b_2: 1.7246 - d_1: 1.4397 - d_2: 1.4633 - n: 1.3988 - mean_metric: 0.3833 - val_loss: 3.4295 - val_a_1: 1.8590 - val_a_2: 1.6972 - val_b_1: 1.3552 - val_b_2: 1.2822 - val_d_1: 1.0157 - val_d_2: 1.0391 - val_n: 1.4102 - val_mean_metric: 0.3134 - lr: 0.0010
# Epoch 58/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9743 - a_1: 1.9642 - a_2: 2.0162 - b_1: 1.6822 - b_2: 1.7056 - d_1: 1.4534 - d_2: 1.4645 - n: 1.3968 - mean_metric: 0.3843 - val_loss: 3.4718 - val_a_1: 1.9015 - val_a_2: 1.7074 - val_b_1: 1.3542 - val_b_2: 1.3250 - val_d_1: 1.0790 - val_d_2: 1.0366 - val_n: 1.4076 - val_mean_metric: 0.3183 - lr: 0.0010
# Epoch 59/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9191 - a_1: 1.9655 - a_2: 1.9948 - b_1: 1.6531 - b_2: 1.7003 - d_1: 1.4524 - d_2: 1.4613 - n: 1.4018 - mean_metric: 0.3825 - val_loss: 3.4690 - val_a_1: 1.8714 - val_a_2: 1.7085 - val_b_1: 1.3902 - val_b_2: 1.3302 - val_d_1: 1.0300 - val_d_2: 1.0537 - val_n: 1.4099 - val_mean_metric: 0.3177 - lr: 0.0010
# Epoch 60/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9345 - a_1: 1.9375 - a_2: 2.0117 - b_1: 1.6678 - b_2: 1.7094 - d_1: 1.4481 - d_2: 1.4644 - n: 1.4076 - mean_metric: 0.3830 - val_loss: 3.5468 - val_a_1: 1.9661 - val_a_2: 1.6928 - val_b_1: 1.3847 - val_b_2: 1.3073 - val_d_1: 1.1100 - val_d_2: 1.0554 - val_n: 1.4173 - val_mean_metric: 0.3223 - lr: 0.0010
# Epoch 61/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9237 - a_1: 1.9429 - a_2: 1.9995 - b_1: 1.6668 - b_2: 1.7077 - d_1: 1.4632 - d_2: 1.4721 - n: 1.4030 - mean_metric: 0.3833 - val_loss: 3.3924 - val_a_1: 1.8140 - val_a_2: 1.6619 - val_b_1: 1.4019 - val_b_2: 1.2972 - val_d_1: 1.0273 - val_d_2: 1.0604 - val_n: 1.4134 - val_mean_metric: 0.3139 - lr: 0.0010
# Epoch 62/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8716 - a_1: 1.9373 - a_2: 1.9824 - b_1: 1.6640 - b_2: 1.7020 - d_1: 1.4403 - d_2: 1.4616 - n: 1.4003 - mean_metric: 0.3811 - val_loss: 3.3503 - val_a_1: 1.8199 - val_a_2: 1.6434 - val_b_1: 1.3590 - val_b_2: 1.3291 - val_d_1: 1.0271 - val_d_2: 1.0637 - val_n: 1.3979 - val_mean_metric: 0.3128 - lr: 0.0010
# Epoch 63/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9542 - a_1: 1.9804 - a_2: 1.9931 - b_1: 1.6857 - b_2: 1.7096 - d_1: 1.4356 - d_2: 1.4770 - n: 1.4103 - mean_metric: 0.3845 - val_loss: 3.4007 - val_a_1: 1.8634 - val_a_2: 1.6696 - val_b_1: 1.3848 - val_b_2: 1.2714 - val_d_1: 1.0721 - val_d_2: 1.0044 - val_n: 1.4166 - val_mean_metric: 0.3141 - lr: 0.0010
# Epoch 64/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8769 - a_1: 1.9416 - a_2: 1.9765 - b_1: 1.6487 - b_2: 1.7069 - d_1: 1.4359 - d_2: 1.4562 - n: 1.4058 - mean_metric: 0.3807 - val_loss: 3.4212 - val_a_1: 1.8232 - val_a_2: 1.7010 - val_b_1: 1.3528 - val_b_2: 1.4067 - val_d_1: 1.0446 - val_d_2: 1.0862 - val_n: 1.3970 - val_mean_metric: 0.3183 - lr: 0.0010
# Epoch 65/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8706 - a_1: 1.9552 - a_2: 1.9796 - b_1: 1.6752 - b_2: 1.6695 - d_1: 1.4629 - d_2: 1.4374 - n: 1.4040 - mean_metric: 0.3811 - val_loss: 3.3746 - val_a_1: 1.8705 - val_a_2: 1.6900 - val_b_1: 1.3058 - val_b_2: 1.3381 - val_d_1: 0.9992 - val_d_2: 1.0329 - val_n: 1.4063 - val_mean_metric: 0.3128 - lr: 0.0010
# Epoch 66/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8295 - a_1: 1.9430 - a_2: 1.9697 - b_1: 1.6399 - b_2: 1.6836 - d_1: 1.4225 - d_2: 1.4434 - n: 1.4147 - mean_metric: 0.3788 - val_loss: 3.3586 - val_a_1: 1.8063 - val_a_2: 1.6769 - val_b_1: 1.3339 - val_b_2: 1.3354 - val_d_1: 1.0419 - val_d_2: 1.0442 - val_n: 1.4098 - val_mean_metric: 0.3130 - lr: 0.0010
# Epoch 67/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8853 - a_1: 1.9707 - a_2: 1.9908 - b_1: 1.6616 - b_2: 1.6894 - d_1: 1.4403 - d_2: 1.4403 - n: 1.4097 - mean_metric: 0.3816 - val_loss: 3.4262 - val_a_1: 1.9102 - val_a_2: 1.6598 - val_b_1: 1.3091 - val_b_2: 1.3396 - val_d_1: 1.1027 - val_d_2: 1.0597 - val_n: 1.4138 - val_mean_metric: 0.3178 - lr: 0.0010
# Epoch 68/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8536 - a_1: 1.9410 - a_2: 1.9997 - b_1: 1.6336 - b_2: 1.7115 - d_1: 1.4444 - d_2: 1.4268 - n: 1.4022 - mean_metric: 0.3802 - val_loss: 3.3539 - val_a_1: 1.8184 - val_a_2: 1.7001 - val_b_1: 1.3525 - val_b_2: 1.2979 - val_d_1: 1.0014 - val_d_2: 1.0795 - val_n: 1.4004 - val_mean_metric: 0.3131 - lr: 0.0010
# Epoch 69/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9061 - a_1: 1.9564 - a_2: 1.9953 - b_1: 1.6760 - b_2: 1.7198 - d_1: 1.4507 - d_2: 1.4356 - n: 1.4150 - mean_metric: 0.3831 - val_loss: 3.4697 - val_a_1: 1.9304 - val_a_2: 1.7019 - val_b_1: 1.3564 - val_b_2: 1.3675 - val_d_1: 0.9952 - val_d_2: 1.1000 - val_n: 1.3935 - val_mean_metric: 0.3194 - lr: 0.0010
# Epoch 70/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.9179 - a_1: 1.9419 - a_2: 1.9960 - b_1: 1.6938 - b_2: 1.7242 - d_1: 1.4564 - d_2: 1.4548 - n: 1.4046 - mean_metric: 0.3840 - val_loss: 3.2823 - val_a_1: 1.7897 - val_a_2: 1.6287 - val_b_1: 1.2900 - val_b_2: 1.3098 - val_d_1: 1.0301 - val_d_2: 1.0395 - val_n: 1.4100 - val_mean_metric: 0.3081 - lr: 0.0010
# Epoch 71/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8337 - a_1: 1.9243 - a_2: 1.9780 - b_1: 1.6711 - b_2: 1.6872 - d_1: 1.4414 - d_2: 1.4396 - n: 1.4055 - mean_metric: 0.3798 - val_loss: 3.3430 - val_a_1: 1.7926 - val_a_2: 1.6818 - val_b_1: 1.3178 - val_b_2: 1.3295 - val_d_1: 1.0093 - val_d_2: 1.1021 - val_n: 1.4139 - val_mean_metric: 0.3130 - lr: 0.0010
# Epoch 72/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8578 - a_1: 1.9329 - a_2: 1.9794 - b_1: 1.6522 - b_2: 1.6953 - d_1: 1.4588 - d_2: 1.4581 - n: 1.4065 - mean_metric: 0.3810 - val_loss: 3.3203 - val_a_1: 1.7672 - val_a_2: 1.6392 - val_b_1: 1.3613 - val_b_2: 1.3803 - val_d_1: 1.0077 - val_d_2: 1.0299 - val_n: 1.4076 - val_mean_metric: 0.3112 - lr: 0.0010
# Epoch 73/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8394 - a_1: 1.9441 - a_2: 1.9790 - b_1: 1.6583 - b_2: 1.6752 - d_1: 1.4356 - d_2: 1.4640 - n: 1.4100 - mean_metric: 0.3804 - val_loss: 3.2636 - val_a_1: 1.7801 - val_a_2: 1.6451 - val_b_1: 1.3332 - val_b_2: 1.2467 - val_d_1: 0.9845 - val_d_2: 1.0413 - val_n: 1.4187 - val_mean_metric: 0.3066 - lr: 0.0010
# Epoch 74/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7934 - a_1: 1.9131 - a_2: 1.9474 - b_1: 1.6514 - b_2: 1.6868 - d_1: 1.4323 - d_2: 1.4453 - n: 1.4122 - mean_metric: 0.3778 - val_loss: 3.2925 - val_a_1: 1.7869 - val_a_2: 1.6625 - val_b_1: 1.3562 - val_b_2: 1.2897 - val_d_1: 0.9967 - val_d_2: 1.0349 - val_n: 1.4117 - val_mean_metric: 0.3095 - lr: 0.0010
# Epoch 75/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8250 - a_1: 1.9142 - a_2: 1.9895 - b_1: 1.6906 - b_2: 1.6972 - d_1: 1.4234 - d_2: 1.4548 - n: 1.4096 - mean_metric: 0.3808 - val_loss: 3.2823 - val_a_1: 1.7946 - val_a_2: 1.6728 - val_b_1: 1.3589 - val_b_2: 1.2539 - val_d_1: 0.9834 - val_d_2: 1.0110 - val_n: 1.4170 - val_mean_metric: 0.3079 - lr: 0.0010
# Epoch 76/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7989 - a_1: 1.9506 - a_2: 1.9816 - b_1: 1.6449 - b_2: 1.6834 - d_1: 1.4340 - d_2: 1.4248 - n: 1.4060 - mean_metric: 0.3790 - val_loss: 3.3266 - val_a_1: 1.7968 - val_a_2: 1.6901 - val_b_1: 1.3635 - val_b_2: 1.3022 - val_d_1: 1.0257 - val_d_2: 1.0218 - val_n: 1.4064 - val_mean_metric: 0.3117 - lr: 0.0010
# Epoch 77/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8141 - a_1: 1.9173 - a_2: 1.9897 - b_1: 1.6483 - b_2: 1.6821 - d_1: 1.4229 - d_2: 1.4561 - n: 1.4084 - mean_metric: 0.3791 - val_loss: 3.2784 - val_a_1: 1.7853 - val_a_2: 1.6443 - val_b_1: 1.3806 - val_b_2: 1.2555 - val_d_1: 1.0092 - val_d_2: 1.0389 - val_n: 1.4124 - val_mean_metric: 0.3091 - lr: 0.0010
# Epoch 78/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7645 - a_1: 1.9315 - a_2: 1.9651 - b_1: 1.6582 - b_2: 1.6716 - d_1: 1.4009 - d_2: 1.4480 - n: 1.4115 - mean_metric: 0.3777 - val_loss: 3.2707 - val_a_1: 1.8170 - val_a_2: 1.6588 - val_b_1: 1.3232 - val_b_2: 1.2516 - val_d_1: 1.0061 - val_d_2: 1.0097 - val_n: 1.4207 - val_mean_metric: 0.3078 - lr: 0.0010
# Epoch 79/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7952 - a_1: 1.9277 - a_2: 1.9682 - b_1: 1.6515 - b_2: 1.6890 - d_1: 1.4337 - d_2: 1.4408 - n: 1.4141 - mean_metric: 0.3791 - val_loss: 3.2400 - val_a_1: 1.7594 - val_a_2: 1.6642 - val_b_1: 1.3337 - val_b_2: 1.3082 - val_d_1: 0.9614 - val_d_2: 1.0214 - val_n: 1.4079 - val_mean_metric: 0.3068 - lr: 0.0010
# Epoch 80/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7591 - a_1: 1.9189 - a_2: 1.9538 - b_1: 1.6409 - b_2: 1.6918 - d_1: 1.4055 - d_2: 1.4367 - n: 1.4117 - mean_metric: 0.3769 - val_loss: 3.3018 - val_a_1: 1.7503 - val_a_2: 1.6956 - val_b_1: 1.3417 - val_b_2: 1.3082 - val_d_1: 1.0543 - val_d_2: 1.0201 - val_n: 1.4138 - val_mean_metric: 0.3109 - lr: 0.0010
# Epoch 81/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7757 - a_1: 1.9272 - a_2: 1.9776 - b_1: 1.6684 - b_2: 1.6852 - d_1: 1.4014 - d_2: 1.4320 - n: 1.4112 - mean_metric: 0.3783 - val_loss: 3.2804 - val_a_1: 1.8156 - val_a_2: 1.6602 - val_b_1: 1.3490 - val_b_2: 1.2610 - val_d_1: 1.0267 - val_d_2: 1.0169 - val_n: 1.4093 - val_mean_metric: 0.3095 - lr: 0.0010
# Epoch 82/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7955 - a_1: 1.9260 - a_2: 1.9892 - b_1: 1.6596 - b_2: 1.7056 - d_1: 1.4110 - d_2: 1.4233 - n: 1.4078 - mean_metric: 0.3789 - val_loss: 3.3214 - val_a_1: 1.7547 - val_a_2: 1.6896 - val_b_1: 1.3748 - val_b_2: 1.3173 - val_d_1: 1.0354 - val_d_2: 1.0457 - val_n: 1.4116 - val_mean_metric: 0.3124 - lr: 0.0010
# Epoch 83/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.8048 - a_1: 1.9369 - a_2: 2.0089 - b_1: 1.6437 - b_2: 1.6776 - d_1: 1.4239 - d_2: 1.4352 - n: 1.4151 - mean_metric: 0.3795 - val_loss: 3.3293 - val_a_1: 1.8968 - val_a_2: 1.6197 - val_b_1: 1.3121 - val_b_2: 1.2738 - val_d_1: 1.0601 - val_d_2: 1.0495 - val_n: 1.4090 - val_mean_metric: 0.3121 - lr: 0.0010
# Epoch 84/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7515 - a_1: 1.9216 - a_2: 1.9646 - b_1: 1.6483 - b_2: 1.6837 - d_1: 1.4158 - d_2: 1.4371 - n: 1.4085 - mean_metric: 0.3776 - val_loss: 3.2996 - val_a_1: 1.7880 - val_a_2: 1.6647 - val_b_1: 1.3793 - val_b_2: 1.2776 - val_d_1: 1.0296 - val_d_2: 1.0639 - val_n: 1.4186 - val_mean_metric: 0.3121 - lr: 0.0010
# Epoch 85/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7235 - a_1: 1.9172 - a_2: 1.9668 - b_1: 1.6524 - b_2: 1.6559 - d_1: 1.3955 - d_2: 1.4603 - n: 1.4039 - mean_metric: 0.3766 - val_loss: 3.2123 - val_a_1: 1.7392 - val_a_2: 1.6790 - val_b_1: 1.3033 - val_b_2: 1.2736 - val_d_1: 0.9897 - val_d_2: 1.0116 - val_n: 1.4064 - val_mean_metric: 0.3050 - lr: 0.0010
# Epoch 86/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7599 - a_1: 1.9407 - a_2: 1.9694 - b_1: 1.6497 - b_2: 1.6960 - d_1: 1.4085 - d_2: 1.4272 - n: 1.4073 - mean_metric: 0.3783 - val_loss: 3.2584 - val_a_1: 1.7466 - val_a_2: 1.6687 - val_b_1: 1.3465 - val_b_2: 1.3086 - val_d_1: 1.0396 - val_d_2: 1.0337 - val_n: 1.4043 - val_mean_metric: 0.3098 - lr: 0.0010
# Epoch 87/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7515 - a_1: 1.9293 - a_2: 1.9607 - b_1: 1.6514 - b_2: 1.6762 - d_1: 1.4037 - d_2: 1.4355 - n: 1.4064 - mean_metric: 0.3770 - val_loss: 3.2436 - val_a_1: 1.7683 - val_a_2: 1.6415 - val_b_1: 1.3196 - val_b_2: 1.3115 - val_d_1: 1.0550 - val_d_2: 0.9822 - val_n: 1.4087 - val_mean_metric: 0.3078 - lr: 0.0010
# Epoch 88/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6901 - a_1: 1.9122 - a_2: 1.9623 - b_1: 1.6295 - b_2: 1.6655 - d_1: 1.3997 - d_2: 1.4312 - n: 1.4075 - mean_metric: 0.3752 - val_loss: 3.2230 - val_a_1: 1.7709 - val_a_2: 1.6665 - val_b_1: 1.2926 - val_b_2: 1.3016 - val_d_1: 1.0067 - val_d_2: 0.9903 - val_n: 1.4130 - val_mean_metric: 0.3063 - lr: 0.0010
# Epoch 89/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7276 - a_1: 1.9373 - a_2: 1.9700 - b_1: 1.6392 - b_2: 1.6687 - d_1: 1.3952 - d_2: 1.4386 - n: 1.4138 - mean_metric: 0.3771 - val_loss: 3.1930 - val_a_1: 1.7699 - val_a_2: 1.6503 - val_b_1: 1.2993 - val_b_2: 1.3221 - val_d_1: 0.9494 - val_d_2: 0.9930 - val_n: 1.3936 - val_mean_metric: 0.3042 - lr: 0.0010
# Epoch 90/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7334 - a_1: 1.9417 - a_2: 1.9752 - b_1: 1.6385 - b_2: 1.6854 - d_1: 1.3982 - d_2: 1.4213 - n: 1.4078 - mean_metric: 0.3772 - val_loss: 3.1916 - val_a_1: 1.7678 - val_a_2: 1.6681 - val_b_1: 1.3189 - val_b_2: 1.2697 - val_d_1: 0.9347 - val_d_2: 1.0141 - val_n: 1.4054 - val_mean_metric: 0.3043 - lr: 0.0010
# Epoch 91/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7343 - a_1: 1.9185 - a_2: 1.9745 - b_1: 1.6337 - b_2: 1.6866 - d_1: 1.4091 - d_2: 1.4447 - n: 1.4098 - mean_metric: 0.3775 - val_loss: 3.2781 - val_a_1: 1.7584 - val_a_2: 1.6728 - val_b_1: 1.3194 - val_b_2: 1.2982 - val_d_1: 1.0602 - val_d_2: 1.0785 - val_n: 1.4035 - val_mean_metric: 0.3111 - lr: 0.0010
# Epoch 92/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7281 - a_1: 1.9128 - a_2: 1.9891 - b_1: 1.6456 - b_2: 1.6750 - d_1: 1.3850 - d_2: 1.4368 - n: 1.4057 - mean_metric: 0.3765 - val_loss: 3.2470 - val_a_1: 1.7547 - val_a_2: 1.6745 - val_b_1: 1.3491 - val_b_2: 1.2950 - val_d_1: 0.9849 - val_d_2: 1.0171 - val_n: 1.4081 - val_mean_metric: 0.3077 - lr: 0.0010
# Epoch 93/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7029 - a_1: 1.9146 - a_2: 1.9562 - b_1: 1.6383 - b_2: 1.6894 - d_1: 1.3881 - d_2: 1.4205 - n: 1.4114 - mean_metric: 0.3754 - val_loss: 3.3113 - val_a_1: 1.8710 - val_a_2: 1.6936 - val_b_1: 1.3293 - val_b_2: 1.2769 - val_d_1: 0.9829 - val_d_2: 1.0212 - val_n: 1.4105 - val_mean_metric: 0.3110 - lr: 0.0010
# Epoch 94/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7358 - a_1: 1.9249 - a_2: 1.9865 - b_1: 1.6627 - b_2: 1.6833 - d_1: 1.4018 - d_2: 1.4072 - n: 1.4082 - mean_metric: 0.3775 - val_loss: 3.2843 - val_a_1: 1.7885 - val_a_2: 1.6982 - val_b_1: 1.3400 - val_b_2: 1.2998 - val_d_1: 1.0156 - val_d_2: 0.9804 - val_n: 1.4184 - val_mean_metric: 0.3095 - lr: 0.0010
# Epoch 95/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7436 - a_1: 1.9335 - a_2: 1.9897 - b_1: 1.6590 - b_2: 1.6767 - d_1: 1.3824 - d_2: 1.4390 - n: 1.4043 - mean_metric: 0.3776 - val_loss: 3.2936 - val_a_1: 1.8389 - val_a_2: 1.7133 - val_b_1: 1.3006 - val_b_2: 1.3217 - val_d_1: 0.9653 - val_d_2: 0.9890 - val_n: 1.4085 - val_mean_metric: 0.3094 - lr: 0.0010
# Epoch 96/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6917 - a_1: 1.9274 - a_2: 1.9350 - b_1: 1.6567 - b_2: 1.6821 - d_1: 1.3953 - d_2: 1.4228 - n: 1.4036 - mean_metric: 0.3757 - val_loss: 3.2172 - val_a_1: 1.8041 - val_a_2: 1.6513 - val_b_1: 1.3333 - val_b_2: 1.2670 - val_d_1: 0.9537 - val_d_2: 1.0326 - val_n: 1.4020 - val_mean_metric: 0.3064 - lr: 0.0010
# Epoch 97/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6884 - a_1: 1.9184 - a_2: 1.9648 - b_1: 1.6442 - b_2: 1.6975 - d_1: 1.3932 - d_2: 1.4027 - n: 1.4024 - mean_metric: 0.3756 - val_loss: 3.3242 - val_a_1: 1.8541 - val_a_2: 1.6904 - val_b_1: 1.3452 - val_b_2: 1.3029 - val_d_1: 1.0036 - val_d_2: 1.0478 - val_n: 1.4119 - val_mean_metric: 0.3132 - lr: 0.0010
# Epoch 98/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6889 - a_1: 1.9094 - a_2: 1.9642 - b_1: 1.6404 - b_2: 1.6875 - d_1: 1.3730 - d_2: 1.4476 - n: 1.4073 - mean_metric: 0.3760 - val_loss: 3.1522 - val_a_1: 1.7628 - val_a_2: 1.6338 - val_b_1: 1.2969 - val_b_2: 1.2647 - val_d_1: 0.9655 - val_d_2: 0.9972 - val_n: 1.4015 - val_mean_metric: 0.3024 - lr: 0.0010
# Epoch 99/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6629 - a_1: 1.8925 - a_2: 1.9441 - b_1: 1.6480 - b_2: 1.6668 - d_1: 1.3751 - d_2: 1.4511 - n: 1.4037 - mean_metric: 0.3744 - val_loss: 3.1951 - val_a_1: 1.8204 - val_a_2: 1.6734 - val_b_1: 1.2815 - val_b_2: 1.3072 - val_d_1: 0.9425 - val_d_2: 0.9929 - val_n: 1.3976 - val_mean_metric: 0.3055 - lr: 0.0010
# Epoch 100/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7302 - a_1: 1.9228 - a_2: 1.9702 - b_1: 1.6468 - b_2: 1.6891 - d_1: 1.3874 - d_2: 1.4568 - n: 1.4102 - mean_metric: 0.3777 - val_loss: 3.2291 - val_a_1: 1.7570 - val_a_2: 1.6738 - val_b_1: 1.2735 - val_b_2: 1.3241 - val_d_1: 1.0599 - val_d_2: 0.9963 - val_n: 1.4025 - val_mean_metric: 0.3078 - lr: 0.0010
# Epoch 101/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6531 - a_1: 1.9029 - a_2: 1.9640 - b_1: 1.6308 - b_2: 1.6731 - d_1: 1.3813 - d_2: 1.4169 - n: 1.4056 - mean_metric: 0.3741 - val_loss: 3.2044 - val_a_1: 1.7484 - val_a_2: 1.6752 - val_b_1: 1.3550 - val_b_2: 1.2587 - val_d_1: 0.9854 - val_d_2: 1.0487 - val_n: 1.3956 - val_mean_metric: 0.3071 - lr: 0.0010
# Epoch 102/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 4.6760 - a_1: 1.9229 - a_2: 1.9617 - b_1: 1.6506 - b_2: 1.6484 - d_1: 1.3724 - d_2: 1.4243 - n: 1.4051 - mean_metric: 0.3745 - val_loss: 3.2501 - val_a_1: 1.7566 - val_a_2: 1.7085 - val_b_1: 1.3082 - val_b_2: 1.3325 - val_d_1: 1.0474 - val_d_2: 1.0581 - val_n: 1.3970 - val_mean_metric: 0.3117 - lr: 0.0010
# Epoch 103/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6881 - a_1: 1.9170 - a_2: 1.9807 - b_1: 1.6315 - b_2: 1.6835 - d_1: 1.3794 - d_2: 1.4334 - n: 1.4071 - mean_metric: 0.3761 - val_loss: 3.2343 - val_a_1: 1.8458 - val_a_2: 1.6776 - val_b_1: 1.3319 - val_b_2: 1.2535 - val_d_1: 0.9668 - val_d_2: 1.0107 - val_n: 1.4057 - val_mean_metric: 0.3079 - lr: 0.0010
# Epoch 104/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7131 - a_1: 1.9248 - a_2: 1.9788 - b_1: 1.6586 - b_2: 1.6732 - d_1: 1.3747 - d_2: 1.4512 - n: 1.3995 - mean_metric: 0.3769 - val_loss: 3.2262 - val_a_1: 1.7334 - val_a_2: 1.6780 - val_b_1: 1.3712 - val_b_2: 1.3509 - val_d_1: 1.0004 - val_d_2: 0.9739 - val_n: 1.3930 - val_mean_metric: 0.3082 - lr: 0.0010
# Epoch 105/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.7145 - a_1: 1.9511 - a_2: 1.9862 - b_1: 1.6518 - b_2: 1.7037 - d_1: 1.3688 - d_2: 1.4076 - n: 1.4029 - mean_metric: 0.3774 - val_loss: 3.1496 - val_a_1: 1.7120 - val_a_2: 1.6866 - val_b_1: 1.2732 - val_b_2: 1.2389 - val_d_1: 1.0172 - val_d_2: 1.0391 - val_n: 1.3841 - val_mean_metric: 0.3034 - lr: 0.0010
# Epoch 106/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6205 - a_1: 1.9043 - a_2: 1.9498 - b_1: 1.6453 - b_2: 1.6578 - d_1: 1.3580 - d_2: 1.4375 - n: 1.4070 - mean_metric: 0.3735 - val_loss: 3.0950 - val_a_1: 1.7108 - val_a_2: 1.6254 - val_b_1: 1.3006 - val_b_2: 1.2477 - val_d_1: 0.9348 - val_d_2: 1.0096 - val_n: 1.3960 - val_mean_metric: 0.2993 - lr: 0.0010
# Epoch 107/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6652 - a_1: 1.9208 - a_2: 1.9700 - b_1: 1.6312 - b_2: 1.6721 - d_1: 1.3670 - d_2: 1.4264 - n: 1.3949 - mean_metric: 0.3745 - val_loss: 3.2157 - val_a_1: 1.7956 - val_a_2: 1.6958 - val_b_1: 1.2779 - val_b_2: 1.2671 - val_d_1: 1.0451 - val_d_2: 1.0081 - val_n: 1.3888 - val_mean_metric: 0.3075 - lr: 0.0010
# Epoch 108/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6649 - a_1: 1.9233 - a_2: 1.9456 - b_1: 1.6342 - b_2: 1.6613 - d_1: 1.3724 - d_2: 1.4419 - n: 1.4026 - mean_metric: 0.3743 - val_loss: 3.2349 - val_a_1: 1.7472 - val_a_2: 1.6674 - val_b_1: 1.3519 - val_b_2: 1.3498 - val_d_1: 1.0215 - val_d_2: 1.0128 - val_n: 1.3973 - val_mean_metric: 0.3098 - lr: 0.0010
# Epoch 109/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6621 - a_1: 1.9128 - a_2: 1.9675 - b_1: 1.6158 - b_2: 1.6830 - d_1: 1.3611 - d_2: 1.4437 - n: 1.3980 - mean_metric: 0.3744 - val_loss: 3.1373 - val_a_1: 1.7065 - val_a_2: 1.6526 - val_b_1: 1.2856 - val_b_2: 1.2643 - val_d_1: 1.0156 - val_d_2: 1.0079 - val_n: 1.3913 - val_mean_metric: 0.3025 - lr: 0.0010
# Epoch 110/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6463 - a_1: 1.9162 - a_2: 1.9748 - b_1: 1.6382 - b_2: 1.6689 - d_1: 1.3518 - d_2: 1.4108 - n: 1.4024 - mean_metric: 0.3737 - val_loss: 3.1986 - val_a_1: 1.7936 - val_a_2: 1.6788 - val_b_1: 1.3016 - val_b_2: 1.2778 - val_d_1: 0.9835 - val_d_2: 1.0420 - val_n: 1.3967 - val_mean_metric: 0.3073 - lr: 0.0010
# Epoch 111/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 4.7217 - a_1: 1.9483 - a_2: 1.9740 - b_1: 1.6561 - b_2: 1.6567 - d_1: 1.3869 - d_2: 1.4428 - n: 1.4076 - mean_metric: 0.3773 - val_loss: 3.1982 - val_a_1: 1.7271 - val_a_2: 1.6522 - val_b_1: 1.3572 - val_b_2: 1.3178 - val_d_1: 1.0179 - val_d_2: 1.0279 - val_n: 1.3965 - val_mean_metric: 0.3081 - lr: 0.0010
# Epoch 112/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6539 - a_1: 1.9138 - a_2: 1.9525 - b_1: 1.6406 - b_2: 1.6975 - d_1: 1.3380 - d_2: 1.4512 - n: 1.3968 - mean_metric: 0.3745 - val_loss: 3.1062 - val_a_1: 1.7081 - val_a_2: 1.6328 - val_b_1: 1.2901 - val_b_2: 1.2763 - val_d_1: 0.9668 - val_d_2: 1.0173 - val_n: 1.3919 - val_mean_metric: 0.3012 - lr: 0.0010
# Epoch 113/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6836 - a_1: 1.9043 - a_2: 1.9665 - b_1: 1.6580 - b_2: 1.6739 - d_1: 1.3597 - d_2: 1.4517 - n: 1.3937 - mean_metric: 0.3752 - val_loss: 3.0641 - val_a_1: 1.7215 - val_a_2: 1.5888 - val_b_1: 1.2684 - val_b_2: 1.2674 - val_d_1: 0.9443 - val_d_2: 1.0036 - val_n: 1.3833 - val_mean_metric: 0.2977 - lr: 0.0010
# Epoch 114/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6601 - a_1: 1.9507 - a_2: 1.9586 - b_1: 1.6238 - b_2: 1.6664 - d_1: 1.3680 - d_2: 1.4263 - n: 1.4099 - mean_metric: 0.3750 - val_loss: 3.1015 - val_a_1: 1.7207 - val_a_2: 1.6349 - val_b_1: 1.2643 - val_b_2: 1.2888 - val_d_1: 0.9646 - val_d_2: 0.9984 - val_n: 1.3887 - val_mean_metric: 0.3004 - lr: 0.0010
# Epoch 115/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 4.6778 - a_1: 1.9278 - a_2: 1.9865 - b_1: 1.6485 - b_2: 1.6789 - d_1: 1.3656 - d_2: 1.4116 - n: 1.3991 - mean_metric: 0.3755 - val_loss: 3.1189 - val_a_1: 1.7701 - val_a_2: 1.6207 - val_b_1: 1.3051 - val_b_2: 1.2631 - val_d_1: 0.9634 - val_d_2: 0.9980 - val_n: 1.3835 - val_mean_metric: 0.3018 - lr: 0.0010
# Epoch 116/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 4.6873 - a_1: 1.9243 - a_2: 1.9716 - b_1: 1.6488 - b_2: 1.7007 - d_1: 1.3493 - d_2: 1.4363 - n: 1.3991 - mean_metric: 0.3760 - val_loss: 3.1462 - val_a_1: 1.7209 - val_a_2: 1.6467 - val_b_1: 1.3040 - val_b_2: 1.2723 - val_d_1: 1.0067 - val_d_2: 1.0404 - val_n: 1.3890 - val_mean_metric: 0.3043 - lr: 0.0010
# Epoch 117/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 4.6628 - a_1: 1.9341 - a_2: 1.9617 - b_1: 1.6491 - b_2: 1.6711 - d_1: 1.3531 - d_2: 1.4272 - n: 1.4008 - mean_metric: 0.3748 - val_loss: 3.2157 - val_a_1: 1.7646 - val_a_2: 1.7105 - val_b_1: 1.3693 - val_b_2: 1.2655 - val_d_1: 0.9850 - val_d_2: 1.0686 - val_n: 1.3854 - val_mean_metric: 0.3098 - lr: 0.0010
# Epoch 118/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.5922 - a_1: 1.8891 - a_2: 1.9618 - b_1: 1.6445 - b_2: 1.6454 - d_1: 1.3554 - d_2: 1.3977 - n: 1.3926 - mean_metric: 0.3712 - val_loss: 3.0752 - val_a_1: 1.6819 - val_a_2: 1.6316 - val_b_1: 1.2953 - val_b_2: 1.2410 - val_d_1: 0.9692 - val_d_2: 1.0109 - val_n: 1.3839 - val_mean_metric: 0.2989 - lr: 0.0010
# Epoch 119/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 4.6489 - a_1: 1.9191 - a_2: 1.9773 - b_1: 1.6338 - b_2: 1.6560 - d_1: 1.3464 - d_2: 1.4357 - n: 1.3997 - mean_metric: 0.3738 - val_loss: 3.1950 - val_a_1: 1.7314 - val_a_2: 1.7160 - val_b_1: 1.3211 - val_b_2: 1.3157 - val_d_1: 0.9653 - val_d_2: 1.0675 - val_n: 1.3866 - val_mean_metric: 0.3083 - lr: 0.0010
# Epoch 120/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 4.6967 - a_1: 1.9112 - a_2: 1.9999 - b_1: 1.6297 - b_2: 1.6911 - d_1: 1.3594 - d_2: 1.4466 - n: 1.4012 - mean_metric: 0.3762 - val_loss: 3.0953 - val_a_1: 1.7462 - val_a_2: 1.6411 - val_b_1: 1.2586 - val_b_2: 1.2015 - val_d_1: 0.9588 - val_d_2: 1.0464 - val_n: 1.3807 - val_mean_metric: 0.2996 - lr: 0.0010
# Epoch 121/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6386 - a_1: 1.9193 - a_2: 1.9654 - b_1: 1.6234 - b_2: 1.6867 - d_1: 1.3452 - d_2: 1.4289 - n: 1.3938 - mean_metric: 0.3737 - val_loss: 3.0789 - val_a_1: 1.7091 - val_a_2: 1.6772 - val_b_1: 1.2485 - val_b_2: 1.2623 - val_d_1: 0.9375 - val_d_2: 1.0079 - val_n: 1.3790 - val_mean_metric: 0.2992 - lr: 0.0010
# Epoch 122/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6465 - a_1: 1.9222 - a_2: 1.9660 - b_1: 1.6504 - b_2: 1.6541 - d_1: 1.3572 - d_2: 1.4217 - n: 1.3932 - mean_metric: 0.3738 - val_loss: 3.1854 - val_a_1: 1.7321 - val_a_2: 1.6788 - val_b_1: 1.3129 - val_b_2: 1.3123 - val_d_1: 1.0453 - val_d_2: 1.0143 - val_n: 1.3834 - val_mean_metric: 0.3075 - lr: 0.0010
# Epoch 123/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6275 - a_1: 1.9397 - a_2: 1.9453 - b_1: 1.6365 - b_2: 1.6592 - d_1: 1.3488 - d_2: 1.4138 - n: 1.3910 - mean_metric: 0.3729 - val_loss: 3.0703 - val_a_1: 1.7403 - val_a_2: 1.6071 - val_b_1: 1.2950 - val_b_2: 1.2746 - val_d_1: 0.9560 - val_d_2: 1.0090 - val_n: 1.3794 - val_mean_metric: 0.3005 - lr: 0.0010
# Epoch 124/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6312 - a_1: 1.8938 - a_2: 1.9612 - b_1: 1.6372 - b_2: 1.6686 - d_1: 1.3407 - d_2: 1.4370 - n: 1.4026 - mean_metric: 0.3730 - val_loss: 3.0521 - val_a_1: 1.7106 - val_a_2: 1.6358 - val_b_1: 1.2423 - val_b_2: 1.2597 - val_d_1: 0.9469 - val_d_2: 0.9979 - val_n: 1.3787 - val_mean_metric: 0.2976 - lr: 0.0010
# Epoch 125/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.6197 - a_1: 1.9098 - a_2: 1.9742 - b_1: 1.6451 - b_2: 1.6613 - d_1: 1.3417 - d_2: 1.4203 - n: 1.4008 - mean_metric: 0.3734 - val_loss: 3.0643 - val_a_1: 1.6861 - val_a_2: 1.6237 - val_b_1: 1.2845 - val_b_2: 1.2310 - val_d_1: 0.9909 - val_d_2: 1.0308 - val_n: 1.3764 - val_mean_metric: 0.2992 - lr: 0.0010
# Epoch 126/1000
# ...
# Epoch 960/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9255 - a_1: 1.7582 - a_2: 1.7457 - b_1: 1.4799 - b_2: 1.4739 - d_1: 1.1542 - d_2: 1.2517 - n: 1.3805 - mean_metric: 0.3369 - val_loss: 2.2793 - val_a_1: 1.4551 - val_a_2: 1.2973 - val_b_1: 0.9893 - val_b_2: 0.9896 - val_d_1: 0.7060 - val_d_2: 0.7658 - val_n: 1.3556 - val_mean_metric: 0.2452 - lr: 7.7650e-05
# Epoch 961/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9105 - a_1: 1.7654 - a_2: 1.7284 - b_1: 1.5062 - b_2: 1.4443 - d_1: 1.1704 - d_2: 1.2200 - n: 1.3798 - mean_metric: 0.3359 - val_loss: 2.3033 - val_a_1: 1.4604 - val_a_2: 1.3081 - val_b_1: 1.0156 - val_b_2: 0.9973 - val_d_1: 0.7330 - val_d_2: 0.7877 - val_n: 1.3561 - val_mean_metric: 0.2484 - lr: 7.6000e-05
# Epoch 962/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9255 - a_1: 1.7608 - a_2: 1.7229 - b_1: 1.4808 - b_2: 1.4792 - d_1: 1.1692 - d_2: 1.2314 - n: 1.3811 - mean_metric: 0.3362 - val_loss: 2.2939 - val_a_1: 1.4486 - val_a_2: 1.2997 - val_b_1: 0.9923 - val_b_2: 1.0049 - val_d_1: 0.7505 - val_d_2: 0.7858 - val_n: 1.3539 - val_mean_metric: 0.2477 - lr: 7.4350e-05
# Epoch 963/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9470 - a_1: 1.7610 - a_2: 1.7157 - b_1: 1.5188 - b_2: 1.4748 - d_1: 1.1729 - d_2: 1.2386 - n: 1.3768 - mean_metric: 0.3373 - val_loss: 2.2807 - val_a_1: 1.4549 - val_a_2: 1.3044 - val_b_1: 0.9949 - val_b_2: 0.9852 - val_d_1: 0.7053 - val_d_2: 0.7658 - val_n: 1.3549 - val_mean_metric: 0.2454 - lr: 7.2700e-05
# Epoch 964/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9764 - a_1: 1.7827 - a_2: 1.7411 - b_1: 1.5192 - b_2: 1.5013 - d_1: 1.1617 - d_2: 1.2204 - n: 1.3790 - mean_metric: 0.3388 - val_loss: 2.2961 - val_a_1: 1.4672 - val_a_2: 1.3148 - val_b_1: 0.9943 - val_b_2: 0.9928 - val_d_1: 0.7192 - val_d_2: 0.7764 - val_n: 1.3566 - val_mean_metric: 0.2473 - lr: 7.1050e-05
# Epoch 965/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9361 - a_1: 1.7657 - a_2: 1.7292 - b_1: 1.5055 - b_2: 1.4564 - d_1: 1.1684 - d_2: 1.2563 - n: 1.3798 - mean_metric: 0.3374 - val_loss: 2.2783 - val_a_1: 1.4698 - val_a_2: 1.3032 - val_b_1: 0.9956 - val_b_2: 0.9797 - val_d_1: 0.6827 - val_d_2: 0.7296 - val_n: 1.3565 - val_mean_metric: 0.2439 - lr: 6.9400e-05
# Epoch 966/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.0158 - a_1: 1.7687 - a_2: 1.7314 - b_1: 1.5293 - b_2: 1.4903 - d_1: 1.1932 - d_2: 1.2589 - n: 1.3783 - mean_metric: 0.3404 - val_loss: 2.2977 - val_a_1: 1.4576 - val_a_2: 1.2966 - val_b_1: 1.0040 - val_b_2: 1.0009 - val_d_1: 0.7309 - val_d_2: 0.7770 - val_n: 1.3581 - val_mean_metric: 0.2474 - lr: 6.7750e-05
# Epoch 967/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9720 - a_1: 1.7607 - a_2: 1.7226 - b_1: 1.5098 - b_2: 1.5054 - d_1: 1.1852 - d_2: 1.2386 - n: 1.3777 - mean_metric: 0.3387 - val_loss: 2.2965 - val_a_1: 1.4739 - val_a_2: 1.3103 - val_b_1: 1.0059 - val_b_2: 0.9871 - val_d_1: 0.7187 - val_d_2: 0.7392 - val_n: 1.3580 - val_mean_metric: 0.2463 - lr: 6.6100e-05
# Epoch 968/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 3.9213 - a_1: 1.7668 - a_2: 1.7316 - b_1: 1.5028 - b_2: 1.4365 - d_1: 1.1780 - d_2: 1.2474 - n: 1.3741 - mean_metric: 0.3367 - val_loss: 2.2904 - val_a_1: 1.4576 - val_a_2: 1.3005 - val_b_1: 1.0011 - val_b_2: 0.9891 - val_d_1: 0.7382 - val_d_2: 0.7705 - val_n: 1.3564 - val_mean_metric: 0.2470 - lr: 6.4450e-05
# Epoch 969/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9294 - a_1: 1.7676 - a_2: 1.7365 - b_1: 1.4766 - b_2: 1.4931 - d_1: 1.1626 - d_2: 1.2384 - n: 1.3731 - mean_metric: 0.3370 - val_loss: 2.2976 - val_a_1: 1.4700 - val_a_2: 1.3157 - val_b_1: 1.0067 - val_b_2: 0.9829 - val_d_1: 0.7257 - val_d_2: 0.7640 - val_n: 1.3570 - val_mean_metric: 0.2473 - lr: 6.2800e-05
# Epoch 970/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9225 - a_1: 1.7558 - a_2: 1.7302 - b_1: 1.4812 - b_2: 1.4522 - d_1: 1.1793 - d_2: 1.2424 - n: 1.3794 - mean_metric: 0.3361 - val_loss: 2.2977 - val_a_1: 1.4602 - val_a_2: 1.3181 - val_b_1: 0.9993 - val_b_2: 0.9994 - val_d_1: 0.7258 - val_d_2: 0.7786 - val_n: 1.3563 - val_mean_metric: 0.2478 - lr: 6.1150e-05
# Epoch 971/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9800 - a_1: 1.7762 - a_2: 1.7207 - b_1: 1.5044 - b_2: 1.4822 - d_1: 1.1776 - d_2: 1.2455 - n: 1.3783 - mean_metric: 0.3382 - val_loss: 2.2858 - val_a_1: 1.4663 - val_a_2: 1.3116 - val_b_1: 0.9969 - val_b_2: 0.9819 - val_d_1: 0.7194 - val_d_2: 0.7486 - val_n: 1.3564 - val_mean_metric: 0.2459 - lr: 5.9500e-05
# Epoch 972/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9445 - a_1: 1.7662 - a_2: 1.7351 - b_1: 1.5005 - b_2: 1.4306 - d_1: 1.1881 - d_2: 1.2587 - n: 1.3787 - mean_metric: 0.3373 - val_loss: 2.2961 - val_a_1: 1.4770 - val_a_2: 1.3191 - val_b_1: 0.9998 - val_b_2: 0.9905 - val_d_1: 0.7132 - val_d_2: 0.7583 - val_n: 1.3553 - val_mean_metric: 0.2470 - lr: 5.7850e-05
# Epoch 973/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9462 - a_1: 1.7627 - a_2: 1.7086 - b_1: 1.5057 - b_2: 1.4747 - d_1: 1.1847 - d_2: 1.2478 - n: 1.3741 - mean_metric: 0.3373 - val_loss: 2.2835 - val_a_1: 1.4570 - val_a_2: 1.3165 - val_b_1: 0.9957 - val_b_2: 0.9885 - val_d_1: 0.6966 - val_d_2: 0.7517 - val_n: 1.3544 - val_mean_metric: 0.2453 - lr: 5.6200e-05
# Epoch 974/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9433 - a_1: 1.7353 - a_2: 1.7188 - b_1: 1.5175 - b_2: 1.4619 - d_1: 1.1604 - d_2: 1.2779 - n: 1.3698 - mean_metric: 0.3368 - val_loss: 2.2864 - val_a_1: 1.4817 - val_a_2: 1.3279 - val_b_1: 0.9958 - val_b_2: 0.9692 - val_d_1: 0.6630 - val_d_2: 0.7298 - val_n: 1.3600 - val_mean_metric: 0.2442 - lr: 5.4550e-05
# Epoch 975/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9820 - a_1: 1.7760 - a_2: 1.7278 - b_1: 1.4894 - b_2: 1.4931 - d_1: 1.1697 - d_2: 1.2641 - n: 1.3806 - mean_metric: 0.3387 - val_loss: 2.2826 - val_a_1: 1.4540 - val_a_2: 1.3062 - val_b_1: 0.9956 - val_b_2: 0.9942 - val_d_1: 0.7036 - val_d_2: 0.7589 - val_n: 1.3561 - val_mean_metric: 0.2455 - lr: 5.2900e-05
# Epoch 976/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9268 - a_1: 1.7445 - a_2: 1.7187 - b_1: 1.4899 - b_2: 1.4737 - d_1: 1.1772 - d_2: 1.2539 - n: 1.3787 - mean_metric: 0.3366 - val_loss: 2.2864 - val_a_1: 1.4593 - val_a_2: 1.3099 - val_b_1: 0.9952 - val_b_2: 0.9854 - val_d_1: 0.7240 - val_d_2: 0.7675 - val_n: 1.3542 - val_mean_metric: 0.2464 - lr: 5.1250e-05
# Epoch 977/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9713 - a_1: 1.7597 - a_2: 1.7292 - b_1: 1.5245 - b_2: 1.4824 - d_1: 1.1758 - d_2: 1.2433 - n: 1.3838 - mean_metric: 0.3387 - val_loss: 2.2739 - val_a_1: 1.4523 - val_a_2: 1.3001 - val_b_1: 0.9907 - val_b_2: 0.9762 - val_d_1: 0.6987 - val_d_2: 0.7654 - val_n: 1.3563 - val_mean_metric: 0.2446 - lr: 4.9600e-05
# Epoch 978/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9285 - a_1: 1.7620 - a_2: 1.7237 - b_1: 1.4957 - b_2: 1.4783 - d_1: 1.1644 - d_2: 1.2402 - n: 1.3771 - mean_metric: 0.3367 - val_loss: 2.2837 - val_a_1: 1.4534 - val_a_2: 1.3010 - val_b_1: 0.9968 - val_b_2: 0.9811 - val_d_1: 0.7095 - val_d_2: 0.7893 - val_n: 1.3564 - val_mean_metric: 0.2462 - lr: 4.7950e-05
# Epoch 979/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 3.8967 - a_1: 1.7498 - a_2: 1.7168 - b_1: 1.4812 - b_2: 1.4350 - d_1: 1.1803 - d_2: 1.2417 - n: 1.3853 - mean_metric: 0.3351 - val_loss: 2.2776 - val_a_1: 1.4533 - val_a_2: 1.2950 - val_b_1: 0.9912 - val_b_2: 0.9759 - val_d_1: 0.7322 - val_d_2: 0.7748 - val_n: 1.3551 - val_mean_metric: 0.2458 - lr: 4.6300e-05
# Epoch 980/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 4.0004 - a_1: 1.7727 - a_2: 1.7169 - b_1: 1.4951 - b_2: 1.4868 - d_1: 1.1887 - d_2: 1.2662 - n: 1.3821 - mean_metric: 0.3390 - val_loss: 2.2943 - val_a_1: 1.4616 - val_a_2: 1.3132 - val_b_1: 1.0015 - val_b_2: 0.9910 - val_d_1: 0.7296 - val_d_2: 0.7623 - val_n: 1.3560 - val_mean_metric: 0.2470 - lr: 4.4650e-05
# Epoch 981/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9746 - a_1: 1.7702 - a_2: 1.7306 - b_1: 1.5064 - b_2: 1.4988 - d_1: 1.1684 - d_2: 1.2332 - n: 1.3776 - mean_metric: 0.3382 - val_loss: 2.2955 - val_a_1: 1.4575 - val_a_2: 1.2974 - val_b_1: 1.0051 - val_b_2: 1.0000 - val_d_1: 0.7455 - val_d_2: 0.7717 - val_n: 1.3556 - val_mean_metric: 0.2476 - lr: 4.3000e-05
# Epoch 982/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9717 - a_1: 1.7559 - a_2: 1.7440 - b_1: 1.5063 - b_2: 1.4720 - d_1: 1.1668 - d_2: 1.2702 - n: 1.3769 - mean_metric: 0.3384 - val_loss: 2.2998 - val_a_1: 1.4620 - val_a_2: 1.3095 - val_b_1: 1.0047 - val_b_2: 0.9932 - val_d_1: 0.7431 - val_d_2: 0.7820 - val_n: 1.3562 - val_mean_metric: 0.2482 - lr: 4.1350e-05
# Epoch 983/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9331 - a_1: 1.7540 - a_2: 1.7171 - b_1: 1.5052 - b_2: 1.4662 - d_1: 1.1729 - d_2: 1.2445 - n: 1.3765 - mean_metric: 0.3367 - val_loss: 2.3025 - val_a_1: 1.4585 - val_a_2: 1.3077 - val_b_1: 1.0077 - val_b_2: 0.9970 - val_d_1: 0.7345 - val_d_2: 0.8046 - val_n: 1.3542 - val_mean_metric: 0.2486 - lr: 3.9700e-05
# Epoch 984/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9401 - a_1: 1.7612 - a_2: 1.7155 - b_1: 1.4773 - b_2: 1.4746 - d_1: 1.1821 - d_2: 1.2566 - n: 1.3781 - mean_metric: 0.3369 - val_loss: 2.2834 - val_a_1: 1.4589 - val_a_2: 1.3111 - val_b_1: 0.9951 - val_b_2: 0.9817 - val_d_1: 0.7068 - val_d_2: 0.7694 - val_n: 1.3563 - val_mean_metric: 0.2459 - lr: 3.8050e-05
# Epoch 985/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9636 - a_1: 1.7530 - a_2: 1.7314 - b_1: 1.5145 - b_2: 1.4708 - d_1: 1.1726 - d_2: 1.2540 - n: 1.3770 - mean_metric: 0.3378 - val_loss: 2.2882 - val_a_1: 1.4573 - val_a_2: 1.3116 - val_b_1: 0.9899 - val_b_2: 0.9942 - val_d_1: 0.7055 - val_d_2: 0.7815 - val_n: 1.3555 - val_mean_metric: 0.2464 - lr: 3.6400e-05
# Epoch 986/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9574 - a_1: 1.7512 - a_2: 1.7074 - b_1: 1.5123 - b_2: 1.4763 - d_1: 1.1661 - d_2: 1.2637 - n: 1.3796 - mean_metric: 0.3373 - val_loss: 2.2874 - val_a_1: 1.4594 - val_a_2: 1.3204 - val_b_1: 0.9906 - val_b_2: 0.9849 - val_d_1: 0.7160 - val_d_2: 0.7504 - val_n: 1.3588 - val_mean_metric: 0.2459 - lr: 3.4750e-05
# Epoch 987/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9314 - a_1: 1.7590 - a_2: 1.7247 - b_1: 1.5017 - b_2: 1.4804 - d_1: 1.1609 - d_2: 1.2440 - n: 1.3840 - mean_metric: 0.3372 - val_loss: 2.3099 - val_a_1: 1.4621 - val_a_2: 1.3175 - val_b_1: 1.0129 - val_b_2: 1.0060 - val_d_1: 0.7385 - val_d_2: 0.7835 - val_n: 1.3577 - val_mean_metric: 0.2491 - lr: 3.3100e-05
# Epoch 988/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9851 - a_1: 1.7825 - a_2: 1.7489 - b_1: 1.4942 - b_2: 1.4903 - d_1: 1.1834 - d_2: 1.2465 - n: 1.3757 - mean_metric: 0.3394 - val_loss: 2.2841 - val_a_1: 1.4819 - val_a_2: 1.3182 - val_b_1: 0.9944 - val_b_2: 0.9748 - val_d_1: 0.6667 - val_d_2: 0.7341 - val_n: 1.3582 - val_mean_metric: 0.2442 - lr: 3.1450e-05
# Epoch 989/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9185 - a_1: 1.7823 - a_2: 1.7192 - b_1: 1.4787 - b_2: 1.4613 - d_1: 1.1507 - d_2: 1.2596 - n: 1.3790 - mean_metric: 0.3364 - val_loss: 2.2914 - val_a_1: 1.4656 - val_a_2: 1.3198 - val_b_1: 1.0058 - val_b_2: 0.9835 - val_d_1: 0.7041 - val_d_2: 0.7483 - val_n: 1.3570 - val_mean_metric: 0.2460 - lr: 2.9800e-05
# Epoch 990/1000
# 70/70 [==============================] - 2s 22ms/step - loss: 3.9622 - a_1: 1.7660 - a_2: 1.7225 - b_1: 1.4908 - b_2: 1.4801 - d_1: 1.1605 - d_2: 1.2693 - n: 1.3717 - mean_metric: 0.3375 - val_loss: 2.2866 - val_a_1: 1.4679 - val_a_2: 1.3150 - val_b_1: 0.9964 - val_b_2: 0.9767 - val_d_1: 0.6942 - val_d_2: 0.7682 - val_n: 1.3576 - val_mean_metric: 0.2458 - lr: 2.8150e-05
# Epoch 991/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9290 - a_1: 1.7745 - a_2: 1.7319 - b_1: 1.4956 - b_2: 1.4471 - d_1: 1.1633 - d_2: 1.2483 - n: 1.3806 - mean_metric: 0.3368 - val_loss: 2.3075 - val_a_1: 1.4744 - val_a_2: 1.3177 - val_b_1: 1.0245 - val_b_2: 0.9957 - val_d_1: 0.7092 - val_d_2: 0.7668 - val_n: 1.3570 - val_mean_metric: 0.2480 - lr: 2.6500e-05
# Epoch 992/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9806 - a_1: 1.7440 - a_2: 1.7035 - b_1: 1.5009 - b_2: 1.5005 - d_1: 1.1784 - d_2: 1.2832 - n: 1.3714 - mean_metric: 0.3381 - val_loss: 2.2929 - val_a_1: 1.4748 - val_a_2: 1.3205 - val_b_1: 1.0045 - val_b_2: 0.9841 - val_d_1: 0.6978 - val_d_2: 0.7465 - val_n: 1.3560 - val_mean_metric: 0.2460 - lr: 2.4850e-05
# Epoch 993/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9629 - a_1: 1.7652 - a_2: 1.7344 - b_1: 1.5066 - b_2: 1.4693 - d_1: 1.1845 - d_2: 1.2393 - n: 1.3767 - mean_metric: 0.3379 - val_loss: 2.2883 - val_a_1: 1.4792 - val_a_2: 1.3214 - val_b_1: 0.9919 - val_b_2: 0.9800 - val_d_1: 0.6879 - val_d_2: 0.7436 - val_n: 1.3567 - val_mean_metric: 0.2453 - lr: 2.3200e-05
# Epoch 994/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9938 - a_1: 1.7770 - a_2: 1.7315 - b_1: 1.5039 - b_2: 1.4796 - d_1: 1.1948 - d_2: 1.2546 - n: 1.3793 - mean_metric: 0.3394 - val_loss: 2.2851 - val_a_1: 1.4868 - val_a_2: 1.3195 - val_b_1: 0.9834 - val_b_2: 0.9736 - val_d_1: 0.6867 - val_d_2: 0.7479 - val_n: 1.3573 - val_mean_metric: 0.2451 - lr: 2.1550e-05
# Epoch 995/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9728 - a_1: 1.7737 - a_2: 1.7452 - b_1: 1.4927 - b_2: 1.4854 - d_1: 1.1717 - d_2: 1.2401 - n: 1.3737 - mean_metric: 0.3382 - val_loss: 2.2905 - val_a_1: 1.4762 - val_a_2: 1.3261 - val_b_1: 0.9896 - val_b_2: 0.9820 - val_d_1: 0.6998 - val_d_2: 0.7454 - val_n: 1.3594 - val_mean_metric: 0.2459 - lr: 1.9900e-05
# Epoch 996/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9741 - a_1: 1.7672 - a_2: 1.7408 - b_1: 1.4833 - b_2: 1.4898 - d_1: 1.1859 - d_2: 1.2390 - n: 1.3753 - mean_metric: 0.3380 - val_loss: 2.2876 - val_a_1: 1.4794 - val_a_2: 1.3192 - val_b_1: 0.9926 - val_b_2: 0.9771 - val_d_1: 0.6848 - val_d_2: 0.7537 - val_n: 1.3585 - val_mean_metric: 0.2454 - lr: 1.8250e-05
# Epoch 997/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9406 - a_1: 1.7692 - a_2: 1.7247 - b_1: 1.5117 - b_2: 1.4590 - d_1: 1.1645 - d_2: 1.2557 - n: 1.3794 - mean_metric: 0.3375 - val_loss: 2.2876 - val_a_1: 1.4771 - val_a_2: 1.3203 - val_b_1: 0.9923 - val_b_2: 0.9813 - val_d_1: 0.6821 - val_d_2: 0.7470 - val_n: 1.3592 - val_mean_metric: 0.2452 - lr: 1.6600e-05
# Epoch 998/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9039 - a_1: 1.7355 - a_2: 1.6970 - b_1: 1.4985 - b_2: 1.4624 - d_1: 1.1751 - d_2: 1.2594 - n: 1.3795 - mean_metric: 0.3356 - val_loss: 2.2889 - val_a_1: 1.4771 - val_a_2: 1.3210 - val_b_1: 0.9919 - val_b_2: 0.9835 - val_d_1: 0.6971 - val_d_2: 0.7424 - val_n: 1.3587 - val_mean_metric: 0.2456 - lr: 1.4950e-05
# Epoch 999/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9903 - a_1: 1.7669 - a_2: 1.7504 - b_1: 1.5170 - b_2: 1.4952 - d_1: 1.1739 - d_2: 1.2415 - n: 1.3797 - mean_metric: 0.3395 - val_loss: 2.2928 - val_a_1: 1.4762 - val_a_2: 1.3193 - val_b_1: 0.9923 - val_b_2: 0.9878 - val_d_1: 0.7101 - val_d_2: 0.7531 - val_n: 1.3587 - val_mean_metric: 0.2465 - lr: 1.3300e-05
# Epoch 1000/1000
# 70/70 [==============================] - 1s 16ms/step - loss: 3.9194 - a_1: 1.7485 - a_2: 1.7160 - b_1: 1.4999 - b_2: 1.4636 - d_1: 1.1585 - d_2: 1.2492 - n: 1.3702 - mean_metric: 0.3357 - val_loss: 2.2908 - val_a_1: 1.4809 - val_a_2: 1.3183 - val_b_1: 0.9985 - val_b_2: 0.9774 - val_d_1: 0.6943 - val_d_2: 0.7482 - val_n: 1.3580 - val_mean_metric: 0.2458 - lr: 1.1650e-05

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(val_epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    campvectest, coefcampvectest)
# Out:
# 63/63 [==============================] - 0s 4ms/step - loss: 2.2368 - a_1: 1.4443 - a_2: 1.3189 - b_1: 0.9447 - b_2: 0.9891 - d_1: 0.7188 - d_2: 0.7545 - n: 1.3398 - mean_metric: 0.2483

# %%
predictions = model.predict(campvectest)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
print(coefcampvectest[0,:])
print(predictions[0,:])
from sklearn.metrics import mean_absolute_error
print(np.sum(coefcampvectest, axis=-1))

mae1 = mean_absolute_error(coefcampvectest[0,:], predictions[0,:])
mae1
# Out:
# [ 2  2 10  1  9  7  2]
# [4.3561025 3.3578026 7.5225067 0.8959869 7.6193194 6.7350254 2.0140662]
# [33 25 37 ... 37 26 30]
# 1.136447548866272

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefcampvectest, predictions)

# Calcula la desviación estándar del error
error = coefcampvectest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 1.0743411161238328, Desviación estándar del error: 1.4198616312923058, Error absoluto máximo: 6.772658824920654

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefcampvectest - predictions)

# Calcula el error para cada dato
error = coefcampvectest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefcampvectest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.24230210755297077
# Desviación estándar del error relativo: 0.10701370311237877
# Error absoluto máximo relativo: 0.549382746964693

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales con ruido/History 50,100/historyconvcampvec50.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos con ruido/Modelos 50,100/'

# %%
model.save(path_to_save + '/convolucionalcv50.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_activation':custom_activation,'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)
new_model = keras.models.load_model('../../../Modelos con ruido/Modelos 50,100/convolucionalcv50.h5', custom_objects=custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random 
import matplotlib.pyplot as plt
for i in range(0, 1):
    # constantes
    a1 = random.randint(1, 10)
    a2 = random.randint(1, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(1, 5)

    coef = [a1, a2, b1, b2, d1, d2, n]

    for i_ci in range(0, 1):
        x_range_neg = 0
        x_range_pos = 10
        y_range_neg = 0
        y_range_pos =10

        y1 = np.linspace(x_range_neg, x_range_pos, 50)
        y2 = np.linspace(y_range_neg, y_range_pos, 50)

        Y1, Y2 = np.meshgrid(y1, y2)

        t1 = 0

        NI, NJ = Y1.shape
        u, v = np.zeros((NI, NJ)), np.zeros((NI, NJ))

        for i in range(NI):
            for j in range(NJ):
                # asignar a cada ODE a un elemento de vector
                X = Y1[i, j]
                Y = Y2[i, j]
                noise1 = np.random.normal(0, .5)
                noise2 = np.random.normal(0, .5)

                # definimos cada ODE
                dX_dt=(a1)/(1+Y**(n))-(d1)*X+b1+noise1
                dY_dt=(a2)/(1+X**(n))-(d2)*Y+b2+noise2

                u[i, j], v[i, j] = dX_dt, dY_dt

        M = (np.hypot(u, v))
        u /= M
        v /= M

    campvecci = np.append([u], [v], axis=0)

    campvec = campvecci
    print(coef)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# [3, 10, 3, 10, 8, 4, 1]

# %%
campvecnone = campvec[None, :]
campvecnone = np.transpose(campvecnone, (0,2,3,1))

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 78ms/step
# [[3. 8. 3. 7. 7. 4. 3.]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 50)
y2 = np.linspace(0, 10, 50)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
plt.show()

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1 = np.linspace(x_range_neg, x_range_pos, 50)
y2 = np.linspace(y_range_neg, y_range_pos, 50)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
