# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_28780\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos con ruido/Campo 20 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 20, 20)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (1000, 2, 20, 20)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (1000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (2000, 2, 20, 20)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (2000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 20, 20), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creamos función de costo

# %%
def custom_loss(y_true, y_pred):
    campvec = []
    # constantes
    a1 = tf.cast(y_true[:, 0], tf.float64)
    #tf.print(a1)
    a1 = tf.reshape(a1, shape=(-1, 1, 1))

    a2 = tf.cast(y_true[:, 1], tf.float64)
    a2 = tf.reshape(a2, shape=(-1, 1, 1))
    
    b1 = tf.cast(y_true[:, 2], tf.float64)
    b1 = tf.reshape(b1,shape = (-1,1,1))
    
    b2 = tf.cast(y_true[:, 3], tf.float64)
    b2 = tf.reshape(b2,shape = (-1,1,1))

    d1 = tf.cast(y_true[:, 4], tf.float64)
    d1 = tf.reshape(d1, shape=(-1, 1, 1))

    d2 = tf.cast(y_true[:, 5], tf.float64)
    d2 = tf.reshape(d2, shape=(-1, 1, 1))

    n = tf.cast(y_true[:, 6], tf.float64)
    n = tf.reshape(n, shape=(-1, 1, 1))

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        X = tf.cast(X, tf.float64)
        X = tf.reshape(X, shape=(1, 20,20))
        Y = y[1]
        Y = tf.cast(Y, tf.float64)
        Y = tf.reshape(Y, shape=(1, 20,20))
        
        # definimos cada ODE
        dX_dt = tf.divide(a1,(1 + tf.math.pow(Y, n)+1e-5)) - tf.multiply(d1,X) + b1
        dY_dt = tf.divide(a2,(1 + tf.math.pow(X, n)+1e-7)) - tf.multiply(d2,Y) + b2
        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 20
    y_range_neg = 0
    y_range_pos = 20
    y1 = tf.linspace(x_range_neg, x_range_pos, 20)
    y2 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y1, Y2 = tf.meshgrid(y1, y2)
    t = 0
    u, v = tf.zeros(Y1.shape), tf.zeros(Y2.shape)
    u, v = f(t, [Y1, Y2])
    #M = tf.sqrt(tf.square(u) + tf.square(v))
    #u /= M
    #v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = tf.cast(y_pred[:, 0], tf.float64)
    a12 = tf.reshape(a12, shape=(-1, 1, 1))

    a22 = tf.cast(y_pred[:, 1], tf.float64)
    a22 = tf.reshape(a22, shape=(-1, 1, 1))
    
    b12 = tf.cast(y_pred[:, 2], tf.float64)
    b12 = tf.reshape(b12,shape = (-1,1,1))
    
    b22 = tf.cast(y_pred[:, 3], tf.float64)
    b22 = tf.reshape(b22,shape = (-1,1,1))

    d12 = tf.cast(y_pred[:, 4], tf.float64)
    d12 = tf.reshape(d12, shape=(-1, 1, 1))

    d22 = tf.cast(y_pred[:, 5], tf.float64)
    d22 = tf.reshape(d22, shape=(-1, 1, 1))

    n2 = tf.cast(y_pred[:, 6], tf.float64)
    n2 = tf.reshape(n2, shape=(-1, 1, 1))
    
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        X2 = tf.cast(X2, tf.float64)
        X2 = tf.reshape(X2, shape=(1, 20,20))
        Y2 = ye2[1]
        Y2 = tf.cast(Y2, tf.float64)
        Y2 = tf.reshape(Y2, shape=(1, 20,20))

        # definimos cada ODE
        dX2_dt = tf.divide(a12,(1 + tf.math.pow(Y2, n2)+1e-8)) - tf.multiply(d12,X2) + b12
        dY2_dt = tf.divide(a22,(1 + tf.math.pow(X2, n2)+1e-8)) - tf.multiply(d22,Y2) + b22
        return [dX2_dt, dY2_dt]

    y12 = tf.linspace(x_range_neg, x_range_pos, 20)
    y22 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y12, Y22 = tf.meshgrid(y12, y22)
    u2, v2 = tf.zeros(Y12.shape), tf.zeros(Y22.shape)
    u2, v2 = f2(t, [Y12, Y22])
    #M2 = tf.sqrt(tf.square(u2) + tf.square(v2))
    #u2 /= M2
    #v2 /= M2
    campvecx = tf.abs(tf.subtract(u,u2))
    campvecy = tf.abs(tf.subtract(v,v2))
    campvec_magnitude = tf.add(campvecx,campvecy)
    loss = tf.reduce_mean(campvec_magnitude)
    #tf.print(y_pred)
    return loss

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
model.add(Flatten(input_shape=(2, 20, 20)))
model.add(BatchNormalization())
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(50, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(BatchNormalization())
model.add(Dense(50, activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(7))

# %%
model.add(Flatten(input_shape=(2,20,20)))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))

model.add(Dense(7, activation= custom_activation))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 800)               0
#
#  batch_normalization_8 (Batc  (None, 800)              3200
#  hNormalization)
#
#  dense_42 (Dense)            (None, 100)               80100
#
#  dense_43 (Dense)            (None, 100)               10100
#
#  dropout_14 (Dropout)        (None, 100)               0
#
#  dense_44 (Dense)            (None, 100)               10100
#
#  dense_45 (Dense)            (None, 50)                5050
#
#  dropout_15 (Dropout)        (None, 50)                0
#
#  batch_normalization_9 (Batc  (None, 50)               200
#  hNormalization)
#
#  dense_46 (Dense)            (None, 50)                2550
#
#  dropout_16 (Dropout)        (None, 50)                0
#
#  dense_47 (Dense)            (None, 50)                2550
#
#  dense_48 (Dense)            (None, 7)                 357
#
#  flatten_7 (Flatten)         (None, 7)                 0
#
#  batch_normalization_10 (Bat  (None, 7)                28
#  chNormalization)
#
#  dense_49 (Dense)            (None, 128)               1024
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_50 (Dense)            (None, 64)                8256
#
#  dense_51 (Dense)            (None, 128)               8320
#
#  dense_52 (Dense)            (None, 64)                8256
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_53 (Dense)            (None, 128)               8320
#
#  dense_54 (Dense)            (None, 64)                8256
#
#  dense_55 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 157,122
# Trainable params: 155,408
# Non-trainable params: 1,714
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= custom_loss,
              metrics=metrics)

# %%
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 1000,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 70/70 [==============================] - 2s 11ms/step - loss: 48.4217 - a_1: 3.2933 - a_2: 3.0216 - b_1: 2.9235 - b_2: 2.9657 - d_1: 1.9761 - d_2: 1.7390 - n: 2.2119 - mean_metric: 0.5947 - val_loss: 50.7219 - val_a_1: 3.1139 - val_a_2: 2.9366 - val_b_1: 2.9501 - val_b_2: 2.9617 - val_d_1: 1.9802 - val_d_2: 1.8343 - val_n: 1.7246 - val_mean_metric: 0.5759 - lr: 0.0010
# Epoch 2/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 39.2324 - a_1: 3.1601 - a_2: 2.9754 - b_1: 2.9052 - b_2: 2.8766 - d_1: 1.4304 - d_2: 1.4177 - n: 1.9996 - mean_metric: 0.5499 - val_loss: 34.6069 - val_a_1: 3.0262 - val_a_2: 2.8162 - val_b_1: 2.8400 - val_b_2: 3.0105 - val_d_1: 1.1294 - val_d_2: 1.3034 - val_n: 2.0104 - val_mean_metric: 0.5310 - lr: 0.0010
# Epoch 3/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 36.6208 - a_1: 3.0604 - a_2: 2.8745 - b_1: 2.8776 - b_2: 2.7903 - d_1: 1.3142 - d_2: 1.2756 - n: 2.2019 - mean_metric: 0.5379 - val_loss: 31.1739 - val_a_1: 2.8581 - val_a_2: 2.8717 - val_b_1: 2.7945 - val_b_2: 2.8240 - val_d_1: 0.9880 - val_d_2: 1.1128 - val_n: 2.1901 - val_mean_metric: 0.5147 - lr: 0.0010
# Epoch 4/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 35.4621 - a_1: 2.9677 - a_2: 2.9341 - b_1: 2.8325 - b_2: 2.7806 - d_1: 1.2527 - d_2: 1.2296 - n: 2.3052 - mean_metric: 0.5348 - val_loss: 31.1166 - val_a_1: 2.8752 - val_a_2: 2.8643 - val_b_1: 2.8045 - val_b_2: 2.7356 - val_d_1: 0.9925 - val_d_2: 1.1102 - val_n: 2.3892 - val_mean_metric: 0.5191 - lr: 0.0010
# Epoch 5/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 34.6080 - a_1: 2.9600 - a_2: 2.9037 - b_1: 2.8093 - b_2: 2.7563 - d_1: 1.2161 - d_2: 1.1992 - n: 2.3996 - mean_metric: 0.5329 - val_loss: 29.8341 - val_a_1: 2.8840 - val_a_2: 2.8772 - val_b_1: 2.8422 - val_b_2: 2.7709 - val_d_1: 0.9677 - val_d_2: 1.0218 - val_n: 2.3010 - val_mean_metric: 0.5155 - lr: 0.0010
# Epoch 6/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 33.8530 - a_1: 2.9045 - a_2: 2.8994 - b_1: 2.8139 - b_2: 2.7503 - d_1: 1.1864 - d_2: 1.1663 - n: 2.2361 - mean_metric: 0.5235 - val_loss: 30.3585 - val_a_1: 2.8275 - val_a_2: 2.9259 - val_b_1: 2.7915 - val_b_2: 2.6639 - val_d_1: 0.9559 - val_d_2: 1.0681 - val_n: 2.3637 - val_mean_metric: 0.5133 - lr: 0.0010
# Epoch 7/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 33.4300 - a_1: 2.8975 - a_2: 2.9395 - b_1: 2.8242 - b_2: 2.7169 - d_1: 1.1565 - d_2: 1.1604 - n: 2.3523 - mean_metric: 0.5265 - val_loss: 29.4200 - val_a_1: 2.8458 - val_a_2: 2.9285 - val_b_1: 2.7936 - val_b_2: 2.6911 - val_d_1: 0.9721 - val_d_2: 0.9976 - val_n: 2.4459 - val_mean_metric: 0.5159 - lr: 0.0010
# Epoch 8/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 32.7236 - a_1: 2.8806 - a_2: 2.9234 - b_1: 2.7874 - b_2: 2.7360 - d_1: 1.1242 - d_2: 1.1349 - n: 2.2786 - mean_metric: 0.5206 - val_loss: 29.6142 - val_a_1: 2.8038 - val_a_2: 2.9176 - val_b_1: 2.7988 - val_b_2: 2.6540 - val_d_1: 0.9525 - val_d_2: 1.0281 - val_n: 2.3132 - val_mean_metric: 0.5091 - lr: 0.0010
# Epoch 9/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 32.6700 - a_1: 2.8637 - a_2: 2.9050 - b_1: 2.8004 - b_2: 2.7085 - d_1: 1.1312 - d_2: 1.1451 - n: 2.2689 - mean_metric: 0.5191 - val_loss: 28.3297 - val_a_1: 2.8094 - val_a_2: 2.8932 - val_b_1: 2.7940 - val_b_2: 2.6794 - val_d_1: 0.9334 - val_d_2: 0.9555 - val_n: 2.3267 - val_mean_metric: 0.5066 - lr: 0.0010
# Epoch 10/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 31.7720 - a_1: 2.8547 - a_2: 2.9239 - b_1: 2.7570 - b_2: 2.7096 - d_1: 1.1124 - d_2: 1.0913 - n: 2.2040 - mean_metric: 0.5135 - val_loss: 28.3152 - val_a_1: 2.8292 - val_a_2: 2.9308 - val_b_1: 2.7092 - val_b_2: 2.6842 - val_d_1: 0.9529 - val_d_2: 0.9474 - val_n: 2.2010 - val_mean_metric: 0.5021 - lr: 0.0010
# Epoch 11/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 31.6545 - a_1: 2.8635 - a_2: 2.8854 - b_1: 2.7527 - b_2: 2.6883 - d_1: 1.1087 - d_2: 1.0840 - n: 2.1754 - mean_metric: 0.5104 - val_loss: 27.6224 - val_a_1: 2.8043 - val_a_2: 2.8406 - val_b_1: 2.7392 - val_b_2: 2.6249 - val_d_1: 0.9247 - val_d_2: 0.9225 - val_n: 2.2176 - val_mean_metric: 0.4961 - lr: 0.0010
# Epoch 12/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 31.5205 - a_1: 2.8697 - a_2: 2.8803 - b_1: 2.7369 - b_2: 2.6886 - d_1: 1.1015 - d_2: 1.0983 - n: 2.1841 - mean_metric: 0.5104 - val_loss: 28.0245 - val_a_1: 2.7903 - val_a_2: 2.8464 - val_b_1: 2.7318 - val_b_2: 2.6542 - val_d_1: 0.9535 - val_d_2: 0.9355 - val_n: 2.2009 - val_mean_metric: 0.4973 - lr: 0.0010
# Epoch 13/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 31.1689 - a_1: 2.8500 - a_2: 2.8974 - b_1: 2.7382 - b_2: 2.6850 - d_1: 1.0809 - d_2: 1.0933 - n: 2.1641 - mean_metric: 0.5088 - val_loss: 27.6587 - val_a_1: 2.8132 - val_a_2: 2.9142 - val_b_1: 2.7072 - val_b_2: 2.6081 - val_d_1: 0.9326 - val_d_2: 0.9262 - val_n: 2.2505 - val_mean_metric: 0.4987 - lr: 0.0010
# Epoch 14/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 30.8390 - a_1: 2.8740 - a_2: 2.8662 - b_1: 2.7376 - b_2: 2.6938 - d_1: 1.0904 - d_2: 1.0641 - n: 2.1948 - mean_metric: 0.5092 - val_loss: 28.7667 - val_a_1: 2.8000 - val_a_2: 2.8452 - val_b_1: 2.7668 - val_b_2: 2.6383 - val_d_1: 0.9691 - val_d_2: 1.0040 - val_n: 2.3194 - val_mean_metric: 0.5049 - lr: 0.0010
# Epoch 15/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 30.5277 - a_1: 2.8374 - a_2: 2.8587 - b_1: 2.7291 - b_2: 2.6902 - d_1: 1.0716 - d_2: 1.0713 - n: 2.2088 - mean_metric: 0.5074 - val_loss: 26.8745 - val_a_1: 2.8020 - val_a_2: 2.8514 - val_b_1: 2.7075 - val_b_2: 2.6219 - val_d_1: 0.9113 - val_d_2: 0.9064 - val_n: 2.4431 - val_mean_metric: 0.5017 - lr: 0.0010
# Epoch 16/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 30.4342 - a_1: 2.8540 - a_2: 2.8479 - b_1: 2.7177 - b_2: 2.6734 - d_1: 1.0768 - d_2: 1.0581 - n: 2.2579 - mean_metric: 0.5081 - val_loss: 27.2747 - val_a_1: 2.7918 - val_a_2: 2.8317 - val_b_1: 2.7246 - val_b_2: 2.6291 - val_d_1: 0.9142 - val_d_2: 0.9504 - val_n: 2.3086 - val_mean_metric: 0.4986 - lr: 0.0010
# Epoch 17/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 30.0365 - a_1: 2.8415 - a_2: 2.8382 - b_1: 2.6938 - b_2: 2.6708 - d_1: 1.0530 - d_2: 1.0641 - n: 2.2054 - mean_metric: 0.5043 - val_loss: 26.7820 - val_a_1: 2.7940 - val_a_2: 2.8368 - val_b_1: 2.6500 - val_b_2: 2.6705 - val_d_1: 0.9207 - val_d_2: 0.9209 - val_n: 2.2833 - val_mean_metric: 0.4961 - lr: 0.0010
# Epoch 18/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 29.9422 - a_1: 2.8707 - a_2: 2.8780 - b_1: 2.7053 - b_2: 2.6680 - d_1: 1.0628 - d_2: 1.0510 - n: 2.1513 - mean_metric: 0.5048 - val_loss: 27.3004 - val_a_1: 2.7899 - val_a_2: 2.8155 - val_b_1: 2.7134 - val_b_2: 2.6411 - val_d_1: 0.9160 - val_d_2: 0.9653 - val_n: 2.2589 - val_mean_metric: 0.4969 - lr: 0.0010
# Epoch 19/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 29.5800 - a_1: 2.8588 - a_2: 2.8127 - b_1: 2.7331 - b_2: 2.6719 - d_1: 1.0403 - d_2: 1.0534 - n: 2.1617 - mean_metric: 0.5031 - val_loss: 26.7170 - val_a_1: 2.7895 - val_a_2: 2.8087 - val_b_1: 2.7646 - val_b_2: 2.6349 - val_d_1: 0.8942 - val_d_2: 0.9411 - val_n: 2.3159 - val_mean_metric: 0.4985 - lr: 0.0010
# Epoch 20/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 29.3215 - a_1: 2.8672 - a_2: 2.8365 - b_1: 2.7181 - b_2: 2.6710 - d_1: 1.0442 - d_2: 1.0353 - n: 2.1814 - mean_metric: 0.5037 - val_loss: 26.5716 - val_a_1: 2.8140 - val_a_2: 2.8048 - val_b_1: 2.7476 - val_b_2: 2.6443 - val_d_1: 0.9240 - val_d_2: 0.9027 - val_n: 2.3316 - val_mean_metric: 0.4992 - lr: 0.0010
# Epoch 21/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 28.7563 - a_1: 2.8623 - a_2: 2.8286 - b_1: 2.7037 - b_2: 2.6856 - d_1: 1.0240 - d_2: 1.0147 - n: 2.2267 - mean_metric: 0.5035 - val_loss: 25.9627 - val_a_1: 2.7838 - val_a_2: 2.8351 - val_b_1: 2.7181 - val_b_2: 2.6330 - val_d_1: 0.8823 - val_d_2: 0.9220 - val_n: 2.3029 - val_mean_metric: 0.4962 - lr: 0.0010
# Epoch 22/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 28.6413 - a_1: 2.8355 - a_2: 2.8339 - b_1: 2.7242 - b_2: 2.6610 - d_1: 1.0312 - d_2: 1.0085 - n: 2.1715 - mean_metric: 0.5009 - val_loss: 25.9945 - val_a_1: 2.7709 - val_a_2: 2.8181 - val_b_1: 2.7187 - val_b_2: 2.6330 - val_d_1: 0.9371 - val_d_2: 0.8708 - val_n: 2.2868 - val_mean_metric: 0.4948 - lr: 0.0010
# Epoch 23/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 28.5992 - a_1: 2.8433 - a_2: 2.8289 - b_1: 2.6847 - b_2: 2.6444 - d_1: 1.0288 - d_2: 1.0155 - n: 2.1237 - mean_metric: 0.4978 - val_loss: 27.3970 - val_a_1: 2.7815 - val_a_2: 2.8312 - val_b_1: 2.6834 - val_b_2: 2.6541 - val_d_1: 1.0073 - val_d_2: 0.9260 - val_n: 2.2638 - val_mean_metric: 0.4985 - lr: 0.0010
# Epoch 24/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 28.3663 - a_1: 2.8232 - a_2: 2.8248 - b_1: 2.6722 - b_2: 2.6609 - d_1: 1.0229 - d_2: 1.0090 - n: 2.1873 - mean_metric: 0.4988 - val_loss: 26.0423 - val_a_1: 2.7694 - val_a_2: 2.8216 - val_b_1: 2.6781 - val_b_2: 2.6469 - val_d_1: 0.9414 - val_d_2: 0.8810 - val_n: 2.4005 - val_mean_metric: 0.4982 - lr: 0.0010
# Epoch 25/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 28.4178 - a_1: 2.8371 - a_2: 2.8471 - b_1: 2.6900 - b_2: 2.6449 - d_1: 1.0318 - d_2: 1.0166 - n: 2.2316 - mean_metric: 0.5020 - val_loss: 25.5543 - val_a_1: 2.7961 - val_a_2: 2.8337 - val_b_1: 2.6803 - val_b_2: 2.5990 - val_d_1: 0.9061 - val_d_2: 0.8998 - val_n: 2.3161 - val_mean_metric: 0.4946 - lr: 0.0010
# Epoch 26/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 27.9635 - a_1: 2.8269 - a_2: 2.8353 - b_1: 2.6985 - b_2: 2.6521 - d_1: 1.0145 - d_2: 0.9997 - n: 2.3073 - mean_metric: 0.5032 - val_loss: 25.7625 - val_a_1: 2.7576 - val_a_2: 2.8230 - val_b_1: 2.6990 - val_b_2: 2.6114 - val_d_1: 0.8962 - val_d_2: 0.9209 - val_n: 2.5267 - val_mean_metric: 0.5014 - lr: 0.0010
# Epoch 27/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 27.7227 - a_1: 2.8175 - a_2: 2.8139 - b_1: 2.6914 - b_2: 2.6619 - d_1: 1.0117 - d_2: 0.9865 - n: 2.3134 - mean_metric: 0.5019 - val_loss: 25.2118 - val_a_1: 2.7833 - val_a_2: 2.8163 - val_b_1: 2.6875 - val_b_2: 2.5998 - val_d_1: 0.8822 - val_d_2: 0.9048 - val_n: 2.5151 - val_mean_metric: 0.4999 - lr: 0.0010
# Epoch 28/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 27.5831 - a_1: 2.8277 - a_2: 2.8070 - b_1: 2.6772 - b_2: 2.6439 - d_1: 0.9992 - d_2: 1.0008 - n: 2.3116 - mean_metric: 0.5009 - val_loss: 24.8354 - val_a_1: 2.7659 - val_a_2: 2.8125 - val_b_1: 2.6765 - val_b_2: 2.6197 - val_d_1: 0.8865 - val_d_2: 0.8855 - val_n: 2.3542 - val_mean_metric: 0.4937 - lr: 0.0010
# Epoch 29/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 27.4324 - a_1: 2.8162 - a_2: 2.8317 - b_1: 2.6992 - b_2: 2.6462 - d_1: 1.0034 - d_2: 0.9970 - n: 2.2149 - mean_metric: 0.4989 - val_loss: 25.9452 - val_a_1: 2.7674 - val_a_2: 2.8037 - val_b_1: 2.7033 - val_b_2: 2.5888 - val_d_1: 0.9875 - val_d_2: 0.8820 - val_n: 2.3624 - val_mean_metric: 0.4968 - lr: 0.0010
# Epoch 30/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 27.2934 - a_1: 2.8221 - a_2: 2.8306 - b_1: 2.6817 - b_2: 2.6582 - d_1: 0.9964 - d_2: 0.9869 - n: 2.2204 - mean_metric: 0.4986 - val_loss: 24.8902 - val_a_1: 2.8142 - val_a_2: 2.8248 - val_b_1: 2.6467 - val_b_2: 2.6309 - val_d_1: 0.9001 - val_d_2: 0.8813 - val_n: 2.3325 - val_mean_metric: 0.4946 - lr: 0.0010
# Epoch 31/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 26.9935 - a_1: 2.8392 - a_2: 2.8062 - b_1: 2.6876 - b_2: 2.6696 - d_1: 0.9949 - d_2: 0.9740 - n: 2.1951 - mean_metric: 0.4977 - val_loss: 24.6260 - val_a_1: 2.7895 - val_a_2: 2.8100 - val_b_1: 2.6553 - val_b_2: 2.6458 - val_d_1: 0.8815 - val_d_2: 0.8853 - val_n: 2.1943 - val_mean_metric: 0.4891 - lr: 0.0010
# Epoch 32/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 27.1304 - a_1: 2.8182 - a_2: 2.8128 - b_1: 2.7017 - b_2: 2.6589 - d_1: 0.9899 - d_2: 0.9947 - n: 2.1765 - mean_metric: 0.4972 - val_loss: 25.9288 - val_a_1: 2.7802 - val_a_2: 2.8179 - val_b_1: 2.6874 - val_b_2: 2.6886 - val_d_1: 0.9673 - val_d_2: 0.9120 - val_n: 2.2016 - val_mean_metric: 0.4954 - lr: 0.0010
# Epoch 33/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 27.0010 - a_1: 2.8426 - a_2: 2.8084 - b_1: 2.6934 - b_2: 2.6580 - d_1: 0.9872 - d_2: 0.9905 - n: 2.1597 - mean_metric: 0.4967 - val_loss: 24.8955 - val_a_1: 2.8082 - val_a_2: 2.7807 - val_b_1: 2.6338 - val_b_2: 2.5933 - val_d_1: 0.9084 - val_d_2: 0.8936 - val_n: 2.2471 - val_mean_metric: 0.4892 - lr: 0.0010
# Epoch 34/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 26.9456 - a_1: 2.8485 - a_2: 2.7899 - b_1: 2.6870 - b_2: 2.6435 - d_1: 0.9959 - d_2: 0.9899 - n: 2.1283 - mean_metric: 0.4949 - val_loss: 25.0560 - val_a_1: 2.8314 - val_a_2: 2.7751 - val_b_1: 2.6949 - val_b_2: 2.6040 - val_d_1: 0.9210 - val_d_2: 0.8941 - val_n: 2.1983 - val_mean_metric: 0.4909 - lr: 0.0010
# Epoch 35/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 26.5068 - a_1: 2.8462 - a_2: 2.8158 - b_1: 2.6790 - b_2: 2.6897 - d_1: 0.9761 - d_2: 0.9665 - n: 2.1214 - mean_metric: 0.4952 - val_loss: 25.3186 - val_a_1: 2.7938 - val_a_2: 2.8066 - val_b_1: 2.6635 - val_b_2: 2.6591 - val_d_1: 0.9411 - val_d_2: 0.9126 - val_n: 2.2076 - val_mean_metric: 0.4931 - lr: 0.0010
# Epoch 36/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 26.2549 - a_1: 2.8227 - a_2: 2.8019 - b_1: 2.6963 - b_2: 2.6655 - d_1: 0.9712 - d_2: 0.9570 - n: 2.1554 - mean_metric: 0.4945 - val_loss: 24.6683 - val_a_1: 2.7697 - val_a_2: 2.8066 - val_b_1: 2.6473 - val_b_2: 2.6508 - val_d_1: 0.9062 - val_d_2: 0.8982 - val_n: 2.1795 - val_mean_metric: 0.4890 - lr: 0.0010
# Epoch 37/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 26.4094 - a_1: 2.8042 - a_2: 2.8146 - b_1: 2.7000 - b_2: 2.6605 - d_1: 0.9829 - d_2: 0.9689 - n: 2.1316 - mean_metric: 0.4942 - val_loss: 23.9648 - val_a_1: 2.7709 - val_a_2: 2.7930 - val_b_1: 2.6812 - val_b_2: 2.6012 - val_d_1: 0.9013 - val_d_2: 0.8485 - val_n: 2.1124 - val_mean_metric: 0.4840 - lr: 0.0010
# Epoch 38/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 26.1047 - a_1: 2.8252 - a_2: 2.8086 - b_1: 2.6946 - b_2: 2.6718 - d_1: 0.9633 - d_2: 0.9708 - n: 2.1299 - mean_metric: 0.4943 - val_loss: 24.7463 - val_a_1: 2.7972 - val_a_2: 2.8198 - val_b_1: 2.6375 - val_b_2: 2.6819 - val_d_1: 0.9271 - val_d_2: 0.8906 - val_n: 2.3397 - val_mean_metric: 0.4967 - lr: 0.0010
# Epoch 39/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.8776 - a_1: 2.8340 - a_2: 2.8109 - b_1: 2.6893 - b_2: 2.6781 - d_1: 0.9664 - d_2: 0.9482 - n: 2.2372 - mean_metric: 0.4976 - val_loss: 24.4171 - val_a_1: 2.7888 - val_a_2: 2.7988 - val_b_1: 2.6502 - val_b_2: 2.6347 - val_d_1: 0.9288 - val_d_2: 0.8735 - val_n: 2.2809 - val_mean_metric: 0.4922 - lr: 0.0010
# Epoch 40/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.8858 - a_1: 2.8233 - a_2: 2.7966 - b_1: 2.6609 - b_2: 2.6752 - d_1: 0.9657 - d_2: 0.9611 - n: 2.2228 - mean_metric: 0.4956 - val_loss: 24.6835 - val_a_1: 2.7848 - val_a_2: 2.7982 - val_b_1: 2.6822 - val_b_2: 2.6037 - val_d_1: 0.9178 - val_d_2: 0.9345 - val_n: 2.3765 - val_mean_metric: 0.4969 - lr: 0.0010
# Epoch 41/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.6913 - a_1: 2.8384 - a_2: 2.8100 - b_1: 2.6812 - b_2: 2.6578 - d_1: 0.9546 - d_2: 0.9582 - n: 2.1884 - mean_metric: 0.4951 - val_loss: 23.1786 - val_a_1: 2.8013 - val_a_2: 2.8283 - val_b_1: 2.6346 - val_b_2: 2.5875 - val_d_1: 0.8579 - val_d_2: 0.8438 - val_n: 2.2389 - val_mean_metric: 0.4868 - lr: 0.0010
# Epoch 42/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.5927 - a_1: 2.8370 - a_2: 2.8126 - b_1: 2.6725 - b_2: 2.6251 - d_1: 0.9527 - d_2: 0.9598 - n: 2.1075 - mean_metric: 0.4911 - val_loss: 23.9133 - val_a_1: 2.7918 - val_a_2: 2.7969 - val_b_1: 2.6171 - val_b_2: 2.6416 - val_d_1: 0.8667 - val_d_2: 0.9088 - val_n: 2.2438 - val_mean_metric: 0.4892 - lr: 0.0010
# Epoch 43/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.6342 - a_1: 2.8472 - a_2: 2.8101 - b_1: 2.6978 - b_2: 2.6559 - d_1: 0.9600 - d_2: 0.9561 - n: 2.1000 - mean_metric: 0.4931 - val_loss: 24.5201 - val_a_1: 2.7951 - val_a_2: 2.8015 - val_b_1: 2.7190 - val_b_2: 2.5982 - val_d_1: 0.9220 - val_d_2: 0.9061 - val_n: 2.0962 - val_mean_metric: 0.4883 - lr: 0.0010
# Epoch 44/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.4118 - a_1: 2.8339 - a_2: 2.7873 - b_1: 2.6811 - b_2: 2.6540 - d_1: 0.9489 - d_2: 0.9478 - n: 2.0200 - mean_metric: 0.4879 - val_loss: 23.2513 - val_a_1: 2.8032 - val_a_2: 2.7986 - val_b_1: 2.6812 - val_b_2: 2.6309 - val_d_1: 0.8479 - val_d_2: 0.8605 - val_n: 2.1134 - val_mean_metric: 0.4849 - lr: 0.0010
# Epoch 45/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.1021 - a_1: 2.8290 - a_2: 2.8152 - b_1: 2.6849 - b_2: 2.6800 - d_1: 0.9350 - d_2: 0.9385 - n: 2.0282 - mean_metric: 0.4893 - val_loss: 23.3032 - val_a_1: 2.7894 - val_a_2: 2.8339 - val_b_1: 2.6598 - val_b_2: 2.6469 - val_d_1: 0.8760 - val_d_2: 0.8430 - val_n: 2.1662 - val_mean_metric: 0.4875 - lr: 0.0010
# Epoch 46/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.0147 - a_1: 2.8477 - a_2: 2.8057 - b_1: 2.6876 - b_2: 2.6644 - d_1: 0.9398 - d_2: 0.9354 - n: 2.0340 - mean_metric: 0.4894 - val_loss: 23.5340 - val_a_1: 2.7900 - val_a_2: 2.7941 - val_b_1: 2.6486 - val_b_2: 2.6914 - val_d_1: 0.8748 - val_d_2: 0.8861 - val_n: 2.2207 - val_mean_metric: 0.4905 - lr: 0.0010
# Epoch 47/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 25.3128 - a_1: 2.8512 - a_2: 2.7944 - b_1: 2.6906 - b_2: 2.6587 - d_1: 0.9462 - d_2: 0.9684 - n: 2.0354 - mean_metric: 0.4904 - val_loss: 22.6847 - val_a_1: 2.7958 - val_a_2: 2.7876 - val_b_1: 2.6627 - val_b_2: 2.6281 - val_d_1: 0.8584 - val_d_2: 0.8302 - val_n: 2.0398 - val_mean_metric: 0.4805 - lr: 0.0010
# Epoch 48/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.9171 - a_1: 2.8428 - a_2: 2.7962 - b_1: 2.6833 - b_2: 2.6662 - d_1: 0.9386 - d_2: 0.9412 - n: 1.9507 - mean_metric: 0.4862 - val_loss: 22.5839 - val_a_1: 2.7877 - val_a_2: 2.8090 - val_b_1: 2.6633 - val_b_2: 2.6392 - val_d_1: 0.8538 - val_d_2: 0.8251 - val_n: 2.0869 - val_mean_metric: 0.4826 - lr: 0.0010
# Epoch 49/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.7810 - a_1: 2.8223 - a_2: 2.7923 - b_1: 2.6591 - b_2: 2.6531 - d_1: 0.9368 - d_2: 0.9337 - n: 1.9928 - mean_metric: 0.4853 - val_loss: 23.3538 - val_a_1: 2.7922 - val_a_2: 2.8029 - val_b_1: 2.6239 - val_b_2: 2.6382 - val_d_1: 0.8745 - val_d_2: 0.8797 - val_n: 2.0982 - val_mean_metric: 0.4840 - lr: 0.0010
# Epoch 50/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.7964 - a_1: 2.8137 - a_2: 2.7953 - b_1: 2.6741 - b_2: 2.6675 - d_1: 0.9396 - d_2: 0.9429 - n: 2.0297 - mean_metric: 0.4876 - val_loss: 22.8063 - val_a_1: 2.7918 - val_a_2: 2.8060 - val_b_1: 2.6793 - val_b_2: 2.6089 - val_d_1: 0.8552 - val_d_2: 0.8623 - val_n: 2.1732 - val_mean_metric: 0.4863 - lr: 0.0010
# Epoch 51/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.6483 - a_1: 2.8313 - a_2: 2.7889 - b_1: 2.6778 - b_2: 2.6730 - d_1: 0.9573 - d_2: 0.9173 - n: 2.0118 - mean_metric: 0.4875 - val_loss: 22.9695 - val_a_1: 2.8063 - val_a_2: 2.7974 - val_b_1: 2.6799 - val_b_2: 2.5791 - val_d_1: 0.8455 - val_d_2: 0.8783 - val_n: 2.0688 - val_mean_metric: 0.4823 - lr: 0.0010
# Epoch 52/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.5921 - a_1: 2.8329 - a_2: 2.7827 - b_1: 2.6837 - b_2: 2.6518 - d_1: 0.9340 - d_2: 0.9287 - n: 1.9656 - mean_metric: 0.4850 - val_loss: 22.9187 - val_a_1: 2.7793 - val_a_2: 2.7812 - val_b_1: 2.6631 - val_b_2: 2.6210 - val_d_1: 0.8474 - val_d_2: 0.8750 - val_n: 2.1028 - val_mean_metric: 0.4827 - lr: 0.0010
# Epoch 53/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.7120 - a_1: 2.8252 - a_2: 2.7814 - b_1: 2.6765 - b_2: 2.6793 - d_1: 0.9371 - d_2: 0.9524 - n: 1.9395 - mean_metric: 0.4853 - val_loss: 22.5668 - val_a_1: 2.7890 - val_a_2: 2.7903 - val_b_1: 2.6590 - val_b_2: 2.6552 - val_d_1: 0.8531 - val_d_2: 0.8628 - val_n: 2.0176 - val_mean_metric: 0.4814 - lr: 0.0010
# Epoch 54/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.5362 - a_1: 2.8209 - a_2: 2.7865 - b_1: 2.6954 - b_2: 2.6525 - d_1: 0.9456 - d_2: 0.9303 - n: 1.9389 - mean_metric: 0.4846 - val_loss: 22.6177 - val_a_1: 2.8165 - val_a_2: 2.8094 - val_b_1: 2.7160 - val_b_2: 2.5997 - val_d_1: 0.8613 - val_d_2: 0.8389 - val_n: 2.0374 - val_mean_metric: 0.4830 - lr: 0.0010
# Epoch 55/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.0309 - a_1: 2.8428 - a_2: 2.7823 - b_1: 2.6893 - b_2: 2.6630 - d_1: 0.9323 - d_2: 0.9022 - n: 1.9433 - mean_metric: 0.4841 - val_loss: 22.3647 - val_a_1: 2.8019 - val_a_2: 2.7975 - val_b_1: 2.6811 - val_b_2: 2.6004 - val_d_1: 0.8655 - val_d_2: 0.8365 - val_n: 2.0229 - val_mean_metric: 0.4806 - lr: 0.0010
# Epoch 56/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.9430 - a_1: 2.8354 - a_2: 2.8005 - b_1: 2.6791 - b_2: 2.6663 - d_1: 0.9236 - d_2: 0.9051 - n: 1.9450 - mean_metric: 0.4841 - val_loss: 22.5389 - val_a_1: 2.8080 - val_a_2: 2.8011 - val_b_1: 2.6540 - val_b_2: 2.6136 - val_d_1: 0.8677 - val_d_2: 0.8696 - val_n: 2.0155 - val_mean_metric: 0.4814 - lr: 0.0010
# Epoch 57/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.8235 - a_1: 2.8415 - a_2: 2.8036 - b_1: 2.6832 - b_2: 2.6626 - d_1: 0.9243 - d_2: 0.8981 - n: 1.8905 - mean_metric: 0.4824 - val_loss: 22.6358 - val_a_1: 2.8104 - val_a_2: 2.8000 - val_b_1: 2.6987 - val_b_2: 2.6155 - val_d_1: 0.8733 - val_d_2: 0.8561 - val_n: 2.0188 - val_mean_metric: 0.4828 - lr: 0.0010
# Epoch 58/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.0133 - a_1: 2.8236 - a_2: 2.7875 - b_1: 2.6901 - b_2: 2.6532 - d_1: 0.9156 - d_2: 0.9293 - n: 1.8836 - mean_metric: 0.4818 - val_loss: 22.5818 - val_a_1: 2.8008 - val_a_2: 2.7763 - val_b_1: 2.7337 - val_b_2: 2.6573 - val_d_1: 0.8698 - val_d_2: 0.8613 - val_n: 1.9565 - val_mean_metric: 0.4823 - lr: 0.0010
# Epoch 59/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.9559 - a_1: 2.8425 - a_2: 2.7815 - b_1: 2.6987 - b_2: 2.6672 - d_1: 0.9331 - d_2: 0.9082 - n: 1.8938 - mean_metric: 0.4831 - val_loss: 22.5237 - val_a_1: 2.8239 - val_a_2: 2.8015 - val_b_1: 2.6693 - val_b_2: 2.6281 - val_d_1: 0.8755 - val_d_2: 0.8551 - val_n: 2.0020 - val_mean_metric: 0.4822 - lr: 0.0010
# Epoch 60/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.9570 - a_1: 2.8459 - a_2: 2.7900 - b_1: 2.6858 - b_2: 2.6472 - d_1: 0.9226 - d_2: 0.9298 - n: 1.8911 - mean_metric: 0.4827 - val_loss: 22.4108 - val_a_1: 2.8241 - val_a_2: 2.8075 - val_b_1: 2.6309 - val_b_2: 2.6168 - val_d_1: 0.8694 - val_d_2: 0.8456 - val_n: 1.9070 - val_mean_metric: 0.4772 - lr: 0.0010
# Epoch 61/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 24.1128 - a_1: 2.8414 - a_2: 2.7871 - b_1: 2.6847 - b_2: 2.6616 - d_1: 0.9455 - d_2: 0.9184 - n: 1.8754 - mean_metric: 0.4828 - val_loss: 22.9575 - val_a_1: 2.8320 - val_a_2: 2.7995 - val_b_1: 2.6831 - val_b_2: 2.6150 - val_d_1: 0.9266 - val_d_2: 0.8566 - val_n: 1.9388 - val_mean_metric: 0.4821 - lr: 0.0010
# Epoch 62/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.6958 - a_1: 2.8314 - a_2: 2.7806 - b_1: 2.6854 - b_2: 2.6548 - d_1: 0.9170 - d_2: 0.9180 - n: 1.8895 - mean_metric: 0.4816 - val_loss: 22.0662 - val_a_1: 2.8063 - val_a_2: 2.7966 - val_b_1: 2.6787 - val_b_2: 2.6210 - val_d_1: 0.8690 - val_d_2: 0.8369 - val_n: 1.9088 - val_mean_metric: 0.4777 - lr: 0.0010
# Epoch 63/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.5026 - a_1: 2.8576 - a_2: 2.7911 - b_1: 2.6746 - b_2: 2.6510 - d_1: 0.9144 - d_2: 0.9089 - n: 1.9217 - mean_metric: 0.4830 - val_loss: 22.2200 - val_a_1: 2.8012 - val_a_2: 2.7826 - val_b_1: 2.6558 - val_b_2: 2.6620 - val_d_1: 0.8714 - val_d_2: 0.8467 - val_n: 2.0153 - val_mean_metric: 0.4816 - lr: 0.0010
# Epoch 64/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.3200 - a_1: 2.8521 - a_2: 2.7921 - b_1: 2.6909 - b_2: 2.6706 - d_1: 0.9054 - d_2: 0.8997 - n: 1.9115 - mean_metric: 0.4830 - val_loss: 21.6481 - val_a_1: 2.8087 - val_a_2: 2.8068 - val_b_1: 2.6965 - val_b_2: 2.6375 - val_d_1: 0.8280 - val_d_2: 0.8483 - val_n: 1.9059 - val_mean_metric: 0.4782 - lr: 0.0010
# Epoch 65/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.3724 - a_1: 2.8289 - a_2: 2.7917 - b_1: 2.6941 - b_2: 2.6690 - d_1: 0.9216 - d_2: 0.8989 - n: 1.8685 - mean_metric: 0.4814 - val_loss: 21.8723 - val_a_1: 2.7987 - val_a_2: 2.8033 - val_b_1: 2.6636 - val_b_2: 2.5852 - val_d_1: 0.8555 - val_d_2: 0.8443 - val_n: 1.9130 - val_mean_metric: 0.4759 - lr: 0.0010
# Epoch 66/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.4568 - a_1: 2.8345 - a_2: 2.7901 - b_1: 2.6990 - b_2: 2.6646 - d_1: 0.9182 - d_2: 0.9048 - n: 1.8322 - mean_metric: 0.4805 - val_loss: 21.9403 - val_a_1: 2.8145 - val_a_2: 2.8026 - val_b_1: 2.6930 - val_b_2: 2.6822 - val_d_1: 0.8399 - val_d_2: 0.8557 - val_n: 1.8479 - val_mean_metric: 0.4783 - lr: 0.0010
# Epoch 67/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.2541 - a_1: 2.8364 - a_2: 2.8022 - b_1: 2.6820 - b_2: 2.6751 - d_1: 0.9068 - d_2: 0.9069 - n: 1.8085 - mean_metric: 0.4797 - val_loss: 21.6384 - val_a_1: 2.8054 - val_a_2: 2.7880 - val_b_1: 2.6487 - val_b_2: 2.6184 - val_d_1: 0.8385 - val_d_2: 0.8479 - val_n: 1.8056 - val_mean_metric: 0.4723 - lr: 0.0010
# Epoch 68/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.7831 - a_1: 2.8411 - a_2: 2.7843 - b_1: 2.6869 - b_2: 2.6682 - d_1: 0.8949 - d_2: 0.8753 - n: 1.8003 - mean_metric: 0.4775 - val_loss: 21.3093 - val_a_1: 2.8018 - val_a_2: 2.8055 - val_b_1: 2.6901 - val_b_2: 2.6301 - val_d_1: 0.8310 - val_d_2: 0.8109 - val_n: 1.9034 - val_mean_metric: 0.4762 - lr: 0.0010
# Epoch 69/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.1022 - a_1: 2.8409 - a_2: 2.7971 - b_1: 2.6883 - b_2: 2.6779 - d_1: 0.8997 - d_2: 0.8998 - n: 1.8387 - mean_metric: 0.4804 - val_loss: 23.0125 - val_a_1: 2.7914 - val_a_2: 2.7982 - val_b_1: 2.7143 - val_b_2: 2.6587 - val_d_1: 0.9200 - val_d_2: 0.8705 - val_n: 1.8606 - val_mean_metric: 0.4809 - lr: 0.0010
# Epoch 70/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.8286 - a_1: 2.8433 - a_2: 2.7864 - b_1: 2.6842 - b_2: 2.6708 - d_1: 0.8866 - d_2: 0.8946 - n: 1.8487 - mean_metric: 0.4796 - val_loss: 22.0600 - val_a_1: 2.8307 - val_a_2: 2.8001 - val_b_1: 2.6381 - val_b_2: 2.6537 - val_d_1: 0.8909 - val_d_2: 0.8299 - val_n: 1.9486 - val_mean_metric: 0.4802 - lr: 0.0010
# Epoch 71/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.8701 - a_1: 2.8331 - a_2: 2.8058 - b_1: 2.6675 - b_2: 2.6665 - d_1: 0.9111 - d_2: 0.8839 - n: 1.8940 - mean_metric: 0.4811 - val_loss: 21.4868 - val_a_1: 2.7870 - val_a_2: 2.8078 - val_b_1: 2.6709 - val_b_2: 2.6232 - val_d_1: 0.8329 - val_d_2: 0.8342 - val_n: 1.9714 - val_mean_metric: 0.4781 - lr: 0.0010
# Epoch 72/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.6519 - a_1: 2.8307 - a_2: 2.8037 - b_1: 2.6999 - b_2: 2.6691 - d_1: 0.8967 - d_2: 0.8735 - n: 1.8749 - mean_metric: 0.4805 - val_loss: 21.0079 - val_a_1: 2.7965 - val_a_2: 2.7976 - val_b_1: 2.6754 - val_b_2: 2.5983 - val_d_1: 0.8457 - val_d_2: 0.7997 - val_n: 1.9228 - val_mean_metric: 0.4750 - lr: 0.0010
# Epoch 73/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 23.1190 - a_1: 2.8405 - a_2: 2.7851 - b_1: 2.6869 - b_2: 2.6644 - d_1: 0.9021 - d_2: 0.9272 - n: 1.8516 - mean_metric: 0.4808 - val_loss: 21.6728 - val_a_1: 2.8308 - val_a_2: 2.8140 - val_b_1: 2.6463 - val_b_2: 2.6281 - val_d_1: 0.8535 - val_d_2: 0.8479 - val_n: 1.8692 - val_mean_metric: 0.4768 - lr: 0.0010
# Epoch 74/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.6694 - a_1: 2.8469 - a_2: 2.8105 - b_1: 2.6792 - b_2: 2.6691 - d_1: 0.8926 - d_2: 0.8939 - n: 1.8324 - mean_metric: 0.4798 - val_loss: 22.0115 - val_a_1: 2.8069 - val_a_2: 2.8183 - val_b_1: 2.7178 - val_b_2: 2.6160 - val_d_1: 0.8777 - val_d_2: 0.8656 - val_n: 1.8505 - val_mean_metric: 0.4789 - lr: 0.0010
# Epoch 75/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.6095 - a_1: 2.8372 - a_2: 2.7969 - b_1: 2.7006 - b_2: 2.6700 - d_1: 0.9044 - d_2: 0.8816 - n: 1.8048 - mean_metric: 0.4789 - val_loss: 21.3149 - val_a_1: 2.8143 - val_a_2: 2.8217 - val_b_1: 2.7054 - val_b_2: 2.5950 - val_d_1: 0.8138 - val_d_2: 0.8640 - val_n: 1.8296 - val_mean_metric: 0.4753 - lr: 0.0010
# Epoch 76/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.4531 - a_1: 2.8343 - a_2: 2.8117 - b_1: 2.6928 - b_2: 2.6617 - d_1: 0.8794 - d_2: 0.8855 - n: 1.7996 - mean_metric: 0.4780 - val_loss: 21.2950 - val_a_1: 2.7917 - val_a_2: 2.8157 - val_b_1: 2.6797 - val_b_2: 2.5903 - val_d_1: 0.8375 - val_d_2: 0.8469 - val_n: 1.8703 - val_mean_metric: 0.4749 - lr: 0.0010
# Epoch 77/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.7456 - a_1: 2.8143 - a_2: 2.7848 - b_1: 2.7076 - b_2: 2.6574 - d_1: 0.9055 - d_2: 0.8960 - n: 1.8133 - mean_metric: 0.4784 - val_loss: 21.8485 - val_a_1: 2.8057 - val_a_2: 2.8034 - val_b_1: 2.6910 - val_b_2: 2.6412 - val_d_1: 0.8529 - val_d_2: 0.8718 - val_n: 1.8675 - val_mean_metric: 0.4783 - lr: 0.0010
# Epoch 78/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.7020 - a_1: 2.8418 - a_2: 2.7948 - b_1: 2.6787 - b_2: 2.6750 - d_1: 0.9016 - d_2: 0.8954 - n: 1.7977 - mean_metric: 0.4786 - val_loss: 22.0760 - val_a_1: 2.7841 - val_a_2: 2.7947 - val_b_1: 2.6580 - val_b_2: 2.6496 - val_d_1: 0.8921 - val_d_2: 0.8499 - val_n: 1.8301 - val_mean_metric: 0.4758 - lr: 0.0010
# Epoch 79/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.4095 - a_1: 2.8357 - a_2: 2.7997 - b_1: 2.6795 - b_2: 2.6657 - d_1: 0.8959 - d_2: 0.8765 - n: 1.8089 - mean_metric: 0.4777 - val_loss: 21.5609 - val_a_1: 2.8108 - val_a_2: 2.8071 - val_b_1: 2.6524 - val_b_2: 2.6660 - val_d_1: 0.8598 - val_d_2: 0.8547 - val_n: 1.8579 - val_mean_metric: 0.4774 - lr: 0.0010
# Epoch 80/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.5999 - a_1: 2.8446 - a_2: 2.7823 - b_1: 2.6866 - b_2: 2.6599 - d_1: 0.9018 - d_2: 0.8969 - n: 1.7865 - mean_metric: 0.4776 - val_loss: 20.9664 - val_a_1: 2.8031 - val_a_2: 2.7884 - val_b_1: 2.6730 - val_b_2: 2.7068 - val_d_1: 0.8461 - val_d_2: 0.8281 - val_n: 1.7775 - val_mean_metric: 0.4746 - lr: 0.0010
# Epoch 81/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.2857 - a_1: 2.8436 - a_2: 2.7752 - b_1: 2.6873 - b_2: 2.6739 - d_1: 0.8862 - d_2: 0.8841 - n: 1.7550 - mean_metric: 0.4759 - val_loss: 21.4708 - val_a_1: 2.8208 - val_a_2: 2.7961 - val_b_1: 2.6392 - val_b_2: 2.6477 - val_d_1: 0.8272 - val_d_2: 0.8810 - val_n: 1.8004 - val_mean_metric: 0.4743 - lr: 0.0010
# Epoch 82/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.0015 - a_1: 2.8303 - a_2: 2.7718 - b_1: 2.6777 - b_2: 2.6677 - d_1: 0.8705 - d_2: 0.8759 - n: 1.7685 - mean_metric: 0.4745 - val_loss: 21.1458 - val_a_1: 2.7920 - val_a_2: 2.7782 - val_b_1: 2.6488 - val_b_2: 2.6904 - val_d_1: 0.8818 - val_d_2: 0.8020 - val_n: 1.8154 - val_mean_metric: 0.4741 - lr: 0.0010
# Epoch 83/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.1010 - a_1: 2.8256 - a_2: 2.7790 - b_1: 2.6827 - b_2: 2.6603 - d_1: 0.8859 - d_2: 0.8760 - n: 1.7784 - mean_metric: 0.4754 - val_loss: 22.1081 - val_a_1: 2.7859 - val_a_2: 2.7982 - val_b_1: 2.6737 - val_b_2: 2.6397 - val_d_1: 0.8777 - val_d_2: 0.8973 - val_n: 1.8322 - val_mean_metric: 0.4773 - lr: 0.0010
# Epoch 84/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.1418 - a_1: 2.8290 - a_2: 2.7868 - b_1: 2.6782 - b_2: 2.6727 - d_1: 0.8898 - d_2: 0.8720 - n: 1.8041 - mean_metric: 0.4767 - val_loss: 21.4785 - val_a_1: 2.7927 - val_a_2: 2.7948 - val_b_1: 2.6484 - val_b_2: 2.6457 - val_d_1: 0.8582 - val_d_2: 0.8537 - val_n: 1.8353 - val_mean_metric: 0.4748 - lr: 0.0010
# Epoch 85/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.1057 - a_1: 2.8278 - a_2: 2.7803 - b_1: 2.6617 - b_2: 2.6791 - d_1: 0.8918 - d_2: 0.8741 - n: 1.7995 - mean_metric: 0.4762 - val_loss: 21.3778 - val_a_1: 2.7948 - val_a_2: 2.8038 - val_b_1: 2.6834 - val_b_2: 2.6536 - val_d_1: 0.8767 - val_d_2: 0.8410 - val_n: 1.8483 - val_mean_metric: 0.4772 - lr: 0.0010
# Epoch 86/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 22.1339 - a_1: 2.8279 - a_2: 2.7919 - b_1: 2.6594 - b_2: 2.6816 - d_1: 0.9040 - d_2: 0.8709 - n: 1.7981 - mean_metric: 0.4768 - val_loss: 21.4716 - val_a_1: 2.8119 - val_a_2: 2.8052 - val_b_1: 2.6818 - val_b_2: 2.6137 - val_d_1: 0.8751 - val_d_2: 0.8632 - val_n: 1.8402 - val_mean_metric: 0.4768 - lr: 0.0010
# Epoch 87/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.8473 - a_1: 2.8358 - a_2: 2.7885 - b_1: 2.6987 - b_2: 2.6750 - d_1: 0.8813 - d_2: 0.8714 - n: 1.7712 - mean_metric: 0.4764 - val_loss: 20.7349 - val_a_1: 2.8171 - val_a_2: 2.8047 - val_b_1: 2.6337 - val_b_2: 2.6429 - val_d_1: 0.8239 - val_d_2: 0.8364 - val_n: 1.7789 - val_mean_metric: 0.4718 - lr: 0.0010
# Epoch 88/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.8051 - a_1: 2.8328 - a_2: 2.7761 - b_1: 2.6854 - b_2: 2.6617 - d_1: 0.8839 - d_2: 0.8630 - n: 1.7641 - mean_metric: 0.4746 - val_loss: 21.0863 - val_a_1: 2.7981 - val_a_2: 2.7875 - val_b_1: 2.6444 - val_b_2: 2.6867 - val_d_1: 0.8673 - val_d_2: 0.8329 - val_n: 1.8107 - val_mean_metric: 0.4748 - lr: 0.0010
# Epoch 89/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.8127 - a_1: 2.8446 - a_2: 2.7817 - b_1: 2.6949 - b_2: 2.6853 - d_1: 0.8782 - d_2: 0.8694 - n: 1.7875 - mean_metric: 0.4771 - val_loss: 20.5199 - val_a_1: 2.8489 - val_a_2: 2.8183 - val_b_1: 2.6244 - val_b_2: 2.6640 - val_d_1: 0.8320 - val_d_2: 0.8197 - val_n: 1.8166 - val_mean_metric: 0.4747 - lr: 0.0010
# Epoch 90/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.8109 - a_1: 2.8422 - a_2: 2.7860 - b_1: 2.6843 - b_2: 2.6544 - d_1: 0.8844 - d_2: 0.8786 - n: 1.7977 - mean_metric: 0.4767 - val_loss: 20.7004 - val_a_1: 2.7870 - val_a_2: 2.8059 - val_b_1: 2.6435 - val_b_2: 2.6622 - val_d_1: 0.8248 - val_d_2: 0.8303 - val_n: 1.8276 - val_mean_metric: 0.4733 - lr: 0.0010
# Epoch 91/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.6292 - a_1: 2.8290 - a_2: 2.7907 - b_1: 2.7016 - b_2: 2.6754 - d_1: 0.8824 - d_2: 0.8527 - n: 1.7821 - mean_metric: 0.4762 - val_loss: 20.2748 - val_a_1: 2.8162 - val_a_2: 2.8104 - val_b_1: 2.6483 - val_b_2: 2.6225 - val_d_1: 0.8098 - val_d_2: 0.8215 - val_n: 1.8709 - val_mean_metric: 0.4739 - lr: 0.0010
# Epoch 92/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.4840 - a_1: 2.8428 - a_2: 2.7883 - b_1: 2.6693 - b_2: 2.6871 - d_1: 0.8688 - d_2: 0.8633 - n: 1.7824 - mean_metric: 0.4758 - val_loss: 20.6002 - val_a_1: 2.7966 - val_a_2: 2.7892 - val_b_1: 2.6435 - val_b_2: 2.6526 - val_d_1: 0.8262 - val_d_2: 0.8416 - val_n: 1.8104 - val_mean_metric: 0.4725 - lr: 0.0010
# Epoch 93/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.3259 - a_1: 2.8248 - a_2: 2.7841 - b_1: 2.6968 - b_2: 2.6874 - d_1: 0.8601 - d_2: 0.8488 - n: 1.7597 - mean_metric: 0.4744 - val_loss: 20.4458 - val_a_1: 2.7946 - val_a_2: 2.8017 - val_b_1: 2.7248 - val_b_2: 2.6971 - val_d_1: 0.8420 - val_d_2: 0.8205 - val_n: 1.8257 - val_mean_metric: 0.4774 - lr: 0.0010
# Epoch 94/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.4468 - a_1: 2.8289 - a_2: 2.7778 - b_1: 2.6951 - b_2: 2.6731 - d_1: 0.8749 - d_2: 0.8537 - n: 1.7377 - mean_metric: 0.4738 - val_loss: 20.2110 - val_a_1: 2.7915 - val_a_2: 2.7890 - val_b_1: 2.6909 - val_b_2: 2.6178 - val_d_1: 0.8171 - val_d_2: 0.8179 - val_n: 1.7606 - val_mean_metric: 0.4701 - lr: 0.0010
# Epoch 95/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.4388 - a_1: 2.8330 - a_2: 2.7718 - b_1: 2.6975 - b_2: 2.6563 - d_1: 0.8774 - d_2: 0.8568 - n: 1.7447 - mean_metric: 0.4737 - val_loss: 20.8221 - val_a_1: 2.8057 - val_a_2: 2.7862 - val_b_1: 2.6543 - val_b_2: 2.6726 - val_d_1: 0.8254 - val_d_2: 0.8811 - val_n: 1.8054 - val_mean_metric: 0.4749 - lr: 0.0010
# Epoch 96/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.3664 - a_1: 2.8356 - a_2: 2.7857 - b_1: 2.7021 - b_2: 2.6654 - d_1: 0.8721 - d_2: 0.8576 - n: 1.7457 - mean_metric: 0.4746 - val_loss: 20.4146 - val_a_1: 2.7902 - val_a_2: 2.7885 - val_b_1: 2.6640 - val_b_2: 2.6449 - val_d_1: 0.8496 - val_d_2: 0.8238 - val_n: 1.7899 - val_mean_metric: 0.4722 - lr: 0.0010
# Epoch 97/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.1531 - a_1: 2.8275 - a_2: 2.7881 - b_1: 2.7002 - b_2: 2.6731 - d_1: 0.8601 - d_2: 0.8520 - n: 1.7340 - mean_metric: 0.4736 - val_loss: 20.6358 - val_a_1: 2.8018 - val_a_2: 2.7871 - val_b_1: 2.6438 - val_b_2: 2.6777 - val_d_1: 0.8519 - val_d_2: 0.8491 - val_n: 1.7724 - val_mean_metric: 0.4733 - lr: 0.0010
# Epoch 98/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.3647 - a_1: 2.8370 - a_2: 2.7784 - b_1: 2.6666 - b_2: 2.6726 - d_1: 0.8735 - d_2: 0.8686 - n: 1.7135 - mean_metric: 0.4728 - val_loss: 20.6288 - val_a_1: 2.7969 - val_a_2: 2.7763 - val_b_1: 2.6310 - val_b_2: 2.6877 - val_d_1: 0.8462 - val_d_2: 0.8378 - val_n: 1.7085 - val_mean_metric: 0.4700 - lr: 0.0010
# Epoch 99/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.0406 - a_1: 2.8411 - a_2: 2.7674 - b_1: 2.6972 - b_2: 2.6744 - d_1: 0.8569 - d_2: 0.8499 - n: 1.6910 - mean_metric: 0.4717 - val_loss: 20.3968 - val_a_1: 2.8096 - val_a_2: 2.7823 - val_b_1: 2.6923 - val_b_2: 2.6049 - val_d_1: 0.8202 - val_d_2: 0.8390 - val_n: 1.7260 - val_mean_metric: 0.4697 - lr: 0.0010
# Epoch 100/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.0720 - a_1: 2.8381 - a_2: 2.7700 - b_1: 2.6746 - b_2: 2.6474 - d_1: 0.8676 - d_2: 0.8525 - n: 1.7085 - mean_metric: 0.4711 - val_loss: 20.1670 - val_a_1: 2.7929 - val_a_2: 2.7919 - val_b_1: 2.6625 - val_b_2: 2.6186 - val_d_1: 0.8137 - val_d_2: 0.8394 - val_n: 1.6695 - val_mean_metric: 0.4669 - lr: 0.0010
# Epoch 101/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.2606 - a_1: 2.8377 - a_2: 2.7797 - b_1: 2.6957 - b_2: 2.6901 - d_1: 0.8640 - d_2: 0.8667 - n: 1.7005 - mean_metric: 0.4737 - val_loss: 20.7979 - val_a_1: 2.7982 - val_a_2: 2.8032 - val_b_1: 2.6611 - val_b_2: 2.6972 - val_d_1: 0.8311 - val_d_2: 0.8601 - val_n: 1.7207 - val_mean_metric: 0.4729 - lr: 0.0010
# Epoch 102/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.8925 - a_1: 2.8320 - a_2: 2.7841 - b_1: 2.6756 - b_2: 2.6647 - d_1: 0.8551 - d_2: 0.8474 - n: 1.7287 - mean_metric: 0.4720 - val_loss: 20.1746 - val_a_1: 2.7840 - val_a_2: 2.7942 - val_b_1: 2.6618 - val_b_2: 2.6510 - val_d_1: 0.8289 - val_d_2: 0.8256 - val_n: 1.7524 - val_mean_metric: 0.4705 - lr: 0.0010
# Epoch 103/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.9752 - a_1: 2.8171 - a_2: 2.7760 - b_1: 2.6851 - b_2: 2.6744 - d_1: 0.8571 - d_2: 0.8478 - n: 1.7135 - mean_metric: 0.4715 - val_loss: 20.1059 - val_a_1: 2.7951 - val_a_2: 2.8113 - val_b_1: 2.6638 - val_b_2: 2.6449 - val_d_1: 0.8247 - val_d_2: 0.8212 - val_n: 1.7452 - val_mean_metric: 0.4708 - lr: 0.0010
# Epoch 104/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.0714 - a_1: 2.8416 - a_2: 2.7886 - b_1: 2.6976 - b_2: 2.6628 - d_1: 0.8678 - d_2: 0.8529 - n: 1.7286 - mean_metric: 0.4738 - val_loss: 19.8543 - val_a_1: 2.8151 - val_a_2: 2.7946 - val_b_1: 2.6993 - val_b_2: 2.6433 - val_d_1: 0.8251 - val_d_2: 0.8062 - val_n: 1.7300 - val_mean_metric: 0.4710 - lr: 0.0010
# Epoch 105/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.8557 - a_1: 2.8373 - a_2: 2.7854 - b_1: 2.6843 - b_2: 2.6863 - d_1: 0.8555 - d_2: 0.8488 - n: 1.7202 - mean_metric: 0.4731 - val_loss: 20.3468 - val_a_1: 2.8067 - val_a_2: 2.7960 - val_b_1: 2.6585 - val_b_2: 2.6349 - val_d_1: 0.8377 - val_d_2: 0.8418 - val_n: 1.7664 - val_mean_metric: 0.4720 - lr: 0.0010
# Epoch 106/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.0815 - a_1: 2.8274 - a_2: 2.7853 - b_1: 2.6764 - b_2: 2.6594 - d_1: 0.8772 - d_2: 0.8539 - n: 1.7370 - mean_metric: 0.4730 - val_loss: 20.0491 - val_a_1: 2.7801 - val_a_2: 2.7808 - val_b_1: 2.6535 - val_b_2: 2.6676 - val_d_1: 0.8302 - val_d_2: 0.8348 - val_n: 1.7272 - val_mean_metric: 0.4697 - lr: 0.0010
# Epoch 107/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.0770 - a_1: 2.8266 - a_2: 2.7715 - b_1: 2.6982 - b_2: 2.6759 - d_1: 0.8805 - d_2: 0.8518 - n: 1.7193 - mean_metric: 0.4732 - val_loss: 20.2450 - val_a_1: 2.8193 - val_a_2: 2.7876 - val_b_1: 2.6795 - val_b_2: 2.6203 - val_d_1: 0.8449 - val_d_2: 0.8358 - val_n: 1.7716 - val_mean_metric: 0.4725 - lr: 0.0010
# Epoch 108/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.0066 - a_1: 2.8495 - a_2: 2.7913 - b_1: 2.6739 - b_2: 2.6804 - d_1: 0.8641 - d_2: 0.8565 - n: 1.7299 - mean_metric: 0.4739 - val_loss: 20.1586 - val_a_1: 2.8122 - val_a_2: 2.7941 - val_b_1: 2.6497 - val_b_2: 2.6349 - val_d_1: 0.8152 - val_d_2: 0.8375 - val_n: 1.7112 - val_mean_metric: 0.4691 - lr: 0.0010
# Epoch 109/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.2048 - a_1: 2.8364 - a_2: 2.7736 - b_1: 2.6916 - b_2: 2.6637 - d_1: 0.8696 - d_2: 0.8739 - n: 1.7262 - mean_metric: 0.4736 - val_loss: 19.9446 - val_a_1: 2.8166 - val_a_2: 2.7845 - val_b_1: 2.6249 - val_b_2: 2.6727 - val_d_1: 0.8409 - val_d_2: 0.8176 - val_n: 1.7798 - val_mean_metric: 0.4718 - lr: 0.0010
# Epoch 110/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 21.0724 - a_1: 2.8326 - a_2: 2.7706 - b_1: 2.6874 - b_2: 2.6817 - d_1: 0.8736 - d_2: 0.8575 - n: 1.7381 - mean_metric: 0.4738 - val_loss: 20.3251 - val_a_1: 2.8192 - val_a_2: 2.7797 - val_b_1: 2.6854 - val_b_2: 2.6474 - val_d_1: 0.8756 - val_d_2: 0.8154 - val_n: 1.7467 - val_mean_metric: 0.4729 - lr: 0.0010
# Epoch 111/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.8716 - a_1: 2.8469 - a_2: 2.7770 - b_1: 2.6942 - b_2: 2.6737 - d_1: 0.8654 - d_2: 0.8496 - n: 1.7174 - mean_metric: 0.4733 - val_loss: 20.3044 - val_a_1: 2.7995 - val_a_2: 2.7964 - val_b_1: 2.6753 - val_b_2: 2.6699 - val_d_1: 0.8437 - val_d_2: 0.8520 - val_n: 1.7524 - val_mean_metric: 0.4735 - lr: 0.0010
# Epoch 112/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.7689 - a_1: 2.8276 - a_2: 2.7792 - b_1: 2.6958 - b_2: 2.6757 - d_1: 0.8517 - d_2: 0.8560 - n: 1.7199 - mean_metric: 0.4726 - val_loss: 20.2461 - val_a_1: 2.8019 - val_a_2: 2.7939 - val_b_1: 2.6368 - val_b_2: 2.6723 - val_d_1: 0.8485 - val_d_2: 0.8336 - val_n: 1.7381 - val_mean_metric: 0.4714 - lr: 0.0010
# Epoch 113/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.5938 - a_1: 2.8329 - a_2: 2.7898 - b_1: 2.7012 - b_2: 2.6701 - d_1: 0.8597 - d_2: 0.8411 - n: 1.7327 - mean_metric: 0.4733 - val_loss: 20.1222 - val_a_1: 2.8124 - val_a_2: 2.8029 - val_b_1: 2.6500 - val_b_2: 2.6418 - val_d_1: 0.8588 - val_d_2: 0.8355 - val_n: 1.7339 - val_mean_metric: 0.4717 - lr: 0.0010
# Epoch 114/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.7972 - a_1: 2.8417 - a_2: 2.7861 - b_1: 2.6964 - b_2: 2.6747 - d_1: 0.8594 - d_2: 0.8592 - n: 1.7160 - mean_metric: 0.4736 - val_loss: 20.2068 - val_a_1: 2.7996 - val_a_2: 2.8125 - val_b_1: 2.6850 - val_b_2: 2.6807 - val_d_1: 0.8619 - val_d_2: 0.8267 - val_n: 1.8022 - val_mean_metric: 0.4761 - lr: 0.0010
# Epoch 115/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.6701 - a_1: 2.8190 - a_2: 2.7890 - b_1: 2.6920 - b_2: 2.6793 - d_1: 0.8476 - d_2: 0.8500 - n: 1.7389 - mean_metric: 0.4730 - val_loss: 19.7836 - val_a_1: 2.7880 - val_a_2: 2.8040 - val_b_1: 2.7032 - val_b_2: 2.6600 - val_d_1: 0.8214 - val_d_2: 0.8331 - val_n: 1.7635 - val_mean_metric: 0.4730 - lr: 0.0010
# Epoch 116/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.4449 - a_1: 2.8268 - a_2: 2.7879 - b_1: 2.7018 - b_2: 2.6788 - d_1: 0.8455 - d_2: 0.8386 - n: 1.7451 - mean_metric: 0.4733 - val_loss: 20.2209 - val_a_1: 2.8042 - val_a_2: 2.8017 - val_b_1: 2.6459 - val_b_2: 2.6844 - val_d_1: 0.8561 - val_d_2: 0.8147 - val_n: 1.7539 - val_mean_metric: 0.4726 - lr: 0.0010
# Epoch 117/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.5190 - a_1: 2.8306 - a_2: 2.7773 - b_1: 2.7009 - b_2: 2.6854 - d_1: 0.8492 - d_2: 0.8410 - n: 1.7394 - mean_metric: 0.4732 - val_loss: 20.3832 - val_a_1: 2.8001 - val_a_2: 2.7951 - val_b_1: 2.7000 - val_b_2: 2.6252 - val_d_1: 0.8696 - val_d_2: 0.8408 - val_n: 1.7941 - val_mean_metric: 0.4747 - lr: 0.0010
# Epoch 118/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.4488 - a_1: 2.8383 - a_2: 2.7637 - b_1: 2.6792 - b_2: 2.6743 - d_1: 0.8584 - d_2: 0.8351 - n: 1.7344 - mean_metric: 0.4719 - val_loss: 19.8200 - val_a_1: 2.8012 - val_a_2: 2.7785 - val_b_1: 2.6869 - val_b_2: 2.6826 - val_d_1: 0.8233 - val_d_2: 0.8288 - val_n: 1.7761 - val_mean_metric: 0.4731 - lr: 0.0010
# Epoch 119/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.3145 - a_1: 2.8285 - a_2: 2.7742 - b_1: 2.6718 - b_2: 2.6538 - d_1: 0.8401 - d_2: 0.8432 - n: 1.7282 - mean_metric: 0.4705 - val_loss: 19.8515 - val_a_1: 2.8085 - val_a_2: 2.7689 - val_b_1: 2.6669 - val_b_2: 2.6596 - val_d_1: 0.8294 - val_d_2: 0.8321 - val_n: 1.7338 - val_mean_metric: 0.4706 - lr: 0.0010
# Epoch 120/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.4478 - a_1: 2.8503 - a_2: 2.7747 - b_1: 2.6699 - b_2: 2.6794 - d_1: 0.8580 - d_2: 0.8446 - n: 1.7243 - mean_metric: 0.4725 - val_loss: 19.5206 - val_a_1: 2.8146 - val_a_2: 2.7957 - val_b_1: 2.6576 - val_b_2: 2.6422 - val_d_1: 0.8022 - val_d_2: 0.8324 - val_n: 1.7682 - val_mean_metric: 0.4710 - lr: 0.0010
# Epoch 121/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.3094 - a_1: 2.8313 - a_2: 2.7757 - b_1: 2.6726 - b_2: 2.6694 - d_1: 0.8427 - d_2: 0.8429 - n: 1.7289 - mean_metric: 0.4712 - val_loss: 20.4101 - val_a_1: 2.8025 - val_a_2: 2.7831 - val_b_1: 2.6311 - val_b_2: 2.6920 - val_d_1: 0.8750 - val_d_2: 0.8366 - val_n: 1.7841 - val_mean_metric: 0.4740 - lr: 0.0010
# Epoch 122/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.2650 - a_1: 2.8256 - a_2: 2.7745 - b_1: 2.6862 - b_2: 2.6615 - d_1: 0.8433 - d_2: 0.8386 - n: 1.7130 - mean_metric: 0.4706 - val_loss: 19.8205 - val_a_1: 2.7935 - val_a_2: 2.7838 - val_b_1: 2.6857 - val_b_2: 2.6293 - val_d_1: 0.8171 - val_d_2: 0.8449 - val_n: 1.7442 - val_mean_metric: 0.4705 - lr: 0.0010
# Epoch 123/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.3410 - a_1: 2.8261 - a_2: 2.7754 - b_1: 2.6709 - b_2: 2.6922 - d_1: 0.8512 - d_2: 0.8402 - n: 1.7151 - mean_metric: 0.4714 - val_loss: 20.0604 - val_a_1: 2.8011 - val_a_2: 2.7942 - val_b_1: 2.6591 - val_b_2: 2.7171 - val_d_1: 0.8268 - val_d_2: 0.8527 - val_n: 1.7031 - val_mean_metric: 0.4724 - lr: 0.0010
# Epoch 124/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 20.2373 - a_1: 2.8278 - a_2: 2.7904 - b_1: 2.6999 - b_2: 2.6866 - d_1: 0.8440 - d_2: 0.8413 - n: 1.7146 - mean_metric: 0.4726 - val_loss: 20.1020 - val_a_1: 2.8115 - val_a_2: 2.8162 - val_b_1: 2.6822 - val_b_2: 2.6837 - val_d_1: 0.8410 - val_d_2: 0.8477 - val_n: 1.7444 - val_mean_metric: 0.4747 - lr: 0.0010
# Epoch 125/1000
# ...
# Epoch 960/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6948 - a_1: 2.8291 - a_2: 2.7845 - b_1: 2.6970 - b_2: 2.6913 - d_1: 0.6008 - d_2: 0.5984 - n: 1.5480 - mean_metric: 0.4511 - val_loss: 17.2396 - val_a_1: 2.7854 - val_a_2: 2.7832 - val_b_1: 2.7319 - val_b_2: 2.6810 - val_d_1: 0.7720 - val_d_2: 0.7971 - val_n: 1.5643 - val_mean_metric: 0.4645 - lr: 7.7650e-05
# Epoch 961/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7265 - a_1: 2.8299 - a_2: 2.7879 - b_1: 2.6970 - b_2: 2.6918 - d_1: 0.6012 - d_2: 0.6046 - n: 1.5469 - mean_metric: 0.4514 - val_loss: 17.2592 - val_a_1: 2.7854 - val_a_2: 2.7831 - val_b_1: 2.7243 - val_b_2: 2.6837 - val_d_1: 0.7703 - val_d_2: 0.8009 - val_n: 1.5636 - val_mean_metric: 0.4644 - lr: 7.6000e-05
# Epoch 962/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7031 - a_1: 2.8279 - a_2: 2.7906 - b_1: 2.6885 - b_2: 2.6928 - d_1: 0.6059 - d_2: 0.6016 - n: 1.5438 - mean_metric: 0.4512 - val_loss: 17.2599 - val_a_1: 2.7827 - val_a_2: 2.7836 - val_b_1: 2.7293 - val_b_2: 2.6879 - val_d_1: 0.7686 - val_d_2: 0.7981 - val_n: 1.5610 - val_mean_metric: 0.4643 - lr: 7.4350e-05
# Epoch 963/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7649 - a_1: 2.8285 - a_2: 2.7895 - b_1: 2.6985 - b_2: 2.7076 - d_1: 0.6028 - d_2: 0.6047 - n: 1.5417 - mean_metric: 0.4519 - val_loss: 17.2391 - val_a_1: 2.7811 - val_a_2: 2.7827 - val_b_1: 2.7378 - val_b_2: 2.6984 - val_d_1: 0.7673 - val_d_2: 0.7942 - val_n: 1.5604 - val_mean_metric: 0.4647 - lr: 7.2700e-05
# Epoch 964/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8258 - a_1: 2.8298 - a_2: 2.7834 - b_1: 2.6929 - b_2: 2.7062 - d_1: 0.6032 - d_2: 0.6108 - n: 1.5514 - mean_metric: 0.4520 - val_loss: 17.2114 - val_a_1: 2.7841 - val_a_2: 2.7812 - val_b_1: 2.7326 - val_b_2: 2.6925 - val_d_1: 0.7677 - val_d_2: 0.7964 - val_n: 1.5632 - val_mean_metric: 0.4646 - lr: 7.1050e-05
# Epoch 965/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8119 - a_1: 2.8274 - a_2: 2.7883 - b_1: 2.7026 - b_2: 2.7034 - d_1: 0.6023 - d_2: 0.6093 - n: 1.5451 - mean_metric: 0.4521 - val_loss: 17.2541 - val_a_1: 2.7825 - val_a_2: 2.7824 - val_b_1: 2.7317 - val_b_2: 2.6914 - val_d_1: 0.7685 - val_d_2: 0.7973 - val_n: 1.5610 - val_mean_metric: 0.4645 - lr: 6.9400e-05
# Epoch 966/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6152 - a_1: 2.8292 - a_2: 2.7887 - b_1: 2.6877 - b_2: 2.7008 - d_1: 0.6006 - d_2: 0.5947 - n: 1.5508 - mean_metric: 0.4512 - val_loss: 17.2137 - val_a_1: 2.7869 - val_a_2: 2.7818 - val_b_1: 2.7219 - val_b_2: 2.6909 - val_d_1: 0.7683 - val_d_2: 0.7957 - val_n: 1.5612 - val_mean_metric: 0.4642 - lr: 6.7750e-05
# Epoch 967/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6808 - a_1: 2.8292 - a_2: 2.7853 - b_1: 2.6884 - b_2: 2.7061 - d_1: 0.6008 - d_2: 0.5967 - n: 1.5450 - mean_metric: 0.4512 - val_loss: 17.2131 - val_a_1: 2.7875 - val_a_2: 2.7839 - val_b_1: 2.7204 - val_b_2: 2.6960 - val_d_1: 0.7689 - val_d_2: 0.7952 - val_n: 1.5620 - val_mean_metric: 0.4644 - lr: 6.6100e-05
# Epoch 968/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8757 - a_1: 2.8292 - a_2: 2.7877 - b_1: 2.6907 - b_2: 2.7100 - d_1: 0.6156 - d_2: 0.6016 - n: 1.5412 - mean_metric: 0.4520 - val_loss: 17.3196 - val_a_1: 2.7881 - val_a_2: 2.7823 - val_b_1: 2.7230 - val_b_2: 2.6956 - val_d_1: 0.7741 - val_d_2: 0.7975 - val_n: 1.5643 - val_mean_metric: 0.4648 - lr: 6.4450e-05
# Epoch 969/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8070 - a_1: 2.8310 - a_2: 2.7900 - b_1: 2.6857 - b_2: 2.7060 - d_1: 0.6061 - d_2: 0.6058 - n: 1.5446 - mean_metric: 0.4517 - val_loss: 17.2352 - val_a_1: 2.7888 - val_a_2: 2.7836 - val_b_1: 2.7110 - val_b_2: 2.6883 - val_d_1: 0.7717 - val_d_2: 0.7969 - val_n: 1.5638 - val_mean_metric: 0.4641 - lr: 6.2800e-05
# Epoch 970/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7948 - a_1: 2.8343 - a_2: 2.7885 - b_1: 2.6824 - b_2: 2.7019 - d_1: 0.6064 - d_2: 0.6071 - n: 1.5435 - mean_metric: 0.4515 - val_loss: 17.2509 - val_a_1: 2.7886 - val_a_2: 2.7840 - val_b_1: 2.7161 - val_b_2: 2.6945 - val_d_1: 0.7696 - val_d_2: 0.7947 - val_n: 1.5650 - val_mean_metric: 0.4644 - lr: 6.1150e-05
# Epoch 971/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7453 - a_1: 2.8320 - a_2: 2.7868 - b_1: 2.6806 - b_2: 2.6997 - d_1: 0.6036 - d_2: 0.5999 - n: 1.5449 - mean_metric: 0.4510 - val_loss: 17.2515 - val_a_1: 2.7877 - val_a_2: 2.7847 - val_b_1: 2.7188 - val_b_2: 2.6918 - val_d_1: 0.7687 - val_d_2: 0.7944 - val_n: 1.5632 - val_mean_metric: 0.4643 - lr: 5.9500e-05
# Epoch 972/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7881 - a_1: 2.8309 - a_2: 2.7895 - b_1: 2.6756 - b_2: 2.6993 - d_1: 0.6089 - d_2: 0.6033 - n: 1.5484 - mean_metric: 0.4513 - val_loss: 17.2289 - val_a_1: 2.7867 - val_a_2: 2.7838 - val_b_1: 2.7095 - val_b_2: 2.6894 - val_d_1: 0.7713 - val_d_2: 0.7972 - val_n: 1.5634 - val_mean_metric: 0.4640 - lr: 5.7850e-05
# Epoch 973/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6375 - a_1: 2.8315 - a_2: 2.7913 - b_1: 2.6841 - b_2: 2.7055 - d_1: 0.6010 - d_2: 0.5921 - n: 1.5481 - mean_metric: 0.4512 - val_loss: 17.2885 - val_a_1: 2.7849 - val_a_2: 2.7863 - val_b_1: 2.7164 - val_b_2: 2.6987 - val_d_1: 0.7722 - val_d_2: 0.7959 - val_n: 1.5642 - val_mean_metric: 0.4646 - lr: 5.6200e-05
# Epoch 974/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6828 - a_1: 2.8299 - a_2: 2.7871 - b_1: 2.6818 - b_2: 2.7057 - d_1: 0.6050 - d_2: 0.5899 - n: 1.5461 - mean_metric: 0.4510 - val_loss: 17.2785 - val_a_1: 2.7853 - val_a_2: 2.7875 - val_b_1: 2.7166 - val_b_2: 2.6916 - val_d_1: 0.7714 - val_d_2: 0.7989 - val_n: 1.5647 - val_mean_metric: 0.4645 - lr: 5.4550e-05
# Epoch 975/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6492 - a_1: 2.8286 - a_2: 2.7907 - b_1: 2.6771 - b_2: 2.6988 - d_1: 0.5965 - d_2: 0.6007 - n: 1.5512 - mean_metric: 0.4509 - val_loss: 17.3297 - val_a_1: 2.7883 - val_a_2: 2.7862 - val_b_1: 2.7253 - val_b_2: 2.6842 - val_d_1: 0.7743 - val_d_2: 0.8002 - val_n: 1.5654 - val_mean_metric: 0.4648 - lr: 5.2900e-05
# Epoch 976/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7554 - a_1: 2.8310 - a_2: 2.7921 - b_1: 2.6881 - b_2: 2.7029 - d_1: 0.5989 - d_2: 0.6088 - n: 1.5447 - mean_metric: 0.4516 - val_loss: 17.2034 - val_a_1: 2.7864 - val_a_2: 2.7866 - val_b_1: 2.7172 - val_b_2: 2.6902 - val_d_1: 0.7680 - val_d_2: 0.7955 - val_n: 1.5653 - val_mean_metric: 0.4643 - lr: 5.1250e-05
# Epoch 977/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8003 - a_1: 2.8268 - a_2: 2.7906 - b_1: 2.6974 - b_2: 2.6983 - d_1: 0.6040 - d_2: 0.6031 - n: 1.5434 - mean_metric: 0.4516 - val_loss: 17.2469 - val_a_1: 2.7850 - val_a_2: 2.7851 - val_b_1: 2.7184 - val_b_2: 2.6906 - val_d_1: 0.7744 - val_d_2: 0.7939 - val_n: 1.5657 - val_mean_metric: 0.4644 - lr: 4.9600e-05
# Epoch 978/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6867 - a_1: 2.8276 - a_2: 2.7926 - b_1: 2.6906 - b_2: 2.7049 - d_1: 0.5976 - d_2: 0.5994 - n: 1.5451 - mean_metric: 0.4514 - val_loss: 17.2354 - val_a_1: 2.7856 - val_a_2: 2.7846 - val_b_1: 2.7213 - val_b_2: 2.6926 - val_d_1: 0.7716 - val_d_2: 0.7938 - val_n: 1.5657 - val_mean_metric: 0.4645 - lr: 4.7950e-05
# Epoch 979/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6804 - a_1: 2.8309 - a_2: 2.7887 - b_1: 2.6914 - b_2: 2.7024 - d_1: 0.6036 - d_2: 0.5948 - n: 1.5442 - mean_metric: 0.4513 - val_loss: 17.2630 - val_a_1: 2.7853 - val_a_2: 2.7853 - val_b_1: 2.7258 - val_b_2: 2.6849 - val_d_1: 0.7693 - val_d_2: 0.7977 - val_n: 1.5655 - val_mean_metric: 0.4644 - lr: 4.6300e-05
# Epoch 980/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8330 - a_1: 2.8304 - a_2: 2.7905 - b_1: 2.6898 - b_2: 2.7009 - d_1: 0.6021 - d_2: 0.6120 - n: 1.5489 - mean_metric: 0.4519 - val_loss: 17.2158 - val_a_1: 2.7857 - val_a_2: 2.7841 - val_b_1: 2.7194 - val_b_2: 2.6879 - val_d_1: 0.7698 - val_d_2: 0.7949 - val_n: 1.5653 - val_mean_metric: 0.4642 - lr: 4.4650e-05
# Epoch 981/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8258 - a_1: 2.8262 - a_2: 2.7875 - b_1: 2.6904 - b_2: 2.6994 - d_1: 0.6116 - d_2: 0.6022 - n: 1.5395 - mean_metric: 0.4514 - val_loss: 17.1968 - val_a_1: 2.7838 - val_a_2: 2.7846 - val_b_1: 2.7195 - val_b_2: 2.6942 - val_d_1: 0.7677 - val_d_2: 0.7928 - val_n: 1.5643 - val_mean_metric: 0.4642 - lr: 4.3000e-05
# Epoch 982/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7339 - a_1: 2.8266 - a_2: 2.7876 - b_1: 2.6847 - b_2: 2.7110 - d_1: 0.5991 - d_2: 0.6041 - n: 1.5420 - mean_metric: 0.4513 - val_loss: 17.2173 - val_a_1: 2.7829 - val_a_2: 2.7853 - val_b_1: 2.7236 - val_b_2: 2.6886 - val_d_1: 0.7682 - val_d_2: 0.7963 - val_n: 1.5644 - val_mean_metric: 0.4643 - lr: 4.1350e-05
# Epoch 983/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8590 - a_1: 2.8267 - a_2: 2.7890 - b_1: 2.6796 - b_2: 2.6951 - d_1: 0.6152 - d_2: 0.6045 - n: 1.5390 - mean_metric: 0.4511 - val_loss: 17.2268 - val_a_1: 2.7845 - val_a_2: 2.7845 - val_b_1: 2.7263 - val_b_2: 2.6817 - val_d_1: 0.7692 - val_d_2: 0.7974 - val_n: 1.5656 - val_mean_metric: 0.4643 - lr: 3.9700e-05
# Epoch 984/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7595 - a_1: 2.8276 - a_2: 2.7886 - b_1: 2.6897 - b_2: 2.7026 - d_1: 0.6084 - d_2: 0.5976 - n: 1.5454 - mean_metric: 0.4515 - val_loss: 17.2227 - val_a_1: 2.7850 - val_a_2: 2.7850 - val_b_1: 2.7234 - val_b_2: 2.6839 - val_d_1: 0.7690 - val_d_2: 0.7982 - val_n: 1.5659 - val_mean_metric: 0.4643 - lr: 3.8050e-05
# Epoch 985/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6650 - a_1: 2.8279 - a_2: 2.7910 - b_1: 2.6883 - b_2: 2.6949 - d_1: 0.5975 - d_2: 0.6001 - n: 1.5437 - mean_metric: 0.4509 - val_loss: 17.2539 - val_a_1: 2.7849 - val_a_2: 2.7851 - val_b_1: 2.7251 - val_b_2: 2.6903 - val_d_1: 0.7721 - val_d_2: 0.7966 - val_n: 1.5648 - val_mean_metric: 0.4646 - lr: 3.6400e-05
# Epoch 986/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.8016 - a_1: 2.8309 - a_2: 2.7931 - b_1: 2.6925 - b_2: 2.7011 - d_1: 0.6022 - d_2: 0.6088 - n: 1.5529 - mean_metric: 0.4522 - val_loss: 17.2226 - val_a_1: 2.7857 - val_a_2: 2.7856 - val_b_1: 2.7222 - val_b_2: 2.6869 - val_d_1: 0.7689 - val_d_2: 0.7975 - val_n: 1.5643 - val_mean_metric: 0.4643 - lr: 3.4750e-05
# Epoch 987/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7501 - a_1: 2.8287 - a_2: 2.7916 - b_1: 2.6950 - b_2: 2.6915 - d_1: 0.6002 - d_2: 0.6045 - n: 1.5494 - mean_metric: 0.4515 - val_loss: 17.2536 - val_a_1: 2.7863 - val_a_2: 2.7846 - val_b_1: 2.7251 - val_b_2: 2.6872 - val_d_1: 0.7706 - val_d_2: 0.7974 - val_n: 1.5653 - val_mean_metric: 0.4645 - lr: 3.3100e-05
# Epoch 988/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6867 - a_1: 2.8286 - a_2: 2.7898 - b_1: 2.6839 - b_2: 2.7036 - d_1: 0.6027 - d_2: 0.5976 - n: 1.5479 - mean_metric: 0.4512 - val_loss: 17.2355 - val_a_1: 2.7850 - val_a_2: 2.7849 - val_b_1: 2.7245 - val_b_2: 2.6868 - val_d_1: 0.7700 - val_d_2: 0.7989 - val_n: 1.5662 - val_mean_metric: 0.4645 - lr: 3.1450e-05
# Epoch 989/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7862 - a_1: 2.8282 - a_2: 2.7890 - b_1: 2.6903 - b_2: 2.6990 - d_1: 0.6064 - d_2: 0.6027 - n: 1.5380 - mean_metric: 0.4512 - val_loss: 17.2157 - val_a_1: 2.7832 - val_a_2: 2.7842 - val_b_1: 2.7241 - val_b_2: 2.6820 - val_d_1: 0.7692 - val_d_2: 0.7976 - val_n: 1.5663 - val_mean_metric: 0.4642 - lr: 2.9800e-05
# Epoch 990/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7135 - a_1: 2.8261 - a_2: 2.7911 - b_1: 2.6929 - b_2: 2.6999 - d_1: 0.6067 - d_2: 0.6003 - n: 1.5434 - mean_metric: 0.4514 - val_loss: 17.2446 - val_a_1: 2.7828 - val_a_2: 2.7847 - val_b_1: 2.7306 - val_b_2: 2.6860 - val_d_1: 0.7689 - val_d_2: 0.7970 - val_n: 1.5649 - val_mean_metric: 0.4645 - lr: 2.8150e-05
# Epoch 991/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7167 - a_1: 2.8285 - a_2: 2.7901 - b_1: 2.6873 - b_2: 2.7024 - d_1: 0.5913 - d_2: 0.6062 - n: 1.5475 - mean_metric: 0.4512 - val_loss: 17.2308 - val_a_1: 2.7830 - val_a_2: 2.7857 - val_b_1: 2.7247 - val_b_2: 2.6857 - val_d_1: 0.7699 - val_d_2: 0.7970 - val_n: 1.5646 - val_mean_metric: 0.4643 - lr: 2.6500e-05
# Epoch 992/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7421 - a_1: 2.8289 - a_2: 2.7891 - b_1: 2.6823 - b_2: 2.6951 - d_1: 0.6046 - d_2: 0.6020 - n: 1.5480 - mean_metric: 0.4511 - val_loss: 17.2536 - val_a_1: 2.7833 - val_a_2: 2.7840 - val_b_1: 2.7248 - val_b_2: 2.6816 - val_d_1: 0.7712 - val_d_2: 0.7974 - val_n: 1.5648 - val_mean_metric: 0.4642 - lr: 2.4850e-05
# Epoch 993/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6852 - a_1: 2.8260 - a_2: 2.7884 - b_1: 2.6896 - b_2: 2.7032 - d_1: 0.6006 - d_2: 0.5987 - n: 1.5448 - mean_metric: 0.4512 - val_loss: 17.2200 - val_a_1: 2.7833 - val_a_2: 2.7848 - val_b_1: 2.7228 - val_b_2: 2.6859 - val_d_1: 0.7706 - val_d_2: 0.7955 - val_n: 1.5649 - val_mean_metric: 0.4642 - lr: 2.3200e-05
# Epoch 994/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.5685 - a_1: 2.8292 - a_2: 2.7936 - b_1: 2.6908 - b_2: 2.6936 - d_1: 0.5964 - d_2: 0.5973 - n: 1.5435 - mean_metric: 0.4509 - val_loss: 17.2376 - val_a_1: 2.7831 - val_a_2: 2.7846 - val_b_1: 2.7219 - val_b_2: 2.6881 - val_d_1: 0.7705 - val_d_2: 0.7961 - val_n: 1.5648 - val_mean_metric: 0.4643 - lr: 2.1550e-05
# Epoch 995/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6878 - a_1: 2.8272 - a_2: 2.7911 - b_1: 2.6821 - b_2: 2.6964 - d_1: 0.5989 - d_2: 0.5967 - n: 1.5514 - mean_metric: 0.4509 - val_loss: 17.2207 - val_a_1: 2.7831 - val_a_2: 2.7852 - val_b_1: 2.7216 - val_b_2: 2.6888 - val_d_1: 0.7709 - val_d_2: 0.7956 - val_n: 1.5647 - val_mean_metric: 0.4643 - lr: 1.9900e-05
# Epoch 996/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7986 - a_1: 2.8279 - a_2: 2.7903 - b_1: 2.6804 - b_2: 2.6985 - d_1: 0.6060 - d_2: 0.6071 - n: 1.5466 - mean_metric: 0.4514 - val_loss: 17.2355 - val_a_1: 2.7826 - val_a_2: 2.7850 - val_b_1: 2.7251 - val_b_2: 2.6900 - val_d_1: 0.7696 - val_d_2: 0.7966 - val_n: 1.5640 - val_mean_metric: 0.4644 - lr: 1.8250e-05
# Epoch 997/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7209 - a_1: 2.8264 - a_2: 2.7900 - b_1: 2.6912 - b_2: 2.7029 - d_1: 0.6020 - d_2: 0.6010 - n: 1.5425 - mean_metric: 0.4513 - val_loss: 17.2223 - val_a_1: 2.7834 - val_a_2: 2.7853 - val_b_1: 2.7260 - val_b_2: 2.6881 - val_d_1: 0.7687 - val_d_2: 0.7970 - val_n: 1.5640 - val_mean_metric: 0.4644 - lr: 1.6600e-05
# Epoch 998/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6522 - a_1: 2.8281 - a_2: 2.7890 - b_1: 2.6903 - b_2: 2.7019 - d_1: 0.5994 - d_2: 0.5983 - n: 1.5457 - mean_metric: 0.4512 - val_loss: 17.2295 - val_a_1: 2.7833 - val_a_2: 2.7852 - val_b_1: 2.7265 - val_b_2: 2.6901 - val_d_1: 0.7691 - val_d_2: 0.7965 - val_n: 1.5639 - val_mean_metric: 0.4645 - lr: 1.4950e-05
# Epoch 999/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.6953 - a_1: 2.8254 - a_2: 2.7912 - b_1: 2.6976 - b_2: 2.7000 - d_1: 0.5969 - d_2: 0.6041 - n: 1.5445 - mean_metric: 0.4514 - val_loss: 17.2408 - val_a_1: 2.7831 - val_a_2: 2.7852 - val_b_1: 2.7251 - val_b_2: 2.6911 - val_d_1: 0.7703 - val_d_2: 0.7968 - val_n: 1.5646 - val_mean_metric: 0.4645 - lr: 1.3300e-05
# Epoch 1000/1000
# 70/70 [==============================] - 0s 5ms/step - loss: 13.7333 - a_1: 2.8258 - a_2: 2.7909 - b_1: 2.6967 - b_2: 2.7036 - d_1: 0.6024 - d_2: 0.5989 - n: 1.5467 - mean_metric: 0.4516 - val_loss: 17.2234 - val_a_1: 2.7834 - val_a_2: 2.7854 - val_b_1: 2.7250 - val_b_2: 2.6898 - val_d_1: 0.7688 - val_d_2: 0.7977 - val_n: 1.5644 - val_mean_metric: 0.4645 - lr: 1.1650e-05

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(val_epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    campvectest, coefcampvectest)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 17.3185 - a_1: 2.7723 - a_2: 2.8302 - b_1: 2.6035 - b_2: 2.6811 - d_1: 0.7703 - d_2: 0.7874 - n: 1.4852 - mean_metric: 0.4639

# %%
predictions = model.predict(campvectest)
# Out:
# 32/32 [==============================] - 0s 836us/step

# %%
print(coefcampvectest[0,:])
print(predictions[0,:])
from sklearn.metrics import mean_absolute_error
print(np.sum(coefcampvectest, axis=-1))

mae1 = mean_absolute_error(coefcampvectest[0,:], predictions[0,:])
mae1
# Out:
# [ 4  8  1 10  8  7  4]
# [4.173119  4.09608   5.2695875 5.516447  9.097172  6.9154253 2.4230857]
# [42 39 36 35 32 23 38 42 29 19 26 29 39 31 47 33 18 48 31 32 31 30 52 26
#  31 37 41 23 20 33 35 36 30 42 32 37 35 34 34 38 35 32 31 39 37 33 31 39
#  34 30 45 33 36 27 23 33 40 39 37 32 29 44 23 22 35 34 35 38 31 22 40 28
#  25 15 33 19 31 37 47 26 38 37 26 26 31 28 37 30 34 25 25 47 38 24 47 18
#  32 25 28 32 25 35 43 41 33 31 39 35 25 29 31 30 43 24 32 28 35 33 36 39
#  31 29 29 41 32 44 19 28 31 37 36 39 24 28 26 40 28 34 27 20 34 34 28 35
#  36 37 42 30 18 41 32 27 30 31 33 31 31 45 28 52 33 47 31 36 30 43 45 37
#  30 29 46 45 25 30 42 17 33 37 30 30 27 30 25 34 13 23 16 21 37 32 33 26
#  20 44 27 37 28 24 28 41 38 47 23 31 25 46 37 32 21 23 20 43 27 27 23 36
#  24 21 40 36 28 46 48 31 38 37 45 35 30 32 42 33 39 24 24 27 44 27 36 30
#  43 28 31 25 15 30 36 32 33 28 39 29 30 34 33 28 45 40 34 34 32 13 31 36
#  29 34 31 36 26 34 33 39 27 26 36 38 37 24 36 37 32 24 31 40 46 29 44 39
#  44 31 32 41 29 31 43 26 32 39 37 47 25 21 14 32 41 32 40 33 28 42 31 46
#  39 52 46 37 34 41 25 41 41 34 25 34 34 30 54 33 34 27 40 38 24 29 23 17
#  33 29 29 24 33 31 30 33 42 19 31 34 49 57 37 40 28 29 23 21 41 36 29 40
#  26 47 33 30 43 15 18 30 31 52 34 41 32 31 26 36 30 27 36 41 20 33 26 30
#  31 46 44 37 37 26 40 40 34 50 30 43 31 19 39 25 25 25 37 39 31 36 21 36
#  39 38 32 32 24 38 40 35 30 39 18 46 28 39 32 34 32 42 30 28 33 37 36 26
#  30 31 26 23 26 39 29 25 35 24 14 32 34 37 30 36 25 28 26 18 36 41 29 36
#  29 32 35 45 36 31 36 25 29 20 32 29 29 38 32 27 28 33 26 43 29 41 30 37
#  30 43 39 27 24 47 37 25 24 33 54 34 26 28 48 22 42 35 35 30 40 30 38 19
#  34 36 35 15 24 34 25 23 29 28 38 31 31 38 23 19 34 24 45 31 40 22 36 45
#  28 21 36 38 26 34 33 36 27 23 19 33 36 35 21 39 37 34 29 36 33 17 35 21
#  27 34 37 40 26 34 38 43 34 32 23 37 32 23 17 41 36 42 30 19 40 36 37 30
#  28 39 24 31 41 16 32 28 34 40 33 36 34 25 24 25 20 35 26 25 36 26 34 45
#  36 30 25 39 28 35 38 32 25 31 33 19 28 25 27 34 29 33 38 32 24 23 35 34
#  35 46 43 27 35 30 27 15 43 20 29 25 23 29 26 30 36 37 28 14 33 44 40 28
#  31 26 26 44 28 27 31 47 38 26 40 33 30 29 26 21 27 31 15 48 31 38 35 25
#  21 34 36 24 30 25 37 40 39 29 43 12 32 18 28 35 26 40 34 44 28 27 27 28
#  25 23 38 32 34 22 24 41 30 23 46 21 25 21 46 21 24 43 32 38 13 39 45 39
#  29 38 40 38 35 21 36 53 39 31 27 17 38 26 20 42 41 48 50 19 24 17 19 19
#  35 31 11 26 33 25 29 22 41 39 33 51 18 35 27 31 30 41 21 38 42 18 40 42
#  35 27 41 43 33 29 31 26 39 26 35 31 32 36 34 41 33 41 33 25 29 32 42 30
#  31 36 44 25 28 21 43 41 33 24 36 29 37 28 32 35 46 20 31 32 34 22 45 13
#  29 42 27 44 27 31 34 24 36 52 27 42 32 23 23 44 30 19 40 42 34 19 50 43
#  40 30 31 45 34 35 37 31 37 46 21 41 41 27 32 37 15 43 26 24 26 33 29 14
#  34 32 41 33 34 31 17 34 43 18 46 21 29 40 36 33 17 22 37 17 32 24 35 19
#  31 28 28 37 37 46 42 39 40 47 39 40 15 45 23 30 40 17 32 20 29 28 34 31
#  40 26 42 28 36 26 29 41 34 28 33 24 41 21 30 19 27 21 31 32 33 16 36 24
#  36 32 39 30 38 38 35 23 20 45 37 21 47 36 36 43 34 34 49 12 38 39 28 38
#  34 34 36 27 31 27 11 30 25 35 23 35 34 30 31 29 32 33 39 45 50 24 27 29
#  19 37 31 40 39 43 34 33 38 47 34 39 35 28 30 30]
# 2.226977212088449

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefcampvectest, predictions)

# Calcula la desviación estándar del error
error = coefcampvectest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 1.9925551998593978, Desviación estándar del error: 2.5722752827294437, Error absoluto máximo: 7.141513824462891

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefcampvectest - predictions)

# Calcula el error para cada dato
error = coefcampvectest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefcampvectest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.47179305993472637
# Desviación estándar del error relativo: 0.3047176839122211
# Error absoluto máximo relativo: 1.8793572675098071

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales con ruido/History 20,50/historycampvec20funcioncosto.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos con ruido/Modelos 20,50'

# %%
model.save(path_to_save + '/campovectorial20funcioncosto.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
def custom_loss(y_true, y_pred):
    campvec = []
    # constantes
    a1 = tf.cast(y_true[:, 0], tf.float64)
    #tf.print(a1)
    a1 = tf.reshape(a1, shape=(-1, 1, 1))

    a2 = tf.cast(y_true[:, 1], tf.float64)
    a2 = tf.reshape(a2, shape=(-1, 1, 1))
    
    b1 = tf.cast(y_true[:, 2], tf.float64)
    b1 = tf.reshape(b1,shape = (-1,1,1))
    
    b2 = tf.cast(y_true[:, 3], tf.float64)
    b2 = tf.reshape(b2,shape = (-1,1,1))

    d1 = tf.cast(y_true[:, 4], tf.float64)
    d1 = tf.reshape(d1, shape=(-1, 1, 1))

    d2 = tf.cast(y_true[:, 5], tf.float64)
    d2 = tf.reshape(d2, shape=(-1, 1, 1))

    n = tf.cast(y_true[:, 6], tf.float64)
    n = tf.reshape(n, shape=(-1, 1, 1))

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        X = tf.cast(X, tf.float64)
        X = tf.reshape(X, shape=(1, 20,20))
        Y = y[1]
        Y = tf.cast(Y, tf.float64)
        Y = tf.reshape(Y, shape=(1, 20,20))
        
        # definimos cada ODE
        dX_dt = tf.divide(a1,(1 + tf.math.pow(Y, n)+1e-5)) - tf.multiply(d1,X) + b1
        dY_dt = tf.divide(a2,(1 + tf.math.pow(X, n)+1e-7)) - tf.multiply(d2,Y) + b2
        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 20
    y_range_neg = 0
    y_range_pos = 20
    y1 = tf.linspace(x_range_neg, x_range_pos, 20)
    y2 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y1, Y2 = tf.meshgrid(y1, y2)
    t = 0
    u, v = tf.zeros(Y1.shape), tf.zeros(Y2.shape)
    u, v = f(t, [Y1, Y2])
    #M = tf.sqrt(tf.square(u) + tf.square(v))
    #u /= M
    #v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = tf.cast(y_pred[:, 0], tf.float64)
    a12 = tf.reshape(a12, shape=(-1, 1, 1))

    a22 = tf.cast(y_pred[:, 1], tf.float64)
    a22 = tf.reshape(a22, shape=(-1, 1, 1))
    
    b12 = tf.cast(y_pred[:, 2], tf.float64)
    b12 = tf.reshape(b12,shape = (-1,1,1))
    
    b22 = tf.cast(y_pred[:, 3], tf.float64)
    b22 = tf.reshape(b22,shape = (-1,1,1))

    d12 = tf.cast(y_pred[:, 4], tf.float64)
    d12 = tf.reshape(d12, shape=(-1, 1, 1))

    d22 = tf.cast(y_pred[:, 5], tf.float64)
    d22 = tf.reshape(d22, shape=(-1, 1, 1))

    n2 = tf.cast(y_pred[:, 6], tf.float64)
    n2 = tf.reshape(n2, shape=(-1, 1, 1))
    
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        X2 = tf.cast(X2, tf.float64)
        X2 = tf.reshape(X2, shape=(1, 20,20))
        Y2 = ye2[1]
        Y2 = tf.cast(Y2, tf.float64)
        Y2 = tf.reshape(Y2, shape=(1, 20,20))

        # definimos cada ODE
        dX2_dt = tf.divide(a12,(1 + tf.math.pow(Y2, n2)+1e-8)) - tf.multiply(d12,X2) + b12
        dY2_dt = tf.divide(a22,(1 + tf.math.pow(X2, n2)+1e-8)) - tf.multiply(d22,Y2) + b22
        return [dX2_dt, dY2_dt]

    y12 = tf.linspace(x_range_neg, x_range_pos, 20)
    y22 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y12, Y22 = tf.meshgrid(y12, y22)
    u2, v2 = tf.zeros(Y12.shape), tf.zeros(Y22.shape)
    u2, v2 = f2(t, [Y12, Y22])
    #M2 = tf.sqrt(tf.square(u2) + tf.square(v2))
    #u2 /= M2
    #v2 /= M2
    campvecx = tf.abs(tf.subtract(u,u2))
    campvecy = tf.abs(tf.subtract(v,v2))
    campvec_magnitude = tf.add(campvecx,campvecy)
    loss = tf.reduce_mean(campvec_magnitude)
    #tf.print(y_pred)
    return loss

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_activation':custom_activation, 'custom_loss': custom_loss,'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)

# %%
new_model = keras.models.load_model('../../../Modelos/Modelos 20,50/campovectorial20funcioncosto.h5', 
                                     custom_objects= custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 20)
    y2 = np.linspace(y_range_neg, y_range_pos, 20)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)
    contador = contador+1
    print(contador)
    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [3, 8, 3, 4, 1, 5, 3]
# 1

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# [[4.9725375 4.866832  5.406149  5.1622105 1.50568   7.8840957 2.584898 ]]

# %%
new_predictions = (model.predict(campvecnone))
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# [[4.9725375 4.866832  5.406149  5.1622105 1.50568   7.8840957 2.584898 ]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 20)
y2 = np.linspace(0, 10, 20)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
np.shape(new_predictions)
# Out:
# (1, 7)

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1 = np.linspace(x_range_neg, x_range_pos, 20)
y2 = np.linspace(y_range_neg, y_range_pos, 20)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
