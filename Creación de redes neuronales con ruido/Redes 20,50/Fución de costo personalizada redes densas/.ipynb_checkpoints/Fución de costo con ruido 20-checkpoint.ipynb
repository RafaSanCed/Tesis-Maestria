# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_34836\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos con ruido/Campo 20 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 20, 20)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (2000, 2, 20, 20)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (1000, 2, 20, 20)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 20, 20), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creamos función de costo

# %%
def custom_loss(y_true, y_pred):
    campvec = []
    # constantes
    a1 = tf.cast(y_true[:, 0], tf.float64)
    #tf.print(a1)
    a1 = tf.reshape(a1, shape=(-1, 1, 1))

    a2 = tf.cast(y_true[:, 1], tf.float64)
    a2 = tf.reshape(a2, shape=(-1, 1, 1))
    
    b1 = tf.cast(y_true[:, 2], tf.float64)
    b1 = tf.reshape(b1,shape = (-1,1,1))
    
    b2 = tf.cast(y_true[:, 3], tf.float64)
    b2 = tf.reshape(b2,shape = (-1,1,1))

    d1 = tf.cast(y_true[:, 4], tf.float64)
    d1 = tf.reshape(d1, shape=(-1, 1, 1))

    d2 = tf.cast(y_true[:, 5], tf.float64)
    d2 = tf.reshape(d2, shape=(-1, 1, 1))

    n = tf.cast(y_true[:, 6], tf.float64)
    n = tf.reshape(n, shape=(-1, 1, 1))

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        X = tf.cast(X, tf.float64)
        X = tf.reshape(X, shape=(1, 20,20))
        Y = y[1]
        Y = tf.cast(Y, tf.float64)
        Y = tf.reshape(Y, shape=(1, 20,20))
        
        # definimos cada ODE
        dX_dt = tf.divide(a1,(1 + tf.math.pow(Y, n)+1e-5)) - tf.multiply(d1,X) + b1
        dY_dt = tf.divide(a2,(1 + tf.math.pow(X, n)+1e-7)) - tf.multiply(d2,Y) + b2
        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 20
    y_range_neg = 0
    y_range_pos = 20
    y1 = tf.linspace(x_range_neg, x_range_pos, 20)
    y2 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y1, Y2 = tf.meshgrid(y1, y2)
    t = 0
    u, v = tf.zeros(Y1.shape), tf.zeros(Y2.shape)
    u, v = f(t, [Y1, Y2])
    #M = tf.sqrt(tf.square(u) + tf.square(v))
    #u /= M
    #v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = tf.cast(y_pred[:, 0], tf.float64)
    a12 = tf.reshape(a12, shape=(-1, 1, 1))

    a22 = tf.cast(y_pred[:, 1], tf.float64)
    a22 = tf.reshape(a22, shape=(-1, 1, 1))
    
    b12 = tf.cast(y_pred[:, 2], tf.float64)
    b12 = tf.reshape(b12,shape = (-1,1,1))
    
    b22 = tf.cast(y_pred[:, 3], tf.float64)
    b22 = tf.reshape(b22,shape = (-1,1,1))

    d12 = tf.cast(y_pred[:, 4], tf.float64)
    d12 = tf.reshape(d12, shape=(-1, 1, 1))

    d22 = tf.cast(y_pred[:, 5], tf.float64)
    d22 = tf.reshape(d22, shape=(-1, 1, 1))

    n2 = tf.cast(y_pred[:, 6], tf.float64)
    n2 = tf.reshape(n2, shape=(-1, 1, 1))
    
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        X2 = tf.cast(X2, tf.float64)
        X2 = tf.reshape(X2, shape=(1, 20,20))
        Y2 = ye2[1]
        Y2 = tf.cast(Y2, tf.float64)
        Y2 = tf.reshape(Y2, shape=(1, 20,20))

        # definimos cada ODE
        dX2_dt = tf.divide(a12,(1 + tf.math.pow(Y2, n2)+1e-8)) - tf.multiply(d12,X2) + b12
        dY2_dt = tf.divide(a22,(1 + tf.math.pow(X2, n2)+1e-8)) - tf.multiply(d22,Y2) + b22
        return [dX2_dt, dY2_dt]

    y12 = tf.linspace(x_range_neg, x_range_pos, 20)
    y22 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y12, Y22 = tf.meshgrid(y12, y22)
    u2, v2 = tf.zeros(Y12.shape), tf.zeros(Y22.shape)
    u2, v2 = f2(t, [Y12, Y22])
    #M2 = tf.sqrt(tf.square(u2) + tf.square(v2))
    #u2 /= M2
    #v2 /= M2
    campvecx = tf.abs(tf.subtract(u,u2))
    campvecy = tf.abs(tf.subtract(v,v2))
    campvec_magnitude = tf.add(campvecx,campvecy)
    loss = tf.reduce_mean(campvec_magnitude)
    #tf.print(y_pred)
    return loss

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
model.add(Flatten(input_shape=(2, 20, 20)))
model.add(BatchNormalization())
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(50, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(BatchNormalization())
model.add(Dense(50, activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(7))

# %%
model.add(Flatten(input_shape=(2,20,20)))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))

model.add(Dense(7, activation= custom_activation))

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2

# Initialize the model
model = Sequential()

model.add(Flatten(input_shape=(2,20,20)))
# Add Dense Layers
# Dense Layer 1
model.add(Dense(49, activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=l2(0.001)))

# Dense Layer 2
model.add(Dense(126, activation='sigmoid', kernel_initializer='random_normal', kernel_regularizer=l2(0.001)))

# Show the model architecture
model.add(Dense(7, activation= custom_activation))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 800)               0
#
#  dense_6 (Dense)             (None, 49)                39249
#
#  dense_7 (Dense)             (None, 126)               6300
#
#  dense_8 (Dense)             (None, 7)                 889
#
# =================================================================
# Total params: 46,438
# Trainable params: 46,438
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 800)               0
#
#  dense_6 (Dense)             (None, 49)                39249
#
#  dense_7 (Dense)             (None, 126)               6300
#
#  dense_8 (Dense)             (None, 7)                 889
#
# =================================================================
# Total params: 46,438
# Trainable params: 46,438
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= custom_loss,
              metrics=metrics)

# %%
def adaptive_learning_rate(epoch):
    initial_lr = 0.001
    final_lr = 0.0001  # Updated final learning rate
    start_decay_epoch = 100
    end_decay_epoch = 350
    
    if epoch < start_decay_epoch:
        return initial_lr
    elif epoch >= start_decay_epoch and epoch <= end_decay_epoch:
        lr_range = initial_lr - final_lr
        decay_epochs = end_decay_epoch - start_decay_epoch
        decay_per_epoch = lr_range / decay_epochs
        return initial_lr - (epoch - start_decay_epoch) * decay_per_epoch
    else:
        return final_lr
    
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 100,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(adaptive_learning_rate)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 70/70 [==============================] - 1s 7ms/step - loss: 25.1164 - a_1: 2.6112 - a_2: 2.5902 - b_1: 2.6798 - b_2: 2.6351 - d_1: 1.2912 - d_2: 1.3442 - n: 1.3269 - mean_metric: 0.4507 - val_loss: 18.4499 - val_a_1: 2.5728 - val_a_2: 2.5452 - val_b_1: 2.6007 - val_b_2: 2.6723 - val_d_1: 0.9915 - val_d_2: 1.0197 - val_n: 1.3261 - val_mean_metric: 0.4219 - lr: 0.0010
# Epoch 2/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 17.3097 - a_1: 2.5473 - a_2: 2.5573 - b_1: 2.6050 - b_2: 2.6204 - d_1: 0.9288 - d_2: 0.9574 - n: 1.3571 - mean_metric: 0.4224 - val_loss: 16.2046 - val_a_1: 2.4884 - val_a_2: 2.4933 - val_b_1: 2.5573 - val_b_2: 2.6647 - val_d_1: 0.8598 - val_d_2: 0.8971 - val_n: 1.4987 - val_mean_metric: 0.4136 - lr: 0.0010
# Epoch 3/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 16.1001 - a_1: 2.4894 - a_2: 2.5228 - b_1: 2.5654 - b_2: 2.6003 - d_1: 0.8514 - d_2: 0.8821 - n: 1.4133 - mean_metric: 0.4148 - val_loss: 15.7313 - val_a_1: 2.4514 - val_a_2: 2.4724 - val_b_1: 2.5160 - val_b_2: 2.6169 - val_d_1: 0.8564 - val_d_2: 0.8445 - val_n: 1.4858 - val_mean_metric: 0.4070 - lr: 0.0010
# Epoch 4/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 15.5797 - a_1: 2.4608 - a_2: 2.5037 - b_1: 2.5180 - b_2: 2.5579 - d_1: 0.8251 - d_2: 0.8433 - n: 1.3997 - mean_metric: 0.4080 - val_loss: 15.6430 - val_a_1: 2.4080 - val_a_2: 2.4608 - val_b_1: 2.4848 - val_b_2: 2.5714 - val_d_1: 0.8336 - val_d_2: 0.8467 - val_n: 1.4837 - val_mean_metric: 0.4023 - lr: 0.0010
# Epoch 5/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 15.4061 - a_1: 2.4440 - a_2: 2.4853 - b_1: 2.4724 - b_2: 2.5015 - d_1: 0.8199 - d_2: 0.8240 - n: 1.3995 - mean_metric: 0.4030 - val_loss: 15.0262 - val_a_1: 2.3847 - val_a_2: 2.4408 - val_b_1: 2.4385 - val_b_2: 2.4997 - val_d_1: 0.8249 - val_d_2: 0.8016 - val_n: 1.4793 - val_mean_metric: 0.3955 - lr: 0.0010
# Epoch 6/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 15.0855 - a_1: 2.4335 - a_2: 2.4732 - b_1: 2.3957 - b_2: 2.4329 - d_1: 0.8068 - d_2: 0.8044 - n: 1.4186 - mean_metric: 0.3973 - val_loss: 15.3601 - val_a_1: 2.3801 - val_a_2: 2.4337 - val_b_1: 2.3558 - val_b_2: 2.4442 - val_d_1: 0.7977 - val_d_2: 0.8465 - val_n: 1.4775 - val_mean_metric: 0.3914 - lr: 0.0010
# Epoch 7/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 14.9266 - a_1: 2.4287 - a_2: 2.4636 - b_1: 2.3051 - b_2: 2.3671 - d_1: 0.7918 - d_2: 0.8026 - n: 1.4277 - mean_metric: 0.3918 - val_loss: 14.2840 - val_a_1: 2.3720 - val_a_2: 2.4246 - val_b_1: 2.2272 - val_b_2: 2.3380 - val_d_1: 0.7658 - val_d_2: 0.7835 - val_n: 1.5004 - val_mean_metric: 0.3815 - lr: 0.0010
# Epoch 8/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 14.6180 - a_1: 2.4182 - a_2: 2.4524 - b_1: 2.1753 - b_2: 2.2661 - d_1: 0.7818 - d_2: 0.7819 - n: 1.4404 - mean_metric: 0.3834 - val_loss: 14.5252 - val_a_1: 2.3694 - val_a_2: 2.4138 - val_b_1: 2.1378 - val_b_2: 2.2470 - val_d_1: 0.7837 - val_d_2: 0.7838 - val_n: 1.5107 - val_mean_metric: 0.3764 - lr: 0.0010
# Epoch 9/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 14.5808 - a_1: 2.4148 - a_2: 2.4414 - b_1: 2.0594 - b_2: 2.1802 - d_1: 0.7772 - d_2: 0.7789 - n: 1.4537 - mean_metric: 0.3768 - val_loss: 14.4457 - val_a_1: 2.3925 - val_a_2: 2.4007 - val_b_1: 1.9999 - val_b_2: 2.1645 - val_d_1: 0.7658 - val_d_2: 0.7884 - val_n: 1.5065 - val_mean_metric: 0.3694 - lr: 0.0010
# Epoch 10/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 14.4280 - a_1: 2.4187 - a_2: 2.4237 - b_1: 1.9262 - b_2: 2.1021 - d_1: 0.7717 - d_2: 0.7695 - n: 1.4375 - mean_metric: 0.3688 - val_loss: 14.4962 - val_a_1: 2.3929 - val_a_2: 2.3896 - val_b_1: 1.8950 - val_b_2: 2.0757 - val_d_1: 0.7815 - val_d_2: 0.7785 - val_n: 1.5057 - val_mean_metric: 0.3632 - lr: 0.0010
# Epoch 11/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 14.3795 - a_1: 2.4220 - a_2: 2.4119 - b_1: 1.8345 - b_2: 2.0212 - d_1: 0.7667 - d_2: 0.7680 - n: 1.4464 - mean_metric: 0.3633 - val_loss: 14.1253 - val_a_1: 2.4019 - val_a_2: 2.3788 - val_b_1: 1.7929 - val_b_2: 1.9962 - val_d_1: 0.7568 - val_d_2: 0.7623 - val_n: 1.4944 - val_mean_metric: 0.3560 - lr: 0.0010
# Epoch 12/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 14.3504 - a_1: 2.4340 - a_2: 2.4073 - b_1: 1.7417 - b_2: 1.9452 - d_1: 0.7644 - d_2: 0.7641 - n: 1.4379 - mean_metric: 0.3578 - val_loss: 14.5745 - val_a_1: 2.4141 - val_a_2: 2.3721 - val_b_1: 1.7336 - val_b_2: 1.9167 - val_d_1: 0.7705 - val_d_2: 0.7868 - val_n: 1.4872 - val_mean_metric: 0.3529 - lr: 0.0010
# Epoch 13/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 14.1692 - a_1: 2.4387 - a_2: 2.4015 - b_1: 1.6702 - b_2: 1.8751 - d_1: 0.7540 - d_2: 0.7576 - n: 1.4320 - mean_metric: 0.3527 - val_loss: 13.9756 - val_a_1: 2.4200 - val_a_2: 2.3609 - val_b_1: 1.6520 - val_b_2: 1.8410 - val_d_1: 0.7411 - val_d_2: 0.7635 - val_n: 1.5053 - val_mean_metric: 0.3468 - lr: 0.0010
# Epoch 14/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.9627 - a_1: 2.4422 - a_2: 2.3977 - b_1: 1.6157 - b_2: 1.7992 - d_1: 0.7411 - d_2: 0.7491 - n: 1.4508 - mean_metric: 0.3485 - val_loss: 14.0360 - val_a_1: 2.4217 - val_a_2: 2.3508 - val_b_1: 1.6019 - val_b_2: 1.7644 - val_d_1: 0.7362 - val_d_2: 0.7693 - val_n: 1.5175 - val_mean_metric: 0.3430 - lr: 0.0010
# Epoch 15/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.9923 - a_1: 2.4492 - a_2: 2.3953 - b_1: 1.5685 - b_2: 1.7457 - d_1: 0.7476 - d_2: 0.7421 - n: 1.4487 - mean_metric: 0.3454 - val_loss: 13.8962 - val_a_1: 2.4223 - val_a_2: 2.3531 - val_b_1: 1.5638 - val_b_2: 1.7290 - val_d_1: 0.7397 - val_d_2: 0.7537 - val_n: 1.4953 - val_mean_metric: 0.3398 - lr: 0.0010
# Epoch 16/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.8611 - a_1: 2.4502 - a_2: 2.3947 - b_1: 1.5263 - b_2: 1.6924 - d_1: 0.7383 - d_2: 0.7386 - n: 1.4559 - mean_metric: 0.3423 - val_loss: 14.3196 - val_a_1: 2.4328 - val_a_2: 2.3510 - val_b_1: 1.5145 - val_b_2: 1.6800 - val_d_1: 0.7489 - val_d_2: 0.7724 - val_n: 1.5242 - val_mean_metric: 0.3388 - lr: 0.0010
# Epoch 17/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 13.8925 - a_1: 2.4520 - a_2: 2.3971 - b_1: 1.4968 - b_2: 1.6592 - d_1: 0.7393 - d_2: 0.7358 - n: 1.4418 - mean_metric: 0.3400 - val_loss: 13.8319 - val_a_1: 2.4229 - val_a_2: 2.3497 - val_b_1: 1.4982 - val_b_2: 1.6293 - val_d_1: 0.7297 - val_d_2: 0.7500 - val_n: 1.4997 - val_mean_metric: 0.3344 - lr: 0.0010
# Epoch 18/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.7228 - a_1: 2.4513 - a_2: 2.3974 - b_1: 1.4651 - b_2: 1.6032 - d_1: 0.7280 - d_2: 0.7316 - n: 1.4476 - mean_metric: 0.3370 - val_loss: 14.3932 - val_a_1: 2.4395 - val_a_2: 2.3487 - val_b_1: 1.4510 - val_b_2: 1.5903 - val_d_1: 0.7650 - val_d_2: 0.7619 - val_n: 1.5018 - val_mean_metric: 0.3337 - lr: 0.0010
# Epoch 19/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.7970 - a_1: 2.4516 - a_2: 2.4010 - b_1: 1.4434 - b_2: 1.5671 - d_1: 0.7314 - d_2: 0.7323 - n: 1.4348 - mean_metric: 0.3350 - val_loss: 14.5273 - val_a_1: 2.4134 - val_a_2: 2.3588 - val_b_1: 1.4847 - val_b_2: 1.5442 - val_d_1: 0.7627 - val_d_2: 0.7723 - val_n: 1.4726 - val_mean_metric: 0.3322 - lr: 0.0010
# Epoch 20/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.7105 - a_1: 2.4474 - a_2: 2.4035 - b_1: 1.4252 - b_2: 1.5377 - d_1: 0.7266 - d_2: 0.7285 - n: 1.4260 - mean_metric: 0.3329 - val_loss: 13.8959 - val_a_1: 2.4122 - val_a_2: 2.3551 - val_b_1: 1.4364 - val_b_2: 1.4801 - val_d_1: 0.7304 - val_d_2: 0.7501 - val_n: 1.4688 - val_mean_metric: 0.3268 - lr: 0.0010
# Epoch 21/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 13.8025 - a_1: 2.4427 - a_2: 2.4031 - b_1: 1.3987 - b_2: 1.5126 - d_1: 0.7360 - d_2: 0.7261 - n: 1.4157 - mean_metric: 0.3310 - val_loss: 14.3226 - val_a_1: 2.4074 - val_a_2: 2.3573 - val_b_1: 1.4235 - val_b_2: 1.5028 - val_d_1: 0.7575 - val_d_2: 0.7593 - val_n: 1.4526 - val_mean_metric: 0.3276 - lr: 0.0010
# Epoch 22/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.7694 - a_1: 2.4410 - a_2: 2.4025 - b_1: 1.3816 - b_2: 1.4825 - d_1: 0.7355 - d_2: 0.7227 - n: 1.4078 - mean_metric: 0.3292 - val_loss: 14.6280 - val_a_1: 2.4050 - val_a_2: 2.3614 - val_b_1: 1.4133 - val_b_2: 1.4718 - val_d_1: 0.7941 - val_d_2: 0.7516 - val_n: 1.4550 - val_mean_metric: 0.3274 - lr: 0.0010
# Epoch 23/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.6138 - a_1: 2.4364 - a_2: 2.4025 - b_1: 1.3560 - b_2: 1.4523 - d_1: 0.7296 - d_2: 0.7138 - n: 1.4064 - mean_metric: 0.3267 - val_loss: 14.2735 - val_a_1: 2.3949 - val_a_2: 2.3541 - val_b_1: 1.3862 - val_b_2: 1.4480 - val_d_1: 0.7619 - val_d_2: 0.7545 - val_n: 1.4847 - val_mean_metric: 0.3253 - lr: 0.0010
# Epoch 24/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 13.5539 - a_1: 2.4277 - a_2: 2.3990 - b_1: 1.3425 - b_2: 1.4275 - d_1: 0.7192 - d_2: 0.7168 - n: 1.4082 - mean_metric: 0.3250 - val_loss: 13.8877 - val_a_1: 2.4015 - val_a_2: 2.3621 - val_b_1: 1.3346 - val_b_2: 1.3960 - val_d_1: 0.7342 - val_d_2: 0.7385 - val_n: 1.4603 - val_mean_metric: 0.3205 - lr: 0.0010
# Epoch 25/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.4734 - a_1: 2.4208 - a_2: 2.3985 - b_1: 1.3215 - b_2: 1.4119 - d_1: 0.7114 - d_2: 0.7149 - n: 1.4110 - mean_metric: 0.3235 - val_loss: 13.7803 - val_a_1: 2.3915 - val_a_2: 2.3483 - val_b_1: 1.3297 - val_b_2: 1.3862 - val_d_1: 0.7318 - val_d_2: 0.7354 - val_n: 1.4579 - val_mean_metric: 0.3190 - lr: 0.0010
# Epoch 26/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.5058 - a_1: 2.4166 - a_2: 2.3981 - b_1: 1.3075 - b_2: 1.3827 - d_1: 0.7247 - d_2: 0.7031 - n: 1.4110 - mean_metric: 0.3220 - val_loss: 14.3742 - val_a_1: 2.3866 - val_a_2: 2.3597 - val_b_1: 1.3174 - val_b_2: 1.3846 - val_d_1: 0.7747 - val_d_2: 0.7380 - val_n: 1.4492 - val_mean_metric: 0.3199 - lr: 0.0010
# Epoch 27/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.3447 - a_1: 2.4129 - a_2: 2.3969 - b_1: 1.2888 - b_2: 1.3623 - d_1: 0.7091 - d_2: 0.7029 - n: 1.4052 - mean_metric: 0.3199 - val_loss: 13.6823 - val_a_1: 2.3711 - val_a_2: 2.3513 - val_b_1: 1.3052 - val_b_2: 1.3360 - val_d_1: 0.7131 - val_d_2: 0.7395 - val_n: 1.4655 - val_mean_metric: 0.3160 - lr: 0.0010
# Epoch 28/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 13.3492 - a_1: 2.4043 - a_2: 2.3954 - b_1: 1.2842 - b_2: 1.3368 - d_1: 0.7057 - d_2: 0.7046 - n: 1.4087 - mean_metric: 0.3188 - val_loss: 13.8119 - val_a_1: 2.3676 - val_a_2: 2.3492 - val_b_1: 1.3076 - val_b_2: 1.3332 - val_d_1: 0.7323 - val_d_2: 0.7321 - val_n: 1.4589 - val_mean_metric: 0.3160 - lr: 0.0010
# Epoch 29/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.2453 - a_1: 2.3975 - a_2: 2.3902 - b_1: 1.2701 - b_2: 1.3211 - d_1: 0.7016 - d_2: 0.6983 - n: 1.4036 - mean_metric: 0.3170 - val_loss: 13.4516 - val_a_1: 2.3531 - val_a_2: 2.3419 - val_b_1: 1.2840 - val_b_2: 1.3111 - val_d_1: 0.7135 - val_d_2: 0.7176 - val_n: 1.4695 - val_mean_metric: 0.3132 - lr: 0.0010
# Epoch 30/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 13.1409 - a_1: 2.3928 - a_2: 2.3852 - b_1: 1.2560 - b_2: 1.3113 - d_1: 0.6949 - d_2: 0.6942 - n: 1.4109 - mean_metric: 0.3158 - val_loss: 13.3702 - val_a_1: 2.3457 - val_a_2: 2.3403 - val_b_1: 1.2631 - val_b_2: 1.2976 - val_d_1: 0.7016 - val_d_2: 0.7160 - val_n: 1.4512 - val_mean_metric: 0.3109 - lr: 0.0010
# Epoch 31/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 13.1645 - a_1: 2.3829 - a_2: 2.3815 - b_1: 1.2435 - b_2: 1.2974 - d_1: 0.6967 - d_2: 0.6932 - n: 1.4071 - mean_metric: 0.3145 - val_loss: 13.6651 - val_a_1: 2.3481 - val_a_2: 2.3368 - val_b_1: 1.2557 - val_b_2: 1.2904 - val_d_1: 0.7142 - val_d_2: 0.7269 - val_n: 1.4645 - val_mean_metric: 0.3116 - lr: 0.0010
# Epoch 32/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 13.0797 - a_1: 2.3788 - a_2: 2.3780 - b_1: 1.2385 - b_2: 1.2685 - d_1: 0.6910 - d_2: 0.6894 - n: 1.4100 - mean_metric: 0.3129 - val_loss: 13.4430 - val_a_1: 2.3355 - val_a_2: 2.3313 - val_b_1: 1.2941 - val_b_2: 1.2930 - val_d_1: 0.7183 - val_d_2: 0.7074 - val_n: 1.4524 - val_mean_metric: 0.3114 - lr: 0.0010
# Epoch 33/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.9986 - a_1: 2.3728 - a_2: 2.3717 - b_1: 1.2321 - b_2: 1.2597 - d_1: 0.6873 - d_2: 0.6841 - n: 1.4050 - mean_metric: 0.3117 - val_loss: 13.6922 - val_a_1: 2.3332 - val_a_2: 2.3313 - val_b_1: 1.2549 - val_b_2: 1.2752 - val_d_1: 0.7294 - val_d_2: 0.7157 - val_n: 1.4568 - val_mean_metric: 0.3103 - lr: 0.0010
# Epoch 34/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 13.0217 - a_1: 2.3686 - a_2: 2.3669 - b_1: 1.2192 - b_2: 1.2342 - d_1: 0.6888 - d_2: 0.6846 - n: 1.4114 - mean_metric: 0.3105 - val_loss: 13.5907 - val_a_1: 2.3308 - val_a_2: 2.3296 - val_b_1: 1.2459 - val_b_2: 1.2590 - val_d_1: 0.7060 - val_d_2: 0.7307 - val_n: 1.4935 - val_mean_metric: 0.3103 - lr: 0.0010
# Epoch 35/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.9686 - a_1: 2.3634 - a_2: 2.3620 - b_1: 1.2102 - b_2: 1.2287 - d_1: 0.6851 - d_2: 0.6816 - n: 1.4031 - mean_metric: 0.3092 - val_loss: 13.2400 - val_a_1: 2.3212 - val_a_2: 2.3188 - val_b_1: 1.2205 - val_b_2: 1.2300 - val_d_1: 0.6905 - val_d_2: 0.7103 - val_n: 1.4437 - val_mean_metric: 0.3054 - lr: 0.0010
# Epoch 36/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.8772 - a_1: 2.3552 - a_2: 2.3576 - b_1: 1.2023 - b_2: 1.2125 - d_1: 0.6771 - d_2: 0.6795 - n: 1.4058 - mean_metric: 0.3078 - val_loss: 13.0157 - val_a_1: 2.3168 - val_a_2: 2.3116 - val_b_1: 1.2351 - val_b_2: 1.2197 - val_d_1: 0.6801 - val_d_2: 0.7008 - val_n: 1.4437 - val_mean_metric: 0.3045 - lr: 0.0010
# Epoch 37/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.9518 - a_1: 2.3480 - a_2: 2.3518 - b_1: 1.1995 - b_2: 1.2024 - d_1: 0.6862 - d_2: 0.6767 - n: 1.3975 - mean_metric: 0.3071 - val_loss: 13.7606 - val_a_1: 2.3015 - val_a_2: 2.3260 - val_b_1: 1.2534 - val_b_2: 1.2225 - val_d_1: 0.7151 - val_d_2: 0.7324 - val_n: 1.4667 - val_mean_metric: 0.3079 - lr: 0.0010
# Epoch 38/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.9480 - a_1: 2.3462 - a_2: 2.3515 - b_1: 1.1889 - b_2: 1.2077 - d_1: 0.6825 - d_2: 0.6806 - n: 1.4061 - mean_metric: 0.3070 - val_loss: 13.1151 - val_a_1: 2.3040 - val_a_2: 2.3061 - val_b_1: 1.2290 - val_b_2: 1.2051 - val_d_1: 0.6820 - val_d_2: 0.7040 - val_n: 1.4474 - val_mean_metric: 0.3036 - lr: 0.0010
# Epoch 39/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.5946 - a_1: 2.3344 - a_2: 2.3404 - b_1: 1.1822 - b_2: 1.1713 - d_1: 0.6650 - d_2: 0.6624 - n: 1.3989 - mean_metric: 0.3037 - val_loss: 12.8824 - val_a_1: 2.2852 - val_a_2: 2.3021 - val_b_1: 1.1899 - val_b_2: 1.2003 - val_d_1: 0.6672 - val_d_2: 0.6976 - val_n: 1.4319 - val_mean_metric: 0.3004 - lr: 0.0010
# Epoch 40/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.8810 - a_1: 2.3314 - a_2: 2.3365 - b_1: 1.1712 - b_2: 1.1960 - d_1: 0.6766 - d_2: 0.6764 - n: 1.4143 - mean_metric: 0.3052 - val_loss: 13.0150 - val_a_1: 2.2906 - val_a_2: 2.2932 - val_b_1: 1.1953 - val_b_2: 1.2264 - val_d_1: 0.6812 - val_d_2: 0.6920 - val_n: 1.4515 - val_mean_metric: 0.3022 - lr: 0.0010
# Epoch 41/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.6266 - a_1: 2.3247 - a_2: 2.3223 - b_1: 1.1660 - b_2: 1.1604 - d_1: 0.6680 - d_2: 0.6594 - n: 1.4137 - mean_metric: 0.3024 - val_loss: 13.3342 - val_a_1: 2.2916 - val_a_2: 2.2928 - val_b_1: 1.2116 - val_b_2: 1.1674 - val_d_1: 0.6970 - val_d_2: 0.7056 - val_n: 1.4514 - val_mean_metric: 0.3018 - lr: 0.0010
# Epoch 42/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.6379 - a_1: 2.3204 - a_2: 2.3210 - b_1: 1.1634 - b_2: 1.1517 - d_1: 0.6617 - d_2: 0.6678 - n: 1.4169 - mean_metric: 0.3020 - val_loss: 12.9955 - val_a_1: 2.2876 - val_a_2: 2.2793 - val_b_1: 1.1939 - val_b_2: 1.1670 - val_d_1: 0.6768 - val_d_2: 0.6914 - val_n: 1.4434 - val_mean_metric: 0.2994 - lr: 0.0010
# Epoch 43/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.5652 - a_1: 2.3171 - a_2: 2.3143 - b_1: 1.1542 - b_2: 1.1466 - d_1: 0.6579 - d_2: 0.6635 - n: 1.4143 - mean_metric: 0.3010 - val_loss: 12.6686 - val_a_1: 2.2688 - val_a_2: 2.2729 - val_b_1: 1.1664 - val_b_2: 1.1571 - val_d_1: 0.6548 - val_d_2: 0.6821 - val_n: 1.4468 - val_mean_metric: 0.2966 - lr: 0.0010
# Epoch 44/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.4984 - a_1: 2.3086 - a_2: 2.3034 - b_1: 1.1420 - b_2: 1.1245 - d_1: 0.6602 - d_2: 0.6532 - n: 1.4208 - mean_metric: 0.2992 - val_loss: 13.2103 - val_a_1: 2.2772 - val_a_2: 2.2711 - val_b_1: 1.1681 - val_b_2: 1.1702 - val_d_1: 0.7022 - val_d_2: 0.6820 - val_n: 1.4460 - val_mean_metric: 0.2987 - lr: 0.0010
# Epoch 45/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.9653 - a_1: 2.3107 - a_2: 2.3070 - b_1: 1.1410 - b_2: 1.1404 - d_1: 0.6791 - d_2: 0.6782 - n: 1.4256 - mean_metric: 0.3014 - val_loss: 13.2927 - val_a_1: 2.2716 - val_a_2: 2.2692 - val_b_1: 1.2115 - val_b_2: 1.1867 - val_d_1: 0.7055 - val_d_2: 0.6914 - val_n: 1.4539 - val_mean_metric: 0.3009 - lr: 0.0010
# Epoch 46/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.4470 - a_1: 2.3009 - a_2: 2.2949 - b_1: 1.1440 - b_2: 1.1157 - d_1: 0.6585 - d_2: 0.6490 - n: 1.4215 - mean_metric: 0.2984 - val_loss: 13.1669 - val_a_1: 2.2692 - val_a_2: 2.2612 - val_b_1: 1.1658 - val_b_2: 1.1405 - val_d_1: 0.6613 - val_d_2: 0.7130 - val_n: 1.4495 - val_mean_metric: 0.2969 - lr: 0.0010
# Epoch 47/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.6374 - a_1: 2.2968 - a_2: 2.2923 - b_1: 1.1278 - b_2: 1.1031 - d_1: 0.6608 - d_2: 0.6632 - n: 1.4312 - mean_metric: 0.2981 - val_loss: 12.7489 - val_a_1: 2.2641 - val_a_2: 2.2470 - val_b_1: 1.1514 - val_b_2: 1.1335 - val_d_1: 0.6657 - val_d_2: 0.6719 - val_n: 1.4306 - val_mean_metric: 0.2940 - lr: 0.0010
# Epoch 48/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.2931 - a_1: 2.2909 - a_2: 2.2856 - b_1: 1.1163 - b_2: 1.0910 - d_1: 0.6456 - d_2: 0.6450 - n: 1.4348 - mean_metric: 0.2960 - val_loss: 12.6885 - val_a_1: 2.2492 - val_a_2: 2.2516 - val_b_1: 1.1381 - val_b_2: 1.1340 - val_d_1: 0.6492 - val_d_2: 0.6794 - val_n: 1.4381 - val_mean_metric: 0.2932 - lr: 0.0010
# Epoch 49/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.2860 - a_1: 2.2828 - a_2: 2.2748 - b_1: 1.1159 - b_2: 1.0899 - d_1: 0.6450 - d_2: 0.6442 - n: 1.4371 - mean_metric: 0.2954 - val_loss: 12.4031 - val_a_1: 2.2428 - val_a_2: 2.2421 - val_b_1: 1.1264 - val_b_2: 1.1097 - val_d_1: 0.6406 - val_d_2: 0.6633 - val_n: 1.4519 - val_mean_metric: 0.2913 - lr: 0.0010
# Epoch 50/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.6528 - a_1: 2.2840 - a_2: 2.2789 - b_1: 1.1100 - b_2: 1.1089 - d_1: 0.6674 - d_2: 0.6562 - n: 1.4573 - mean_metric: 0.2977 - val_loss: 13.5068 - val_a_1: 2.2475 - val_a_2: 2.2474 - val_b_1: 1.1870 - val_b_2: 1.1410 - val_d_1: 0.7150 - val_d_2: 0.6963 - val_n: 1.4722 - val_mean_metric: 0.2984 - lr: 0.0010
# Epoch 51/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.4877 - a_1: 2.2826 - a_2: 2.2753 - b_1: 1.1163 - b_2: 1.0960 - d_1: 0.6583 - d_2: 0.6486 - n: 1.4498 - mean_metric: 0.2966 - val_loss: 12.7740 - val_a_1: 2.2447 - val_a_2: 2.2399 - val_b_1: 1.1349 - val_b_2: 1.1244 - val_d_1: 0.6563 - val_d_2: 0.6807 - val_n: 1.4572 - val_mean_metric: 0.2932 - lr: 0.0010
# Epoch 52/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.3065 - a_1: 2.2692 - a_2: 2.2638 - b_1: 1.1038 - b_2: 1.0824 - d_1: 0.6500 - d_2: 0.6387 - n: 1.4572 - mean_metric: 0.2946 - val_loss: 12.5494 - val_a_1: 2.2320 - val_a_2: 2.2311 - val_b_1: 1.1283 - val_b_2: 1.1077 - val_d_1: 0.6409 - val_d_2: 0.6730 - val_n: 1.4510 - val_mean_metric: 0.2909 - lr: 0.0010
# Epoch 53/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.3226 - a_1: 2.2682 - a_2: 2.2555 - b_1: 1.0994 - b_2: 1.0678 - d_1: 0.6526 - d_2: 0.6381 - n: 1.4633 - mean_metric: 0.2940 - val_loss: 12.9255 - val_a_1: 2.2318 - val_a_2: 2.2295 - val_b_1: 1.1434 - val_b_2: 1.1139 - val_d_1: 0.6627 - val_d_2: 0.6865 - val_n: 1.4848 - val_mean_metric: 0.2936 - lr: 0.0010
# Epoch 54/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.3371 - a_1: 2.2662 - a_2: 2.2487 - b_1: 1.0926 - b_2: 1.0621 - d_1: 0.6520 - d_2: 0.6383 - n: 1.4778 - mean_metric: 0.2938 - val_loss: 12.9043 - val_a_1: 2.2347 - val_a_2: 2.2173 - val_b_1: 1.1246 - val_b_2: 1.0954 - val_d_1: 0.6608 - val_d_2: 0.6817 - val_n: 1.4604 - val_mean_metric: 0.2912 - lr: 0.0010
# Epoch 55/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.1786 - a_1: 2.2600 - a_2: 2.2431 - b_1: 1.0884 - b_2: 1.0497 - d_1: 0.6441 - d_2: 0.6308 - n: 1.4773 - mean_metric: 0.2924 - val_loss: 12.6894 - val_a_1: 2.2210 - val_a_2: 2.2036 - val_b_1: 1.1348 - val_b_2: 1.0918 - val_d_1: 0.6553 - val_d_2: 0.6724 - val_n: 1.4818 - val_mean_metric: 0.2908 - lr: 0.0010
# Epoch 56/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.2233 - a_1: 2.2537 - a_2: 2.2412 - b_1: 1.0804 - b_2: 1.0517 - d_1: 0.6398 - d_2: 0.6383 - n: 1.4865 - mean_metric: 0.2923 - val_loss: 13.0381 - val_a_1: 2.2298 - val_a_2: 2.1959 - val_b_1: 1.1422 - val_b_2: 1.0964 - val_d_1: 0.6644 - val_d_2: 0.6932 - val_n: 1.5092 - val_mean_metric: 0.2930 - lr: 0.0010
# Epoch 57/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.2245 - a_1: 2.2555 - a_2: 2.2347 - b_1: 1.0858 - b_2: 1.0489 - d_1: 0.6479 - d_2: 0.6303 - n: 1.4952 - mean_metric: 0.2926 - val_loss: 12.9921 - val_a_1: 2.2111 - val_a_2: 2.1990 - val_b_1: 1.1342 - val_b_2: 1.1065 - val_d_1: 0.6800 - val_d_2: 0.6717 - val_n: 1.4843 - val_mean_metric: 0.2916 - lr: 0.0010
# Epoch 58/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.3323 - a_1: 2.2489 - a_2: 2.2283 - b_1: 1.0790 - b_2: 1.0467 - d_1: 0.6420 - d_2: 0.6472 - n: 1.5050 - mean_metric: 0.2925 - val_loss: 12.8376 - val_a_1: 2.2067 - val_a_2: 2.1935 - val_b_1: 1.1043 - val_b_2: 1.0949 - val_d_1: 0.6412 - val_d_2: 0.6874 - val_n: 1.4943 - val_mean_metric: 0.2896 - lr: 0.0010
# Epoch 59/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.1983 - a_1: 2.2484 - a_2: 2.2270 - b_1: 1.0714 - b_2: 1.0381 - d_1: 0.6416 - d_2: 0.6325 - n: 1.5129 - mean_metric: 0.2917 - val_loss: 12.4945 - val_a_1: 2.2034 - val_a_2: 2.1897 - val_b_1: 1.0899 - val_b_2: 1.0897 - val_d_1: 0.6336 - val_d_2: 0.6678 - val_n: 1.5103 - val_mean_metric: 0.2884 - lr: 0.0010
# Epoch 60/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.1390 - a_1: 2.2404 - a_2: 2.2194 - b_1: 1.0614 - b_2: 1.0348 - d_1: 0.6373 - d_2: 0.6309 - n: 1.5168 - mean_metric: 0.2907 - val_loss: 12.5474 - val_a_1: 2.2030 - val_a_2: 2.1897 - val_b_1: 1.0925 - val_b_2: 1.0795 - val_d_1: 0.6405 - val_d_2: 0.6665 - val_n: 1.5321 - val_mean_metric: 0.2891 - lr: 0.0010
# Epoch 61/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.2375 - a_1: 2.2379 - a_2: 2.2195 - b_1: 1.0619 - b_2: 1.0314 - d_1: 0.6455 - d_2: 0.6324 - n: 1.5296 - mean_metric: 0.2913 - val_loss: 12.8721 - val_a_1: 2.1959 - val_a_2: 2.1924 - val_b_1: 1.1119 - val_b_2: 1.0855 - val_d_1: 0.6573 - val_d_2: 0.6849 - val_n: 1.5408 - val_mean_metric: 0.2911 - lr: 0.0010
# Epoch 62/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.0881 - a_1: 2.2287 - a_2: 2.2105 - b_1: 1.0601 - b_2: 1.0213 - d_1: 0.6348 - d_2: 0.6286 - n: 1.5298 - mean_metric: 0.2900 - val_loss: 12.5692 - val_a_1: 2.1878 - val_a_2: 2.1743 - val_b_1: 1.0837 - val_b_2: 1.0674 - val_d_1: 0.6281 - val_d_2: 0.6809 - val_n: 1.5260 - val_mean_metric: 0.2873 - lr: 0.0010
# Epoch 63/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.0605 - a_1: 2.2236 - a_2: 2.2091 - b_1: 1.0554 - b_2: 1.0201 - d_1: 0.6343 - d_2: 0.6250 - n: 1.5325 - mean_metric: 0.2895 - val_loss: 12.4595 - val_a_1: 2.2021 - val_a_2: 2.1718 - val_b_1: 1.1118 - val_b_2: 1.0502 - val_d_1: 0.6465 - val_d_2: 0.6558 - val_n: 1.5402 - val_mean_metric: 0.2883 - lr: 0.0010
# Epoch 64/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.1210 - a_1: 2.2233 - a_2: 2.2002 - b_1: 1.0604 - b_2: 1.0237 - d_1: 0.6357 - d_2: 0.6289 - n: 1.5388 - mean_metric: 0.2898 - val_loss: 12.2989 - val_a_1: 2.1772 - val_a_2: 2.1708 - val_b_1: 1.0618 - val_b_2: 1.0653 - val_d_1: 0.6324 - val_d_2: 0.6495 - val_n: 1.5189 - val_mean_metric: 0.2851 - lr: 0.0010
# Epoch 65/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.0537 - a_1: 2.2181 - a_2: 2.1932 - b_1: 1.0469 - b_2: 1.0191 - d_1: 0.6318 - d_2: 0.6246 - n: 1.5401 - mean_metric: 0.2887 - val_loss: 12.4528 - val_a_1: 2.1733 - val_a_2: 2.1583 - val_b_1: 1.0882 - val_b_2: 1.0707 - val_d_1: 0.6406 - val_d_2: 0.6570 - val_n: 1.5360 - val_mean_metric: 0.2866 - lr: 0.0010
# Epoch 66/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.9869 - a_1: 2.2145 - a_2: 2.1883 - b_1: 1.0469 - b_2: 1.0126 - d_1: 0.6296 - d_2: 0.6226 - n: 1.5520 - mean_metric: 0.2885 - val_loss: 12.2202 - val_a_1: 2.1676 - val_a_2: 2.1552 - val_b_1: 1.0846 - val_b_2: 1.0568 - val_d_1: 0.6199 - val_d_2: 0.6556 - val_n: 1.5335 - val_mean_metric: 0.2850 - lr: 0.0010
# Epoch 67/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.0039 - a_1: 2.2079 - a_2: 2.1835 - b_1: 1.0478 - b_2: 1.0058 - d_1: 0.6288 - d_2: 0.6231 - n: 1.5612 - mean_metric: 0.2882 - val_loss: 12.6571 - val_a_1: 2.1704 - val_a_2: 2.1527 - val_b_1: 1.1287 - val_b_2: 1.0505 - val_d_1: 0.6481 - val_d_2: 0.6718 - val_n: 1.5582 - val_mean_metric: 0.2883 - lr: 0.0010
# Epoch 68/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 12.0428 - a_1: 2.2063 - a_2: 2.1810 - b_1: 1.0503 - b_2: 1.0073 - d_1: 0.6298 - d_2: 0.6263 - n: 1.5683 - mean_metric: 0.2886 - val_loss: 12.3045 - val_a_1: 2.1743 - val_a_2: 2.1289 - val_b_1: 1.0789 - val_b_2: 1.0397 - val_d_1: 0.6269 - val_d_2: 0.6569 - val_n: 1.5464 - val_mean_metric: 0.2844 - lr: 0.0010
# Epoch 69/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.9344 - a_1: 2.1959 - a_2: 2.1702 - b_1: 1.0421 - b_2: 1.0018 - d_1: 0.6256 - d_2: 0.6193 - n: 1.5683 - mean_metric: 0.2872 - val_loss: 12.4411 - val_a_1: 2.1500 - val_a_2: 2.1482 - val_b_1: 1.0678 - val_b_2: 1.0462 - val_d_1: 0.6323 - val_d_2: 0.6608 - val_n: 1.5514 - val_mean_metric: 0.2845 - lr: 0.0010
# Epoch 70/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.9405 - a_1: 2.1953 - a_2: 2.1726 - b_1: 1.0421 - b_2: 1.0053 - d_1: 0.6227 - d_2: 0.6214 - n: 1.5762 - mean_metric: 0.2875 - val_loss: 12.2162 - val_a_1: 2.1445 - val_a_2: 2.1292 - val_b_1: 1.0720 - val_b_2: 1.0705 - val_d_1: 0.6254 - val_d_2: 0.6468 - val_n: 1.5266 - val_mean_metric: 0.2832 - lr: 0.0010
# Epoch 71/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.9987 - a_1: 2.1931 - a_2: 2.1599 - b_1: 1.0346 - b_2: 1.0038 - d_1: 0.6277 - d_2: 0.6220 - n: 1.5773 - mean_metric: 0.2870 - val_loss: 12.1787 - val_a_1: 2.1480 - val_a_2: 2.1221 - val_b_1: 1.0717 - val_b_2: 1.0430 - val_d_1: 0.6195 - val_d_2: 0.6513 - val_n: 1.5520 - val_mean_metric: 0.2830 - lr: 0.0010
# Epoch 72/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.0989 - a_1: 2.1876 - a_2: 2.1649 - b_1: 1.0399 - b_2: 1.0011 - d_1: 0.6329 - d_2: 0.6258 - n: 1.5890 - mean_metric: 0.2877 - val_loss: 13.1498 - val_a_1: 2.1572 - val_a_2: 2.1450 - val_b_1: 1.1049 - val_b_2: 1.0882 - val_d_1: 0.6673 - val_d_2: 0.6906 - val_n: 1.5907 - val_mean_metric: 0.2903 - lr: 0.0010
# Epoch 73/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 12.1536 - a_1: 2.1819 - a_2: 2.1617 - b_1: 1.0392 - b_2: 0.9998 - d_1: 0.6338 - d_2: 0.6307 - n: 1.5942 - mean_metric: 0.2877 - val_loss: 12.4053 - val_a_1: 2.1448 - val_a_2: 2.1249 - val_b_1: 1.0700 - val_b_2: 1.0374 - val_d_1: 0.6235 - val_d_2: 0.6669 - val_n: 1.5667 - val_mean_metric: 0.2838 - lr: 0.0010
# Epoch 74/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.9976 - a_1: 2.1801 - a_2: 2.1488 - b_1: 1.0359 - b_2: 0.9929 - d_1: 0.6298 - d_2: 0.6188 - n: 1.5998 - mean_metric: 0.2866 - val_loss: 12.2699 - val_a_1: 2.1373 - val_a_2: 2.1151 - val_b_1: 1.0626 - val_b_2: 1.0684 - val_d_1: 0.6219 - val_d_2: 0.6537 - val_n: 1.5523 - val_mean_metric: 0.2831 - lr: 0.0010
# Epoch 75/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.8945 - a_1: 2.1730 - a_2: 2.1457 - b_1: 1.0304 - b_2: 0.9979 - d_1: 0.6216 - d_2: 0.6163 - n: 1.6080 - mean_metric: 0.2862 - val_loss: 12.3661 - val_a_1: 2.1237 - val_a_2: 2.1080 - val_b_1: 1.0560 - val_b_2: 1.0402 - val_d_1: 0.6174 - val_d_2: 0.6649 - val_n: 1.5636 - val_mean_metric: 0.2820 - lr: 0.0010
# Epoch 76/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7698 - a_1: 2.1628 - a_2: 2.1366 - b_1: 1.0221 - b_2: 0.9880 - d_1: 0.6129 - d_2: 0.6120 - n: 1.6116 - mean_metric: 0.2847 - val_loss: 12.3031 - val_a_1: 2.1216 - val_a_2: 2.1010 - val_b_1: 1.0692 - val_b_2: 1.0327 - val_d_1: 0.6227 - val_d_2: 0.6567 - val_n: 1.5847 - val_mean_metric: 0.2824 - lr: 0.0010
# Epoch 77/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.9198 - a_1: 2.1635 - a_2: 2.1330 - b_1: 1.0205 - b_2: 0.9914 - d_1: 0.6227 - d_2: 0.6170 - n: 1.6167 - mean_metric: 0.2853 - val_loss: 12.6403 - val_a_1: 2.1206 - val_a_2: 2.0943 - val_b_1: 1.0530 - val_b_2: 1.0408 - val_d_1: 0.6372 - val_d_2: 0.6701 - val_n: 1.6005 - val_mean_metric: 0.2833 - lr: 0.0010
# Epoch 78/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.8429 - a_1: 2.1547 - a_2: 2.1335 - b_1: 1.0249 - b_2: 0.9822 - d_1: 0.6158 - d_2: 0.6169 - n: 1.6174 - mean_metric: 0.2847 - val_loss: 12.1602 - val_a_1: 2.1060 - val_a_2: 2.0846 - val_b_1: 1.0443 - val_b_2: 1.0247 - val_d_1: 0.6143 - val_d_2: 0.6477 - val_n: 1.5862 - val_mean_metric: 0.2799 - lr: 0.0010
# Epoch 79/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7574 - a_1: 2.1456 - a_2: 2.1162 - b_1: 1.0199 - b_2: 0.9834 - d_1: 0.6145 - d_2: 0.6092 - n: 1.6242 - mean_metric: 0.2837 - val_loss: 12.1358 - val_a_1: 2.1000 - val_a_2: 2.0683 - val_b_1: 1.0473 - val_b_2: 1.0556 - val_d_1: 0.6238 - val_d_2: 0.6373 - val_n: 1.5918 - val_mean_metric: 0.2804 - lr: 0.0010
# Epoch 80/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7704 - a_1: 2.1400 - a_2: 2.1154 - b_1: 1.0194 - b_2: 0.9859 - d_1: 0.6135 - d_2: 0.6092 - n: 1.6332 - mean_metric: 0.2838 - val_loss: 12.2552 - val_a_1: 2.1016 - val_a_2: 2.0671 - val_b_1: 1.0364 - val_b_2: 1.0428 - val_d_1: 0.6241 - val_d_2: 0.6466 - val_n: 1.5986 - val_mean_metric: 0.2802 - lr: 0.0010
# Epoch 81/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.8559 - a_1: 2.1383 - a_2: 2.1162 - b_1: 1.0183 - b_2: 0.9833 - d_1: 0.6159 - d_2: 0.6149 - n: 1.6403 - mean_metric: 0.2841 - val_loss: 12.0154 - val_a_1: 2.1028 - val_a_2: 2.0663 - val_b_1: 1.0600 - val_b_2: 1.0281 - val_d_1: 0.6107 - val_d_2: 0.6406 - val_n: 1.6153 - val_mean_metric: 0.2804 - lr: 0.0010
# Epoch 82/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.7354 - a_1: 2.1351 - a_2: 2.1052 - b_1: 1.0215 - b_2: 0.9767 - d_1: 0.6132 - d_2: 0.6065 - n: 1.6490 - mean_metric: 0.2835 - val_loss: 12.7065 - val_a_1: 2.0981 - val_a_2: 2.0703 - val_b_1: 1.0658 - val_b_2: 1.0358 - val_d_1: 0.6553 - val_d_2: 0.6630 - val_n: 1.6371 - val_mean_metric: 0.2836 - lr: 0.0010
# Epoch 83/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.8134 - a_1: 2.1309 - a_2: 2.1118 - b_1: 1.0136 - b_2: 0.9776 - d_1: 0.6175 - d_2: 0.6093 - n: 1.6544 - mean_metric: 0.2838 - val_loss: 12.2424 - val_a_1: 2.0879 - val_a_2: 2.0587 - val_b_1: 1.0441 - val_b_2: 1.0265 - val_d_1: 0.6283 - val_d_2: 0.6419 - val_n: 1.6087 - val_mean_metric: 0.2796 - lr: 0.0010
# Epoch 84/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.7872 - a_1: 2.1207 - a_2: 2.0937 - b_1: 1.0098 - b_2: 0.9765 - d_1: 0.6134 - d_2: 0.6107 - n: 1.6554 - mean_metric: 0.2826 - val_loss: 12.3786 - val_a_1: 2.0759 - val_a_2: 2.0497 - val_b_1: 1.0359 - val_b_2: 1.0284 - val_d_1: 0.6399 - val_d_2: 0.6451 - val_n: 1.6303 - val_mean_metric: 0.2799 - lr: 0.0010
# Epoch 85/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.9261 - a_1: 2.1164 - a_2: 2.0931 - b_1: 1.0167 - b_2: 0.9754 - d_1: 0.6201 - d_2: 0.6177 - n: 1.6606 - mean_metric: 0.2833 - val_loss: 12.5157 - val_a_1: 2.0831 - val_a_2: 2.0493 - val_b_1: 1.0665 - val_b_2: 1.0611 - val_d_1: 0.6374 - val_d_2: 0.6573 - val_n: 1.6225 - val_mean_metric: 0.2821 - lr: 0.0010
# Epoch 86/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.7819 - a_1: 2.1162 - a_2: 2.0924 - b_1: 1.0070 - b_2: 0.9807 - d_1: 0.6135 - d_2: 0.6102 - n: 1.6666 - mean_metric: 0.2829 - val_loss: 12.4889 - val_a_1: 2.0702 - val_a_2: 2.0536 - val_b_1: 1.0435 - val_b_2: 1.0376 - val_d_1: 0.6440 - val_d_2: 0.6484 - val_n: 1.6290 - val_mean_metric: 0.2805 - lr: 0.0010
# Epoch 87/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7638 - a_1: 2.1097 - a_2: 2.0801 - b_1: 1.0098 - b_2: 0.9681 - d_1: 0.6102 - d_2: 0.6106 - n: 1.6746 - mean_metric: 0.2821 - val_loss: 12.3396 - val_a_1: 2.0707 - val_a_2: 2.0447 - val_b_1: 1.0326 - val_b_2: 1.0313 - val_d_1: 0.6204 - val_d_2: 0.6523 - val_n: 1.6415 - val_mean_metric: 0.2795 - lr: 0.0010
# Epoch 88/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.6931 - a_1: 2.1008 - a_2: 2.0722 - b_1: 1.0085 - b_2: 0.9643 - d_1: 0.6080 - d_2: 0.6050 - n: 1.6821 - mean_metric: 0.2815 - val_loss: 12.3927 - val_a_1: 2.0641 - val_a_2: 2.0308 - val_b_1: 1.0307 - val_b_2: 1.0199 - val_d_1: 0.6190 - val_d_2: 0.6577 - val_n: 1.6446 - val_mean_metric: 0.2787 - lr: 0.0010
# Epoch 89/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.8966 - a_1: 2.1013 - a_2: 2.0732 - b_1: 0.9979 - b_2: 0.9735 - d_1: 0.6173 - d_2: 0.6153 - n: 1.6865 - mean_metric: 0.2822 - val_loss: 12.4080 - val_a_1: 2.0595 - val_a_2: 2.0313 - val_b_1: 1.0419 - val_b_2: 1.0212 - val_d_1: 0.6239 - val_d_2: 0.6576 - val_n: 1.6414 - val_mean_metric: 0.2790 - lr: 0.0010
# Epoch 90/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.8706 - a_1: 2.0981 - a_2: 2.0706 - b_1: 1.0003 - b_2: 0.9640 - d_1: 0.6153 - d_2: 0.6139 - n: 1.6890 - mean_metric: 0.2817 - val_loss: 12.4662 - val_a_1: 2.0554 - val_a_2: 2.0378 - val_b_1: 1.0345 - val_b_2: 1.0541 - val_d_1: 0.6262 - val_d_2: 0.6562 - val_n: 1.6297 - val_mean_metric: 0.2795 - lr: 0.0010
# Epoch 91/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7551 - a_1: 2.0881 - a_2: 2.0738 - b_1: 1.0041 - b_2: 0.9656 - d_1: 0.6101 - d_2: 0.6082 - n: 1.6922 - mean_metric: 0.2815 - val_loss: 11.9101 - val_a_1: 2.0402 - val_a_2: 2.0126 - val_b_1: 1.0261 - val_b_2: 1.0074 - val_d_1: 0.6061 - val_d_2: 0.6308 - val_n: 1.6590 - val_mean_metric: 0.2761 - lr: 0.0010
# Epoch 92/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7764 - a_1: 2.0824 - a_2: 2.0634 - b_1: 0.9985 - b_2: 0.9674 - d_1: 0.6098 - d_2: 0.6108 - n: 1.6928 - mean_metric: 0.2810 - val_loss: 12.0874 - val_a_1: 2.0433 - val_a_2: 2.0159 - val_b_1: 1.0279 - val_b_2: 1.0017 - val_d_1: 0.6129 - val_d_2: 0.6396 - val_n: 1.6412 - val_mean_metric: 0.2761 - lr: 0.0010
# Epoch 93/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7486 - a_1: 2.0775 - a_2: 2.0559 - b_1: 1.0000 - b_2: 0.9619 - d_1: 0.6071 - d_2: 0.6097 - n: 1.6914 - mean_metric: 0.2802 - val_loss: 12.3089 - val_a_1: 2.0328 - val_a_2: 2.0147 - val_b_1: 1.0348 - val_b_2: 1.0054 - val_d_1: 0.6282 - val_d_2: 0.6421 - val_n: 1.6481 - val_mean_metric: 0.2768 - lr: 0.0010
# Epoch 94/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.7142 - a_1: 2.0671 - a_2: 2.0458 - b_1: 1.0005 - b_2: 0.9574 - d_1: 0.6067 - d_2: 0.6058 - n: 1.6947 - mean_metric: 0.2795 - val_loss: 12.1079 - val_a_1: 2.0311 - val_a_2: 2.0037 - val_b_1: 1.0287 - val_b_2: 1.0006 - val_d_1: 0.6103 - val_d_2: 0.6416 - val_n: 1.6451 - val_mean_metric: 0.2754 - lr: 0.0010
# Epoch 95/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.6231 - a_1: 2.0639 - a_2: 2.0409 - b_1: 0.9968 - b_2: 0.9573 - d_1: 0.6006 - d_2: 0.6029 - n: 1.7035 - mean_metric: 0.2791 - val_loss: 11.8368 - val_a_1: 2.0175 - val_a_2: 1.9857 - val_b_1: 1.0177 - val_b_2: 0.9965 - val_d_1: 0.6009 - val_d_2: 0.6293 - val_n: 1.6656 - val_mean_metric: 0.2739 - lr: 0.0010
# Epoch 96/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.6746 - a_1: 2.0539 - a_2: 2.0317 - b_1: 0.9912 - b_2: 0.9558 - d_1: 0.6048 - d_2: 0.6039 - n: 1.7129 - mean_metric: 0.2788 - val_loss: 11.8755 - val_a_1: 2.0100 - val_a_2: 1.9832 - val_b_1: 0.9958 - val_b_2: 1.0547 - val_d_1: 0.6000 - val_d_2: 0.6279 - val_n: 1.6618 - val_mean_metric: 0.2745 - lr: 0.0010
# Epoch 97/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.6766 - a_1: 2.0516 - a_2: 2.0278 - b_1: 0.9852 - b_2: 0.9529 - d_1: 0.6064 - d_2: 0.6017 - n: 1.7162 - mean_metric: 0.2783 - val_loss: 12.1917 - val_a_1: 2.0050 - val_a_2: 1.9840 - val_b_1: 1.0160 - val_b_2: 0.9974 - val_d_1: 0.6223 - val_d_2: 0.6367 - val_n: 1.6560 - val_mean_metric: 0.2741 - lr: 0.0010
# Epoch 98/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.6004 - a_1: 2.0412 - a_2: 2.0184 - b_1: 0.9810 - b_2: 0.9469 - d_1: 0.6012 - d_2: 0.5995 - n: 1.7173 - mean_metric: 0.2773 - val_loss: 12.1613 - val_a_1: 2.0084 - val_a_2: 1.9867 - val_b_1: 1.0214 - val_b_2: 1.0207 - val_d_1: 0.6194 - val_d_2: 0.6375 - val_n: 1.6639 - val_mean_metric: 0.2753 - lr: 0.0010
# Epoch 99/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.6538 - a_1: 2.0445 - a_2: 2.0192 - b_1: 0.9895 - b_2: 0.9575 - d_1: 0.6062 - d_2: 0.5999 - n: 1.7247 - mean_metric: 0.2783 - val_loss: 12.1828 - val_a_1: 1.9995 - val_a_2: 1.9833 - val_b_1: 1.0368 - val_b_2: 1.0043 - val_d_1: 0.6266 - val_d_2: 0.6319 - val_n: 1.6705 - val_mean_metric: 0.2751 - lr: 0.0010
# Epoch 100/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.6213 - a_1: 2.0334 - a_2: 2.0113 - b_1: 0.9852 - b_2: 0.9537 - d_1: 0.6011 - d_2: 0.6005 - n: 1.7283 - mean_metric: 0.2774 - val_loss: 11.9952 - val_a_1: 1.9880 - val_a_2: 1.9596 - val_b_1: 1.0256 - val_b_2: 1.0163 - val_d_1: 0.6061 - val_d_2: 0.6326 - val_n: 1.6839 - val_mean_metric: 0.2739 - lr: 0.0010
# Epoch 101/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5525 - a_1: 2.0255 - a_2: 2.0082 - b_1: 0.9892 - b_2: 0.9477 - d_1: 0.5990 - d_2: 0.5963 - n: 1.7264 - mean_metric: 0.2768 - val_loss: 12.0118 - val_a_1: 1.9810 - val_a_2: 1.9535 - val_b_1: 1.0355 - val_b_2: 1.0431 - val_d_1: 0.6084 - val_d_2: 0.6336 - val_n: 1.6773 - val_mean_metric: 0.2745 - lr: 0.0010
# Epoch 102/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.5384 - a_1: 2.0211 - a_2: 2.0067 - b_1: 0.9872 - b_2: 0.9620 - d_1: 0.5985 - d_2: 0.5949 - n: 1.7235 - mean_metric: 0.2769 - val_loss: 11.8090 - val_a_1: 1.9694 - val_a_2: 1.9564 - val_b_1: 0.9978 - val_b_2: 1.0073 - val_d_1: 0.5961 - val_d_2: 0.6234 - val_n: 1.6794 - val_mean_metric: 0.2714 - lr: 9.9640e-04
# Epoch 103/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.5512 - a_1: 2.0108 - a_2: 1.9896 - b_1: 0.9849 - b_2: 0.9528 - d_1: 0.5990 - d_2: 0.5958 - n: 1.7272 - mean_metric: 0.2758 - val_loss: 12.2427 - val_a_1: 1.9728 - val_a_2: 1.9482 - val_b_1: 1.0186 - val_b_2: 1.0066 - val_d_1: 0.6246 - val_d_2: 0.6354 - val_n: 1.6896 - val_mean_metric: 0.2734 - lr: 9.9280e-04
# Epoch 104/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.5355 - a_1: 1.9969 - a_2: 1.9875 - b_1: 0.9850 - b_2: 0.9419 - d_1: 0.5955 - d_2: 0.5972 - n: 1.7368 - mean_metric: 0.2752 - val_loss: 12.3264 - val_a_1: 1.9705 - val_a_2: 1.9480 - val_b_1: 1.0466 - val_b_2: 0.9828 - val_d_1: 0.6070 - val_d_2: 0.6622 - val_n: 1.6889 - val_mean_metric: 0.2737 - lr: 9.8920e-04
# Epoch 105/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5503 - a_1: 2.0009 - a_2: 1.9823 - b_1: 0.9864 - b_2: 0.9419 - d_1: 0.5972 - d_2: 0.5966 - n: 1.7351 - mean_metric: 0.2752 - val_loss: 12.5181 - val_a_1: 1.9665 - val_a_2: 1.9534 - val_b_1: 1.0310 - val_b_2: 1.0188 - val_d_1: 0.6443 - val_d_2: 0.6418 - val_n: 1.6777 - val_mean_metric: 0.2745 - lr: 9.8560e-04
# Epoch 106/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.5919 - a_1: 1.9893 - a_2: 1.9789 - b_1: 0.9875 - b_2: 0.9459 - d_1: 0.5990 - d_2: 0.5976 - n: 1.7370 - mean_metric: 0.2750 - val_loss: 12.0530 - val_a_1: 1.9662 - val_a_2: 1.9407 - val_b_1: 1.0267 - val_b_2: 1.0038 - val_d_1: 0.6144 - val_d_2: 0.6296 - val_n: 1.6821 - val_mean_metric: 0.2724 - lr: 9.8200e-04
# Epoch 107/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5552 - a_1: 1.9847 - a_2: 1.9716 - b_1: 0.9718 - b_2: 0.9484 - d_1: 0.5952 - d_2: 0.5988 - n: 1.7397 - mean_metric: 0.2743 - val_loss: 12.0098 - val_a_1: 1.9513 - val_a_2: 1.9326 - val_b_1: 1.0191 - val_b_2: 1.0155 - val_d_1: 0.6081 - val_d_2: 0.6345 - val_n: 1.6773 - val_mean_metric: 0.2716 - lr: 9.7840e-04
# Epoch 108/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.6015 - a_1: 1.9784 - a_2: 1.9635 - b_1: 0.9776 - b_2: 0.9375 - d_1: 0.5983 - d_2: 0.5991 - n: 1.7445 - mean_metric: 0.2739 - val_loss: 11.9278 - val_a_1: 1.9454 - val_a_2: 1.9235 - val_b_1: 1.0148 - val_b_2: 1.0383 - val_d_1: 0.6059 - val_d_2: 0.6297 - val_n: 1.6961 - val_mean_metric: 0.2721 - lr: 9.7480e-04
# Epoch 109/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7072 - a_1: 1.9744 - a_2: 1.9691 - b_1: 0.9736 - b_2: 0.9548 - d_1: 0.6025 - d_2: 0.6050 - n: 1.7404 - mean_metric: 0.2746 - val_loss: 11.8450 - val_a_1: 1.9338 - val_a_2: 1.9200 - val_b_1: 1.0022 - val_b_2: 0.9775 - val_d_1: 0.5977 - val_d_2: 0.6276 - val_n: 1.6937 - val_mean_metric: 0.2690 - lr: 9.7120e-04
# Epoch 110/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.6012 - a_1: 1.9631 - a_2: 1.9594 - b_1: 0.9729 - b_2: 0.9462 - d_1: 0.5946 - d_2: 0.6028 - n: 1.7462 - mean_metric: 0.2735 - val_loss: 11.8420 - val_a_1: 1.9216 - val_a_2: 1.9118 - val_b_1: 1.0012 - val_b_2: 0.9967 - val_d_1: 0.6008 - val_d_2: 0.6275 - val_n: 1.6741 - val_mean_metric: 0.2684 - lr: 9.6760e-04
# Epoch 111/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7158 - a_1: 1.9655 - a_2: 1.9575 - b_1: 0.9739 - b_2: 0.9417 - d_1: 0.5982 - d_2: 0.6091 - n: 1.7333 - mean_metric: 0.2733 - val_loss: 11.8367 - val_a_1: 1.9058 - val_a_2: 1.9140 - val_b_1: 0.9822 - val_b_2: 0.9924 - val_d_1: 0.5928 - val_d_2: 0.6360 - val_n: 1.6964 - val_mean_metric: 0.2680 - lr: 9.6400e-04
# Epoch 112/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.7040 - a_1: 1.9522 - a_2: 1.9593 - b_1: 0.9705 - b_2: 0.9431 - d_1: 0.6003 - d_2: 0.6062 - n: 1.7401 - mean_metric: 0.2731 - val_loss: 11.7423 - val_a_1: 1.9088 - val_a_2: 1.9110 - val_b_1: 0.9737 - val_b_2: 1.0027 - val_d_1: 0.5978 - val_d_2: 0.6214 - val_n: 1.7156 - val_mean_metric: 0.2683 - lr: 9.6040e-04
# Epoch 113/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.4911 - a_1: 1.9453 - a_2: 1.9430 - b_1: 0.9690 - b_2: 0.9412 - d_1: 0.5930 - d_2: 0.5933 - n: 1.7473 - mean_metric: 0.2718 - val_loss: 11.7658 - val_a_1: 1.8978 - val_a_2: 1.8925 - val_b_1: 0.9782 - val_b_2: 1.0137 - val_d_1: 0.5957 - val_d_2: 0.6247 - val_n: 1.7081 - val_mean_metric: 0.2677 - lr: 9.5680e-04
# Epoch 114/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.5396 - a_1: 1.9351 - a_2: 1.9394 - b_1: 0.9580 - b_2: 0.9408 - d_1: 0.5914 - d_2: 0.5987 - n: 1.7469 - mean_metric: 0.2711 - val_loss: 11.7479 - val_a_1: 1.8915 - val_a_2: 1.9005 - val_b_1: 0.9656 - val_b_2: 0.9729 - val_d_1: 0.5944 - val_d_2: 0.6201 - val_n: 1.7003 - val_mean_metric: 0.2657 - lr: 9.5320e-04
# Epoch 115/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5074 - a_1: 1.9358 - a_2: 1.9347 - b_1: 0.9648 - b_2: 0.9390 - d_1: 0.5904 - d_2: 0.5961 - n: 1.7476 - mean_metric: 0.2711 - val_loss: 11.8007 - val_a_1: 1.9000 - val_a_2: 1.8974 - val_b_1: 0.9843 - val_b_2: 1.0084 - val_d_1: 0.5955 - val_d_2: 0.6254 - val_n: 1.7006 - val_mean_metric: 0.2677 - lr: 9.4960e-04
# Epoch 116/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5119 - a_1: 1.9281 - a_2: 1.9293 - b_1: 0.9662 - b_2: 0.9391 - d_1: 0.5952 - d_2: 0.5924 - n: 1.7451 - mean_metric: 0.2707 - val_loss: 11.6852 - val_a_1: 1.8921 - val_a_2: 1.8788 - val_b_1: 0.9835 - val_b_2: 1.0005 - val_d_1: 0.5956 - val_d_2: 0.6168 - val_n: 1.7004 - val_mean_metric: 0.2664 - lr: 9.4600e-04
# Epoch 117/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.4344 - a_1: 1.9218 - a_2: 1.9238 - b_1: 0.9612 - b_2: 0.9290 - d_1: 0.5914 - d_2: 0.5879 - n: 1.7476 - mean_metric: 0.2697 - val_loss: 11.7111 - val_a_1: 1.8660 - val_a_2: 1.8841 - val_b_1: 0.9695 - val_b_2: 0.9876 - val_d_1: 0.5948 - val_d_2: 0.6183 - val_n: 1.7030 - val_mean_metric: 0.2650 - lr: 9.4240e-04
# Epoch 118/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5900 - a_1: 1.9167 - a_2: 1.9244 - b_1: 0.9591 - b_2: 0.9408 - d_1: 0.5984 - d_2: 0.5950 - n: 1.7511 - mean_metric: 0.2704 - val_loss: 11.7152 - val_a_1: 1.8696 - val_a_2: 1.8662 - val_b_1: 0.9653 - val_b_2: 0.9789 - val_d_1: 0.5934 - val_d_2: 0.6205 - val_n: 1.7085 - val_mean_metric: 0.2644 - lr: 9.3880e-04
# Epoch 119/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5954 - a_1: 1.9096 - a_2: 1.9205 - b_1: 0.9627 - b_2: 0.9336 - d_1: 0.6019 - d_2: 0.5928 - n: 1.7542 - mean_metric: 0.2701 - val_loss: 11.8116 - val_a_1: 1.8749 - val_a_2: 1.8752 - val_b_1: 0.9823 - val_b_2: 0.9777 - val_d_1: 0.6019 - val_d_2: 0.6188 - val_n: 1.6874 - val_mean_metric: 0.2649 - lr: 9.3520e-04
# Epoch 120/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5879 - a_1: 1.9074 - a_2: 1.9250 - b_1: 0.9536 - b_2: 0.9346 - d_1: 0.6008 - d_2: 0.5924 - n: 1.7582 - mean_metric: 0.2700 - val_loss: 11.7870 - val_a_1: 1.8656 - val_a_2: 1.8665 - val_b_1: 0.9689 - val_b_2: 0.9736 - val_d_1: 0.6007 - val_d_2: 0.6150 - val_n: 1.7016 - val_mean_metric: 0.2640 - lr: 9.3160e-04
# Epoch 121/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 11.5314 - a_1: 1.9000 - a_2: 1.9091 - b_1: 0.9552 - b_2: 0.9313 - d_1: 0.5979 - d_2: 0.5905 - n: 1.7429 - mean_metric: 0.2685 - val_loss: 11.7076 - val_a_1: 1.8570 - val_a_2: 1.8629 - val_b_1: 0.9789 - val_b_2: 0.9816 - val_d_1: 0.5968 - val_d_2: 0.6156 - val_n: 1.7034 - val_mean_metric: 0.2642 - lr: 9.2800e-04
# Epoch 122/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.5605 - a_1: 1.8964 - a_2: 1.9102 - b_1: 0.9629 - b_2: 0.9281 - d_1: 0.5970 - d_2: 0.5931 - n: 1.7485 - mean_metric: 0.2689 - val_loss: 11.8376 - val_a_1: 1.8628 - val_a_2: 1.8638 - val_b_1: 0.9837 - val_b_2: 0.9854 - val_d_1: 0.6018 - val_d_2: 0.6209 - val_n: 1.6941 - val_mean_metric: 0.2647 - lr: 9.2440e-04
# Epoch 123/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.5284 - a_1: 1.8944 - a_2: 1.9152 - b_1: 0.9590 - b_2: 0.9361 - d_1: 0.5932 - d_2: 0.5941 - n: 1.7539 - mean_metric: 0.2692 - val_loss: 11.6831 - val_a_1: 1.8560 - val_a_2: 1.8573 - val_b_1: 0.9714 - val_b_2: 0.9907 - val_d_1: 0.5921 - val_d_2: 0.6175 - val_n: 1.6934 - val_mean_metric: 0.2636 - lr: 9.2080e-04
# Epoch 124/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 11.3830 - a_1: 1.8782 - a_2: 1.8987 - b_1: 0.9613 - b_2: 0.9343 - d_1: 0.5891 - d_2: 0.5838 - n: 1.7522 - mean_metric: 0.2676 - val_loss: 11.6636 - val_a_1: 1.8389 - val_a_2: 1.8503 - val_b_1: 0.9582 - val_b_2: 0.9797 - val_d_1: 0.5912 - val_d_2: 0.6179 - val_n: 1.7225 - val_mean_metric: 0.2630 - lr: 9.1720e-04
# Epoch 125/1000
# ...
# Epoch 413/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7896 - a_1: 1.3110 - a_2: 1.4635 - b_1: 0.8243 - b_2: 0.8054 - d_1: 0.4951 - d_2: 0.4955 - n: 1.7077 - mean_metric: 0.2211 - val_loss: 11.5191 - val_a_1: 1.3336 - val_a_2: 1.4168 - val_b_1: 0.8525 - val_b_2: 0.8586 - val_d_1: 0.5697 - val_d_2: 0.5985 - val_n: 1.6661 - val_mean_metric: 0.2243 - lr: 1.0000e-04
# Epoch 414/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7887 - a_1: 1.3108 - a_2: 1.4634 - b_1: 0.8234 - b_2: 0.8057 - d_1: 0.4947 - d_2: 0.4957 - n: 1.7067 - mean_metric: 0.2211 - val_loss: 11.5032 - val_a_1: 1.3352 - val_a_2: 1.4159 - val_b_1: 0.8538 - val_b_2: 0.8587 - val_d_1: 0.5697 - val_d_2: 0.5972 - val_n: 1.6664 - val_mean_metric: 0.2244 - lr: 1.0000e-04
# Epoch 415/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7864 - a_1: 1.3114 - a_2: 1.4624 - b_1: 0.8235 - b_2: 0.8050 - d_1: 0.4948 - d_2: 0.4953 - n: 1.7057 - mean_metric: 0.2210 - val_loss: 11.5063 - val_a_1: 1.3342 - val_a_2: 1.4160 - val_b_1: 0.8548 - val_b_2: 0.8587 - val_d_1: 0.5696 - val_d_2: 0.5977 - val_n: 1.6653 - val_mean_metric: 0.2243 - lr: 1.0000e-04
# Epoch 416/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7786 - a_1: 1.3104 - a_2: 1.4630 - b_1: 0.8233 - b_2: 0.8051 - d_1: 0.4941 - d_2: 0.4952 - n: 1.7062 - mean_metric: 0.2209 - val_loss: 11.5239 - val_a_1: 1.3333 - val_a_2: 1.4143 - val_b_1: 0.8555 - val_b_2: 0.8581 - val_d_1: 0.5699 - val_d_2: 0.5989 - val_n: 1.6636 - val_mean_metric: 0.2243 - lr: 1.0000e-04
# Epoch 417/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7888 - a_1: 1.3109 - a_2: 1.4621 - b_1: 0.8245 - b_2: 0.8060 - d_1: 0.4950 - d_2: 0.4954 - n: 1.7068 - mean_metric: 0.2211 - val_loss: 11.5151 - val_a_1: 1.3331 - val_a_2: 1.4152 - val_b_1: 0.8556 - val_b_2: 0.8589 - val_d_1: 0.5705 - val_d_2: 0.5977 - val_n: 1.6641 - val_mean_metric: 0.2243 - lr: 1.0000e-04
# Epoch 418/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7902 - a_1: 1.3113 - a_2: 1.4615 - b_1: 0.8239 - b_2: 0.8052 - d_1: 0.4950 - d_2: 0.4955 - n: 1.7053 - mean_metric: 0.2210 - val_loss: 11.5123 - val_a_1: 1.3339 - val_a_2: 1.4148 - val_b_1: 0.8556 - val_b_2: 0.8578 - val_d_1: 0.5702 - val_d_2: 0.5978 - val_n: 1.6652 - val_mean_metric: 0.2243 - lr: 1.0000e-04
# Epoch 419/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7934 - a_1: 1.3100 - a_2: 1.4605 - b_1: 0.8237 - b_2: 0.8045 - d_1: 0.4953 - d_2: 0.4956 - n: 1.7058 - mean_metric: 0.2209 - val_loss: 11.5137 - val_a_1: 1.3331 - val_a_2: 1.4141 - val_b_1: 0.8538 - val_b_2: 0.8578 - val_d_1: 0.5693 - val_d_2: 0.5986 - val_n: 1.6654 - val_mean_metric: 0.2242 - lr: 1.0000e-04
# Epoch 420/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7755 - a_1: 1.3090 - a_2: 1.4617 - b_1: 0.8225 - b_2: 0.8042 - d_1: 0.4940 - d_2: 0.4950 - n: 1.7055 - mean_metric: 0.2208 - val_loss: 11.5136 - val_a_1: 1.3333 - val_a_2: 1.4149 - val_b_1: 0.8541 - val_b_2: 0.8582 - val_d_1: 0.5701 - val_d_2: 0.5979 - val_n: 1.6649 - val_mean_metric: 0.2243 - lr: 1.0000e-04
# Epoch 421/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7755 - a_1: 1.3111 - a_2: 1.4604 - b_1: 0.8227 - b_2: 0.8045 - d_1: 0.4937 - d_2: 0.4950 - n: 1.7047 - mean_metric: 0.2209 - val_loss: 11.5189 - val_a_1: 1.3335 - val_a_2: 1.4144 - val_b_1: 0.8567 - val_b_2: 0.8572 - val_d_1: 0.5707 - val_d_2: 0.5980 - val_n: 1.6645 - val_mean_metric: 0.2243 - lr: 1.0000e-04
# Epoch 422/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7721 - a_1: 1.3094 - a_2: 1.4605 - b_1: 0.8233 - b_2: 0.8046 - d_1: 0.4938 - d_2: 0.4948 - n: 1.7048 - mean_metric: 0.2208 - val_loss: 11.5136 - val_a_1: 1.3327 - val_a_2: 1.4139 - val_b_1: 0.8555 - val_b_2: 0.8575 - val_d_1: 0.5702 - val_d_2: 0.5979 - val_n: 1.6638 - val_mean_metric: 0.2242 - lr: 1.0000e-04
# Epoch 423/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7752 - a_1: 1.3084 - a_2: 1.4588 - b_1: 0.8229 - b_2: 0.8044 - d_1: 0.4940 - d_2: 0.4949 - n: 1.7042 - mean_metric: 0.2207 - val_loss: 11.5146 - val_a_1: 1.3324 - val_a_2: 1.4135 - val_b_1: 0.8538 - val_b_2: 0.8577 - val_d_1: 0.5702 - val_d_2: 0.5978 - val_n: 1.6643 - val_mean_metric: 0.2241 - lr: 1.0000e-04
# Epoch 424/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7806 - a_1: 1.3092 - a_2: 1.4588 - b_1: 0.8230 - b_2: 0.8046 - d_1: 0.4947 - d_2: 0.4946 - n: 1.7032 - mean_metric: 0.2207 - val_loss: 11.5192 - val_a_1: 1.3328 - val_a_2: 1.4125 - val_b_1: 0.8549 - val_b_2: 0.8582 - val_d_1: 0.5703 - val_d_2: 0.5982 - val_n: 1.6626 - val_mean_metric: 0.2241 - lr: 1.0000e-04
# Epoch 425/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7785 - a_1: 1.3086 - a_2: 1.4578 - b_1: 0.8225 - b_2: 0.8046 - d_1: 0.4946 - d_2: 0.4946 - n: 1.7035 - mean_metric: 0.2207 - val_loss: 11.5114 - val_a_1: 1.3319 - val_a_2: 1.4117 - val_b_1: 0.8545 - val_b_2: 0.8585 - val_d_1: 0.5695 - val_d_2: 0.5982 - val_n: 1.6630 - val_mean_metric: 0.2241 - lr: 1.0000e-04
# Epoch 426/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7844 - a_1: 1.3088 - a_2: 1.4584 - b_1: 0.8231 - b_2: 0.8053 - d_1: 0.4947 - d_2: 0.4951 - n: 1.7033 - mean_metric: 0.2207 - val_loss: 11.5154 - val_a_1: 1.3315 - val_a_2: 1.4113 - val_b_1: 0.8556 - val_b_2: 0.8580 - val_d_1: 0.5700 - val_d_2: 0.5980 - val_n: 1.6625 - val_mean_metric: 0.2241 - lr: 1.0000e-04
# Epoch 427/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7824 - a_1: 1.3088 - a_2: 1.4578 - b_1: 0.8241 - b_2: 0.8056 - d_1: 0.4946 - d_2: 0.4950 - n: 1.7022 - mean_metric: 0.2207 - val_loss: 11.5138 - val_a_1: 1.3319 - val_a_2: 1.4116 - val_b_1: 0.8554 - val_b_2: 0.8580 - val_d_1: 0.5695 - val_d_2: 0.5984 - val_n: 1.6624 - val_mean_metric: 0.2241 - lr: 1.0000e-04
# Epoch 428/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7769 - a_1: 1.3077 - a_2: 1.4568 - b_1: 0.8230 - b_2: 0.8045 - d_1: 0.4943 - d_2: 0.4947 - n: 1.7020 - mean_metric: 0.2205 - val_loss: 11.5094 - val_a_1: 1.3322 - val_a_2: 1.4118 - val_b_1: 0.8553 - val_b_2: 0.8571 - val_d_1: 0.5699 - val_d_2: 0.5976 - val_n: 1.6641 - val_mean_metric: 0.2241 - lr: 1.0000e-04
# Epoch 429/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7733 - a_1: 1.3075 - a_2: 1.4588 - b_1: 0.8229 - b_2: 0.8050 - d_1: 0.4941 - d_2: 0.4945 - n: 1.7014 - mean_metric: 0.2205 - val_loss: 11.5064 - val_a_1: 1.3322 - val_a_2: 1.4125 - val_b_1: 0.8550 - val_b_2: 0.8579 - val_d_1: 0.5693 - val_d_2: 0.5978 - val_n: 1.6623 - val_mean_metric: 0.2241 - lr: 1.0000e-04
# Epoch 430/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7723 - a_1: 1.3092 - a_2: 1.4558 - b_1: 0.8227 - b_2: 0.8055 - d_1: 0.4940 - d_2: 0.4946 - n: 1.7008 - mean_metric: 0.2205 - val_loss: 11.5307 - val_a_1: 1.3323 - val_a_2: 1.4105 - val_b_1: 0.8544 - val_b_2: 0.8576 - val_d_1: 0.5713 - val_d_2: 0.5987 - val_n: 1.6618 - val_mean_metric: 0.2240 - lr: 1.0000e-04
# Epoch 431/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7666 - a_1: 1.3077 - a_2: 1.4569 - b_1: 0.8228 - b_2: 0.8040 - d_1: 0.4937 - d_2: 0.4941 - n: 1.7001 - mean_metric: 0.2204 - val_loss: 11.5180 - val_a_1: 1.3300 - val_a_2: 1.4103 - val_b_1: 0.8537 - val_b_2: 0.8582 - val_d_1: 0.5698 - val_d_2: 0.5984 - val_n: 1.6610 - val_mean_metric: 0.2239 - lr: 1.0000e-04
# Epoch 432/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7716 - a_1: 1.3070 - a_2: 1.4557 - b_1: 0.8225 - b_2: 0.8042 - d_1: 0.4941 - d_2: 0.4942 - n: 1.7009 - mean_metric: 0.2204 - val_loss: 11.5242 - val_a_1: 1.3313 - val_a_2: 1.4093 - val_b_1: 0.8547 - val_b_2: 0.8576 - val_d_1: 0.5702 - val_d_2: 0.5986 - val_n: 1.6612 - val_mean_metric: 0.2239 - lr: 1.0000e-04
# Epoch 433/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7638 - a_1: 1.3076 - a_2: 1.4551 - b_1: 0.8222 - b_2: 0.8036 - d_1: 0.4936 - d_2: 0.4937 - n: 1.7004 - mean_metric: 0.2203 - val_loss: 11.5097 - val_a_1: 1.3317 - val_a_2: 1.4094 - val_b_1: 0.8546 - val_b_2: 0.8573 - val_d_1: 0.5694 - val_d_2: 0.5980 - val_n: 1.6616 - val_mean_metric: 0.2239 - lr: 1.0000e-04
# Epoch 434/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7701 - a_1: 1.3074 - a_2: 1.4550 - b_1: 0.8228 - b_2: 0.8044 - d_1: 0.4939 - d_2: 0.4942 - n: 1.6997 - mean_metric: 0.2204 - val_loss: 11.5114 - val_a_1: 1.3307 - val_a_2: 1.4095 - val_b_1: 0.8517 - val_b_2: 0.8569 - val_d_1: 0.5690 - val_d_2: 0.5986 - val_n: 1.6612 - val_mean_metric: 0.2238 - lr: 1.0000e-04
# Epoch 435/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7629 - a_1: 1.3065 - a_2: 1.4546 - b_1: 0.8215 - b_2: 0.8042 - d_1: 0.4934 - d_2: 0.4941 - n: 1.6985 - mean_metric: 0.2202 - val_loss: 11.5084 - val_a_1: 1.3297 - val_a_2: 1.4093 - val_b_1: 0.8534 - val_b_2: 0.8572 - val_d_1: 0.5695 - val_d_2: 0.5977 - val_n: 1.6607 - val_mean_metric: 0.2238 - lr: 1.0000e-04
# Epoch 436/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7606 - a_1: 1.3051 - a_2: 1.4543 - b_1: 0.8226 - b_2: 0.8035 - d_1: 0.4934 - d_2: 0.4939 - n: 1.6982 - mean_metric: 0.2202 - val_loss: 11.5052 - val_a_1: 1.3294 - val_a_2: 1.4080 - val_b_1: 0.8528 - val_b_2: 0.8576 - val_d_1: 0.5689 - val_d_2: 0.5980 - val_n: 1.6610 - val_mean_metric: 0.2237 - lr: 1.0000e-04
# Epoch 437/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7568 - a_1: 1.3062 - a_2: 1.4540 - b_1: 0.8223 - b_2: 0.8041 - d_1: 0.4930 - d_2: 0.4938 - n: 1.6985 - mean_metric: 0.2202 - val_loss: 11.5284 - val_a_1: 1.3312 - val_a_2: 1.4083 - val_b_1: 0.8554 - val_b_2: 0.8577 - val_d_1: 0.5711 - val_d_2: 0.5985 - val_n: 1.6612 - val_mean_metric: 0.2239 - lr: 1.0000e-04
# Epoch 438/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7557 - a_1: 1.3057 - a_2: 1.4531 - b_1: 0.8228 - b_2: 0.8038 - d_1: 0.4930 - d_2: 0.4936 - n: 1.6974 - mean_metric: 0.2201 - val_loss: 11.5029 - val_a_1: 1.3289 - val_a_2: 1.4071 - val_b_1: 0.8516 - val_b_2: 0.8567 - val_d_1: 0.5685 - val_d_2: 0.5981 - val_n: 1.6597 - val_mean_metric: 0.2236 - lr: 1.0000e-04
# Epoch 439/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7469 - a_1: 1.3051 - a_2: 1.4534 - b_1: 0.8218 - b_2: 0.8031 - d_1: 0.4926 - d_2: 0.4933 - n: 1.6977 - mean_metric: 0.2200 - val_loss: 11.5152 - val_a_1: 1.3295 - val_a_2: 1.4082 - val_b_1: 0.8504 - val_b_2: 0.8576 - val_d_1: 0.5694 - val_d_2: 0.5982 - val_n: 1.6597 - val_mean_metric: 0.2236 - lr: 1.0000e-04
# Epoch 440/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7505 - a_1: 1.3047 - a_2: 1.4527 - b_1: 0.8214 - b_2: 0.8040 - d_1: 0.4928 - d_2: 0.4933 - n: 1.6979 - mean_metric: 0.2200 - val_loss: 11.5248 - val_a_1: 1.3306 - val_a_2: 1.4075 - val_b_1: 0.8555 - val_b_2: 0.8574 - val_d_1: 0.5716 - val_d_2: 0.5975 - val_n: 1.6611 - val_mean_metric: 0.2239 - lr: 1.0000e-04
# Epoch 441/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7587 - a_1: 1.3053 - a_2: 1.4527 - b_1: 0.8223 - b_2: 0.8037 - d_1: 0.4929 - d_2: 0.4937 - n: 1.6965 - mean_metric: 0.2200 - val_loss: 11.5054 - val_a_1: 1.3293 - val_a_2: 1.4073 - val_b_1: 0.8562 - val_b_2: 0.8563 - val_d_1: 0.5691 - val_d_2: 0.5981 - val_n: 1.6589 - val_mean_metric: 0.2237 - lr: 1.0000e-04
# Epoch 442/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 9.7472 - a_1: 1.3044 - a_2: 1.4531 - b_1: 0.8220 - b_2: 0.8033 - d_1: 0.4925 - d_2: 0.4932 - n: 1.6968 - mean_metric: 0.2200 - val_loss: 11.5025 - val_a_1: 1.3288 - val_a_2: 1.4074 - val_b_1: 0.8536 - val_b_2: 0.8580 - val_d_1: 0.5685 - val_d_2: 0.5981 - val_n: 1.6596 - val_mean_metric: 0.2237 - lr: 1.0000e-04
# Epoch 443/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7431 - a_1: 1.3056 - a_2: 1.4517 - b_1: 0.8218 - b_2: 0.8039 - d_1: 0.4922 - d_2: 0.4930 - n: 1.6960 - mean_metric: 0.2199 - val_loss: 11.5128 - val_a_1: 1.3299 - val_a_2: 1.4071 - val_b_1: 0.8556 - val_b_2: 0.8563 - val_d_1: 0.5705 - val_d_2: 0.5978 - val_n: 1.6600 - val_mean_metric: 0.2238 - lr: 1.0000e-04
# Epoch 444/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7499 - a_1: 1.3056 - a_2: 1.4511 - b_1: 0.8230 - b_2: 0.8029 - d_1: 0.4928 - d_2: 0.4931 - n: 1.6970 - mean_metric: 0.2200 - val_loss: 11.5131 - val_a_1: 1.3289 - val_a_2: 1.4055 - val_b_1: 0.8531 - val_b_2: 0.8569 - val_d_1: 0.5691 - val_d_2: 0.5985 - val_n: 1.6591 - val_mean_metric: 0.2236 - lr: 1.0000e-04
# Epoch 445/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7389 - a_1: 1.3049 - a_2: 1.4499 - b_1: 0.8214 - b_2: 0.8034 - d_1: 0.4921 - d_2: 0.4927 - n: 1.6962 - mean_metric: 0.2198 - val_loss: 11.5138 - val_a_1: 1.3275 - val_a_2: 1.4041 - val_b_1: 0.8516 - val_b_2: 0.8562 - val_d_1: 0.5686 - val_d_2: 0.5987 - val_n: 1.6576 - val_mean_metric: 0.2234 - lr: 1.0000e-04
# Epoch 446/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7325 - a_1: 1.3038 - a_2: 1.4506 - b_1: 0.8220 - b_2: 0.8031 - d_1: 0.4917 - d_2: 0.4926 - n: 1.6949 - mean_metric: 0.2198 - val_loss: 11.5172 - val_a_1: 1.3278 - val_a_2: 1.4038 - val_b_1: 0.8541 - val_b_2: 0.8579 - val_d_1: 0.5696 - val_d_2: 0.5985 - val_n: 1.6577 - val_mean_metric: 0.2235 - lr: 1.0000e-04
# Epoch 447/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7345 - a_1: 1.3041 - a_2: 1.4491 - b_1: 0.8220 - b_2: 0.8036 - d_1: 0.4918 - d_2: 0.4926 - n: 1.6948 - mean_metric: 0.2198 - val_loss: 11.5142 - val_a_1: 1.3267 - val_a_2: 1.4035 - val_b_1: 0.8511 - val_b_2: 0.8569 - val_d_1: 0.5690 - val_d_2: 0.5985 - val_n: 1.6567 - val_mean_metric: 0.2233 - lr: 1.0000e-04
# Epoch 448/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 9.7309 - a_1: 1.3035 - a_2: 1.4477 - b_1: 0.8218 - b_2: 0.8026 - d_1: 0.4918 - d_2: 0.4923 - n: 1.6942 - mean_metric: 0.2196 - val_loss: 11.5142 - val_a_1: 1.3275 - val_a_2: 1.4047 - val_b_1: 0.8544 - val_b_2: 0.8563 - val_d_1: 0.5697 - val_d_2: 0.5982 - val_n: 1.6593 - val_mean_metric: 0.2235 - lr: 1.0000e-04
# Epoch 449/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7315 - a_1: 1.3030 - a_2: 1.4487 - b_1: 0.8214 - b_2: 0.8028 - d_1: 0.4914 - d_2: 0.4924 - n: 1.6937 - mean_metric: 0.2196 - val_loss: 11.4970 - val_a_1: 1.3279 - val_a_2: 1.4039 - val_b_1: 0.8526 - val_b_2: 0.8573 - val_d_1: 0.5681 - val_d_2: 0.5976 - val_n: 1.6582 - val_mean_metric: 0.2234 - lr: 1.0000e-04
# Epoch 450/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7347 - a_1: 1.3032 - a_2: 1.4486 - b_1: 0.8216 - b_2: 0.8031 - d_1: 0.4917 - d_2: 0.4926 - n: 1.6940 - mean_metric: 0.2196 - val_loss: 11.5045 - val_a_1: 1.3279 - val_a_2: 1.4044 - val_b_1: 0.8522 - val_b_2: 0.8567 - val_d_1: 0.5688 - val_d_2: 0.5979 - val_n: 1.6572 - val_mean_metric: 0.2234 - lr: 1.0000e-04
# Epoch 451/1000
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7433 - a_1: 1.3033 - a_2: 1.4487 - b_1: 0.8212 - b_2: 0.8027 - d_1: 0.4924 - d_2: 0.4927 - n: 1.6932 - mean_metric: 0.2196 - val_loss: 11.5284 - val_a_1: 1.3282 - val_a_2: 1.4029 - val_b_1: 0.8545 - val_b_2: 0.8564 - val_d_1: 0.5704 - val_d_2: 0.5987 - val_n: 1.6563 - val_mean_metric: 0.2235 - lr: 1.0000e-04
# Epoch 452/1000
# 48/70 [===================>..........] - ETA: 0s - loss: 9.8028 - a_1: 1.2997 - a_2: 1.4545 - b_1: 0.8169 - b_2: 0.8054 - d_1: 0.4913 - d_2: 0.5001 - n: 1.6901 - mean_metric: 0.2200Restoring model weights from the end of the best epoch: 352.
# 70/70 [==============================] - 0s 2ms/step - loss: 9.7363 - a_1: 1.3022 - a_2: 1.4471 - b_1: 0.8219 - b_2: 0.8025 - d_1: 0.4918 - d_2: 0.4925 - n: 1.6935 - mean_metric: 0.2195 - val_loss: 11.5138 - val_a_1: 1.3275 - val_a_2: 1.4033 - val_b_1: 0.8546 - val_b_2: 0.8564 - val_d_1: 0.5704 - val_d_2: 0.5973 - val_n: 1.6574 - val_mean_metric: 0.2234 - lr: 1.0000e-04
# Epoch 452: early stopping

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(452)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    campvectest, coefcampvectest)
# Out:
# 63/63 [==============================] - 1s 1ms/step - loss: 11.8285 - a_1: 1.3385 - a_2: 1.4431 - b_1: 0.8813 - b_2: 0.8656 - d_1: 0.6094 - d_2: 0.5990 - n: 1.7055 - mean_metric: 0.2323

# %%
predictions = model.predict(campvectest)
# Out:
# 63/63 [==============================] - 0s 487us/step

# %%
print(coefcampvectest[0,:])
print(predictions[0,:])
from sklearn.metrics import mean_absolute_error
print(np.sum(coefcampvectest, axis=-1))

mae1 = mean_absolute_error(coefcampvectest[0,:], predictions[0,:])
mae1
# Out:
# [2 3 3 0 7 2 4]
# [1.5436381 1.6746035 3.659616  0.7049761 9.376869  2.951168  3.512204 ]
# [21 34 35 ... 36 44 35]
# 0.9945976904460362

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefcampvectest, predictions)

# Calcula la desviación estándar del error
error = coefcampvectest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 1.0631251067298166, Desviación estándar del error: 1.4441522597578527, Error absoluto máximo: 7.072739601135254

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefcampvectest - predictions)

# Calcula el error para cada dato
error = coefcampvectest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefcampvectest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.24042723531531499
# Desviación estándar del error relativo: 0.2151059872187845
# Error absoluto máximo relativo: 1.967426795225877

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales con ruido/History 20,50/historycampvec20funcioncosto.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos con ruido/Modelos 20,50'

# %%
model.save(path_to_save + '/campovectorial20funcioncosto.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
def custom_loss(y_true, y_pred):
    campvec = []
    # constantes
    a1 = tf.cast(y_true[:, 0], tf.float64)
    #tf.print(a1)
    a1 = tf.reshape(a1, shape=(-1, 1, 1))

    a2 = tf.cast(y_true[:, 1], tf.float64)
    a2 = tf.reshape(a2, shape=(-1, 1, 1))
    
    b1 = tf.cast(y_true[:, 2], tf.float64)
    b1 = tf.reshape(b1,shape = (-1,1,1))
    
    b2 = tf.cast(y_true[:, 3], tf.float64)
    b2 = tf.reshape(b2,shape = (-1,1,1))

    d1 = tf.cast(y_true[:, 4], tf.float64)
    d1 = tf.reshape(d1, shape=(-1, 1, 1))

    d2 = tf.cast(y_true[:, 5], tf.float64)
    d2 = tf.reshape(d2, shape=(-1, 1, 1))

    n = tf.cast(y_true[:, 6], tf.float64)
    n = tf.reshape(n, shape=(-1, 1, 1))

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        X = tf.cast(X, tf.float64)
        X = tf.reshape(X, shape=(1, 20,20))
        Y = y[1]
        Y = tf.cast(Y, tf.float64)
        Y = tf.reshape(Y, shape=(1, 20,20))
        
        # definimos cada ODE
        dX_dt = tf.divide(a1,(1 + tf.math.pow(Y, n)+1e-5)) - tf.multiply(d1,X) + b1
        dY_dt = tf.divide(a2,(1 + tf.math.pow(X, n)+1e-7)) - tf.multiply(d2,Y) + b2
        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 20
    y_range_neg = 0
    y_range_pos = 20
    y1 = tf.linspace(x_range_neg, x_range_pos, 20)
    y2 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y1, Y2 = tf.meshgrid(y1, y2)
    t = 0
    u, v = tf.zeros(Y1.shape), tf.zeros(Y2.shape)
    u, v = f(t, [Y1, Y2])
    #M = tf.sqrt(tf.square(u) + tf.square(v))
    #u /= M
    #v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = tf.cast(y_pred[:, 0], tf.float64)
    a12 = tf.reshape(a12, shape=(-1, 1, 1))

    a22 = tf.cast(y_pred[:, 1], tf.float64)
    a22 = tf.reshape(a22, shape=(-1, 1, 1))
    
    b12 = tf.cast(y_pred[:, 2], tf.float64)
    b12 = tf.reshape(b12,shape = (-1,1,1))
    
    b22 = tf.cast(y_pred[:, 3], tf.float64)
    b22 = tf.reshape(b22,shape = (-1,1,1))

    d12 = tf.cast(y_pred[:, 4], tf.float64)
    d12 = tf.reshape(d12, shape=(-1, 1, 1))

    d22 = tf.cast(y_pred[:, 5], tf.float64)
    d22 = tf.reshape(d22, shape=(-1, 1, 1))

    n2 = tf.cast(y_pred[:, 6], tf.float64)
    n2 = tf.reshape(n2, shape=(-1, 1, 1))
    
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        X2 = tf.cast(X2, tf.float64)
        X2 = tf.reshape(X2, shape=(1, 20,20))
        Y2 = ye2[1]
        Y2 = tf.cast(Y2, tf.float64)
        Y2 = tf.reshape(Y2, shape=(1, 20,20))

        # definimos cada ODE
        dX2_dt = tf.divide(a12,(1 + tf.math.pow(Y2, n2)+1e-8)) - tf.multiply(d12,X2) + b12
        dY2_dt = tf.divide(a22,(1 + tf.math.pow(X2, n2)+1e-8)) - tf.multiply(d22,Y2) + b22
        return [dX2_dt, dY2_dt]

    y12 = tf.linspace(x_range_neg, x_range_pos, 20)
    y22 = tf.linspace(y_range_neg, y_range_pos, 20)
    Y12, Y22 = tf.meshgrid(y12, y22)
    u2, v2 = tf.zeros(Y12.shape), tf.zeros(Y22.shape)
    u2, v2 = f2(t, [Y12, Y22])
    #M2 = tf.sqrt(tf.square(u2) + tf.square(v2))
    #u2 /= M2
    #v2 /= M2
    campvecx = tf.abs(tf.subtract(u,u2))
    campvecy = tf.abs(tf.subtract(v,v2))
    campvec_magnitude = tf.add(campvecx,campvecy)
    loss = tf.reduce_mean(campvec_magnitude)
    #tf.print(y_pred)
    return loss

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_activation':custom_activation, 'custom_loss': custom_loss,'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)

# %%
new_model = keras.models.load_model('../../../Modelos con ruido/Modelos 20,50/campovectorial20funcioncosto.h5', 
                                     custom_objects= custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random 
import matplotlib.pyplot as plt
for i in range(0, 1):
    # constantes
    a1 = random.randint(1, 10)
    a2 = random.randint(1, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(1, 5)

    coef = [a1, a2, b1, b2, d1, d2, n]

    for i_ci in range(0, 1):
        x_range_neg = 0
        x_range_pos = 10
        y_range_neg = 0
        y_range_pos =10

        y1 = np.linspace(x_range_neg, x_range_pos, 20)
        y2 = np.linspace(y_range_neg, y_range_pos, 20)

        Y1, Y2 = np.meshgrid(y1, y2)

        t1 = 0

        NI, NJ = Y1.shape
        u, v = np.zeros((NI, NJ)), np.zeros((NI, NJ))

        for i in range(NI):
            for j in range(NJ):
                # asignar a cada ODE a un elemento de vector
                X = Y1[i, j]
                Y = Y2[i, j]
                noise1 = np.random.normal(0, .5)
                noise2 = np.random.normal(0, .5)

                # definimos cada ODE
                dX_dt=(a1)/(1+Y**(n))-(d1)*X+b1+noise1
                dY_dt=(a2)/(1+X**(n))-(d2)*Y+b2+noise2

                u[i, j], v[i, j] = dX_dt, dY_dt

        M = (np.hypot(u, v))
        u1, v1 = u, v
        u /= M
        v /= M

    campvecci = np.append([u], [v], axis=0)

    campvec = campvecci
    print(coef)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# [9, 6, 4, 0, 9, 6, 3]

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [[8. 4. 4. 1. 9. 6. 5.]]

# %% [markdown]
# ## Encontreamos puntos de equilibrio datos reales

# %%
from scipy.optimize import fsolve
# Sistema de ecuaciones
def system(Y):
    X, Y = Y
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b2
    return [dX_dt, dY_dt]

# Adivinanza inicial para X, Y
initial_guess = [0, 0]

# Encontrar los puntos de equilibrio
primer_cuadrante_reales = fsolve(system, initial_guess)
primer_cuadrante_reales = tuple(primer_cuadrante_reales)


print(primer_cuadrante_reales)
# Out:
# (1.3313417222689017, 0.29530189968306175)

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
import matplotlib.pyplot as plt

x_values = primer_cuadrante_reales[0]
y_values =primer_cuadrante_reales[1]

y1 = np.linspace(0, 10, 20)
y2 = np.linspace(0, 10, 20)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.scatter(x_values, y_values, color='red')  # Puedes cambiar el color como prefieras
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
plt.show()

# %%
np.shape(new_predictions)
# Out:
# (1, 7)

# %% [markdown]
# ## Encotnramos puntos de equilibrio datos predecidos

# %%
a1pred = new_predictions[0,0]
a2pred = new_predictions[0,1]
b1pred = new_predictions[0,2]
b2pred = new_predictions[0,3]
d1pred = new_predictions[0,4]
d2pred = new_predictions[0,5]
npred = new_predictions[0,6]

def systempred(Ypred):
    Xpred, Ypred = Ypred
    dXpred_dt = a1pred/(1+Ypred**npred)-d1pred*Xpred+b1pred
    dYpred_dt = a2pred/(1+Xpred**npred)-d2pred*Ypred+b2pred
    return [dXpred_dt, dYpred_dt]

# Adivinanza inicial para X, Y
initial_guesspred = [0, 0]

# Encontrar los puntos de equilibrio
primer_cuadrante_predecidos = fsolve(systempred, initial_guesspred)
primer_cuadrante_predecidos = tuple(primer_cuadrante_predecidos)


print(primer_cuadrante_predecidos)
# Out:
# (1.3313417222689017, 0.29530189968306175)

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
import matplotlib.pyplot as plt

def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1pred/(1+Y**npred)-d1pred*X+b1pred
    dY_dt = a2pred/(1+X**npred)-d2pred*Y+b2pred

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1pred = np.linspace(x_range_neg, x_range_pos, 20)
y2pred = np.linspace(y_range_neg, y_range_pos, 20)

Y1pred, Y2pred = np.meshgrid(y1pred, y2pred)
    
t1 = 0

upred, vpred = np.zeros(Y1pred.shape), np.zeros(Y2pred.shape)

NI, NJ = Y1.shape

u1pred, v1pred = f(t1, [Y1, Y2])
upred, vpred = f(t1, [Y1, Y2])
Mpred = (np.hypot(upred, vpred))
upred /= Mpred
vpred /= Mpred


x_valuespred = primer_cuadrante_predecidos[0]
y_valuespred =primer_cuadrante_predecidos[1]
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, upred, vpred, Mpred, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.scatter(x_valuespred, y_valuespred, color='red')  # Puedes cambiar el color como prefieras
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %% [markdown]
# ## Graficamos ambos

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Primero graficamos la predicción, que debería ser más clara (alpha < 1)
Q = ax.quiver(Y1, Y2, upred, vpred, Mpred, angles='xy', alpha=0.5)

# Luego, graficamos los datos originales, que serán más oscuros (alpha = 1)
Q1 = ax.quiver(Y1, Y2, u, v, M, angles='xy', alpha=1)

ax.scatter(x_valuespred, y_valuespred, color='red', alpha = 0.5)
ax.scatter(x_values, y_values, color='red', alpha = 1)
ax.set_title('Comparación prediccionees con datos reales', fontsize=20)
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('Concentración X')
ax.set_ylabel('Concentración Y')

plt.show()

# %% [markdown]
# ## Graficamos las diferencias

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Calculamos las diferencias
u_diff = u - upred
v_diff = v - vpred

# Aseguramos que ningún vector tenga una magnitud exactamente igual a cero
epsilon = 1e-7
u_diff2 = u_diff + epsilon
v_diff2 = v_diff + epsilon

# Ahora calculamos la magnitud
#M_diff = np.hypot(u_diff2, v_diff2)
M_diff = np.hypot(u_diff, v_diff)

#Calcula la magnitud de los vectores
magnitudes = np.sqrt(u_diff**2 + v_diff**2)

# Calcula el rango de las magnitudes
rango = (np.max(magnitudes) - np.min(magnitudes))*30
print(rango)
# Escala para las flechas. Aumenta este valor si las flechas son demasiado grandes.
scale = 70

# Graficamos las diferencias
#Q = ax.quiver(Y1, Y2, u_diff2, v_diff2, M_diff, angles='xy')
Q = ax.quiver(Y1, Y2, u_diff, v_diff, M_diff, angles='xy', scale = rango)
#Q = ax.quiver(Y1, Y2, u_diff, v_diff, M_diff, angles='xy')


ax.set_title('Diferencias entre campos vectoriales', fontsize=20)
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('Concentración X')
ax.set_ylabel('Concentración Y')

# Creamos una leyenda para la magnitud de las flechas
cbar = plt.colorbar(Q, ax=ax)
cbar.set_label('Magnitud de la diferencia')

plt.show()
# Out:
# 14.057229916701909

# %% [markdown]
# ## Errores relativos

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Calculamos las diferencias
u_diff = u - upred
v_diff = v - vpred

# Aseguramos que ningún vector tenga una magnitud exactamente igual a cero
epsilon = 1e-7

# Calculamos la magnitud del vector original y de la diferencia
M_orig = np.hypot(u1, v1) + epsilon
M_diff = np.hypot(u1pred, v1pred)

# Calculamos la diferencia relativa
M_diff_rel = M_diff / M_orig

#Calcula la magnitud de los vectores
magnitudes = np.sqrt(u_diff**2 + v_diff**2)

# Calcula el rango de las magnitudes
rango = (np.max(magnitudes) - np.min(magnitudes))*30

# Graficamos las diferencias relativas
Q = ax.quiver(Y1, Y2, u_diff, v_diff, M_diff_rel, angles='xy', scale = rango)

ax.set_title('Diferencias relativas entre campos vectoriales', fontsize=20)
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('Concentración X')
ax.set_ylabel('Concentración Y')

# Creamos una leyenda para la magnitud de las flechas
cbar = plt.colorbar(Q, ax=ax)
cbar.set_label('Magnitud de la diferencia relativa')

plt.show()

# %%
# Calculamos las diferencias
u_diff = u - upred
v_diff = v - vpred

# Aseguramos que ningún vector tenga una magnitud exactamente igual a cero
epsilon = 1e-7

# Calculamos la magnitud del vector original y de la diferencia
M_orig = np.hypot(u, v) + epsilon
M_diff = np.hypot(u_diff, v_diff)

# Calculamos la diferencia relativa
M_diff_rel = M_diff / M_orig

# Aplicamos el filtro para la diferencia relativa mayor a 0.05
mask = M_diff_rel > 0.05

# Calculamos el porcentaje de puntos que cumplen con la condición
porcentaje = np.mean(mask) * 100

print(f"El porcentaje de puntos cuyo error relativo es mayor a 0.05 es {porcentaje:.2f}%")
# Out:
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 es 8.25%

# %% [markdown]
# ## Simulamos n veces

# %%
import numpy as np
import random
from scipy.optimize import fsolve

# Listas para almacenar los resultados
porcentajes = []

# Repetimos el proceso 10 veces
for repetir in range(10000):
    campvec = []
    coef = []
    # constantes
    a1 = random.randint(1, 10)
    a2 = random.randint(1, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(1, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def ftrue(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b2

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 20)
    y2 = np.linspace(y_range_neg, y_range_pos, 20)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape
    
    
    for i in range(NI):
        for j in range(NJ):
            # asignar a cada ODE a un elemento de vector
            X = Y1[i, j]
            Y = Y2[i, j]
            noise1 = np.random.normal(0, .5)
            noise2 = np.random.normal(0, .5)
            # definimos cada ODE
            dX_dt=(a1)/(1+Y**(n))-(d1)*X+b1+noise1
            dY_dt=(a2)/(1+X**(n))-(d2)*Y+b2+noise2
            u[i, j], v[i, j] = dX_dt, dY_dt

    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u], [v], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
#    print(coef1)
    
    campvec = np.array(campvec)

    
    campvecnone = campvec[None, :]
    
    new_predictions = new_model.predict(campvecnone)
    new_predictions = np.round(new_predictions)
    new_predictions = np.clip(new_predictions, 0, None)
#    print(new_predictions)
    
    
    a1pred = new_predictions[0,0]
    a2pred = new_predictions[0,1]
    b1pred = new_predictions[0,2]
    b2pred = new_predictions[0,3]
    d1pred = new_predictions[0,4]
    d2pred = new_predictions[0,5]
    npred = new_predictions[0,6]
    
    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        dX_dt = a1pred/(1+Y**npred)-d1pred*X+b1pred
        dY_dt = a2pred/(1+X**npred)-d2pred*Y+b2pred

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1pred = np.linspace(x_range_neg, x_range_pos, 20)
    y2pred = np.linspace(y_range_neg, y_range_pos, 20)

    Y1pred, Y2pred = np.meshgrid(y1pred, y2pred)
    
    t1 = 0

    upred, vpred = np.zeros(Y1pred.shape), np.zeros(Y2pred.shape)

    NI, NJ = Y1.shape

    u1pred, v1pred = f(t1, [Y1, Y2])
    upred, vpred = f(t1, [Y1, Y2])
    Mpred = (np.hypot(upred, vpred))
    upred /= Mpred
    vpred /= Mpred
    
    utrue, vtrue = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    utrue, vtrue = ftrue(t1, [Y1, Y2])
    Mtrue = (np.hypot(utrue, vtrue))
    utrue /= Mtrue
    vtrue /= Mtrue  

 # Calculamos las diferencias
    u_diff = utrue - upred
    v_diff = vtrue - vpred

    # Aseguramos que ningún vector tenga una magnitud exactamente igual a cero
    epsilon = 1e-7

    # Calculamos la magnitud del vector original y de la diferencia
    M_orig = np.hypot(u, v) + epsilon
    M_diff = np.hypot(u_diff, v_diff)

    # Calculamos la diferencia relativa
    M_diff_rel = M_diff / M_orig

    # Aplicamos el filtro para la diferencia relativa mayor a 0.05
    mask = M_diff_rel > 0.05

    # Calculamos el porcentaje de puntos que cumplen con la condición
    porcentaje = np.mean(mask) * 100

    # Almacenamos el resultado en la lista
    porcentajes.append(porcentaje)

    print(f"El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración {repetir+1} es {porcentaje:.2f}%")

# Muestra todos los porcentajes al final
print("Porcentajes para las 10 iteraciones:", porcentajes)

# Calcula y muestra el promedio de los porcentajes
promedio = np.mean(porcentajes)
print(f"El promedio de los porcentajes es {promedio:.2f}%")
# Out:
# --------------------------------------------
# 1/1 [==============================] - 0s 161ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 1 es 5.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 59ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 2 es 23.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 85ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 3 es 35.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 48ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 4 es 71.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 56ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 5 es 75.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 6 es 20.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 66ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 7 es 14.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 53ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 8 es 13.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 56ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9 es 24.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 10 es 30.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 52ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 11 es 26.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 59ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 12 es 25.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 13 es 21.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 14 es 22.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 15 es 25.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 16 es 29.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 17 es 10.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 79ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 18 es 72.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 75ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 19 es 8.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 54ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 20 es 69.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 49ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 21 es 79.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 51ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 22 es 20.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 81ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 23 es 28.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 73ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 24 es 32.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 25 es 94.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 26 es 11.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 76ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 27 es 45.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 48ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 28 es 33.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 29 es 82.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 77ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 30 es 3.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 31 es 55.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 32 es 51.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 33 es 3.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 34 es 59.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 61ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 35 es 8.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 81ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 36 es 41.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 76ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 37 es 17.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 46ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 38 es 28.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 49ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 39 es 5.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 40 es 61.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 41 es 19.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 57ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 42 es 2.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 88ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 43 es 2.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 65ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 44 es 2.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 45 es 8.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 53ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 46 es 5.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 47 es 70.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 64ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 48 es 45.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 49 es 4.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 50 es 64.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 51 es 7.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 57ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 52 es 5.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 69ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 53 es 31.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 54 es 81.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 73ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 55 es 20.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 56 es 14.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 57 es 14.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 58 es 52.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 15ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 59 es 80.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 64ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 60 es 11.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 61 es 33.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 51ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 62 es 64.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 63 es 13.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 64 es 5.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 52ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 65 es 53.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 66 es 49.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 67 es 2.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 73ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 68 es 12.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 69 es 2.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 59ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 70 es 3.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 71 es 5.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 47ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 72 es 11.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 73 es 28.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 74 es 7.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 51ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 75 es 88.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 76 es 8.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 54ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 77 es 10.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 51ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 78 es 11.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 79 es 18.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 80 es 14.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 58ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 81 es 31.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 82 es 85.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 83 es 82.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 63ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 84 es 31.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 85 es 85.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 86 es 51.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 87 es 6.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 65ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 88 es 16.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 89 es 60.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 80ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 90 es 19.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 91 es 20.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 92 es 7.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 93 es 74.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 53ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 94 es 45.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 61ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 95 es 15.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 96 es 52.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 70ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 97 es 15.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 98 es 69.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 99 es 27.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 100 es 73.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 101 es 27.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 102 es 64.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 103 es 15.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 104 es 19.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 105 es 2.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 72ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 106 es 39.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 107 es 35.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 108 es 83.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 61ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 109 es 48.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 72ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 110 es 1.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 69ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 111 es 32.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 47ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 112 es 5.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 76ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 113 es 84.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 114 es 9.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 73ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 115 es 58.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 56ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 116 es 12.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 117 es 11.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 45ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 118 es 96.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 51ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 119 es 69.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 70ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 120 es 20.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 121 es 46.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 64ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 122 es 16.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 49ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 123 es 32.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 51ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 124 es 53.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 52ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 125 es 19.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 57ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 126 es 64.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 127 es 15.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 128 es 11.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 129 es 17.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 130 es 2.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 57ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 131 es 30.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 132 es 54.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 46ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 133 es 25.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 134 es 3.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 66ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 135 es 22.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 69ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 136 es 28.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 77ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 137 es 85.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 138 es 35.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 139 es 17.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 140 es 18.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 141 es 55.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 142 es 16.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 143 es 4.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 53ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 144 es 28.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 145 es 63.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 146 es 87.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 147 es 33.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 148 es 15.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 149 es 20.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 150 es 92.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 151 es 56.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 52ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 152 es 12.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 58ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 153 es 4.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 154 es 11.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 65ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 155 es 2.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 75ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 156 es 56.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 157 es 17.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 51ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 158 es 44.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 159 es 22.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 160 es 17.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 78ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 161 es 11.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 162 es 17.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 54ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 163 es 30.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 164 es 85.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 57ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 165 es 39.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 78ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 166 es 7.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 61ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 167 es 38.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 70ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 168 es 41.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 53ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 169 es 21.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 170 es 9.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 171 es 46.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 79ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 172 es 32.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 173 es 1.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 64ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 174 es 34.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 175 es 59.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 84ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 176 es 6.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 177 es 3.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 47ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 178 es 50.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 179 es 9.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 180 es 6.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 80ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 181 es 52.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 182 es 36.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 183 es 5.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 56ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 184 es 49.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 185 es 25.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 186 es 42.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 187 es 7.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 54ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 188 es 11.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 189 es 8.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 190 es 46.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 191 es 12.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 192 es 17.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 193 es 20.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 194 es 38.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 195 es 37.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 17ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 196 es 27.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 197 es 40.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 198 es 10.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 199 es 23.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 200 es 5.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 53ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 201 es 8.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 64ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 202 es 22.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 203 es 88.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 54ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 204 es 12.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 72ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 205 es 57.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 206 es 66.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 58ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 207 es 6.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 208 es 43.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 209 es 4.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 210 es 80.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 211 es 8.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 212 es 20.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 45ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 213 es 20.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 214 es 3.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 44ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 215 es 9.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 61ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 216 es 28.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 78ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 217 es 43.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 218 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 219 es 11.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 81ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 220 es 2.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 221 es 20.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 222 es 46.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 223 es 11.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 224 es 95.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 225 es 6.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 226 es 4.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 227 es 21.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 61ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 228 es 40.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 59ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 229 es 26.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 55ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 230 es 15.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 49ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 231 es 36.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 68ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 232 es 52.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 63ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 233 es 41.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 234 es 55.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 72ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 235 es 14.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 70ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 236 es 58.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 237 es 87.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 72ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 238 es 10.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 239 es 39.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 240 es 29.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 241 es 39.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 242 es 62.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 57ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 243 es 19.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 244 es 60.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 54ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 245 es 12.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 246 es 11.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 73ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 247 es 1.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 248 es 5.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 45ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 249 es 7.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 250 es 21.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 251 es 72.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 69ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 252 es 35.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 253 es 9.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 66ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 254 es 4.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 57ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 255 es 9.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 44ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 256 es 4.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 257 es 21.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 76ms/step
# ...
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9937 es 33.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9938 es 5.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9939 es 33.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9940 es 30.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9941 es 3.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9942 es 95.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 73ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9943 es 11.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9944 es 84.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9945 es 7.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 48ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9946 es 10.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 44ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9947 es 2.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 63ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9948 es 9.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 59ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9949 es 33.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 66ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9950 es 2.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9951 es 63.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 44ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9952 es 69.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 65ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9953 es 8.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 56ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9954 es 3.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 46ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9955 es 22.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 46ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9956 es 62.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 65ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9957 es 5.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 76ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9958 es 13.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9959 es 10.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9960 es 57.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 69ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9961 es 5.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 65ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9962 es 9.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9963 es 55.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 44ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9964 es 4.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 67ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9965 es 16.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9966 es 16.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 61ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9967 es 8.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 49ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9968 es 84.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9969 es 17.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9970 es 21.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 66ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9971 es 4.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 59ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9972 es 9.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 53ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9973 es 24.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 58ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9974 es 10.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9975 es 33.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9976 es 6.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 72ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9977 es 22.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9978 es 77.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 79ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9979 es 68.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 72ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9980 es 12.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9981 es 15.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 77ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9982 es 63.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 79ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9983 es 2.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9984 es 30.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9985 es 40.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9986 es 5.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9987 es 21.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9988 es 31.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 71ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9989 es 5.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9990 es 16.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9991 es 23.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 80ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9992 es 34.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 73ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9993 es 20.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9994 es 57.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 64ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9995 es 16.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 69ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9996 es 72.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9997 es 21.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9998 es 26.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 64ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9999 es 16.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 10000 es 19.75%
# Porcentajes para las 10 iteraciones: [5.75, 23.75, 35.75, 71.25, 75.5, 20.75, 14.75, 13.0, 24.0, 30.25, 26.25, 25.75, 21.75, 22.25, 25.75, 29.5, 10.25, 72.25, 8.25, 69.25, 79.0, 20.75, 28.749999999999996, 32.5, 94.75, 11.25, 45.25, 33.75, 82.75, 3.5000000000000004, 55.50000000000001, 51.5, 3.75, 59.75, 8.25, 41.0, 17.75, 28.249999999999996, 5.75, 61.5, 19.75, 2.5, 2.0, 2.25, 8.0, 5.0, 70.75, 45.25, 4.0, 64.0, 7.5, 5.75, 31.0, 81.5, 20.25, 14.249999999999998, 14.249999999999998, 52.5, 80.25, 11.25, 33.0, 64.75, 13.25, 5.5, 53.25, 49.0, 2.5, 12.5, 2.75, 3.25, 5.5, 11.0, 28.499999999999996, 7.249999999999999, 88.0, 8.25, 10.5, 11.5, 18.0, 14.249999999999998, 31.25, 85.0, 82.0, 31.0, 85.25, 51.24999999999999, 6.25, 16.75, 60.25, 19.75, 20.5, 7.5, 74.75, 45.75, 15.5, 52.0, 15.5, 69.25, 27.500000000000004, 73.0, 27.0, 64.25, 15.5, 19.75, 2.0, 39.75, 35.0, 83.5, 48.5, 1.25, 32.5, 5.25, 84.5, 9.5, 58.25, 12.0, 11.5, 96.25, 69.5, 20.25, 46.75, 16.25, 32.0, 53.0, 19.5, 64.0, 15.5, 11.5, 17.75, 2.75, 30.0, 54.0, 25.75, 3.5000000000000004, 22.5, 28.499999999999996, 85.75, 35.25, 17.25, 18.75, 55.75, 16.25, 4.5, 28.000000000000004, 63.24999999999999, 87.0, 33.75, 15.25, 20.5, 92.75, 56.25, 12.5, 4.5, 11.0, 2.5, 56.00000000000001, 17.0, 44.75, 22.25, 17.25, 11.25, 17.75, 30.25, 85.25, 39.75, 7.000000000000001, 38.25, 41.25, 21.75, 9.75, 46.0, 32.5, 1.7500000000000002, 34.75, 59.75, 6.5, 3.5000000000000004, 50.0, 9.5, 6.0, 52.25, 36.25, 5.0, 49.25, 25.0, 42.5, 7.5, 11.75, 8.25, 46.25, 12.5, 17.0, 20.0, 38.0, 37.5, 27.0, 40.75, 10.5, 23.75, 5.5, 8.25, 22.25, 88.0, 12.75, 56.99999999999999, 66.5, 6.0, 43.25, 4.0, 80.5, 8.25, 20.0, 20.25, 3.5000000000000004, 9.5, 28.000000000000004, 43.75, 99.25, 11.5, 2.5, 20.75, 46.75, 11.75, 95.75, 6.75, 4.5, 21.75, 40.0, 26.25, 15.0, 36.5, 52.0, 41.0, 55.50000000000001, 14.000000000000002, 57.99999999999999, 87.5, 10.75, 39.0, 29.25, 39.75, 62.5, 19.25, 60.0, 12.75, 11.0, 1.5, 5.5, 7.5, 21.5, 72.5, 35.0, 9.75, 4.75, 9.25, 4.25, 21.0, 7.249999999999999, 51.24999999999999, 62.5, 5.75, 14.000000000000002, 15.5, 9.0, 52.5, 3.0, 52.5, 48.0, 45.5, 6.5, 3.75, 61.75000000000001, 42.5, 88.25, 52.75, 86.5, 6.5, 2.25, 44.0, 14.499999999999998, 20.5, 1.25, 9.75, 57.99999999999999, 52.0, 20.0, 49.25, 63.5, 80.25, 66.25, 3.75, 65.25, 35.75, 97.25, 40.25, 31.25, 19.75, 65.0, 24.75, 82.75, 30.25, 88.25, 7.000000000000001, 40.75, 11.0, 17.25, 66.75, 10.0, 26.5, 5.0, 21.0, 9.75, 9.25, 35.25, 31.0, 30.25, 76.0, 57.75, 81.5, 9.75, 4.25, 75.75, 47.25, 4.0, 18.75, 53.25, 7.5, 67.25, 19.75, 7.249999999999999, 28.499999999999996, 2.25, 25.25, 43.75, 22.0, 4.25, 19.0, 10.25, 24.75, 8.75, 7.75, 12.25, 52.75, 2.25, 32.75, 9.0, 19.25, 73.5, 12.5, 5.25, 3.25, 37.25, 41.75, 60.75000000000001, 40.75, 44.75, 20.75, 89.25, 46.5, 55.75, 39.5, 63.74999999999999, 57.49999999999999, 5.0, 3.0, 14.75, 15.75, 57.49999999999999, 23.0, 4.5, 13.0, 10.25, 31.5, 21.5, 37.25, 55.75, 20.5, 4.25, 5.5, 70.0, 2.75, 6.5, 9.75, 28.499999999999996, 10.5, 10.0, 6.5, 11.75, 23.5, 4.0, 65.0, 61.5, 7.75, 34.75, 42.75, 56.99999999999999, 15.5, 16.75, 17.5, 4.75, 52.0, 46.0, 12.25, 37.25, 45.5, 51.0, 18.75, 24.25, 46.5, 17.0, 37.5, 11.25, 30.25, 83.25, 34.75, 6.5, 26.0, 5.25, 6.0, 31.5, 57.75, 42.0, 44.75, 33.0, 49.75, 67.0, 6.75, 10.25, 32.75, 26.5, 8.5, 16.25, 26.0, 53.0, 51.0, 33.5, 21.75, 6.25, 7.5, 24.5, 6.5, 38.0, 80.5, 33.0, 30.5, 59.0, 14.249999999999998, 59.0, 4.5, 37.0, 7.000000000000001, 53.0, 27.500000000000004, 19.75, 7.249999999999999, 30.75, 4.75, 44.5, 6.0, 5.5, 49.75, 28.999999999999996, 9.75, 57.99999999999999, 5.5, 30.75, 8.25, 17.75, 15.25, 37.5, 34.75, 6.0, 32.0, 10.5, 44.5, 63.74999999999999, 5.0, 23.0, 75.25, 95.5, 1.5, 5.75, 15.25, 18.25, 33.25, 6.5, 5.75, 32.25, 11.75, 2.5, 45.75, 81.25, 39.75, 30.75, 22.5, 23.25, 42.0, 29.75, 15.0, 12.5, 19.0, 25.75, 31.25, 38.0, 64.0, 15.25, 74.0, 62.0, 13.750000000000002, 16.0, 5.25, 32.0, 15.0, 7.75, 39.0, 20.25, 1.7500000000000002, 51.0, 37.0, 75.5, 37.75, 3.0, 15.25, 6.25, 10.75, 15.0, 5.25, 6.5, 4.0, ...
# El promedio de los porcentajes es 30.33%

# %%
import matplotlib.pyplot as plt

# ...

# Muestra todos los porcentajes al final
# Calcula y muestra el promedio de los porcentajes
promedio = np.mean(porcentajes)
print(f"El promedio de los porcentajes es {promedio:.2f}%")

# Crea un histograma de los porcentajes
plt.figure(figsize=(10, 6))
plt.hist(porcentajes, bins=50, edgecolor='black', alpha=0.7, color = 'darkred')
plt.title('Distribución de los Porcentajes de Error Relativo')
plt.xlabel('Porcentaje de Error Relativo')
plt.ylabel('Frecuencia')
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# El promedio de los porcentajes es 30.33%
