# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_25612\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos con ruido/Campo 20 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')
campvectrain = np.transpose(campvectrain, (0,2,3,1))

# %%
np.shape(campvectrain)
# Out:
# (7000, 20, 20, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')
campvectest = np.transpose(campvectest, (0,2,3,1))

# %%
np.shape(campvectest)
# Out:
# (1000, 20, 20, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (1000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')
campvecval = np.transpose(campvecval, (0,2,3,1))

# %%
np.shape(campvecval)
# Out:
# (2000, 20, 20, 2)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (2000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(20, 20, 2), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
# Primera capa convolucional
model.add(Conv2D(32, (3, 3), activation='tanh', input_shape=(20, 20, 2),kernel_initializer='glorot_uniform'
, kernel_regularizer=l1(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Segunda capa convolucional
model.add(Conv2D(64, (3, 3), activation='tanh',kernel_initializer='glorot_uniform'
, kernel_regularizer=l1(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='tanh',kernel_initializer='glorot_uniform'
, kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='tanh',kernel_initializer='glorot_uniform'
, kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer='glorot_uniform'
, kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(7))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 18, 18, 32)        608
#
#  max_pooling2d (MaxPooling2D  (None, 9, 9, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 128)               73856
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 105,831
# Trainable params: 105,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= 'mean_squared_error',
              metrics=metrics)

# %%
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_mean_metric', patience = 1000,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 70/70 [==============================] - 2s 13ms/step - loss: 17.5917 - a_1: 3.3444 - a_2: 3.1489 - b_1: 2.9735 - b_2: 3.3905 - d_1: 2.3785 - d_2: 2.5010 - n: 1.8379 - mean_metric: 0.6416 - val_loss: 11.1096 - val_a_1: 2.7061 - val_a_2: 2.6717 - val_b_1: 2.2404 - val_b_2: 2.4760 - val_d_1: 1.2922 - val_d_2: 1.1970 - val_n: 1.5394 - val_mean_metric: 0.4647 - lr: 0.0010
# Epoch 2/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 11.9328 - a_1: 2.8776 - a_2: 2.8222 - b_1: 2.2714 - b_2: 2.5543 - d_1: 1.5325 - d_2: 1.5733 - n: 1.6399 - mean_metric: 0.5010 - val_loss: 9.5655 - val_a_1: 2.6872 - val_a_2: 2.6549 - val_b_1: 1.9115 - val_b_2: 2.0109 - val_d_1: 1.1355 - val_d_2: 1.1323 - val_n: 1.5079 - val_mean_metric: 0.4291 - lr: 0.0010
# Epoch 3/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 10.1176 - a_1: 2.8011 - a_2: 2.7656 - b_1: 1.9374 - b_2: 1.9258 - d_1: 1.4439 - d_2: 1.4691 - n: 1.5893 - mean_metric: 0.4569 - val_loss: 8.2891 - val_a_1: 2.6388 - val_a_2: 2.6354 - val_b_1: 1.6292 - val_b_2: 1.5302 - val_d_1: 1.0198 - val_d_2: 0.9855 - val_n: 1.5000 - val_mean_metric: 0.3929 - lr: 0.0010
# Epoch 4/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 9.1456 - a_1: 2.7611 - a_2: 2.7408 - b_1: 1.7988 - b_2: 1.7867 - d_1: 1.3644 - d_2: 1.3998 - n: 1.5540 - mean_metric: 0.4397 - val_loss: 7.5109 - val_a_1: 2.5558 - val_a_2: 2.6177 - val_b_1: 1.5129 - val_b_2: 1.4499 - val_d_1: 1.0334 - val_d_2: 0.9670 - val_n: 1.4701 - val_mean_metric: 0.3820 - lr: 0.0010
# Epoch 5/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 8.2600 - a_1: 2.5774 - a_2: 2.7065 - b_1: 1.7495 - b_2: 1.7160 - d_1: 1.3312 - d_2: 1.3548 - n: 1.4942 - mean_metric: 0.4242 - val_loss: 6.8452 - val_a_1: 2.3032 - val_a_2: 2.6149 - val_b_1: 1.5230 - val_b_2: 1.4522 - val_d_1: 0.9986 - val_d_2: 0.9525 - val_n: 1.4025 - val_mean_metric: 0.3702 - lr: 0.0010
# Epoch 6/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 7.5619 - a_1: 2.2904 - a_2: 2.6919 - b_1: 1.7040 - b_2: 1.6665 - d_1: 1.3125 - d_2: 1.3366 - n: 1.4408 - mean_metric: 0.4082 - val_loss: 6.2607 - val_a_1: 2.0626 - val_a_2: 2.5600 - val_b_1: 1.4794 - val_b_2: 1.3739 - val_d_1: 1.0215 - val_d_2: 1.0078 - val_n: 1.3746 - val_mean_metric: 0.3581 - lr: 0.0010
# Epoch 7/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 6.9990 - a_1: 2.1658 - a_2: 2.6066 - b_1: 1.6464 - b_2: 1.6389 - d_1: 1.2998 - d_2: 1.2911 - n: 1.4154 - mean_metric: 0.3958 - val_loss: 5.8040 - val_a_1: 1.9801 - val_a_2: 2.4256 - val_b_1: 1.4180 - val_b_2: 1.3529 - val_d_1: 1.0556 - val_d_2: 0.9584 - val_n: 1.3357 - val_mean_metric: 0.3464 - lr: 0.0010
# Epoch 8/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 6.4666 - a_1: 2.0960 - a_2: 2.3753 - b_1: 1.6251 - b_2: 1.5960 - d_1: 1.2894 - d_2: 1.2858 - n: 1.3906 - mean_metric: 0.3825 - val_loss: 5.3103 - val_a_1: 1.9292 - val_a_2: 2.1291 - val_b_1: 1.4693 - val_b_2: 1.3135 - val_d_1: 0.9830 - val_d_2: 0.9140 - val_n: 1.3049 - val_mean_metric: 0.3305 - lr: 0.0010
# Epoch 9/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 6.0366 - a_1: 2.0334 - a_2: 2.1237 - b_1: 1.5958 - b_2: 1.5604 - d_1: 1.2944 - d_2: 1.2856 - n: 1.3269 - mean_metric: 0.3680 - val_loss: 4.8939 - val_a_1: 1.8484 - val_a_2: 1.9032 - val_b_1: 1.3727 - val_b_2: 1.2974 - val_d_1: 1.0113 - val_d_2: 0.9620 - val_n: 1.2449 - val_mean_metric: 0.3173 - lr: 0.0010
# Epoch 10/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 5.6937 - a_1: 1.9857 - a_2: 2.0140 - b_1: 1.5570 - b_2: 1.5230 - d_1: 1.2681 - d_2: 1.2561 - n: 1.2786 - mean_metric: 0.3570 - val_loss: 4.6611 - val_a_1: 1.8260 - val_a_2: 1.8203 - val_b_1: 1.3447 - val_b_2: 1.2785 - val_d_1: 0.9691 - val_d_2: 0.9055 - val_n: 1.2315 - val_mean_metric: 0.3086 - lr: 0.0010
# Epoch 11/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 5.5081 - a_1: 1.9675 - a_2: 1.9735 - b_1: 1.5529 - b_2: 1.5151 - d_1: 1.2382 - d_2: 1.2547 - n: 1.2802 - mean_metric: 0.3537 - val_loss: 4.5194 - val_a_1: 1.8247 - val_a_2: 1.8067 - val_b_1: 1.3309 - val_b_2: 1.2594 - val_d_1: 0.9214 - val_d_2: 0.8910 - val_n: 1.2360 - val_mean_metric: 0.3051 - lr: 0.0010
# Epoch 12/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 5.3533 - a_1: 1.9441 - a_2: 1.9069 - b_1: 1.5503 - b_2: 1.4957 - d_1: 1.2429 - d_2: 1.2505 - n: 1.2705 - mean_metric: 0.3497 - val_loss: 4.4106 - val_a_1: 1.7903 - val_a_2: 1.7327 - val_b_1: 1.3190 - val_b_2: 1.3069 - val_d_1: 0.9397 - val_d_2: 0.9293 - val_n: 1.2264 - val_mean_metric: 0.3043 - lr: 0.0010
# Epoch 13/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 5.1647 - a_1: 1.9167 - a_2: 1.8759 - b_1: 1.5265 - b_2: 1.4565 - d_1: 1.2245 - d_2: 1.2084 - n: 1.2576 - mean_metric: 0.3434 - val_loss: 4.2668 - val_a_1: 1.7568 - val_a_2: 1.7105 - val_b_1: 1.2937 - val_b_2: 1.2353 - val_d_1: 0.9428 - val_d_2: 0.9470 - val_n: 1.2078 - val_mean_metric: 0.2993 - lr: 0.0010
# Epoch 14/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 5.0539 - a_1: 1.8912 - a_2: 1.8587 - b_1: 1.5051 - b_2: 1.4457 - d_1: 1.2290 - d_2: 1.2202 - n: 1.2665 - mean_metric: 0.3417 - val_loss: 4.1831 - val_a_1: 1.7543 - val_a_2: 1.6810 - val_b_1: 1.3072 - val_b_2: 1.2326 - val_d_1: 0.8995 - val_d_2: 0.9308 - val_n: 1.2033 - val_mean_metric: 0.2965 - lr: 0.0010
# Epoch 15/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.9132 - a_1: 1.8519 - a_2: 1.8489 - b_1: 1.4881 - b_2: 1.4688 - d_1: 1.1889 - d_2: 1.1853 - n: 1.2650 - mean_metric: 0.3378 - val_loss: 4.1067 - val_a_1: 1.7186 - val_a_2: 1.6896 - val_b_1: 1.2789 - val_b_2: 1.2764 - val_d_1: 0.9228 - val_d_2: 0.8968 - val_n: 1.2138 - val_mean_metric: 0.2961 - lr: 0.0010
# Epoch 16/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.8812 - a_1: 1.8754 - a_2: 1.8276 - b_1: 1.4910 - b_2: 1.4371 - d_1: 1.2046 - d_2: 1.2068 - n: 1.2738 - mean_metric: 0.3384 - val_loss: 4.0793 - val_a_1: 1.8325 - val_a_2: 1.6834 - val_b_1: 1.2658 - val_b_2: 1.1994 - val_d_1: 0.9015 - val_d_2: 0.9076 - val_n: 1.2346 - val_mean_metric: 0.2971 - lr: 0.0010
# Epoch 17/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.7955 - a_1: 1.8547 - a_2: 1.8291 - b_1: 1.4603 - b_2: 1.4409 - d_1: 1.2017 - d_2: 1.2025 - n: 1.2577 - mean_metric: 0.3362 - val_loss: 3.9424 - val_a_1: 1.7074 - val_a_2: 1.6450 - val_b_1: 1.2792 - val_b_2: 1.1729 - val_d_1: 0.9100 - val_d_2: 0.9179 - val_n: 1.2230 - val_mean_metric: 0.2915 - lr: 0.0010
# Epoch 18/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.7380 - a_1: 1.8475 - a_2: 1.8119 - b_1: 1.4720 - b_2: 1.4199 - d_1: 1.2060 - d_2: 1.2043 - n: 1.2520 - mean_metric: 0.3351 - val_loss: 3.9293 - val_a_1: 1.6952 - val_a_2: 1.6568 - val_b_1: 1.2939 - val_b_2: 1.1612 - val_d_1: 0.9027 - val_d_2: 0.9515 - val_n: 1.2139 - val_mean_metric: 0.2921 - lr: 0.0010
# Epoch 19/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.6200 - a_1: 1.8131 - a_2: 1.7731 - b_1: 1.4564 - b_2: 1.4041 - d_1: 1.1873 - d_2: 1.1912 - n: 1.2609 - mean_metric: 0.3309 - val_loss: 3.8257 - val_a_1: 1.6743 - val_a_2: 1.6437 - val_b_1: 1.2629 - val_b_2: 1.1576 - val_d_1: 0.8779 - val_d_2: 0.8564 - val_n: 1.2285 - val_mean_metric: 0.2864 - lr: 0.0010
# Epoch 20/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.5617 - a_1: 1.8120 - a_2: 1.8013 - b_1: 1.4407 - b_2: 1.3826 - d_1: 1.1778 - d_2: 1.1779 - n: 1.2575 - mean_metric: 0.3297 - val_loss: 3.8203 - val_a_1: 1.6709 - val_a_2: 1.6088 - val_b_1: 1.3157 - val_b_2: 1.1628 - val_d_1: 0.9128 - val_d_2: 0.8982 - val_n: 1.2186 - val_mean_metric: 0.2892 - lr: 0.0010
# Epoch 21/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 4.5026 - a_1: 1.7990 - a_2: 1.7646 - b_1: 1.4154 - b_2: 1.3956 - d_1: 1.1663 - d_2: 1.1700 - n: 1.2597 - mean_metric: 0.3271 - val_loss: 3.7680 - val_a_1: 1.6844 - val_a_2: 1.6100 - val_b_1: 1.2908 - val_b_2: 1.1957 - val_d_1: 0.8931 - val_d_2: 0.8663 - val_n: 1.2276 - val_mean_metric: 0.2886 - lr: 0.0010
# Epoch 22/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.4714 - a_1: 1.7947 - a_2: 1.7846 - b_1: 1.4167 - b_2: 1.3957 - d_1: 1.1785 - d_2: 1.1691 - n: 1.2581 - mean_metric: 0.3281 - val_loss: 3.7492 - val_a_1: 1.6523 - val_a_2: 1.6051 - val_b_1: 1.3009 - val_b_2: 1.1699 - val_d_1: 0.8737 - val_d_2: 0.9222 - val_n: 1.2131 - val_mean_metric: 0.2876 - lr: 0.0010
# Epoch 23/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.3625 - a_1: 1.7743 - a_2: 1.7363 - b_1: 1.4057 - b_2: 1.3776 - d_1: 1.1446 - d_2: 1.1541 - n: 1.2522 - mean_metric: 0.3230 - val_loss: 3.7173 - val_a_1: 1.6255 - val_a_2: 1.6044 - val_b_1: 1.2819 - val_b_2: 1.1711 - val_d_1: 0.9443 - val_d_2: 0.9042 - val_n: 1.2223 - val_mean_metric: 0.2881 - lr: 0.0010
# Epoch 24/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.4081 - a_1: 1.7716 - a_2: 1.7604 - b_1: 1.4247 - b_2: 1.3923 - d_1: 1.1709 - d_2: 1.1698 - n: 1.2599 - mean_metric: 0.3264 - val_loss: 3.7262 - val_a_1: 1.6685 - val_a_2: 1.6149 - val_b_1: 1.2689 - val_b_2: 1.2002 - val_d_1: 0.9468 - val_d_2: 0.8671 - val_n: 1.2196 - val_mean_metric: 0.2892 - lr: 0.0010
# Epoch 25/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.3693 - a_1: 1.7607 - a_2: 1.7544 - b_1: 1.4131 - b_2: 1.3984 - d_1: 1.1731 - d_2: 1.1692 - n: 1.2635 - mean_metric: 0.3258 - val_loss: 3.6261 - val_a_1: 1.6732 - val_a_2: 1.5803 - val_b_1: 1.2359 - val_b_2: 1.1793 - val_d_1: 0.8521 - val_d_2: 0.8555 - val_n: 1.2216 - val_mean_metric: 0.2830 - lr: 0.0010
# Epoch 26/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.2714 - a_1: 1.7586 - a_2: 1.7156 - b_1: 1.4016 - b_2: 1.3635 - d_1: 1.1496 - d_2: 1.1437 - n: 1.2524 - mean_metric: 0.3210 - val_loss: 3.6274 - val_a_1: 1.6607 - val_a_2: 1.6051 - val_b_1: 1.2062 - val_b_2: 1.2543 - val_d_1: 0.8386 - val_d_2: 0.8724 - val_n: 1.2201 - val_mean_metric: 0.2850 - lr: 0.0010
# Epoch 27/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.2320 - a_1: 1.7450 - a_2: 1.7056 - b_1: 1.3870 - b_2: 1.3600 - d_1: 1.1465 - d_2: 1.1569 - n: 1.2634 - mean_metric: 0.3204 - val_loss: 3.5665 - val_a_1: 1.5944 - val_a_2: 1.5907 - val_b_1: 1.2530 - val_b_2: 1.1455 - val_d_1: 0.8770 - val_d_2: 0.8844 - val_n: 1.2184 - val_mean_metric: 0.2818 - lr: 0.0010
# Epoch 28/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.2500 - a_1: 1.7360 - a_2: 1.7506 - b_1: 1.4032 - b_2: 1.3593 - d_1: 1.1586 - d_2: 1.1594 - n: 1.2555 - mean_metric: 0.3222 - val_loss: 3.5602 - val_a_1: 1.6074 - val_a_2: 1.5594 - val_b_1: 1.2725 - val_b_2: 1.1752 - val_d_1: 0.8555 - val_d_2: 0.9038 - val_n: 1.2179 - val_mean_metric: 0.2828 - lr: 0.0010
# Epoch 29/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.1701 - a_1: 1.7215 - a_2: 1.7108 - b_1: 1.3841 - b_2: 1.3515 - d_1: 1.1421 - d_2: 1.1358 - n: 1.2706 - mean_metric: 0.3189 - val_loss: 3.4647 - val_a_1: 1.5834 - val_a_2: 1.5491 - val_b_1: 1.2330 - val_b_2: 1.1333 - val_d_1: 0.8656 - val_d_2: 0.8471 - val_n: 1.2179 - val_mean_metric: 0.2775 - lr: 0.0010
# Epoch 30/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.1422 - a_1: 1.7573 - a_2: 1.7073 - b_1: 1.3607 - b_2: 1.3448 - d_1: 1.1398 - d_2: 1.1400 - n: 1.2617 - mean_metric: 0.3187 - val_loss: 3.4698 - val_a_1: 1.6163 - val_a_2: 1.5412 - val_b_1: 1.2391 - val_b_2: 1.1265 - val_d_1: 0.8321 - val_d_2: 0.8830 - val_n: 1.2277 - val_mean_metric: 0.2786 - lr: 0.0010
# Epoch 31/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.1366 - a_1: 1.7408 - a_2: 1.7172 - b_1: 1.3676 - b_2: 1.3430 - d_1: 1.1469 - d_2: 1.1348 - n: 1.2655 - mean_metric: 0.3187 - val_loss: 3.4045 - val_a_1: 1.5698 - val_a_2: 1.5651 - val_b_1: 1.1890 - val_b_2: 1.1132 - val_d_1: 0.8398 - val_d_2: 0.8524 - val_n: 1.2310 - val_mean_metric: 0.2752 - lr: 0.0010
# Epoch 32/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.0849 - a_1: 1.7263 - a_2: 1.7188 - b_1: 1.3609 - b_2: 1.3227 - d_1: 1.1234 - d_2: 1.1334 - n: 1.2643 - mean_metric: 0.3166 - val_loss: 3.4510 - val_a_1: 1.6119 - val_a_2: 1.5963 - val_b_1: 1.2157 - val_b_2: 1.1271 - val_d_1: 0.8260 - val_d_2: 0.8550 - val_n: 1.2346 - val_mean_metric: 0.2787 - lr: 0.0010
# Epoch 33/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.0716 - a_1: 1.7139 - a_2: 1.6946 - b_1: 1.3753 - b_2: 1.3331 - d_1: 1.1303 - d_2: 1.1215 - n: 1.2637 - mean_metric: 0.3160 - val_loss: 3.3846 - val_a_1: 1.5765 - val_a_2: 1.5329 - val_b_1: 1.1972 - val_b_2: 1.0997 - val_d_1: 0.8374 - val_d_2: 0.9049 - val_n: 1.2343 - val_mean_metric: 0.2759 - lr: 0.0010
# Epoch 34/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 4.0296 - a_1: 1.7105 - a_2: 1.6879 - b_1: 1.3803 - b_2: 1.3226 - d_1: 1.1220 - d_2: 1.1149 - n: 1.2702 - mean_metric: 0.3152 - val_loss: 3.3976 - val_a_1: 1.5788 - val_a_2: 1.5355 - val_b_1: 1.2133 - val_b_2: 1.1307 - val_d_1: 0.8796 - val_d_2: 0.8498 - val_n: 1.2351 - val_mean_metric: 0.2772 - lr: 0.0010
# Epoch 35/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.9982 - a_1: 1.7104 - a_2: 1.6848 - b_1: 1.3336 - b_2: 1.3315 - d_1: 1.1218 - d_2: 1.1214 - n: 1.2606 - mean_metric: 0.3139 - val_loss: 3.3754 - val_a_1: 1.5852 - val_a_2: 1.5409 - val_b_1: 1.2341 - val_b_2: 1.1157 - val_d_1: 0.8547 - val_d_2: 0.8643 - val_n: 1.2241 - val_mean_metric: 0.2771 - lr: 0.0010
# Epoch 36/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.9830 - a_1: 1.7102 - a_2: 1.6849 - b_1: 1.3339 - b_2: 1.3207 - d_1: 1.1220 - d_2: 1.1229 - n: 1.2742 - mean_metric: 0.3139 - val_loss: 3.3997 - val_a_1: 1.5747 - val_a_2: 1.5214 - val_b_1: 1.2003 - val_b_2: 1.2355 - val_d_1: 0.8382 - val_d_2: 0.9016 - val_n: 1.2312 - val_mean_metric: 0.2799 - lr: 0.0010
# Epoch 37/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.9656 - a_1: 1.7075 - a_2: 1.6752 - b_1: 1.3411 - b_2: 1.3258 - d_1: 1.1035 - d_2: 1.1335 - n: 1.2697 - mean_metric: 0.3136 - val_loss: 3.3329 - val_a_1: 1.5375 - val_a_2: 1.5674 - val_b_1: 1.1514 - val_b_2: 1.1371 - val_d_1: 0.8359 - val_d_2: 0.8410 - val_n: 1.2348 - val_mean_metric: 0.2734 - lr: 0.0010
# Epoch 38/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 4.0014 - a_1: 1.7103 - a_2: 1.6925 - b_1: 1.3487 - b_2: 1.3354 - d_1: 1.1123 - d_2: 1.1309 - n: 1.2759 - mean_metric: 0.3151 - val_loss: 3.3268 - val_a_1: 1.5959 - val_a_2: 1.5226 - val_b_1: 1.1690 - val_b_2: 1.1118 - val_d_1: 0.8615 - val_d_2: 0.8554 - val_n: 1.2280 - val_mean_metric: 0.2747 - lr: 0.0010
# Epoch 39/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.9143 - a_1: 1.6831 - a_2: 1.6710 - b_1: 1.3282 - b_2: 1.3362 - d_1: 1.1105 - d_2: 1.1089 - n: 1.2609 - mean_metric: 0.3116 - val_loss: 3.2914 - val_a_1: 1.5749 - val_a_2: 1.5204 - val_b_1: 1.2314 - val_b_2: 1.0802 - val_d_1: 0.8437 - val_d_2: 0.8717 - val_n: 1.2264 - val_mean_metric: 0.2748 - lr: 0.0010
# Epoch 40/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.9135 - a_1: 1.6964 - a_2: 1.6824 - b_1: 1.3298 - b_2: 1.3142 - d_1: 1.1029 - d_2: 1.1253 - n: 1.2722 - mean_metric: 0.3125 - val_loss: 3.3225 - val_a_1: 1.5565 - val_a_2: 1.5199 - val_b_1: 1.2773 - val_b_2: 1.1162 - val_d_1: 0.8655 - val_d_2: 0.8833 - val_n: 1.2398 - val_mean_metric: 0.2784 - lr: 0.0010
# Epoch 41/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.8510 - a_1: 1.7018 - a_2: 1.6377 - b_1: 1.3248 - b_2: 1.2975 - d_1: 1.0951 - d_2: 1.1075 - n: 1.2633 - mean_metric: 0.3094 - val_loss: 3.1929 - val_a_1: 1.5486 - val_a_2: 1.4997 - val_b_1: 1.1381 - val_b_2: 1.0809 - val_d_1: 0.8447 - val_d_2: 0.8270 - val_n: 1.2324 - val_mean_metric: 0.2690 - lr: 0.0010
# Epoch 42/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.8917 - a_1: 1.6880 - a_2: 1.6873 - b_1: 1.3403 - b_2: 1.2939 - d_1: 1.1114 - d_2: 1.1101 - n: 1.2731 - mean_metric: 0.3118 - val_loss: 3.3237 - val_a_1: 1.5462 - val_a_2: 1.5689 - val_b_1: 1.1845 - val_b_2: 1.1731 - val_d_1: 0.8650 - val_d_2: 0.8876 - val_n: 1.2335 - val_mean_metric: 0.2784 - lr: 0.0010
# Epoch 43/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.8554 - a_1: 1.6921 - a_2: 1.6805 - b_1: 1.3081 - b_2: 1.2996 - d_1: 1.1035 - d_2: 1.1021 - n: 1.2728 - mean_metric: 0.3103 - val_loss: 3.1653 - val_a_1: 1.5433 - val_a_2: 1.5139 - val_b_1: 1.1002 - val_b_2: 1.1064 - val_d_1: 0.8314 - val_d_2: 0.8098 - val_n: 1.2266 - val_mean_metric: 0.2677 - lr: 0.0010
# Epoch 44/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.8373 - a_1: 1.7098 - a_2: 1.6658 - b_1: 1.3266 - b_2: 1.2854 - d_1: 1.0974 - d_2: 1.1017 - n: 1.2681 - mean_metric: 0.3102 - val_loss: 3.2011 - val_a_1: 1.5418 - val_a_2: 1.5083 - val_b_1: 1.1830 - val_b_2: 1.0649 - val_d_1: 0.8362 - val_d_2: 0.8609 - val_n: 1.2292 - val_mean_metric: 0.2707 - lr: 0.0010
# Epoch 45/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.8429 - a_1: 1.6874 - a_2: 1.6622 - b_1: 1.3333 - b_2: 1.3129 - d_1: 1.0978 - d_2: 1.1150 - n: 1.2679 - mean_metric: 0.3109 - val_loss: 3.2023 - val_a_1: 1.5644 - val_a_2: 1.5439 - val_b_1: 1.1190 - val_b_2: 1.0954 - val_d_1: 0.8573 - val_d_2: 0.8528 - val_n: 1.2274 - val_mean_metric: 0.2719 - lr: 0.0010
# Epoch 46/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.7462 - a_1: 1.6727 - a_2: 1.6438 - b_1: 1.2885 - b_2: 1.2787 - d_1: 1.0861 - d_2: 1.0728 - n: 1.2687 - mean_metric: 0.3054 - val_loss: 3.1263 - val_a_1: 1.5298 - val_a_2: 1.5061 - val_b_1: 1.0861 - val_b_2: 1.0909 - val_d_1: 0.8075 - val_d_2: 0.7878 - val_n: 1.2315 - val_mean_metric: 0.2646 - lr: 0.0010
# Epoch 47/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.7777 - a_1: 1.6798 - a_2: 1.6561 - b_1: 1.3014 - b_2: 1.2645 - d_1: 1.0957 - d_2: 1.0970 - n: 1.2685 - mean_metric: 0.3072 - val_loss: 3.2621 - val_a_1: 1.5627 - val_a_2: 1.4926 - val_b_1: 1.2122 - val_b_2: 1.1846 - val_d_1: 0.9236 - val_d_2: 0.8292 - val_n: 1.2254 - val_mean_metric: 0.2774 - lr: 0.0010
# Epoch 48/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.7461 - a_1: 1.6806 - a_2: 1.6269 - b_1: 1.2924 - b_2: 1.2942 - d_1: 1.0885 - d_2: 1.0776 - n: 1.2729 - mean_metric: 0.3062 - val_loss: 3.0951 - val_a_1: 1.5292 - val_a_2: 1.4777 - val_b_1: 1.0687 - val_b_2: 1.1397 - val_d_1: 0.7949 - val_d_2: 0.7802 - val_n: 1.2409 - val_mean_metric: 0.2644 - lr: 0.0010
# Epoch 49/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6943 - a_1: 1.6822 - a_2: 1.6381 - b_1: 1.2665 - b_2: 1.2456 - d_1: 1.0747 - d_2: 1.0679 - n: 1.2773 - mean_metric: 0.3035 - val_loss: 3.2968 - val_a_1: 1.5765 - val_a_2: 1.5684 - val_b_1: 1.2284 - val_b_2: 1.0958 - val_d_1: 0.8539 - val_d_2: 0.9414 - val_n: 1.2229 - val_mean_metric: 0.2793 - lr: 0.0010
# Epoch 50/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.7508 - a_1: 1.6827 - a_2: 1.6493 - b_1: 1.2970 - b_2: 1.2749 - d_1: 1.0961 - d_2: 1.0722 - n: 1.2673 - mean_metric: 0.3064 - val_loss: 3.1231 - val_a_1: 1.5264 - val_a_2: 1.4868 - val_b_1: 1.1550 - val_b_2: 1.0847 - val_d_1: 0.7810 - val_d_2: 0.8091 - val_n: 1.2218 - val_mean_metric: 0.2654 - lr: 0.0010
# Epoch 51/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6967 - a_1: 1.6566 - a_2: 1.6133 - b_1: 1.2645 - b_2: 1.2813 - d_1: 1.0703 - d_2: 1.0936 - n: 1.2747 - mean_metric: 0.3036 - val_loss: 3.1043 - val_a_1: 1.5823 - val_a_2: 1.4954 - val_b_1: 1.0772 - val_b_2: 1.0848 - val_d_1: 0.8230 - val_d_2: 0.7688 - val_n: 1.2233 - val_mean_metric: 0.2651 - lr: 0.0010
# Epoch 52/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.7047 - a_1: 1.6777 - a_2: 1.6427 - b_1: 1.2605 - b_2: 1.2567 - d_1: 1.0848 - d_2: 1.0827 - n: 1.2727 - mean_metric: 0.3044 - val_loss: 3.0571 - val_a_1: 1.5300 - val_a_2: 1.4897 - val_b_1: 1.0838 - val_b_2: 1.0302 - val_d_1: 0.8290 - val_d_2: 0.8482 - val_n: 1.2281 - val_mean_metric: 0.2645 - lr: 0.0010
# Epoch 53/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6644 - a_1: 1.6507 - a_2: 1.6338 - b_1: 1.2684 - b_2: 1.2676 - d_1: 1.0707 - d_2: 1.0728 - n: 1.2595 - mean_metric: 0.3026 - val_loss: 3.0029 - val_a_1: 1.5075 - val_a_2: 1.4703 - val_b_1: 1.0619 - val_b_2: 1.0581 - val_d_1: 0.7828 - val_d_2: 0.8125 - val_n: 1.2207 - val_mean_metric: 0.2604 - lr: 0.0010
# Epoch 54/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6347 - a_1: 1.6725 - a_2: 1.6145 - b_1: 1.2620 - b_2: 1.2462 - d_1: 1.0760 - d_2: 1.0692 - n: 1.2580 - mean_metric: 0.3018 - val_loss: 3.0436 - val_a_1: 1.5228 - val_a_2: 1.4842 - val_b_1: 1.1361 - val_b_2: 1.0425 - val_d_1: 0.8380 - val_d_2: 0.7526 - val_n: 1.2209 - val_mean_metric: 0.2632 - lr: 0.0010
# Epoch 55/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6183 - a_1: 1.6528 - a_2: 1.6068 - b_1: 1.2634 - b_2: 1.2576 - d_1: 1.0594 - d_2: 1.0756 - n: 1.2715 - mean_metric: 0.3014 - val_loss: 2.9897 - val_a_1: 1.4996 - val_a_2: 1.4554 - val_b_1: 1.1069 - val_b_2: 1.0449 - val_d_1: 0.7814 - val_d_2: 0.8116 - val_n: 1.2224 - val_mean_metric: 0.2607 - lr: 0.0010
# Epoch 56/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6294 - a_1: 1.6432 - a_2: 1.6223 - b_1: 1.2759 - b_2: 1.2485 - d_1: 1.0738 - d_2: 1.0776 - n: 1.2718 - mean_metric: 0.3022 - val_loss: 2.9870 - val_a_1: 1.5081 - val_a_2: 1.4691 - val_b_1: 1.0785 - val_b_2: 1.0614 - val_d_1: 0.7567 - val_d_2: 0.8091 - val_n: 1.2195 - val_mean_metric: 0.2601 - lr: 0.0010
# Epoch 57/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5749 - a_1: 1.6535 - a_2: 1.6049 - b_1: 1.2641 - b_2: 1.2298 - d_1: 1.0413 - d_2: 1.0600 - n: 1.2652 - mean_metric: 0.2992 - val_loss: 2.9218 - val_a_1: 1.4983 - val_a_2: 1.4402 - val_b_1: 1.0294 - val_b_2: 1.0477 - val_d_1: 0.7689 - val_d_2: 0.7543 - val_n: 1.2222 - val_mean_metric: 0.2554 - lr: 0.0010
# Epoch 58/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6085 - a_1: 1.6637 - a_2: 1.6249 - b_1: 1.2613 - b_2: 1.2371 - d_1: 1.0554 - d_2: 1.0522 - n: 1.2604 - mean_metric: 0.3003 - val_loss: 3.0022 - val_a_1: 1.4893 - val_a_2: 1.5360 - val_b_1: 1.0584 - val_b_2: 1.0708 - val_d_1: 0.7348 - val_d_2: 0.7997 - val_n: 1.2360 - val_mean_metric: 0.2608 - lr: 0.0010
# Epoch 59/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.6349 - a_1: 1.6492 - a_2: 1.6121 - b_1: 1.2749 - b_2: 1.2519 - d_1: 1.0729 - d_2: 1.0689 - n: 1.2710 - mean_metric: 0.3018 - val_loss: 2.9820 - val_a_1: 1.4941 - val_a_2: 1.4718 - val_b_1: 1.1031 - val_b_2: 1.0436 - val_d_1: 0.7663 - val_d_2: 0.7689 - val_n: 1.2146 - val_mean_metric: 0.2587 - lr: 0.0010
# Epoch 60/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5537 - a_1: 1.6406 - a_2: 1.6135 - b_1: 1.2488 - b_2: 1.2338 - d_1: 1.0552 - d_2: 1.0312 - n: 1.2676 - mean_metric: 0.2982 - val_loss: 2.9074 - val_a_1: 1.4927 - val_a_2: 1.4453 - val_b_1: 1.0352 - val_b_2: 1.0123 - val_d_1: 0.7496 - val_d_2: 0.8055 - val_n: 1.2235 - val_mean_metric: 0.2555 - lr: 0.0010
# Epoch 61/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5434 - a_1: 1.6347 - a_2: 1.6122 - b_1: 1.2370 - b_2: 1.2380 - d_1: 1.0535 - d_2: 1.0681 - n: 1.2647 - mean_metric: 0.2988 - val_loss: 2.9066 - val_a_1: 1.4999 - val_a_2: 1.4419 - val_b_1: 1.0567 - val_b_2: 1.0135 - val_d_1: 0.7602 - val_d_2: 0.7863 - val_n: 1.2198 - val_mean_metric: 0.2560 - lr: 0.0010
# Epoch 62/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5517 - a_1: 1.6358 - a_2: 1.5882 - b_1: 1.2595 - b_2: 1.2426 - d_1: 1.0667 - d_2: 1.0552 - n: 1.2650 - mean_metric: 0.2990 - val_loss: 2.8756 - val_a_1: 1.4911 - val_a_2: 1.4236 - val_b_1: 1.0198 - val_b_2: 1.0626 - val_d_1: 0.7466 - val_d_2: 0.7501 - val_n: 1.2251 - val_mean_metric: 0.2540 - lr: 0.0010
# Epoch 63/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5633 - a_1: 1.6476 - a_2: 1.6234 - b_1: 1.2426 - b_2: 1.2256 - d_1: 1.0606 - d_2: 1.0618 - n: 1.2694 - mean_metric: 0.2996 - val_loss: 2.8887 - val_a_1: 1.5157 - val_a_2: 1.4579 - val_b_1: 1.0397 - val_b_2: 1.0061 - val_d_1: 0.7902 - val_d_2: 0.7443 - val_n: 1.2167 - val_mean_metric: 0.2557 - lr: 0.0010
# Epoch 64/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5101 - a_1: 1.6278 - a_2: 1.5990 - b_1: 1.2281 - b_2: 1.2349 - d_1: 1.0554 - d_2: 1.0557 - n: 1.2611 - mean_metric: 0.2972 - val_loss: 2.8282 - val_a_1: 1.4618 - val_a_2: 1.4248 - val_b_1: 1.0257 - val_b_2: 0.9952 - val_d_1: 0.7318 - val_d_2: 0.7778 - val_n: 1.2231 - val_mean_metric: 0.2514 - lr: 0.0010
# Epoch 65/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5364 - a_1: 1.6365 - a_2: 1.5997 - b_1: 1.2466 - b_2: 1.2551 - d_1: 1.0525 - d_2: 1.0588 - n: 1.2668 - mean_metric: 0.2991 - val_loss: 2.9262 - val_a_1: 1.4745 - val_a_2: 1.4229 - val_b_1: 1.1301 - val_b_2: 0.9946 - val_d_1: 0.8127 - val_d_2: 0.8217 - val_n: 1.2169 - val_mean_metric: 0.2591 - lr: 0.0010
# Epoch 66/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4915 - a_1: 1.6472 - a_2: 1.5944 - b_1: 1.2207 - b_2: 1.2157 - d_1: 1.0646 - d_2: 1.0332 - n: 1.2634 - mean_metric: 0.2966 - val_loss: 2.8483 - val_a_1: 1.4794 - val_a_2: 1.4204 - val_b_1: 1.0557 - val_b_2: 1.0087 - val_d_1: 0.7427 - val_d_2: 0.8000 - val_n: 1.2130 - val_mean_metric: 0.2540 - lr: 0.0010
# Epoch 67/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5173 - a_1: 1.6358 - a_2: 1.5948 - b_1: 1.2510 - b_2: 1.2130 - d_1: 1.0549 - d_2: 1.0655 - n: 1.2761 - mean_metric: 0.2982 - val_loss: 2.9515 - val_a_1: 1.4844 - val_a_2: 1.4690 - val_b_1: 1.1002 - val_b_2: 1.0127 - val_d_1: 0.7843 - val_d_2: 0.9141 - val_n: 1.2210 - val_mean_metric: 0.2627 - lr: 0.0010
# Epoch 68/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.5012 - a_1: 1.6449 - a_2: 1.6060 - b_1: 1.2247 - b_2: 1.2168 - d_1: 1.0382 - d_2: 1.0487 - n: 1.2655 - mean_metric: 0.2967 - val_loss: 2.7939 - val_a_1: 1.4730 - val_a_2: 1.4230 - val_b_1: 0.9896 - val_b_2: 0.9879 - val_d_1: 0.7553 - val_d_2: 0.7457 - val_n: 1.2180 - val_mean_metric: 0.2498 - lr: 0.0010
# Epoch 69/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4884 - a_1: 1.6445 - a_2: 1.6138 - b_1: 1.2173 - b_2: 1.2227 - d_1: 1.0495 - d_2: 1.0398 - n: 1.2669 - mean_metric: 0.2970 - val_loss: 2.8139 - val_a_1: 1.4565 - val_a_2: 1.4345 - val_b_1: 1.0287 - val_b_2: 1.0542 - val_d_1: 0.7374 - val_d_2: 0.7282 - val_n: 1.2170 - val_mean_metric: 0.2520 - lr: 0.0010
# Epoch 70/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4631 - a_1: 1.6240 - a_2: 1.6021 - b_1: 1.2366 - b_2: 1.2079 - d_1: 1.0457 - d_2: 1.0293 - n: 1.2690 - mean_metric: 0.2957 - val_loss: 2.8060 - val_a_1: 1.4705 - val_a_2: 1.4468 - val_b_1: 1.0285 - val_b_2: 1.0071 - val_d_1: 0.7280 - val_d_2: 0.7404 - val_n: 1.2222 - val_mean_metric: 0.2515 - lr: 0.0010
# Epoch 71/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4683 - a_1: 1.6289 - a_2: 1.5988 - b_1: 1.2246 - b_2: 1.2182 - d_1: 1.0536 - d_2: 1.0315 - n: 1.2636 - mean_metric: 0.2960 - val_loss: 2.7930 - val_a_1: 1.4784 - val_a_2: 1.4156 - val_b_1: 1.0078 - val_b_2: 0.9692 - val_d_1: 0.7167 - val_d_2: 0.7294 - val_n: 1.2167 - val_mean_metric: 0.2479 - lr: 0.0010
# Epoch 72/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4176 - a_1: 1.6038 - a_2: 1.5803 - b_1: 1.2036 - b_2: 1.1996 - d_1: 1.0305 - d_2: 1.0317 - n: 1.2727 - mean_metric: 0.2928 - val_loss: 2.8711 - val_a_1: 1.4808 - val_a_2: 1.4416 - val_b_1: 1.0500 - val_b_2: 1.1222 - val_d_1: 0.7184 - val_d_2: 0.7443 - val_n: 1.2141 - val_mean_metric: 0.2557 - lr: 0.0010
# Epoch 73/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4974 - a_1: 1.6387 - a_2: 1.5882 - b_1: 1.2152 - b_2: 1.2388 - d_1: 1.0520 - d_2: 1.0575 - n: 1.2707 - mean_metric: 0.2973 - val_loss: 2.8959 - val_a_1: 1.5081 - val_a_2: 1.4353 - val_b_1: 0.9934 - val_b_2: 1.1154 - val_d_1: 0.7369 - val_d_2: 0.8248 - val_n: 1.2228 - val_mean_metric: 0.2579 - lr: 0.0010
# Epoch 74/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4452 - a_1: 1.6182 - a_2: 1.5990 - b_1: 1.1852 - b_2: 1.2199 - d_1: 1.0351 - d_2: 1.0325 - n: 1.2702 - mean_metric: 0.2940 - val_loss: 2.7439 - val_a_1: 1.4576 - val_a_2: 1.4213 - val_b_1: 0.9722 - val_b_2: 0.9545 - val_d_1: 0.7313 - val_d_2: 0.7610 - val_n: 1.2192 - val_mean_metric: 0.2473 - lr: 0.0010
# Epoch 75/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3944 - a_1: 1.6014 - a_2: 1.5895 - b_1: 1.2139 - b_2: 1.2021 - d_1: 1.0221 - d_2: 1.0062 - n: 1.2634 - mean_metric: 0.2919 - val_loss: 2.7363 - val_a_1: 1.4455 - val_a_2: 1.4085 - val_b_1: 1.0010 - val_b_2: 0.9866 - val_d_1: 0.7441 - val_d_2: 0.7426 - val_n: 1.2135 - val_mean_metric: 0.2482 - lr: 0.0010
# Epoch 76/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4127 - a_1: 1.6104 - a_2: 1.5833 - b_1: 1.2093 - b_2: 1.2160 - d_1: 1.0222 - d_2: 1.0324 - n: 1.2753 - mean_metric: 0.2936 - val_loss: 2.7531 - val_a_1: 1.4509 - val_a_2: 1.4108 - val_b_1: 1.0013 - val_b_2: 0.9857 - val_d_1: 0.7317 - val_d_2: 0.8025 - val_n: 1.2193 - val_mean_metric: 0.2501 - lr: 0.0010
# Epoch 77/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3737 - a_1: 1.6167 - a_2: 1.5734 - b_1: 1.2150 - b_2: 1.1814 - d_1: 1.0204 - d_2: 1.0254 - n: 1.2548 - mean_metric: 0.2916 - val_loss: 2.7568 - val_a_1: 1.4699 - val_a_2: 1.4592 - val_b_1: 0.9655 - val_b_2: 1.0304 - val_d_1: 0.7312 - val_d_2: 0.7194 - val_n: 1.2150 - val_mean_metric: 0.2498 - lr: 0.0010
# Epoch 78/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4102 - a_1: 1.6213 - a_2: 1.5871 - b_1: 1.2229 - b_2: 1.2039 - d_1: 1.0343 - d_2: 1.0371 - n: 1.2614 - mean_metric: 0.2942 - val_loss: 2.7257 - val_a_1: 1.4493 - val_a_2: 1.4359 - val_b_1: 0.9819 - val_b_2: 0.9568 - val_d_1: 0.7061 - val_d_2: 0.7575 - val_n: 1.2102 - val_mean_metric: 0.2467 - lr: 0.0010
# Epoch 79/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3831 - a_1: 1.6124 - a_2: 1.5712 - b_1: 1.2020 - b_2: 1.1974 - d_1: 1.0411 - d_2: 1.0336 - n: 1.2616 - mean_metric: 0.2926 - val_loss: 2.7627 - val_a_1: 1.4448 - val_a_2: 1.3963 - val_b_1: 0.9693 - val_b_2: 1.0954 - val_d_1: 0.7298 - val_d_2: 0.7794 - val_n: 1.2154 - val_mean_metric: 0.2511 - lr: 0.0010
# Epoch 80/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3375 - a_1: 1.6070 - a_2: 1.5702 - b_1: 1.2080 - b_2: 1.1842 - d_1: 1.0093 - d_2: 1.0046 - n: 1.2495 - mean_metric: 0.2898 - val_loss: 2.7560 - val_a_1: 1.4602 - val_a_2: 1.4569 - val_b_1: 1.0238 - val_b_2: 1.0039 - val_d_1: 0.6989 - val_d_2: 0.7243 - val_n: 1.2094 - val_mean_metric: 0.2493 - lr: 0.0010
# Epoch 81/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3747 - a_1: 1.6176 - a_2: 1.5751 - b_1: 1.2090 - b_2: 1.2006 - d_1: 1.0210 - d_2: 1.0306 - n: 1.2550 - mean_metric: 0.2923 - val_loss: 2.7733 - val_a_1: 1.4539 - val_a_2: 1.4457 - val_b_1: 1.0415 - val_b_2: 1.0238 - val_d_1: 0.7394 - val_d_2: 0.7054 - val_n: 1.2227 - val_mean_metric: 0.2512 - lr: 0.0010
# Epoch 82/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3424 - a_1: 1.6155 - a_2: 1.5676 - b_1: 1.1878 - b_2: 1.1905 - d_1: 1.0181 - d_2: 1.0051 - n: 1.2631 - mean_metric: 0.2903 - val_loss: 2.7085 - val_a_1: 1.4584 - val_a_2: 1.3938 - val_b_1: 1.0111 - val_b_2: 1.0157 - val_d_1: 0.6930 - val_d_2: 0.7013 - val_n: 1.2111 - val_mean_metric: 0.2463 - lr: 0.0010
# Epoch 83/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3309 - a_1: 1.5990 - a_2: 1.5650 - b_1: 1.1858 - b_2: 1.1857 - d_1: 1.0174 - d_2: 1.0032 - n: 1.2653 - mean_metric: 0.2894 - val_loss: 2.6707 - val_a_1: 1.4422 - val_a_2: 1.4018 - val_b_1: 0.9668 - val_b_2: 0.9438 - val_d_1: 0.7361 - val_d_2: 0.6796 - val_n: 1.2179 - val_mean_metric: 0.2431 - lr: 0.0010
# Epoch 84/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3159 - a_1: 1.5998 - a_2: 1.5589 - b_1: 1.1909 - b_2: 1.1805 - d_1: 1.0003 - d_2: 1.0039 - n: 1.2569 - mean_metric: 0.2884 - val_loss: 2.6792 - val_a_1: 1.4472 - val_a_2: 1.4008 - val_b_1: 0.9780 - val_b_2: 1.0012 - val_d_1: 0.6872 - val_d_2: 0.6998 - val_n: 1.2129 - val_mean_metric: 0.2444 - lr: 0.0010
# Epoch 85/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3078 - a_1: 1.6115 - a_2: 1.5566 - b_1: 1.1628 - b_2: 1.1824 - d_1: 0.9962 - d_2: 0.9963 - n: 1.2724 - mean_metric: 0.2880 - val_loss: 2.7398 - val_a_1: 1.4365 - val_a_2: 1.5130 - val_b_1: 1.0325 - val_b_2: 0.9608 - val_d_1: 0.6863 - val_d_2: 0.7129 - val_n: 1.2271 - val_mean_metric: 0.2491 - lr: 0.0010
# Epoch 86/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2937 - a_1: 1.5891 - a_2: 1.5601 - b_1: 1.1847 - b_2: 1.1917 - d_1: 1.0045 - d_2: 0.9955 - n: 1.2608 - mean_metric: 0.2882 - val_loss: 2.7194 - val_a_1: 1.4584 - val_a_2: 1.4275 - val_b_1: 0.9608 - val_b_2: 1.0098 - val_d_1: 0.6997 - val_d_2: 0.7665 - val_n: 1.2121 - val_mean_metric: 0.2480 - lr: 0.0010
# Epoch 87/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3244 - a_1: 1.6166 - a_2: 1.5779 - b_1: 1.1905 - b_2: 1.1803 - d_1: 1.0047 - d_2: 1.0046 - n: 1.2695 - mean_metric: 0.2901 - val_loss: 2.6776 - val_a_1: 1.4794 - val_a_2: 1.3868 - val_b_1: 0.9806 - val_b_2: 1.0094 - val_d_1: 0.6742 - val_d_2: 0.7134 - val_n: 1.2167 - val_mean_metric: 0.2455 - lr: 0.0010
# Epoch 88/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3332 - a_1: 1.6236 - a_2: 1.5501 - b_1: 1.1848 - b_2: 1.2038 - d_1: 1.0133 - d_2: 1.0074 - n: 1.2615 - mean_metric: 0.2902 - val_loss: 2.6853 - val_a_1: 1.4580 - val_a_2: 1.4037 - val_b_1: 0.9533 - val_b_2: 0.9288 - val_d_1: 0.7169 - val_d_2: 0.7429 - val_n: 1.2193 - val_mean_metric: 0.2443 - lr: 0.0010
# Epoch 89/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2788 - a_1: 1.6075 - a_2: 1.5512 - b_1: 1.1750 - b_2: 1.1663 - d_1: 0.9943 - d_2: 0.9816 - n: 1.2624 - mean_metric: 0.2867 - val_loss: 2.6628 - val_a_1: 1.4473 - val_a_2: 1.3963 - val_b_1: 0.9600 - val_b_2: 0.9637 - val_d_1: 0.7244 - val_d_2: 0.7077 - val_n: 1.2110 - val_mean_metric: 0.2439 - lr: 0.0010
# Epoch 90/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.3103 - a_1: 1.6112 - a_2: 1.5638 - b_1: 1.1940 - b_2: 1.1851 - d_1: 1.0080 - d_2: 1.0046 - n: 1.2644 - mean_metric: 0.2898 - val_loss: 2.7644 - val_a_1: 1.4862 - val_a_2: 1.4015 - val_b_1: 0.9916 - val_b_2: 1.0494 - val_d_1: 0.7044 - val_d_2: 0.7780 - val_n: 1.2180 - val_mean_metric: 0.2511 - lr: 0.0010
# Epoch 91/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.2901 - a_1: 1.5796 - a_2: 1.5626 - b_1: 1.1766 - b_2: 1.1932 - d_1: 1.0011 - d_2: 0.9989 - n: 1.2579 - mean_metric: 0.2877 - val_loss: 2.7029 - val_a_1: 1.4270 - val_a_2: 1.4462 - val_b_1: 0.9914 - val_b_2: 1.0428 - val_d_1: 0.6662 - val_d_2: 0.7391 - val_n: 1.2130 - val_mean_metric: 0.2476 - lr: 0.0010
# Epoch 92/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.2637 - a_1: 1.5930 - a_2: 1.5542 - b_1: 1.1965 - b_2: 1.1829 - d_1: 0.9875 - d_2: 0.9855 - n: 1.2664 - mean_metric: 0.2876 - val_loss: 2.6963 - val_a_1: 1.4969 - val_a_2: 1.4004 - val_b_1: 0.9712 - val_b_2: 1.0214 - val_d_1: 0.6638 - val_d_2: 0.7187 - val_n: 1.2110 - val_mean_metric: 0.2463 - lr: 0.0010
# Epoch 93/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2935 - a_1: 1.6161 - a_2: 1.5481 - b_1: 1.1941 - b_2: 1.1785 - d_1: 1.0056 - d_2: 1.0085 - n: 1.2636 - mean_metric: 0.2891 - val_loss: 2.6498 - val_a_1: 1.4477 - val_a_2: 1.3816 - val_b_1: 0.9890 - val_b_2: 1.0023 - val_d_1: 0.6769 - val_d_2: 0.7132 - val_n: 1.2133 - val_mean_metric: 0.2443 - lr: 0.0010
# Epoch 94/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2303 - a_1: 1.5812 - a_2: 1.5566 - b_1: 1.1548 - b_2: 1.1626 - d_1: 0.9956 - d_2: 0.9893 - n: 1.2534 - mean_metric: 0.2852 - val_loss: 2.7017 - val_a_1: 1.4496 - val_a_2: 1.4252 - val_b_1: 0.9768 - val_b_2: 1.0570 - val_d_1: 0.6831 - val_d_2: 0.7103 - val_n: 1.2084 - val_mean_metric: 0.2471 - lr: 0.0010
# Epoch 95/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2326 - a_1: 1.5946 - a_2: 1.5426 - b_1: 1.1499 - b_2: 1.1779 - d_1: 0.9826 - d_2: 0.9854 - n: 1.2598 - mean_metric: 0.2852 - val_loss: 2.7145 - val_a_1: 1.4587 - val_a_2: 1.3951 - val_b_1: 1.0116 - val_b_2: 0.9356 - val_d_1: 0.7544 - val_d_2: 0.8189 - val_n: 1.2083 - val_mean_metric: 0.2495 - lr: 0.0010
# Epoch 96/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2131 - a_1: 1.5790 - a_2: 1.5495 - b_1: 1.1549 - b_2: 1.1413 - d_1: 0.9854 - d_2: 0.9878 - n: 1.2575 - mean_metric: 0.2839 - val_loss: 2.5984 - val_a_1: 1.3991 - val_a_2: 1.4372 - val_b_1: 0.9435 - val_b_2: 0.9211 - val_d_1: 0.6610 - val_d_2: 0.7139 - val_n: 1.2238 - val_mean_metric: 0.2402 - lr: 0.0010
# Epoch 97/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2583 - a_1: 1.5889 - a_2: 1.5498 - b_1: 1.1746 - b_2: 1.1736 - d_1: 1.0113 - d_2: 0.9798 - n: 1.2697 - mean_metric: 0.2870 - val_loss: 2.6157 - val_a_1: 1.4447 - val_a_2: 1.4277 - val_b_1: 0.9366 - val_b_2: 0.9644 - val_d_1: 0.6841 - val_d_2: 0.6723 - val_n: 1.2135 - val_mean_metric: 0.2416 - lr: 0.0010
# Epoch 98/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2207 - a_1: 1.5800 - a_2: 1.5464 - b_1: 1.1562 - b_2: 1.1631 - d_1: 0.9772 - d_2: 0.9872 - n: 1.2584 - mean_metric: 0.2843 - val_loss: 2.8536 - val_a_1: 1.4329 - val_a_2: 1.5032 - val_b_1: 1.0539 - val_b_2: 1.0826 - val_d_1: 0.7422 - val_d_2: 0.8788 - val_n: 1.2351 - val_mean_metric: 0.2610 - lr: 0.0010
# Epoch 99/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2283 - a_1: 1.5810 - a_2: 1.5550 - b_1: 1.1465 - b_2: 1.1660 - d_1: 0.9921 - d_2: 0.9925 - n: 1.2629 - mean_metric: 0.2853 - val_loss: 2.5891 - val_a_1: 1.4200 - val_a_2: 1.3811 - val_b_1: 0.9790 - val_b_2: 0.9366 - val_d_1: 0.6531 - val_d_2: 0.6929 - val_n: 1.2158 - val_mean_metric: 0.2395 - lr: 0.0010
# Epoch 100/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1692 - a_1: 1.5816 - a_2: 1.5158 - b_1: 1.1342 - b_2: 1.1450 - d_1: 0.9805 - d_2: 0.9615 - n: 1.2659 - mean_metric: 0.2816 - val_loss: 2.6070 - val_a_1: 1.4223 - val_a_2: 1.3917 - val_b_1: 0.9793 - val_b_2: 0.9976 - val_d_1: 0.6425 - val_d_2: 0.6847 - val_n: 1.2141 - val_mean_metric: 0.2413 - lr: 0.0010
# Epoch 101/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.1517 - a_1: 1.5804 - a_2: 1.5377 - b_1: 1.1349 - b_2: 1.1592 - d_1: 0.9621 - d_2: 0.9581 - n: 1.2492 - mean_metric: 0.2815 - val_loss: 2.5819 - val_a_1: 1.4181 - val_a_2: 1.3936 - val_b_1: 0.9579 - val_b_2: 0.9555 - val_d_1: 0.6706 - val_d_2: 0.6991 - val_n: 1.2207 - val_mean_metric: 0.2407 - lr: 0.0010
# Epoch 102/1000
# 70/70 [==============================] - 1s 10ms/step - loss: 3.2016 - a_1: 1.5817 - a_2: 1.5362 - b_1: 1.1619 - b_2: 1.1613 - d_1: 0.9910 - d_2: 0.9929 - n: 1.2610 - mean_metric: 0.2850 - val_loss: 2.5652 - val_a_1: 1.4121 - val_a_2: 1.3733 - val_b_1: 0.9816 - val_b_2: 0.9505 - val_d_1: 0.6779 - val_d_2: 0.6670 - val_n: 1.2171 - val_mean_metric: 0.2396 - lr: 0.0010
# Epoch 103/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2110 - a_1: 1.5870 - a_2: 1.5301 - b_1: 1.1709 - b_2: 1.1763 - d_1: 0.9879 - d_2: 0.9746 - n: 1.2532 - mean_metric: 0.2848 - val_loss: 2.6299 - val_a_1: 1.4641 - val_a_2: 1.4236 - val_b_1: 0.9629 - val_b_2: 0.9260 - val_d_1: 0.6435 - val_d_2: 0.6625 - val_n: 1.2218 - val_mean_metric: 0.2403 - lr: 0.0010
# Epoch 104/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2449 - a_1: 1.5687 - a_2: 1.5429 - b_1: 1.1742 - b_2: 1.1551 - d_1: 0.9852 - d_2: 0.9908 - n: 1.2652 - mean_metric: 0.2848 - val_loss: 2.7188 - val_a_1: 1.4385 - val_a_2: 1.3792 - val_b_1: 1.0361 - val_b_2: 1.0299 - val_d_1: 0.6607 - val_d_2: 0.7382 - val_n: 1.2101 - val_mean_metric: 0.2466 - lr: 0.0010
# Epoch 105/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.2409 - a_1: 1.5936 - a_2: 1.5467 - b_1: 1.1568 - b_2: 1.1622 - d_1: 0.9849 - d_2: 0.9793 - n: 1.2564 - mean_metric: 0.2848 - val_loss: 2.5916 - val_a_1: 1.4405 - val_a_2: 1.4063 - val_b_1: 0.9451 - val_b_2: 0.9244 - val_d_1: 0.6531 - val_d_2: 0.6486 - val_n: 1.2076 - val_mean_metric: 0.2378 - lr: 0.0010
# Epoch 106/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1780 - a_1: 1.5840 - a_2: 1.5318 - b_1: 1.1514 - b_2: 1.1410 - d_1: 0.9721 - d_2: 0.9614 - n: 1.2554 - mean_metric: 0.2820 - val_loss: 2.5513 - val_a_1: 1.3949 - val_a_2: 1.3638 - val_b_1: 0.9516 - val_b_2: 0.9341 - val_d_1: 0.6772 - val_d_2: 0.6598 - val_n: 1.2082 - val_mean_metric: 0.2366 - lr: 0.0010
# Epoch 107/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1667 - a_1: 1.5961 - a_2: 1.5255 - b_1: 1.1336 - b_2: 1.1429 - d_1: 0.9747 - d_2: 0.9750 - n: 1.2634 - mean_metric: 0.2825 - val_loss: 2.7297 - val_a_1: 1.4454 - val_a_2: 1.3970 - val_b_1: 1.0293 - val_b_2: 1.0955 - val_d_1: 0.6754 - val_d_2: 0.7739 - val_n: 1.2199 - val_mean_metric: 0.2513 - lr: 0.0010
# Epoch 108/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1817 - a_1: 1.5863 - a_2: 1.5156 - b_1: 1.1639 - b_2: 1.1659 - d_1: 0.9707 - d_2: 0.9611 - n: 1.2616 - mean_metric: 0.2830 - val_loss: 2.5469 - val_a_1: 1.4473 - val_a_2: 1.3539 - val_b_1: 0.9787 - val_b_2: 0.9151 - val_d_1: 0.6438 - val_d_2: 0.6621 - val_n: 1.2174 - val_mean_metric: 0.2375 - lr: 0.0010
# Epoch 109/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1785 - a_1: 1.5801 - a_2: 1.5381 - b_1: 1.1616 - b_2: 1.1491 - d_1: 0.9749 - d_2: 0.9668 - n: 1.2644 - mean_metric: 0.2833 - val_loss: 2.5678 - val_a_1: 1.3917 - val_a_2: 1.3917 - val_b_1: 0.9503 - val_b_2: 0.9993 - val_d_1: 0.6309 - val_d_2: 0.6656 - val_n: 1.2179 - val_mean_metric: 0.2385 - lr: 0.0010
# Epoch 110/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1596 - a_1: 1.5878 - a_2: 1.5327 - b_1: 1.1481 - b_2: 1.1629 - d_1: 0.9663 - d_2: 0.9394 - n: 1.2626 - mean_metric: 0.2821 - val_loss: 2.6858 - val_a_1: 1.4053 - val_a_2: 1.3984 - val_b_1: 0.9883 - val_b_2: 1.1485 - val_d_1: 0.6491 - val_d_2: 0.7395 - val_n: 1.2194 - val_mean_metric: 0.2484 - lr: 0.0010
# Epoch 111/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1569 - a_1: 1.5831 - a_2: 1.5191 - b_1: 1.1477 - b_2: 1.1624 - d_1: 0.9566 - d_2: 0.9556 - n: 1.2542 - mean_metric: 0.2814 - val_loss: 2.5733 - val_a_1: 1.4258 - val_a_2: 1.3654 - val_b_1: 1.0220 - val_b_2: 0.9350 - val_d_1: 0.6217 - val_d_2: 0.6775 - val_n: 1.2183 - val_mean_metric: 0.2391 - lr: 0.0010
# Epoch 112/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1226 - a_1: 1.5568 - a_2: 1.5387 - b_1: 1.1420 - b_2: 1.1372 - d_1: 0.9624 - d_2: 0.9404 - n: 1.2570 - mean_metric: 0.2799 - val_loss: 2.4580 - val_a_1: 1.3890 - val_a_2: 1.3529 - val_b_1: 0.8902 - val_b_2: 0.9120 - val_d_1: 0.6279 - val_d_2: 0.6111 - val_n: 1.2183 - val_mean_metric: 0.2304 - lr: 0.0010
# Epoch 113/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1221 - a_1: 1.5688 - a_2: 1.5235 - b_1: 1.1473 - b_2: 1.1289 - d_1: 0.9667 - d_2: 0.9611 - n: 1.2596 - mean_metric: 0.2807 - val_loss: 2.5154 - val_a_1: 1.3965 - val_a_2: 1.3774 - val_b_1: 0.9515 - val_b_2: 0.9020 - val_d_1: 0.6502 - val_d_2: 0.6649 - val_n: 1.2127 - val_mean_metric: 0.2354 - lr: 0.0010
# Epoch 114/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1243 - a_1: 1.5580 - a_2: 1.5218 - b_1: 1.1564 - b_2: 1.1316 - d_1: 0.9695 - d_2: 0.9462 - n: 1.2646 - mean_metric: 0.2805 - val_loss: 2.4914 - val_a_1: 1.3783 - val_a_2: 1.3625 - val_b_1: 0.9313 - val_b_2: 0.8959 - val_d_1: 0.6227 - val_d_2: 0.6852 - val_n: 1.2137 - val_mean_metric: 0.2333 - lr: 0.0010
# Epoch 115/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1337 - a_1: 1.5656 - a_2: 1.5244 - b_1: 1.1415 - b_2: 1.1443 - d_1: 0.9579 - d_2: 0.9362 - n: 1.2573 - mean_metric: 0.2797 - val_loss: 2.8481 - val_a_1: 1.6341 - val_a_2: 1.4260 - val_b_1: 0.9995 - val_b_2: 0.9574 - val_d_1: 0.7263 - val_d_2: 0.9105 - val_n: 1.2164 - val_mean_metric: 0.2589 - lr: 0.0010
# Epoch 116/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1708 - a_1: 1.5829 - a_2: 1.5073 - b_1: 1.1720 - b_2: 1.1642 - d_1: 0.9811 - d_2: 0.9679 - n: 1.2525 - mean_metric: 0.2830 - val_loss: 2.7870 - val_a_1: 1.4195 - val_a_2: 1.5030 - val_b_1: 0.9789 - val_b_2: 1.0417 - val_d_1: 0.8132 - val_d_2: 0.8684 - val_n: 1.2186 - val_mean_metric: 0.2582 - lr: 0.0010
# Epoch 117/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1349 - a_1: 1.5647 - a_2: 1.5286 - b_1: 1.1380 - b_2: 1.1382 - d_1: 0.9548 - d_2: 0.9522 - n: 1.2522 - mean_metric: 0.2798 - val_loss: 2.5285 - val_a_1: 1.4141 - val_a_2: 1.3969 - val_b_1: 0.9473 - val_b_2: 0.9441 - val_d_1: 0.6215 - val_d_2: 0.6317 - val_n: 1.2040 - val_mean_metric: 0.2356 - lr: 0.0010
# Epoch 118/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1406 - a_1: 1.5716 - a_2: 1.5253 - b_1: 1.1404 - b_2: 1.1412 - d_1: 0.9661 - d_2: 0.9524 - n: 1.2560 - mean_metric: 0.2806 - val_loss: 2.5028 - val_a_1: 1.3799 - val_a_2: 1.3590 - val_b_1: 0.8953 - val_b_2: 0.9318 - val_d_1: 0.6640 - val_d_2: 0.6853 - val_n: 1.2165 - val_mean_metric: 0.2347 - lr: 0.0010
# Epoch 119/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.0821 - a_1: 1.5617 - a_2: 1.5210 - b_1: 1.1289 - b_2: 1.1183 - d_1: 0.9397 - d_2: 0.9297 - n: 1.2612 - mean_metric: 0.2775 - val_loss: 2.6711 - val_a_1: 1.4148 - val_a_2: 1.3684 - val_b_1: 0.9515 - val_b_2: 1.2023 - val_d_1: 0.6793 - val_d_2: 0.7431 - val_n: 1.2229 - val_mean_metric: 0.2495 - lr: 0.0010
# Epoch 120/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1343 - a_1: 1.5725 - a_2: 1.5271 - b_1: 1.1353 - b_2: 1.1570 - d_1: 0.9542 - d_2: 0.9424 - n: 1.2544 - mean_metric: 0.2802 - val_loss: 2.5136 - val_a_1: 1.3819 - val_a_2: 1.3702 - val_b_1: 0.9508 - val_b_2: 0.9514 - val_d_1: 0.6206 - val_d_2: 0.6390 - val_n: 1.2131 - val_mean_metric: 0.2345 - lr: 0.0010
# Epoch 121/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1089 - a_1: 1.5688 - a_2: 1.5013 - b_1: 1.1460 - b_2: 1.1366 - d_1: 0.9606 - d_2: 0.9559 - n: 1.2606 - mean_metric: 0.2799 - val_loss: 2.5758 - val_a_1: 1.4469 - val_a_2: 1.4029 - val_b_1: 1.0230 - val_b_2: 0.9045 - val_d_1: 0.6157 - val_d_2: 0.6960 - val_n: 1.2190 - val_mean_metric: 0.2405 - lr: 0.0010
# Epoch 122/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.1151 - a_1: 1.5550 - a_2: 1.5206 - b_1: 1.1457 - b_2: 1.1412 - d_1: 0.9456 - d_2: 0.9537 - n: 1.2592 - mean_metric: 0.2795 - val_loss: 2.4379 - val_a_1: 1.3937 - val_a_2: 1.3408 - val_b_1: 0.8954 - val_b_2: 0.9028 - val_d_1: 0.6298 - val_d_2: 0.6068 - val_n: 1.2097 - val_mean_metric: 0.2297 - lr: 0.0010
# Epoch 123/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.0927 - a_1: 1.5624 - a_2: 1.5426 - b_1: 1.1313 - b_2: 1.1287 - d_1: 0.9507 - d_2: 0.9463 - n: 1.2514 - mean_metric: 0.2793 - val_loss: 2.4437 - val_a_1: 1.3736 - val_a_2: 1.3413 - val_b_1: 0.9303 - val_b_2: 0.8922 - val_d_1: 0.6322 - val_d_2: 0.6397 - val_n: 1.2096 - val_mean_metric: 0.2309 - lr: 0.0010
# Epoch 124/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.0459 - a_1: 1.5456 - a_2: 1.5108 - b_1: 1.1403 - b_2: 1.1145 - d_1: 0.9362 - d_2: 0.9185 - n: 1.2588 - mean_metric: 0.2763 - val_loss: 2.4507 - val_a_1: 1.3951 - val_a_2: 1.3564 - val_b_1: 0.9059 - val_b_2: 0.8818 - val_d_1: 0.6673 - val_d_2: 0.6262 - val_n: 1.2131 - val_mean_metric: 0.2318 - lr: 0.0010
# Epoch 125/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 3.0707 - a_1: 1.5661 - a_2: 1.5180 - b_1: 1.1254 - b_2: 1.1305 - d_1: 0.9324 - d_2: 0.9328 - n: 1.2615 - mean_metric: 0.2778 - val_loss: 2.5010 - val_a_1: 1.4402 - val_a_2: 1.3579 - val_b_1: 0.9290 - val_b_2: 0.9164 - val_d_1: 0.6510 - val_d_2: 0.6655 - val_n: 1.2156 - val_mean_metric: 0.2362 - lr: 0.0010
# Epoch 126/1000
# ...
# Epoch 960/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.2077 - a_1: 1.2958 - a_2: 1.2803 - b_1: 0.9596 - b_2: 0.9598 - d_1: 0.7645 - d_2: 0.7912 - n: 0.8621 - mean_metric: 0.2269 - val_loss: 1.6162 - val_a_1: 1.0463 - val_a_2: 1.0650 - val_b_1: 0.6805 - val_b_2: 0.6377 - val_d_1: 0.4579 - val_d_2: 0.4029 - val_n: 0.7347 - val_mean_metric: 0.1653 - lr: 7.7650e-05
# Epoch 961/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1894 - a_1: 1.2786 - a_2: 1.2785 - b_1: 0.9418 - b_2: 0.9481 - d_1: 0.7699 - d_2: 0.7800 - n: 0.8705 - mean_metric: 0.2253 - val_loss: 1.6029 - val_a_1: 1.0426 - val_a_2: 1.0646 - val_b_1: 0.6644 - val_b_2: 0.6387 - val_d_1: 0.4114 - val_d_2: 0.3949 - val_n: 0.7373 - val_mean_metric: 0.1630 - lr: 7.6000e-05
# Epoch 962/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1909 - a_1: 1.2883 - a_2: 1.2680 - b_1: 0.9515 - b_2: 0.9445 - d_1: 0.7810 - d_2: 0.7729 - n: 0.8747 - mean_metric: 0.2258 - val_loss: 1.6035 - val_a_1: 1.0453 - val_a_2: 1.0566 - val_b_1: 0.6823 - val_b_2: 0.6474 - val_d_1: 0.4181 - val_d_2: 0.3970 - val_n: 0.7382 - val_mean_metric: 0.1640 - lr: 7.4350e-05
# Epoch 963/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1813 - a_1: 1.2786 - a_2: 1.2658 - b_1: 0.9522 - b_2: 0.9405 - d_1: 0.7609 - d_2: 0.7634 - n: 0.8729 - mean_metric: 0.2242 - val_loss: 1.6222 - val_a_1: 1.0488 - val_a_2: 1.0800 - val_b_1: 0.6706 - val_b_2: 0.6369 - val_d_1: 0.4365 - val_d_2: 0.3971 - val_n: 0.7565 - val_mean_metric: 0.1654 - lr: 7.2700e-05
# Epoch 964/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.2064 - a_1: 1.2951 - a_2: 1.2638 - b_1: 0.9488 - b_2: 0.9543 - d_1: 0.7799 - d_2: 0.7793 - n: 0.8715 - mean_metric: 0.2262 - val_loss: 1.6079 - val_a_1: 1.0454 - val_a_2: 1.0679 - val_b_1: 0.6802 - val_b_2: 0.6413 - val_d_1: 0.4169 - val_d_2: 0.3921 - val_n: 0.7424 - val_mean_metric: 0.1641 - lr: 7.1050e-05
# Epoch 965/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.2029 - a_1: 1.2901 - a_2: 1.2848 - b_1: 0.9485 - b_2: 0.9679 - d_1: 0.7755 - d_2: 0.7742 - n: 0.8670 - mean_metric: 0.2266 - val_loss: 1.6573 - val_a_1: 1.0607 - val_a_2: 1.0899 - val_b_1: 0.6861 - val_b_2: 0.6461 - val_d_1: 0.4534 - val_d_2: 0.4554 - val_n: 0.7642 - val_mean_metric: 0.1696 - lr: 6.9400e-05
# Epoch 966/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1896 - a_1: 1.2753 - a_2: 1.2745 - b_1: 0.9508 - b_2: 0.9351 - d_1: 0.7622 - d_2: 0.7812 - n: 0.8665 - mean_metric: 0.2246 - val_loss: 1.6153 - val_a_1: 1.0446 - val_a_2: 1.0690 - val_b_1: 0.6686 - val_b_2: 0.6406 - val_d_1: 0.4227 - val_d_2: 0.4152 - val_n: 0.7461 - val_mean_metric: 0.1647 - lr: 6.7750e-05
# Epoch 967/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1915 - a_1: 1.2796 - a_2: 1.2691 - b_1: 0.9485 - b_2: 0.9387 - d_1: 0.7686 - d_2: 0.7763 - n: 0.8791 - mean_metric: 0.2250 - val_loss: 1.6155 - val_a_1: 1.0447 - val_a_2: 1.0715 - val_b_1: 0.6704 - val_b_2: 0.6386 - val_d_1: 0.4386 - val_d_2: 0.3937 - val_n: 0.7421 - val_mean_metric: 0.1645 - lr: 6.6100e-05
# Epoch 968/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1912 - a_1: 1.2847 - a_2: 1.2630 - b_1: 0.9498 - b_2: 0.9461 - d_1: 0.7819 - d_2: 0.7774 - n: 0.8643 - mean_metric: 0.2253 - val_loss: 1.6439 - val_a_1: 1.0496 - val_a_2: 1.0948 - val_b_1: 0.6856 - val_b_2: 0.6494 - val_d_1: 0.4637 - val_d_2: 0.4336 - val_n: 0.7439 - val_mean_metric: 0.1685 - lr: 6.4450e-05
# Epoch 969/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1947 - a_1: 1.2880 - a_2: 1.2665 - b_1: 0.9549 - b_2: 0.9530 - d_1: 0.7719 - d_2: 0.7752 - n: 0.8663 - mean_metric: 0.2256 - val_loss: 1.6343 - val_a_1: 1.0644 - val_a_2: 1.0710 - val_b_1: 0.6827 - val_b_2: 0.6489 - val_d_1: 0.4339 - val_d_2: 0.4650 - val_n: 0.7339 - val_mean_metric: 0.1678 - lr: 6.2800e-05
# Epoch 970/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1889 - a_1: 1.2797 - a_2: 1.2751 - b_1: 0.9573 - b_2: 0.9464 - d_1: 0.7671 - d_2: 0.7727 - n: 0.8691 - mean_metric: 0.2253 - val_loss: 1.6095 - val_a_1: 1.0521 - val_a_2: 1.0659 - val_b_1: 0.6827 - val_b_2: 0.6340 - val_d_1: 0.4072 - val_d_2: 0.4249 - val_n: 0.7334 - val_mean_metric: 0.1645 - lr: 6.1150e-05
# Epoch 971/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1784 - a_1: 1.2944 - a_2: 1.2565 - b_1: 0.9335 - b_2: 0.9443 - d_1: 0.7659 - d_2: 0.7847 - n: 0.8750 - mean_metric: 0.2249 - val_loss: 1.6121 - val_a_1: 1.0471 - val_a_2: 1.0559 - val_b_1: 0.6802 - val_b_2: 0.6393 - val_d_1: 0.4251 - val_d_2: 0.4222 - val_n: 0.7358 - val_mean_metric: 0.1647 - lr: 5.9500e-05
# Epoch 972/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1891 - a_1: 1.2887 - a_2: 1.2769 - b_1: 0.9335 - b_2: 0.9302 - d_1: 0.7760 - d_2: 0.7913 - n: 0.8662 - mean_metric: 0.2251 - val_loss: 1.6419 - val_a_1: 1.0497 - val_a_2: 1.0814 - val_b_1: 0.6842 - val_b_2: 0.6535 - val_d_1: 0.4377 - val_d_2: 0.4662 - val_n: 0.7396 - val_mean_metric: 0.1682 - lr: 5.7850e-05
# Epoch 973/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1928 - a_1: 1.2764 - a_2: 1.2683 - b_1: 0.9667 - b_2: 0.9409 - d_1: 0.7690 - d_2: 0.7866 - n: 0.8674 - mean_metric: 0.2255 - val_loss: 1.6052 - val_a_1: 1.0431 - val_a_2: 1.0610 - val_b_1: 0.6719 - val_b_2: 0.6325 - val_d_1: 0.4036 - val_d_2: 0.3972 - val_n: 0.7487 - val_mean_metric: 0.1631 - lr: 5.6200e-05
# Epoch 974/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1882 - a_1: 1.2878 - a_2: 1.2672 - b_1: 0.9509 - b_2: 0.9348 - d_1: 0.7720 - d_2: 0.7814 - n: 0.8726 - mean_metric: 0.2253 - val_loss: 1.6284 - val_a_1: 1.0584 - val_a_2: 1.0713 - val_b_1: 0.6863 - val_b_2: 0.6476 - val_d_1: 0.4065 - val_d_2: 0.4265 - val_n: 0.7455 - val_mean_metric: 0.1659 - lr: 5.4550e-05
# Epoch 975/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1817 - a_1: 1.2841 - a_2: 1.2638 - b_1: 0.9529 - b_2: 0.9404 - d_1: 0.7586 - d_2: 0.7742 - n: 0.8661 - mean_metric: 0.2244 - val_loss: 1.6194 - val_a_1: 1.0471 - val_a_2: 1.0654 - val_b_1: 0.6762 - val_b_2: 0.6413 - val_d_1: 0.4254 - val_d_2: 0.4088 - val_n: 0.7476 - val_mean_metric: 0.1649 - lr: 5.2900e-05
# Epoch 976/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1953 - a_1: 1.3013 - a_2: 1.2675 - b_1: 0.9477 - b_2: 0.9460 - d_1: 0.7725 - d_2: 0.7723 - n: 0.8718 - mean_metric: 0.2257 - val_loss: 1.6064 - val_a_1: 1.0519 - val_a_2: 1.0615 - val_b_1: 0.6653 - val_b_2: 0.6399 - val_d_1: 0.4195 - val_d_2: 0.4040 - val_n: 0.7381 - val_mean_metric: 0.1639 - lr: 5.1250e-05
# Epoch 977/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1945 - a_1: 1.2978 - a_2: 1.2664 - b_1: 0.9560 - b_2: 0.9431 - d_1: 0.7717 - d_2: 0.7626 - n: 0.8720 - mean_metric: 0.2253 - val_loss: 1.6472 - val_a_1: 1.0576 - val_a_2: 1.0737 - val_b_1: 0.6931 - val_b_2: 0.6586 - val_d_1: 0.4307 - val_d_2: 0.4670 - val_n: 0.7439 - val_mean_metric: 0.1686 - lr: 4.9600e-05
# Epoch 978/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1983 - a_1: 1.2903 - a_2: 1.2543 - b_1: 0.9529 - b_2: 0.9468 - d_1: 0.7646 - d_2: 0.7828 - n: 0.8805 - mean_metric: 0.2255 - val_loss: 1.6254 - val_a_1: 1.0526 - val_a_2: 1.0689 - val_b_1: 0.6758 - val_b_2: 0.6362 - val_d_1: 0.4253 - val_d_2: 0.4329 - val_n: 0.7501 - val_mean_metric: 0.1659 - lr: 4.7950e-05
# Epoch 979/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1993 - a_1: 1.2885 - a_2: 1.2663 - b_1: 0.9572 - b_2: 0.9472 - d_1: 0.7689 - d_2: 0.7753 - n: 0.8767 - mean_metric: 0.2257 - val_loss: 1.6462 - val_a_1: 1.0600 - val_a_2: 1.0725 - val_b_1: 0.6829 - val_b_2: 0.6432 - val_d_1: 0.4527 - val_d_2: 0.4483 - val_n: 0.7494 - val_mean_metric: 0.1681 - lr: 4.6300e-05
# Epoch 980/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1821 - a_1: 1.2906 - a_2: 1.2694 - b_1: 0.9407 - b_2: 0.9274 - d_1: 0.7739 - d_2: 0.7680 - n: 0.8688 - mean_metric: 0.2243 - val_loss: 1.6227 - val_a_1: 1.0543 - val_a_2: 1.0710 - val_b_1: 0.6731 - val_b_2: 0.6345 - val_d_1: 0.4067 - val_d_2: 0.4182 - val_n: 0.7512 - val_mean_metric: 0.1648 - lr: 4.4650e-05
# Epoch 981/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1966 - a_1: 1.2956 - a_2: 1.2611 - b_1: 0.9446 - b_2: 0.9487 - d_1: 0.7711 - d_2: 0.7863 - n: 0.8748 - mean_metric: 0.2258 - val_loss: 1.6256 - val_a_1: 1.0470 - val_a_2: 1.0726 - val_b_1: 0.6757 - val_b_2: 0.6503 - val_d_1: 0.4200 - val_d_2: 0.4343 - val_n: 0.7492 - val_mean_metric: 0.1661 - lr: 4.3000e-05
# Epoch 982/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1902 - a_1: 1.2781 - a_2: 1.2797 - b_1: 0.9670 - b_2: 0.9296 - d_1: 0.7639 - d_2: 0.7775 - n: 0.8633 - mean_metric: 0.2251 - val_loss: 1.6260 - val_a_1: 1.0581 - val_a_2: 1.0693 - val_b_1: 0.6774 - val_b_2: 0.6406 - val_d_1: 0.4255 - val_d_2: 0.4367 - val_n: 0.7466 - val_mean_metric: 0.1663 - lr: 4.1350e-05
# Epoch 983/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1890 - a_1: 1.2948 - a_2: 1.2686 - b_1: 0.9483 - b_2: 0.9410 - d_1: 0.7662 - d_2: 0.7792 - n: 0.8709 - mean_metric: 0.2253 - val_loss: 1.6135 - val_a_1: 1.0518 - val_a_2: 1.0665 - val_b_1: 0.6804 - val_b_2: 0.6393 - val_d_1: 0.4178 - val_d_2: 0.4259 - val_n: 0.7335 - val_mean_metric: 0.1650 - lr: 3.9700e-05
# Epoch 984/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1646 - a_1: 1.2680 - a_2: 1.2624 - b_1: 0.9407 - b_2: 0.9382 - d_1: 0.7671 - d_2: 0.7691 - n: 0.8650 - mean_metric: 0.2233 - val_loss: 1.6224 - val_a_1: 1.0522 - val_a_2: 1.0625 - val_b_1: 0.6773 - val_b_2: 0.6347 - val_d_1: 0.4093 - val_d_2: 0.4293 - val_n: 0.7515 - val_mean_metric: 0.1650 - lr: 3.8050e-05
# Epoch 985/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1900 - a_1: 1.2903 - a_2: 1.2512 - b_1: 0.9486 - b_2: 0.9555 - d_1: 0.7729 - d_2: 0.7850 - n: 0.8649 - mean_metric: 0.2254 - val_loss: 1.6087 - val_a_1: 1.0505 - val_a_2: 1.0491 - val_b_1: 0.6678 - val_b_2: 0.6392 - val_d_1: 0.4139 - val_d_2: 0.4145 - val_n: 0.7441 - val_mean_metric: 0.1638 - lr: 3.6400e-05
# Epoch 986/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1723 - a_1: 1.2779 - a_2: 1.2703 - b_1: 0.9446 - b_2: 0.9362 - d_1: 0.7587 - d_2: 0.7728 - n: 0.8617 - mean_metric: 0.2239 - val_loss: 1.6042 - val_a_1: 1.0479 - val_a_2: 1.0560 - val_b_1: 0.6735 - val_b_2: 0.6335 - val_d_1: 0.4008 - val_d_2: 0.4155 - val_n: 0.7371 - val_mean_metric: 0.1633 - lr: 3.4750e-05
# Epoch 987/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1851 - a_1: 1.2862 - a_2: 1.2644 - b_1: 0.9492 - b_2: 0.9364 - d_1: 0.7741 - d_2: 0.7848 - n: 0.8763 - mean_metric: 0.2254 - val_loss: 1.6304 - val_a_1: 1.0561 - val_a_2: 1.0710 - val_b_1: 0.6913 - val_b_2: 0.6405 - val_d_1: 0.4215 - val_d_2: 0.4394 - val_n: 0.7447 - val_mean_metric: 0.1666 - lr: 3.3100e-05
# Epoch 988/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1807 - a_1: 1.2793 - a_2: 1.2575 - b_1: 0.9483 - b_2: 0.9349 - d_1: 0.7727 - d_2: 0.7763 - n: 0.8650 - mean_metric: 0.2242 - val_loss: 1.6259 - val_a_1: 1.0549 - val_a_2: 1.0534 - val_b_1: 0.6816 - val_b_2: 0.6445 - val_d_1: 0.4325 - val_d_2: 0.4663 - val_n: 0.7386 - val_mean_metric: 0.1669 - lr: 3.1450e-05
# Epoch 989/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1799 - a_1: 1.2897 - a_2: 1.2641 - b_1: 0.9465 - b_2: 0.9375 - d_1: 0.7595 - d_2: 0.7818 - n: 0.8629 - mean_metric: 0.2245 - val_loss: 1.6184 - val_a_1: 1.0566 - val_a_2: 1.0566 - val_b_1: 0.6853 - val_b_2: 0.6392 - val_d_1: 0.4270 - val_d_2: 0.4286 - val_n: 0.7400 - val_mean_metric: 0.1656 - lr: 2.9800e-05
# Epoch 990/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1690 - a_1: 1.2792 - a_2: 1.2685 - b_1: 0.9346 - b_2: 0.9303 - d_1: 0.7614 - d_2: 0.7716 - n: 0.8634 - mean_metric: 0.2234 - val_loss: 1.6077 - val_a_1: 1.0555 - val_a_2: 1.0502 - val_b_1: 0.6709 - val_b_2: 0.6346 - val_d_1: 0.4168 - val_d_2: 0.4307 - val_n: 0.7396 - val_mean_metric: 0.1644 - lr: 2.8150e-05
# Epoch 991/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1830 - a_1: 1.2860 - a_2: 1.2588 - b_1: 0.9351 - b_2: 0.9492 - d_1: 0.7661 - d_2: 0.7711 - n: 0.8700 - mean_metric: 0.2243 - val_loss: 1.6189 - val_a_1: 1.0541 - val_a_2: 1.0555 - val_b_1: 0.6869 - val_b_2: 0.6390 - val_d_1: 0.4119 - val_d_2: 0.4375 - val_n: 0.7455 - val_mean_metric: 0.1655 - lr: 2.6500e-05
# Epoch 992/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1844 - a_1: 1.2944 - a_2: 1.2693 - b_1: 0.9507 - b_2: 0.9387 - d_1: 0.7701 - d_2: 0.7736 - n: 0.8579 - mean_metric: 0.2248 - val_loss: 1.6083 - val_a_1: 1.0510 - val_a_2: 1.0527 - val_b_1: 0.6755 - val_b_2: 0.6288 - val_d_1: 0.4211 - val_d_2: 0.4107 - val_n: 0.7435 - val_mean_metric: 0.1640 - lr: 2.4850e-05
# Epoch 993/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1673 - a_1: 1.2702 - a_2: 1.2589 - b_1: 0.9552 - b_2: 0.9328 - d_1: 0.7627 - d_2: 0.7718 - n: 0.8669 - mean_metric: 0.2237 - val_loss: 1.6050 - val_a_1: 1.0477 - val_a_2: 1.0464 - val_b_1: 0.6757 - val_b_2: 0.6342 - val_d_1: 0.4158 - val_d_2: 0.4128 - val_n: 0.7419 - val_mean_metric: 0.1637 - lr: 2.3200e-05
# Epoch 994/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.2002 - a_1: 1.2951 - a_2: 1.2684 - b_1: 0.9581 - b_2: 0.9450 - d_1: 0.7709 - d_2: 0.7656 - n: 0.8734 - mean_metric: 0.2256 - val_loss: 1.6038 - val_a_1: 1.0460 - val_a_2: 1.0482 - val_b_1: 0.6721 - val_b_2: 0.6382 - val_d_1: 0.4158 - val_d_2: 0.4143 - val_n: 0.7416 - val_mean_metric: 0.1637 - lr: 2.1550e-05
# Epoch 995/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1887 - a_1: 1.2912 - a_2: 1.2760 - b_1: 0.9436 - b_2: 0.9547 - d_1: 0.7492 - d_2: 0.7737 - n: 0.8819 - mean_metric: 0.2254 - val_loss: 1.6094 - val_a_1: 1.0483 - val_a_2: 1.0505 - val_b_1: 0.6780 - val_b_2: 0.6360 - val_d_1: 0.4236 - val_d_2: 0.4298 - val_n: 0.7384 - val_mean_metric: 0.1647 - lr: 1.9900e-05
# Epoch 996/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1648 - a_1: 1.2806 - a_2: 1.2547 - b_1: 0.9580 - b_2: 0.9223 - d_1: 0.7679 - d_2: 0.7626 - n: 0.8594 - mean_metric: 0.2232 - val_loss: 1.6002 - val_a_1: 1.0471 - val_a_2: 1.0479 - val_b_1: 0.6758 - val_b_2: 0.6335 - val_d_1: 0.4085 - val_d_2: 0.4140 - val_n: 0.7374 - val_mean_metric: 0.1633 - lr: 1.8250e-05
# Epoch 997/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1696 - a_1: 1.2752 - a_2: 1.2758 - b_1: 0.9337 - b_2: 0.9344 - d_1: 0.7729 - d_2: 0.7603 - n: 0.8683 - mean_metric: 0.2238 - val_loss: 1.6038 - val_a_1: 1.0445 - val_a_2: 1.0499 - val_b_1: 0.6784 - val_b_2: 0.6353 - val_d_1: 0.4204 - val_d_2: 0.4154 - val_n: 0.7345 - val_mean_metric: 0.1638 - lr: 1.6600e-05
# Epoch 998/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1760 - a_1: 1.2838 - a_2: 1.2562 - b_1: 0.9551 - b_2: 0.9296 - d_1: 0.7564 - d_2: 0.7658 - n: 0.8729 - mean_metric: 0.2237 - val_loss: 1.6211 - val_a_1: 1.0495 - val_a_2: 1.0543 - val_b_1: 0.6827 - val_b_2: 0.6472 - val_d_1: 0.4352 - val_d_2: 0.4473 - val_n: 0.7367 - val_mean_metric: 0.1662 - lr: 1.4950e-05
# Epoch 999/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1679 - a_1: 1.2675 - a_2: 1.2689 - b_1: 0.9373 - b_2: 0.9527 - d_1: 0.7552 - d_2: 0.7638 - n: 0.8717 - mean_metric: 0.2237 - val_loss: 1.6086 - val_a_1: 1.0470 - val_a_2: 1.0525 - val_b_1: 0.6805 - val_b_2: 0.6369 - val_d_1: 0.4140 - val_d_2: 0.4339 - val_n: 0.7349 - val_mean_metric: 0.1645 - lr: 1.3300e-05
# Epoch 1000/1000
# 70/70 [==============================] - 1s 11ms/step - loss: 2.1747 - a_1: 1.2627 - a_2: 1.2636 - b_1: 0.9373 - b_2: 0.9528 - d_1: 0.7599 - d_2: 0.7795 - n: 0.8701 - mean_metric: 0.2239 - val_loss: 1.6063 - val_a_1: 1.0459 - val_a_2: 1.0498 - val_b_1: 0.6824 - val_b_2: 0.6317 - val_d_1: 0.4197 - val_d_2: 0.4265 - val_n: 0.7355 - val_mean_metric: 0.1642 - lr: 1.1650e-05

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(val_epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    campvectest, coefcampvectest)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 1.6857 - a_1: 1.1015 - a_2: 1.1262 - b_1: 0.6703 - b_2: 0.6816 - d_1: 0.4139 - d_2: 0.4131 - n: 0.7380 - mean_metric: 0.1710

# %%
predictions = model.predict(campvectest)
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
print(coefcampvectest[0,:])
print(predictions[0,:])
from sklearn.metrics import mean_absolute_error
print(np.sum(coefcampvectest, axis=-1))

mae1 = mean_absolute_error(coefcampvectest[0,:], predictions[0,:])
mae1
# Out:
# [ 4  8  1 10  8  7  4]
# [3.5134323 7.999728  1.174232  8.613667  7.396215  6.5528407 2.5348613]
# [42 39 36 35 32 23 38 42 29 19 26 29 39 31 47 33 18 48 31 32 31 30 52 26
#  31 37 41 23 20 33 35 36 30 42 32 37 35 34 34 38 35 32 31 39 37 33 31 39
#  34 30 45 33 36 27 23 33 40 39 37 32 29 44 23 22 35 34 35 38 31 22 40 28
#  25 15 33 19 31 37 47 26 38 37 26 26 31 28 37 30 34 25 25 47 38 24 47 18
#  32 25 28 32 25 35 43 41 33 31 39 35 25 29 31 30 43 24 32 28 35 33 36 39
#  31 29 29 41 32 44 19 28 31 37 36 39 24 28 26 40 28 34 27 20 34 34 28 35
#  36 37 42 30 18 41 32 27 30 31 33 31 31 45 28 52 33 47 31 36 30 43 45 37
#  30 29 46 45 25 30 42 17 33 37 30 30 27 30 25 34 13 23 16 21 37 32 33 26
#  20 44 27 37 28 24 28 41 38 47 23 31 25 46 37 32 21 23 20 43 27 27 23 36
#  24 21 40 36 28 46 48 31 38 37 45 35 30 32 42 33 39 24 24 27 44 27 36 30
#  43 28 31 25 15 30 36 32 33 28 39 29 30 34 33 28 45 40 34 34 32 13 31 36
#  29 34 31 36 26 34 33 39 27 26 36 38 37 24 36 37 32 24 31 40 46 29 44 39
#  44 31 32 41 29 31 43 26 32 39 37 47 25 21 14 32 41 32 40 33 28 42 31 46
#  39 52 46 37 34 41 25 41 41 34 25 34 34 30 54 33 34 27 40 38 24 29 23 17
#  33 29 29 24 33 31 30 33 42 19 31 34 49 57 37 40 28 29 23 21 41 36 29 40
#  26 47 33 30 43 15 18 30 31 52 34 41 32 31 26 36 30 27 36 41 20 33 26 30
#  31 46 44 37 37 26 40 40 34 50 30 43 31 19 39 25 25 25 37 39 31 36 21 36
#  39 38 32 32 24 38 40 35 30 39 18 46 28 39 32 34 32 42 30 28 33 37 36 26
#  30 31 26 23 26 39 29 25 35 24 14 32 34 37 30 36 25 28 26 18 36 41 29 36
#  29 32 35 45 36 31 36 25 29 20 32 29 29 38 32 27 28 33 26 43 29 41 30 37
#  30 43 39 27 24 47 37 25 24 33 54 34 26 28 48 22 42 35 35 30 40 30 38 19
#  34 36 35 15 24 34 25 23 29 28 38 31 31 38 23 19 34 24 45 31 40 22 36 45
#  28 21 36 38 26 34 33 36 27 23 19 33 36 35 21 39 37 34 29 36 33 17 35 21
#  27 34 37 40 26 34 38 43 34 32 23 37 32 23 17 41 36 42 30 19 40 36 37 30
#  28 39 24 31 41 16 32 28 34 40 33 36 34 25 24 25 20 35 26 25 36 26 34 45
#  36 30 25 39 28 35 38 32 25 31 33 19 28 25 27 34 29 33 38 32 24 23 35 34
#  35 46 43 27 35 30 27 15 43 20 29 25 23 29 26 30 36 37 28 14 33 44 40 28
#  31 26 26 44 28 27 31 47 38 26 40 33 30 29 26 21 27 31 15 48 31 38 35 25
#  21 34 36 24 30 25 37 40 39 29 43 12 32 18 28 35 26 40 34 44 28 27 27 28
#  25 23 38 32 34 22 24 41 30 23 46 21 25 21 46 21 24 43 32 38 13 39 45 39
#  29 38 40 38 35 21 36 53 39 31 27 17 38 26 20 42 41 48 50 19 24 17 19 19
#  35 31 11 26 33 25 29 22 41 39 33 51 18 35 27 31 30 41 21 38 42 18 40 42
#  35 27 41 43 33 29 31 26 39 26 35 31 32 36 34 41 33 41 33 25 29 32 42 30
#  31 36 44 25 28 21 43 41 33 24 36 29 37 28 32 35 46 20 31 32 34 22 45 13
#  29 42 27 44 27 31 34 24 36 52 27 42 32 23 23 44 30 19 40 42 34 19 50 43
#  40 30 31 45 34 35 37 31 37 46 21 41 41 27 32 37 15 43 26 24 26 33 29 14
#  34 32 41 33 34 31 17 34 43 18 46 21 29 40 36 33 17 22 37 17 32 24 35 19
#  31 28 28 37 37 46 42 39 40 47 39 40 15 45 23 30 40 17 32 20 29 28 34 31
#  40 26 42 28 36 26 29 41 34 28 33 24 41 21 30 19 27 21 31 32 33 16 36 24
#  36 32 39 30 38 38 35 23 20 45 37 21 47 36 36 43 34 34 49 12 38 39 28 38
#  34 34 36 27 31 27 11 30 25 35 23 35 34 30 31 29 32 33 39 45 50 24 27 29
#  19 37 31 40 39 43 34 33 38 47 34 39 35 28 30 30]
# 0.6519268580845424

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefcampvectest, predictions)

# Calcula la desviación estándar del error
error = coefcampvectest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 0.7345410900626864, Desviación estándar del error: 1.104814714519351, Error absoluto máximo: 8.884089231491089

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefcampvectest - predictions)

# Calcula el error para cada dato
error = coefcampvectest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefcampvectest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.17582364914606413
# Desviación estándar del error relativo: 0.09494177491647524
# Error absoluto máximo relativo: 0.41316630290104794

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales con ruido/History 20,50/historyconvcampvec20.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos con ruido/Modelos 20,50/'

# %%
model.save(path_to_save + '/convolucionalcv20.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_activation':custom_activation,'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)

new_model = keras.models.load_model('../../../Modelos con ruido/Modelos 20,50/convolucionalcv20.h5', custom_objects=custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 20)
    y2 = np.linspace(y_range_neg, y_range_pos, 20)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [5, 4, 9, 3, 0, 10, 3]

# %%
campvecnone = campvec[None, :]
campvecnone = np.transpose(campvecnone, (0,2,3,1))

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# [[8. 5. 7. 6. 0. 7. 4.]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 20)
y2 = np.linspace(0, 10, 20)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
plt.show()

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1 = np.linspace(x_range_neg, x_range_pos, 20)
y2 = np.linspace(y_range_neg, y_range_pos, 20)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
