# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_5328\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos/Campo 20 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')
campvectrain = np.transpose(campvectrain, (0,2,3,1))

# %%
np.shape(campvectrain)
# Out:
# (7000, 20, 20, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')
campvectest = np.transpose(campvectest, (0,2,3,1))

# %%
np.shape(campvectest)
# Out:
# (2000, 20, 20, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')
campvecval = np.transpose(campvecval, (0,2,3,1))

# %%
np.shape(campvecval)
# Out:
# (1000, 20, 20, 2)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(20, 20, 2), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 10
SHUFFLE_BUFFER_SIZE = 10

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
# Primera capa convolucional
model.add(Conv2D(32, (3, 3), activation='tanh', input_shape=(20, 20, 2),kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Segunda capa convolucional
model.add(Conv2D(64, (3, 3), activation='tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64, activation='tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(7, activation= custom_activation))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 18, 18, 32)        608
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 32)         0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 64)          18496
#
#  max_pooling2d_8 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 128)               73856
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 105,831
# Trainable params: 105,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=10.0)

# %%
model.compile(optimizer= optimizer,
              loss= 'MSE',
              metrics=['mae'])

# %%
def scheduler(epoch, lr):
  if epoch < 100:
    return lr
  else:
    return 1e-3 -  2e-8* epoch

# %%
val_epochs = 10

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 800,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/10
# 700/700 [==============================] - 3s 4ms/step - loss: 66.1321 - accuracy: 0.3229 - val_loss: 63.7848 - val_accuracy: 0.3890 - lr: 0.0010
# Epoch 2/10
# 700/700 [==============================] - 3s 4ms/step - loss: 63.0518 - accuracy: 0.3997 - val_loss: 61.2107 - val_accuracy: 0.4990 - lr: 0.0010
# Epoch 3/10
# 700/700 [==============================] - 3s 4ms/step - loss: 61.3192 - accuracy: 0.4737 - val_loss: 60.2567 - val_accuracy: 0.5250 - lr: 0.0010
# Epoch 4/10
# 287/700 [===========>..................] - ETA: 1s - loss: 60.8986 - accuracy: 0.4986
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <cell line: 7>()
#       3 early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 800,verbose = 1,
#       4                                               restore_best_weights = True)
#       6 reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
# ----> 7 history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mae']
val_acc = history.history['val_mae']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(val_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales con ruido/History 20,50/historyconvcampvec20.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos con ruido/Modelos 20,50/'

# %%
model.save(path_to_save + '/convolucionalcv20.h5')

# %% [markdown]
# # Importamos el modelo

# %%
custom_objects = {'custom_activation': custom_activation}
new_model = keras.models.load_model('../../../Modelos con ruido/Modelos 20,50/convolucionalcv20.h5', custom_objects=custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 20)
    y2 = np.linspace(y_range_neg, y_range_pos, 20)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [5, 4, 9, 3, 0, 10, 3]

# %%
campvecnone = campvec[None, :]
campvecnone = np.transpose(campvecnone, (0,2,3,1))

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# [[8. 5. 7. 6. 0. 7. 4.]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 20)
y2 = np.linspace(0, 10, 20)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
plt.show()

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1 = np.linspace(x_range_neg, x_range_pos, 20)
y2 = np.linspace(y_range_neg, y_range_pos, 20)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
