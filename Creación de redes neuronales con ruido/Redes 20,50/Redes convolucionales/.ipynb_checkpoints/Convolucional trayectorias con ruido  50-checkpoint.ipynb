# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_27324\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos con ruido/Trayectorias 50 eval'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
varftrain = np.load(path + '/varftrain.npy')
varftrain = np.transpose(varftrain, (0,3,1,2))

# %%
np.shape(varftrain)
# Out:
# (7000, 50, 10, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefvarftrain = np.load(path + '/coefvarftrain.npy')

# %%
np.shape(coefvarftrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
varftest = np.load(path + '/varftest.npy')
varftest = np.transpose(varftest, (0,3,1,2))

# %%
np.shape(varftest)
# Out:
# (2000, 50, 10, 2)

# %% [markdown]
# ### Coeficientes

# %%
coefvarftest = np.load(path + '/coefvarftest.npy')

# %%
np.shape(coefvarftest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
varfval = np.load(path + '/varfval.npy')
varfval = np.transpose(varfval, (0,3,1,2))

# %%
np.shape(varfval)
# Out:
# (1000, 50, 10, 2)

# %% [markdown]
# ### Coeficienes

# %%
coefvarfval = np.load(path + '/coefvarfval.npy')

# %%
np.shape(coefvarfval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((varftrain, coefvarftrain))
test_dataset = tf.data.Dataset.from_tensor_slices((varftest, coefvarftest))
val_dataset = tf.data.Dataset.from_tensor_slices((varfval, coefvarfval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(50, 10, 2), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
# Primera capa convolucional
model.add(Conv2D(50, (5, 1), activation='tanh', input_shape=(50, 10, 2),kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(MaxPooling2D(pool_size=(2, 1)))

# Segunda capa convolucional
model.add(Conv2D(12, (5, 1), activation='tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001) ))
model.add(MaxPooling2D(pool_size=(2, 1)))

# Tercera capa convolucional
model.add(Conv2D(9, (5, 1), activation='tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001), padding = 'same'))

#Cuarta capa convolucional
model.add(Conv2D(50, (5, 2), activation='tanh'))
model.add(MaxPooling2D(pool_size=(2, 1)))

#Aplanamos la entrada
model.add(Flatten())

#Capas densas
model.add(Dense(50, activation='tanh', kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(20, activation='tanh', kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(20,activation = 'relu', kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(7, activation= custom_activation))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 46, 10, 50)        550
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 10, 50)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 19, 10, 12)        3012
#
#  max_pooling2d_4 (MaxPooling  (None, 9, 10, 12)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 9, 10, 9)          549
#
#  conv2d_7 (Conv2D)           (None, 5, 9, 50)          4550
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 9, 50)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 900)               0
#
#  dense_3 (Dense)             (None, 50)                45050
#
#  dense_4 (Dense)             (None, 20)                1020
#
#  dense_5 (Dense)             (None, 20)                420
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_6 (Dense)             (None, 7)                 147
#
# =================================================================
# Total params: 55,298
# Trainable params: 55,298
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= 'mean_squared_error',
              metrics=metrics)

# %%
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 1000,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 70/70 [==============================] - 2s 23ms/step - loss: 10.9652 - a_1: 2.7919 - a_2: 2.8115 - b_1: 2.4914 - b_2: 2.6392 - d_1: 2.1191 - d_2: 2.4881 - n: 1.8542 - mean_metric: 0.5716 - val_loss: 9.4066 - val_a_1: 2.6830 - val_a_2: 2.6277 - val_b_1: 2.1981 - val_b_2: 2.3425 - val_d_1: 1.7197 - val_d_2: 2.3441 - val_n: 1.6608 - val_mean_metric: 0.5088 - lr: 0.0010
# Epoch 2/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 9.7954 - a_1: 2.7545 - a_2: 2.7813 - b_1: 2.3999 - b_2: 2.3626 - d_1: 1.7725 - d_2: 2.1086 - n: 1.7544 - mean_metric: 0.5297 - val_loss: 8.5032 - val_a_1: 2.6566 - val_a_2: 2.6265 - val_b_1: 2.0297 - val_b_2: 2.2411 - val_d_1: 1.5161 - val_d_2: 1.9024 - val_n: 1.5835 - val_mean_metric: 0.4755 - lr: 0.0010
# Epoch 3/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 9.0919 - a_1: 2.7368 - a_2: 2.7639 - b_1: 2.2715 - b_2: 2.2508 - d_1: 1.6197 - d_2: 1.8844 - n: 1.6511 - mean_metric: 0.5047 - val_loss: 7.8026 - val_a_1: 2.6527 - val_a_2: 2.6102 - val_b_1: 1.9494 - val_b_2: 2.0824 - val_d_1: 1.2950 - val_d_2: 1.7122 - val_n: 1.5042 - val_mean_metric: 0.4511 - lr: 0.0010
# Epoch 4/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 8.4392 - a_1: 2.7319 - a_2: 2.7414 - b_1: 2.1715 - b_2: 2.1752 - d_1: 1.4554 - d_2: 1.6630 - n: 1.5670 - mean_metric: 0.4822 - val_loss: 7.2855 - val_a_1: 2.6416 - val_a_2: 2.6040 - val_b_1: 1.8698 - val_b_2: 2.0000 - val_d_1: 1.1504 - val_d_2: 1.4013 - val_n: 1.4944 - val_mean_metric: 0.4300 - lr: 0.0010
# Epoch 5/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 7.9983 - a_1: 2.7090 - a_2: 2.7176 - b_1: 2.0679 - b_2: 2.1154 - d_1: 1.4209 - d_2: 1.5263 - n: 1.5385 - mean_metric: 0.4685 - val_loss: 6.9661 - val_a_1: 2.6314 - val_a_2: 2.5924 - val_b_1: 1.8372 - val_b_2: 1.9701 - val_d_1: 1.0866 - val_d_2: 1.2452 - val_n: 1.4778 - val_mean_metric: 0.4195 - lr: 0.0010
# Epoch 6/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 7.6807 - a_1: 2.6981 - a_2: 2.7217 - b_1: 2.0227 - b_2: 2.0708 - d_1: 1.3591 - d_2: 1.4305 - n: 1.5297 - mean_metric: 0.4598 - val_loss: 6.7002 - val_a_1: 2.6184 - val_a_2: 2.5914 - val_b_1: 1.7793 - val_b_2: 1.9381 - val_d_1: 1.0357 - val_d_2: 1.1895 - val_n: 1.4702 - val_mean_metric: 0.4123 - lr: 0.0010
# Epoch 7/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 7.2918 - a_1: 2.6655 - a_2: 2.6902 - b_1: 1.9479 - b_2: 2.0116 - d_1: 1.3018 - d_2: 1.3089 - n: 1.5311 - mean_metric: 0.4474 - val_loss: 6.3965 - val_a_1: 2.6088 - val_a_2: 2.5874 - val_b_1: 1.7299 - val_b_2: 1.8548 - val_d_1: 0.9598 - val_d_2: 1.0434 - val_n: 1.4853 - val_mean_metric: 0.4008 - lr: 0.0010
# Epoch 8/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 7.0460 - a_1: 2.6636 - a_2: 2.6691 - b_1: 1.9047 - b_2: 1.9788 - d_1: 1.2788 - d_2: 1.2384 - n: 1.5064 - mean_metric: 0.4402 - val_loss: 6.1017 - val_a_1: 2.6016 - val_a_2: 2.5634 - val_b_1: 1.6986 - val_b_2: 1.7582 - val_d_1: 0.8884 - val_d_2: 0.9353 - val_n: 1.4641 - val_mean_metric: 0.3890 - lr: 0.0010
# Epoch 9/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 6.8352 - a_1: 2.6530 - a_2: 2.6491 - b_1: 1.8690 - b_2: 1.9632 - d_1: 1.2206 - d_2: 1.1970 - n: 1.5195 - mean_metric: 0.4345 - val_loss: 6.0133 - val_a_1: 2.5953 - val_a_2: 2.5596 - val_b_1: 1.6921 - val_b_2: 1.7838 - val_d_1: 0.9075 - val_d_2: 0.8924 - val_n: 1.4675 - val_mean_metric: 0.3886 - lr: 0.0010
# Epoch 10/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 6.6615 - a_1: 2.6456 - a_2: 2.6526 - b_1: 1.8587 - b_2: 1.9257 - d_1: 1.1617 - d_2: 1.1593 - n: 1.5105 - mean_metric: 0.4293 - val_loss: 5.8421 - val_a_1: 2.5930 - val_a_2: 2.5507 - val_b_1: 1.6561 - val_b_2: 1.7273 - val_d_1: 0.8301 - val_d_2: 0.8938 - val_n: 1.4653 - val_mean_metric: 0.3827 - lr: 0.0010
# Epoch 11/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 6.5042 - a_1: 2.6376 - a_2: 2.6299 - b_1: 1.8313 - b_2: 1.9110 - d_1: 1.1500 - d_2: 1.1236 - n: 1.5122 - mean_metric: 0.4254 - val_loss: 5.7644 - val_a_1: 2.5884 - val_a_2: 2.5397 - val_b_1: 1.6345 - val_b_2: 1.7721 - val_d_1: 0.7556 - val_d_2: 0.8517 - val_n: 1.4695 - val_mean_metric: 0.3793 - lr: 0.0010
# Epoch 12/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 6.3571 - a_1: 2.6354 - a_2: 2.6264 - b_1: 1.7854 - b_2: 1.8913 - d_1: 1.1058 - d_2: 1.1035 - n: 1.5011 - mean_metric: 0.4204 - val_loss: 5.6434 - val_a_1: 2.5766 - val_a_2: 2.5303 - val_b_1: 1.6681 - val_b_2: 1.7161 - val_d_1: 0.7466 - val_d_2: 0.8319 - val_n: 1.4708 - val_mean_metric: 0.3769 - lr: 0.0010
# Epoch 13/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 6.2277 - a_1: 2.6271 - a_2: 2.6104 - b_1: 1.7543 - b_2: 1.8835 - d_1: 1.0838 - d_2: 1.0454 - n: 1.5004 - mean_metric: 0.4158 - val_loss: 5.5314 - val_a_1: 2.5654 - val_a_2: 2.5433 - val_b_1: 1.6135 - val_b_2: 1.6785 - val_d_1: 0.7278 - val_d_2: 0.7692 - val_n: 1.4649 - val_mean_metric: 0.3711 - lr: 0.0010
# Epoch 14/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 6.1323 - a_1: 2.6278 - a_2: 2.6064 - b_1: 1.7238 - b_2: 1.8349 - d_1: 1.0741 - d_2: 1.0571 - n: 1.4990 - mean_metric: 0.4131 - val_loss: 5.4526 - val_a_1: 2.5597 - val_a_2: 2.5232 - val_b_1: 1.5527 - val_b_2: 1.7008 - val_d_1: 0.7316 - val_d_2: 0.8196 - val_n: 1.4711 - val_mean_metric: 0.3710 - lr: 0.0010
# Epoch 15/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 6.0549 - a_1: 2.6242 - a_2: 2.6051 - b_1: 1.7025 - b_2: 1.8271 - d_1: 1.0515 - d_2: 1.0503 - n: 1.4915 - mean_metric: 0.4107 - val_loss: 5.3566 - val_a_1: 2.5654 - val_a_2: 2.5205 - val_b_1: 1.5374 - val_b_2: 1.7126 - val_d_1: 0.6474 - val_d_2: 0.7096 - val_n: 1.4635 - val_mean_metric: 0.3644 - lr: 0.0010
# Epoch 16/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.9249 - a_1: 2.6161 - a_2: 2.5949 - b_1: 1.6604 - b_2: 1.8086 - d_1: 1.0196 - d_2: 1.0063 - n: 1.4935 - mean_metric: 0.4055 - val_loss: 5.2515 - val_a_1: 2.5557 - val_a_2: 2.5079 - val_b_1: 1.4932 - val_b_2: 1.6434 - val_d_1: 0.6887 - val_d_2: 0.6992 - val_n: 1.4575 - val_mean_metric: 0.3607 - lr: 0.0010
# Epoch 17/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.9043 - a_1: 2.6148 - a_2: 2.5935 - b_1: 1.6667 - b_2: 1.7672 - d_1: 1.0333 - d_2: 1.0293 - n: 1.4950 - mean_metric: 0.4056 - val_loss: 5.2354 - val_a_1: 2.5603 - val_a_2: 2.5099 - val_b_1: 1.5851 - val_b_2: 1.5559 - val_d_1: 0.6609 - val_d_2: 0.7287 - val_n: 1.4568 - val_mean_metric: 0.3611 - lr: 0.0010
# Epoch 18/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.8229 - a_1: 2.6112 - a_2: 2.5889 - b_1: 1.6503 - b_2: 1.7578 - d_1: 1.0057 - d_2: 1.0044 - n: 1.4867 - mean_metric: 0.4024 - val_loss: 5.1186 - val_a_1: 2.5545 - val_a_2: 2.5062 - val_b_1: 1.4705 - val_b_2: 1.5650 - val_d_1: 0.6051 - val_d_2: 0.6808 - val_n: 1.4509 - val_mean_metric: 0.3538 - lr: 0.0010
# Epoch 19/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.7988 - a_1: 2.6197 - a_2: 2.5876 - b_1: 1.6469 - b_2: 1.7401 - d_1: 0.9983 - d_2: 1.0038 - n: 1.4818 - mean_metric: 0.4015 - val_loss: 5.1203 - val_a_1: 2.5485 - val_a_2: 2.5159 - val_b_1: 1.4792 - val_b_2: 1.5889 - val_d_1: 0.6197 - val_d_2: 0.6793 - val_n: 1.4579 - val_mean_metric: 0.3556 - lr: 0.0010
# Epoch 20/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.7221 - a_1: 2.6178 - a_2: 2.5871 - b_1: 1.5984 - b_2: 1.7189 - d_1: 0.9896 - d_2: 1.0090 - n: 1.4861 - mean_metric: 0.3991 - val_loss: 5.0566 - val_a_1: 2.5552 - val_a_2: 2.4896 - val_b_1: 1.4618 - val_b_2: 1.5335 - val_d_1: 0.6395 - val_d_2: 0.6861 - val_n: 1.4590 - val_mean_metric: 0.3535 - lr: 0.0010
# Epoch 21/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.7011 - a_1: 2.6086 - a_2: 2.5804 - b_1: 1.5980 - b_2: 1.7258 - d_1: 0.9969 - d_2: 0.9788 - n: 1.4756 - mean_metric: 0.3977 - val_loss: 5.0257 - val_a_1: 2.5601 - val_a_2: 2.5098 - val_b_1: 1.4180 - val_b_2: 1.5897 - val_d_1: 0.5896 - val_d_2: 0.6049 - val_n: 1.4553 - val_mean_metric: 0.3504 - lr: 0.0010
# Epoch 22/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.6380 - a_1: 2.6175 - a_2: 2.5756 - b_1: 1.5692 - b_2: 1.6887 - d_1: 1.0004 - d_2: 0.9878 - n: 1.4724 - mean_metric: 0.3961 - val_loss: 4.9903 - val_a_1: 2.5498 - val_a_2: 2.4972 - val_b_1: 1.4048 - val_b_2: 1.5149 - val_d_1: 0.5904 - val_d_2: 0.7055 - val_n: 1.4579 - val_mean_metric: 0.3502 - lr: 0.0010
# Epoch 23/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.6251 - a_1: 2.6177 - a_2: 2.5841 - b_1: 1.5918 - b_2: 1.6725 - d_1: 0.9888 - d_2: 0.9690 - n: 1.4765 - mean_metric: 0.3957 - val_loss: 4.9791 - val_a_1: 2.5551 - val_a_2: 2.4935 - val_b_1: 1.4053 - val_b_2: 1.5867 - val_d_1: 0.5518 - val_d_2: 0.6342 - val_n: 1.4561 - val_mean_metric: 0.3489 - lr: 0.0010
# Epoch 24/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.5976 - a_1: 2.6239 - a_2: 2.5822 - b_1: 1.5764 - b_2: 1.6749 - d_1: 0.9622 - d_2: 0.9638 - n: 1.4728 - mean_metric: 0.3942 - val_loss: 4.9686 - val_a_1: 2.5505 - val_a_2: 2.4961 - val_b_1: 1.4189 - val_b_2: 1.5953 - val_d_1: 0.5744 - val_d_2: 0.6242 - val_n: 1.4531 - val_mean_metric: 0.3498 - lr: 0.0010
# Epoch 25/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.5645 - a_1: 2.6152 - a_2: 2.5713 - b_1: 1.5453 - b_2: 1.6634 - d_1: 0.9715 - d_2: 0.9707 - n: 1.4672 - mean_metric: 0.3924 - val_loss: 5.0308 - val_a_1: 2.5499 - val_a_2: 2.5022 - val_b_1: 1.4899 - val_b_2: 1.6247 - val_d_1: 0.5413 - val_d_2: 0.6537 - val_n: 1.4508 - val_mean_metric: 0.3531 - lr: 0.0010
# Epoch 26/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.5643 - a_1: 2.6174 - a_2: 2.5759 - b_1: 1.5777 - b_2: 1.6534 - d_1: 0.9735 - d_2: 0.9657 - n: 1.4691 - mean_metric: 0.3934 - val_loss: 4.9457 - val_a_1: 2.5603 - val_a_2: 2.5028 - val_b_1: 1.4976 - val_b_2: 1.4260 - val_d_1: 0.5629 - val_d_2: 0.6772 - val_n: 1.4453 - val_mean_metric: 0.3486 - lr: 0.0010
# Epoch 27/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.4860 - a_1: 2.6109 - a_2: 2.5720 - b_1: 1.5334 - b_2: 1.6160 - d_1: 0.9600 - d_2: 0.9679 - n: 1.4637 - mean_metric: 0.3898 - val_loss: 4.8295 - val_a_1: 2.5387 - val_a_2: 2.5052 - val_b_1: 1.3871 - val_b_2: 1.4428 - val_d_1: 0.5480 - val_d_2: 0.6384 - val_n: 1.4419 - val_mean_metric: 0.3430 - lr: 0.0010
# Epoch 28/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.4418 - a_1: 2.6018 - a_2: 2.5765 - b_1: 1.5478 - b_2: 1.5918 - d_1: 0.9554 - d_2: 0.9517 - n: 1.4617 - mean_metric: 0.3886 - val_loss: 4.8853 - val_a_1: 2.5580 - val_a_2: 2.4861 - val_b_1: 1.5090 - val_b_2: 1.4396 - val_d_1: 0.5656 - val_d_2: 0.6690 - val_n: 1.4409 - val_mean_metric: 0.3484 - lr: 0.0010
# Epoch 29/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.4849 - a_1: 2.6185 - a_2: 2.5752 - b_1: 1.5591 - b_2: 1.5896 - d_1: 0.9732 - d_2: 0.9748 - n: 1.4594 - mean_metric: 0.3906 - val_loss: 4.8422 - val_a_1: 2.5538 - val_a_2: 2.5033 - val_b_1: 1.4210 - val_b_2: 1.3937 - val_d_1: 0.5838 - val_d_2: 0.6412 - val_n: 1.4483 - val_mean_metric: 0.3444 - lr: 0.0010
# Epoch 30/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.4203 - a_1: 2.6072 - a_2: 2.5757 - b_1: 1.5372 - b_2: 1.5591 - d_1: 0.9656 - d_2: 0.9345 - n: 1.4614 - mean_metric: 0.3870 - val_loss: 4.8059 - val_a_1: 2.5535 - val_a_2: 2.4942 - val_b_1: 1.4697 - val_b_2: 1.3670 - val_d_1: 0.5433 - val_d_2: 0.5762 - val_n: 1.4372 - val_mean_metric: 0.3410 - lr: 0.0010
# Epoch 31/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.3941 - a_1: 2.6116 - a_2: 2.5706 - b_1: 1.5270 - b_2: 1.5531 - d_1: 0.9546 - d_2: 0.9266 - n: 1.4604 - mean_metric: 0.3857 - val_loss: 4.7685 - val_a_1: 2.5417 - val_a_2: 2.4764 - val_b_1: 1.4600 - val_b_2: 1.3424 - val_d_1: 0.5391 - val_d_2: 0.6629 - val_n: 1.4364 - val_mean_metric: 0.3416 - lr: 0.0010
# Epoch 32/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.4032 - a_1: 2.6043 - a_2: 2.5597 - b_1: 1.5639 - b_2: 1.5506 - d_1: 0.9476 - d_2: 0.9285 - n: 1.4613 - mean_metric: 0.3862 - val_loss: 4.7460 - val_a_1: 2.5464 - val_a_2: 2.4824 - val_b_1: 1.4276 - val_b_2: 1.3386 - val_d_1: 0.5346 - val_d_2: 0.5984 - val_n: 1.4445 - val_mean_metric: 0.3388 - lr: 0.0010
# Epoch 33/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.4062 - a_1: 2.6101 - a_2: 2.5697 - b_1: 1.5403 - b_2: 1.5620 - d_1: 0.9629 - d_2: 0.9438 - n: 1.4608 - mean_metric: 0.3873 - val_loss: 4.8144 - val_a_1: 2.5405 - val_a_2: 2.4963 - val_b_1: 1.4164 - val_b_2: 1.4889 - val_d_1: 0.5556 - val_d_2: 0.6113 - val_n: 1.4323 - val_mean_metric: 0.3442 - lr: 0.0010
# Epoch 34/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.3944 - a_1: 2.5974 - a_2: 2.5631 - b_1: 1.5613 - b_2: 1.5358 - d_1: 0.9847 - d_2: 0.9411 - n: 1.4580 - mean_metric: 0.3870 - val_loss: 4.6795 - val_a_1: 2.5437 - val_a_2: 2.4722 - val_b_1: 1.3775 - val_b_2: 1.3437 - val_d_1: 0.5410 - val_d_2: 0.5983 - val_n: 1.4253 - val_mean_metric: 0.3365 - lr: 0.0010
# Epoch 35/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.3321 - a_1: 2.5998 - a_2: 2.5606 - b_1: 1.5260 - b_2: 1.5387 - d_1: 0.9450 - d_2: 0.9364 - n: 1.4503 - mean_metric: 0.3842 - val_loss: 4.7142 - val_a_1: 2.5322 - val_a_2: 2.4889 - val_b_1: 1.3619 - val_b_2: 1.3693 - val_d_1: 0.5800 - val_d_2: 0.6325 - val_n: 1.4307 - val_mean_metric: 0.3395 - lr: 0.0010
# Epoch 36/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.3457 - a_1: 2.6029 - a_2: 2.5541 - b_1: 1.5382 - b_2: 1.5464 - d_1: 0.9482 - d_2: 0.9285 - n: 1.4513 - mean_metric: 0.3846 - val_loss: 4.6621 - val_a_1: 2.5377 - val_a_2: 2.4812 - val_b_1: 1.3472 - val_b_2: 1.3009 - val_d_1: 0.6125 - val_d_2: 0.6180 - val_n: 1.4298 - val_mean_metric: 0.3373 - lr: 0.0010
# Epoch 37/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.2760 - a_1: 2.6047 - a_2: 2.5550 - b_1: 1.4992 - b_2: 1.4955 - d_1: 0.9422 - d_2: 0.9131 - n: 1.4481 - mean_metric: 0.3809 - val_loss: 4.5688 - val_a_1: 2.5404 - val_a_2: 2.4708 - val_b_1: 1.3246 - val_b_2: 1.2552 - val_d_1: 0.5385 - val_d_2: 0.5489 - val_n: 1.4290 - val_mean_metric: 0.3301 - lr: 0.0010
# Epoch 38/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.2422 - a_1: 2.5934 - a_2: 2.5564 - b_1: 1.4905 - b_2: 1.4900 - d_1: 0.9396 - d_2: 0.9172 - n: 1.4492 - mean_metric: 0.3802 - val_loss: 4.6377 - val_a_1: 2.5254 - val_a_2: 2.4782 - val_b_1: 1.3299 - val_b_2: 1.3820 - val_d_1: 0.5458 - val_d_2: 0.5907 - val_n: 1.4282 - val_mean_metric: 0.3357 - lr: 0.0010
# Epoch 39/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.2247 - a_1: 2.5857 - a_2: 2.5450 - b_1: 1.4878 - b_2: 1.4946 - d_1: 0.9201 - d_2: 0.9116 - n: 1.4405 - mean_metric: 0.3785 - val_loss: 4.5948 - val_a_1: 2.5375 - val_a_2: 2.4739 - val_b_1: 1.3157 - val_b_2: 1.3033 - val_d_1: 0.5583 - val_d_2: 0.5777 - val_n: 1.4265 - val_mean_metric: 0.3330 - lr: 0.0010
# Epoch 40/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.2175 - a_1: 2.5939 - a_2: 2.5423 - b_1: 1.5021 - b_2: 1.4743 - d_1: 0.9363 - d_2: 0.9122 - n: 1.4422 - mean_metric: 0.3790 - val_loss: 4.5611 - val_a_1: 2.5295 - val_a_2: 2.4601 - val_b_1: 1.3620 - val_b_2: 1.2522 - val_d_1: 0.5435 - val_d_2: 0.5770 - val_n: 1.4237 - val_mean_metric: 0.3314 - lr: 0.0010
# Epoch 41/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.2096 - a_1: 2.5871 - a_2: 2.5273 - b_1: 1.5173 - b_2: 1.4600 - d_1: 0.9510 - d_2: 0.8918 - n: 1.4410 - mean_metric: 0.3783 - val_loss: 4.5580 - val_a_1: 2.5227 - val_a_2: 2.4443 - val_b_1: 1.3840 - val_b_2: 1.2684 - val_d_1: 0.5377 - val_d_2: 0.5711 - val_n: 1.4242 - val_mean_metric: 0.3316 - lr: 0.0010
# Epoch 42/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.1830 - a_1: 2.5857 - a_2: 2.5246 - b_1: 1.4877 - b_2: 1.4834 - d_1: 0.9180 - d_2: 0.9090 - n: 1.4358 - mean_metric: 0.3771 - val_loss: 4.5615 - val_a_1: 2.5271 - val_a_2: 2.4562 - val_b_1: 1.3406 - val_b_2: 1.3028 - val_d_1: 0.5849 - val_d_2: 0.5995 - val_n: 1.4255 - val_mean_metric: 0.3343 - lr: 0.0010
# Epoch 43/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.1453 - a_1: 2.5794 - a_2: 2.5096 - b_1: 1.4733 - b_2: 1.4771 - d_1: 0.9232 - d_2: 0.8932 - n: 1.4362 - mean_metric: 0.3754 - val_loss: 4.6790 - val_a_1: 2.5420 - val_a_2: 2.4261 - val_b_1: 1.5427 - val_b_2: 1.3874 - val_d_1: 0.5496 - val_d_2: 0.5808 - val_n: 1.4197 - val_mean_metric: 0.3412 - lr: 0.0010
# Epoch 44/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.1544 - a_1: 2.5889 - a_2: 2.5090 - b_1: 1.4830 - b_2: 1.4546 - d_1: 0.9314 - d_2: 0.9149 - n: 1.4347 - mean_metric: 0.3762 - val_loss: 4.5640 - val_a_1: 2.5187 - val_a_2: 2.4438 - val_b_1: 1.3478 - val_b_2: 1.3473 - val_d_1: 0.4995 - val_d_2: 0.6189 - val_n: 1.4194 - val_mean_metric: 0.3330 - lr: 0.0010
# Epoch 45/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.1340 - a_1: 2.5866 - a_2: 2.5096 - b_1: 1.4800 - b_2: 1.4623 - d_1: 0.9155 - d_2: 0.8988 - n: 1.4412 - mean_metric: 0.3755 - val_loss: 4.4751 - val_a_1: 2.5202 - val_a_2: 2.4408 - val_b_1: 1.2931 - val_b_2: 1.2425 - val_d_1: 0.5281 - val_d_2: 0.5327 - val_n: 1.4228 - val_mean_metric: 0.3260 - lr: 0.0010
# Epoch 46/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.1264 - a_1: 2.5690 - a_2: 2.5184 - b_1: 1.4848 - b_2: 1.4256 - d_1: 0.9297 - d_2: 0.9029 - n: 1.4457 - mean_metric: 0.3749 - val_loss: 4.5603 - val_a_1: 2.5178 - val_a_2: 2.4545 - val_b_1: 1.3533 - val_b_2: 1.3148 - val_d_1: 0.5391 - val_d_2: 0.5387 - val_n: 1.4273 - val_mean_metric: 0.3314 - lr: 0.0010
# Epoch 47/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.1220 - a_1: 2.5697 - a_2: 2.5152 - b_1: 1.4603 - b_2: 1.4626 - d_1: 0.9266 - d_2: 0.8892 - n: 1.4371 - mean_metric: 0.3743 - val_loss: 4.4554 - val_a_1: 2.5055 - val_a_2: 2.4345 - val_b_1: 1.2770 - val_b_2: 1.2456 - val_d_1: 0.5384 - val_d_2: 0.5919 - val_n: 1.4232 - val_mean_metric: 0.3271 - lr: 0.0010
# Epoch 48/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.0949 - a_1: 2.5768 - a_2: 2.5105 - b_1: 1.4823 - b_2: 1.4417 - d_1: 0.9214 - d_2: 0.8863 - n: 1.4312 - mean_metric: 0.3740 - val_loss: 4.4715 - val_a_1: 2.5103 - val_a_2: 2.4350 - val_b_1: 1.3305 - val_b_2: 1.2512 - val_d_1: 0.5507 - val_d_2: 0.5737 - val_n: 1.4213 - val_mean_metric: 0.3290 - lr: 0.0010
# Epoch 49/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.0772 - a_1: 2.5791 - a_2: 2.4876 - b_1: 1.4714 - b_2: 1.4372 - d_1: 0.9150 - d_2: 0.8954 - n: 1.4310 - mean_metric: 0.3729 - val_loss: 4.4247 - val_a_1: 2.5167 - val_a_2: 2.4179 - val_b_1: 1.2751 - val_b_2: 1.2954 - val_d_1: 0.5271 - val_d_2: 0.5121 - val_n: 1.4190 - val_mean_metric: 0.3254 - lr: 0.0010
# Epoch 50/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.0658 - a_1: 2.5759 - a_2: 2.4949 - b_1: 1.4508 - b_2: 1.4447 - d_1: 0.9223 - d_2: 0.8893 - n: 1.4321 - mean_metric: 0.3727 - val_loss: 4.5425 - val_a_1: 2.5279 - val_a_2: 2.4507 - val_b_1: 1.3274 - val_b_2: 1.2383 - val_d_1: 0.6324 - val_d_2: 0.6821 - val_n: 1.4186 - val_mean_metric: 0.3357 - lr: 0.0010
# Epoch 51/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.0697 - a_1: 2.5794 - a_2: 2.4879 - b_1: 1.4572 - b_2: 1.4519 - d_1: 0.9067 - d_2: 0.8982 - n: 1.4312 - mean_metric: 0.3727 - val_loss: 4.4199 - val_a_1: 2.5168 - val_a_2: 2.4135 - val_b_1: 1.3108 - val_b_2: 1.2160 - val_d_1: 0.5253 - val_d_2: 0.5832 - val_n: 1.4191 - val_mean_metric: 0.3261 - lr: 0.0010
# Epoch 52/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.0665 - a_1: 2.5681 - a_2: 2.4997 - b_1: 1.4735 - b_2: 1.4354 - d_1: 0.9192 - d_2: 0.8715 - n: 1.4357 - mean_metric: 0.3724 - val_loss: 4.4779 - val_a_1: 2.5078 - val_a_2: 2.4202 - val_b_1: 1.2828 - val_b_2: 1.2971 - val_d_1: 0.5776 - val_d_2: 0.5278 - val_n: 1.4245 - val_mean_metric: 0.3279 - lr: 0.0010
# Epoch 53/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.0341 - a_1: 2.5685 - a_2: 2.4876 - b_1: 1.4458 - b_2: 1.4394 - d_1: 0.9006 - d_2: 0.8880 - n: 1.4326 - mean_metric: 0.3711 - val_loss: 4.4263 - val_a_1: 2.5057 - val_a_2: 2.4096 - val_b_1: 1.2553 - val_b_2: 1.3718 - val_d_1: 0.5045 - val_d_2: 0.5111 - val_n: 1.4254 - val_mean_metric: 0.3260 - lr: 0.0010
# Epoch 54/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9789 - a_1: 2.5542 - a_2: 2.4786 - b_1: 1.4361 - b_2: 1.4076 - d_1: 0.9076 - d_2: 0.8818 - n: 1.4287 - mean_metric: 0.3688 - val_loss: 4.3359 - val_a_1: 2.4995 - val_a_2: 2.4060 - val_b_1: 1.2601 - val_b_2: 1.2220 - val_d_1: 0.5309 - val_d_2: 0.5113 - val_n: 1.4136 - val_mean_metric: 0.3215 - lr: 0.0010
# Epoch 55/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 5.0037 - a_1: 2.5629 - a_2: 2.4775 - b_1: 1.4632 - b_2: 1.4211 - d_1: 0.9165 - d_2: 0.8775 - n: 1.4242 - mean_metric: 0.3704 - val_loss: 4.4513 - val_a_1: 2.5064 - val_a_2: 2.4031 - val_b_1: 1.4199 - val_b_2: 1.2363 - val_d_1: 0.5193 - val_d_2: 0.5647 - val_n: 1.4216 - val_mean_metric: 0.3289 - lr: 0.0010
# Epoch 56/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9895 - a_1: 2.5656 - a_2: 2.4567 - b_1: 1.4554 - b_2: 1.4269 - d_1: 0.8998 - d_2: 0.8670 - n: 1.4322 - mean_metric: 0.3692 - val_loss: 4.3268 - val_a_1: 2.4991 - val_a_2: 2.3810 - val_b_1: 1.2699 - val_b_2: 1.2461 - val_d_1: 0.5361 - val_d_2: 0.5180 - val_n: 1.4162 - val_mean_metric: 0.3222 - lr: 0.0010
# Epoch 57/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9691 - a_1: 2.5529 - a_2: 2.4610 - b_1: 1.4612 - b_2: 1.3973 - d_1: 0.9088 - d_2: 0.8553 - n: 1.4301 - mean_metric: 0.3679 - val_loss: 4.3046 - val_a_1: 2.4843 - val_a_2: 2.3769 - val_b_1: 1.2910 - val_b_2: 1.2154 - val_d_1: 0.5241 - val_d_2: 0.5174 - val_n: 1.4179 - val_mean_metric: 0.3209 - lr: 0.0010
# Epoch 58/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9633 - a_1: 2.5512 - a_2: 2.4549 - b_1: 1.4602 - b_2: 1.3870 - d_1: 0.9074 - d_2: 0.8764 - n: 1.4321 - mean_metric: 0.3680 - val_loss: 4.3536 - val_a_1: 2.4911 - val_a_2: 2.3875 - val_b_1: 1.2805 - val_b_2: 1.2372 - val_d_1: 0.5226 - val_d_2: 0.6004 - val_n: 1.4135 - val_mean_metric: 0.3244 - lr: 0.0010
# Epoch 59/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9663 - a_1: 2.5484 - a_2: 2.4599 - b_1: 1.4582 - b_2: 1.3992 - d_1: 0.9057 - d_2: 0.8734 - n: 1.4291 - mean_metric: 0.3681 - val_loss: 4.3364 - val_a_1: 2.4889 - val_a_2: 2.3883 - val_b_1: 1.3059 - val_b_2: 1.1832 - val_d_1: 0.5139 - val_d_2: 0.5402 - val_n: 1.4222 - val_mean_metric: 0.3215 - lr: 0.0010
# Epoch 60/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9064 - a_1: 2.5407 - a_2: 2.4415 - b_1: 1.4463 - b_2: 1.3984 - d_1: 0.8838 - d_2: 0.8642 - n: 1.4261 - mean_metric: 0.3658 - val_loss: 4.4092 - val_a_1: 2.4821 - val_a_2: 2.4025 - val_b_1: 1.3642 - val_b_2: 1.1886 - val_d_1: 0.5798 - val_d_2: 0.5378 - val_n: 1.4208 - val_mean_metric: 0.3259 - lr: 0.0010
# Epoch 61/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9032 - a_1: 2.5500 - a_2: 2.4408 - b_1: 1.4433 - b_2: 1.3877 - d_1: 0.8802 - d_2: 0.8561 - n: 1.4278 - mean_metric: 0.3651 - val_loss: 4.2931 - val_a_1: 2.4708 - val_a_2: 2.3746 - val_b_1: 1.2996 - val_b_2: 1.2213 - val_d_1: 0.5098 - val_d_2: 0.5141 - val_n: 1.4162 - val_mean_metric: 0.3202 - lr: 0.0010
# Epoch 62/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9307 - a_1: 2.5449 - a_2: 2.4348 - b_1: 1.4807 - b_2: 1.4044 - d_1: 0.8881 - d_2: 0.8610 - n: 1.4288 - mean_metric: 0.3671 - val_loss: 4.2446 - val_a_1: 2.4706 - val_a_2: 2.3600 - val_b_1: 1.2639 - val_b_2: 1.1816 - val_d_1: 0.5161 - val_d_2: 0.5076 - val_n: 1.4148 - val_mean_metric: 0.3173 - lr: 0.0010
# Epoch 63/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.9100 - a_1: 2.5352 - a_2: 2.4315 - b_1: 1.4626 - b_2: 1.3867 - d_1: 0.9040 - d_2: 0.8752 - n: 1.4210 - mean_metric: 0.3662 - val_loss: 4.3379 - val_a_1: 2.4725 - val_a_2: 2.3736 - val_b_1: 1.3512 - val_b_2: 1.1765 - val_d_1: 0.5977 - val_d_2: 0.5411 - val_n: 1.4148 - val_mean_metric: 0.3242 - lr: 0.0010
# Epoch 64/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.8551 - a_1: 2.5353 - a_2: 2.4261 - b_1: 1.4334 - b_2: 1.3607 - d_1: 0.8893 - d_2: 0.8453 - n: 1.4215 - mean_metric: 0.3628 - val_loss: 4.2993 - val_a_1: 2.4632 - val_a_2: 2.3830 - val_b_1: 1.3012 - val_b_2: 1.1895 - val_d_1: 0.5137 - val_d_2: 0.5770 - val_n: 1.4209 - val_mean_metric: 0.3217 - lr: 0.0010
# Epoch 65/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.8598 - a_1: 2.5359 - a_2: 2.4142 - b_1: 1.4398 - b_2: 1.3900 - d_1: 0.8850 - d_2: 0.8483 - n: 1.4197 - mean_metric: 0.3634 - val_loss: 4.2948 - val_a_1: 2.4528 - val_a_2: 2.3706 - val_b_1: 1.2927 - val_b_2: 1.2538 - val_d_1: 0.5233 - val_d_2: 0.5241 - val_n: 1.4155 - val_mean_metric: 0.3211 - lr: 0.0010
# Epoch 66/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.8656 - a_1: 2.5297 - a_2: 2.4067 - b_1: 1.4446 - b_2: 1.3647 - d_1: 0.8991 - d_2: 0.8708 - n: 1.4213 - mean_metric: 0.3636 - val_loss: 4.3185 - val_a_1: 2.4617 - val_a_2: 2.3460 - val_b_1: 1.2718 - val_b_2: 1.2801 - val_d_1: 0.5236 - val_d_2: 0.6020 - val_n: 1.4135 - val_mean_metric: 0.3233 - lr: 0.0010
# Epoch 67/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.8523 - a_1: 2.5342 - a_2: 2.3957 - b_1: 1.4365 - b_2: 1.3695 - d_1: 0.8799 - d_2: 0.8722 - n: 1.4219 - mean_metric: 0.3627 - val_loss: 4.2888 - val_a_1: 2.4544 - val_a_2: 2.3408 - val_b_1: 1.3283 - val_b_2: 1.2844 - val_d_1: 0.5020 - val_d_2: 0.5241 - val_n: 1.4116 - val_mean_metric: 0.3215 - lr: 0.0010
# Epoch 68/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.8310 - a_1: 2.5284 - a_2: 2.4159 - b_1: 1.4206 - b_2: 1.3578 - d_1: 0.8902 - d_2: 0.8623 - n: 1.4166 - mean_metric: 0.3621 - val_loss: 4.2505 - val_a_1: 2.4427 - val_a_2: 2.3693 - val_b_1: 1.2704 - val_b_2: 1.1722 - val_d_1: 0.5016 - val_d_2: 0.5699 - val_n: 1.4124 - val_mean_metric: 0.3181 - lr: 0.0010
# Epoch 69/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.8567 - a_1: 2.5270 - a_2: 2.3992 - b_1: 1.4533 - b_2: 1.3818 - d_1: 0.8886 - d_2: 0.8610 - n: 1.4251 - mean_metric: 0.3636 - val_loss: 4.2078 - val_a_1: 2.4442 - val_a_2: 2.3449 - val_b_1: 1.2608 - val_b_2: 1.2329 - val_d_1: 0.5066 - val_d_2: 0.4873 - val_n: 1.4110 - val_mean_metric: 0.3164 - lr: 0.0010
# Epoch 70/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7962 - a_1: 2.5199 - a_2: 2.4090 - b_1: 1.4071 - b_2: 1.3554 - d_1: 0.8725 - d_2: 0.8314 - n: 1.4231 - mean_metric: 0.3596 - val_loss: 4.2256 - val_a_1: 2.4580 - val_a_2: 2.3325 - val_b_1: 1.3258 - val_b_2: 1.1788 - val_d_1: 0.5195 - val_d_2: 0.5415 - val_n: 1.4112 - val_mean_metric: 0.3189 - lr: 0.0010
# Epoch 71/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7995 - a_1: 2.5296 - a_2: 2.3760 - b_1: 1.4220 - b_2: 1.3743 - d_1: 0.8690 - d_2: 0.8566 - n: 1.4242 - mean_metric: 0.3608 - val_loss: 4.2121 - val_a_1: 2.4535 - val_a_2: 2.3474 - val_b_1: 1.2940 - val_b_2: 1.1800 - val_d_1: 0.5448 - val_d_2: 0.4942 - val_n: 1.4162 - val_mean_metric: 0.3178 - lr: 0.0010
# Epoch 72/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7686 - a_1: 2.5126 - a_2: 2.3991 - b_1: 1.4118 - b_2: 1.3340 - d_1: 0.8709 - d_2: 0.8518 - n: 1.4208 - mean_metric: 0.3591 - val_loss: 4.2065 - val_a_1: 2.4305 - val_a_2: 2.3519 - val_b_1: 1.2878 - val_b_2: 1.1809 - val_d_1: 0.5064 - val_d_2: 0.5388 - val_n: 1.4146 - val_mean_metric: 0.3172 - lr: 0.0010
# Epoch 73/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7613 - a_1: 2.5094 - a_2: 2.3838 - b_1: 1.3983 - b_2: 1.3407 - d_1: 0.8678 - d_2: 0.8568 - n: 1.4206 - mean_metric: 0.3583 - val_loss: 4.2386 - val_a_1: 2.4301 - val_a_2: 2.3476 - val_b_1: 1.2461 - val_b_2: 1.3379 - val_d_1: 0.5390 - val_d_2: 0.5249 - val_n: 1.4165 - val_mean_metric: 0.3214 - lr: 0.0010
# Epoch 74/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7907 - a_1: 2.5087 - a_2: 2.3855 - b_1: 1.4372 - b_2: 1.3357 - d_1: 0.8758 - d_2: 0.8464 - n: 1.4203 - mean_metric: 0.3593 - val_loss: 4.1641 - val_a_1: 2.4301 - val_a_2: 2.3294 - val_b_1: 1.2898 - val_b_2: 1.1651 - val_d_1: 0.4751 - val_d_2: 0.5253 - val_n: 1.4117 - val_mean_metric: 0.3144 - lr: 0.0010
# Epoch 75/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7614 - a_1: 2.5025 - a_2: 2.3817 - b_1: 1.4379 - b_2: 1.3344 - d_1: 0.8721 - d_2: 0.8395 - n: 1.4218 - mean_metric: 0.3587 - val_loss: 4.2047 - val_a_1: 2.4145 - val_a_2: 2.3430 - val_b_1: 1.3581 - val_b_2: 1.1413 - val_d_1: 0.4865 - val_d_2: 0.5283 - val_n: 1.4172 - val_mean_metric: 0.3165 - lr: 0.0010
# Epoch 76/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7174 - a_1: 2.5074 - a_2: 2.3702 - b_1: 1.4171 - b_2: 1.3066 - d_1: 0.8357 - d_2: 0.8495 - n: 1.4236 - mean_metric: 0.3560 - val_loss: 4.1553 - val_a_1: 2.4121 - val_a_2: 2.3351 - val_b_1: 1.2896 - val_b_2: 1.1658 - val_d_1: 0.4808 - val_d_2: 0.5013 - val_n: 1.4133 - val_mean_metric: 0.3134 - lr: 0.0010
# Epoch 77/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7324 - a_1: 2.4870 - a_2: 2.3815 - b_1: 1.4226 - b_2: 1.3546 - d_1: 0.8615 - d_2: 0.8450 - n: 1.4209 - mean_metric: 0.3581 - val_loss: 4.1607 - val_a_1: 2.4132 - val_a_2: 2.3072 - val_b_1: 1.2483 - val_b_2: 1.1649 - val_d_1: 0.5559 - val_d_2: 0.5341 - val_n: 1.4126 - val_mean_metric: 0.3148 - lr: 0.0010
# Epoch 78/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7215 - a_1: 2.5068 - a_2: 2.3589 - b_1: 1.4308 - b_2: 1.3203 - d_1: 0.8554 - d_2: 0.8429 - n: 1.4291 - mean_metric: 0.3571 - val_loss: 4.1440 - val_a_1: 2.4122 - val_a_2: 2.3345 - val_b_1: 1.2471 - val_b_2: 1.1800 - val_d_1: 0.5049 - val_d_2: 0.4929 - val_n: 1.4184 - val_mean_metric: 0.3132 - lr: 0.0010
# Epoch 79/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.7076 - a_1: 2.4991 - a_2: 2.3435 - b_1: 1.4037 - b_2: 1.3217 - d_1: 0.8754 - d_2: 0.8439 - n: 1.4278 - mean_metric: 0.3561 - val_loss: 4.1642 - val_a_1: 2.4044 - val_a_2: 2.3272 - val_b_1: 1.2796 - val_b_2: 1.2169 - val_d_1: 0.5363 - val_d_2: 0.5272 - val_n: 1.4190 - val_mean_metric: 0.3172 - lr: 0.0010
# Epoch 80/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6945 - a_1: 2.4778 - a_2: 2.3606 - b_1: 1.4048 - b_2: 1.3130 - d_1: 0.8676 - d_2: 0.8552 - n: 1.4211 - mean_metric: 0.3556 - val_loss: 4.1686 - val_a_1: 2.4045 - val_a_2: 2.3119 - val_b_1: 1.2916 - val_b_2: 1.2072 - val_d_1: 0.5322 - val_d_2: 0.5058 - val_n: 1.4119 - val_mean_metric: 0.3157 - lr: 0.0010
# Epoch 81/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6869 - a_1: 2.4948 - a_2: 2.3588 - b_1: 1.4015 - b_2: 1.3186 - d_1: 0.8508 - d_2: 0.8386 - n: 1.4259 - mean_metric: 0.3554 - val_loss: 4.1391 - val_a_1: 2.3977 - val_a_2: 2.3184 - val_b_1: 1.2814 - val_b_2: 1.1497 - val_d_1: 0.5119 - val_d_2: 0.5327 - val_n: 1.4167 - val_mean_metric: 0.3138 - lr: 0.0010
# Epoch 82/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6837 - a_1: 2.4891 - a_2: 2.3603 - b_1: 1.4160 - b_2: 1.3012 - d_1: 0.8564 - d_2: 0.8305 - n: 1.4237 - mean_metric: 0.3550 - val_loss: 4.1558 - val_a_1: 2.4003 - val_a_2: 2.3180 - val_b_1: 1.3059 - val_b_2: 1.1735 - val_d_1: 0.4931 - val_d_2: 0.5686 - val_n: 1.4138 - val_mean_metric: 0.3159 - lr: 0.0010
# Epoch 83/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6866 - a_1: 2.4849 - a_2: 2.3474 - b_1: 1.4054 - b_2: 1.3247 - d_1: 0.8618 - d_2: 0.8488 - n: 1.4227 - mean_metric: 0.3557 - val_loss: 4.1775 - val_a_1: 2.4012 - val_a_2: 2.3342 - val_b_1: 1.3020 - val_b_2: 1.1771 - val_d_1: 0.5025 - val_d_2: 0.5123 - val_n: 1.4161 - val_mean_metric: 0.3150 - lr: 0.0010
# Epoch 84/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6286 - a_1: 2.4791 - a_2: 2.3305 - b_1: 1.4061 - b_2: 1.2960 - d_1: 0.8480 - d_2: 0.8149 - n: 1.4221 - mean_metric: 0.3523 - val_loss: 4.1246 - val_a_1: 2.3903 - val_a_2: 2.3346 - val_b_1: 1.2794 - val_b_2: 1.1394 - val_d_1: 0.5212 - val_d_2: 0.4886 - val_n: 1.4180 - val_mean_metric: 0.3126 - lr: 0.0010
# Epoch 85/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6958 - a_1: 2.4764 - a_2: 2.3468 - b_1: 1.4096 - b_2: 1.3472 - d_1: 0.8467 - d_2: 0.8376 - n: 1.4244 - mean_metric: 0.3553 - val_loss: 4.2014 - val_a_1: 2.4087 - val_a_2: 2.3081 - val_b_1: 1.3183 - val_b_2: 1.2236 - val_d_1: 0.5255 - val_d_2: 0.5187 - val_n: 1.4145 - val_mean_metric: 0.3174 - lr: 0.0010
# Epoch 86/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6309 - a_1: 2.4733 - a_2: 2.3312 - b_1: 1.3888 - b_2: 1.3075 - d_1: 0.8444 - d_2: 0.8349 - n: 1.4212 - mean_metric: 0.3524 - val_loss: 4.1360 - val_a_1: 2.3796 - val_a_2: 2.3033 - val_b_1: 1.2485 - val_b_2: 1.2240 - val_d_1: 0.4943 - val_d_2: 0.5619 - val_n: 1.4149 - val_mean_metric: 0.3144 - lr: 0.0010
# Epoch 87/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6354 - a_1: 2.4683 - a_2: 2.3258 - b_1: 1.3986 - b_2: 1.2979 - d_1: 0.8450 - d_2: 0.8318 - n: 1.4270 - mean_metric: 0.3522 - val_loss: 4.1891 - val_a_1: 2.3873 - val_a_2: 2.3567 - val_b_1: 1.2673 - val_b_2: 1.2025 - val_d_1: 0.5214 - val_d_2: 0.5310 - val_n: 1.4277 - val_mean_metric: 0.3166 - lr: 0.0010
# Epoch 88/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5849 - a_1: 2.4607 - a_2: 2.3041 - b_1: 1.3751 - b_2: 1.2998 - d_1: 0.8414 - d_2: 0.8261 - n: 1.4233 - mean_metric: 0.3501 - val_loss: 4.1813 - val_a_1: 2.3795 - val_a_2: 2.3247 - val_b_1: 1.2630 - val_b_2: 1.3072 - val_d_1: 0.5083 - val_d_2: 0.5080 - val_n: 1.4237 - val_mean_metric: 0.3172 - lr: 0.0010
# Epoch 89/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5842 - a_1: 2.4773 - a_2: 2.2996 - b_1: 1.3902 - b_2: 1.2813 - d_1: 0.8180 - d_2: 0.8112 - n: 1.4266 - mean_metric: 0.3492 - val_loss: 4.1762 - val_a_1: 2.3626 - val_a_2: 2.2949 - val_b_1: 1.2794 - val_b_2: 1.3411 - val_d_1: 0.5125 - val_d_2: 0.4882 - val_n: 1.4110 - val_mean_metric: 0.3165 - lr: 0.0010
# Epoch 90/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6260 - a_1: 2.4763 - a_2: 2.3059 - b_1: 1.4059 - b_2: 1.3077 - d_1: 0.8270 - d_2: 0.8315 - n: 1.4247 - mean_metric: 0.3517 - val_loss: 4.1520 - val_a_1: 2.3937 - val_a_2: 2.3480 - val_b_1: 1.2725 - val_b_2: 1.1605 - val_d_1: 0.5106 - val_d_2: 0.5368 - val_n: 1.4168 - val_mean_metric: 0.3148 - lr: 0.0010
# Epoch 91/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5666 - a_1: 2.4625 - a_2: 2.3081 - b_1: 1.3795 - b_2: 1.2612 - d_1: 0.8307 - d_2: 0.8209 - n: 1.4303 - mean_metric: 0.3488 - val_loss: 4.1769 - val_a_1: 2.3853 - val_a_2: 2.3320 - val_b_1: 1.2530 - val_b_2: 1.2969 - val_d_1: 0.4787 - val_d_2: 0.5055 - val_n: 1.4137 - val_mean_metric: 0.3156 - lr: 0.0010
# Epoch 92/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.6020 - a_1: 2.4703 - a_2: 2.2839 - b_1: 1.3914 - b_2: 1.2938 - d_1: 0.8547 - d_2: 0.8268 - n: 1.4309 - mean_metric: 0.3508 - val_loss: 4.1733 - val_a_1: 2.3714 - val_a_2: 2.3370 - val_b_1: 1.2595 - val_b_2: 1.2352 - val_d_1: 0.4913 - val_d_2: 0.5328 - val_n: 1.4158 - val_mean_metric: 0.3149 - lr: 0.0010
# Epoch 93/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5665 - a_1: 2.4536 - a_2: 2.2892 - b_1: 1.4051 - b_2: 1.2834 - d_1: 0.8340 - d_2: 0.8052 - n: 1.4269 - mean_metric: 0.3489 - val_loss: 4.2327 - val_a_1: 2.3819 - val_a_2: 2.3976 - val_b_1: 1.2687 - val_b_2: 1.2005 - val_d_1: 0.5166 - val_d_2: 0.5064 - val_n: 1.4182 - val_mean_metric: 0.3165 - lr: 0.0010
# Epoch 94/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5868 - a_1: 2.4511 - a_2: 2.2983 - b_1: 1.4037 - b_2: 1.2845 - d_1: 0.8302 - d_2: 0.8257 - n: 1.4297 - mean_metric: 0.3498 - val_loss: 4.1290 - val_a_1: 2.3887 - val_a_2: 2.3175 - val_b_1: 1.2764 - val_b_2: 1.1480 - val_d_1: 0.5108 - val_d_2: 0.4875 - val_n: 1.4192 - val_mean_metric: 0.3119 - lr: 0.0010
# Epoch 95/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5502 - a_1: 2.4530 - a_2: 2.2840 - b_1: 1.4108 - b_2: 1.2643 - d_1: 0.8070 - d_2: 0.8225 - n: 1.4231 - mean_metric: 0.3479 - val_loss: 4.1618 - val_a_1: 2.3660 - val_a_2: 2.3128 - val_b_1: 1.3290 - val_b_2: 1.2057 - val_d_1: 0.4829 - val_d_2: 0.5330 - val_n: 1.4187 - val_mean_metric: 0.3151 - lr: 0.0010
# Epoch 96/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5594 - a_1: 2.4423 - a_2: 2.2727 - b_1: 1.3927 - b_2: 1.2799 - d_1: 0.8148 - d_2: 0.8282 - n: 1.4289 - mean_metric: 0.3477 - val_loss: 4.1337 - val_a_1: 2.3779 - val_a_2: 2.3401 - val_b_1: 1.2586 - val_b_2: 1.1411 - val_d_1: 0.4747 - val_d_2: 0.5576 - val_n: 1.4205 - val_mean_metric: 0.3126 - lr: 0.0010
# Epoch 97/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5441 - a_1: 2.4686 - a_2: 2.2678 - b_1: 1.3883 - b_2: 1.2666 - d_1: 0.8183 - d_2: 0.8242 - n: 1.4256 - mean_metric: 0.3478 - val_loss: 4.1400 - val_a_1: 2.3908 - val_a_2: 2.3301 - val_b_1: 1.3090 - val_b_2: 1.0839 - val_d_1: 0.4883 - val_d_2: 0.5009 - val_n: 1.4197 - val_mean_metric: 0.3110 - lr: 0.0010
# Epoch 98/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5522 - a_1: 2.4354 - a_2: 2.2765 - b_1: 1.3965 - b_2: 1.2884 - d_1: 0.8170 - d_2: 0.8243 - n: 1.4277 - mean_metric: 0.3480 - val_loss: 4.1623 - val_a_1: 2.3778 - val_a_2: 2.3390 - val_b_1: 1.3062 - val_b_2: 1.1260 - val_d_1: 0.4906 - val_d_2: 0.5123 - val_n: 1.4182 - val_mean_metric: 0.3126 - lr: 0.0010
# Epoch 99/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5445 - a_1: 2.4479 - a_2: 2.2651 - b_1: 1.3857 - b_2: 1.2784 - d_1: 0.8317 - d_2: 0.8186 - n: 1.4338 - mean_metric: 0.3477 - val_loss: 4.1339 - val_a_1: 2.3588 - val_a_2: 2.3209 - val_b_1: 1.2724 - val_b_2: 1.1686 - val_d_1: 0.5133 - val_d_2: 0.5301 - val_n: 1.4080 - val_mean_metric: 0.3126 - lr: 0.0010
# Epoch 100/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5163 - a_1: 2.4247 - a_2: 2.2661 - b_1: 1.3807 - b_2: 1.2691 - d_1: 0.7968 - d_2: 0.8186 - n: 1.4294 - mean_metric: 0.3453 - val_loss: 4.1586 - val_a_1: 2.3678 - val_a_2: 2.3052 - val_b_1: 1.3138 - val_b_2: 1.2281 - val_d_1: 0.5670 - val_d_2: 0.4745 - val_n: 1.4176 - val_mean_metric: 0.3159 - lr: 0.0010
# Epoch 101/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5309 - a_1: 2.4404 - a_2: 2.2561 - b_1: 1.3808 - b_2: 1.2772 - d_1: 0.8121 - d_2: 0.8266 - n: 1.4288 - mean_metric: 0.3464 - val_loss: 4.1968 - val_a_1: 2.3725 - val_a_2: 2.3712 - val_b_1: 1.3325 - val_b_2: 1.1156 - val_d_1: 0.4984 - val_d_2: 0.5002 - val_n: 1.4227 - val_mean_metric: 0.3140 - lr: 0.0010
# Epoch 102/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.5013 - a_1: 2.4419 - a_2: 2.2213 - b_1: 1.3876 - b_2: 1.2699 - d_1: 0.8114 - d_2: 0.8254 - n: 1.4260 - mean_metric: 0.3451 - val_loss: 4.1280 - val_a_1: 2.3602 - val_a_2: 2.3277 - val_b_1: 1.3243 - val_b_2: 1.0935 - val_d_1: 0.4596 - val_d_2: 0.5001 - val_n: 1.4240 - val_mean_metric: 0.3099 - lr: 0.0010
# Epoch 103/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4991 - a_1: 2.4336 - a_2: 2.2628 - b_1: 1.3838 - b_2: 1.2471 - d_1: 0.8120 - d_2: 0.8131 - n: 1.4249 - mean_metric: 0.3450 - val_loss: 4.0851 - val_a_1: 2.3484 - val_a_2: 2.2931 - val_b_1: 1.2399 - val_b_2: 1.1815 - val_d_1: 0.5030 - val_d_2: 0.4840 - val_n: 1.4141 - val_mean_metric: 0.3091 - lr: 0.0010
# Epoch 104/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4524 - a_1: 2.4216 - a_2: 2.2139 - b_1: 1.3734 - b_2: 1.2429 - d_1: 0.8117 - d_2: 0.8200 - n: 1.4242 - mean_metric: 0.3427 - val_loss: 4.1364 - val_a_1: 2.3487 - val_a_2: 2.3239 - val_b_1: 1.2945 - val_b_2: 1.1340 - val_d_1: 0.5135 - val_d_2: 0.4964 - val_n: 1.4168 - val_mean_metric: 0.3112 - lr: 0.0010
# Epoch 105/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4263 - a_1: 2.4059 - a_2: 2.1809 - b_1: 1.3655 - b_2: 1.2361 - d_1: 0.8087 - d_2: 0.8345 - n: 1.4269 - mean_metric: 0.3410 - val_loss: 4.1587 - val_a_1: 2.3334 - val_a_2: 2.3348 - val_b_1: 1.3141 - val_b_2: 1.1880 - val_d_1: 0.5013 - val_d_2: 0.4762 - val_n: 1.4193 - val_mean_metric: 0.3125 - lr: 0.0010
# Epoch 106/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4854 - a_1: 2.4145 - a_2: 2.2096 - b_1: 1.3865 - b_2: 1.2535 - d_1: 0.8419 - d_2: 0.8281 - n: 1.4317 - mean_metric: 0.3445 - val_loss: 4.1850 - val_a_1: 2.3424 - val_a_2: 2.3651 - val_b_1: 1.3072 - val_b_2: 1.1539 - val_d_1: 0.5460 - val_d_2: 0.4911 - val_n: 1.4192 - val_mean_metric: 0.3143 - lr: 0.0010
# Epoch 107/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4475 - a_1: 2.4070 - a_2: 2.2130 - b_1: 1.3766 - b_2: 1.2397 - d_1: 0.8155 - d_2: 0.8092 - n: 1.4318 - mean_metric: 0.3422 - val_loss: 4.1439 - val_a_1: 2.3417 - val_a_2: 2.3325 - val_b_1: 1.2764 - val_b_2: 1.1643 - val_d_1: 0.4918 - val_d_2: 0.5023 - val_n: 1.4192 - val_mean_metric: 0.3112 - lr: 0.0010
# Epoch 108/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4287 - a_1: 2.4026 - a_2: 2.2029 - b_1: 1.3586 - b_2: 1.2306 - d_1: 0.8048 - d_2: 0.8267 - n: 1.4301 - mean_metric: 0.3409 - val_loss: 4.1521 - val_a_1: 2.3477 - val_a_2: 2.3252 - val_b_1: 1.2853 - val_b_2: 1.1496 - val_d_1: 0.5310 - val_d_2: 0.5179 - val_n: 1.4214 - val_mean_metric: 0.3128 - lr: 0.0010
# Epoch 109/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4676 - a_1: 2.3942 - a_2: 2.1889 - b_1: 1.3947 - b_2: 1.2710 - d_1: 0.8083 - d_2: 0.8329 - n: 1.4266 - mean_metric: 0.3430 - val_loss: 4.1434 - val_a_1: 2.3314 - val_a_2: 2.3570 - val_b_1: 1.2998 - val_b_2: 1.1160 - val_d_1: 0.4998 - val_d_2: 0.5183 - val_n: 1.4193 - val_mean_metric: 0.3116 - lr: 0.0010
# Epoch 110/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4717 - a_1: 2.4219 - a_2: 2.2009 - b_1: 1.3763 - b_2: 1.2310 - d_1: 0.8122 - d_2: 0.8219 - n: 1.4357 - mean_metric: 0.3424 - val_loss: 4.1968 - val_a_1: 2.4052 - val_a_2: 2.3425 - val_b_1: 1.2871 - val_b_2: 1.1080 - val_d_1: 0.4937 - val_d_2: 0.4928 - val_n: 1.4204 - val_mean_metric: 0.3119 - lr: 0.0010
# Epoch 111/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4761 - a_1: 2.4212 - a_2: 2.1946 - b_1: 1.4026 - b_2: 1.2658 - d_1: 0.8044 - d_2: 0.8188 - n: 1.4310 - mean_metric: 0.3437 - val_loss: 4.1549 - val_a_1: 2.3343 - val_a_2: 2.3142 - val_b_1: 1.3192 - val_b_2: 1.1604 - val_d_1: 0.5107 - val_d_2: 0.5095 - val_n: 1.4206 - val_mean_metric: 0.3125 - lr: 0.0010
# Epoch 112/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4118 - a_1: 2.3863 - a_2: 2.1691 - b_1: 1.3742 - b_2: 1.2695 - d_1: 0.7920 - d_2: 0.8101 - n: 1.4314 - mean_metric: 0.3402 - val_loss: 4.1185 - val_a_1: 2.3387 - val_a_2: 2.3363 - val_b_1: 1.2734 - val_b_2: 1.1367 - val_d_1: 0.4686 - val_d_2: 0.4968 - val_n: 1.4183 - val_mean_metric: 0.3093 - lr: 0.0010
# Epoch 113/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3938 - a_1: 2.3931 - a_2: 2.1544 - b_1: 1.3493 - b_2: 1.2498 - d_1: 0.7917 - d_2: 0.8248 - n: 1.4304 - mean_metric: 0.3388 - val_loss: 4.1134 - val_a_1: 2.3419 - val_a_2: 2.3206 - val_b_1: 1.2642 - val_b_2: 1.1133 - val_d_1: 0.4732 - val_d_2: 0.4893 - val_n: 1.4233 - val_mean_metric: 0.3079 - lr: 0.0010
# Epoch 114/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4137 - a_1: 2.3864 - a_2: 2.1584 - b_1: 1.3748 - b_2: 1.2406 - d_1: 0.8120 - d_2: 0.8314 - n: 1.4247 - mean_metric: 0.3400 - val_loss: 4.1451 - val_a_1: 2.3276 - val_a_2: 2.3286 - val_b_1: 1.2755 - val_b_2: 1.1340 - val_d_1: 0.4778 - val_d_2: 0.5436 - val_n: 1.4234 - val_mean_metric: 0.3106 - lr: 0.0010
# Epoch 115/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.4158 - a_1: 2.3959 - a_2: 2.1474 - b_1: 1.3667 - b_2: 1.2514 - d_1: 0.7910 - d_2: 0.8391 - n: 1.4309 - mean_metric: 0.3398 - val_loss: 4.1328 - val_a_1: 2.3325 - val_a_2: 2.3394 - val_b_1: 1.2365 - val_b_2: 1.1586 - val_d_1: 0.4824 - val_d_2: 0.4973 - val_n: 1.4227 - val_mean_metric: 0.3093 - lr: 0.0010
# Epoch 116/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3833 - a_1: 2.3827 - a_2: 2.1310 - b_1: 1.3714 - b_2: 1.2306 - d_1: 0.8010 - d_2: 0.8301 - n: 1.4305 - mean_metric: 0.3384 - val_loss: 4.2004 - val_a_1: 2.3136 - val_a_2: 2.3829 - val_b_1: 1.3095 - val_b_2: 1.1271 - val_d_1: 0.5667 - val_d_2: 0.4946 - val_n: 1.4233 - val_mean_metric: 0.3141 - lr: 0.0010
# Epoch 117/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3694 - a_1: 2.3752 - a_2: 2.1253 - b_1: 1.3616 - b_2: 1.2495 - d_1: 0.7911 - d_2: 0.8377 - n: 1.4319 - mean_metric: 0.3381 - val_loss: 4.1726 - val_a_1: 2.3171 - val_a_2: 2.3983 - val_b_1: 1.2676 - val_b_2: 1.1105 - val_d_1: 0.5039 - val_d_2: 0.4932 - val_n: 1.4266 - val_mean_metric: 0.3108 - lr: 0.0010
# Epoch 118/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3921 - a_1: 2.3623 - a_2: 2.1548 - b_1: 1.3721 - b_2: 1.2331 - d_1: 0.7902 - d_2: 0.8339 - n: 1.4388 - mean_metric: 0.3385 - val_loss: 4.1683 - val_a_1: 2.3378 - val_a_2: 2.3669 - val_b_1: 1.2660 - val_b_2: 1.1105 - val_d_1: 0.5025 - val_d_2: 0.5090 - val_n: 1.4267 - val_mean_metric: 0.3109 - lr: 0.0010
# Epoch 119/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3635 - a_1: 2.3635 - a_2: 2.1244 - b_1: 1.3712 - b_2: 1.2293 - d_1: 0.7888 - d_2: 0.8194 - n: 1.4366 - mean_metric: 0.3369 - val_loss: 4.2359 - val_a_1: 2.3168 - val_a_2: 2.4144 - val_b_1: 1.3212 - val_b_2: 1.1325 - val_d_1: 0.4886 - val_d_2: 0.4769 - val_n: 1.4310 - val_mean_metric: 0.3129 - lr: 0.0010
# Epoch 120/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3401 - a_1: 2.3772 - a_2: 2.0859 - b_1: 1.3617 - b_2: 1.2472 - d_1: 0.8035 - d_2: 0.8007 - n: 1.4314 - mean_metric: 0.3360 - val_loss: 4.0911 - val_a_1: 2.3090 - val_a_2: 2.3442 - val_b_1: 1.2324 - val_b_2: 1.1094 - val_d_1: 0.4643 - val_d_2: 0.4872 - val_n: 1.4272 - val_mean_metric: 0.3062 - lr: 0.0010
# Epoch 121/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3613 - a_1: 2.3560 - a_2: 2.1211 - b_1: 1.3658 - b_2: 1.2297 - d_1: 0.7948 - d_2: 0.8239 - n: 1.4346 - mean_metric: 0.3366 - val_loss: 4.1810 - val_a_1: 2.3308 - val_a_2: 2.3631 - val_b_1: 1.2710 - val_b_2: 1.1358 - val_d_1: 0.5335 - val_d_2: 0.5206 - val_n: 1.4347 - val_mean_metric: 0.3132 - lr: 0.0010
# Epoch 122/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3211 - a_1: 2.3536 - a_2: 2.0969 - b_1: 1.3540 - b_2: 1.2055 - d_1: 0.8131 - d_2: 0.8190 - n: 1.4293 - mean_metric: 0.3349 - val_loss: 4.1424 - val_a_1: 2.3026 - val_a_2: 2.3571 - val_b_1: 1.2616 - val_b_2: 1.1670 - val_d_1: 0.4635 - val_d_2: 0.4705 - val_n: 1.4281 - val_mean_metric: 0.3087 - lr: 0.0010
# Epoch 123/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.2967 - a_1: 2.3527 - a_2: 2.0812 - b_1: 1.3574 - b_2: 1.2105 - d_1: 0.7725 - d_2: 0.8292 - n: 1.4350 - mean_metric: 0.3337 - val_loss: 4.1965 - val_a_1: 2.3186 - val_a_2: 2.3727 - val_b_1: 1.2952 - val_b_2: 1.1116 - val_d_1: 0.5204 - val_d_2: 0.5133 - val_n: 1.4303 - val_mean_metric: 0.3123 - lr: 0.0010
# Epoch 124/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3046 - a_1: 2.3504 - a_2: 2.0762 - b_1: 1.3605 - b_2: 1.2331 - d_1: 0.7820 - d_2: 0.8012 - n: 1.4389 - mean_metric: 0.3339 - val_loss: 4.1532 - val_a_1: 2.3069 - val_a_2: 2.3463 - val_b_1: 1.2847 - val_b_2: 1.1438 - val_d_1: 0.5003 - val_d_2: 0.4894 - val_n: 1.4360 - val_mean_metric: 0.3105 - lr: 0.0010
# Epoch 125/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 4.3653 - a_1: 2.3459 - a_2: 2.1201 - b_1: 1.3469 - b_2: 1.2244 - d_1: 0.8152 - d_2: 0.8436 - n: 1.4366 - mean_metric: 0.3368 - val_loss: 4.2009 - val_a_1: 2.3174 - val_a_2: 2.3683 - val_b_1: 1.2871 - val_b_2: 1.1046 - val_d_1: 0.5579 - val_d_2: 0.4876 - val_n: 1.4351 - val_mean_metric: 0.3122 - lr: 0.0010
# Epoch 126/1000
# ...
# Epoch 960/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7982 - a_1: 1.3288 - a_2: 1.0927 - b_1: 1.1082 - b_2: 1.0130 - d_1: 0.7747 - d_2: 0.6997 - n: 1.4632 - mean_metric: 0.2486 - val_loss: 5.6623 - val_a_1: 2.8365 - val_a_2: 2.8523 - val_b_1: 1.4759 - val_b_2: 1.1837 - val_d_1: 0.4642 - val_d_2: 0.4124 - val_n: 1.4642 - val_mean_metric: 0.3490 - lr: 7.7650e-05
# Epoch 961/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7978 - a_1: 1.3306 - a_2: 1.1050 - b_1: 1.1155 - b_2: 0.9923 - d_1: 0.7692 - d_2: 0.7100 - n: 1.4630 - mean_metric: 0.2488 - val_loss: 5.6690 - val_a_1: 2.8363 - val_a_2: 2.8630 - val_b_1: 1.4720 - val_b_2: 1.1872 - val_d_1: 0.4739 - val_d_2: 0.4160 - val_n: 1.4646 - val_mean_metric: 0.3498 - lr: 7.6000e-05
# Epoch 962/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8234 - a_1: 1.3497 - a_2: 1.0938 - b_1: 1.1242 - b_2: 1.0193 - d_1: 0.7828 - d_2: 0.6897 - n: 1.4595 - mean_metric: 0.2500 - val_loss: 5.6457 - val_a_1: 2.8260 - val_a_2: 2.8564 - val_b_1: 1.4684 - val_b_2: 1.1826 - val_d_1: 0.4688 - val_d_2: 0.4113 - val_n: 1.4642 - val_mean_metric: 0.3486 - lr: 7.4350e-05
# Epoch 963/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8041 - a_1: 1.3425 - a_2: 1.0902 - b_1: 1.1298 - b_2: 1.0212 - d_1: 0.7707 - d_2: 0.6792 - n: 1.4640 - mean_metric: 0.2493 - val_loss: 5.6690 - val_a_1: 2.8261 - val_a_2: 2.8691 - val_b_1: 1.4779 - val_b_2: 1.1829 - val_d_1: 0.4679 - val_d_2: 0.4168 - val_n: 1.4643 - val_mean_metric: 0.3495 - lr: 7.2700e-05
# Epoch 964/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7824 - a_1: 1.3247 - a_2: 1.0740 - b_1: 1.1248 - b_2: 1.0315 - d_1: 0.7660 - d_2: 0.6894 - n: 1.4573 - mean_metric: 0.2482 - val_loss: 5.6627 - val_a_1: 2.8298 - val_a_2: 2.8577 - val_b_1: 1.4762 - val_b_2: 1.1824 - val_d_1: 0.4688 - val_d_2: 0.4115 - val_n: 1.4639 - val_mean_metric: 0.3491 - lr: 7.1050e-05
# Epoch 965/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7842 - a_1: 1.3385 - a_2: 1.0869 - b_1: 1.1168 - b_2: 1.0150 - d_1: 0.7710 - d_2: 0.6968 - n: 1.4606 - mean_metric: 0.2488 - val_loss: 5.6512 - val_a_1: 2.8207 - val_a_2: 2.8653 - val_b_1: 1.4790 - val_b_2: 1.1836 - val_d_1: 0.4666 - val_d_2: 0.4108 - val_n: 1.4637 - val_mean_metric: 0.3490 - lr: 6.9400e-05
# Epoch 966/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8111 - a_1: 1.3607 - a_2: 1.0926 - b_1: 1.1145 - b_2: 1.0200 - d_1: 0.7726 - d_2: 0.6976 - n: 1.4598 - mean_metric: 0.2499 - val_loss: 5.6507 - val_a_1: 2.8338 - val_a_2: 2.8529 - val_b_1: 1.4648 - val_b_2: 1.1861 - val_d_1: 0.4651 - val_d_2: 0.4125 - val_n: 1.4641 - val_mean_metric: 0.3487 - lr: 6.7750e-05
# Epoch 967/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7880 - a_1: 1.3370 - a_2: 1.0872 - b_1: 1.1235 - b_2: 1.0095 - d_1: 0.7633 - d_2: 0.7050 - n: 1.4630 - mean_metric: 0.2489 - val_loss: 5.6811 - val_a_1: 2.8310 - val_a_2: 2.8677 - val_b_1: 1.4811 - val_b_2: 1.1820 - val_d_1: 0.4699 - val_d_2: 0.4103 - val_n: 1.4644 - val_mean_metric: 0.3496 - lr: 6.6100e-05
# Epoch 968/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8271 - a_1: 1.3563 - a_2: 1.0726 - b_1: 1.1391 - b_2: 1.0318 - d_1: 0.7761 - d_2: 0.6967 - n: 1.4646 - mean_metric: 0.2506 - val_loss: 5.6716 - val_a_1: 2.8254 - val_a_2: 2.8743 - val_b_1: 1.4679 - val_b_2: 1.1811 - val_d_1: 0.4674 - val_d_2: 0.4094 - val_n: 1.4638 - val_mean_metric: 0.3490 - lr: 6.4450e-05
# Epoch 969/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7754 - a_1: 1.3397 - a_2: 1.0904 - b_1: 1.1239 - b_2: 1.0112 - d_1: 0.7619 - d_2: 0.6875 - n: 1.4639 - mean_metric: 0.2486 - val_loss: 5.6635 - val_a_1: 2.8205 - val_a_2: 2.8690 - val_b_1: 1.4692 - val_b_2: 1.1866 - val_d_1: 0.4660 - val_d_2: 0.4099 - val_n: 1.4637 - val_mean_metric: 0.3489 - lr: 6.2800e-05
# Epoch 970/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7909 - a_1: 1.3164 - a_2: 1.0965 - b_1: 1.1229 - b_2: 1.0071 - d_1: 0.7766 - d_2: 0.7002 - n: 1.4632 - mean_metric: 0.2487 - val_loss: 5.6566 - val_a_1: 2.8236 - val_a_2: 2.8690 - val_b_1: 1.4607 - val_b_2: 1.1862 - val_d_1: 0.4681 - val_d_2: 0.4061 - val_n: 1.4644 - val_mean_metric: 0.3487 - lr: 6.1150e-05
# Epoch 971/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7938 - a_1: 1.3339 - a_2: 1.0830 - b_1: 1.1293 - b_2: 1.0074 - d_1: 0.7746 - d_2: 0.6962 - n: 1.4627 - mean_metric: 0.2490 - val_loss: 5.6556 - val_a_1: 2.8246 - val_a_2: 2.8651 - val_b_1: 1.4570 - val_b_2: 1.1924 - val_d_1: 0.4685 - val_d_2: 0.4117 - val_n: 1.4644 - val_mean_metric: 0.3488 - lr: 5.9500e-05
# Epoch 972/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8010 - a_1: 1.3290 - a_2: 1.1030 - b_1: 1.1330 - b_2: 1.0167 - d_1: 0.7731 - d_2: 0.6877 - n: 1.4617 - mean_metric: 0.2495 - val_loss: 5.6696 - val_a_1: 2.8275 - val_a_2: 2.8688 - val_b_1: 1.4655 - val_b_2: 1.1840 - val_d_1: 0.4746 - val_d_2: 0.4079 - val_n: 1.4640 - val_mean_metric: 0.3491 - lr: 5.7850e-05
# Epoch 973/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8047 - a_1: 1.3536 - a_2: 1.0941 - b_1: 1.1174 - b_2: 1.0188 - d_1: 0.7668 - d_2: 0.7032 - n: 1.4627 - mean_metric: 0.2499 - val_loss: 5.6589 - val_a_1: 2.8204 - val_a_2: 2.8770 - val_b_1: 1.4661 - val_b_2: 1.1785 - val_d_1: 0.4719 - val_d_2: 0.4138 - val_n: 1.4639 - val_mean_metric: 0.3491 - lr: 5.6200e-05
# Epoch 974/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8173 - a_1: 1.3635 - a_2: 1.0796 - b_1: 1.1216 - b_2: 1.0358 - d_1: 0.7772 - d_2: 0.6831 - n: 1.4668 - mean_metric: 0.2502 - val_loss: 5.6729 - val_a_1: 2.8230 - val_a_2: 2.8685 - val_b_1: 1.4713 - val_b_2: 1.1885 - val_d_1: 0.4761 - val_d_2: 0.4063 - val_n: 1.4639 - val_mean_metric: 0.3493 - lr: 5.4550e-05
# Epoch 975/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8006 - a_1: 1.3402 - a_2: 1.0865 - b_1: 1.1292 - b_2: 1.0131 - d_1: 0.7664 - d_2: 0.7029 - n: 1.4609 - mean_metric: 0.2493 - val_loss: 5.6656 - val_a_1: 2.8193 - val_a_2: 2.8744 - val_b_1: 1.4633 - val_b_2: 1.1851 - val_d_1: 0.4757 - val_d_2: 0.4075 - val_n: 1.4642 - val_mean_metric: 0.3490 - lr: 5.2900e-05
# Epoch 976/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8048 - a_1: 1.3581 - a_2: 1.0935 - b_1: 1.1159 - b_2: 1.0184 - d_1: 0.7555 - d_2: 0.6981 - n: 1.4633 - mean_metric: 0.2495 - val_loss: 5.6688 - val_a_1: 2.8271 - val_a_2: 2.8682 - val_b_1: 1.4659 - val_b_2: 1.1867 - val_d_1: 0.4683 - val_d_2: 0.4106 - val_n: 1.4636 - val_mean_metric: 0.3491 - lr: 5.1250e-05
# Epoch 977/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8141 - a_1: 1.3538 - a_2: 1.0901 - b_1: 1.1244 - b_2: 1.0384 - d_1: 0.7675 - d_2: 0.6810 - n: 1.4597 - mean_metric: 0.2498 - val_loss: 5.6583 - val_a_1: 2.8210 - val_a_2: 2.8727 - val_b_1: 1.4596 - val_b_2: 1.1873 - val_d_1: 0.4660 - val_d_2: 0.4059 - val_n: 1.4640 - val_mean_metric: 0.3486 - lr: 4.9600e-05
# Epoch 978/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8021 - a_1: 1.3224 - a_2: 1.0964 - b_1: 1.1203 - b_2: 1.0314 - d_1: 0.7906 - d_2: 0.6899 - n: 1.4605 - mean_metric: 0.2497 - val_loss: 5.6609 - val_a_1: 2.8298 - val_a_2: 2.8626 - val_b_1: 1.4631 - val_b_2: 1.1768 - val_d_1: 0.4695 - val_d_2: 0.4157 - val_n: 1.4633 - val_mean_metric: 0.3488 - lr: 4.7950e-05
# Epoch 979/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8080 - a_1: 1.3435 - a_2: 1.0916 - b_1: 1.1255 - b_2: 0.9979 - d_1: 0.7804 - d_2: 0.7075 - n: 1.4620 - mean_metric: 0.2496 - val_loss: 5.6739 - val_a_1: 2.8290 - val_a_2: 2.8747 - val_b_1: 1.4655 - val_b_2: 1.1854 - val_d_1: 0.4726 - val_d_2: 0.4082 - val_n: 1.4633 - val_mean_metric: 0.3493 - lr: 4.6300e-05
# Epoch 980/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8067 - a_1: 1.3369 - a_2: 1.0743 - b_1: 1.1154 - b_2: 1.0245 - d_1: 0.7784 - d_2: 0.6998 - n: 1.4622 - mean_metric: 0.2491 - val_loss: 5.6725 - val_a_1: 2.8287 - val_a_2: 2.8779 - val_b_1: 1.4552 - val_b_2: 1.1872 - val_d_1: 0.4778 - val_d_2: 0.4078 - val_n: 1.4633 - val_mean_metric: 0.3493 - lr: 4.4650e-05
# Epoch 981/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7917 - a_1: 1.3422 - a_2: 1.0850 - b_1: 1.1296 - b_2: 0.9990 - d_1: 0.7617 - d_2: 0.7000 - n: 1.4635 - mean_metric: 0.2486 - val_loss: 5.6689 - val_a_1: 2.8272 - val_a_2: 2.8741 - val_b_1: 1.4571 - val_b_2: 1.1866 - val_d_1: 0.4717 - val_d_2: 0.4101 - val_n: 1.4635 - val_mean_metric: 0.3491 - lr: 4.3000e-05
# Epoch 982/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7949 - a_1: 1.3446 - a_2: 1.0877 - b_1: 1.1145 - b_2: 1.0042 - d_1: 0.7802 - d_2: 0.6897 - n: 1.4599 - mean_metric: 0.2486 - val_loss: 5.6615 - val_a_1: 2.8256 - val_a_2: 2.8693 - val_b_1: 1.4555 - val_b_2: 1.1862 - val_d_1: 0.4704 - val_d_2: 0.4063 - val_n: 1.4630 - val_mean_metric: 0.3486 - lr: 4.1350e-05
# Epoch 983/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7938 - a_1: 1.3562 - a_2: 1.0657 - b_1: 1.1204 - b_2: 1.0003 - d_1: 0.7611 - d_2: 0.7060 - n: 1.4601 - mean_metric: 0.2483 - val_loss: 5.6626 - val_a_1: 2.8268 - val_a_2: 2.8724 - val_b_1: 1.4600 - val_b_2: 1.1843 - val_d_1: 0.4725 - val_d_2: 0.4084 - val_n: 1.4630 - val_mean_metric: 0.3490 - lr: 3.9700e-05
# Epoch 984/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7961 - a_1: 1.3503 - a_2: 1.0874 - b_1: 1.1115 - b_2: 1.0116 - d_1: 0.7820 - d_2: 0.6842 - n: 1.4613 - mean_metric: 0.2490 - val_loss: 5.6576 - val_a_1: 2.8228 - val_a_2: 2.8672 - val_b_1: 1.4580 - val_b_2: 1.1864 - val_d_1: 0.4699 - val_d_2: 0.4069 - val_n: 1.4633 - val_mean_metric: 0.3485 - lr: 3.8050e-05
# Epoch 985/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8075 - a_1: 1.3681 - a_2: 1.0903 - b_1: 1.1165 - b_2: 1.0218 - d_1: 0.7733 - d_2: 0.6849 - n: 1.4618 - mean_metric: 0.2499 - val_loss: 5.6666 - val_a_1: 2.8272 - val_a_2: 2.8714 - val_b_1: 1.4561 - val_b_2: 1.1867 - val_d_1: 0.4702 - val_d_2: 0.4120 - val_n: 1.4631 - val_mean_metric: 0.3489 - lr: 3.6400e-05
# Epoch 986/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8224 - a_1: 1.3514 - a_2: 1.1000 - b_1: 1.1156 - b_2: 1.0165 - d_1: 0.7795 - d_2: 0.7010 - n: 1.4610 - mean_metric: 0.2501 - val_loss: 5.6841 - val_a_1: 2.8318 - val_a_2: 2.8759 - val_b_1: 1.4647 - val_b_2: 1.1820 - val_d_1: 0.4715 - val_d_2: 0.4120 - val_n: 1.4626 - val_mean_metric: 0.3494 - lr: 3.4750e-05
# Epoch 987/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7826 - a_1: 1.3171 - a_2: 1.0845 - b_1: 1.1279 - b_2: 1.0190 - d_1: 0.7607 - d_2: 0.6892 - n: 1.4616 - mean_metric: 0.2479 - val_loss: 5.6768 - val_a_1: 2.8304 - val_a_2: 2.8738 - val_b_1: 1.4645 - val_b_2: 1.1849 - val_d_1: 0.4683 - val_d_2: 0.4107 - val_n: 1.4636 - val_mean_metric: 0.3493 - lr: 3.3100e-05
# Epoch 988/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7975 - a_1: 1.3345 - a_2: 1.0745 - b_1: 1.1294 - b_2: 1.0256 - d_1: 0.7673 - d_2: 0.6934 - n: 1.4627 - mean_metric: 0.2489 - val_loss: 5.6756 - val_a_1: 2.8331 - val_a_2: 2.8736 - val_b_1: 1.4592 - val_b_2: 1.1815 - val_d_1: 0.4713 - val_d_2: 0.4083 - val_n: 1.4634 - val_mean_metric: 0.3491 - lr: 3.1450e-05
# Epoch 989/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8113 - a_1: 1.3603 - a_2: 1.0844 - b_1: 1.1225 - b_2: 1.0116 - d_1: 0.7607 - d_2: 0.6878 - n: 1.4660 - mean_metric: 0.2491 - val_loss: 5.6753 - val_a_1: 2.8321 - val_a_2: 2.8701 - val_b_1: 1.4656 - val_b_2: 1.1815 - val_d_1: 0.4724 - val_d_2: 0.4106 - val_n: 1.4637 - val_mean_metric: 0.3492 - lr: 2.9800e-05
# Epoch 990/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7839 - a_1: 1.3242 - a_2: 1.0839 - b_1: 1.1202 - b_2: 1.0223 - d_1: 0.7674 - d_2: 0.6961 - n: 1.4619 - mean_metric: 0.2485 - val_loss: 5.6673 - val_a_1: 2.8306 - val_a_2: 2.8687 - val_b_1: 1.4659 - val_b_2: 1.1804 - val_d_1: 0.4676 - val_d_2: 0.4068 - val_n: 1.4631 - val_mean_metric: 0.3488 - lr: 2.8150e-05
# Epoch 991/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7805 - a_1: 1.3309 - a_2: 1.0845 - b_1: 1.1283 - b_2: 1.0221 - d_1: 0.7515 - d_2: 0.6920 - n: 1.4590 - mean_metric: 0.2483 - val_loss: 5.6648 - val_a_1: 2.8268 - val_a_2: 2.8684 - val_b_1: 1.4691 - val_b_2: 1.1800 - val_d_1: 0.4672 - val_d_2: 0.4066 - val_n: 1.4627 - val_mean_metric: 0.3488 - lr: 2.6500e-05
# Epoch 992/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7696 - a_1: 1.3223 - a_2: 1.0767 - b_1: 1.1081 - b_2: 1.0311 - d_1: 0.7569 - d_2: 0.6888 - n: 1.4626 - mean_metric: 0.2475 - val_loss: 5.6693 - val_a_1: 2.8280 - val_a_2: 2.8658 - val_b_1: 1.4722 - val_b_2: 1.1804 - val_d_1: 0.4701 - val_d_2: 0.4044 - val_n: 1.4631 - val_mean_metric: 0.3488 - lr: 2.4850e-05
# Epoch 993/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7852 - a_1: 1.3318 - a_2: 1.0725 - b_1: 1.1197 - b_2: 1.0101 - d_1: 0.7652 - d_2: 0.6911 - n: 1.4605 - mean_metric: 0.2477 - val_loss: 5.6810 - val_a_1: 2.8287 - val_a_2: 2.8722 - val_b_1: 1.4763 - val_b_2: 1.1790 - val_d_1: 0.4677 - val_d_2: 0.4075 - val_n: 1.4630 - val_mean_metric: 0.3492 - lr: 2.3200e-05
# Epoch 994/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7903 - a_1: 1.3280 - a_2: 1.0788 - b_1: 1.1162 - b_2: 1.0134 - d_1: 0.7722 - d_2: 0.6991 - n: 1.4623 - mean_metric: 0.2483 - val_loss: 5.6796 - val_a_1: 2.8312 - val_a_2: 2.8726 - val_b_1: 1.4729 - val_b_2: 1.1761 - val_d_1: 0.4678 - val_d_2: 0.4074 - val_n: 1.4633 - val_mean_metric: 0.3491 - lr: 2.1550e-05
# Epoch 995/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7770 - a_1: 1.3423 - a_2: 1.0785 - b_1: 1.1109 - b_2: 1.0020 - d_1: 0.7641 - d_2: 0.6916 - n: 1.4596 - mean_metric: 0.2477 - val_loss: 5.6770 - val_a_1: 2.8303 - val_a_2: 2.8687 - val_b_1: 1.4769 - val_b_2: 1.1791 - val_d_1: 0.4671 - val_d_2: 0.4063 - val_n: 1.4633 - val_mean_metric: 0.3491 - lr: 1.9900e-05
# Epoch 996/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7868 - a_1: 1.3229 - a_2: 1.0700 - b_1: 1.1258 - b_2: 1.0070 - d_1: 0.7718 - d_2: 0.7018 - n: 1.4641 - mean_metric: 0.2481 - val_loss: 5.6835 - val_a_1: 2.8318 - val_a_2: 2.8712 - val_b_1: 1.4822 - val_b_2: 1.1741 - val_d_1: 0.4682 - val_d_2: 0.4056 - val_n: 1.4631 - val_mean_metric: 0.3492 - lr: 1.8250e-05
# Epoch 997/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7688 - a_1: 1.3387 - a_2: 1.0766 - b_1: 1.1274 - b_2: 1.0064 - d_1: 0.7474 - d_2: 0.6980 - n: 1.4621 - mean_metric: 0.2479 - val_loss: 5.6815 - val_a_1: 2.8325 - val_a_2: 2.8662 - val_b_1: 1.4815 - val_b_2: 1.1806 - val_d_1: 0.4661 - val_d_2: 0.4043 - val_n: 1.4628 - val_mean_metric: 0.3492 - lr: 1.6600e-05
# Epoch 998/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8016 - a_1: 1.3322 - a_2: 1.0748 - b_1: 1.1404 - b_2: 1.0127 - d_1: 0.7712 - d_2: 0.6833 - n: 1.4631 - mean_metric: 0.2486 - val_loss: 5.6787 - val_a_1: 2.8323 - val_a_2: 2.8678 - val_b_1: 1.4816 - val_b_2: 1.1768 - val_d_1: 0.4661 - val_d_2: 0.4049 - val_n: 1.4627 - val_mean_metric: 0.3491 - lr: 1.4950e-05
# Epoch 999/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.8005 - a_1: 1.3146 - a_2: 1.0789 - b_1: 1.1277 - b_2: 1.0399 - d_1: 0.7681 - d_2: 0.6893 - n: 1.4606 - mean_metric: 0.2487 - val_loss: 5.6794 - val_a_1: 2.8335 - val_a_2: 2.8706 - val_b_1: 1.4763 - val_b_2: 1.1750 - val_d_1: 0.4670 - val_d_2: 0.4026 - val_n: 1.4629 - val_mean_metric: 0.3490 - lr: 1.3300e-05
# Epoch 1000/1000
# 70/70 [==============================] - 1s 20ms/step - loss: 2.7741 - a_1: 1.3365 - a_2: 1.0850 - b_1: 1.1103 - b_2: 0.9901 - d_1: 0.7650 - d_2: 0.6927 - n: 1.4594 - mean_metric: 0.2472 - val_loss: 5.6731 - val_a_1: 2.8307 - val_a_2: 2.8660 - val_b_1: 1.4779 - val_b_2: 1.1767 - val_d_1: 0.4663 - val_d_2: 0.4031 - val_n: 1.4628 - val_mean_metric: 0.3488 - lr: 1.1650e-05

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(val_epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    varftest, coefvarftest)
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 5.7495 - a_1: 2.7688 - a_2: 3.0252 - b_1: 1.4242 - b_2: 1.2719 - d_1: 0.4707 - d_2: 0.3975 - n: 1.4643 - mean_metric: 0.3567

# %%
predictions = model.predict(varftest)
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefvarftest, predictions)

# Calcula la desviación estándar del error
error = coefvarftest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 1.5457850108968432, Desviación estándar del error: 2.266194734660778, Error absoluto máximo: 9.989936492405832

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefvarftest - predictions)

# Calcula el error para cada dato
error = coefvarftest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefvarftest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.3546690504787801
# Desviación estándar del error relativo: 0.17474309101153904
# Error absoluto máximo relativo: 1.8712003827095032

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales con ruido/History 20,50/historyconvtrayec50.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos con ruido/Modelos 20,50/'

# %%
model.save(path_to_save + '/convolucionaltr50.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_activation':custom_activation,'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)
new_model = keras.models.load_model('../../../Modelos con ruido/Modelos 20,50/convolucionaltr50.h5', custom_objects=custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp
condini = []
varf = []
coef = []
contador = 0
T = 5
t_span = [0,5]
dt = 0.1
N = int(T/dt)

for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    # Declaramos el vector de tiempo
    t_span = [0, 5]
    times = np.linspace(t_span[0], t_span[1], 200)
    
    varfci2 = []
    for i_ci in range(10):
        # Definimos las condiciones iniciales
        X = np.zeros(N)
        Y = np.zeros(N)
        X[0] = random.randint(0, 10)
        Y[0] = random.randint(0, 10)
        y0 = np.array([X[0], Y[0]])
        condini.append(y0)

        # Simulación con ruido
        for i in range(N-1):
            noise1 = np.random.normal(0, .5)
            noise2 = np.random.normal(0, .5)

            X[i+1] = X[i] + (a1/(1+Y[i]**n) - d1*X[i] + b1)*dt + noise1*np.sqrt(dt)
            Y[i+1] = Y[i] + (a2/(1+X[i]**n) - d2*Y[i] + b2)*dt + noise2*np.sqrt(dt)


        varfci = np.append([X], [Y], axis=0)
        varfci2.append(varfci)

       

    varf= varfci2
    print('--------------------------------------------')
    print(coef1)
    print(np.shape(varf))
varf = np.array(varf)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [5, 2, 7, 8, 6, 2, 1]
# (10, 2, 50)

# %%
varfnone = varf[None, :]
varfnone = np.transpose(varfnone, (0,3,1,2))

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(varfnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# [[ 3.  3.  7. 10.  6.  2.  2.]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
import matplotlib.pyplot as plt

t_span = [0, 5]
times = np.linspace(t_span[0], t_span[1], 50)
fig, axes = plt.subplots(2, 5, figsize=(20, 10))  # 5 filas de gráficos, 2 columnas
axes = axes.ravel()  # esto convierte la matriz de ejes en un array plano, para poder iterar sobre ellos

for i in range(10):
    axes[i].plot(times, np.array(varf)[i, 0, :], label=f"Concentración X")
    axes[i].plot(times,np.array(varf)[i,1,:], label=f"Concentración Y")
    axes[i].set_xlabel('Tiempo')
    axes[i].set_ylabel('Concentración de genes')
    axes[i].legend()
    axes[i].set_title(f'{i+1}° Condición inicial')

fig.suptitle('Trayectorias con coeficientes reales', fontsize=20)  # Título general para todas las subfiguras

plt.tight_layout()  # esto ayuda a que los gráficos no se superpongan
plt.show()

# %%
np.shape(new_predictions)
# Out:
# (1, 7)

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]

varfpred = []

def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

# Declaramos el vector de tiempo
t_span = [0, 5]
times = np.linspace(t_span[0], t_span[1], 50)
varfci2pred = []

for i_ci in range(0, 10):
# Definimos las condiciones iniciales
    y0 = condini[i_ci]
    # Resolvemos
    sol = solve_ivp(f, t_span, y0, t_eval=times)
    tiempo = sol.t
    var1pred = sol.y[0]
    var2pred = sol.y[1]
    varfcipred = np.append([var1pred], [var2pred], axis=0)
    varfci2pred.append(varfcipred)
    
varfpred= varfci2pred

fig, axes = plt.subplots(2, 5, figsize=(20, 10))  # 5 filas de gráficos, 2 columnas
axes = axes.ravel()  # esto convierte la matriz de ejes en un array plano, para poder iterar sobre ellos
# Graficamos
for i in range(10):
    axes[i].plot(times, np.array(varfpred)[i, 0, :], label=f"Concentración X")
    axes[i].plot(times,np.array(varfpred)[i,1,:], label=f"Concentración Y")
    axes[i].set_xlabel('Tiempo')
    axes[i].set_ylabel('Concentración de genes')
    axes[i].legend()
    axes[i].set_title(f'{i+1}° Condición inicial')

fig.suptitle('Trayectorias con coeficientes pronosticados', fontsize=20)  # Título general para todas las subfiguras

plt.tight_layout()  
plt.show()

# %% [markdown]
# ## Graficamos ambos

# %%
# %matplotlib inline
#%matplotlib qt
t_span = [0, 5]
times = np.linspace(t_span[0], t_span[1], 50)
fig, axes = plt.subplots(2, 5, figsize=(20, 10))  # 2 filas de gráficos, 5 columnas
axes = axes.ravel()  # esto convierte la matriz de ejes en un array plano, para poder iterar sobre ellos

for i in range(10):
    # varf
    axes[i].plot(times, np.array(varf)[i, 0, :], label=f"Concentración X real", alpha=1, color = 'blue')
    axes[i].plot(times,np.array(varf)[i,1,:], label=f"Concentración Y real", alpha=1, color = 'orange')

    # varfpred
    axes[i].plot(times, np.array(varfpred)[i, 0, :], label=f"Concentración X pronosticada", alpha=0.3)
    axes[i].plot(times,np.array(varfpred)[i,1,:], label=f"Concentración Y pronosticada", alpha=0.3)

    axes[i].set_xlabel('Tiempo')
    axes[i].set_ylabel('Concentración de genes')
    axes[i].legend()
    axes[i].set_title(f'{i+1}° Condición inicial')

fig.suptitle('Comparación real y pronosticada', fontsize=20)  # Título general para todas las subfiguras

plt.tight_layout()  # esto ayuda a que los gráficos no se superpongan
plt.show()

# %% [markdown]
# # Graficamos las diferencias

# %%
t_span = [0, 5]
times = np.linspace(t_span[0], t_span[1], 50)
fig, axes = plt.subplots(2, 5, figsize=(20, 10))  # 2 filas de gráficos, 5 columnas
axes = axes.ravel()  # esto convierte la matriz de ejes en un array plano, para poder iterar sobre ellos

sum_errors_X = []
sum_errors_Y = []
for i in range(10):
    # Diferencia
    diff_X = np.array(varf)[i, 0, :] - np.array(varfpred)[i, 0, :]
    diff_Y = np.array(varf)[i, 1, :] - np.array(varfpred)[i, 1, :]
    axes[i].plot(times, diff_X, label=f"Diferencia concentración X", alpha=1, color = "purple")
    axes[i].plot(times, diff_Y, label=f"Diferencia concentración Y", alpha=1, color = "g")
    # Suma de los errores
    sum_errors_X.append(np.sum(np.abs(diff_X)))
    sum_errors_Y.append(np.sum(np.abs(diff_Y)))

    axes[i].set_xlabel('Tiempo')
    axes[i].set_ylabel('Concentración de genes')
    axes[i].legend()
    axes[i].set_title(f'{i+1}° Condición inicial')

fig.suptitle('Comparación real y pronosticada', fontsize=20)  # Título general para todas las subfiguras

plt.tight_layout()  # esto ayuda a que los gráficos no se superpongan
plt.show()

# %%
print(np.sum(sum_errors_X)/2000)
print(np.sum(sum_errors_Y)/2000)
# Out:
# 0.052840781821124914
# 0.07784061709861138
