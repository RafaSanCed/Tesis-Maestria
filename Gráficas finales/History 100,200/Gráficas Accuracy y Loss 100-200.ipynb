# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfcampvec = pd.read_csv('historycampvec100.csv')
dfcosto = pd.read_csv('historycampvec100funcioncosto.csv')
dfconvcampvec = pd.read_csv('historyconvcampvec100.csv')
dfconvtray = pd.read_csv('historyconvtrayec200.csv')
dftray = pd.read_csv('historytrayec200.csv')
dfcosto
# Out:
#           loss  accuracy   val_loss  val_accuracy        lr
# 0    23.222572  0.275000  11.019129         0.269  0.001000
# 1    20.243862  0.245857  11.117661         0.208  0.001000
# 2    19.746256  0.284000   9.399395         0.328  0.001000
# 3    19.301498  0.290429   9.340211         0.342  0.001000
# 4    19.440130  0.293571   8.482206         0.336  0.001000
# ..         ...       ...        ...           ...       ...
# 995  15.925649  0.217286  18.287136         0.213  0.000018
# 996  16.072342  0.223143  20.078390         0.207  0.000017
# 997  16.308073  0.220857  19.098009         0.200  0.000015
# 998  16.268078  0.216143  20.935072         0.211  0.000013
# 999  15.905339  0.219571  20.644369         0.212  0.000012
#
# [1000 rows x 5 columns]

# %%
fig, ax = plt.subplots()

# Configura el título, etiquetas de eje usando el método 'set' del objeto 'ax'
ax.set_title('Función de costo campos vectoriales')
ax.set_xlabel('Epochs')
ax.set_ylabel('Valor función de costo')

# Ahora, dibuja las líneas para los otros dataframes.
dfcampvec['loss'].plot(kind='line', ax=ax, label='Campo vectorial densa')
dfcosto['loss'].plot(kind='line', ax=ax, label='Campo vectorial función de costo')
dfconvcampvec['loss'].plot(kind='line', ax=ax, label='Convolucional campo vectorial')
dfconvtray['loss'].plot(kind='line', ax=ax, label='Convolucional trayectorias')
dftray['loss'].plot(kind='line', ax=ax, label='Trayectorias densa')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = dfcosto['val_loss'].plot(kind='line', title='Val_Loss', xlabel='Epochs', ylabel='Valor función de costo datos validación')
dfcampvec['val_loss'].plot(kind='line', ax=ax, label='Campo vectorial densa')
dfcosto['val_loss'].plot(kind='line', ax=ax, label='Campo vectorial función de costo')
dfconvcampvec['val_loss'].plot(kind='line', ax=ax, label='Convolucional campo vectorial')
dfconvtray['val_loss'].plot(kind='line', ax=ax, label='Convolucional trayectorias')
dftray['val_loss'].plot(kind='line', ax=ax, label='Trayectorias densa')
# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = dfcosto['accuracy'].plot(kind='line', title='Val_Loss', xlabel='Epochs', ylabel='Valor precisión')
dfcampvec['accuracy'].plot(kind='line', ax=ax, label='Campo vectorial densa')
dfcosto['accuracy'].plot(kind='line', ax=ax, label='Campo vectorial función de costo')
dfconvcampvec['accuracy'].plot(kind='line', ax=ax, label='Convolucional campo vectorial')
dfconvtray['accuracy'].plot(kind='line', ax=ax, label='Convolucional trayectorias')
dftray['accuracy'].plot(kind='line', ax=ax, label='Trayectorias densa')
# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = dfcosto['val_accuracy'].plot(kind='line', title='Val_Loss', xlabel='Epochs', ylabel='Valor precisión')
dfcampvec['val_accuracy'].plot(kind='line', ax=ax, label='Campo vectorial densa')
dfcosto['val_accuracy'].plot(kind='line', ax=ax, label='Campo vectorial función de costo')
dfconvcampvec['val_accuracy'].plot(kind='line', ax=ax, label='Convolucional campo vectorial')
dfconvtray['val_accuracy'].plot(kind='line', ax=ax, label='Convolucional trayectorias')
dftray['val_accuracy'].plot(kind='line', ax=ax, label='Trayectorias densa')
# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()
