# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
conv200 = pd.read_csv('History 100,200/historyconvtrayec200.csv')
dense200 = pd.read_csv('History 100,200/historytrayec200.csv')
conv100 = pd.read_csv('History 50,100//historyconvtrayec100.csv')
dense100 =  pd.read_csv('History 50,100/historytrayec100.csv')
conv50 = pd.read_csv('History 20,50/historyconvtrayec50.csv')
dense50 = pd.read_csv('History 20,50/historytrayec50.csv')
conv50
# Out:
#           loss       a_1       a_2       b_1       b_2       d_1       d_2
# 0    10.955194  2.799141  2.767599  2.536006  2.693903  2.287957  2.120655  \
# 1     9.685841  2.775717  2.737574  2.266082  2.519756  1.857078  1.755439
# 2     9.063599  2.732421  2.701384  2.212198  2.416524  1.630967  1.661166
# 3     8.591114  2.701818  2.672017  2.191056  2.350232  1.531192  1.527516
# 4     8.121593  2.680137  2.654147  2.153931  2.219481  1.430072  1.389678
# ..         ...       ...       ...       ...       ...       ...       ...
# 995   2.916591  1.419509  1.507277  1.095299  0.967674  0.754141  0.750008
# 996   2.940880  1.438122  1.514590  1.084743  0.982400  0.744338  0.759695
# 997   2.923121  1.430640  1.510133  1.092117  0.986703  0.749003  0.754221
# 998   2.927421  1.430902  1.513146  1.096848  0.965780  0.768020  0.748676
# 999   2.935468  1.431909  1.502163  1.119138  0.962244  0.752934  0.761662
#
# ...

# %%
ax = df200conv['val_loss'].plot(kind='line', title='Función de costo datos de validación determinista', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Conv 200')
df200dense['val_loss'].plot(kind='line', ax=ax, label='Densa 200')
df100dense['val_loss'].plot(kind='line', ax=ax, label='Densa 100')
df100conv['val_loss'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_loss'].plot(kind='line', ax=ax, label='Conv 50')
df50dense['val_loss'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
# Creación de la gráfica
plt.figure(figsize=(12, 8))

# Graficar 'mean_metric' y 'val_mean_metric' para conv200 y dense200
plt.plot(conv200['mean_metric'], label='conv200 mean_metric', linestyle='--')
plt.plot(conv200['val_mean_metric'], label='conv200 val_mean_metric', linestyle='-')
plt.plot(dense200['mean_metric'], label='dense200 mean_metric', linestyle='--')
plt.plot(dense200['val_mean_metric'], label='dense200 val_mean_metric', linestyle='-')

# Graficar 'mean_metric' y 'val_mean_metric' para conv100 y dense100
plt.plot(conv100['mean_metric'], label='conv100 mean_metric', linestyle='--')
plt.plot(conv100['val_mean_metric'], label='conv100 val_mean_metric', linestyle='-')
plt.plot(dense100['mean_metric'], label='dense100 mean_metric', linestyle='--')
plt.plot(dense100['val_mean_metric'], label='dense100 val_mean_metric', linestyle='-')

# Graficar 'mean_metric' y 'val_mean_metric' para conv50 y dense50
plt.plot(conv50['mean_metric'], label='conv50 mean_metric', linestyle='--')
plt.plot(conv50['val_mean_metric'], label='conv50 val_mean_metric', linestyle='-')
plt.plot(dense50['mean_metric'], label='dense50 mean_metric', linestyle='--')
plt.plot(dense50['val_mean_metric'], label='dense50 val_mean_metric', linestyle='-')

# Añadir títulos y etiquetas
plt.title('Comparación de mean_metric y val_mean_metric en campos vecotoriales')
plt.xlabel('Época')
plt.ylabel('Valor de mean_metric y val_mean_metric')
plt.legend()

# Mostrar la gráfica
plt.show()

# %%
ax = df200conv['val_loss'].plot(kind='line', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Conv 200')
df100conv['val_loss'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_loss'].plot(kind='line', ax=ax, label='Conv 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = df200dense['val_loss'].plot(kind='line', title='Loss y Val_Loss Redes Densas', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Densa 200')
df100dense['val_loss'].plot(kind='line', ax=ax, label='Densa 100')
df50dense['val_loss'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %% [markdown]
# # MAE

# %%
ax = df200conv['val_mae'].plot(kind='line', title='Error Absoluto Medio', xlabel='Épocas', 
                                ylabel='MAE en datos de validación', label='Conv 200')
df200dense['val_mae'].plot(kind='line', ax=ax, label='Densa 200')
df100dense['val_mae'].plot(kind='line', ax=ax, label='Densa 100')
df100conv['val_mae'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_mae'].plot(kind='line', ax=ax, label='Conv 50')
df50dense['val_mae'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = df200conv['val_mae'].plot(kind='line', xlabel='Épocas', 
                                ylabel='MAE en datos de validación', label='Conv 200')
df100conv['val_mae'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_mae'].plot(kind='line', ax=ax, label='Conv 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = df100dense['val_mae'].plot(kind='line', xlabel='Épocas', 
                                ylabel='MAE en datos de validación', label='Densa 100')
df200dense['val_mae'].plot(kind='line', ax=ax, label='Densa 200')
df50dense['val_mae'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Suponiendo que tus DataFrames ya están cargados
# df100tray, df100conv, df50tray, df50conv, df20tray, df20conv
dataset_names = ['dense100', 'conv100', 'dense100', 'conv100', 'dense50', 'conv50']
# Lista de todos los DataFrames
dataframes = [dense200, conv200, dense100, conv100, dense50, conv50]

# Columnas que quieres graficar
columns_to_plot = ['a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n']

# Iterar a través de cada columna
for col in columns_to_plot:
    plt.figure(figsize=(10, 6))
    for i, (df, name) in enumerate(zip(dataframes, dataset_names)):
        plt.plot(df[col], label=f"{col}  {name}")
        plt.plot(df[f"val_{col}"], linestyle='--', label=f"val_{col}  {name}")
    plt.savefig(f"{col}_plot trayec.png")
    plt.title(f"Plot for {col}")
    plt.xlabel("Epochs")
    plt.ylabel(col)
    plt.legend()
    plt.show()
