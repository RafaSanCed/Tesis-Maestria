# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_24324\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos/Campo 20 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 20, 20)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (1000, 2, 20, 20)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (1000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (2000, 2, 20, 20)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (2000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 20, 20), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 20
SHUFFLE_BUFFER_SIZE = 20

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
model.add(Flatten(input_shape=(2, 20, 20)))
model.add(BatchNormalization())
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(100, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(50, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(BatchNormalization())
model.add(Dense(50, activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='tanh', kernel_initializer='glorot_uniform', kernel_regularizer=l1(0.001)))
model.add(Dense(7, activation = custom_activation
               ))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 800)               0
#
#  batch_normalization (BatchN  (None, 800)              3200
#  ormalization)
#
#  dense (Dense)               (None, 100)               80100
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 50)                5050
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  batch_normalization_1 (Batc  (None, 50)               200
#  hNormalization)
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_5 (Dense)             (None, 50)                2550
#
#  dense_6 (Dense)             (None, 7)                 357
#
# =================================================================
# Total params: 114,207
# Trainable params: 112,507
# Non-trainable params: 1,700
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= 'mean_squared_error',
              metrics=metrics)

# %%
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 1000,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 350/350 [==============================] - 2s 2ms/step - loss: 10.3931 - a_1: 2.3512 - a_2: 2.5791 - b_1: 1.5652 - b_2: 1.5471 - d_1: 1.3340 - d_2: 1.3351 - n: 1.5173 - mean_metric: 0.4043 - val_loss: 7.0639 - val_a_1: 1.6340 - val_a_2: 1.4788 - val_b_1: 0.8923 - val_b_2: 0.9880 - val_d_1: 0.9009 - val_d_2: 0.7616 - val_n: 1.2525 - val_mean_metric: 0.2589 - lr: 0.0010
# Epoch 2/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 7.6000 - a_1: 1.7488 - a_2: 1.8365 - b_1: 1.3684 - b_2: 1.3793 - d_1: 1.2203 - d_2: 1.2631 - n: 1.3593 - mean_metric: 0.3366 - val_loss: 5.4865 - val_a_1: 1.2941 - val_a_2: 1.3411 - val_b_1: 0.9036 - val_b_2: 0.9252 - val_d_1: 0.7375 - val_d_2: 0.7072 - val_n: 1.2347 - val_mean_metric: 0.2339 - lr: 0.0010
# Epoch 3/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 6.3336 - a_1: 1.7059 - a_2: 1.7193 - b_1: 1.3241 - b_2: 1.3619 - d_1: 1.1413 - d_2: 1.1920 - n: 1.3484 - mean_metric: 0.3238 - val_loss: 4.6287 - val_a_1: 1.2747 - val_a_2: 1.3379 - val_b_1: 0.8241 - val_b_2: 0.8578 - val_d_1: 0.9080 - val_d_2: 0.7154 - val_n: 1.2403 - val_mean_metric: 0.2344 - lr: 0.0010
# Epoch 4/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 5.5439 - a_1: 1.6670 - a_2: 1.6814 - b_1: 1.2892 - b_2: 1.3169 - d_1: 1.1413 - d_2: 1.1836 - n: 1.3377 - mean_metric: 0.3181 - val_loss: 4.1557 - val_a_1: 1.2943 - val_a_2: 1.3591 - val_b_1: 0.9204 - val_b_2: 0.8768 - val_d_1: 0.8987 - val_d_2: 0.6881 - val_n: 1.2424 - val_mean_metric: 0.2383 - lr: 0.0010
# Epoch 5/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 5.0677 - a_1: 1.6492 - a_2: 1.6836 - b_1: 1.2840 - b_2: 1.2993 - d_1: 1.1667 - d_2: 1.1683 - n: 1.3389 - mean_metric: 0.3172 - val_loss: 3.6350 - val_a_1: 1.1969 - val_a_2: 1.2240 - val_b_1: 1.0420 - val_b_2: 0.8641 - val_d_1: 0.7018 - val_d_2: 0.7199 - val_n: 1.2384 - val_mean_metric: 0.2289 - lr: 0.0010
# Epoch 6/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 4.6344 - a_1: 1.6424 - a_2: 1.6511 - b_1: 1.2558 - b_2: 1.2816 - d_1: 1.1365 - d_2: 1.1341 - n: 1.3353 - mean_metric: 0.3121 - val_loss: 3.3166 - val_a_1: 1.2887 - val_a_2: 1.3182 - val_b_1: 0.8615 - val_b_2: 0.8770 - val_d_1: 0.7331 - val_d_2: 0.5888 - val_n: 1.2333 - val_mean_metric: 0.2260 - lr: 0.0010
# Epoch 7/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 4.3417 - a_1: 1.6232 - a_2: 1.6371 - b_1: 1.2494 - b_2: 1.2643 - d_1: 1.1309 - d_2: 1.1290 - n: 1.3359 - mean_metric: 0.3100 - val_loss: 3.0374 - val_a_1: 1.2450 - val_a_2: 1.2275 - val_b_1: 0.8383 - val_b_2: 0.7978 - val_d_1: 0.6817 - val_d_2: 0.6883 - val_n: 1.2362 - val_mean_metric: 0.2199 - lr: 0.0010
# Epoch 8/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 4.0868 - a_1: 1.5978 - a_2: 1.6426 - b_1: 1.2444 - b_2: 1.2524 - d_1: 1.1100 - d_2: 1.1073 - n: 1.3298 - mean_metric: 0.3071 - val_loss: 3.0109 - val_a_1: 1.3384 - val_a_2: 1.3084 - val_b_1: 0.9494 - val_b_2: 0.8822 - val_d_1: 0.7493 - val_d_2: 0.6716 - val_n: 1.2319 - val_mean_metric: 0.2336 - lr: 0.0010
# Epoch 9/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.9105 - a_1: 1.5943 - a_2: 1.6104 - b_1: 1.2271 - b_2: 1.2590 - d_1: 1.1144 - d_2: 1.1170 - n: 1.3299 - mean_metric: 0.3060 - val_loss: 2.8261 - val_a_1: 1.2308 - val_a_2: 1.1830 - val_b_1: 0.7982 - val_b_2: 0.8799 - val_d_1: 0.8113 - val_d_2: 0.9936 - val_n: 1.2361 - val_mean_metric: 0.2336 - lr: 0.0010
# Epoch 10/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.7354 - a_1: 1.5786 - a_2: 1.5832 - b_1: 1.2462 - b_2: 1.2192 - d_1: 1.0756 - d_2: 1.1236 - n: 1.3323 - mean_metric: 0.3029 - val_loss: 2.6294 - val_a_1: 1.1914 - val_a_2: 1.2879 - val_b_1: 0.8946 - val_b_2: 0.8033 - val_d_1: 0.8099 - val_d_2: 0.6571 - val_n: 1.2401 - val_mean_metric: 0.2254 - lr: 0.0010
# Epoch 11/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.6135 - a_1: 1.5687 - a_2: 1.5971 - b_1: 1.2064 - b_2: 1.2270 - d_1: 1.0916 - d_2: 1.1025 - n: 1.3275 - mean_metric: 0.3016 - val_loss: 2.4047 - val_a_1: 1.2588 - val_a_2: 1.1997 - val_b_1: 0.7855 - val_b_2: 0.7620 - val_d_1: 0.6161 - val_d_2: 0.5836 - val_n: 1.2322 - val_mean_metric: 0.2109 - lr: 0.0010
# Epoch 12/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.4980 - a_1: 1.5591 - a_2: 1.5689 - b_1: 1.2094 - b_2: 1.2375 - d_1: 1.0470 - d_2: 1.0989 - n: 1.3260 - mean_metric: 0.2991 - val_loss: 2.2822 - val_a_1: 1.1754 - val_a_2: 1.1041 - val_b_1: 0.8207 - val_b_2: 0.8100 - val_d_1: 0.5583 - val_d_2: 0.5503 - val_n: 1.2356 - val_mean_metric: 0.2048 - lr: 0.0010
# Epoch 13/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.3933 - a_1: 1.5495 - a_2: 1.5646 - b_1: 1.2036 - b_2: 1.1968 - d_1: 1.0399 - d_2: 1.1034 - n: 1.3193 - mean_metric: 0.2969 - val_loss: 2.3258 - val_a_1: 1.1537 - val_a_2: 1.1783 - val_b_1: 0.7697 - val_b_2: 0.8829 - val_d_1: 0.7820 - val_d_2: 0.6602 - val_n: 1.2398 - val_mean_metric: 0.2183 - lr: 0.0010
# Epoch 14/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.3008 - a_1: 1.5300 - a_2: 1.5495 - b_1: 1.1908 - b_2: 1.1879 - d_1: 1.0409 - d_2: 1.0747 - n: 1.3252 - mean_metric: 0.2944 - val_loss: 2.1793 - val_a_1: 1.1765 - val_a_2: 1.1721 - val_b_1: 0.7586 - val_b_2: 0.8179 - val_d_1: 0.5535 - val_d_2: 0.5928 - val_n: 1.2362 - val_mean_metric: 0.2066 - lr: 0.0010
# Epoch 15/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.2406 - a_1: 1.5216 - a_2: 1.5397 - b_1: 1.1740 - b_2: 1.2188 - d_1: 1.0425 - d_2: 1.0614 - n: 1.3239 - mean_metric: 0.2937 - val_loss: 2.1657 - val_a_1: 1.2069 - val_a_2: 1.1272 - val_b_1: 0.7709 - val_b_2: 0.8870 - val_d_1: 0.6287 - val_d_2: 0.6329 - val_n: 1.2305 - val_mean_metric: 0.2123 - lr: 0.0010
# Epoch 16/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.0971 - a_1: 1.4930 - a_2: 1.5214 - b_1: 1.1442 - b_2: 1.1678 - d_1: 1.0011 - d_2: 1.0323 - n: 1.3232 - mean_metric: 0.2872 - val_loss: 2.0381 - val_a_1: 1.1173 - val_a_2: 1.1255 - val_b_1: 0.6641 - val_b_2: 0.6987 - val_d_1: 0.8135 - val_d_2: 0.5301 - val_n: 1.2393 - val_mean_metric: 0.2027 - lr: 0.0010
# Epoch 17/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 3.0380 - a_1: 1.4944 - a_2: 1.5217 - b_1: 1.1324 - b_2: 1.1133 - d_1: 1.0035 - d_2: 1.0380 - n: 1.3157 - mean_metric: 0.2851 - val_loss: 1.9768 - val_a_1: 1.1202 - val_a_2: 1.1180 - val_b_1: 0.7083 - val_b_2: 0.7047 - val_d_1: 0.6209 - val_d_2: 0.5034 - val_n: 1.2272 - val_mean_metric: 0.1966 - lr: 0.0010
# Epoch 18/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.9751 - a_1: 1.5094 - a_2: 1.5030 - b_1: 1.1198 - b_2: 1.1205 - d_1: 0.9672 - d_2: 1.0170 - n: 1.3230 - mean_metric: 0.2832 - val_loss: 1.9699 - val_a_1: 1.1601 - val_a_2: 1.1106 - val_b_1: 0.6420 - val_b_2: 0.7029 - val_d_1: 0.6931 - val_d_2: 0.6176 - val_n: 1.2287 - val_mean_metric: 0.2016 - lr: 0.0010
# Epoch 19/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.9132 - a_1: 1.4753 - a_2: 1.4975 - b_1: 1.0930 - b_2: 1.1049 - d_1: 0.9740 - d_2: 1.0152 - n: 1.3146 - mean_metric: 0.2802 - val_loss: 1.9107 - val_a_1: 1.0689 - val_a_2: 1.1214 - val_b_1: 0.6799 - val_b_2: 0.7252 - val_d_1: 0.5556 - val_d_2: 0.5638 - val_n: 1.2299 - val_mean_metric: 0.1947 - lr: 0.0010
# Epoch 20/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.8608 - a_1: 1.4800 - a_2: 1.4996 - b_1: 1.0863 - b_2: 1.0935 - d_1: 0.9578 - d_2: 0.9723 - n: 1.3143 - mean_metric: 0.2780 - val_loss: 1.8841 - val_a_1: 1.0533 - val_a_2: 1.0480 - val_b_1: 0.6591 - val_b_2: 0.7096 - val_d_1: 0.7539 - val_d_2: 0.5535 - val_n: 1.2191 - val_mean_metric: 0.1965 - lr: 0.0010
# Epoch 21/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.8579 - a_1: 1.4813 - a_2: 1.4914 - b_1: 1.1103 - b_2: 1.1137 - d_1: 0.9500 - d_2: 0.9780 - n: 1.3174 - mean_metric: 0.2792 - val_loss: 1.8410 - val_a_1: 1.0948 - val_a_2: 1.0779 - val_b_1: 0.6150 - val_b_2: 0.6910 - val_d_1: 0.5974 - val_d_2: 0.5220 - val_n: 1.2240 - val_mean_metric: 0.1907 - lr: 0.0010
# Epoch 22/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.8127 - a_1: 1.4526 - a_2: 1.4750 - b_1: 1.1114 - b_2: 1.0962 - d_1: 0.9450 - d_2: 0.9571 - n: 1.3166 - mean_metric: 0.2765 - val_loss: 1.8259 - val_a_1: 1.0059 - val_a_2: 1.0908 - val_b_1: 0.8758 - val_b_2: 0.6709 - val_d_1: 0.4463 - val_d_2: 0.4428 - val_n: 1.2280 - val_mean_metric: 0.1886 - lr: 0.0010
# Epoch 23/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.7555 - a_1: 1.4605 - a_2: 1.4528 - b_1: 1.0639 - b_2: 1.0818 - d_1: 0.9432 - d_2: 0.9530 - n: 1.3181 - mean_metric: 0.2737 - val_loss: 1.7705 - val_a_1: 1.0700 - val_a_2: 1.0709 - val_b_1: 0.6960 - val_b_2: 0.6099 - val_d_1: 0.5079 - val_d_2: 0.4765 - val_n: 1.2167 - val_mean_metric: 0.1850 - lr: 0.0010
# Epoch 24/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.7617 - a_1: 1.4450 - a_2: 1.4692 - b_1: 1.0797 - b_2: 1.1002 - d_1: 0.9494 - d_2: 0.9452 - n: 1.3047 - mean_metric: 0.2741 - val_loss: 1.8591 - val_a_1: 1.0295 - val_a_2: 1.0988 - val_b_1: 0.7645 - val_b_2: 0.6901 - val_d_1: 0.6493 - val_d_2: 0.5464 - val_n: 1.2204 - val_mean_metric: 0.1966 - lr: 0.0010
# Epoch 25/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.7613 - a_1: 1.4602 - a_2: 1.5025 - b_1: 1.0787 - b_2: 1.0898 - d_1: 0.9565 - d_2: 0.9206 - n: 1.3083 - mean_metric: 0.2751 - val_loss: 1.8091 - val_a_1: 1.0028 - val_a_2: 1.0711 - val_b_1: 0.7531 - val_b_2: 0.6122 - val_d_1: 0.6401 - val_d_2: 0.5748 - val_n: 1.2322 - val_mean_metric: 0.1927 - lr: 0.0010
# Epoch 26/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.6595 - a_1: 1.4349 - a_2: 1.4624 - b_1: 1.0576 - b_2: 1.0483 - d_1: 0.9237 - d_2: 0.9083 - n: 1.3027 - mean_metric: 0.2690 - val_loss: 1.8844 - val_a_1: 1.1184 - val_a_2: 1.0964 - val_b_1: 0.7856 - val_b_2: 0.6572 - val_d_1: 0.7276 - val_d_2: 0.5240 - val_n: 1.2187 - val_mean_metric: 0.2008 - lr: 0.0010
# Epoch 27/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.6819 - a_1: 1.4219 - a_2: 1.4648 - b_1: 1.0854 - b_2: 1.0813 - d_1: 0.9082 - d_2: 0.9316 - n: 1.2963 - mean_metric: 0.2708 - val_loss: 1.8365 - val_a_1: 1.1137 - val_a_2: 1.1478 - val_b_1: 0.6350 - val_b_2: 0.6698 - val_d_1: 0.6858 - val_d_2: 0.6083 - val_n: 1.2137 - val_mean_metric: 0.1990 - lr: 0.0010
# Epoch 28/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.6682 - a_1: 1.4340 - a_2: 1.4601 - b_1: 1.0791 - b_2: 1.0639 - d_1: 0.9162 - d_2: 0.9256 - n: 1.3030 - mean_metric: 0.2704 - val_loss: 1.8137 - val_a_1: 1.0343 - val_a_2: 1.0778 - val_b_1: 0.8112 - val_b_2: 0.6182 - val_d_1: 0.6126 - val_d_2: 0.6038 - val_n: 1.2229 - val_mean_metric: 0.1958 - lr: 0.0010
# Epoch 29/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.6285 - a_1: 1.4441 - a_2: 1.4518 - b_1: 1.0664 - b_2: 1.0311 - d_1: 0.8999 - d_2: 0.9037 - n: 1.3029 - mean_metric: 0.2680 - val_loss: 1.7520 - val_a_1: 1.0544 - val_a_2: 1.0390 - val_b_1: 0.8416 - val_b_2: 0.6143 - val_d_1: 0.5255 - val_d_2: 0.4925 - val_n: 1.2152 - val_mean_metric: 0.1894 - lr: 0.0010
# Epoch 30/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.6349 - a_1: 1.4343 - a_2: 1.4528 - b_1: 1.0575 - b_2: 1.0599 - d_1: 0.8941 - d_2: 0.9542 - n: 1.3023 - mean_metric: 0.2697 - val_loss: 1.7748 - val_a_1: 1.0176 - val_a_2: 1.0404 - val_b_1: 0.7132 - val_b_2: 0.7307 - val_d_1: 0.7391 - val_d_2: 0.5141 - val_n: 1.2016 - val_mean_metric: 0.1951 - lr: 0.0010
# Epoch 31/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.6303 - a_1: 1.4324 - a_2: 1.4447 - b_1: 1.0891 - b_2: 1.0426 - d_1: 0.9154 - d_2: 0.9246 - n: 1.2968 - mean_metric: 0.2696 - val_loss: 1.7048 - val_a_1: 0.9838 - val_a_2: 1.0857 - val_b_1: 0.6923 - val_b_2: 0.7008 - val_d_1: 0.5034 - val_d_2: 0.4979 - val_n: 1.2197 - val_mean_metric: 0.1861 - lr: 0.0010
# Epoch 32/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5999 - a_1: 1.4183 - a_2: 1.4385 - b_1: 1.0535 - b_2: 1.0531 - d_1: 0.9129 - d_2: 0.9269 - n: 1.2952 - mean_metric: 0.2679 - val_loss: 1.6973 - val_a_1: 1.0130 - val_a_2: 1.0573 - val_b_1: 0.7108 - val_b_2: 0.6363 - val_d_1: 0.5055 - val_d_2: 0.5721 - val_n: 1.2101 - val_mean_metric: 0.1868 - lr: 0.0010
# Epoch 33/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5618 - a_1: 1.4159 - a_2: 1.4472 - b_1: 1.0238 - b_2: 1.0650 - d_1: 0.8759 - d_2: 0.8948 - n: 1.2972 - mean_metric: 0.2651 - val_loss: 1.7323 - val_a_1: 1.0610 - val_a_2: 1.0690 - val_b_1: 0.7088 - val_b_2: 0.7573 - val_d_1: 0.5619 - val_d_2: 0.5016 - val_n: 1.2171 - val_mean_metric: 0.1925 - lr: 0.0010
# Epoch 34/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5498 - a_1: 1.4314 - a_2: 1.4307 - b_1: 1.0258 - b_2: 1.0355 - d_1: 0.9092 - d_2: 0.9095 - n: 1.2983 - mean_metric: 0.2658 - val_loss: 1.7320 - val_a_1: 1.0049 - val_a_2: 1.0493 - val_b_1: 0.7819 - val_b_2: 0.6892 - val_d_1: 0.6019 - val_d_2: 0.5254 - val_n: 1.2147 - val_mean_metric: 0.1922 - lr: 0.0010
# Epoch 35/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5722 - a_1: 1.4279 - a_2: 1.4408 - b_1: 1.0408 - b_2: 1.0483 - d_1: 0.8887 - d_2: 0.9131 - n: 1.3024 - mean_metric: 0.2667 - val_loss: 1.7236 - val_a_1: 0.9717 - val_a_2: 1.0742 - val_b_1: 0.7424 - val_b_2: 0.7061 - val_d_1: 0.5758 - val_d_2: 0.5859 - val_n: 1.2128 - val_mean_metric: 0.1923 - lr: 0.0010
# Epoch 36/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5475 - a_1: 1.4169 - a_2: 1.4505 - b_1: 1.0322 - b_2: 1.0320 - d_1: 0.8835 - d_2: 0.9105 - n: 1.2968 - mean_metric: 0.2654 - val_loss: 1.6628 - val_a_1: 1.0746 - val_a_2: 1.0327 - val_b_1: 0.6890 - val_b_2: 0.6979 - val_d_1: 0.5350 - val_d_2: 0.4469 - val_n: 1.2126 - val_mean_metric: 0.1864 - lr: 0.0010
# Epoch 37/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5290 - a_1: 1.3947 - a_2: 1.4257 - b_1: 1.0306 - b_2: 1.0462 - d_1: 0.8958 - d_2: 0.9146 - n: 1.2896 - mean_metric: 0.2644 - val_loss: 1.7459 - val_a_1: 0.9979 - val_a_2: 1.0992 - val_b_1: 0.7095 - val_b_2: 0.6707 - val_d_1: 0.6496 - val_d_2: 0.6000 - val_n: 1.2091 - val_mean_metric: 0.1944 - lr: 0.0010
# Epoch 38/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5533 - a_1: 1.4103 - a_2: 1.4366 - b_1: 1.0538 - b_2: 1.0389 - d_1: 0.8935 - d_2: 0.9047 - n: 1.2912 - mean_metric: 0.2656 - val_loss: 1.7019 - val_a_1: 0.9860 - val_a_2: 1.0356 - val_b_1: 0.7149 - val_b_2: 0.7674 - val_d_1: 0.5458 - val_d_2: 0.5530 - val_n: 1.2119 - val_mean_metric: 0.1904 - lr: 0.0010
# Epoch 39/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4902 - a_1: 1.3889 - a_2: 1.4043 - b_1: 1.0271 - b_2: 1.0294 - d_1: 0.8820 - d_2: 0.8861 - n: 1.2878 - mean_metric: 0.2614 - val_loss: 1.6925 - val_a_1: 1.0190 - val_a_2: 1.0016 - val_b_1: 0.7204 - val_b_2: 0.7177 - val_d_1: 0.4535 - val_d_2: 0.6377 - val_n: 1.2071 - val_mean_metric: 0.1886 - lr: 0.0010
# Epoch 40/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5452 - a_1: 1.4021 - a_2: 1.4400 - b_1: 1.0450 - b_2: 1.0331 - d_1: 0.9114 - d_2: 0.9055 - n: 1.2839 - mean_metric: 0.2652 - val_loss: 1.7402 - val_a_1: 1.0298 - val_a_2: 1.0126 - val_b_1: 0.7160 - val_b_2: 0.7507 - val_d_1: 0.7197 - val_d_2: 0.5574 - val_n: 1.2029 - val_mean_metric: 0.1962 - lr: 0.0010
# Epoch 41/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5318 - a_1: 1.4217 - a_2: 1.4295 - b_1: 1.0472 - b_2: 1.0454 - d_1: 0.8972 - d_2: 0.9002 - n: 1.2935 - mean_metric: 0.2657 - val_loss: 1.6577 - val_a_1: 0.9882 - val_a_2: 1.0585 - val_b_1: 0.7391 - val_b_2: 0.6445 - val_d_1: 0.4625 - val_d_2: 0.5977 - val_n: 1.2064 - val_mean_metric: 0.1866 - lr: 0.0010
# Epoch 42/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4909 - a_1: 1.3891 - a_2: 1.4180 - b_1: 1.0260 - b_2: 1.0263 - d_1: 0.9010 - d_2: 0.9100 - n: 1.2871 - mean_metric: 0.2633 - val_loss: 1.7426 - val_a_1: 1.0035 - val_a_2: 1.0326 - val_b_1: 0.7042 - val_b_2: 0.6611 - val_d_1: 0.9261 - val_d_2: 0.5115 - val_n: 1.2147 - val_mean_metric: 0.1984 - lr: 0.0010
# Epoch 43/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4861 - a_1: 1.3808 - a_2: 1.4210 - b_1: 1.0542 - b_2: 1.0551 - d_1: 0.8765 - d_2: 0.8850 - n: 1.2843 - mean_metric: 0.2631 - val_loss: 1.6491 - val_a_1: 1.0388 - val_a_2: 1.0222 - val_b_1: 0.7340 - val_b_2: 0.6571 - val_d_1: 0.4820 - val_d_2: 0.5028 - val_n: 1.2095 - val_mean_metric: 0.1850 - lr: 0.0010
# Epoch 44/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5048 - a_1: 1.4072 - a_2: 1.4160 - b_1: 1.0468 - b_2: 1.0447 - d_1: 0.8618 - d_2: 0.9120 - n: 1.2804 - mean_metric: 0.2635 - val_loss: 1.6630 - val_a_1: 1.0154 - val_a_2: 1.0155 - val_b_1: 0.7179 - val_b_2: 0.6806 - val_d_1: 0.5189 - val_d_2: 0.6337 - val_n: 1.2010 - val_mean_metric: 0.1894 - lr: 0.0010
# Epoch 45/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4952 - a_1: 1.4034 - a_2: 1.4235 - b_1: 1.0377 - b_2: 1.0453 - d_1: 0.8772 - d_2: 0.8927 - n: 1.2814 - mean_metric: 0.2635 - val_loss: 1.6667 - val_a_1: 1.0297 - val_a_2: 1.0151 - val_b_1: 0.6727 - val_b_2: 0.6912 - val_d_1: 0.5777 - val_d_2: 0.5755 - val_n: 1.2120 - val_mean_metric: 0.1891 - lr: 0.0010
# Epoch 46/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5132 - a_1: 1.4145 - a_2: 1.4400 - b_1: 1.0516 - b_2: 1.0321 - d_1: 0.8878 - d_2: 0.9006 - n: 1.2875 - mean_metric: 0.2652 - val_loss: 1.6538 - val_a_1: 1.0014 - val_a_2: 1.0585 - val_b_1: 0.7262 - val_b_2: 0.7351 - val_d_1: 0.5817 - val_d_2: 0.4800 - val_n: 1.1983 - val_mean_metric: 0.1893 - lr: 0.0010
# Epoch 47/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.5059 - a_1: 1.4323 - a_2: 1.4364 - b_1: 1.0514 - b_2: 1.0172 - d_1: 0.8680 - d_2: 0.9074 - n: 1.2821 - mean_metric: 0.2644 - val_loss: 1.6426 - val_a_1: 0.9782 - val_a_2: 1.0390 - val_b_1: 0.6872 - val_b_2: 0.6343 - val_d_1: 0.6375 - val_d_2: 0.5839 - val_n: 1.1979 - val_mean_metric: 0.1886 - lr: 0.0010
# Epoch 48/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4848 - a_1: 1.4071 - a_2: 1.4256 - b_1: 1.0347 - b_2: 1.0082 - d_1: 0.8857 - d_2: 0.8907 - n: 1.2873 - mean_metric: 0.2626 - val_loss: 1.6433 - val_a_1: 1.0121 - val_a_2: 0.9991 - val_b_1: 0.7038 - val_b_2: 0.6652 - val_d_1: 0.4842 - val_d_2: 0.5852 - val_n: 1.2023 - val_mean_metric: 0.1851 - lr: 0.0010
# Epoch 49/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4931 - a_1: 1.3903 - a_2: 1.4231 - b_1: 1.0222 - b_2: 1.0177 - d_1: 0.8903 - d_2: 0.9188 - n: 1.2779 - mean_metric: 0.2626 - val_loss: 1.6609 - val_a_1: 1.0131 - val_a_2: 0.9812 - val_b_1: 0.6730 - val_b_2: 0.7366 - val_d_1: 0.5407 - val_d_2: 0.5725 - val_n: 1.1986 - val_mean_metric: 0.1872 - lr: 0.0010
# Epoch 50/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4357 - a_1: 1.3849 - a_2: 1.4053 - b_1: 1.0229 - b_2: 0.9884 - d_1: 0.8912 - d_2: 0.8745 - n: 1.2790 - mean_metric: 0.2596 - val_loss: 1.6327 - val_a_1: 0.9527 - val_a_2: 0.9808 - val_b_1: 0.6670 - val_b_2: 0.7571 - val_d_1: 0.5582 - val_d_2: 0.6414 - val_n: 1.2066 - val_mean_metric: 0.1888 - lr: 0.0010
# Epoch 51/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4287 - a_1: 1.3999 - a_2: 1.3973 - b_1: 1.0339 - b_2: 0.9742 - d_1: 0.8619 - d_2: 0.8991 - n: 1.2811 - mean_metric: 0.2597 - val_loss: 1.6845 - val_a_1: 1.0928 - val_a_2: 1.0437 - val_b_1: 0.7298 - val_b_2: 0.6809 - val_d_1: 0.5947 - val_d_2: 0.5171 - val_n: 1.1974 - val_mean_metric: 0.1919 - lr: 0.0010
# Epoch 52/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4087 - a_1: 1.3787 - a_2: 1.3852 - b_1: 1.0150 - b_2: 0.9582 - d_1: 0.8858 - d_2: 0.8940 - n: 1.2809 - mean_metric: 0.2579 - val_loss: 1.6372 - val_a_1: 0.9410 - val_a_2: 0.9835 - val_b_1: 0.6821 - val_b_2: 0.7417 - val_d_1: 0.4747 - val_d_2: 0.7492 - val_n: 1.1855 - val_mean_metric: 0.1885 - lr: 0.0010
# Epoch 53/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4424 - a_1: 1.3991 - a_2: 1.4100 - b_1: 1.0165 - b_2: 0.9764 - d_1: 0.8920 - d_2: 0.8995 - n: 1.2828 - mean_metric: 0.2605 - val_loss: 1.6332 - val_a_1: 1.0395 - val_a_2: 1.0040 - val_b_1: 0.7149 - val_b_2: 0.6075 - val_d_1: 0.6172 - val_d_2: 0.4837 - val_n: 1.1925 - val_mean_metric: 0.1853 - lr: 0.0010
# Epoch 54/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4323 - a_1: 1.3910 - a_2: 1.3982 - b_1: 1.0388 - b_2: 0.9680 - d_1: 0.8952 - d_2: 0.9038 - n: 1.2738 - mean_metric: 0.2603 - val_loss: 1.6929 - val_a_1: 1.1661 - val_a_2: 1.0089 - val_b_1: 0.6863 - val_b_2: 0.6110 - val_d_1: 0.6357 - val_d_2: 0.6280 - val_n: 1.1978 - val_mean_metric: 0.1944 - lr: 0.0010
# Epoch 55/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4497 - a_1: 1.3954 - a_2: 1.4116 - b_1: 1.0455 - b_2: 0.9774 - d_1: 0.8836 - d_2: 0.8873 - n: 1.2735 - mean_metric: 0.2607 - val_loss: 1.6444 - val_a_1: 0.9441 - val_a_2: 0.9532 - val_b_1: 0.6958 - val_b_2: 0.6429 - val_d_1: 0.6453 - val_d_2: 0.6114 - val_n: 1.1851 - val_mean_metric: 0.1859 - lr: 0.0010
# Epoch 56/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3994 - a_1: 1.3683 - a_2: 1.4086 - b_1: 1.0125 - b_2: 0.9549 - d_1: 0.8735 - d_2: 0.8734 - n: 1.2685 - mean_metric: 0.2568 - val_loss: 1.6117 - val_a_1: 0.9816 - val_a_2: 0.9491 - val_b_1: 0.7161 - val_b_2: 0.6575 - val_d_1: 0.7026 - val_d_2: 0.5075 - val_n: 1.1866 - val_mean_metric: 0.1867 - lr: 0.0010
# Epoch 57/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4040 - a_1: 1.3808 - a_2: 1.3916 - b_1: 1.0282 - b_2: 0.9496 - d_1: 0.8826 - d_2: 0.9136 - n: 1.2742 - mean_metric: 0.2586 - val_loss: 1.7420 - val_a_1: 1.0977 - val_a_2: 1.0794 - val_b_1: 0.6775 - val_b_2: 0.7033 - val_d_1: 0.6939 - val_d_2: 0.6988 - val_n: 1.1944 - val_mean_metric: 0.2012 - lr: 0.0010
# Epoch 58/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4141 - a_1: 1.3799 - a_2: 1.4054 - b_1: 1.0423 - b_2: 0.9585 - d_1: 0.8580 - d_2: 0.9039 - n: 1.2667 - mean_metric: 0.2585 - val_loss: 1.6761 - val_a_1: 1.0296 - val_a_2: 1.0445 - val_b_1: 0.8305 - val_b_2: 0.6363 - val_d_1: 0.6427 - val_d_2: 0.5416 - val_n: 1.1906 - val_mean_metric: 0.1938 - lr: 0.0010
# Epoch 59/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4006 - a_1: 1.3803 - a_2: 1.3928 - b_1: 1.0364 - b_2: 0.9404 - d_1: 0.8588 - d_2: 0.9087 - n: 1.2746 - mean_metric: 0.2577 - val_loss: 1.5910 - val_a_1: 1.0036 - val_a_2: 0.9699 - val_b_1: 0.7434 - val_b_2: 0.5736 - val_d_1: 0.4642 - val_d_2: 0.5884 - val_n: 1.1872 - val_mean_metric: 0.1811 - lr: 0.0010
# Epoch 60/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3872 - a_1: 1.3936 - a_2: 1.3766 - b_1: 1.0215 - b_2: 0.9338 - d_1: 0.8784 - d_2: 0.9033 - n: 1.2697 - mean_metric: 0.2573 - val_loss: 1.6008 - val_a_1: 1.0898 - val_a_2: 0.9333 - val_b_1: 0.6600 - val_b_2: 0.6557 - val_d_1: 0.5077 - val_d_2: 0.6161 - val_n: 1.1806 - val_mean_metric: 0.1848 - lr: 0.0010
# Epoch 61/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.4121 - a_1: 1.3988 - a_2: 1.3975 - b_1: 1.0413 - b_2: 0.9503 - d_1: 0.8826 - d_2: 0.8980 - n: 1.2600 - mean_metric: 0.2590 - val_loss: 1.5520 - val_a_1: 1.0380 - val_a_2: 0.9591 - val_b_1: 0.6802 - val_b_2: 0.6546 - val_d_1: 0.4126 - val_d_2: 0.5299 - val_n: 1.1805 - val_mean_metric: 0.1786 - lr: 0.0010
# Epoch 62/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3986 - a_1: 1.3895 - a_2: 1.3832 - b_1: 1.0378 - b_2: 0.9514 - d_1: 0.8479 - d_2: 0.8940 - n: 1.2647 - mean_metric: 0.2569 - val_loss: 1.6040 - val_a_1: 1.1578 - val_a_2: 0.9347 - val_b_1: 0.7943 - val_b_2: 0.5677 - val_d_1: 0.5222 - val_d_2: 0.5075 - val_n: 1.1816 - val_mean_metric: 0.1855 - lr: 0.0010
# Epoch 63/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3731 - a_1: 1.3894 - a_2: 1.3773 - b_1: 1.0287 - b_2: 0.9387 - d_1: 0.8635 - d_2: 0.8974 - n: 1.2606 - mean_metric: 0.2565 - val_loss: 1.5357 - val_a_1: 1.0238 - val_a_2: 0.9516 - val_b_1: 0.6929 - val_b_2: 0.5356 - val_d_1: 0.5168 - val_d_2: 0.4959 - val_n: 1.1782 - val_mean_metric: 0.1767 - lr: 0.0010
# Epoch 64/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3727 - a_1: 1.3720 - a_2: 1.3848 - b_1: 1.0297 - b_2: 0.9368 - d_1: 0.8634 - d_2: 0.9075 - n: 1.2591 - mean_metric: 0.2565 - val_loss: 1.5984 - val_a_1: 1.0089 - val_a_2: 0.9352 - val_b_1: 0.7751 - val_b_2: 0.6044 - val_d_1: 0.6433 - val_d_2: 0.4977 - val_n: 1.1773 - val_mean_metric: 0.1848 - lr: 0.0010
# Epoch 65/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3822 - a_1: 1.3782 - a_2: 1.3745 - b_1: 1.0250 - b_2: 0.9388 - d_1: 0.8780 - d_2: 0.8952 - n: 1.2533 - mean_metric: 0.2561 - val_loss: 1.5787 - val_a_1: 1.0044 - val_a_2: 0.9750 - val_b_1: 0.6804 - val_b_2: 0.5846 - val_d_1: 0.5440 - val_d_2: 0.5633 - val_n: 1.1817 - val_mean_metric: 0.1812 - lr: 0.0010
# Epoch 66/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3524 - a_1: 1.4059 - a_2: 1.3519 - b_1: 1.0369 - b_2: 0.9211 - d_1: 0.8444 - d_2: 0.8710 - n: 1.2621 - mean_metric: 0.2544 - val_loss: 1.6375 - val_a_1: 0.9581 - val_a_2: 0.9577 - val_b_1: 0.9827 - val_b_2: 0.5868 - val_d_1: 0.5500 - val_d_2: 0.5428 - val_n: 1.1620 - val_mean_metric: 0.1880 - lr: 0.0010
# Epoch 67/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3672 - a_1: 1.3985 - a_2: 1.3501 - b_1: 1.0134 - b_2: 0.9694 - d_1: 0.8729 - d_2: 0.8785 - n: 1.2423 - mean_metric: 0.2555 - val_loss: 1.6278 - val_a_1: 1.1238 - val_a_2: 0.9079 - val_b_1: 0.6783 - val_b_2: 0.6360 - val_d_1: 0.7500 - val_d_2: 0.5109 - val_n: 1.1697 - val_mean_metric: 0.1892 - lr: 0.0010
# Epoch 68/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3601 - a_1: 1.3843 - a_2: 1.3569 - b_1: 1.0409 - b_2: 0.9383 - d_1: 0.8629 - d_2: 0.8736 - n: 1.2487 - mean_metric: 0.2548 - val_loss: 1.5392 - val_a_1: 0.9669 - val_a_2: 0.9171 - val_b_1: 0.6466 - val_b_2: 0.6270 - val_d_1: 0.4906 - val_d_2: 0.6156 - val_n: 1.1680 - val_mean_metric: 0.1779 - lr: 0.0010
# Epoch 69/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3480 - a_1: 1.3948 - a_2: 1.3446 - b_1: 1.0178 - b_2: 0.9490 - d_1: 0.8558 - d_2: 0.8997 - n: 1.2482 - mean_metric: 0.2550 - val_loss: 1.6162 - val_a_1: 1.0213 - val_a_2: 0.9774 - val_b_1: 0.7361 - val_b_2: 0.6079 - val_d_1: 0.6235 - val_d_2: 0.6788 - val_n: 1.1743 - val_mean_metric: 0.1906 - lr: 0.0010
# Epoch 70/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3362 - a_1: 1.3706 - a_2: 1.3391 - b_1: 1.0241 - b_2: 0.9231 - d_1: 0.8595 - d_2: 0.8679 - n: 1.2542 - mean_metric: 0.2526 - val_loss: 1.5801 - val_a_1: 0.9693 - val_a_2: 0.9048 - val_b_1: 0.6292 - val_b_2: 0.5856 - val_d_1: 0.4820 - val_d_2: 0.9023 - val_n: 1.1662 - val_mean_metric: 0.1847 - lr: 0.0010
# Epoch 71/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3394 - a_1: 1.3674 - a_2: 1.3404 - b_1: 1.0368 - b_2: 0.9519 - d_1: 0.8724 - d_2: 0.8749 - n: 1.2488 - mean_metric: 0.2545 - val_loss: 1.4755 - val_a_1: 0.9333 - val_a_2: 0.8889 - val_b_1: 0.6444 - val_b_2: 0.5706 - val_d_1: 0.4651 - val_d_2: 0.5432 - val_n: 1.1634 - val_mean_metric: 0.1705 - lr: 0.0010
# Epoch 72/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3151 - a_1: 1.3683 - a_2: 1.3383 - b_1: 1.0020 - b_2: 0.9389 - d_1: 0.8401 - d_2: 0.8917 - n: 1.2477 - mean_metric: 0.2523 - val_loss: 1.5380 - val_a_1: 0.9599 - val_a_2: 0.8833 - val_b_1: 0.7386 - val_b_2: 0.5547 - val_d_1: 0.5291 - val_d_2: 0.6267 - val_n: 1.1609 - val_mean_metric: 0.1785 - lr: 0.0010
# Epoch 73/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3391 - a_1: 1.3784 - a_2: 1.3474 - b_1: 1.0141 - b_2: 0.9265 - d_1: 0.8812 - d_2: 0.8798 - n: 1.2442 - mean_metric: 0.2537 - val_loss: 1.5283 - val_a_1: 0.9646 - val_a_2: 0.8845 - val_b_1: 0.7186 - val_b_2: 0.6670 - val_d_1: 0.4776 - val_d_2: 0.5531 - val_n: 1.1607 - val_mean_metric: 0.1777 - lr: 0.0010
# Epoch 74/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3283 - a_1: 1.3861 - a_2: 1.3342 - b_1: 1.0324 - b_2: 0.9356 - d_1: 0.8439 - d_2: 0.8974 - n: 1.2505 - mean_metric: 0.2542 - val_loss: 1.5156 - val_a_1: 0.9585 - val_a_2: 0.8758 - val_b_1: 0.6512 - val_b_2: 0.6494 - val_d_1: 0.5641 - val_d_2: 0.5173 - val_n: 1.1578 - val_mean_metric: 0.1759 - lr: 0.0010
# Epoch 75/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3077 - a_1: 1.3658 - a_2: 1.3287 - b_1: 1.0029 - b_2: 0.9317 - d_1: 0.8786 - d_2: 0.8813 - n: 1.2338 - mean_metric: 0.2523 - val_loss: 1.5639 - val_a_1: 1.0851 - val_a_2: 0.9785 - val_b_1: 0.7163 - val_b_2: 0.5722 - val_d_1: 0.5697 - val_d_2: 0.4659 - val_n: 1.1702 - val_mean_metric: 0.1821 - lr: 0.0010
# Epoch 76/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3137 - a_1: 1.3667 - a_2: 1.3157 - b_1: 1.0393 - b_2: 0.9173 - d_1: 0.8728 - d_2: 0.8894 - n: 1.2350 - mean_metric: 0.2525 - val_loss: 1.4906 - val_a_1: 1.0570 - val_a_2: 0.8629 - val_b_1: 0.6706 - val_b_2: 0.5943 - val_d_1: 0.4256 - val_d_2: 0.5335 - val_n: 1.1534 - val_mean_metric: 0.1735 - lr: 0.0010
# Epoch 77/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3497 - a_1: 1.3764 - a_2: 1.3577 - b_1: 1.0473 - b_2: 0.9144 - d_1: 0.8840 - d_2: 0.8918 - n: 1.2449 - mean_metric: 0.2550 - val_loss: 1.4997 - val_a_1: 0.9402 - val_a_2: 0.9229 - val_b_1: 0.7078 - val_b_2: 0.6405 - val_d_1: 0.4890 - val_d_2: 0.5226 - val_n: 1.1537 - val_mean_metric: 0.1760 - lr: 0.0010
# Epoch 78/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3347 - a_1: 1.3611 - a_2: 1.3454 - b_1: 1.0402 - b_2: 0.9260 - d_1: 0.8735 - d_2: 0.8788 - n: 1.2442 - mean_metric: 0.2536 - val_loss: 1.5583 - val_a_1: 0.9796 - val_a_2: 0.9633 - val_b_1: 0.6651 - val_b_2: 0.7015 - val_d_1: 0.5543 - val_d_2: 0.5848 - val_n: 1.1552 - val_mean_metric: 0.1835 - lr: 0.0010
# Epoch 79/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3541 - a_1: 1.3688 - a_2: 1.3193 - b_1: 1.0381 - b_2: 0.9445 - d_1: 0.8946 - d_2: 0.8909 - n: 1.2446 - mean_metric: 0.2547 - val_loss: 1.5002 - val_a_1: 0.9719 - val_a_2: 0.9168 - val_b_1: 0.6645 - val_b_2: 0.5962 - val_d_1: 0.5236 - val_d_2: 0.4964 - val_n: 1.1547 - val_mean_metric: 0.1744 - lr: 0.0010
# Epoch 80/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3403 - a_1: 1.3853 - a_2: 1.3246 - b_1: 1.0235 - b_2: 0.9557 - d_1: 0.8653 - d_2: 0.8969 - n: 1.2426 - mean_metric: 0.2545 - val_loss: 1.5253 - val_a_1: 0.9169 - val_a_2: 0.9375 - val_b_1: 0.6764 - val_b_2: 0.6219 - val_d_1: 0.5981 - val_d_2: 0.5334 - val_n: 1.1509 - val_mean_metric: 0.1780 - lr: 0.0010
# Epoch 81/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3336 - a_1: 1.3854 - a_2: 1.3159 - b_1: 1.0424 - b_2: 0.9292 - d_1: 0.8539 - d_2: 0.9136 - n: 1.2450 - mean_metric: 0.2542 - val_loss: 1.5968 - val_a_1: 0.9553 - val_a_2: 0.9794 - val_b_1: 0.7367 - val_b_2: 0.7426 - val_d_1: 0.6409 - val_d_2: 0.5818 - val_n: 1.1568 - val_mean_metric: 0.1897 - lr: 0.0010
# Epoch 82/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3072 - a_1: 1.3915 - a_2: 1.3013 - b_1: 1.0172 - b_2: 0.9334 - d_1: 0.8664 - d_2: 0.8871 - n: 1.2334 - mean_metric: 0.2526 - val_loss: 1.5814 - val_a_1: 0.9224 - val_a_2: 0.9179 - val_b_1: 0.6905 - val_b_2: 0.6096 - val_d_1: 0.8778 - val_d_2: 0.5563 - val_n: 1.1489 - val_mean_metric: 0.1874 - lr: 0.0010
# Epoch 83/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3045 - a_1: 1.3551 - a_2: 1.3230 - b_1: 1.0156 - b_2: 0.9114 - d_1: 0.8726 - d_2: 0.9082 - n: 1.2328 - mean_metric: 0.2519 - val_loss: 1.4531 - val_a_1: 0.9362 - val_a_2: 0.8493 - val_b_1: 0.6669 - val_b_2: 0.6005 - val_d_1: 0.4053 - val_d_2: 0.5219 - val_n: 1.1507 - val_mean_metric: 0.1681 - lr: 0.0010
# Epoch 84/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3335 - a_1: 1.3833 - a_2: 1.3142 - b_1: 1.0291 - b_2: 0.9266 - d_1: 0.8776 - d_2: 0.9056 - n: 1.2410 - mean_metric: 0.2539 - val_loss: 1.4726 - val_a_1: 0.9653 - val_a_2: 0.8812 - val_b_1: 0.6685 - val_b_2: 0.5348 - val_d_1: 0.4568 - val_d_2: 0.5969 - val_n: 1.1468 - val_mean_metric: 0.1720 - lr: 0.0010
# Epoch 85/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2933 - a_1: 1.3668 - a_2: 1.3110 - b_1: 1.0216 - b_2: 0.9195 - d_1: 0.8730 - d_2: 0.8783 - n: 1.2330 - mean_metric: 0.2515 - val_loss: 1.5046 - val_a_1: 0.9115 - val_a_2: 0.9617 - val_b_1: 0.6266 - val_b_2: 0.7041 - val_d_1: 0.5210 - val_d_2: 0.4436 - val_n: 1.1531 - val_mean_metric: 0.1743 - lr: 0.0010
# Epoch 86/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3021 - a_1: 1.3803 - a_2: 1.3183 - b_1: 1.0105 - b_2: 0.9095 - d_1: 0.8689 - d_2: 0.8908 - n: 1.2353 - mean_metric: 0.2520 - val_loss: 1.5299 - val_a_1: 0.9744 - val_a_2: 0.8636 - val_b_1: 0.6389 - val_b_2: 0.5431 - val_d_1: 0.7473 - val_d_2: 0.5806 - val_n: 1.1409 - val_mean_metric: 0.1797 - lr: 0.0010
# Epoch 87/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3251 - a_1: 1.3805 - a_2: 1.3201 - b_1: 1.0269 - b_2: 0.9384 - d_1: 0.8673 - d_2: 0.8852 - n: 1.2399 - mean_metric: 0.2534 - val_loss: 1.5728 - val_a_1: 0.9367 - val_a_2: 1.0190 - val_b_1: 0.7377 - val_b_2: 0.6242 - val_d_1: 0.6311 - val_d_2: 0.6419 - val_n: 1.1485 - val_mean_metric: 0.1878 - lr: 0.0010
# Epoch 88/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2958 - a_1: 1.3596 - a_2: 1.3010 - b_1: 1.0270 - b_2: 0.9373 - d_1: 0.8697 - d_2: 0.8737 - n: 1.2423 - mean_metric: 0.2518 - val_loss: 1.5446 - val_a_1: 0.9507 - val_a_2: 0.8873 - val_b_1: 0.7894 - val_b_2: 0.7113 - val_d_1: 0.5310 - val_d_2: 0.5431 - val_n: 1.1442 - val_mean_metric: 0.1820 - lr: 0.0010
# Epoch 89/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3316 - a_1: 1.3682 - a_2: 1.3168 - b_1: 1.0285 - b_2: 0.9523 - d_1: 0.8808 - d_2: 0.8932 - n: 1.2366 - mean_metric: 0.2539 - val_loss: 1.5399 - val_a_1: 0.9902 - val_a_2: 0.9342 - val_b_1: 0.6479 - val_b_2: 0.5813 - val_d_1: 0.7213 - val_d_2: 0.4784 - val_n: 1.1485 - val_mean_metric: 0.1802 - lr: 0.0010
# Epoch 90/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3408 - a_1: 1.3933 - a_2: 1.3004 - b_1: 1.0409 - b_2: 0.9479 - d_1: 0.8724 - d_2: 0.8625 - n: 1.2378 - mean_metric: 0.2533 - val_loss: 1.5914 - val_a_1: 1.1123 - val_a_2: 0.8672 - val_b_1: 0.6980 - val_b_2: 0.6961 - val_d_1: 0.7101 - val_d_2: 0.4680 - val_n: 1.1500 - val_mean_metric: 0.1868 - lr: 0.0010
# Epoch 91/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3060 - a_1: 1.3702 - a_2: 1.3193 - b_1: 1.0276 - b_2: 0.9185 - d_1: 0.8784 - d_2: 0.8765 - n: 1.2278 - mean_metric: 0.2519 - val_loss: 1.5178 - val_a_1: 0.9517 - val_a_2: 0.8636 - val_b_1: 0.6164 - val_b_2: 0.6975 - val_d_1: 0.6612 - val_d_2: 0.5739 - val_n: 1.1449 - val_mean_metric: 0.1805 - lr: 0.0010
# Epoch 92/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2892 - a_1: 1.3585 - a_2: 1.2981 - b_1: 1.0086 - b_2: 0.9344 - d_1: 0.9019 - d_2: 0.8648 - n: 1.2336 - mean_metric: 0.2513 - val_loss: 1.5602 - val_a_1: 0.9868 - val_a_2: 0.8471 - val_b_1: 0.6674 - val_b_2: 0.5186 - val_d_1: 0.9274 - val_d_2: 0.5535 - val_n: 1.1381 - val_mean_metric: 0.1848 - lr: 0.0010
# Epoch 93/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2883 - a_1: 1.3703 - a_2: 1.3003 - b_1: 0.9995 - b_2: 0.9190 - d_1: 0.8681 - d_2: 0.8882 - n: 1.2402 - mean_metric: 0.2507 - val_loss: 1.4824 - val_a_1: 0.9525 - val_a_2: 0.8265 - val_b_1: 0.6271 - val_b_2: 0.6790 - val_d_1: 0.6764 - val_d_2: 0.4781 - val_n: 1.1416 - val_mean_metric: 0.1762 - lr: 0.0010
# Epoch 94/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2904 - a_1: 1.3536 - a_2: 1.3146 - b_1: 0.9923 - b_2: 0.9196 - d_1: 0.8671 - d_2: 0.9185 - n: 1.2333 - mean_metric: 0.2512 - val_loss: 1.4469 - val_a_1: 0.9269 - val_a_2: 0.8860 - val_b_1: 0.6139 - val_b_2: 0.6005 - val_d_1: 0.4543 - val_d_2: 0.5298 - val_n: 1.1441 - val_mean_metric: 0.1689 - lr: 0.0010
# Epoch 95/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2988 - a_1: 1.3822 - a_2: 1.3101 - b_1: 1.0102 - b_2: 0.9410 - d_1: 0.8549 - d_2: 0.8540 - n: 1.2365 - mean_metric: 0.2511 - val_loss: 1.5535 - val_a_1: 0.9827 - val_a_2: 0.9266 - val_b_1: 0.7602 - val_b_2: 0.7239 - val_d_1: 0.4602 - val_d_2: 0.5177 - val_n: 1.1512 - val_mean_metric: 0.1809 - lr: 0.0010
# Epoch 96/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3016 - a_1: 1.3718 - a_2: 1.3314 - b_1: 1.0135 - b_2: 0.9097 - d_1: 0.8465 - d_2: 0.9049 - n: 1.2352 - mean_metric: 0.2518 - val_loss: 1.5091 - val_a_1: 1.0712 - val_a_2: 0.8650 - val_b_1: 0.6704 - val_b_2: 0.5735 - val_d_1: 0.3955 - val_d_2: 0.6524 - val_n: 1.1481 - val_mean_metric: 0.1761 - lr: 0.0010
# Epoch 97/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3005 - a_1: 1.3801 - a_2: 1.3103 - b_1: 1.0200 - b_2: 0.9157 - d_1: 0.8639 - d_2: 0.8805 - n: 1.2365 - mean_metric: 0.2517 - val_loss: 1.5199 - val_a_1: 0.9478 - val_a_2: 0.9449 - val_b_1: 0.6620 - val_b_2: 0.5546 - val_d_1: 0.5895 - val_d_2: 0.6092 - val_n: 1.1507 - val_mean_metric: 0.1787 - lr: 0.0010
# Epoch 98/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2990 - a_1: 1.3704 - a_2: 1.2941 - b_1: 1.0291 - b_2: 0.9419 - d_1: 0.8583 - d_2: 0.8826 - n: 1.2348 - mean_metric: 0.2515 - val_loss: 1.5411 - val_a_1: 1.0820 - val_a_2: 0.9405 - val_b_1: 0.7617 - val_b_2: 0.6022 - val_d_1: 0.5343 - val_d_2: 0.5297 - val_n: 1.1479 - val_mean_metric: 0.1833 - lr: 0.0010
# Epoch 99/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2455 - a_1: 1.3573 - a_2: 1.2780 - b_1: 0.9943 - b_2: 0.9191 - d_1: 0.8672 - d_2: 0.8576 - n: 1.2342 - mean_metric: 0.2482 - val_loss: 1.4679 - val_a_1: 0.9276 - val_a_2: 0.8975 - val_b_1: 0.7336 - val_b_2: 0.6024 - val_d_1: 0.4568 - val_d_2: 0.5387 - val_n: 1.1472 - val_mean_metric: 0.1736 - lr: 0.0010
# Epoch 100/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2778 - a_1: 1.3691 - a_2: 1.3138 - b_1: 1.0104 - b_2: 0.9132 - d_1: 0.8711 - d_2: 0.8634 - n: 1.2336 - mean_metric: 0.2505 - val_loss: 1.4945 - val_a_1: 0.9096 - val_a_2: 0.8630 - val_b_1: 0.6213 - val_b_2: 0.6754 - val_d_1: 0.5367 - val_d_2: 0.6853 - val_n: 1.1457 - val_mean_metric: 0.1781 - lr: 0.0010
# Epoch 101/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3133 - a_1: 1.3727 - a_2: 1.3051 - b_1: 1.0256 - b_2: 0.9243 - d_1: 0.8620 - d_2: 0.8922 - n: 1.2326 - mean_metric: 0.2519 - val_loss: 1.5204 - val_a_1: 0.9415 - val_a_2: 1.0326 - val_b_1: 0.6295 - val_b_2: 0.5515 - val_d_1: 0.6040 - val_d_2: 0.5597 - val_n: 1.1450 - val_mean_metric: 0.1789 - lr: 0.0010
# Epoch 102/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2757 - a_1: 1.3590 - a_2: 1.2964 - b_1: 1.0258 - b_2: 0.9008 - d_1: 0.8795 - d_2: 0.8827 - n: 1.2280 - mean_metric: 0.2506 - val_loss: 1.6133 - val_a_1: 1.0290 - val_a_2: 0.9697 - val_b_1: 0.6342 - val_b_2: 0.8154 - val_d_1: 0.6422 - val_d_2: 0.6927 - val_n: 1.1388 - val_mean_metric: 0.1941 - lr: 0.0010
# Epoch 103/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3026 - a_1: 1.3494 - a_2: 1.2981 - b_1: 1.0169 - b_2: 0.9253 - d_1: 0.8835 - d_2: 0.9053 - n: 1.2347 - mean_metric: 0.2517 - val_loss: 1.4716 - val_a_1: 1.0183 - val_a_2: 0.8992 - val_b_1: 0.6331 - val_b_2: 0.5442 - val_d_1: 0.6087 - val_d_2: 0.5124 - val_n: 1.1383 - val_mean_metric: 0.1754 - lr: 0.0010
# Epoch 104/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2876 - a_1: 1.3674 - a_2: 1.3105 - b_1: 1.0272 - b_2: 0.9209 - d_1: 0.8696 - d_2: 0.8712 - n: 1.2254 - mean_metric: 0.2510 - val_loss: 1.6483 - val_a_1: 0.9612 - val_a_2: 1.0324 - val_b_1: 0.6547 - val_b_2: 0.6419 - val_d_1: 0.9885 - val_d_2: 0.5334 - val_n: 1.1450 - val_mean_metric: 0.1951 - lr: 0.0010
# Epoch 105/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2895 - a_1: 1.3720 - a_2: 1.3052 - b_1: 1.0010 - b_2: 0.9177 - d_1: 0.8698 - d_2: 0.8901 - n: 1.2268 - mean_metric: 0.2509 - val_loss: 1.4259 - val_a_1: 0.9273 - val_a_2: 0.8821 - val_b_1: 0.6092 - val_b_2: 0.5403 - val_d_1: 0.5498 - val_d_2: 0.5302 - val_n: 1.1382 - val_mean_metric: 0.1696 - lr: 0.0010
# Epoch 106/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2510 - a_1: 1.3558 - a_2: 1.2902 - b_1: 1.0022 - b_2: 0.9343 - d_1: 0.8435 - d_2: 0.8822 - n: 1.2276 - mean_metric: 0.2493 - val_loss: 1.4983 - val_a_1: 0.9358 - val_a_2: 0.8309 - val_b_1: 0.6254 - val_b_2: 0.5556 - val_d_1: 0.9060 - val_d_2: 0.5134 - val_n: 1.1356 - val_mean_metric: 0.1802 - lr: 0.0010
# Epoch 107/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2614 - a_1: 1.3644 - a_2: 1.3019 - b_1: 1.0062 - b_2: 0.9182 - d_1: 0.8543 - d_2: 0.8651 - n: 1.2259 - mean_metric: 0.2493 - val_loss: 1.5571 - val_a_1: 1.0715 - val_a_2: 1.1473 - val_b_1: 0.6285 - val_b_2: 0.5544 - val_d_1: 0.6786 - val_d_2: 0.4632 - val_n: 1.1354 - val_mean_metric: 0.1860 - lr: 0.0010
# Epoch 108/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2786 - a_1: 1.3518 - a_2: 1.2986 - b_1: 1.0212 - b_2: 0.9163 - d_1: 0.8679 - d_2: 0.8838 - n: 1.2283 - mean_metric: 0.2504 - val_loss: 1.4912 - val_a_1: 0.9582 - val_a_2: 0.8830 - val_b_1: 0.6641 - val_b_2: 0.6219 - val_d_1: 0.5276 - val_d_2: 0.6462 - val_n: 1.1428 - val_mean_metric: 0.1783 - lr: 0.0010
# Epoch 109/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2866 - a_1: 1.3756 - a_2: 1.2786 - b_1: 1.0179 - b_2: 0.9448 - d_1: 0.8490 - d_2: 0.8972 - n: 1.2241 - mean_metric: 0.2510 - val_loss: 1.4185 - val_a_1: 0.8924 - val_a_2: 0.8445 - val_b_1: 0.6249 - val_b_2: 0.5881 - val_d_1: 0.5822 - val_d_2: 0.4512 - val_n: 1.1398 - val_mean_metric: 0.1678 - lr: 0.0010
# Epoch 110/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2987 - a_1: 1.3892 - a_2: 1.2957 - b_1: 1.0531 - b_2: 0.9230 - d_1: 0.8477 - d_2: 0.8699 - n: 1.2344 - mean_metric: 0.2520 - val_loss: 1.5084 - val_a_1: 0.9801 - val_a_2: 0.8914 - val_b_1: 0.6879 - val_b_2: 0.5858 - val_d_1: 0.6846 - val_d_2: 0.4526 - val_n: 1.1372 - val_mean_metric: 0.1775 - lr: 0.0010
# Epoch 111/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3437 - a_1: 1.4067 - a_2: 1.3252 - b_1: 1.0132 - b_2: 0.9307 - d_1: 0.8725 - d_2: 0.8840 - n: 1.2261 - mean_metric: 0.2533 - val_loss: 1.4385 - val_a_1: 0.9015 - val_a_2: 0.8868 - val_b_1: 0.6862 - val_b_2: 0.5908 - val_d_1: 0.5015 - val_d_2: 0.4436 - val_n: 1.1318 - val_mean_metric: 0.1684 - lr: 0.0010
# Epoch 112/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2886 - a_1: 1.3699 - a_2: 1.2850 - b_1: 1.0226 - b_2: 0.9221 - d_1: 0.8674 - d_2: 0.8681 - n: 1.2356 - mean_metric: 0.2503 - val_loss: 1.4502 - val_a_1: 0.9270 - val_a_2: 0.8816 - val_b_1: 0.6466 - val_b_2: 0.5739 - val_d_1: 0.5178 - val_d_2: 0.5002 - val_n: 1.1437 - val_mean_metric: 0.1700 - lr: 0.0010
# Epoch 113/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2682 - a_1: 1.3636 - a_2: 1.3042 - b_1: 1.0124 - b_2: 0.9192 - d_1: 0.8596 - d_2: 0.8662 - n: 1.2346 - mean_metric: 0.2499 - val_loss: 1.5364 - val_a_1: 0.9416 - val_a_2: 0.8809 - val_b_1: 0.6695 - val_b_2: 0.7697 - val_d_1: 0.6666 - val_d_2: 0.4899 - val_n: 1.1428 - val_mean_metric: 0.1823 - lr: 0.0010
# Epoch 114/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2598 - a_1: 1.3704 - a_2: 1.2911 - b_1: 1.0340 - b_2: 0.9163 - d_1: 0.8446 - d_2: 0.8607 - n: 1.2199 - mean_metric: 0.2492 - val_loss: 1.4767 - val_a_1: 0.9569 - val_a_2: 0.9807 - val_b_1: 0.6771 - val_b_2: 0.5520 - val_d_1: 0.4759 - val_d_2: 0.5390 - val_n: 1.1425 - val_mean_metric: 0.1744 - lr: 0.0010
# Epoch 115/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2865 - a_1: 1.3732 - a_2: 1.3032 - b_1: 1.0261 - b_2: 0.9224 - d_1: 0.8831 - d_2: 0.8759 - n: 1.2192 - mean_metric: 0.2514 - val_loss: 1.4832 - val_a_1: 0.9311 - val_a_2: 0.8550 - val_b_1: 0.6765 - val_b_2: 0.5591 - val_d_1: 0.6555 - val_d_2: 0.5101 - val_n: 1.1442 - val_mean_metric: 0.1746 - lr: 0.0010
# Epoch 116/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3011 - a_1: 1.3749 - a_2: 1.3026 - b_1: 1.0087 - b_2: 0.9215 - d_1: 0.8600 - d_2: 0.8932 - n: 1.2239 - mean_metric: 0.2509 - val_loss: 1.5109 - val_a_1: 1.0387 - val_a_2: 0.8735 - val_b_1: 0.7610 - val_b_2: 0.6407 - val_d_1: 0.5431 - val_d_2: 0.4876 - val_n: 1.1356 - val_mean_metric: 0.1794 - lr: 0.0010
# Epoch 117/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2969 - a_1: 1.3691 - a_2: 1.3165 - b_1: 1.0347 - b_2: 0.9176 - d_1: 0.8573 - d_2: 0.8715 - n: 1.2330 - mean_metric: 0.2512 - val_loss: 1.4587 - val_a_1: 0.9847 - val_a_2: 0.9279 - val_b_1: 0.6974 - val_b_2: 0.5771 - val_d_1: 0.5521 - val_d_2: 0.5182 - val_n: 1.1344 - val_mean_metric: 0.1766 - lr: 0.0010
# Epoch 118/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.3001 - a_1: 1.3769 - a_2: 1.3095 - b_1: 1.0395 - b_2: 0.9344 - d_1: 0.8576 - d_2: 0.8998 - n: 1.2275 - mean_metric: 0.2530 - val_loss: 1.5363 - val_a_1: 0.9557 - val_a_2: 0.8374 - val_b_1: 0.6851 - val_b_2: 0.5659 - val_d_1: 0.5838 - val_d_2: 0.8414 - val_n: 1.1341 - val_mean_metric: 0.1835 - lr: 0.0010
# Epoch 119/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2776 - a_1: 1.3702 - a_2: 1.3057 - b_1: 1.0119 - b_2: 0.9105 - d_1: 0.8607 - d_2: 0.8780 - n: 1.2303 - mean_metric: 0.2502 - val_loss: 1.4806 - val_a_1: 0.9806 - val_a_2: 0.9662 - val_b_1: 0.7336 - val_b_2: 0.5665 - val_d_1: 0.4911 - val_d_2: 0.5290 - val_n: 1.1281 - val_mean_metric: 0.1766 - lr: 0.0010
# Epoch 120/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2810 - a_1: 1.3611 - a_2: 1.2844 - b_1: 1.0228 - b_2: 0.9275 - d_1: 0.8790 - d_2: 0.8778 - n: 1.2254 - mean_metric: 0.2505 - val_loss: 1.5301 - val_a_1: 1.1740 - val_a_2: 0.9135 - val_b_1: 0.6763 - val_b_2: 0.5955 - val_d_1: 0.5250 - val_d_2: 0.5854 - val_n: 1.1458 - val_mean_metric: 0.1839 - lr: 0.0010
# Epoch 121/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2965 - a_1: 1.3962 - a_2: 1.2977 - b_1: 1.0245 - b_2: 0.9458 - d_1: 0.8570 - d_2: 0.8847 - n: 1.2329 - mean_metric: 0.2527 - val_loss: 1.5079 - val_a_1: 0.9908 - val_a_2: 0.8602 - val_b_1: 0.6276 - val_b_2: 0.6065 - val_d_1: 0.7740 - val_d_2: 0.5736 - val_n: 1.1389 - val_mean_metric: 0.1826 - lr: 0.0010
# Epoch 122/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2618 - a_1: 1.3505 - a_2: 1.2923 - b_1: 1.0180 - b_2: 0.9222 - d_1: 0.8681 - d_2: 0.8896 - n: 1.2352 - mean_metric: 0.2506 - val_loss: 1.4782 - val_a_1: 0.9797 - val_a_2: 0.9521 - val_b_1: 0.6279 - val_b_2: 0.6421 - val_d_1: 0.4705 - val_d_2: 0.5234 - val_n: 1.1376 - val_mean_metric: 0.1747 - lr: 0.0010
# Epoch 123/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2748 - a_1: 1.3786 - a_2: 1.2983 - b_1: 1.0172 - b_2: 0.9053 - d_1: 0.8572 - d_2: 0.8739 - n: 1.2250 - mean_metric: 0.2500 - val_loss: 1.5139 - val_a_1: 0.9713 - val_a_2: 0.9402 - val_b_1: 0.6670 - val_b_2: 0.5774 - val_d_1: 0.6216 - val_d_2: 0.5521 - val_n: 1.1410 - val_mean_metric: 0.1792 - lr: 0.0010
# Epoch 124/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 2.2990 - a_1: 1.3704 - a_2: 1.3068 - b_1: 1.0235 - b_2: 0.9402 - d_1: 0.8541 - d_2: 0.8695 - n: 1.2357 - mean_metric: 0.2515 - val_loss: 1.6156 - val_a_1: 1.0182 - val_a_2: 0.9024 - val_b_1: 0.6542 - val_b_2: 0.6438 - val_d_1: 0.9158 - val_d_2: 0.5883 - val_n: 1.1494 - val_mean_metric: 0.1923 - lr: 0.0010
# Epoch 125/1000
# ...
# Epoch 960/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9312 - a_1: 1.2651 - a_2: 1.1571 - b_1: 0.9480 - b_2: 0.8252 - d_1: 0.8046 - d_2: 0.8164 - n: 1.1774 - mean_metric: 0.2312 - val_loss: 1.1788 - val_a_1: 0.8061 - val_a_2: 0.7381 - val_b_1: 0.5638 - val_b_2: 0.4770 - val_d_1: 0.3838 - val_d_2: 0.3675 - val_n: 1.0998 - val_mean_metric: 0.1453 - lr: 7.7650e-05
# Epoch 961/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9137 - a_1: 1.2474 - a_2: 1.1449 - b_1: 0.9382 - b_2: 0.8255 - d_1: 0.7864 - d_2: 0.8221 - n: 1.1745 - mean_metric: 0.2295 - val_loss: 1.1947 - val_a_1: 0.8243 - val_a_2: 0.7381 - val_b_1: 0.5823 - val_b_2: 0.4803 - val_d_1: 0.3918 - val_d_2: 0.3843 - val_n: 1.1015 - val_mean_metric: 0.1476 - lr: 7.6000e-05
# Epoch 962/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9109 - a_1: 1.2580 - a_2: 1.1465 - b_1: 0.9410 - b_2: 0.8418 - d_1: 0.7882 - d_2: 0.8101 - n: 1.1714 - mean_metric: 0.2300 - val_loss: 1.1803 - val_a_1: 0.8375 - val_a_2: 0.7465 - val_b_1: 0.5765 - val_b_2: 0.4757 - val_d_1: 0.3547 - val_d_2: 0.3731 - val_n: 1.1002 - val_mean_metric: 0.1463 - lr: 7.4350e-05
# Epoch 963/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9023 - a_1: 1.2469 - a_2: 1.1437 - b_1: 0.9528 - b_2: 0.8362 - d_1: 0.7948 - d_2: 0.7960 - n: 1.1742 - mean_metric: 0.2297 - val_loss: 1.1728 - val_a_1: 0.8059 - val_a_2: 0.7389 - val_b_1: 0.5615 - val_b_2: 0.4762 - val_d_1: 0.3650 - val_d_2: 0.3873 - val_n: 1.0994 - val_mean_metric: 0.1453 - lr: 7.2700e-05
# Epoch 964/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9543 - a_1: 1.2727 - a_2: 1.1507 - b_1: 0.9676 - b_2: 0.8618 - d_1: 0.7842 - d_2: 0.8407 - n: 1.1819 - mean_metric: 0.2334 - val_loss: 1.1755 - val_a_1: 0.8100 - val_a_2: 0.7410 - val_b_1: 0.5643 - val_b_2: 0.4818 - val_d_1: 0.3509 - val_d_2: 0.3848 - val_n: 1.1001 - val_mean_metric: 0.1453 - lr: 7.1050e-05
# Epoch 965/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9178 - a_1: 1.2376 - a_2: 1.1550 - b_1: 0.9576 - b_2: 0.8404 - d_1: 0.8088 - d_2: 0.8193 - n: 1.1740 - mean_metric: 0.2311 - val_loss: 1.1788 - val_a_1: 0.8594 - val_a_2: 0.7310 - val_b_1: 0.5685 - val_b_2: 0.4722 - val_d_1: 0.3566 - val_d_2: 0.3814 - val_n: 1.1000 - val_mean_metric: 0.1464 - lr: 6.9400e-05
# Epoch 966/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9317 - a_1: 1.2574 - a_2: 1.1461 - b_1: 0.9623 - b_2: 0.8485 - d_1: 0.7958 - d_2: 0.8083 - n: 1.1859 - mean_metric: 0.2316 - val_loss: 1.1773 - val_a_1: 0.8305 - val_a_2: 0.7465 - val_b_1: 0.5714 - val_b_2: 0.4672 - val_d_1: 0.3542 - val_d_2: 0.4100 - val_n: 1.0993 - val_mean_metric: 0.1468 - lr: 6.7750e-05
# Epoch 967/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9068 - a_1: 1.2489 - a_2: 1.1524 - b_1: 0.9548 - b_2: 0.8169 - d_1: 0.7739 - d_2: 0.8160 - n: 1.1728 - mean_metric: 0.2293 - val_loss: 1.1729 - val_a_1: 0.8205 - val_a_2: 0.7421 - val_b_1: 0.5570 - val_b_2: 0.4736 - val_d_1: 0.3518 - val_d_2: 0.3779 - val_n: 1.1001 - val_mean_metric: 0.1449 - lr: 6.6100e-05
# Epoch 968/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9110 - a_1: 1.2510 - a_2: 1.1424 - b_1: 0.9461 - b_2: 0.8480 - d_1: 0.7926 - d_2: 0.7904 - n: 1.1801 - mean_metric: 0.2300 - val_loss: 1.1802 - val_a_1: 0.8354 - val_a_2: 0.7348 - val_b_1: 0.5760 - val_b_2: 0.4771 - val_d_1: 0.3631 - val_d_2: 0.3954 - val_n: 1.1014 - val_mean_metric: 0.1469 - lr: 6.4450e-05
# Epoch 969/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9258 - a_1: 1.2546 - a_2: 1.1502 - b_1: 0.9670 - b_2: 0.8491 - d_1: 0.8139 - d_2: 0.8067 - n: 1.1753 - mean_metric: 0.2321 - val_loss: 1.1784 - val_a_1: 0.8174 - val_a_2: 0.7559 - val_b_1: 0.5996 - val_b_2: 0.4645 - val_d_1: 0.3419 - val_d_2: 0.3881 - val_n: 1.0999 - val_mean_metric: 0.1464 - lr: 6.2800e-05
# Epoch 970/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9279 - a_1: 1.2501 - a_2: 1.1560 - b_1: 0.9618 - b_2: 0.8405 - d_1: 0.7853 - d_2: 0.8334 - n: 1.1789 - mean_metric: 0.2318 - val_loss: 1.1728 - val_a_1: 0.8282 - val_a_2: 0.7706 - val_b_1: 0.5555 - val_b_2: 0.4779 - val_d_1: 0.3529 - val_d_2: 0.3691 - val_n: 1.1005 - val_mean_metric: 0.1460 - lr: 6.1150e-05
# Epoch 971/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.8927 - a_1: 1.2393 - a_2: 1.1555 - b_1: 0.9411 - b_2: 0.8152 - d_1: 0.7825 - d_2: 0.7990 - n: 1.1714 - mean_metric: 0.2283 - val_loss: 1.1837 - val_a_1: 0.8594 - val_a_2: 0.7388 - val_b_1: 0.5619 - val_b_2: 0.4732 - val_d_1: 0.3539 - val_d_2: 0.3897 - val_n: 1.0998 - val_mean_metric: 0.1467 - lr: 5.9500e-05
# Epoch 972/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9083 - a_1: 1.2417 - a_2: 1.1599 - b_1: 0.9516 - b_2: 0.8360 - d_1: 0.7734 - d_2: 0.8152 - n: 1.1756 - mean_metric: 0.2298 - val_loss: 1.1787 - val_a_1: 0.8038 - val_a_2: 0.7395 - val_b_1: 0.5610 - val_b_2: 0.4768 - val_d_1: 0.3622 - val_d_2: 0.3961 - val_n: 1.1006 - val_mean_metric: 0.1455 - lr: 5.7850e-05
# Epoch 973/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9152 - a_1: 1.2225 - a_2: 1.1439 - b_1: 0.9901 - b_2: 0.8493 - d_1: 0.7732 - d_2: 0.8104 - n: 1.1722 - mean_metric: 0.2301 - val_loss: 1.1749 - val_a_1: 0.8087 - val_a_2: 0.7276 - val_b_1: 0.5666 - val_b_2: 0.4776 - val_d_1: 0.3746 - val_d_2: 0.3830 - val_n: 1.1011 - val_mean_metric: 0.1454 - lr: 5.6200e-05
# Epoch 974/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9310 - a_1: 1.2525 - a_2: 1.1506 - b_1: 0.9481 - b_2: 0.8408 - d_1: 0.7907 - d_2: 0.8378 - n: 1.1783 - mean_metric: 0.2314 - val_loss: 1.1738 - val_a_1: 0.8114 - val_a_2: 0.7324 - val_b_1: 0.5721 - val_b_2: 0.4954 - val_d_1: 0.3498 - val_d_2: 0.3785 - val_n: 1.1012 - val_mean_metric: 0.1455 - lr: 5.4550e-05
# Epoch 975/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9193 - a_1: 1.2393 - a_2: 1.1598 - b_1: 0.9725 - b_2: 0.8315 - d_1: 0.7956 - d_2: 0.8057 - n: 1.1732 - mean_metric: 0.2308 - val_loss: 1.1721 - val_a_1: 0.8340 - val_a_2: 0.7449 - val_b_1: 0.5765 - val_b_2: 0.4601 - val_d_1: 0.3639 - val_d_2: 0.3568 - val_n: 1.0995 - val_mean_metric: 0.1453 - lr: 5.2900e-05
# Epoch 976/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.8939 - a_1: 1.2310 - a_2: 1.1406 - b_1: 0.9579 - b_2: 0.8295 - d_1: 0.7939 - d_2: 0.8112 - n: 1.1707 - mean_metric: 0.2294 - val_loss: 1.1735 - val_a_1: 0.8168 - val_a_2: 0.7318 - val_b_1: 0.5628 - val_b_2: 0.4701 - val_d_1: 0.3890 - val_d_2: 0.3880 - val_n: 1.0992 - val_mean_metric: 0.1461 - lr: 5.1250e-05
# Epoch 977/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9070 - a_1: 1.2404 - a_2: 1.1317 - b_1: 0.9625 - b_2: 0.8336 - d_1: 0.7981 - d_2: 0.8234 - n: 1.1768 - mean_metric: 0.2303 - val_loss: 1.1728 - val_a_1: 0.8027 - val_a_2: 0.7615 - val_b_1: 0.5687 - val_b_2: 0.4686 - val_d_1: 0.3575 - val_d_2: 0.3840 - val_n: 1.1000 - val_mean_metric: 0.1456 - lr: 4.9600e-05
# Epoch 978/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9053 - a_1: 1.2426 - a_2: 1.1478 - b_1: 0.9584 - b_2: 0.8375 - d_1: 0.7645 - d_2: 0.8117 - n: 1.1722 - mean_metric: 0.2293 - val_loss: 1.1784 - val_a_1: 0.8294 - val_a_2: 0.7328 - val_b_1: 0.5710 - val_b_2: 0.4714 - val_d_1: 0.3817 - val_d_2: 0.3655 - val_n: 1.0997 - val_mean_metric: 0.1458 - lr: 4.7950e-05
# Epoch 979/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9299 - a_1: 1.2622 - a_2: 1.1346 - b_1: 0.9699 - b_2: 0.8504 - d_1: 0.7992 - d_2: 0.8199 - n: 1.1659 - mean_metric: 0.2315 - val_loss: 1.1734 - val_a_1: 0.8336 - val_a_2: 0.7264 - val_b_1: 0.5610 - val_b_2: 0.4840 - val_d_1: 0.3700 - val_d_2: 0.3756 - val_n: 1.0995 - val_mean_metric: 0.1458 - lr: 4.6300e-05
# Epoch 980/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9312 - a_1: 1.2371 - a_2: 1.1582 - b_1: 0.9628 - b_2: 0.8420 - d_1: 0.8137 - d_2: 0.8199 - n: 1.1743 - mean_metric: 0.2317 - val_loss: 1.1808 - val_a_1: 0.8149 - val_a_2: 0.7445 - val_b_1: 0.5743 - val_b_2: 0.5128 - val_d_1: 0.3472 - val_d_2: 0.3815 - val_n: 1.0976 - val_mean_metric: 0.1465 - lr: 4.4650e-05
# Epoch 981/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9340 - a_1: 1.2488 - a_2: 1.1462 - b_1: 0.9645 - b_2: 0.8445 - d_1: 0.8067 - d_2: 0.8356 - n: 1.1730 - mean_metric: 0.2322 - val_loss: 1.1687 - val_a_1: 0.8170 - val_a_2: 0.7343 - val_b_1: 0.5715 - val_b_2: 0.4686 - val_d_1: 0.3485 - val_d_2: 0.3783 - val_n: 1.0993 - val_mean_metric: 0.1447 - lr: 4.3000e-05
# Epoch 982/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9013 - a_1: 1.2383 - a_2: 1.1586 - b_1: 0.9683 - b_2: 0.8310 - d_1: 0.7626 - d_2: 0.8259 - n: 1.1707 - mean_metric: 0.2300 - val_loss: 1.1736 - val_a_1: 0.8480 - val_a_2: 0.7378 - val_b_1: 0.5597 - val_b_2: 0.4675 - val_d_1: 0.3649 - val_d_2: 0.3694 - val_n: 1.0996 - val_mean_metric: 0.1457 - lr: 4.1350e-05
# Epoch 983/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.8930 - a_1: 1.2338 - a_2: 1.1440 - b_1: 0.9431 - b_2: 0.8349 - d_1: 0.7672 - d_2: 0.8194 - n: 1.1741 - mean_metric: 0.2287 - val_loss: 1.1726 - val_a_1: 0.8321 - val_a_2: 0.7531 - val_b_1: 0.5586 - val_b_2: 0.4641 - val_d_1: 0.3694 - val_d_2: 0.3827 - val_n: 1.0994 - val_mean_metric: 0.1461 - lr: 3.9700e-05
# Epoch 984/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.8990 - a_1: 1.2533 - a_2: 1.1435 - b_1: 0.9418 - b_2: 0.8433 - d_1: 0.7819 - d_2: 0.8112 - n: 1.1735 - mean_metric: 0.2298 - val_loss: 1.1686 - val_a_1: 0.8188 - val_a_2: 0.7308 - val_b_1: 0.5628 - val_b_2: 0.4671 - val_d_1: 0.3517 - val_d_2: 0.3739 - val_n: 1.1006 - val_mean_metric: 0.1443 - lr: 3.8050e-05
# Epoch 985/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9386 - a_1: 1.2639 - a_2: 1.1661 - b_1: 0.9691 - b_2: 0.8312 - d_1: 0.7984 - d_2: 0.8170 - n: 1.1764 - mean_metric: 0.2322 - val_loss: 1.1752 - val_a_1: 0.8387 - val_a_2: 0.7557 - val_b_1: 0.5747 - val_b_2: 0.4665 - val_d_1: 0.3564 - val_d_2: 0.3851 - val_n: 1.1016 - val_mean_metric: 0.1467 - lr: 3.6400e-05
# Epoch 986/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9189 - a_1: 1.2452 - a_2: 1.1302 - b_1: 0.9691 - b_2: 0.8533 - d_1: 0.7957 - d_2: 0.8214 - n: 1.1743 - mean_metric: 0.2312 - val_loss: 1.1716 - val_a_1: 0.8088 - val_a_2: 0.7367 - val_b_1: 0.5680 - val_b_2: 0.4658 - val_d_1: 0.3636 - val_d_2: 0.3752 - val_n: 1.0993 - val_mean_metric: 0.1447 - lr: 3.4750e-05
# Epoch 987/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9186 - a_1: 1.2467 - a_2: 1.1550 - b_1: 0.9605 - b_2: 0.8280 - d_1: 0.7900 - d_2: 0.8098 - n: 1.1768 - mean_metric: 0.2304 - val_loss: 1.1697 - val_a_1: 0.8145 - val_a_2: 0.7590 - val_b_1: 0.5547 - val_b_2: 0.4728 - val_d_1: 0.3474 - val_d_2: 0.3950 - val_n: 1.0998 - val_mean_metric: 0.1456 - lr: 3.3100e-05
# Epoch 988/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9373 - a_1: 1.2505 - a_2: 1.1485 - b_1: 0.9830 - b_2: 0.8421 - d_1: 0.8007 - d_2: 0.8183 - n: 1.1788 - mean_metric: 0.2323 - val_loss: 1.1696 - val_a_1: 0.8056 - val_a_2: 0.7462 - val_b_1: 0.5801 - val_b_2: 0.4621 - val_d_1: 0.3524 - val_d_2: 0.3867 - val_n: 1.0998 - val_mean_metric: 0.1452 - lr: 3.1450e-05
# Epoch 989/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9096 - a_1: 1.2449 - a_2: 1.1323 - b_1: 0.9563 - b_2: 0.8427 - d_1: 0.8146 - d_2: 0.8165 - n: 1.1721 - mean_metric: 0.2309 - val_loss: 1.1713 - val_a_1: 0.8386 - val_a_2: 0.7296 - val_b_1: 0.5729 - val_b_2: 0.4621 - val_d_1: 0.3605 - val_d_2: 0.3654 - val_n: 1.0993 - val_mean_metric: 0.1451 - lr: 2.9800e-05
# Epoch 990/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9316 - a_1: 1.2503 - a_2: 1.1273 - b_1: 0.9560 - b_2: 0.8446 - d_1: 0.8009 - d_2: 0.8545 - n: 1.1735 - mean_metric: 0.2318 - val_loss: 1.1683 - val_a_1: 0.8135 - val_a_2: 0.7433 - val_b_1: 0.5549 - val_b_2: 0.4660 - val_d_1: 0.3582 - val_d_2: 0.3652 - val_n: 1.0986 - val_mean_metric: 0.1441 - lr: 2.8150e-05
# Epoch 991/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9220 - a_1: 1.2585 - a_2: 1.1600 - b_1: 0.9398 - b_2: 0.8541 - d_1: 0.8025 - d_2: 0.8180 - n: 1.1671 - mean_metric: 0.2314 - val_loss: 1.1682 - val_a_1: 0.8281 - val_a_2: 0.7368 - val_b_1: 0.5575 - val_b_2: 0.4612 - val_d_1: 0.3508 - val_d_2: 0.3898 - val_n: 1.0995 - val_mean_metric: 0.1449 - lr: 2.6500e-05
# Epoch 992/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9031 - a_1: 1.2557 - a_2: 1.1436 - b_1: 0.9288 - b_2: 0.8359 - d_1: 0.8040 - d_2: 0.8256 - n: 1.1750 - mean_metric: 0.2306 - val_loss: 1.1700 - val_a_1: 0.8152 - val_a_2: 0.7348 - val_b_1: 0.5669 - val_b_2: 0.4695 - val_d_1: 0.3669 - val_d_2: 0.3848 - val_n: 1.0995 - val_mean_metric: 0.1454 - lr: 2.4850e-05
# Epoch 993/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9114 - a_1: 1.2481 - a_2: 1.1382 - b_1: 0.9506 - b_2: 0.8336 - d_1: 0.7904 - d_2: 0.8144 - n: 1.1751 - mean_metric: 0.2299 - val_loss: 1.1720 - val_a_1: 0.8401 - val_a_2: 0.7290 - val_b_1: 0.5633 - val_b_2: 0.4624 - val_d_1: 0.3648 - val_d_2: 0.3864 - val_n: 1.0988 - val_mean_metric: 0.1456 - lr: 2.3200e-05
# Epoch 994/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.8912 - a_1: 1.2432 - a_2: 1.1395 - b_1: 0.9555 - b_2: 0.8297 - d_1: 0.7967 - d_2: 0.7901 - n: 1.1702 - mean_metric: 0.2289 - val_loss: 1.1664 - val_a_1: 0.8096 - val_a_2: 0.7418 - val_b_1: 0.5745 - val_b_2: 0.4620 - val_d_1: 0.3574 - val_d_2: 0.3791 - val_n: 1.0994 - val_mean_metric: 0.1449 - lr: 2.1550e-05
# Epoch 995/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9253 - a_1: 1.2559 - a_2: 1.1508 - b_1: 0.9501 - b_2: 0.8554 - d_1: 0.7721 - d_2: 0.8354 - n: 1.1751 - mean_metric: 0.2314 - val_loss: 1.1695 - val_a_1: 0.8170 - val_a_2: 0.7645 - val_b_1: 0.5500 - val_b_2: 0.4637 - val_d_1: 0.3542 - val_d_2: 0.4002 - val_n: 1.0976 - val_mean_metric: 0.1457 - lr: 1.9900e-05
# Epoch 996/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.8920 - a_1: 1.2328 - a_2: 1.1496 - b_1: 0.9554 - b_2: 0.8330 - d_1: 0.7884 - d_2: 0.8089 - n: 1.1719 - mean_metric: 0.2295 - val_loss: 1.1675 - val_a_1: 0.8128 - val_a_2: 0.7475 - val_b_1: 0.5623 - val_b_2: 0.4639 - val_d_1: 0.3485 - val_d_2: 0.3847 - val_n: 1.0990 - val_mean_metric: 0.1448 - lr: 1.8250e-05
# Epoch 997/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9243 - a_1: 1.2423 - a_2: 1.1620 - b_1: 0.9542 - b_2: 0.8336 - d_1: 0.7910 - d_2: 0.8281 - n: 1.1815 - mean_metric: 0.2312 - val_loss: 1.1670 - val_a_1: 0.8209 - val_a_2: 0.7472 - val_b_1: 0.5573 - val_b_2: 0.4581 - val_d_1: 0.3548 - val_d_2: 0.3867 - val_n: 1.0988 - val_mean_metric: 0.1450 - lr: 1.6600e-05
# Epoch 998/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9044 - a_1: 1.2517 - a_2: 1.1412 - b_1: 0.9415 - b_2: 0.8539 - d_1: 0.7794 - d_2: 0.7964 - n: 1.1802 - mean_metric: 0.2297 - val_loss: 1.1650 - val_a_1: 0.8178 - val_a_2: 0.7375 - val_b_1: 0.5550 - val_b_2: 0.4650 - val_d_1: 0.3531 - val_d_2: 0.3755 - val_n: 1.0994 - val_mean_metric: 0.1443 - lr: 1.4950e-05
# Epoch 999/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.9295 - a_1: 1.2579 - a_2: 1.1599 - b_1: 0.9575 - b_2: 0.8456 - d_1: 0.7769 - d_2: 0.8154 - n: 1.1816 - mean_metric: 0.2311 - val_loss: 1.1683 - val_a_1: 0.8325 - val_a_2: 0.7311 - val_b_1: 0.5659 - val_b_2: 0.4606 - val_d_1: 0.3514 - val_d_2: 0.3784 - val_n: 1.0994 - val_mean_metric: 0.1448 - lr: 1.3300e-05
# Epoch 1000/1000
# 350/350 [==============================] - 1s 2ms/step - loss: 1.8989 - a_1: 1.2346 - a_2: 1.1437 - b_1: 0.9367 - b_2: 0.8208 - d_1: 0.8028 - d_2: 0.8304 - n: 1.1800 - mean_metric: 0.2297 - val_loss: 1.1674 - val_a_1: 0.8158 - val_a_2: 0.7336 - val_b_1: 0.5599 - val_b_2: 0.4679 - val_d_1: 0.3589 - val_d_2: 0.3808 - val_n: 1.0989 - val_mean_metric: 0.1447 - lr: 1.1650e-05

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(val_epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    campvectest, coefcampvectest)
# Out:
# 32/32 [==============================] - 0s 903us/step - loss: 1.1854 - a_1: 0.8023 - a_2: 0.7479 - b_1: 0.5647 - b_2: 0.4691 - d_1: 0.3685 - d_2: 0.3815 - n: 1.1533 - mean_metric: 0.1471

# %%
predictions = model.predict(campvectest)
# Out:
# 32/32 [==============================] - 0s 677us/step

# %%
print(coefcampvectest[0,:])
print(predictions[0,:])
from sklearn.metrics import mean_absolute_error
print(np.sum(coefcampvectest, axis=-1))

mae1 = mean_absolute_error(coefcampvectest[0,:], predictions[0,:])
mae1
# Out:
# [ 7  2 10  1 10  0  1]
# [7.7473125  1.8148634  9.199808   0.85574836 9.288832   0.7990366
#  2.916911  ]
# [31 32 28 49 25 38 26 42 31 27 24 18 37 33 38 30 24 36 37 38 36 33 20 37
#  24 35 39 26 22 26 39 26 38 42 17 23 26 25 36 24 42 34 42 29 38 28 41 30
#  34 35 42 16 26 28 40 28 32 40 28 35 28 38 34 32 42 39 38 29 33 38 34 30
#  32 39 32 27 31 38 22 36 29 30 35 32 43 32 29 30 41 22 23 47 31 26 34 19
#  29 42 30 22 33 38 25 29 36 41 34 40 32 35 40 39 31 38 21 37 43 40 30 41
#  31 29 40 31 34 36 54 26 39 29 50 26 47 33 44 11 47 27 33 18 32 43 36 34
#  30 34 38 46 24 32 21 48 41 44 42 40 35 29 34 31 33 28 37 30 29 38 35 33
#  32 25 38 35 25 27 21 28 38 40 23 38 34 22 42 37 33 20 40 22 35 34 24 33
#  37 31 35 31 28 23 36 34 40 25 30 31 34 39 26 26 37 36 45 34 28 30 39 37
#  37 35 33 45 31 35 37 31 38 27 35 29 23 51 20 25 31 24 37 43 27 25 27 37
#  26 36 36 39 34 23 24 44 31 30 43 41 31 32 40 28 40 32 36 24 47 44 20 28
#  29 35 27 30 27 37 53 43 47 46 21 20 20 31 39 28 38 26 36 41 27 30 50 33
#  34 37 27 35 23 37 39 32 23 28 44 33 27 31 27 41 26 21 35 39 25 34 24 17
#  30 22 27 14 19 28 24 34 35 32 28 35 40 38 29 42 32 23 40 25 17 19 39 25
#  23 31 44 38 36 34 19 37 42 29 23 32 38 37 27 46 20 38 34 21 40 30 26 34
#  31 30 37 28 42 30 47 29 31 29 21 27 14 37 33 38 31 32 44 36 30 32 22 26
#  27 25 26 31 34 26 29 36 36 27 28 20 42 36 20 32 29 44 41 32 38 34 36 24
#  39 36 42 27 22 40 36 32 36 17 37 47 33 48 44 29 19 36 30 45 25 30 38 53
#  51 31 27 46 32 33 28 31 36 30 36 31 33 34 55 37 36 23 31 38 39 29 36 20
#  24 44 43 48 20 36 37 25 20 32 35 37 42 32 32 19 27 38 28 29 41 30 34 29
#  28 42 31 30 30 33 42 21 41 39 17 38 24 45 42 38 31 33 33 41 41 36 25 43
#  11 32 33 38 41 27 31 23 31 30 49 42 26 41 48 33 17 25 30 40 32 25 33 35
#  35 30 19 44 30 17 28 33 42 27 38 36 22 43 24 22 35 38 27 26 22 28 32 30
#  48 37 26 22 29 25 34 39 36 24 29 38 26 34 33 40 39 31 38 33 31 29 34 39
#  32 31 35 26 37 28 37 26 41 55 34 21 34 37 13 28 32 40 43 38 43 26 40 34
#  41 28 27 48 26 34 36 32 42 29 41 19 34 39 41 30 43 29 28 20 32 33 36 31
#  23 36 30 16 39 21 28 45 18 42 37 46 34 31 30 32 27 31 50 27 27 23 32 27
#  30 25 35 28 29 31 17 23 39 26 37 21 38 28 35 36 29 27 24 48 31 26 21 28
#  43 40 33 33 30 30 16 41 26 42 34 45 28 34 31 46 34 33 51 42 29 31 40 36
#  34 39 29 25 25 41 35 27 33 25 29 33 29 25 35 47 16 36 28 41 37 34 13 43
#  19 35 39 34 24 45 26 39 28 35 24 34 31 28 18 29 31 35 29 32 25 24 31 29
#  30 31 41 50 23 19 42 18 27 29 32 32 31 37 34 33 44 48 32 37 31 30 30 26
#  42 34 30 40 28 19 27 36 34 22 30 43 38 34 29 35 40 24 40 16 24 38 34 44
#  34 34 40 39 31 34 29 35 26 50 24 32 35 26 20 32 31 32 38 29 26 33 45 23
#  31 24 39 43 30 32 21 44 30 32 28 52 30 29 30 29 42 29 47 17 29 30 46 35
#  29 47 25 27 38 33 35 37 35 36 19 34 21 42 32 37 10 38 18 38 31 41 31 44
#  29 26 24 47 42 47 37 28 41 20 41 29 38 28 30 35 26 22 28 36 16 44 31 40
#  28 30 24 37 27 40 32 40 25 27 41 28 23 55 20 18 35 31 44 40 47 36 31 40
#  44 24 16 50 22 25 21 40 37 36 37 30 36 35 36 29 18 29 26 25 30 36 27 34
#  24 29 23 24 26 53 46 34 23 42 25 34 35 45 42 29 32 18 27 23 24 27 36 27
#  41 27 30 31 33 32 31 20 38 54 28 32 39 43 31 33 44 40 48 39 26 33 19 23
#  33 15 21 26 27 23 36 40 26 49 46 31 34 40 30 44]
# 0.7577154891831535

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefcampvectest, predictions)

# Calcula la desviación estándar del error
error = coefcampvectest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 0.6399012011076722, Desviación estándar del error: 1.01007957614984, Error absoluto máximo: 6.775707006454468

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefcampvectest - predictions)

# Calcula el error para cada dato
error = coefcampvectest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefcampvectest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.15089793724351552
# Desviación estándar del error relativo: 0.0642506988326365
# Error absoluto máximo relativo: 0.32236347198486326

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales/History 20,50/historycampvec20.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos/Modelos 20,50/'

# %%
model.save(path_to_save + '/campovectorial20.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_activation':custom_activation, 'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)

new_model = keras.models.load_model('../../../Modelos/Modelos 20,50/campovectorial20.h5', custom_objects= custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b2

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 20)
    y2 = np.linspace(y_range_neg, y_range_pos, 20)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)
    contador = contador+1
    print(contador)
    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [8, 9, 10, 1, 4, 9, 2]
# 1

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# [[9. 9. 9. 1. 4. 9. 2.]]

# %% [markdown]
# ## Encontramos puntos de equilibrio datos reales

# %%
from scipy.optimize import fsolve
# Sistema de ecuaciones
def system(Y):
    X, Y = Y
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b2
    return [dX_dt, dY_dt]

# Adivinanza inicial para X, Y
initial_guess = [0, 0]

# Encontrar los puntos de equilibrio
primer_cuadrante_reales = fsolve(system, initial_guess)
primer_cuadrante_reales = tuple(primer_cuadrante_reales)


print(primer_cuadrante_reales)
# Out:
# (4.4505816565232506, 0.15917029600185498)

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
import matplotlib.pyplot as plt

x_values = primer_cuadrante_reales[0]
y_values =primer_cuadrante_reales[1]

y1 = np.linspace(0, 10, 20)
y2 = np.linspace(0, 10, 20)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.scatter(x_values, y_values, color='red')  # Puedes cambiar el color como prefieras
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
plt.show()

# %% [markdown]
# ## Encontramos puntos de equilibro datos predecidos

# %%
a1pred = new_predictions[0,0]
a2pred = new_predictions[0,1]
b1pred = new_predictions[0,2]
b2pred = new_predictions[0,3]
d1pred = new_predictions[0,4]
d2pred = new_predictions[0,5]
npred = new_predictions[0,6]

def systempred(Ypred):
    Xpred, Ypred = Ypred
    dXpred_dt = a1pred/(1+Ypred**npred)-d1pred*Xpred+b1pred
    dYpred_dt = a2pred/(1+Xpred**npred)-d2pred*Ypred+b2pred
    return [dXpred_dt, dYpred_dt]

# Adivinanza inicial para X, Y
initial_guesspred = [0, 0]

# Encontrar los puntos de equilibrio
primer_cuadrante_predecidos = fsolve(systempred, initial_guesspred)
primer_cuadrante_predecidos = tuple(primer_cuadrante_predecidos)


print(primer_cuadrante_predecidos)
# Out:
# (4.444316400830921, 0.15929935767788453)

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
import matplotlib.pyplot as plt

def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1pred/(1+Y**npred)-d1pred*X+b1pred
    dY_dt = a2pred/(1+X**npred)-d2pred*Y+b2pred

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1pred = np.linspace(x_range_neg, x_range_pos, 20)
y2pred = np.linspace(y_range_neg, y_range_pos, 20)

Y1pred, Y2pred = np.meshgrid(y1pred, y2pred)
    
t1 = 0

upred, vpred = np.zeros(Y1pred.shape), np.zeros(Y2pred.shape)

NI, NJ = Y1.shape

u1pred, v1pred = f(t1, [Y1, Y2])
upred, vpred = f(t1, [Y1, Y2])
Mpred = (np.hypot(upred, vpred))
upred /= Mpred
vpred /= Mpred


x_valuespred = primer_cuadrante_predecidos[0]
y_valuespred =primer_cuadrante_predecidos[1]
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, upred, vpred, Mpred, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.scatter(x_valuespred, y_valuespred, color='red')  # Puedes cambiar el color como prefieras
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %% [markdown]
# ## Graficamos ambos

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Primero graficamos la predicción, que debería ser más clara (alpha < 1)
Q = ax.quiver(Y1, Y2, upred, vpred, Mpred, angles='xy', alpha=0.5)

# Luego, graficamos los datos originales, que serán más oscuros (alpha = 1)
Q1 = ax.quiver(Y1, Y2, u, v, M, angles='xy', alpha=1)

ax.scatter(x_valuespred, y_valuespred, color='red', alpha = 0.5)
ax.scatter(x_values, y_values, color='red', alpha = 1)
ax.set_title('Comparación prediccionees con datos reales', fontsize=20)
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('Concentración X')
ax.set_ylabel('Concentración Y')

plt.show()

# %% [markdown]
# ## Graficamos las diferencias

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Calculamos las diferencias
u_diff = u - upred
v_diff = v - vpred

# Ahora calculamos la magnitud
#M_diff = np.hypot(u_diff2, v_diff2)
M_diff = np.hypot(u_diff, v_diff)

#Calcula la magnitud de los vectores
magnitudes = np.sqrt(u_diff**2 + v_diff**2)

# Calcula el rango de las magnitudes
rango = (np.max(magnitudes) - np.min(magnitudes))*30
print(rango)
# Escala para las flechas. Aumenta este valor si las flechas son demasiado grandes.

# Graficamos las diferencias
#Q = ax.quiver(Y1, Y2, u_diff2, v_diff2, M_diff, angles='xy')
Q = ax.quiver(Y1, Y2, u_diff, v_diff, M_diff, angles='xy', scale = rango)
#Q = ax.quiver(Y1, Y2, u_diff, v_diff, M_diff, angles='xy')


ax.set_title('Diferencias entre campos vectoriales', fontsize=20)
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('Concentración X')
ax.set_ylabel('Concentración Y')

# Creamos una leyenda para la magnitud de las flechas
cbar = plt.colorbar(Q, ax=ax)
cbar.set_label('Magnitud de la diferencia')

plt.show()
# Out:
# 2.0310726036721896

# %% [markdown]
# ## Errores relativos

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Calculamos las diferencias
u_diff = u - upred
v_diff = v - vpred

# Aseguramos que ningún vector tenga una magnitud exactamente igual a cero
epsilon = 1e-7

# Calculamos la magnitud del vector original y de la diferencia
M_orig = np.hypot(u1, v1) + epsilon
M_diff = np.hypot(u1pred, v1pred)

# Calculamos la diferencia relativa
M_diff_rel = M_diff / M_orig

#Calcula la magnitud de los vectores
magnitudes = np.sqrt(u_diff**2 + v_diff**2)

# Calcula el rango de las magnitudes
rango = (np.max(magnitudes) - np.min(magnitudes))*30

# Graficamos las diferencias relativas
Q = ax.quiver(Y1, Y2, u_diff, v_diff, M_diff_rel, angles='xy', scale = rango)

ax.set_title('Diferencias relativas entre campos vectoriales', fontsize=20)
ax.set_xlim([0, 10])
ax.set_ylim([0, 10])
ax.set_xlabel('Concentración X')
ax.set_ylabel('Concentración Y')

# Creamos una leyenda para la magnitud de las flechas
cbar = plt.colorbar(Q, ax=ax)
cbar.set_label('Magnitud de la diferencia relativa')

plt.show()

# %%
max_index_flattened = M_diff_rel.argmax()
max_coords = np.unravel_index(max_index_flattened, M_diff_rel.shape)
M_orig[max_coords]
print('El valor máximo de error relativo es de:', M_diff_rel.max() )
print('El valor de u1 en el error relativo máximo es:',u1[max_coords])
print('El valor de u1pred en el error relativo máximo es:',u1pred[max_coords])
print('El valor de v1 en el error relativo máximo es:',v1[max_coords])
print('El valor de v1pred en el error relativo máximo es:',v1pred[max_coords])
# Out:
# El valor máximo de error relativo es de: 1.0326134791146624
# El valor de u1 en el error relativo máximo es: -7.257625008645132
# El valor de u1pred en el error relativo máximo es: -7.783249187357352
# El valor de v1 en el error relativo máximo es: -8.160104440233873
# El valor de v1pred en el error relativo máximo es: -8.160104440233873

# %%
# Calculamos las diferencias
u_diff = u - upred
v_diff = v - vpred

# Aseguramos que ningún vector tenga una magnitud exactamente igual a cero
epsilon = 1e-7

# Calculamos la magnitud del vector original y de la diferencia
M_orig = np.hypot(u, v) + epsilon
M_diff = np.hypot(u_diff, v_diff)

# Calculamos la diferencia relativa
M_diff_rel = M_diff / M_orig

# Aplicamos el filtro para la diferencia relativa mayor a 0.05
mask = M_diff_rel > 0.05

# Calculamos el porcentaje de puntos que cumplen con la condición
porcentaje = np.mean(mask) * 100

print(f"El porcentaje de puntos cuyo error relativo es mayor a 0.05 es {porcentaje:.2f}%")
# Out:
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 es 2.75%

# %% [markdown]
# ## Simulamos 10,000 veces

# %%
import numpy as np
import random
from scipy.optimize import fsolve

# Listas para almacenar los resultados
porcentajes = []

# Repetimos el proceso 10 veces
for repetir in range(10000):
    campvec = []
    coef = []
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b2

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 20)
    y2 = np.linspace(y_range_neg, y_range_pos, 20)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
#    print(coef1)
    
    campvec = np.array(campvec)

    
    campvecnone = campvec[None, :]
    campvecnone = np.transpose(campvecnone, (0,2,3,1))
    
    new_predictions = new_model.predict(campvecnone)
    new_predictions = np.round(new_predictions)
    new_predictions = np.clip(new_predictions, 0, None)
#    print(new_predictions)
    
    
    a1pred = new_predictions[0,0]
    a2pred = new_predictions[0,1]
    b1pred = new_predictions[0,2]
    b2pred = new_predictions[0,3]
    d1pred = new_predictions[0,4]
    d2pred = new_predictions[0,5]
    npred = new_predictions[0,6]
    
    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        dX_dt = a1pred/(1+Y**npred)-d1pred*X+b1pred
        dY_dt = a2pred/(1+X**npred)-d2pred*Y+b2pred

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1pred = np.linspace(x_range_neg, x_range_pos, 20)
    y2pred = np.linspace(y_range_neg, y_range_pos, 20)

    Y1pred, Y2pred = np.meshgrid(y1pred, y2pred)
    
    t1 = 0

    upred, vpred = np.zeros(Y1pred.shape), np.zeros(Y2pred.shape)

    NI, NJ = Y1.shape

    u1pred, v1pred = f(t1, [Y1, Y2])
    upred, vpred = f(t1, [Y1, Y2])
    Mpred = (np.hypot(upred, vpred))
    upred /= Mpred
    vpred /= Mpred

 # Calculamos las diferencias
    u_diff = u - upred
    v_diff = v - vpred

    # Aseguramos que ningún vector tenga una magnitud exactamente igual a cero
    epsilon = 1e-7

    # Calculamos la magnitud del vector original y de la diferencia
    M_orig = np.hypot(u, v) + epsilon
    M_diff = np.hypot(u_diff, v_diff)

    # Calculamos la diferencia relativa
    M_diff_rel = M_diff / M_orig

    # Aplicamos el filtro para la diferencia relativa mayor a 0.05
    mask = M_diff_rel > 0.05

    # Calculamos el porcentaje de puntos que cumplen con la condición
    porcentaje = np.mean(mask) * 100

    # Almacenamos el resultado en la lista
    porcentajes.append(porcentaje)

    print(f"El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración {repetir+1} es {porcentaje:.2f}%")

# Muestra todos los porcentajes al final
print("Porcentajes para las 10 iteraciones:", porcentajes)

# Calcula y muestra el promedio de los porcentajes
promedio = np.mean(porcentajes)
print(f"El promedio de los porcentajes es {promedio:.2f}%")
# Out:
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 1 es 97.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 2 es 96.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 3 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 4 es 96.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 5 es 81.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 6 es 98.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 7 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 8 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 9 es 97.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 10 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 11 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 12 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 13 es 98.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 14 es 50.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 15 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 16 es 77.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 17 es 91.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 18 es 91.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 19 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 20 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 21 es 96.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 22 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 23 es 64.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 24 es 98.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 25 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 26 es 98.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 27 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 28 es 91.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 29 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 30 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 31 es 86.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 32 es 92.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 33 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 13ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 34 es 96.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 35 es 89.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 36 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 13ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 37 es 96.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 38 es 95.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 39 es 93.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 40 es 94.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 41 es 98.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 42 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 43 es 82.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 44 es 98.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 45 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 46 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 47 es 36.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 48 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 49 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 50 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 51 es 47.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 52 es 97.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 53 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 54 es 75.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 55 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 56 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 57 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 58 es 96.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 59 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 60 es 22.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 61 es 93.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 62 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 63 es 98.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 64 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 65 es 96.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 66 es 92.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 67 es 87.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 68 es 86.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 69 es 98.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 13ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 70 es 83.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 71 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 72 es 98.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 73 es 91.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 74 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 75 es 54.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 76 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 77 es 91.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 78 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 79 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 80 es 98.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 81 es 17.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 82 es 89.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 83 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 84 es 97.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 85 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 86 es 83.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 87 es 95.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 88 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 89 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 90 es 77.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 91 es 91.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 92 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 93 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 94 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 95 es 97.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 96 es 89.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 97 es 95.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 98 es 97.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 99 es 97.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 100 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 101 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 102 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 103 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 104 es 93.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 105 es 81.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 106 es 83.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 107 es 91.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 108 es 92.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 109 es 95.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 110 es 86.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 111 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 112 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 113 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 114 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 115 es 91.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 116 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 117 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 118 es 98.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 119 es 85.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 120 es 75.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 121 es 92.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 122 es 73.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 123 es 94.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 124 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 125 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 126 es 88.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 127 es 95.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 128 es 91.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 129 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 130 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 131 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 132 es 43.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 133 es 93.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 134 es 93.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 135 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 136 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 137 es 92.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 138 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 139 es 76.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 140 es 56.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 141 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 142 es 97.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 143 es 91.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 144 es 98.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 145 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 146 es 98.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 147 es 86.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 148 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 149 es 96.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 150 es 92.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 151 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 152 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 153 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 154 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 155 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 156 es 97.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 157 es 96.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 158 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 159 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 160 es 95.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 161 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 162 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 163 es 90.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 164 es 92.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 165 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 166 es 98.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 167 es 94.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 168 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 169 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 170 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 171 es 83.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 172 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 173 es 68.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 174 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 175 es 98.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 176 es 50.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 177 es 90.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 178 es 96.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 179 es 91.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 180 es 96.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 181 es 97.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 182 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 183 es 96.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 184 es 88.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 185 es 97.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 186 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 187 es 94.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 188 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 189 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 190 es 95.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 191 es 80.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 192 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 193 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 194 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 195 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 196 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 197 es 92.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 198 es 71.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 199 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 200 es 92.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 201 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 202 es 95.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 203 es 97.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 204 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 205 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 206 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 207 es 97.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 208 es 95.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 209 es 97.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 210 es 80.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 211 es 93.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 212 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 213 es 95.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 214 es 92.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 215 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 216 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 217 es 92.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 218 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 219 es 91.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 220 es 98.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 221 es 98.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 222 es 98.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 223 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 224 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 225 es 96.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 226 es 94.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 227 es 98.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 228 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 229 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 230 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 231 es 94.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 232 es 86.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 233 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 234 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 235 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 236 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 237 es 94.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 238 es 98.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 239 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 240 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 241 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 242 es 94.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 243 es 95.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 244 es 86.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 245 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 246 es 97.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 247 es 97.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 248 es 88.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 249 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 250 es 96.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 251 es 87.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 252 es 98.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 253 es 94.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 254 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 255 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 256 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 257 es 95.00%
# ...
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 946 es 90.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 947 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 948 es 82.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 949 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 950 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 951 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 952 es 91.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 953 es 95.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 954 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 955 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 956 es 91.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 957 es 92.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 958 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 959 es 61.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 960 es 50.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 961 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 962 es 83.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 963 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 9ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 964 es 99.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 965 es 99.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 966 es 85.50%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 967 es 99.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 968 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 969 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 970 es 93.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 971 es 100.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 11ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 972 es 99.75%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 973 es 95.00%
# --------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 974 es 95.25%
# --------------------------------------------
# 1/1 [==============================] - 0s 10ms/step
# El porcentaje de puntos cuyo error relativo es mayor a 0.05 en la iteración 975 es 85.00%
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 70
#      67 campvecnone = campvec[None, :]
#      68 campvecnone = np.transpose(campvecnone, (0,2,3,1))
# ---> 70 new_predictions = new_model.predict(campvecnone)
#      71 new_predictions = np.round(new_predictions)
#      72 new_predictions = np.clip(new_predictions, 0, None)
#
# File ~\anaconda3\envs\tfcpu\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tfcpu\lib\site-packages\keras\engine\training.py:2220, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2211     except ValueError:
#    2212         warnings.warn(
#    2213             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2214             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2217             stacklevel=2,
#    2218         )
# -> 2220 data_handler = data_adapter.get_data_handler(
#    2221     x=x,
#    2222     batch_size=batch_size,
#    2223     steps_per_epoch=steps,
#    2224     initial_epoch=0,
#    2225     epochs=1,
#    2226     max_queue_size=max_queue_size,
#    2227     workers=workers,
#    2228     use_multiprocessing=use_multiprocessing,
#    2229     model=self,
#    2230     steps_per_execution=self._steps_per_execution,
#    2231 )
#    2233 # Container that configures and calls `tf.keras.Callback`s.
#    2234 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\envs\tfcpu\lib\site-packages\keras\engine\data_adapter.py:1582, in get_data_handler(*args, **kwargs)
#    1580 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1581     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1582 return DataHandler(*args, **kwargs)
#
# File ~\anaconda3\envs\tfcpu\lib\site-packages\keras\engine\data_adapter.py:1262, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1259     self._steps_per_execution = steps_per_execution
#    1261 adapter_cls = select_data_adapter(x, y)
# -> 1262 self._adapter = adapter_cls(
#    1263     x,
#    1264     y,
#    1265     batch_size=batch_size,
#    1266     steps=steps_per_epoch,
#    1267     epochs=epochs - initial_epoch,
#    1268     sample_weights=sample_weight,
#    1269     shuffle=shuffle,
#    1270     max_queue_size=max_queue_size,
#    1271     workers=workers,
#    1272     use_multiprocessing=use_multiprocessing,
#    1273     distribution_strategy=tf.distribute.get_strategy(),
#    1274     model=model,
#    1275 )
#    1277 strategy = tf.distribute.get_strategy()
#    1279 self._current_step = 0
#
# File ~\anaconda3\envs\tfcpu\lib\site-packages\keras\engine\data_adapter.py:347, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     344         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     345     return flat_dataset
# --> 347 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     349 dataset = self.slice_inputs(indices_dataset, inputs)
#     351 if shuffle == "batch":
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:2245, in DatasetV2.flat_map(self, map_func, name)
#    2212 def flat_map(self, map_func, name=None):
#    2213   """Maps `map_func` across this dataset and flattens the result.
#    2214
#    2215   The type signature is:
#    (...)
#    2243     Dataset: A `Dataset`.
#    2244   """
# -> 2245   return FlatMapDataset(self, map_func, name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:5484, in FlatMapDataset.__init__(self, input_dataset, map_func, name)
#    5482 """See `Dataset.flat_map()` for details."""
#    5483 self._input_dataset = input_dataset
# -> 5484 self._map_func = structured_function.StructuredFunctionWrapper(
#    5485     map_func, self._transformation_name(), dataset=input_dataset)
#    5486 if not isinstance(self._map_func.output_structure, DatasetSpec):
#    5487   raise TypeError(
#    5488       "The `map_func` argument must return a `Dataset` object. Got "
#    5489       f"{_get_type(self._map_func.output_structure)!r}.")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:271, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     264       warnings.warn(
#     265           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     266           "option is set, this option does not apply to tf.data functions. "
#     267           "To force eager execution of tf.data functions, please use "
#     268           "`tf.data.experimental.enable_debug_mode()`.")
#     269     fn_factory = trace_tf_function(defun_kwargs)
# --> 271 self._function = fn_factory()
#     272 # There is no graph to add in eager mode.
#     273 add_to_graph &= not context.executing_eagerly()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:2610, in Function.get_concrete_function(self, *args, **kwargs)
#    2601 def get_concrete_function(self, *args, **kwargs):
#    2602   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    2603
#    2604   Args:
#    (...)
#    2608        or `tf.Tensor` or `tf.TensorSpec`.
#    2609   """
# -> 2610   graph_function = self._get_concrete_function_garbage_collected(
#    2611       *args, **kwargs)
#    2612   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    2613   return graph_function
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:2576, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2574   args, kwargs = None, None
#    2575 with self._lock:
# -> 2576   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2577   seen_names = set()
#    2578   captured = object_identity.ObjectIdentitySet(
#    2579       graph_function.graph.internal_captures)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:2760, in Function._maybe_define_function(self, args, kwargs)
#    2758   # Only get placeholders for arguments, not captures
#    2759   args, kwargs = placeholder_dict["args"]
# -> 2760 graph_function = self._create_graph_function(args, kwargs)
#    2762 graph_capture_container = graph_function.graph._capture_func_lib  # pylint: disable=protected-access
#    2763 # Maintain the list of all captures
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:2670, in Function._create_graph_function(self, args, kwargs)
#    2665 missing_arg_names = [
#    2666     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2667 ]
#    2668 arg_names = base_arg_names + missing_arg_names
#    2669 graph_function = ConcreteFunction(
# -> 2670     func_graph_module.func_graph_from_py_func(
#    2671         self._name,
#    2672         self._python_function,
#    2673         args,
#    2674         kwargs,
#    2675         self.input_signature,
#    2676         autograph=self._autograph,
#    2677         autograph_options=self._autograph_options,
#    2678         arg_names=arg_names,
#    2679         capture_by_value=self._capture_by_value),
#    2680     self._function_attributes,
#    2681     spec=self.function_spec,
#    2682     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2683     # scope. This is not the default behavior since it gets used in some
#    2684     # places (like Keras) where the FuncGraph lives longer than the
#    2685     # ConcreteFunction.
#    2686     shared_func_graph=False)
#    2687 return graph_function
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\func_graph.py:1153, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1150 else:
#    1151   deps_control_manager = ops.NullContextmanager()
# -> 1153 with func_graph.as_default(), deps_control_manager as deps_ctx:
#    1154   current_scope = variable_scope.get_variable_scope()
#    1155   default_use_resource = current_scope.use_resource
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\auto_control_deps.py:433, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     426   continue
#     428 # Ensure stateful ops run.
#     429 # Read-only ops are added to control outputs if the read value is
#     430 # consumed. This covers the case when the read value is returned from
#     431 # the function since that goes through a tf.identity in mark_as_return.
#     432 if ((op_def_registry.get(op.type) is None) or
# --> 433     (op_is_stateful(op) and
#     434      (op.type not in utils.RESOURCE_READ_OPS or
#     435       any(output.consumers() for output in op.outputs)))):
#     436   ops_which_must_run.add(op)
#     438 # Make a note of all opened manager_ids.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\auto_control_deps.py:146, in op_is_stateful(op)
#     143 def op_is_stateful(op):
#     144   # pylint: disable=protected-access
#     145   ret = ((op._is_stateful and
# --> 146           ((op.type not in ASYNC_STATEFUL_OPS) and
#     147            (op.type not in LEGACY_RANDOM_OPS) and
#     148            (op.type not in SKIPPED_ORDER_INSENSITIVE_STATEFUL_OPS))) or
#     149          (op.type in _ALLOWLIST_STATELESS_OPS))
#     150   return ret
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:2583, in Operation.type(self)
#    2580 @property
#    2581 def type(self):
#    2582   """The type of the op (e.g. `"MatMul"`)."""
# -> 2583   return pywrap_tf_session.TF_OperationOpType(self._c_op)
#
# KeyboardInterrupt:
