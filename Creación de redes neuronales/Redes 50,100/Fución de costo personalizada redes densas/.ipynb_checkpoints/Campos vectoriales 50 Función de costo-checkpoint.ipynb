# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_39580\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos/Campo 50 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 50, 50)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (1000, 2, 50, 50)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (1000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (2000, 2, 50, 50)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (2000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 50, 50), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 100
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creamos función de costo

# %%
def custom_loss(y_true, y_pred):
    campvec = []
    # constantes
    a1 = tf.cast(y_true[:, 0], tf.float64)
    #tf.print(a1)
    a1 = tf.reshape(a1, shape=(-1, 1, 1))

    a2 = tf.cast(y_true[:, 1], tf.float64)
    a2 = tf.reshape(a2, shape=(-1, 1, 1))
    
    b1 = tf.cast(y_true[:, 2], tf.float64)
    b1 = tf.reshape(b1,shape = (-1,1,1))
    
    b2 = tf.cast(y_true[:, 3], tf.float64)
    b2 = tf.reshape(b2,shape = (-1,1,1))

    d1 = tf.cast(y_true[:, 4], tf.float64)
    d1 = tf.reshape(d1, shape=(-1, 1, 1))

    d2 = tf.cast(y_true[:, 5], tf.float64)
    d2 = tf.reshape(d2, shape=(-1, 1, 1))

    n = tf.cast(y_true[:, 6], tf.float64)
    n = tf.reshape(n, shape=(-1, 1, 1))

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        X = tf.cast(X, tf.float64)
        X = tf.reshape(X, shape=(1, 50,50))
        Y = y[1]
        Y = tf.cast(Y, tf.float64)
        Y = tf.reshape(Y, shape=(1, 50,50))
        
        # definimos cada ODE
        dX_dt = tf.divide(a1,(1 + tf.math.pow(Y, n)+1e-5)) - tf.multiply(d1,X) + b1
        dY_dt = tf.divide(a2,(1 + tf.math.pow(X, n)+1e-7)) - tf.multiply(d2,Y) + b2
        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 20
    y_range_neg = 0
    y_range_pos = 20
    y1 = tf.linspace(x_range_neg, x_range_pos, 50)
    y2 = tf.linspace(y_range_neg, y_range_pos, 50)
    Y1, Y2 = tf.meshgrid(y1, y2)
    t = 0
    u, v = tf.zeros(Y1.shape), tf.zeros(Y2.shape)
    u, v = f(t, [Y1, Y2])
    #M = tf.sqrt(tf.square(u) + tf.square(v))
    #u /= M
    #v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = tf.cast(y_pred[:, 0], tf.float64)
    a12 = tf.reshape(a12, shape=(-1, 1, 1))

    a22 = tf.cast(y_pred[:, 1], tf.float64)
    a22 = tf.reshape(a22, shape=(-1, 1, 1))
    
    b12 = tf.cast(y_pred[:, 2], tf.float64)
    b12 = tf.reshape(b12,shape = (-1,1,1))
    
    b22 = tf.cast(y_pred[:, 3], tf.float64)
    b22 = tf.reshape(b22,shape = (-1,1,1))

    d12 = tf.cast(y_pred[:, 4], tf.float64)
    d12 = tf.reshape(d12, shape=(-1, 1, 1))

    d22 = tf.cast(y_pred[:, 5], tf.float64)
    d22 = tf.reshape(d22, shape=(-1, 1, 1))

    n2 = tf.cast(y_pred[:, 6], tf.float64)
    n2 = tf.reshape(n2, shape=(-1, 1, 1))
    
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        X2 = tf.cast(X2, tf.float64)
        X2 = tf.reshape(X2, shape=(1, 50,50))
        Y2 = ye2[1]
        Y2 = tf.cast(Y2, tf.float64)
        Y2 = tf.reshape(Y2, shape=(1, 50,50))

        # definimos cada ODE
        dX2_dt = tf.divide(a12,(1 + tf.math.pow(Y2, n2)+1e-8)) - tf.multiply(d12,X2) + b12
        dY2_dt = tf.divide(a22,(1 + tf.math.pow(X2, n2)+1e-8)) - tf.multiply(d22,Y2) + b22
        return [dX2_dt, dY2_dt]

    y12 = tf.linspace(x_range_neg, x_range_pos, 50)
    y22 = tf.linspace(y_range_neg, y_range_pos, 50)
    Y12, Y22 = tf.meshgrid(y12, y22)
    u2, v2 = tf.zeros(Y12.shape), tf.zeros(Y22.shape)
    u2, v2 = f2(t, [Y12, Y22])
    #M2 = tf.sqrt(tf.square(u2) + tf.square(v2))
    #u2 /= M2
    #v2 /= M2
    campvecx = tf.abs(tf.subtract(u,u2))
    campvecy = tf.abs(tf.subtract(v,v2))
    campvec_magnitude = tf.add(campvecx,campvecy)
    loss = tf.reduce_mean(campvec_magnitude)
    #tf.print(y_pred)
    return loss

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
model.add(Flatten(input_shape=(2,50,50)))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))

model.add(Dense(7, activation= custom_activation))

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(2,50,50)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation = custom_activation)
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 5000)              0
#
#  batch_normalization_1 (Batc  (None, 5000)             20000
#  hNormalization)
#
#  dense_7 (Dense)             (None, 128)               640128
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_11 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 685,671
# Trainable params: 675,543
# Non-trainable params: 10,128
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
def total_mae_loss(y_true, y_pred):
    total_loss = 0
    num_parameters = 7
    for i in range(num_parameters):
        total_loss += tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])
    tf.print(y_true, summarize = -1)
    tf.print(y_pred, summarize = -1)
    return total_loss / num_parameters

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
model.compile(optimizer=optimizer,
              loss= custom_loss,
              metrics=metrics)

# %%
def scheduler(epoch, lr):
  if epoch < 400:
    return lr
  else:
    return -1.65e-6*epoch +  0.00166

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 1000,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 70/70 [==============================] - 3s 22ms/step - loss: 11.4115 - a_1: 2.4485 - a_2: 2.3981 - b_1: 2.1395 - b_2: 1.8184 - d_1: 0.5766 - d_2: 0.5697 - n: 1.5152 - mean_metric: 0.3792 - val_loss: 17.6133 - val_a_1: 2.6282 - val_a_2: 2.6110 - val_b_1: 2.2617 - val_b_2: 1.5029 - val_d_1: 0.8144 - val_d_2: 0.7868 - val_n: 1.6495 - val_mean_metric: 0.4029 - lr: 0.0010
# Epoch 2/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 9.6631 - a_1: 2.6644 - a_2: 2.5787 - b_1: 2.1051 - b_2: 1.7569 - d_1: 0.4914 - d_2: 0.4789 - n: 1.5553 - mean_metric: 0.3844 - val_loss: 10.6442 - val_a_1: 2.6336 - val_a_2: 2.4228 - val_b_1: 1.6770 - val_b_2: 1.3039 - val_d_1: 0.5341 - val_d_2: 0.4671 - val_n: 1.4829 - val_mean_metric: 0.3459 - lr: 0.0010
# Epoch 3/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 9.7083 - a_1: 2.6800 - a_2: 2.5888 - b_1: 1.9054 - b_2: 1.5496 - d_1: 0.4725 - d_2: 0.4977 - n: 1.5415 - mean_metric: 0.3714 - val_loss: 7.7152 - val_a_1: 2.7331 - val_a_2: 2.4825 - val_b_1: 1.5162 - val_b_2: 1.1437 - val_d_1: 0.4049 - val_d_2: 0.3226 - val_n: 1.4862 - val_mean_metric: 0.3317 - lr: 0.0010
# Epoch 4/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 9.2118 - a_1: 2.6973 - a_2: 2.6297 - b_1: 1.7871 - b_2: 1.5125 - d_1: 0.4539 - d_2: 0.4682 - n: 1.5362 - mean_metric: 0.3664 - val_loss: 6.2429 - val_a_1: 2.7338 - val_a_2: 2.5488 - val_b_1: 1.2572 - val_b_2: 1.2160 - val_d_1: 0.3131 - val_d_2: 0.2730 - val_n: 1.4821 - val_mean_metric: 0.3229 - lr: 0.0010
# Epoch 5/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 9.3023 - a_1: 2.7289 - a_2: 2.6605 - b_1: 1.6287 - b_2: 1.4431 - d_1: 0.4660 - d_2: 0.4612 - n: 1.5612 - mean_metric: 0.3619 - val_loss: 6.1460 - val_a_1: 2.6786 - val_a_2: 2.5353 - val_b_1: 1.3386 - val_b_2: 1.1456 - val_d_1: 0.3250 - val_d_2: 0.2564 - val_n: 1.6154 - val_mean_metric: 0.3252 - lr: 0.0010
# Epoch 6/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.6927 - a_1: 2.6993 - a_2: 2.6759 - b_1: 1.5132 - b_2: 1.4848 - d_1: 0.4214 - d_2: 0.4465 - n: 1.6486 - mean_metric: 0.3599 - val_loss: 5.2998 - val_a_1: 2.6427 - val_a_2: 2.5914 - val_b_1: 1.1169 - val_b_2: 1.1357 - val_d_1: 0.2695 - val_d_2: 0.2503 - val_n: 1.6032 - val_mean_metric: 0.3159 - lr: 0.0010
# Epoch 7/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 8.6602 - a_1: 2.7028 - a_2: 2.6874 - b_1: 1.5019 - b_2: 1.4135 - d_1: 0.4132 - d_2: 0.4503 - n: 1.6968 - mean_metric: 0.3591 - val_loss: 4.9902 - val_a_1: 2.6913 - val_a_2: 2.5611 - val_b_1: 1.0717 - val_b_2: 1.0578 - val_d_1: 0.2714 - val_d_2: 0.2283 - val_n: 1.6577 - val_mean_metric: 0.3135 - lr: 0.0010
# Epoch 8/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 8.2662 - a_1: 2.7209 - a_2: 2.7041 - b_1: 1.4618 - b_2: 1.4387 - d_1: 0.4056 - d_2: 0.4161 - n: 1.7062 - mean_metric: 0.3587 - val_loss: 5.0237 - val_a_1: 2.6904 - val_a_2: 2.5782 - val_b_1: 1.1014 - val_b_2: 1.1379 - val_d_1: 0.2765 - val_d_2: 0.2414 - val_n: 1.7160 - val_mean_metric: 0.3202 - lr: 0.0010
# Epoch 9/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.6791 - a_1: 2.7211 - a_2: 2.7113 - b_1: 1.4410 - b_2: 1.3543 - d_1: 0.4105 - d_2: 0.4498 - n: 1.6897 - mean_metric: 0.3562 - val_loss: 5.0352 - val_a_1: 2.6694 - val_a_2: 2.5976 - val_b_1: 1.1385 - val_b_2: 0.9573 - val_d_1: 0.2751 - val_d_2: 0.2250 - val_n: 1.7177 - val_mean_metric: 0.3149 - lr: 0.0010
# Epoch 10/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.1170 - a_1: 2.7295 - a_2: 2.7174 - b_1: 1.4302 - b_2: 1.4010 - d_1: 0.3924 - d_2: 0.4117 - n: 1.7378 - mean_metric: 0.3577 - val_loss: 4.8708 - val_a_1: 2.7429 - val_a_2: 2.6040 - val_b_1: 1.0926 - val_b_2: 1.0238 - val_d_1: 0.2862 - val_d_2: 0.2110 - val_n: 1.6926 - val_mean_metric: 0.3173 - lr: 0.0010
# Epoch 11/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 8.2364 - a_1: 2.7287 - a_2: 2.7232 - b_1: 1.4091 - b_2: 1.4170 - d_1: 0.4095 - d_2: 0.4073 - n: 1.7147 - mean_metric: 0.3572 - val_loss: 5.3701 - val_a_1: 2.6992 - val_a_2: 2.6180 - val_b_1: 1.1906 - val_b_2: 0.9392 - val_d_1: 0.2752 - val_d_2: 0.2423 - val_n: 1.6468 - val_mean_metric: 0.3159 - lr: 0.0010
# Epoch 12/1000
# 70/70 [==============================] - 1s 17ms/step - loss: 8.2505 - a_1: 2.7526 - a_2: 2.7642 - b_1: 1.4347 - b_2: 1.4090 - d_1: 0.4044 - d_2: 0.4121 - n: 1.6972 - mean_metric: 0.3594 - val_loss: 4.8276 - val_a_1: 2.6800 - val_a_2: 2.6399 - val_b_1: 1.1360 - val_b_2: 0.9973 - val_d_1: 0.2308 - val_d_2: 0.2115 - val_n: 1.6938 - val_mean_metric: 0.3152 - lr: 0.0010
# Epoch 13/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.5836 - a_1: 2.7665 - a_2: 2.7830 - b_1: 1.4929 - b_2: 1.4113 - d_1: 0.4382 - d_2: 0.4141 - n: 1.7301 - mean_metric: 0.3648 - val_loss: 5.0527 - val_a_1: 2.7778 - val_a_2: 2.7038 - val_b_1: 1.1628 - val_b_2: 0.8966 - val_d_1: 0.2972 - val_d_2: 0.1955 - val_n: 1.7080 - val_mean_metric: 0.3202 - lr: 0.0010
# Epoch 14/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.9871 - a_1: 2.8191 - a_2: 2.7962 - b_1: 1.4591 - b_2: 1.4200 - d_1: 0.3884 - d_2: 0.4015 - n: 1.7586 - mean_metric: 0.3650 - val_loss: 5.8883 - val_a_1: 2.8181 - val_a_2: 2.7090 - val_b_1: 1.0473 - val_b_2: 1.0127 - val_d_1: 0.3320 - val_d_2: 0.2494 - val_n: 1.6603 - val_mean_metric: 0.3230 - lr: 0.0010
# Epoch 15/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.7844 - a_1: 2.8038 - a_2: 2.8007 - b_1: 1.4282 - b_2: 1.4085 - d_1: 0.3783 - d_2: 0.3904 - n: 1.7331 - mean_metric: 0.3617 - val_loss: 4.3852 - val_a_1: 2.7441 - val_a_2: 2.6894 - val_b_1: 1.0266 - val_b_2: 0.9759 - val_d_1: 0.2534 - val_d_2: 0.1893 - val_n: 1.6818 - val_mean_metric: 0.3142 - lr: 0.0010
# Epoch 16/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.6354 - a_1: 2.7760 - a_2: 2.7836 - b_1: 1.3898 - b_2: 1.3473 - d_1: 0.3701 - d_2: 0.3838 - n: 1.7114 - mean_metric: 0.3557 - val_loss: 3.9658 - val_a_1: 2.7209 - val_a_2: 2.7269 - val_b_1: 1.1810 - val_b_2: 1.0214 - val_d_1: 0.1976 - val_d_2: 0.1600 - val_n: 1.6267 - val_mean_metric: 0.3167 - lr: 0.0010
# Epoch 17/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.4110 - a_1: 2.7951 - a_2: 2.7932 - b_1: 1.4442 - b_2: 1.3727 - d_1: 0.3561 - d_2: 0.3772 - n: 1.6895 - mean_metric: 0.3579 - val_loss: 4.1504 - val_a_1: 2.7157 - val_a_2: 2.7041 - val_b_1: 1.1357 - val_b_2: 0.9536 - val_d_1: 0.2163 - val_d_2: 0.1711 - val_n: 1.6363 - val_mean_metric: 0.3133 - lr: 0.0010
# Epoch 18/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.0763 - a_1: 2.7923 - a_2: 2.7999 - b_1: 1.3815 - b_2: 1.3665 - d_1: 0.3897 - d_2: 0.4099 - n: 1.6585 - mean_metric: 0.3569 - val_loss: 4.0944 - val_a_1: 2.7337 - val_a_2: 2.7210 - val_b_1: 1.1124 - val_b_2: 0.9134 - val_d_1: 0.2307 - val_d_2: 0.1665 - val_n: 1.5951 - val_mean_metric: 0.3113 - lr: 0.0010
# Epoch 19/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.6779 - a_1: 2.7830 - a_2: 2.8099 - b_1: 1.4004 - b_2: 1.3537 - d_1: 0.3663 - d_2: 0.3890 - n: 1.6528 - mean_metric: 0.3555 - val_loss: 8.2690 - val_a_1: 2.7062 - val_a_2: 2.7364 - val_b_1: 0.9509 - val_b_2: 1.0336 - val_d_1: 0.6790 - val_d_2: 0.1582 - val_n: 1.5646 - val_mean_metric: 0.3230 - lr: 0.0010
# Epoch 20/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.7473 - a_1: 2.8063 - a_2: 2.8150 - b_1: 1.4254 - b_2: 1.3464 - d_1: 0.4131 - d_2: 0.3508 - n: 1.6174 - mean_metric: 0.3561 - val_loss: 6.3796 - val_a_1: 2.7579 - val_a_2: 2.7381 - val_b_1: 1.3548 - val_b_2: 0.9476 - val_d_1: 0.3659 - val_d_2: 0.2149 - val_n: 1.5600 - val_mean_metric: 0.3267 - lr: 0.0010
# Epoch 21/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.2265 - a_1: 2.7981 - a_2: 2.7956 - b_1: 1.4729 - b_2: 1.3794 - d_1: 0.4127 - d_2: 0.3969 - n: 1.6269 - mean_metric: 0.3597 - val_loss: 7.3647 - val_a_1: 2.7926 - val_a_2: 2.7351 - val_b_1: 1.2257 - val_b_2: 1.2165 - val_d_1: 0.4893 - val_d_2: 0.2372 - val_n: 1.5159 - val_mean_metric: 0.3356 - lr: 0.0010
# Epoch 22/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.8187 - a_1: 2.8392 - a_2: 2.8210 - b_1: 1.5275 - b_2: 1.3950 - d_1: 0.4127 - d_2: 0.3573 - n: 1.6638 - mean_metric: 0.3641 - val_loss: 5.1080 - val_a_1: 2.7982 - val_a_2: 2.7224 - val_b_1: 1.1627 - val_b_2: 0.9854 - val_d_1: 0.3041 - val_d_2: 0.1893 - val_n: 1.6179 - val_mean_metric: 0.3214 - lr: 0.0010
# Epoch 23/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.8677 - a_1: 2.8381 - a_2: 2.8253 - b_1: 1.4295 - b_2: 1.3568 - d_1: 0.3981 - d_2: 0.3784 - n: 1.6623 - mean_metric: 0.3599 - val_loss: 6.0875 - val_a_1: 2.7925 - val_a_2: 2.7294 - val_b_1: 1.1373 - val_b_2: 0.9664 - val_d_1: 0.3646 - val_d_2: 0.2068 - val_n: 1.6305 - val_mean_metric: 0.3230 - lr: 0.0010
# Epoch 24/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.3524 - a_1: 2.8509 - a_2: 2.8366 - b_1: 1.4219 - b_2: 1.3149 - d_1: 0.3724 - d_2: 0.3515 - n: 1.6368 - mean_metric: 0.3565 - val_loss: 4.8803 - val_a_1: 2.7963 - val_a_2: 2.7532 - val_b_1: 1.1785 - val_b_2: 0.8980 - val_d_1: 0.3173 - val_d_2: 0.1354 - val_n: 1.5983 - val_mean_metric: 0.3180 - lr: 0.0010
# Epoch 25/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.6061 - a_1: 2.8429 - a_2: 2.8443 - b_1: 1.3953 - b_2: 1.3069 - d_1: 0.3680 - d_2: 0.3787 - n: 1.6164 - mean_metric: 0.3553 - val_loss: 5.1354 - val_a_1: 2.7956 - val_a_2: 2.8060 - val_b_1: 1.1792 - val_b_2: 0.9623 - val_d_1: 0.3529 - val_d_2: 0.1310 - val_n: 1.5899 - val_mean_metric: 0.3226 - lr: 0.0010
# Epoch 26/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.7492 - a_1: 2.8439 - a_2: 2.8651 - b_1: 1.4450 - b_2: 1.3305 - d_1: 0.3894 - d_2: 0.3670 - n: 1.6175 - mean_metric: 0.3590 - val_loss: 9.7686 - val_a_1: 2.8021 - val_a_2: 2.7664 - val_b_1: 1.5205 - val_b_2: 0.8766 - val_d_1: 0.5293 - val_d_2: 0.3861 - val_n: 1.5321 - val_mean_metric: 0.3423 - lr: 0.0010
# Epoch 27/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5833 - a_1: 2.8384 - a_2: 2.8621 - b_1: 1.4859 - b_2: 1.3247 - d_1: 0.3818 - d_2: 0.3609 - n: 1.6033 - mean_metric: 0.3588 - val_loss: 4.5371 - val_a_1: 2.7853 - val_a_2: 2.7808 - val_b_1: 1.0517 - val_b_2: 0.9678 - val_d_1: 0.2700 - val_d_2: 0.1379 - val_n: 1.5373 - val_mean_metric: 0.3132 - lr: 0.0010
# Epoch 28/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.4880 - a_1: 2.8461 - a_2: 2.8593 - b_1: 1.4018 - b_2: 1.3319 - d_1: 0.3567 - d_2: 0.3712 - n: 1.6113 - mean_metric: 0.3562 - val_loss: 5.7327 - val_a_1: 2.8065 - val_a_2: 2.7884 - val_b_1: 1.0443 - val_b_2: 0.8587 - val_d_1: 0.2953 - val_d_2: 0.2196 - val_n: 1.5594 - val_mean_metric: 0.3146 - lr: 0.0010
# Epoch 29/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.9678 - a_1: 2.8458 - a_2: 2.8621 - b_1: 1.3607 - b_2: 1.3041 - d_1: 0.4188 - d_2: 0.3626 - n: 1.5828 - mean_metric: 0.3548 - val_loss: 3.8242 - val_a_1: 2.7835 - val_a_2: 2.8168 - val_b_1: 1.0776 - val_b_2: 0.9149 - val_d_1: 0.2086 - val_d_2: 0.1413 - val_n: 1.5869 - val_mean_metric: 0.3132 - lr: 0.0010
# Epoch 30/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.6674 - a_1: 2.8526 - a_2: 2.8539 - b_1: 1.3843 - b_2: 1.2720 - d_1: 0.3712 - d_2: 0.3771 - n: 1.5967 - mean_metric: 0.3540 - val_loss: 6.0715 - val_a_1: 2.7866 - val_a_2: 2.8166 - val_b_1: 1.1354 - val_b_2: 0.9987 - val_d_1: 0.3904 - val_d_2: 0.2022 - val_n: 1.5473 - val_mean_metric: 0.3246 - lr: 0.0010
# Epoch 31/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2515 - a_1: 2.8422 - a_2: 2.8754 - b_1: 1.3550 - b_2: 1.3079 - d_1: 0.3573 - d_2: 0.3533 - n: 1.5959 - mean_metric: 0.3532 - val_loss: 4.0498 - val_a_1: 2.7862 - val_a_2: 2.7987 - val_b_1: 0.9529 - val_b_2: 0.8892 - val_d_1: 0.1940 - val_d_2: 0.1760 - val_n: 1.5266 - val_mean_metric: 0.3064 - lr: 0.0010
# Epoch 32/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1468 - a_1: 2.8520 - a_2: 2.8738 - b_1: 1.2960 - b_2: 1.2629 - d_1: 0.3482 - d_2: 0.3500 - n: 1.5705 - mean_metric: 0.3488 - val_loss: 3.9271 - val_a_1: 2.7950 - val_a_2: 2.7804 - val_b_1: 1.0533 - val_b_2: 0.8870 - val_d_1: 0.2035 - val_d_2: 0.1327 - val_n: 1.4878 - val_mean_metric: 0.3070 - lr: 0.0010
# Epoch 33/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3912 - a_1: 2.8491 - a_2: 2.8659 - b_1: 1.3352 - b_2: 1.2642 - d_1: 0.3595 - d_2: 0.3584 - n: 1.5559 - mean_metric: 0.3499 - val_loss: 4.4750 - val_a_1: 2.8014 - val_a_2: 2.8241 - val_b_1: 1.0211 - val_b_2: 1.0207 - val_d_1: 0.1864 - val_d_2: 0.1931 - val_n: 1.4563 - val_mean_metric: 0.3123 - lr: 0.0010
# Epoch 34/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1839 - a_1: 2.8514 - a_2: 2.8535 - b_1: 1.3280 - b_2: 1.2657 - d_1: 0.3503 - d_2: 0.3487 - n: 1.5219 - mean_metric: 0.3476 - val_loss: 3.1303 - val_a_1: 2.8060 - val_a_2: 2.7906 - val_b_1: 1.0471 - val_b_2: 0.8389 - val_d_1: 0.1988 - val_d_2: 0.1089 - val_n: 1.4553 - val_mean_metric: 0.3038 - lr: 0.0010
# Epoch 35/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.0350 - a_1: 2.8421 - a_2: 2.8621 - b_1: 1.2816 - b_2: 1.2615 - d_1: 0.3475 - d_2: 0.3352 - n: 1.5252 - mean_metric: 0.3455 - val_loss: 4.2590 - val_a_1: 2.8193 - val_a_2: 2.7999 - val_b_1: 0.9551 - val_b_2: 0.9121 - val_d_1: 0.2860 - val_d_2: 0.1162 - val_n: 1.4534 - val_mean_metric: 0.3070 - lr: 0.0010
# Epoch 36/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.0714 - a_1: 2.8569 - a_2: 2.8420 - b_1: 1.2852 - b_2: 1.2591 - d_1: 0.3485 - d_2: 0.3377 - n: 1.5248 - mean_metric: 0.3455 - val_loss: 4.5090 - val_a_1: 2.8090 - val_a_2: 2.7982 - val_b_1: 0.9518 - val_b_2: 0.8974 - val_d_1: 0.2857 - val_d_2: 0.1385 - val_n: 1.4405 - val_mean_metric: 0.3063 - lr: 0.0010
# Epoch 37/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.3828 - a_1: 2.8492 - a_2: 2.8567 - b_1: 1.2623 - b_2: 1.2626 - d_1: 0.3610 - d_2: 0.3536 - n: 1.5293 - mean_metric: 0.3462 - val_loss: 4.4214 - val_a_1: 2.8362 - val_a_2: 2.7865 - val_b_1: 1.1070 - val_b_2: 1.0095 - val_d_1: 0.2458 - val_d_2: 0.1838 - val_n: 1.4342 - val_mean_metric: 0.3156 - lr: 0.0010
# Epoch 38/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.1858 - a_1: 2.8609 - a_2: 2.8546 - b_1: 1.2743 - b_2: 1.2423 - d_1: 0.3350 - d_2: 0.3599 - n: 1.5384 - mean_metric: 0.3460 - val_loss: 3.5208 - val_a_1: 2.8267 - val_a_2: 2.7832 - val_b_1: 0.9149 - val_b_2: 0.8971 - val_d_1: 0.2014 - val_d_2: 0.1007 - val_n: 1.4438 - val_mean_metric: 0.3013 - lr: 0.0010
# Epoch 39/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 6.9578 - a_1: 2.8551 - a_2: 2.8669 - b_1: 1.2614 - b_2: 1.2307 - d_1: 0.3399 - d_2: 0.3340 - n: 1.5579 - mean_metric: 0.3453 - val_loss: 4.3680 - val_a_1: 2.8349 - val_a_2: 2.7856 - val_b_1: 0.9315 - val_b_2: 0.9971 - val_d_1: 0.2590 - val_d_2: 0.1179 - val_n: 1.4521 - val_mean_metric: 0.3082 - lr: 0.0010
# Epoch 40/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.0486 - a_1: 2.8553 - a_2: 2.8594 - b_1: 1.2836 - b_2: 1.2281 - d_1: 0.3589 - d_2: 0.3239 - n: 1.5526 - mean_metric: 0.3458 - val_loss: 3.7730 - val_a_1: 2.8132 - val_a_2: 2.7865 - val_b_1: 0.9261 - val_b_2: 0.8675 - val_d_1: 0.2269 - val_d_2: 0.1241 - val_n: 1.4273 - val_mean_metric: 0.3014 - lr: 0.0010
# Epoch 41/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0675 - a_1: 2.8490 - a_2: 2.8461 - b_1: 1.2635 - b_2: 1.2267 - d_1: 0.3394 - d_2: 0.3416 - n: 1.5587 - mean_metric: 0.3446 - val_loss: 4.1321 - val_a_1: 2.8212 - val_a_2: 2.7727 - val_b_1: 1.0401 - val_b_2: 0.9442 - val_d_1: 0.2378 - val_d_2: 0.1305 - val_n: 1.4218 - val_mean_metric: 0.3079 - lr: 0.0010
# Epoch 42/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1452 - a_1: 2.8481 - a_2: 2.8547 - b_1: 1.2624 - b_2: 1.2559 - d_1: 0.3574 - d_2: 0.3377 - n: 1.5447 - mean_metric: 0.3458 - val_loss: 3.7952 - val_a_1: 2.8026 - val_a_2: 2.8034 - val_b_1: 0.8978 - val_b_2: 0.8986 - val_d_1: 0.2310 - val_d_2: 0.0914 - val_n: 1.4206 - val_mean_metric: 0.3005 - lr: 0.0010
# Epoch 43/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1748 - a_1: 2.8562 - a_2: 2.8524 - b_1: 1.2507 - b_2: 1.2719 - d_1: 0.3499 - d_2: 0.3418 - n: 1.5605 - mean_metric: 0.3465 - val_loss: 4.7481 - val_a_1: 2.8229 - val_a_2: 2.7723 - val_b_1: 0.8848 - val_b_2: 0.8311 - val_d_1: 0.2482 - val_d_2: 0.2023 - val_n: 1.4470 - val_mean_metric: 0.3026 - lr: 0.0010
# Epoch 44/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.2233 - a_1: 2.8407 - a_2: 2.8498 - b_1: 1.3228 - b_2: 1.3116 - d_1: 0.3756 - d_2: 0.4283 - n: 1.5942 - mean_metric: 0.3544 - val_loss: 6.9204 - val_a_1: 2.7830 - val_a_2: 2.7737 - val_b_1: 1.3129 - val_b_2: 0.9521 - val_d_1: 0.2283 - val_d_2: 0.3977 - val_n: 1.4495 - val_mean_metric: 0.3253 - lr: 0.0010
# Epoch 45/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4778 - a_1: 2.8294 - a_2: 2.8571 - b_1: 1.2870 - b_2: 1.3044 - d_1: 0.3483 - d_2: 0.3891 - n: 1.5709 - mean_metric: 0.3499 - val_loss: 4.6909 - val_a_1: 2.7483 - val_a_2: 2.8530 - val_b_1: 0.9518 - val_b_2: 0.9640 - val_d_1: 0.2304 - val_d_2: 0.1893 - val_n: 1.4564 - val_mean_metric: 0.3087 - lr: 0.0010
# Epoch 46/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3682 - a_1: 2.8230 - a_2: 2.8452 - b_1: 1.2825 - b_2: 1.2915 - d_1: 0.3392 - d_2: 0.3849 - n: 1.5951 - mean_metric: 0.3491 - val_loss: 5.1318 - val_a_1: 2.7700 - val_a_2: 2.8260 - val_b_1: 0.9465 - val_b_2: 0.9561 - val_d_1: 0.3090 - val_d_2: 0.1519 - val_n: 1.4493 - val_mean_metric: 0.3092 - lr: 0.0010
# Epoch 47/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4792 - a_1: 2.8304 - a_2: 2.8515 - b_1: 1.2755 - b_2: 1.3079 - d_1: 0.3550 - d_2: 0.3737 - n: 1.5758 - mean_metric: 0.3493 - val_loss: 6.5130 - val_a_1: 2.7916 - val_a_2: 2.8210 - val_b_1: 0.9546 - val_b_2: 0.9079 - val_d_1: 0.2616 - val_d_2: 0.3364 - val_n: 1.4558 - val_mean_metric: 0.3131 - lr: 0.0010
# Epoch 48/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3507 - a_1: 2.8208 - a_2: 2.8507 - b_1: 1.2736 - b_2: 1.2728 - d_1: 0.3379 - d_2: 0.3803 - n: 1.5701 - mean_metric: 0.3473 - val_loss: 3.5116 - val_a_1: 2.7880 - val_a_2: 2.7995 - val_b_1: 0.9675 - val_b_2: 0.8933 - val_d_1: 0.1690 - val_d_2: 0.1511 - val_n: 1.4348 - val_mean_metric: 0.3024 - lr: 0.0010
# Epoch 49/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.7995 - a_1: 2.8350 - a_2: 2.8508 - b_1: 1.3418 - b_2: 1.2880 - d_1: 0.3903 - d_2: 0.3647 - n: 1.6099 - mean_metric: 0.3530 - val_loss: 8.9355 - val_a_1: 2.8247 - val_a_2: 2.8336 - val_b_1: 0.9067 - val_b_2: 1.1347 - val_d_1: 0.6562 - val_d_2: 0.2278 - val_n: 1.4837 - val_mean_metric: 0.3309 - lr: 0.0010
# Epoch 50/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5491 - a_1: 2.8276 - a_2: 2.8583 - b_1: 1.3007 - b_2: 1.3236 - d_1: 0.3850 - d_2: 0.3560 - n: 1.5817 - mean_metric: 0.3514 - val_loss: 6.9471 - val_a_1: 2.8078 - val_a_2: 2.7991 - val_b_1: 0.9049 - val_b_2: 1.1838 - val_d_1: 0.5055 - val_d_2: 0.1358 - val_n: 1.4682 - val_mean_metric: 0.3223 - lr: 0.0010
# Epoch 51/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5535 - a_1: 2.8284 - a_2: 2.8375 - b_1: 1.3500 - b_2: 1.3315 - d_1: 0.3842 - d_2: 0.3575 - n: 1.5903 - mean_metric: 0.3529 - val_loss: 14.7706 - val_a_1: 2.7972 - val_a_2: 2.7460 - val_b_1: 1.8491 - val_b_2: 1.3803 - val_d_1: 1.3704 - val_d_2: 0.2110 - val_n: 1.5711 - val_mean_metric: 0.3920 - lr: 0.0010
# Epoch 52/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 8.1655 - a_1: 2.8551 - a_2: 2.8442 - b_1: 1.6216 - b_2: 1.5469 - d_1: 0.4267 - d_2: 0.3872 - n: 1.6232 - mean_metric: 0.3736 - val_loss: 6.7083 - val_a_1: 2.7913 - val_a_2: 2.7903 - val_b_1: 1.0632 - val_b_2: 1.3033 - val_d_1: 0.4767 - val_d_2: 0.2175 - val_n: 1.4854 - val_mean_metric: 0.3328 - lr: 0.0010
# Epoch 53/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5166 - a_1: 2.8475 - a_2: 2.8394 - b_1: 1.5203 - b_2: 1.4275 - d_1: 0.3781 - d_2: 0.3638 - n: 1.6240 - mean_metric: 0.3636 - val_loss: 4.3713 - val_a_1: 2.8236 - val_a_2: 2.7696 - val_b_1: 1.1994 - val_b_2: 1.1166 - val_d_1: 0.2147 - val_d_2: 0.1893 - val_n: 1.5198 - val_mean_metric: 0.3232 - lr: 0.0010
# Epoch 54/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.7465 - a_1: 2.8224 - a_2: 2.8348 - b_1: 1.4496 - b_2: 1.3670 - d_1: 0.3944 - d_2: 0.3724 - n: 1.6412 - mean_metric: 0.3596 - val_loss: 4.3420 - val_a_1: 2.8323 - val_a_2: 2.7674 - val_b_1: 1.1621 - val_b_2: 1.0952 - val_d_1: 0.2267 - val_d_2: 0.1848 - val_n: 1.5652 - val_mean_metric: 0.3232 - lr: 0.0010
# Epoch 55/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4097 - a_1: 2.8170 - a_2: 2.8636 - b_1: 1.4351 - b_2: 1.3578 - d_1: 0.3795 - d_2: 0.3517 - n: 1.6199 - mean_metric: 0.3578 - val_loss: 3.8501 - val_a_1: 2.8134 - val_a_2: 2.7752 - val_b_1: 1.0747 - val_b_2: 0.9352 - val_d_1: 0.2012 - val_d_2: 0.1516 - val_n: 1.4854 - val_mean_metric: 0.3101 - lr: 0.0010
# Epoch 56/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.2110 - a_1: 2.8272 - a_2: 2.8523 - b_1: 1.3808 - b_2: 1.3271 - d_1: 0.3509 - d_2: 0.3580 - n: 1.6180 - mean_metric: 0.3541 - val_loss: 4.1869 - val_a_1: 2.7984 - val_a_2: 2.8001 - val_b_1: 1.0735 - val_b_2: 0.8653 - val_d_1: 0.2479 - val_d_2: 0.1252 - val_n: 1.4923 - val_mean_metric: 0.3090 - lr: 0.0010
# Epoch 57/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4731 - a_1: 2.8091 - a_2: 2.8392 - b_1: 1.3751 - b_2: 1.2828 - d_1: 0.3805 - d_2: 0.3530 - n: 1.6281 - mean_metric: 0.3527 - val_loss: 4.6147 - val_a_1: 2.7928 - val_a_2: 2.8043 - val_b_1: 1.0288 - val_b_2: 0.9534 - val_d_1: 0.2567 - val_d_2: 0.1560 - val_n: 1.4814 - val_mean_metric: 0.3113 - lr: 0.0010
# Epoch 58/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2427 - a_1: 2.8103 - a_2: 2.8443 - b_1: 1.3563 - b_2: 1.3060 - d_1: 0.3541 - d_2: 0.3526 - n: 1.6111 - mean_metric: 0.3515 - val_loss: 4.7793 - val_a_1: 2.7701 - val_a_2: 2.7900 - val_b_1: 1.0231 - val_b_2: 0.9766 - val_d_1: 0.2853 - val_d_2: 0.1650 - val_n: 1.4607 - val_mean_metric: 0.3113 - lr: 0.0010
# Epoch 59/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1079 - a_1: 2.8120 - a_2: 2.8334 - b_1: 1.3531 - b_2: 1.2886 - d_1: 0.3574 - d_2: 0.3320 - n: 1.5994 - mean_metric: 0.3495 - val_loss: 3.8487 - val_a_1: 2.7761 - val_a_2: 2.7930 - val_b_1: 1.0434 - val_b_2: 0.9342 - val_d_1: 0.1891 - val_d_2: 0.1338 - val_n: 1.4826 - val_mean_metric: 0.3074 - lr: 0.0010
# Epoch 60/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.1575 - a_1: 2.8050 - a_2: 2.8442 - b_1: 1.3153 - b_2: 1.2603 - d_1: 0.3402 - d_2: 0.3582 - n: 1.6223 - mean_metric: 0.3486 - val_loss: 5.3802 - val_a_1: 2.7751 - val_a_2: 2.8025 - val_b_1: 0.9685 - val_b_2: 0.8833 - val_d_1: 0.2444 - val_d_2: 0.2550 - val_n: 1.4796 - val_mean_metric: 0.3092 - lr: 0.0010
# Epoch 61/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.1123 - a_1: 2.8141 - a_2: 2.8511 - b_1: 1.3294 - b_2: 1.2708 - d_1: 0.3527 - d_2: 0.3388 - n: 1.6033 - mean_metric: 0.3491 - val_loss: 4.3871 - val_a_1: 2.7913 - val_a_2: 2.7803 - val_b_1: 0.9825 - val_b_2: 0.9869 - val_d_1: 0.2625 - val_d_2: 0.1235 - val_n: 1.4457 - val_mean_metric: 0.3080 - lr: 0.0010
# Epoch 62/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.3961 - a_1: 2.8234 - a_2: 2.8505 - b_1: 1.3194 - b_2: 1.2659 - d_1: 0.3621 - d_2: 0.3598 - n: 1.6012 - mean_metric: 0.3498 - val_loss: 4.4569 - val_a_1: 2.7825 - val_a_2: 2.7929 - val_b_1: 0.9683 - val_b_2: 1.1419 - val_d_1: 0.2455 - val_d_2: 0.1473 - val_n: 1.4378 - val_mean_metric: 0.3128 - lr: 0.0010
# Epoch 63/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.2477 - a_1: 2.8117 - a_2: 2.8571 - b_1: 1.3265 - b_2: 1.2973 - d_1: 0.3590 - d_2: 0.3427 - n: 1.6135 - mean_metric: 0.3506 - val_loss: 5.4864 - val_a_1: 2.8729 - val_a_2: 2.7735 - val_b_1: 1.0672 - val_b_2: 1.1352 - val_d_1: 0.2152 - val_d_2: 0.2557 - val_n: 1.5055 - val_mean_metric: 0.3229 - lr: 0.0010
# Epoch 64/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 7.1236 - a_1: 2.8092 - a_2: 2.8484 - b_1: 1.3160 - b_2: 1.2695 - d_1: 0.3323 - d_2: 0.3544 - n: 1.6149 - mean_metric: 0.3485 - val_loss: 3.9430 - val_a_1: 2.8906 - val_a_2: 2.7899 - val_b_1: 1.0153 - val_b_2: 0.8803 - val_d_1: 0.2323 - val_d_2: 0.1214 - val_n: 1.4750 - val_mean_metric: 0.3091 - lr: 0.0010
# Epoch 65/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 6.7799 - a_1: 2.8394 - a_2: 2.8406 - b_1: 1.3070 - b_2: 1.2725 - d_1: 0.3287 - d_2: 0.3251 - n: 1.6209 - mean_metric: 0.3481 - val_loss: 4.4026 - val_a_1: 2.8200 - val_a_2: 2.8058 - val_b_1: 0.9507 - val_b_2: 0.8508 - val_d_1: 0.2593 - val_d_2: 0.1362 - val_n: 1.4679 - val_mean_metric: 0.3053 - lr: 0.0010
# Epoch 66/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.7595 - a_1: 2.8183 - a_2: 2.8578 - b_1: 1.2533 - b_2: 1.2579 - d_1: 0.3425 - d_2: 0.3079 - n: 1.6301 - mean_metric: 0.3460 - val_loss: 4.2449 - val_a_1: 2.8111 - val_a_2: 2.8058 - val_b_1: 0.9296 - val_b_2: 1.0206 - val_d_1: 0.2414 - val_d_2: 0.1500 - val_n: 1.4563 - val_mean_metric: 0.3094 - lr: 0.0010
# Epoch 67/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0613 - a_1: 2.8219 - a_2: 2.8478 - b_1: 1.2620 - b_2: 1.2251 - d_1: 0.3363 - d_2: 0.3455 - n: 1.6472 - mean_metric: 0.3465 - val_loss: 8.2019 - val_a_1: 2.7575 - val_a_2: 2.8012 - val_b_1: 0.9830 - val_b_2: 0.9497 - val_d_1: 0.2813 - val_d_2: 0.4536 - val_n: 1.4902 - val_mean_metric: 0.3193 - lr: 0.0010
# Epoch 68/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2459 - a_1: 2.8196 - a_2: 2.8496 - b_1: 1.2479 - b_2: 1.2607 - d_1: 0.3557 - d_2: 0.3504 - n: 1.6432 - mean_metric: 0.3480 - val_loss: 4.0914 - val_a_1: 2.8108 - val_a_2: 2.7809 - val_b_1: 0.9672 - val_b_2: 0.9833 - val_d_1: 0.1980 - val_d_2: 0.1422 - val_n: 1.4968 - val_mean_metric: 0.3083 - lr: 0.0010
# Epoch 69/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.9169 - a_1: 2.8158 - a_2: 2.8413 - b_1: 1.2500 - b_2: 1.2656 - d_1: 0.3205 - d_2: 0.3460 - n: 1.6710 - mean_metric: 0.3474 - val_loss: 3.7263 - val_a_1: 2.8154 - val_a_2: 2.8007 - val_b_1: 0.9508 - val_b_2: 1.1010 - val_d_1: 0.2136 - val_d_2: 0.1246 - val_n: 1.4994 - val_mean_metric: 0.3124 - lr: 0.0010
# Epoch 70/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1058 - a_1: 2.8236 - a_2: 2.8540 - b_1: 1.2445 - b_2: 1.2463 - d_1: 0.3309 - d_2: 0.3582 - n: 1.6863 - mean_metric: 0.3485 - val_loss: 3.9578 - val_a_1: 2.8538 - val_a_2: 2.7954 - val_b_1: 0.8953 - val_b_2: 1.1041 - val_d_1: 0.1828 - val_d_2: 0.1875 - val_n: 1.5025 - val_mean_metric: 0.3129 - lr: 0.0010
# Epoch 71/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0706 - a_1: 2.8241 - a_2: 2.8641 - b_1: 1.2563 - b_2: 1.2249 - d_1: 0.3255 - d_2: 0.3618 - n: 1.6875 - mean_metric: 0.3485 - val_loss: 4.6119 - val_a_1: 2.7976 - val_a_2: 2.8194 - val_b_1: 0.9234 - val_b_2: 0.9926 - val_d_1: 0.2809 - val_d_2: 0.1523 - val_n: 1.5054 - val_mean_metric: 0.3113 - lr: 0.0010
# Epoch 72/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 6.9174 - a_1: 2.8228 - a_2: 2.8540 - b_1: 1.2502 - b_2: 1.2441 - d_1: 0.3219 - d_2: 0.3435 - n: 1.7296 - mean_metric: 0.3492 - val_loss: 4.2443 - val_a_1: 2.7902 - val_a_2: 2.8074 - val_b_1: 0.9165 - val_b_2: 0.8904 - val_d_1: 0.2228 - val_d_2: 0.1551 - val_n: 1.5349 - val_mean_metric: 0.3062 - lr: 0.0010
# Epoch 73/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1413 - a_1: 2.8128 - a_2: 2.8407 - b_1: 1.2270 - b_2: 1.2395 - d_1: 0.3435 - d_2: 0.3467 - n: 1.6983 - mean_metric: 0.3473 - val_loss: 3.9468 - val_a_1: 2.8170 - val_a_2: 2.8002 - val_b_1: 0.9544 - val_b_2: 0.9745 - val_d_1: 0.1876 - val_d_2: 0.1761 - val_n: 1.5581 - val_mean_metric: 0.3112 - lr: 0.0010
# Epoch 74/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1911 - a_1: 2.8158 - a_2: 2.8463 - b_1: 1.2629 - b_2: 1.2147 - d_1: 0.3451 - d_2: 0.3517 - n: 1.7002 - mean_metric: 0.3483 - val_loss: 3.9508 - val_a_1: 2.7945 - val_a_2: 2.7994 - val_b_1: 0.9014 - val_b_2: 0.9319 - val_d_1: 0.1879 - val_d_2: 0.1595 - val_n: 1.4790 - val_mean_metric: 0.3041 - lr: 0.0010
# Epoch 75/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.9459 - a_1: 2.8147 - a_2: 2.8434 - b_1: 1.2610 - b_2: 1.2804 - d_1: 0.3405 - d_2: 0.3334 - n: 1.6828 - mean_metric: 0.3489 - val_loss: 3.8784 - val_a_1: 2.8020 - val_a_2: 2.8007 - val_b_1: 0.9330 - val_b_2: 0.9222 - val_d_1: 0.1918 - val_d_2: 0.1670 - val_n: 1.5004 - val_mean_metric: 0.3062 - lr: 0.0010
# Epoch 76/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.9475 - a_1: 2.8169 - a_2: 2.8294 - b_1: 1.2499 - b_2: 1.2354 - d_1: 0.3407 - d_2: 0.3309 - n: 1.6980 - mean_metric: 0.3471 - val_loss: 5.5054 - val_a_1: 2.8103 - val_a_2: 2.7789 - val_b_1: 1.0363 - val_b_2: 0.9592 - val_d_1: 0.3171 - val_d_2: 0.1844 - val_n: 1.5572 - val_mean_metric: 0.3169 - lr: 0.0010
# Epoch 77/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.9977 - a_1: 2.8174 - a_2: 2.8437 - b_1: 1.2566 - b_2: 1.2449 - d_1: 0.3264 - d_2: 0.3492 - n: 1.6830 - mean_metric: 0.3477 - val_loss: 3.9877 - val_a_1: 2.8142 - val_a_2: 2.7877 - val_b_1: 0.9378 - val_b_2: 1.1518 - val_d_1: 0.1881 - val_d_2: 0.1582 - val_n: 1.4947 - val_mean_metric: 0.3133 - lr: 0.0010
# Epoch 78/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.9457 - a_1: 2.8230 - a_2: 2.8484 - b_1: 1.2533 - b_2: 1.2328 - d_1: 0.3192 - d_2: 0.3462 - n: 1.6922 - mean_metric: 0.3475 - val_loss: 3.9268 - val_a_1: 2.8004 - val_a_2: 2.8096 - val_b_1: 0.9004 - val_b_2: 0.9853 - val_d_1: 0.2430 - val_d_2: 0.1154 - val_n: 1.5307 - val_mean_metric: 0.3084 - lr: 0.0010
# Epoch 79/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.8535 - a_1: 2.8231 - a_2: 2.8510 - b_1: 1.2449 - b_2: 1.2283 - d_1: 0.3349 - d_2: 0.3264 - n: 1.6958 - mean_metric: 0.3472 - val_loss: 5.1430 - val_a_1: 2.8209 - val_a_2: 2.7657 - val_b_1: 0.9367 - val_b_2: 0.9203 - val_d_1: 0.3239 - val_d_2: 0.1626 - val_n: 1.5134 - val_mean_metric: 0.3104 - lr: 0.0010
# Epoch 80/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0280 - a_1: 2.8316 - a_2: 2.8350 - b_1: 1.2363 - b_2: 1.2070 - d_1: 0.3374 - d_2: 0.3450 - n: 1.6994 - mean_metric: 0.3467 - val_loss: 3.2433 - val_a_1: 2.7690 - val_a_2: 2.8179 - val_b_1: 0.8477 - val_b_2: 0.9577 - val_d_1: 0.2004 - val_d_2: 0.1020 - val_n: 1.5427 - val_mean_metric: 0.3036 - lr: 0.0010
# Epoch 81/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0875 - a_1: 2.8159 - a_2: 2.8501 - b_1: 1.2520 - b_2: 1.2277 - d_1: 0.3381 - d_2: 0.3404 - n: 1.7014 - mean_metric: 0.3479 - val_loss: 3.5235 - val_a_1: 2.8020 - val_a_2: 2.8025 - val_b_1: 0.8952 - val_b_2: 0.8892 - val_d_1: 0.2059 - val_d_2: 0.0897 - val_n: 1.5195 - val_mean_metric: 0.3025 - lr: 0.0010
# Epoch 82/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0861 - a_1: 2.8315 - a_2: 2.8568 - b_1: 1.2472 - b_2: 1.2317 - d_1: 0.3264 - d_2: 0.3551 - n: 1.7122 - mean_metric: 0.3491 - val_loss: 5.0904 - val_a_1: 2.8167 - val_a_2: 2.8038 - val_b_1: 0.9810 - val_b_2: 1.0367 - val_d_1: 0.3233 - val_d_2: 0.1497 - val_n: 1.5914 - val_mean_metric: 0.3189 - lr: 0.0010
# Epoch 83/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0684 - a_1: 2.8258 - a_2: 2.8371 - b_1: 1.2527 - b_2: 1.2145 - d_1: 0.3446 - d_2: 0.3379 - n: 1.7080 - mean_metric: 0.3477 - val_loss: 3.5294 - val_a_1: 2.8329 - val_a_2: 2.7904 - val_b_1: 0.9756 - val_b_2: 1.0302 - val_d_1: 0.2044 - val_d_2: 0.1091 - val_n: 1.5418 - val_mean_metric: 0.3117 - lr: 0.0010
# Epoch 84/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.9782 - a_1: 2.8395 - a_2: 2.8356 - b_1: 1.2535 - b_2: 1.2282 - d_1: 0.3325 - d_2: 0.3406 - n: 1.7363 - mean_metric: 0.3492 - val_loss: 3.5442 - val_a_1: 2.8323 - val_a_2: 2.7882 - val_b_1: 0.8922 - val_b_2: 0.9386 - val_d_1: 0.2223 - val_d_2: 0.0926 - val_n: 1.5793 - val_mean_metric: 0.3071 - lr: 0.0010
# Epoch 85/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0683 - a_1: 2.8432 - a_2: 2.8420 - b_1: 1.2292 - b_2: 1.2374 - d_1: 0.3348 - d_2: 0.3457 - n: 1.7484 - mean_metric: 0.3496 - val_loss: 7.4446 - val_a_1: 2.7543 - val_a_2: 2.8344 - val_b_1: 0.9644 - val_b_2: 1.0723 - val_d_1: 0.2284 - val_d_2: 0.4294 - val_n: 1.4838 - val_mean_metric: 0.3210 - lr: 0.0010
# Epoch 86/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3435 - a_1: 2.8386 - a_2: 2.8441 - b_1: 1.2173 - b_2: 1.2391 - d_1: 0.3452 - d_2: 0.3725 - n: 1.7168 - mean_metric: 0.3495 - val_loss: 7.8323 - val_a_1: 2.7984 - val_a_2: 2.7976 - val_b_1: 0.9666 - val_b_2: 0.9402 - val_d_1: 0.2296 - val_d_2: 0.5024 - val_n: 1.5001 - val_mean_metric: 0.3199 - lr: 0.0010
# Epoch 87/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4833 - a_1: 2.8200 - a_2: 2.8511 - b_1: 1.2322 - b_2: 1.2286 - d_1: 0.3587 - d_2: 0.3749 - n: 1.7138 - mean_metric: 0.3496 - val_loss: 4.2452 - val_a_1: 2.8034 - val_a_2: 2.7946 - val_b_1: 0.9111 - val_b_2: 0.9251 - val_d_1: 0.2091 - val_d_2: 0.1756 - val_n: 1.5158 - val_mean_metric: 0.3068 - lr: 0.0010
# Epoch 88/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1437 - a_1: 2.8298 - a_2: 2.8399 - b_1: 1.2016 - b_2: 1.2083 - d_1: 0.3336 - d_2: 0.3600 - n: 1.7412 - mean_metric: 0.3475 - val_loss: 4.3565 - val_a_1: 2.8100 - val_a_2: 2.7948 - val_b_1: 0.9008 - val_b_2: 1.0386 - val_d_1: 0.2759 - val_d_2: 0.1249 - val_n: 1.5609 - val_mean_metric: 0.3124 - lr: 0.0010
# Epoch 89/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4263 - a_1: 2.8238 - a_2: 2.8509 - b_1: 1.3330 - b_2: 1.3649 - d_1: 0.3408 - d_2: 0.3731 - n: 1.7367 - mean_metric: 0.3578 - val_loss: 11.1995 - val_a_1: 2.7734 - val_a_2: 2.8433 - val_b_1: 1.3987 - val_b_2: 1.3267 - val_d_1: 0.1782 - val_d_2: 0.8561 - val_n: 1.5135 - val_mean_metric: 0.3579 - lr: 0.0010
# Epoch 90/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.6055 - a_1: 2.8309 - a_2: 2.8562 - b_1: 1.2671 - b_2: 1.3721 - d_1: 0.3290 - d_2: 0.4123 - n: 1.7647 - mean_metric: 0.3580 - val_loss: 10.0150 - val_a_1: 2.8335 - val_a_2: 2.7704 - val_b_1: 0.9901 - val_b_2: 1.0751 - val_d_1: 0.2410 - val_d_2: 0.7614 - val_n: 1.6229 - val_mean_metric: 0.3383 - lr: 0.0010
# Epoch 91/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5514 - a_1: 2.8370 - a_2: 2.8584 - b_1: 1.2526 - b_2: 1.2975 - d_1: 0.3387 - d_2: 0.3990 - n: 1.7852 - mean_metric: 0.3560 - val_loss: 5.7003 - val_a_1: 2.8663 - val_a_2: 2.7610 - val_b_1: 1.0669 - val_b_2: 0.8517 - val_d_1: 0.2247 - val_d_2: 0.3024 - val_n: 1.6596 - val_mean_metric: 0.3199 - lr: 0.0010
# Epoch 92/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5281 - a_1: 2.8317 - a_2: 2.8609 - b_1: 1.2881 - b_2: 1.3283 - d_1: 0.3298 - d_2: 0.4052 - n: 1.7563 - mean_metric: 0.3569 - val_loss: 4.7216 - val_a_1: 2.8050 - val_a_2: 2.7891 - val_b_1: 0.9831 - val_b_2: 0.9474 - val_d_1: 0.1739 - val_d_2: 0.2444 - val_n: 1.5889 - val_mean_metric: 0.3133 - lr: 0.0010
# Epoch 93/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3788 - a_1: 2.8319 - a_2: 2.8455 - b_1: 1.2790 - b_2: 1.2998 - d_1: 0.3445 - d_2: 0.3766 - n: 1.7466 - mean_metric: 0.3544 - val_loss: 4.5072 - val_a_1: 2.8276 - val_a_2: 2.7866 - val_b_1: 1.0566 - val_b_2: 0.8950 - val_d_1: 0.2218 - val_d_2: 0.1706 - val_n: 1.6007 - val_mean_metric: 0.3141 - lr: 0.0010
# Epoch 94/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2995 - a_1: 2.8364 - a_2: 2.8485 - b_1: 1.2371 - b_2: 1.2613 - d_1: 0.3172 - d_2: 0.3900 - n: 1.7510 - mean_metric: 0.3517 - val_loss: 4.1335 - val_a_1: 2.8069 - val_a_2: 2.7960 - val_b_1: 0.9825 - val_b_2: 1.0274 - val_d_1: 0.2035 - val_d_2: 0.1781 - val_n: 1.5616 - val_mean_metric: 0.3141 - lr: 0.0010
# Epoch 95/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4009 - a_1: 2.8251 - a_2: 2.8559 - b_1: 1.2641 - b_2: 1.2986 - d_1: 0.3285 - d_2: 0.3908 - n: 1.7184 - mean_metric: 0.3530 - val_loss: 5.0307 - val_a_1: 2.7725 - val_a_2: 2.8387 - val_b_1: 0.8720 - val_b_2: 0.9937 - val_d_1: 0.2414 - val_d_2: 0.2160 - val_n: 1.5420 - val_mean_metric: 0.3114 - lr: 0.0010
# Epoch 96/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3423 - a_1: 2.8263 - a_2: 2.8480 - b_1: 1.2363 - b_2: 1.2719 - d_1: 0.3252 - d_2: 0.3843 - n: 1.7427 - mean_metric: 0.3515 - val_loss: 8.5941 - val_a_1: 2.7847 - val_a_2: 2.8082 - val_b_1: 1.1357 - val_b_2: 0.9570 - val_d_1: 0.2451 - val_d_2: 0.5367 - val_n: 1.5046 - val_mean_metric: 0.3277 - lr: 0.0010
# Epoch 97/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.8491 - a_1: 2.8114 - a_2: 2.8583 - b_1: 1.3094 - b_2: 1.3071 - d_1: 0.4033 - d_2: 0.3633 - n: 1.6843 - mean_metric: 0.3549 - val_loss: 5.6391 - val_a_1: 2.7810 - val_a_2: 2.8072 - val_b_1: 0.9680 - val_b_2: 1.1894 - val_d_1: 0.3822 - val_d_2: 0.1618 - val_n: 1.5493 - val_mean_metric: 0.3234 - lr: 0.0010
# Epoch 98/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4688 - a_1: 2.8111 - a_2: 2.8446 - b_1: 1.2497 - b_2: 1.3007 - d_1: 0.3519 - d_2: 0.3767 - n: 1.6567 - mean_metric: 0.3501 - val_loss: 3.4398 - val_a_1: 2.7892 - val_a_2: 2.8051 - val_b_1: 1.0553 - val_b_2: 1.1222 - val_d_1: 0.1748 - val_d_2: 0.1569 - val_n: 1.4749 - val_mean_metric: 0.3148 - lr: 0.0010
# Epoch 99/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5779 - a_1: 2.8069 - a_2: 2.8567 - b_1: 1.2789 - b_2: 1.2945 - d_1: 0.3731 - d_2: 0.3664 - n: 1.6804 - mean_metric: 0.3523 - val_loss: 4.3847 - val_a_1: 2.7952 - val_a_2: 2.7958 - val_b_1: 0.9978 - val_b_2: 1.0320 - val_d_1: 0.2567 - val_d_2: 0.1281 - val_n: 1.4907 - val_mean_metric: 0.3121 - lr: 0.0010
# Epoch 100/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3449 - a_1: 2.8126 - a_2: 2.8434 - b_1: 1.2760 - b_2: 1.2874 - d_1: 0.3475 - d_2: 0.3677 - n: 1.6669 - mean_metric: 0.3504 - val_loss: 3.6405 - val_a_1: 2.7955 - val_a_2: 2.7974 - val_b_1: 0.9975 - val_b_2: 1.0172 - val_d_1: 0.1955 - val_d_2: 0.1405 - val_n: 1.4991 - val_mean_metric: 0.3103 - lr: 0.0010
# Epoch 101/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2570 - a_1: 2.8110 - a_2: 2.8474 - b_1: 1.2940 - b_2: 1.2625 - d_1: 0.3423 - d_2: 0.3679 - n: 1.6713 - mean_metric: 0.3502 - val_loss: 4.4535 - val_a_1: 2.8182 - val_a_2: 2.7896 - val_b_1: 1.0553 - val_b_2: 0.9792 - val_d_1: 0.2489 - val_d_2: 0.1293 - val_n: 1.5111 - val_mean_metric: 0.3132 - lr: 0.0010
# Epoch 102/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.7196 - a_1: 2.8100 - a_2: 2.8478 - b_1: 1.2432 - b_2: 1.3050 - d_1: 0.3410 - d_2: 0.4121 - n: 1.6570 - mean_metric: 0.3508 - val_loss: 5.2254 - val_a_1: 2.7987 - val_a_2: 2.7973 - val_b_1: 1.0116 - val_b_2: 1.0973 - val_d_1: 0.3239 - val_d_2: 0.1666 - val_n: 1.5644 - val_mean_metric: 0.3208 - lr: 0.0010
# Epoch 103/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5618 - a_1: 2.8142 - a_2: 2.8378 - b_1: 1.2473 - b_2: 1.2819 - d_1: 0.3453 - d_2: 0.3872 - n: 1.6674 - mean_metric: 0.3497 - val_loss: 3.8326 - val_a_1: 2.7494 - val_a_2: 2.8225 - val_b_1: 0.8151 - val_b_2: 1.0106 - val_d_1: 0.1921 - val_d_2: 0.1482 - val_n: 1.4759 - val_mean_metric: 0.3028 - lr: 0.0010
# Epoch 104/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3184 - a_1: 2.8196 - a_2: 2.8413 - b_1: 1.2485 - b_2: 1.2830 - d_1: 0.3417 - d_2: 0.3702 - n: 1.7026 - mean_metric: 0.3506 - val_loss: 4.3827 - val_a_1: 2.8149 - val_a_2: 2.7886 - val_b_1: 0.9718 - val_b_2: 1.1660 - val_d_1: 0.2589 - val_d_2: 0.1445 - val_n: 1.5028 - val_mean_metric: 0.3171 - lr: 0.0010
# Epoch 105/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1766 - a_1: 2.8179 - a_2: 2.8531 - b_1: 1.2610 - b_2: 1.2874 - d_1: 0.3460 - d_2: 0.3519 - n: 1.6893 - mean_metric: 0.3506 - val_loss: 10.7697 - val_a_1: 2.7881 - val_a_2: 2.7646 - val_b_1: 0.9313 - val_b_2: 0.8458 - val_d_1: 0.2073 - val_d_2: 0.8434 - val_n: 1.5322 - val_mean_metric: 0.3258 - lr: 0.0010
# Epoch 106/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.6581 - a_1: 2.8207 - a_2: 2.8527 - b_1: 1.2300 - b_2: 1.2527 - d_1: 0.3329 - d_2: 0.4135 - n: 1.7125 - mean_metric: 0.3508 - val_loss: 5.3509 - val_a_1: 2.7884 - val_a_2: 2.8163 - val_b_1: 0.8962 - val_b_2: 1.0295 - val_d_1: 0.2259 - val_d_2: 0.2626 - val_n: 1.4879 - val_mean_metric: 0.3124 - lr: 0.0010
# Epoch 107/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4800 - a_1: 2.8186 - a_2: 2.8368 - b_1: 1.2550 - b_2: 1.2428 - d_1: 0.3242 - d_2: 0.4046 - n: 1.6438 - mean_metric: 0.3479 - val_loss: 3.6838 - val_a_1: 2.7863 - val_a_2: 2.8144 - val_b_1: 0.8951 - val_b_2: 0.9828 - val_d_1: 0.1863 - val_d_2: 0.1485 - val_n: 1.4756 - val_mean_metric: 0.3053 - lr: 0.0010
# Epoch 108/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2018 - a_1: 2.8237 - a_2: 2.8449 - b_1: 1.2463 - b_2: 1.2721 - d_1: 0.3184 - d_2: 0.3857 - n: 1.6635 - mean_metric: 0.3489 - val_loss: 4.9912 - val_a_1: 2.7856 - val_a_2: 2.7941 - val_b_1: 0.9127 - val_b_2: 0.9525 - val_d_1: 0.2817 - val_d_2: 0.1683 - val_n: 1.4834 - val_mean_metric: 0.3082 - lr: 0.0010
# Epoch 109/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4690 - a_1: 2.8021 - a_2: 2.8353 - b_1: 1.2474 - b_2: 1.2418 - d_1: 0.3404 - d_2: 0.3877 - n: 1.6663 - mean_metric: 0.3477 - val_loss: 2.8046 - val_a_1: 2.7928 - val_a_2: 2.7912 - val_b_1: 0.8670 - val_b_2: 0.9859 - val_d_1: 0.1322 - val_d_2: 0.1303 - val_n: 1.4816 - val_mean_metric: 0.3017 - lr: 0.0010
# Epoch 110/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2920 - a_1: 2.8075 - a_2: 2.8221 - b_1: 1.2061 - b_2: 1.2669 - d_1: 0.3438 - d_2: 0.3650 - n: 1.6718 - mean_metric: 0.3464 - val_loss: 5.3510 - val_a_1: 2.8178 - val_a_2: 2.7667 - val_b_1: 0.9833 - val_b_2: 1.1678 - val_d_1: 0.3524 - val_d_2: 0.1667 - val_n: 1.4743 - val_mean_metric: 0.3198 - lr: 0.0010
# Epoch 111/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.6391 - a_1: 2.8063 - a_2: 2.8317 - b_1: 1.2349 - b_2: 1.2807 - d_1: 0.3630 - d_2: 0.3858 - n: 1.6530 - mean_metric: 0.3489 - val_loss: 3.9321 - val_a_1: 2.7978 - val_a_2: 2.7748 - val_b_1: 0.9183 - val_b_2: 1.2687 - val_d_1: 0.2254 - val_d_2: 0.1533 - val_n: 1.4514 - val_mean_metric: 0.3152 - lr: 0.0010
# Epoch 112/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4962 - a_1: 2.8184 - a_2: 2.8256 - b_1: 1.2667 - b_2: 1.2797 - d_1: 0.3571 - d_2: 0.3695 - n: 1.6529 - mean_metric: 0.3493 - val_loss: 3.8421 - val_a_1: 2.7982 - val_a_2: 2.7879 - val_b_1: 0.9461 - val_b_2: 0.9271 - val_d_1: 0.2158 - val_d_2: 0.1336 - val_n: 1.5037 - val_mean_metric: 0.3060 - lr: 0.0010
# Epoch 113/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2111 - a_1: 2.8101 - a_2: 2.8340 - b_1: 1.2596 - b_2: 1.2532 - d_1: 0.3281 - d_2: 0.3785 - n: 1.6535 - mean_metric: 0.3476 - val_loss: 5.9413 - val_a_1: 2.8186 - val_a_2: 2.7882 - val_b_1: 1.0272 - val_b_2: 0.9482 - val_d_1: 0.3538 - val_d_2: 0.1541 - val_n: 1.5625 - val_mean_metric: 0.3172 - lr: 0.0010
# Epoch 114/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4951 - a_1: 2.8233 - a_2: 2.8385 - b_1: 1.2638 - b_2: 1.2489 - d_1: 0.3401 - d_2: 0.3884 - n: 1.6630 - mean_metric: 0.3492 - val_loss: 3.4940 - val_a_1: 2.7956 - val_a_2: 2.8090 - val_b_1: 0.9282 - val_b_2: 0.9252 - val_d_1: 0.1555 - val_d_2: 0.1628 - val_n: 1.5023 - val_mean_metric: 0.3049 - lr: 0.0010
# Epoch 115/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.0289 - a_1: 2.8113 - a_2: 2.8470 - b_1: 1.2486 - b_2: 1.2428 - d_1: 0.3383 - d_2: 0.3432 - n: 1.6784 - mean_metric: 0.3474 - val_loss: 4.4110 - val_a_1: 2.8190 - val_a_2: 2.7931 - val_b_1: 0.9328 - val_b_2: 0.9451 - val_d_1: 0.2561 - val_d_2: 0.1205 - val_n: 1.5103 - val_mean_metric: 0.3082 - lr: 0.0010
# Epoch 116/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1981 - a_1: 2.8240 - a_2: 2.8563 - b_1: 1.2542 - b_2: 1.2525 - d_1: 0.3216 - d_2: 0.3753 - n: 1.6761 - mean_metric: 0.3490 - val_loss: 3.4766 - val_a_1: 2.7780 - val_a_2: 2.8104 - val_b_1: 0.9165 - val_b_2: 0.9726 - val_d_1: 0.2058 - val_d_2: 0.1077 - val_n: 1.4765 - val_mean_metric: 0.3046 - lr: 0.0010
# Epoch 117/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.2766 - a_1: 2.8277 - a_2: 2.8424 - b_1: 1.2344 - b_2: 1.2455 - d_1: 0.3242 - d_2: 0.3789 - n: 1.7027 - mean_metric: 0.3489 - val_loss: 4.9990 - val_a_1: 2.8291 - val_a_2: 2.7911 - val_b_1: 0.9944 - val_b_2: 1.0493 - val_d_1: 0.3032 - val_d_2: 0.1566 - val_n: 1.5038 - val_mean_metric: 0.3164 - lr: 0.0010
# Epoch 118/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5733 - a_1: 2.8336 - a_2: 2.8440 - b_1: 1.2436 - b_2: 1.2312 - d_1: 0.3539 - d_2: 0.3840 - n: 1.6830 - mean_metric: 0.3494 - val_loss: 3.4141 - val_a_1: 2.8133 - val_a_2: 2.7890 - val_b_1: 0.9196 - val_b_2: 1.0413 - val_d_1: 0.1667 - val_d_2: 0.1363 - val_n: 1.4990 - val_mean_metric: 0.3078 - lr: 0.0010
# Epoch 119/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3557 - a_1: 2.8400 - a_2: 2.8422 - b_1: 1.2461 - b_2: 1.2633 - d_1: 0.3429 - d_2: 0.3684 - n: 1.7366 - mean_metric: 0.3516 - val_loss: 3.8136 - val_a_1: 2.7963 - val_a_2: 2.8006 - val_b_1: 0.8681 - val_b_2: 0.9815 - val_d_1: 0.2137 - val_d_2: 0.1097 - val_n: 1.5215 - val_mean_metric: 0.3054 - lr: 0.0010
# Epoch 120/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.1020 - a_1: 2.8232 - a_2: 2.8415 - b_1: 1.2245 - b_2: 1.2859 - d_1: 0.3097 - d_2: 0.3734 - n: 1.7502 - mean_metric: 0.3506 - val_loss: 4.1173 - val_a_1: 2.7799 - val_a_2: 2.7992 - val_b_1: 0.9158 - val_b_2: 0.9685 - val_d_1: 0.2479 - val_d_2: 0.1355 - val_n: 1.5265 - val_mean_metric: 0.3080 - lr: 0.0010
# Epoch 121/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.6304 - a_1: 2.7970 - a_2: 2.8352 - b_1: 1.2867 - b_2: 1.2663 - d_1: 0.3752 - d_2: 0.3619 - n: 1.7100 - mean_metric: 0.3514 - val_loss: 8.8523 - val_a_1: 2.7362 - val_a_2: 2.7990 - val_b_1: 0.9577 - val_b_2: 0.9351 - val_d_1: 0.7424 - val_d_2: 0.1305 - val_n: 1.5678 - val_mean_metric: 0.3243 - lr: 0.0010
# Epoch 122/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.5450 - a_1: 2.7964 - a_2: 2.8506 - b_1: 1.2676 - b_2: 1.2760 - d_1: 0.3701 - d_2: 0.3633 - n: 1.6718 - mean_metric: 0.3502 - val_loss: 6.4755 - val_a_1: 2.7634 - val_a_2: 2.8133 - val_b_1: 0.9691 - val_b_2: 1.1487 - val_d_1: 0.3553 - val_d_2: 0.2938 - val_n: 1.8136 - val_mean_metric: 0.3339 - lr: 0.0010
# Epoch 123/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.4380 - a_1: 2.8259 - a_2: 2.8502 - b_1: 1.2369 - b_2: 1.2479 - d_1: 0.3686 - d_2: 0.3506 - n: 1.7004 - mean_metric: 0.3497 - val_loss: 4.4627 - val_a_1: 2.7947 - val_a_2: 2.7775 - val_b_1: 1.0227 - val_b_2: 1.0111 - val_d_1: 0.2674 - val_d_2: 0.1351 - val_n: 1.5406 - val_mean_metric: 0.3138 - lr: 0.0010
# Epoch 124/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 7.3760 - a_1: 2.8125 - a_2: 2.8407 - b_1: 1.2202 - b_2: 1.2415 - d_1: 0.3566 - d_2: 0.3575 - n: 1.7084 - mean_metric: 0.3482 - val_loss: 4.7728 - val_a_1: 2.7796 - val_a_2: 2.8029 - val_b_1: 0.9170 - val_b_2: 0.9890 - val_d_1: 0.1815 - val_d_2: 0.2886 - val_n: 1.5217 - val_mean_metric: 0.3116 - lr: 0.0010
# Epoch 125/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.9887 - a_1: 2.8166 - a_2: 2.8346 - b_1: 1.2594 - b_2: 1.2374 - d_1: 0.3250 - d_2: 0.3521 - n: 1.6936 - mean_metric: 0.3477 - val_loss: 9.1272 - val_a_1: 2.7872 - val_a_2: 2.7902 - val_b_1: 0.9330 - val_b_2: 1.1309 - val_d_1: 0.2545 - val_d_2: 0.6486 - val_n: 1.5263 - val_mean_metric: 0.3310 - lr: 0.0010
# Epoch 126/1000
# ...
# Epoch 960/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0165 - a_1: 3.0906 - a_2: 3.1997 - b_1: 1.1413 - b_2: 1.3342 - d_1: 0.2895 - d_2: 0.2966 - n: 2.5019 - mean_metric: 0.3917 - val_loss: 2.2948 - val_a_1: 3.0639 - val_a_2: 3.0092 - val_b_1: 0.8294 - val_b_2: 0.9662 - val_d_1: 0.0960 - val_d_2: 0.0872 - val_n: 1.8289 - val_mean_metric: 0.3247 - lr: 7.7650e-05
# Epoch 961/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.1137 - a_1: 3.1078 - a_2: 3.2100 - b_1: 1.1409 - b_2: 1.3539 - d_1: 0.2898 - d_2: 0.3098 - n: 2.4984 - mean_metric: 0.3937 - val_loss: 2.5135 - val_a_1: 3.0687 - val_a_2: 2.9990 - val_b_1: 0.8290 - val_b_2: 0.9655 - val_d_1: 0.0987 - val_d_2: 0.1007 - val_n: 1.8017 - val_mean_metric: 0.3241 - lr: 7.6000e-05
# Epoch 962/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.8956 - a_1: 3.1029 - a_2: 3.1904 - b_1: 1.1559 - b_2: 1.3338 - d_1: 0.2705 - d_2: 0.3044 - n: 2.4825 - mean_metric: 0.3913 - val_loss: 2.5586 - val_a_1: 3.0715 - val_a_2: 3.0031 - val_b_1: 0.8212 - val_b_2: 0.9687 - val_d_1: 0.1004 - val_d_2: 0.1027 - val_n: 1.8046 - val_mean_metric: 0.3244 - lr: 7.4350e-05
# Epoch 963/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9910 - a_1: 3.0904 - a_2: 3.1934 - b_1: 1.1517 - b_2: 1.3238 - d_1: 0.2782 - d_2: 0.3084 - n: 2.4904 - mean_metric: 0.3912 - val_loss: 2.5189 - val_a_1: 3.0706 - val_a_2: 3.0050 - val_b_1: 0.8284 - val_b_2: 0.9707 - val_d_1: 0.1011 - val_d_2: 0.0999 - val_n: 1.8107 - val_mean_metric: 0.3249 - lr: 7.2700e-05
# Epoch 964/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0462 - a_1: 3.0918 - a_2: 3.1875 - b_1: 1.1416 - b_2: 1.3266 - d_1: 0.2903 - d_2: 0.3049 - n: 2.4715 - mean_metric: 0.3905 - val_loss: 2.5747 - val_a_1: 3.0741 - val_a_2: 3.0028 - val_b_1: 0.8278 - val_b_2: 0.9711 - val_d_1: 0.0989 - val_d_2: 0.1035 - val_n: 1.8066 - val_mean_metric: 0.3248 - lr: 7.1050e-05
# Epoch 965/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 6.0160 - a_1: 3.1007 - a_2: 3.1974 - b_1: 1.1647 - b_2: 1.3099 - d_1: 0.2815 - d_2: 0.3086 - n: 2.4873 - mean_metric: 0.3918 - val_loss: 2.4992 - val_a_1: 3.0728 - val_a_2: 3.0060 - val_b_1: 0.8322 - val_b_2: 0.9679 - val_d_1: 0.0890 - val_d_2: 0.1025 - val_n: 1.8202 - val_mean_metric: 0.3250 - lr: 6.9400e-05
# Epoch 966/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 5.9885 - a_1: 3.0983 - a_2: 3.1804 - b_1: 1.1548 - b_2: 1.3129 - d_1: 0.2901 - d_2: 0.2995 - n: 2.5126 - mean_metric: 0.3916 - val_loss: 2.5251 - val_a_1: 3.0700 - val_a_2: 3.0050 - val_b_1: 0.8357 - val_b_2: 0.9736 - val_d_1: 0.0959 - val_d_2: 0.1000 - val_n: 1.8178 - val_mean_metric: 0.3253 - lr: 6.7750e-05
# Epoch 967/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 5.8582 - a_1: 3.1006 - a_2: 3.1910 - b_1: 1.1674 - b_2: 1.3333 - d_1: 0.2795 - d_2: 0.2976 - n: 2.5013 - mean_metric: 0.3923 - val_loss: 2.5818 - val_a_1: 3.0677 - val_a_2: 3.0112 - val_b_1: 0.8329 - val_b_2: 0.9769 - val_d_1: 0.1010 - val_d_2: 0.1025 - val_n: 1.8235 - val_mean_metric: 0.3259 - lr: 6.6100e-05
# Epoch 968/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 6.0332 - a_1: 3.0899 - a_2: 3.2088 - b_1: 1.1574 - b_2: 1.3345 - d_1: 0.2833 - d_2: 0.3044 - n: 2.4907 - mean_metric: 0.3923 - val_loss: 2.5276 - val_a_1: 3.0705 - val_a_2: 2.9995 - val_b_1: 0.8298 - val_b_2: 0.9720 - val_d_1: 0.0937 - val_d_2: 0.1053 - val_n: 1.8074 - val_mean_metric: 0.3246 - lr: 6.4450e-05
# Epoch 969/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.7819 - a_1: 3.0948 - a_2: 3.1802 - b_1: 1.1233 - b_2: 1.3251 - d_1: 0.2834 - d_2: 0.2819 - n: 2.4860 - mean_metric: 0.3891 - val_loss: 2.4437 - val_a_1: 3.0705 - val_a_2: 3.0079 - val_b_1: 0.8222 - val_b_2: 0.9749 - val_d_1: 0.0952 - val_d_2: 0.0996 - val_n: 1.8275 - val_mean_metric: 0.3253 - lr: 6.2800e-05
# Epoch 970/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9825 - a_1: 3.0988 - a_2: 3.1811 - b_1: 1.1417 - b_2: 1.3193 - d_1: 0.2870 - d_2: 0.2988 - n: 2.4912 - mean_metric: 0.3906 - val_loss: 2.4937 - val_a_1: 3.0696 - val_a_2: 3.0112 - val_b_1: 0.8287 - val_b_2: 0.9695 - val_d_1: 0.0962 - val_d_2: 0.1011 - val_n: 1.8400 - val_mean_metric: 0.3259 - lr: 6.1150e-05
# Epoch 971/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0234 - a_1: 3.1087 - a_2: 3.2152 - b_1: 1.1537 - b_2: 1.3261 - d_1: 0.2910 - d_2: 0.2986 - n: 2.4790 - mean_metric: 0.3924 - val_loss: 2.5067 - val_a_1: 3.0652 - val_a_2: 3.0065 - val_b_1: 0.8249 - val_b_2: 0.9751 - val_d_1: 0.0933 - val_d_2: 0.1045 - val_n: 1.8173 - val_mean_metric: 0.3249 - lr: 5.9500e-05
# Epoch 972/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9653 - a_1: 3.0856 - a_2: 3.1985 - b_1: 1.1600 - b_2: 1.3302 - d_1: 0.2813 - d_2: 0.3029 - n: 2.5076 - mean_metric: 0.3921 - val_loss: 2.4499 - val_a_1: 3.0682 - val_a_2: 2.9971 - val_b_1: 0.8197 - val_b_2: 0.9709 - val_d_1: 0.0933 - val_d_2: 0.1000 - val_n: 1.7817 - val_mean_metric: 0.3231 - lr: 5.7850e-05
# Epoch 973/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9929 - a_1: 3.1023 - a_2: 3.1804 - b_1: 1.1580 - b_2: 1.3109 - d_1: 0.2804 - d_2: 0.3063 - n: 2.4816 - mean_metric: 0.3907 - val_loss: 2.4065 - val_a_1: 3.0670 - val_a_2: 3.0179 - val_b_1: 0.8268 - val_b_2: 0.9659 - val_d_1: 0.0943 - val_d_2: 0.1015 - val_n: 1.8497 - val_mean_metric: 0.3261 - lr: 5.6200e-05
# Epoch 974/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 6.0557 - a_1: 3.1212 - a_2: 3.2083 - b_1: 1.1630 - b_2: 1.3198 - d_1: 0.2736 - d_2: 0.3202 - n: 2.4723 - mean_metric: 0.3926 - val_loss: 2.5524 - val_a_1: 3.0644 - val_a_2: 3.0059 - val_b_1: 0.8263 - val_b_2: 0.9616 - val_d_1: 0.0928 - val_d_2: 0.1133 - val_n: 1.8223 - val_mean_metric: 0.3249 - lr: 5.4550e-05
# Epoch 975/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0378 - a_1: 3.1004 - a_2: 3.2172 - b_1: 1.1380 - b_2: 1.3237 - d_1: 0.2840 - d_2: 0.3067 - n: 2.4980 - mean_metric: 0.3924 - val_loss: 2.5645 - val_a_1: 3.0628 - val_a_2: 3.0065 - val_b_1: 0.8332 - val_b_2: 0.9683 - val_d_1: 0.0973 - val_d_2: 0.1057 - val_n: 1.8233 - val_mean_metric: 0.3253 - lr: 5.2900e-05
# Epoch 976/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.6473 - a_1: 3.1016 - a_2: 3.1443 - b_1: 1.1603 - b_2: 1.3253 - d_1: 0.2647 - d_2: 0.2922 - n: 2.4680 - mean_metric: 0.3886 - val_loss: 2.5462 - val_a_1: 3.0631 - val_a_2: 3.0032 - val_b_1: 0.8279 - val_b_2: 0.9639 - val_d_1: 0.0990 - val_d_2: 0.1017 - val_n: 1.8023 - val_mean_metric: 0.3241 - lr: 5.1250e-05
# Epoch 977/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9352 - a_1: 3.0879 - a_2: 3.1975 - b_1: 1.1588 - b_2: 1.3100 - d_1: 0.2730 - d_2: 0.3065 - n: 2.4881 - mean_metric: 0.3908 - val_loss: 2.4300 - val_a_1: 3.0619 - val_a_2: 3.0043 - val_b_1: 0.8234 - val_b_2: 0.9598 - val_d_1: 0.0951 - val_d_2: 0.0988 - val_n: 1.8084 - val_mean_metric: 0.3238 - lr: 4.9600e-05
# Epoch 978/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9069 - a_1: 3.1045 - a_2: 3.1935 - b_1: 1.1216 - b_2: 1.3193 - d_1: 0.2835 - d_2: 0.2940 - n: 2.4661 - mean_metric: 0.3894 - val_loss: 2.4686 - val_a_1: 3.0612 - val_a_2: 3.0021 - val_b_1: 0.8333 - val_b_2: 0.9637 - val_d_1: 0.0900 - val_d_2: 0.1029 - val_n: 1.7915 - val_mean_metric: 0.3235 - lr: 4.7950e-05
# Epoch 979/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 5.9958 - a_1: 3.1059 - a_2: 3.2121 - b_1: 1.1414 - b_2: 1.3381 - d_1: 0.2793 - d_2: 0.3056 - n: 2.4684 - mean_metric: 0.3917 - val_loss: 2.4823 - val_a_1: 3.0636 - val_a_2: 2.9978 - val_b_1: 0.8311 - val_b_2: 0.9614 - val_d_1: 0.0948 - val_d_2: 0.0992 - val_n: 1.7751 - val_mean_metric: 0.3228 - lr: 4.6300e-05
# Epoch 980/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9773 - a_1: 3.0930 - a_2: 3.1679 - b_1: 1.1560 - b_2: 1.2862 - d_1: 0.2799 - d_2: 0.3025 - n: 2.4791 - mean_metric: 0.3889 - val_loss: 2.4609 - val_a_1: 3.0621 - val_a_2: 3.0096 - val_b_1: 0.8312 - val_b_2: 0.9613 - val_d_1: 0.0965 - val_d_2: 0.1013 - val_n: 1.8275 - val_mean_metric: 0.3250 - lr: 4.4650e-05
# Epoch 981/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.8883 - a_1: 3.0888 - a_2: 3.1707 - b_1: 1.1268 - b_2: 1.2814 - d_1: 0.2840 - d_2: 0.2932 - n: 2.4471 - mean_metric: 0.3864 - val_loss: 2.4341 - val_a_1: 3.0646 - val_a_2: 3.0043 - val_b_1: 0.8313 - val_b_2: 0.9622 - val_d_1: 0.0958 - val_d_2: 0.0982 - val_n: 1.8111 - val_mean_metric: 0.3243 - lr: 4.3000e-05
# Epoch 982/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 5.8716 - a_1: 3.0969 - a_2: 3.2247 - b_1: 1.1290 - b_2: 1.3262 - d_1: 0.2848 - d_2: 0.2960 - n: 2.4695 - mean_metric: 0.3909 - val_loss: 2.4958 - val_a_1: 3.0709 - val_a_2: 3.0026 - val_b_1: 0.8322 - val_b_2: 0.9596 - val_d_1: 0.0970 - val_d_2: 0.0990 - val_n: 1.8022 - val_mean_metric: 0.3242 - lr: 4.1350e-05
# Epoch 983/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0727 - a_1: 3.1048 - a_2: 3.1682 - b_1: 1.1334 - b_2: 1.3132 - d_1: 0.2867 - d_2: 0.3082 - n: 2.4698 - mean_metric: 0.3894 - val_loss: 2.5050 - val_a_1: 3.0687 - val_a_2: 3.0001 - val_b_1: 0.8344 - val_b_2: 0.9655 - val_d_1: 0.0964 - val_d_2: 0.0994 - val_n: 1.7923 - val_mean_metric: 0.3239 - lr: 3.9700e-05
# Epoch 984/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.1277 - a_1: 3.0836 - a_2: 3.2218 - b_1: 1.1525 - b_2: 1.3066 - d_1: 0.3048 - d_2: 0.2969 - n: 2.4538 - mean_metric: 0.3907 - val_loss: 2.4876 - val_a_1: 3.0706 - val_a_2: 2.9973 - val_b_1: 0.8366 - val_b_2: 0.9646 - val_d_1: 0.0988 - val_d_2: 0.0979 - val_n: 1.7795 - val_mean_metric: 0.3236 - lr: 3.8050e-05
# Epoch 985/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0913 - a_1: 3.0888 - a_2: 3.1751 - b_1: 1.1456 - b_2: 1.3057 - d_1: 0.2884 - d_2: 0.3082 - n: 2.4481 - mean_metric: 0.3887 - val_loss: 2.4399 - val_a_1: 3.0649 - val_a_2: 3.0116 - val_b_1: 0.8365 - val_b_2: 0.9662 - val_d_1: 0.0967 - val_d_2: 0.0957 - val_n: 1.8310 - val_mean_metric: 0.3254 - lr: 3.6400e-05
# Epoch 986/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.1349 - a_1: 3.1149 - a_2: 3.2044 - b_1: 1.1269 - b_2: 1.3583 - d_1: 0.2935 - d_2: 0.3074 - n: 2.5192 - mean_metric: 0.3942 - val_loss: 2.4333 - val_a_1: 3.0631 - val_a_2: 3.0058 - val_b_1: 0.8346 - val_b_2: 0.9727 - val_d_1: 0.0957 - val_d_2: 0.0958 - val_n: 1.8207 - val_mean_metric: 0.3250 - lr: 3.4750e-05
# Epoch 987/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 5.9692 - a_1: 3.0986 - a_2: 3.1820 - b_1: 1.1454 - b_2: 1.2981 - d_1: 0.2842 - d_2: 0.3005 - n: 2.4822 - mean_metric: 0.3897 - val_loss: 2.4832 - val_a_1: 3.0615 - val_a_2: 2.9980 - val_b_1: 0.8317 - val_b_2: 0.9744 - val_d_1: 0.0917 - val_d_2: 0.1042 - val_n: 1.7929 - val_mean_metric: 0.3239 - lr: 3.3100e-05
# Epoch 988/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9801 - a_1: 3.0921 - a_2: 3.1528 - b_1: 1.1507 - b_2: 1.3384 - d_1: 0.2811 - d_2: 0.3045 - n: 2.4814 - mean_metric: 0.3900 - val_loss: 2.4301 - val_a_1: 3.0613 - val_a_2: 3.0118 - val_b_1: 0.8311 - val_b_2: 0.9727 - val_d_1: 0.0950 - val_d_2: 0.0948 - val_n: 1.8282 - val_mean_metric: 0.3252 - lr: 3.1450e-05
# Epoch 989/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.8544 - a_1: 3.1061 - a_2: 3.1846 - b_1: 1.1775 - b_2: 1.3349 - d_1: 0.2717 - d_2: 0.3042 - n: 2.4803 - mean_metric: 0.3920 - val_loss: 2.4633 - val_a_1: 3.0627 - val_a_2: 3.0028 - val_b_1: 0.8323 - val_b_2: 0.9666 - val_d_1: 0.0939 - val_d_2: 0.0983 - val_n: 1.8039 - val_mean_metric: 0.3241 - lr: 2.9800e-05
# Epoch 990/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.8635 - a_1: 3.0968 - a_2: 3.2120 - b_1: 1.1388 - b_2: 1.3225 - d_1: 0.2788 - d_2: 0.3019 - n: 2.4542 - mean_metric: 0.3901 - val_loss: 2.4521 - val_a_1: 3.0628 - val_a_2: 2.9955 - val_b_1: 0.8330 - val_b_2: 0.9666 - val_d_1: 0.0956 - val_d_2: 0.0963 - val_n: 1.7732 - val_mean_metric: 0.3228 - lr: 2.8150e-05
# Epoch 991/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.8003 - a_1: 3.1116 - a_2: 3.2054 - b_1: 1.1336 - b_2: 1.3271 - d_1: 0.2663 - d_2: 0.3033 - n: 2.4778 - mean_metric: 0.3909 - val_loss: 2.3775 - val_a_1: 3.0662 - val_a_2: 3.0036 - val_b_1: 0.8319 - val_b_2: 0.9667 - val_d_1: 0.0919 - val_d_2: 0.0936 - val_n: 1.8043 - val_mean_metric: 0.3240 - lr: 2.6500e-05
# Epoch 992/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0932 - a_1: 3.1024 - a_2: 3.1844 - b_1: 1.1519 - b_2: 1.3333 - d_1: 0.2889 - d_2: 0.3093 - n: 2.4274 - mean_metric: 0.3900 - val_loss: 2.5144 - val_a_1: 3.0647 - val_a_2: 2.9932 - val_b_1: 0.8318 - val_b_2: 0.9655 - val_d_1: 0.0962 - val_d_2: 0.0991 - val_n: 1.7760 - val_mean_metric: 0.3229 - lr: 2.4850e-05
# Epoch 993/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.7392 - a_1: 3.0916 - a_2: 3.2053 - b_1: 1.1369 - b_2: 1.3153 - d_1: 0.2730 - d_2: 0.2951 - n: 2.4638 - mean_metric: 0.3893 - val_loss: 2.5063 - val_a_1: 3.0667 - val_a_2: 2.9981 - val_b_1: 0.8336 - val_b_2: 0.9626 - val_d_1: 0.0965 - val_d_2: 0.0993 - val_n: 1.7816 - val_mean_metric: 0.3233 - lr: 2.3200e-05
# Epoch 994/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.0286 - a_1: 3.1048 - a_2: 3.1629 - b_1: 1.1501 - b_2: 1.3072 - d_1: 0.2827 - d_2: 0.3082 - n: 2.4902 - mean_metric: 0.3903 - val_loss: 2.3897 - val_a_1: 3.0656 - val_a_2: 2.9949 - val_b_1: 0.8367 - val_b_2: 0.9659 - val_d_1: 0.0909 - val_d_2: 0.0954 - val_n: 1.7710 - val_mean_metric: 0.3227 - lr: 2.1550e-05
# Epoch 995/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9443 - a_1: 3.1040 - a_2: 3.1955 - b_1: 1.1390 - b_2: 1.2988 - d_1: 0.2788 - d_2: 0.3032 - n: 2.4772 - mean_metric: 0.3898 - val_loss: 2.4789 - val_a_1: 3.0691 - val_a_2: 2.9944 - val_b_1: 0.8347 - val_b_2: 0.9645 - val_d_1: 0.0986 - val_d_2: 0.0953 - val_n: 1.7651 - val_mean_metric: 0.3228 - lr: 1.9900e-05
# Epoch 996/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.8342 - a_1: 3.0977 - a_2: 3.2072 - b_1: 1.1509 - b_2: 1.3196 - d_1: 0.2807 - d_2: 0.2930 - n: 2.4958 - mean_metric: 0.3915 - val_loss: 2.4496 - val_a_1: 3.0693 - val_a_2: 2.9927 - val_b_1: 0.8330 - val_b_2: 0.9610 - val_d_1: 0.0958 - val_d_2: 0.0962 - val_n: 1.7622 - val_mean_metric: 0.3224 - lr: 1.8250e-05
# Epoch 997/1000
# 70/70 [==============================] - 1s 19ms/step - loss: 5.8718 - a_1: 3.1077 - a_2: 3.1890 - b_1: 1.1717 - b_2: 1.3227 - d_1: 0.2791 - d_2: 0.2967 - n: 2.4875 - mean_metric: 0.3919 - val_loss: 2.4658 - val_a_1: 3.0665 - val_a_2: 2.9937 - val_b_1: 0.8328 - val_b_2: 0.9658 - val_d_1: 0.0975 - val_d_2: 0.0960 - val_n: 1.7720 - val_mean_metric: 0.3229 - lr: 1.6600e-05
# Epoch 998/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.9510 - a_1: 3.0917 - a_2: 3.2109 - b_1: 1.1514 - b_2: 1.3139 - d_1: 0.2821 - d_2: 0.3016 - n: 2.4874 - mean_metric: 0.3912 - val_loss: 2.4349 - val_a_1: 3.0651 - val_a_2: 2.9931 - val_b_1: 0.8324 - val_b_2: 0.9643 - val_d_1: 0.0947 - val_d_2: 0.0962 - val_n: 1.7705 - val_mean_metric: 0.3226 - lr: 1.4950e-05
# Epoch 999/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 6.1468 - a_1: 3.1026 - a_2: 3.2016 - b_1: 1.1657 - b_2: 1.2944 - d_1: 0.3034 - d_2: 0.3055 - n: 2.4254 - mean_metric: 0.3900 - val_loss: 2.4984 - val_a_1: 3.0654 - val_a_2: 3.0009 - val_b_1: 0.8304 - val_b_2: 0.9666 - val_d_1: 0.0971 - val_d_2: 0.0984 - val_n: 1.7940 - val_mean_metric: 0.3238 - lr: 1.3300e-05
# Epoch 1000/1000
# 70/70 [==============================] - 1s 18ms/step - loss: 5.8687 - a_1: 3.1218 - a_2: 3.1986 - b_1: 1.1391 - b_2: 1.3017 - d_1: 0.2829 - d_2: 0.2892 - n: 2.4816 - mean_metric: 0.3904 - val_loss: 2.4644 - val_a_1: 3.0647 - val_a_2: 2.9924 - val_b_1: 0.8346 - val_b_2: 0.9661 - val_d_1: 0.0919 - val_d_2: 0.0992 - val_n: 1.7724 - val_mean_metric: 0.3228 - lr: 1.1650e-05

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mean_metric']
val_acc = history.history['val_mean_metric']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(val_epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Número de coeficientes más uno para la métrica adicional
n_coef = len(coeficientesnombres) + 1

# Número de filas y columnas para los subplots
n_rows = (n_coef + 1) // 2
n_cols = 2

# Crear una figura más grande para acomodar todos los subplots
plt.figure(figsize=(15, 5 * n_rows))

# Crear un subplot para cada coeficiente
for i, name in enumerate(coeficientesnombres):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.plot(history.history[name ], label=name + ' Entrenamiento')
    plt.plot(history.history['val_' + name ], label=name + ' Validación')
    plt.title('MAE ' + name)
    plt.xlabel('Épocas')
    plt.ylabel('MAE')
    plt.legend()

# Agregar un subplot para la métrica prom_per
plt.subplot(n_rows, n_cols, n_coef)
plt.plot(history.history['mean_metric'], label='Promedio Entrenamiento')
plt.plot(history.history['val_mean_metric'], label='Promedio Validación')
plt.title('MAE Promedio')
plt.xlabel('Épocas')
plt.ylabel('MAE Promedio')
plt.legend()

# Ajustar el diseño para asegurarse de que todo encaje bien
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluamos el modelo

# %%
test_loss, test_a1, test_a2, test_b1, test_b2, test_d1, test_d2, test_n, testprom_per = model.evaluate(
    campvectest, coefcampvectest)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 2.4582 - a_1: 3.0318 - a_2: 2.8550 - b_1: 0.8557 - b_2: 1.0189 - d_1: 0.0890 - d_2: 0.0998 - n: 1.7565 - mean_metric: 0.3201

# %%
predictions = model.predict(campvectest)
# Out:
# 32/32 [==============================] - 0s 846us/step

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# Calcula el MAE
mae = mean_absolute_error(coefcampvectest, predictions)

# Calcula la desviación estándar del error
error = coefcampvectest - predictions
std_dev = np.std(error)

# Calcula el error absoluto máximo
max_error = np.max(np.abs(error))

print(f"MAE: {mae}, Desviación estándar del error: {std_dev}, Error absoluto máximo: {max_error}")
# Out:
# MAE: 1.389431118827313, Desviación estándar del error: 2.1603419195790745, Error absoluto máximo: 9.664745777845383

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(error.flatten(), bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error')  # Añade un título al gráfico
plt.xlabel('Error')  # Etiqueta el eje x
plt.ylabel('Frecuencia')  # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %%
# Calcula el error absoluto para cada dato
absolute_error = np.abs(coefcampvectest - predictions)

# Calcula el error para cada dato
error = coefcampvectest - predictions

# Calcula la suma de los valores reales para cada dato
sum_real_values = np.sum(coefcampvectest, axis=-1)

# Divide el error absoluto por la suma de los valores reales para cada dato
relative_error_per_data = np.sum(absolute_error, axis=-1) / sum_real_values

# Calcula el MAE relativo como la media de los errores relativos
relative_mae = np.mean(relative_error_per_data)

# Divide el error por la suma de los valores reales para cada dato
relative_error_per_data_std_max = np.sum(error, axis=-1) / sum_real_values

# Calcula la desviación estándar del error relativo
relative_std_dev = np.std(relative_error_per_data_std_max)

# Calcula el error absoluto máximo relativo
relative_max_error = np.max(np.abs(relative_error_per_data_std_max))

print(f"MAE relativo: {relative_mae}")
print(f"Desviación estándar del error relativo: {relative_std_dev}")
print(f"Error absoluto máximo relativo: {relative_max_error}")
# Out:
# MAE relativo: 0.3157711086766941
# Desviación estándar del error relativo: 0.19085636246009846
# Error absoluto máximo relativo: 1.1923539564013481

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Establece el tamaño del gráfico
plt.hist(relative_error_per_data, bins=30, edgecolor='black', alpha=0.7, color = 'green')  # Añade bordes negros a las barras y ajusta la transparencia
plt.title('Distribución del Error Relativo')  # Añade un título al gráfico
plt.xlabel('Error Relativo')  # Etiqueta el eje x
plt.ylabel('Frecuencia')      # Etiqueta el eje y
plt.grid(axis='y', linestyle='--')  # Añade una cuadrícula horizontal
plt.tight_layout()  # Ajusta el diseño para evitar que se recorten las etiquetas
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales/History 50,100/historycampvec50funcioncosto.csv', index = False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos/Modelos 50,100'
path_to_save = '../../../Modelos/Modelos 50,100'

# %%
model.save(path_to_save + '/campovectorial50funcioncosto.h5')

# %% [markdown]
# # Importamos el modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
coeficientesnombres = ('a_1', 'a_2', 'b_1', 'b_2', 'd_1', 'd_2', 'n')

def mse_component(i):
    def mse_i(y_true, y_pred):
        return tf.keras.losses.mean_absolute_error(y_true[:, i], y_pred[:, i])

    mse_i.__name__ = coeficientesnombres[i]
    return mse_i

def mean_metric(y_true, y_pred):
    total_loss = 0
    for i in range(7):
        total_loss += mse_component(i)(y_true, y_pred)
    sum_of_true_coefficients = tf.reduce_sum(y_true, axis=-1)
    return total_loss / sum_of_true_coefficients

metrics = [mse_component(i) for i in range(7)] + [mean_metric]

# %%
import keras
import tensorflow as tf
# Creación de un diccionario con todas las métricas personalizadas
custom_objects = {'custom_loss':custom_loss,'custom_activation':custom_activation,'mean_metric': mean_metric}
for i in range(7):
    custom_objects[coeficientesnombres[i]] = mse_component(i)
new_model = keras.models.load_model('../../../Modelos/Modelos 50,100/campovectorial50funcioncosto.h5', 
                                    custom_objects=custom_objects)

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos = 10

    y1 = np.linspace(x_range_neg, x_range_pos, 50)
    y2 = np.linspace(y_range_neg, y_range_pos, 50)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [9, 1, 1, 1, 1, 5, 3]

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# [[3. 3. 5. 6. 1. 5. 7.]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 50)
y2 = np.linspace(0, 10, 50)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 20])
plt.ylim([0, 20])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1 = np.linspace(x_range_neg, x_range_pos, 50)
y2 = np.linspace(y_range_neg, y_range_pos, 50)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
