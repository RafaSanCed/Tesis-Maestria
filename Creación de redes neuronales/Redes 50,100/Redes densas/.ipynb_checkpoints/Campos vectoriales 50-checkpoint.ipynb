# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_9484\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos/Campo 50 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 50, 50)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (2000, 2, 50, 50)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (1000, 2, 50, 50)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 50, 50), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 7
SHUFFLE_BUFFER_SIZE = 10

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(2,50,50)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(7)
])

# %%
model = Sequential()
model.add(Flatten(input_shape=(2,50,50)))
model.add(Dense(128,activation='tanh',kernel_initializer=HeNormal()))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal()))
model.add(Dense(128,activation = 'tanh',kernel_initializer=HeNormal()))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal()))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'tanh',kernel_initializer=HeNormal()))
model.add(Dense(64,activation = 'tanh',kernel_initializer=HeNormal()))

model.add(Dense(7))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 5000)              0
#
#  dense_5 (Dense)             (None, 128)               640128
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 681,991
# Trainable params: 681,991
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Entrenamos el modelo

# %%
model.compile(optimizer='Adam',
              loss= 'MSE',
              metrics=['mae'])
#model.compile(optimizer='Adam',
 #             loss= 'mse',
  #            metrics=[custom_loss])

# %%
def scheduler(epoch, lr):
  if epoch < 500:
    return lr
  else:
    return 1e-3 * 0.99 ** epoch

# %%
val_epochs = 100
tf.compat.v1.global_variables_initializer()

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 800,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 8.1857 - mae: 2.3702 - val_loss: 7.3469 - val_mae: 2.2362 - lr: 0.0010
# Epoch 2/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.3953 - mae: 2.2606 - val_loss: 7.2272 - val_mae: 2.2005 - lr: 0.0010
# Epoch 3/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.3389 - mae: 2.2470 - val_loss: 7.2408 - val_mae: 2.2243 - lr: 0.0010
# Epoch 4/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.2868 - mae: 2.2361 - val_loss: 7.1945 - val_mae: 2.1987 - lr: 0.0010
# Epoch 5/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.2577 - mae: 2.2260 - val_loss: 7.2729 - val_mae: 2.2174 - lr: 0.0010
# Epoch 6/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.2715 - mae: 2.2293 - val_loss: 7.0907 - val_mae: 2.1805 - lr: 0.0010
# Epoch 7/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1991 - mae: 2.2165 - val_loss: 7.1300 - val_mae: 2.1847 - lr: 0.0010
# Epoch 8/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1781 - mae: 2.2101 - val_loss: 7.1918 - val_mae: 2.2036 - lr: 0.0010
# Epoch 9/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1921 - mae: 2.2125 - val_loss: 7.1306 - val_mae: 2.1847 - lr: 0.0010
# Epoch 10/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1562 - mae: 2.2040 - val_loss: 7.1023 - val_mae: 2.1730 - lr: 0.0010
# Epoch 11/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1854 - mae: 2.2088 - val_loss: 7.1716 - val_mae: 2.1938 - lr: 0.0010
# Epoch 12/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1809 - mae: 2.2098 - val_loss: 7.0913 - val_mae: 2.1783 - lr: 0.0010
# Epoch 13/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1492 - mae: 2.2053 - val_loss: 7.1163 - val_mae: 2.1869 - lr: 0.0010
# Epoch 14/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1377 - mae: 2.2021 - val_loss: 7.0841 - val_mae: 2.1694 - lr: 0.0010
# Epoch 15/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1028 - mae: 2.1948 - val_loss: 7.0422 - val_mae: 2.1641 - lr: 0.0010
# Epoch 16/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1160 - mae: 2.1948 - val_loss: 7.0486 - val_mae: 2.1706 - lr: 0.0010
# Epoch 17/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1102 - mae: 2.1946 - val_loss: 7.0161 - val_mae: 2.1623 - lr: 0.0010
# Epoch 18/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1326 - mae: 2.1979 - val_loss: 7.0449 - val_mae: 2.1724 - lr: 0.0010
# Epoch 19/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1391 - mae: 2.1987 - val_loss: 6.9803 - val_mae: 2.1541 - lr: 0.0010
# Epoch 20/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.1189 - mae: 2.1914 - val_loss: 6.9908 - val_mae: 2.1586 - lr: 0.0010
# Epoch 21/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0950 - mae: 2.1856 - val_loss: 6.9972 - val_mae: 2.1566 - lr: 0.0010
# Epoch 22/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0585 - mae: 2.1776 - val_loss: 6.9264 - val_mae: 2.1433 - lr: 0.0010
# Epoch 23/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0903 - mae: 2.1834 - val_loss: 6.9680 - val_mae: 2.1497 - lr: 0.0010
# Epoch 24/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0761 - mae: 2.1809 - val_loss: 6.9589 - val_mae: 2.1477 - lr: 0.0010
# Epoch 25/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0757 - mae: 2.1836 - val_loss: 7.0145 - val_mae: 2.1597 - lr: 0.0010
# Epoch 26/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0849 - mae: 2.1831 - val_loss: 7.0710 - val_mae: 2.1706 - lr: 0.0010
# Epoch 27/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0981 - mae: 2.1835 - val_loss: 7.0913 - val_mae: 2.1712 - lr: 0.0010
# Epoch 28/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0672 - mae: 2.1774 - val_loss: 7.0422 - val_mae: 2.1684 - lr: 0.0010
# Epoch 29/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0844 - mae: 2.1837 - val_loss: 7.2571 - val_mae: 2.2017 - lr: 0.0010
# Epoch 30/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0761 - mae: 2.1840 - val_loss: 7.0093 - val_mae: 2.1599 - lr: 0.0010
# Epoch 31/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0587 - mae: 2.1786 - val_loss: 6.9699 - val_mae: 2.1498 - lr: 0.0010
# Epoch 32/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0524 - mae: 2.1762 - val_loss: 6.9576 - val_mae: 2.1457 - lr: 0.0010
# Epoch 33/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0300 - mae: 2.1738 - val_loss: 6.9352 - val_mae: 2.1446 - lr: 0.0010
# Epoch 34/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0278 - mae: 2.1712 - val_loss: 6.9538 - val_mae: 2.1488 - lr: 0.0010
# Epoch 35/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0268 - mae: 2.1713 - val_loss: 6.9424 - val_mae: 2.1386 - lr: 0.0010
# Epoch 36/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0336 - mae: 2.1719 - val_loss: 6.8896 - val_mae: 2.1299 - lr: 0.0010
# Epoch 37/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0554 - mae: 2.1747 - val_loss: 6.9997 - val_mae: 2.1535 - lr: 0.0010
# Epoch 38/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0511 - mae: 2.1745 - val_loss: 7.0184 - val_mae: 2.1580 - lr: 0.0010
# Epoch 39/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0331 - mae: 2.1693 - val_loss: 6.9742 - val_mae: 2.1480 - lr: 0.0010
# Epoch 40/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0063 - mae: 2.1648 - val_loss: 6.9193 - val_mae: 2.1394 - lr: 0.0010
# Epoch 41/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0128 - mae: 2.1685 - val_loss: 7.0144 - val_mae: 2.1655 - lr: 0.0010
# Epoch 42/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0108 - mae: 2.1671 - val_loss: 6.8997 - val_mae: 2.1397 - lr: 0.0010
# Epoch 43/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0054 - mae: 2.1631 - val_loss: 6.9271 - val_mae: 2.1426 - lr: 0.0010
# Epoch 44/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9952 - mae: 2.1640 - val_loss: 6.9879 - val_mae: 2.1535 - lr: 0.0010
# Epoch 45/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9984 - mae: 2.1644 - val_loss: 6.9273 - val_mae: 2.1439 - lr: 0.0010
# Epoch 46/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 7.0001 - mae: 2.1641 - val_loss: 6.9721 - val_mae: 2.1428 - lr: 0.0010
# Epoch 47/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9952 - mae: 2.1622 - val_loss: 6.9400 - val_mae: 2.1393 - lr: 0.0010
# Epoch 48/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9678 - mae: 2.1592 - val_loss: 6.8467 - val_mae: 2.1268 - lr: 0.0010
# Epoch 49/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9644 - mae: 2.1577 - val_loss: 6.8875 - val_mae: 2.1278 - lr: 0.0010
# Epoch 50/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9695 - mae: 2.1585 - val_loss: 6.9094 - val_mae: 2.1367 - lr: 0.0010
# Epoch 51/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9930 - mae: 2.1628 - val_loss: 6.8900 - val_mae: 2.1368 - lr: 0.0010
# Epoch 52/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9700 - mae: 2.1574 - val_loss: 6.8744 - val_mae: 2.1270 - lr: 0.0010
# Epoch 53/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9679 - mae: 2.1545 - val_loss: 6.9277 - val_mae: 2.1354 - lr: 0.0010
# Epoch 54/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9858 - mae: 2.1595 - val_loss: 6.9716 - val_mae: 2.1439 - lr: 0.0010
# Epoch 55/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9814 - mae: 2.1599 - val_loss: 6.9413 - val_mae: 2.1382 - lr: 0.0010
# Epoch 56/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9729 - mae: 2.1610 - val_loss: 6.9032 - val_mae: 2.1333 - lr: 0.0010
# Epoch 57/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9734 - mae: 2.1571 - val_loss: 6.9049 - val_mae: 2.1339 - lr: 0.0010
# Epoch 58/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9857 - mae: 2.1597 - val_loss: 6.9050 - val_mae: 2.1328 - lr: 0.0010
# Epoch 59/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9918 - mae: 2.1606 - val_loss: 6.8921 - val_mae: 2.1337 - lr: 0.0010
# Epoch 60/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9809 - mae: 2.1615 - val_loss: 6.9309 - val_mae: 2.1381 - lr: 0.0010
# Epoch 61/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9694 - mae: 2.1572 - val_loss: 6.9134 - val_mae: 2.1325 - lr: 0.0010
# Epoch 62/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9447 - mae: 2.1518 - val_loss: 6.8855 - val_mae: 2.1275 - lr: 0.0010
# Epoch 63/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9566 - mae: 2.1533 - val_loss: 6.9015 - val_mae: 2.1356 - lr: 0.0010
# Epoch 64/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9610 - mae: 2.1563 - val_loss: 6.9810 - val_mae: 2.1438 - lr: 0.0010
# Epoch 65/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9685 - mae: 2.1579 - val_loss: 6.8738 - val_mae: 2.1292 - lr: 0.0010
# Epoch 66/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9504 - mae: 2.1536 - val_loss: 6.9140 - val_mae: 2.1326 - lr: 0.0010
# Epoch 67/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9459 - mae: 2.1513 - val_loss: 6.8693 - val_mae: 2.1281 - lr: 0.0010
# Epoch 68/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9433 - mae: 2.1519 - val_loss: 6.8747 - val_mae: 2.1335 - lr: 0.0010
# Epoch 69/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9714 - mae: 2.1573 - val_loss: 6.8724 - val_mae: 2.1272 - lr: 0.0010
# Epoch 70/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9398 - mae: 2.1526 - val_loss: 6.8286 - val_mae: 2.1209 - lr: 0.0010
# Epoch 71/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9235 - mae: 2.1488 - val_loss: 6.8384 - val_mae: 2.1239 - lr: 0.0010
# Epoch 72/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9138 - mae: 2.1452 - val_loss: 6.7627 - val_mae: 2.1098 - lr: 0.0010
# Epoch 73/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9151 - mae: 2.1449 - val_loss: 6.7808 - val_mae: 2.1146 - lr: 0.0010
# Epoch 74/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9111 - mae: 2.1439 - val_loss: 6.8143 - val_mae: 2.1189 - lr: 0.0010
# Epoch 75/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9043 - mae: 2.1436 - val_loss: 6.8330 - val_mae: 2.1190 - lr: 0.0010
# Epoch 76/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9042 - mae: 2.1431 - val_loss: 6.8014 - val_mae: 2.1169 - lr: 0.0010
# Epoch 77/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9253 - mae: 2.1465 - val_loss: 6.8437 - val_mae: 2.1196 - lr: 0.0010
# Epoch 78/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9530 - mae: 2.1508 - val_loss: 6.8689 - val_mae: 2.1255 - lr: 0.0010
# Epoch 79/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9188 - mae: 2.1448 - val_loss: 6.8516 - val_mae: 2.1253 - lr: 0.0010
# Epoch 80/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9296 - mae: 2.1489 - val_loss: 6.8795 - val_mae: 2.1294 - lr: 0.0010
# Epoch 81/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9154 - mae: 2.1456 - val_loss: 6.8606 - val_mae: 2.1265 - lr: 0.0010
# Epoch 82/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9258 - mae: 2.1480 - val_loss: 6.8437 - val_mae: 2.1259 - lr: 0.0010
# Epoch 83/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9365 - mae: 2.1489 - val_loss: 6.8304 - val_mae: 2.1208 - lr: 0.0010
# Epoch 84/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9088 - mae: 2.1430 - val_loss: 6.8349 - val_mae: 2.1184 - lr: 0.0010
# Epoch 85/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9217 - mae: 2.1458 - val_loss: 6.8325 - val_mae: 2.1225 - lr: 0.0010
# Epoch 86/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9090 - mae: 2.1421 - val_loss: 6.7989 - val_mae: 2.1093 - lr: 0.0010
# Epoch 87/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9041 - mae: 2.1429 - val_loss: 6.8245 - val_mae: 2.1201 - lr: 0.0010
# Epoch 88/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9260 - mae: 2.1464 - val_loss: 6.8395 - val_mae: 2.1201 - lr: 0.0010
# Epoch 89/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9087 - mae: 2.1436 - val_loss: 6.8657 - val_mae: 2.1245 - lr: 0.0010
# Epoch 90/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9003 - mae: 2.1415 - val_loss: 6.8358 - val_mae: 2.1213 - lr: 0.0010
# Epoch 91/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9222 - mae: 2.1450 - val_loss: 6.8163 - val_mae: 2.1147 - lr: 0.0010
# Epoch 92/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9252 - mae: 2.1470 - val_loss: 6.8586 - val_mae: 2.1228 - lr: 0.0010
# Epoch 93/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9137 - mae: 2.1432 - val_loss: 6.7846 - val_mae: 2.1089 - lr: 0.0010
# Epoch 94/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9229 - mae: 2.1445 - val_loss: 6.8034 - val_mae: 2.1155 - lr: 0.0010
# Epoch 95/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9358 - mae: 2.1475 - val_loss: 6.8685 - val_mae: 2.1316 - lr: 0.0010
# Epoch 96/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9205 - mae: 2.1464 - val_loss: 6.8360 - val_mae: 2.1185 - lr: 0.0010
# Epoch 97/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9121 - mae: 2.1428 - val_loss: 6.8054 - val_mae: 2.1144 - lr: 0.0010
# Epoch 98/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9130 - mae: 2.1453 - val_loss: 6.7932 - val_mae: 2.1108 - lr: 0.0010
# Epoch 99/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9205 - mae: 2.1440 - val_loss: 6.8057 - val_mae: 2.1109 - lr: 0.0010
# Epoch 100/100
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.9176 - mae: 2.1448 - val_loss: 6.8413 - val_mae: 2.1169 - lr: 0.0010

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['mae']
val_acc = history.history['val_mae']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(val_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Guardamos los datos accuracy y loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales/historycampvec50.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos/Modelos 50,100'

# %%
model.save(path_to_save + '/campovectorial50.h5')

# %%
keras.experimental.export_saved_model(model, path_to_save + 'prueba')

# %% [markdown]
# # Importamos el modelo

# %%
new_model = keras.models.load_model('../../Modelos/Modelos 50,100/campovectorial50.h5')

# %%
new_model = keras.experimental.load_from_saved_model('../Modelos/prueba')

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos =10

    y1 = np.linspace(x_range_neg, x_range_pos, 50)
    y2 = np.linspace(y_range_neg, y_range_pos, 50)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)
    contador = contador+1
    print(contador)
    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [6, 2, 7, 5, 10, 0, 0]
# 1

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# [[5.1538033e+00 5.0094638e+00 3.9856071e+00 5.0504580e+00 6.6815658e+00
#   9.7081065e-05 2.6495914e+00]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 50)
y2 = np.linspace(0, 10, 50)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
np.shape(new_predictions)
# Out:
# (1, 7)

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos =10

y1 = np.linspace(x_range_neg, x_range_pos, 50)
y2 = np.linspace(y_range_neg, y_range_pos, 50)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
