# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_12096\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos/Campo 100 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 100, 100)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (2000, 2, 100, 100)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (1000, 2, 100, 100)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 100, 100), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 10
SHUFFLE_BUFFER_SIZE = 10

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
model.add(Flatten(input_shape=(2,100,100)))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))

model.add(Dense(7, activation= custom_activation))

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(2,100,100)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation = custom_activation)
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 20000)             0
#
#  batch_normalization_1 (Batc  (None, 20000)            80000
#  hNormalization)
#
#  dense_7 (Dense)             (None, 128)               2560128
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_11 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 2,665,671
# Trainable params: 2,625,543
# Non-trainable params: 40,128
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
model.compile(optimizer=optimizer,
              loss= 'MSE',
              metrics=['accuracy'])

# %%
def scheduler(epoch, lr):
  if epoch < 100:
    return lr
  else:
    return 1e-3 -  9.9e-6** epoch

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 100,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/100
# 700/700 [==============================] - 6s 8ms/step - loss: 6.8970 - accuracy: 0.3597 - val_loss: 5.0955 - val_accuracy: 0.3970 - lr: 0.0010
# Epoch 2/100
# 700/700 [==============================] - 6s 8ms/step - loss: 5.6930 - accuracy: 0.3880 - val_loss: 4.8281 - val_accuracy: 0.4190 - lr: 0.0010
# Epoch 3/100
# 700/700 [==============================] - 6s 8ms/step - loss: 4.9363 - accuracy: 0.4279 - val_loss: 4.5126 - val_accuracy: 0.4010 - lr: 0.0010
# Epoch 4/100
# 700/700 [==============================] - 6s 8ms/step - loss: 4.4739 - accuracy: 0.4671 - val_loss: 2.8548 - val_accuracy: 0.6090 - lr: 0.0010
# Epoch 5/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.9177 - accuracy: 0.5144 - val_loss: 2.5878 - val_accuracy: 0.6590 - lr: 0.0010
# Epoch 6/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.8277 - accuracy: 0.5236 - val_loss: 2.5315 - val_accuracy: 0.6750 - lr: 0.0010
# Epoch 7/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.7095 - accuracy: 0.5376 - val_loss: 2.4954 - val_accuracy: 0.6290 - lr: 0.0010
# Epoch 8/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.6629 - accuracy: 0.5343 - val_loss: 2.4000 - val_accuracy: 0.6610 - lr: 0.0010
# Epoch 9/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.6765 - accuracy: 0.5319 - val_loss: 2.3801 - val_accuracy: 0.6610 - lr: 0.0010
# Epoch 10/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.6302 - accuracy: 0.5324 - val_loss: 2.3749 - val_accuracy: 0.6590 - lr: 0.0010
# Epoch 11/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.6027 - accuracy: 0.5400 - val_loss: 2.3962 - val_accuracy: 0.7140 - lr: 0.0010
# Epoch 12/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.6095 - accuracy: 0.5389 - val_loss: 2.3372 - val_accuracy: 0.6590 - lr: 0.0010
# Epoch 13/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.5831 - accuracy: 0.5453 - val_loss: 2.3593 - val_accuracy: 0.6970 - lr: 0.0010
# Epoch 14/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.5668 - accuracy: 0.5454 - val_loss: 2.3262 - val_accuracy: 0.6510 - lr: 0.0010
# Epoch 15/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.5920 - accuracy: 0.5350 - val_loss: 2.2927 - val_accuracy: 0.7010 - lr: 0.0010
# Epoch 16/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.5054 - accuracy: 0.5531 - val_loss: 2.3777 - val_accuracy: 0.6820 - lr: 0.0010
# Epoch 17/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.4898 - accuracy: 0.5446 - val_loss: 2.2847 - val_accuracy: 0.7040 - lr: 0.0010
# Epoch 18/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.5133 - accuracy: 0.5509 - val_loss: 2.3002 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 19/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.4744 - accuracy: 0.5544 - val_loss: 2.2770 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 20/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.4776 - accuracy: 0.5534 - val_loss: 2.2944 - val_accuracy: 0.7050 - lr: 0.0010
# Epoch 21/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.4659 - accuracy: 0.5469 - val_loss: 2.2287 - val_accuracy: 0.6760 - lr: 0.0010
# Epoch 22/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.5010 - accuracy: 0.5427 - val_loss: 2.2587 - val_accuracy: 0.6990 - lr: 0.0010
# Epoch 23/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.4494 - accuracy: 0.5536 - val_loss: 2.2274 - val_accuracy: 0.6830 - lr: 0.0010
# Epoch 24/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.5088 - accuracy: 0.5404 - val_loss: 2.2370 - val_accuracy: 0.6640 - lr: 0.0010
# Epoch 25/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3
100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.1356 - accuracy: 0.5587 - val_loss: 1.9101 - val_accuracy: 0.7010 - lr: 0.0010
# Epoch 77/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.1261 - accuracy: 0.5691 - val_loss: 1.9245 - val_accuracy: 0.7300 - lr: 0.0010
# Epoch 78/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.1304 - accuracy: 0.5677 - val_loss: 1.9254 - val_accuracy: 0.7210 - lr: 0.0010
# Epoch 79/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.0930 - accuracy: 0.5671 - val_loss: 1.9465 - val_accuracy: 0.6850 - lr: 0.0010
# Epoch 80/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.1018 - accuracy: 0.5673 - val_loss: 1.9348 - val_accuracy: 0.7340 - lr: 0.0010
# Epoch 81/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0846 - accuracy: 0.5670 - val_loss: 1.9632 - val_accuracy: 0.7120 - lr: 0.0010
# Epoch 82/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.1101 - accuracy: 0.5740 - val_loss: 1.9466 - val_accuracy: 0.7370 - lr: 0.0010
# Epoch 83/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.1099 - accuracy: 0.5636 - val_loss: 1.9183 - val_accuracy: 0.7240 - lr: 0.0010
# Epoch 84/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0982 - accuracy: 0.5761 - val_loss: 2.0414 - val_accuracy: 0.7180 - lr: 0.0010
# Epoch 85/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0663 - accuracy: 0.5706 - val_loss: 1.9298 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 86/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0925 - accuracy: 0.5649 - val_loss: 1.9227 - val_accuracy: 0.7180 - lr: 0.0010
# Epoch 87/100
# 700/700 [==============================] - 5s 8ms/step - loss: 3.0687 - accuracy: 0.5607 - val_loss: 1.9542 - val_accuracy: 0.7450 - lr: 0.0010
# Epoch 88/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0780 - accuracy: 0.5764 - val_loss: 1.9395 - val_accuracy: 0.7090 - lr: 0.0010
# Epoch 89/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0992 - accuracy: 0.5669 - val_loss: 1.9547 - val_accuracy: 0.7110 - lr: 0.0010
# Epoch 90/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0933 - accuracy: 0.5671 - val_loss: 1.9072 - val_accuracy: 0.7240 - lr: 0.0010
# Epoch 91/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0726 - accuracy: 0.5616 - val_loss: 1.9448 - val_accuracy: 0.7260 - lr: 0.0010
# Epoch 92/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0868 - accuracy: 0.5617 - val_loss: 1.9170 - val_accuracy: 0.7190 - lr: 0.0010
# Epoch 93/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0716 - accuracy: 0.5734 - val_loss: 1.9312 - val_accuracy: 0.7460 - lr: 0.0010
# Epoch 94/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0798 - accuracy: 0.5640 - val_loss: 1.9353 - val_accuracy: 0.7210 - lr: 0.0010
# Epoch 95/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0345 - accuracy: 0.5689 - val_loss: 1.9099 - val_accuracy: 0.7120 - lr: 0.0010
# Epoch 96/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.1001 - accuracy: 0.5624 - val_loss: 1.9668 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 97/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0669 - accuracy: 0.5666 - val_loss: 1.8746 - val_accuracy: 0.7230 - lr: 0.0010
# Epoch 98/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0890 - accuracy: 0.5723 - val_loss: 1.9144 - val_accuracy: 0.7420 - lr: 0.0010
# Epoch 99/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0558 - accuracy: 0.5684 - val_loss: 1.9282 - val_accuracy: 0.7300 - lr: 0.0010
# Epoch 100/100
# 700/700 [==============================] - 6s 8ms/step - loss: 3.0783 - accuracy: 0.5610 - val_loss: 1.9392 - val_accuracy: 0.7430 - lr: 0.0010

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(val_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales/historycampvec100.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos/Modelos 100,200'

# %%
model.save(path_to_save + '/campovectorial100.h5')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 model.save(path_to_save + '/campovectorial100.h5')
#
# File ~\anaconda3\envs\tfcpu\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tfcpu\lib\site-packages\keras\saving\hdf5_format.py:80, in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      54 """Saves a model to a HDF5 file.
#      55
#      56 The saved model contains:
#    (...)
#      76     ImportError: if h5py is not available.
#      77 """
#      79 if h5py is None:
# ---> 80     raise ImportError(
#      81         "`save_model()` using h5 format requires h5py. Could not "
#      82         "import h5py."
#      83     )
#      85 # TODO(psv) Add warning when we save models that contain non-serializable
#      86 # entities like metrics added using `add_metric` and losses added using
#      87 # `add_loss.`
#      88 if len(model.weights) != len(model._undeduplicated_weights):
#
# ImportError: `save_model()` using h5 format requires h5py. Could not import h5py.

# %% [markdown]
# # Importamos el modelo

# %%
new_model = keras.models.load_model('../../Modelos/Modelos 100,200/campovectorial100.h5')

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 20
    y_range_neg = 0
    y_range_pos =20

    y1 = np.linspace(x_range_neg, x_range_pos, 100)
    y2 = np.linspace(y_range_neg, y_range_pos, 100)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [4, 10, 0, 5, 2, 5, 1]

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# [[4.9765053 4.90493   2.8920193 4.86968   3.7813644 7.3230314 2.623407 ]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 20, 100)
y2 = np.linspace(0, 20, 100)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 20])
plt.ylim([0, 20])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
np.shape(new_predictions)
# Out:
# (1, 7)

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 20
y_range_neg = 0
y_range_pos = 20

y1 = np.linspace(x_range_neg, x_range_pos, 100)
y2 = np.linspace(y_range_neg, y_range_pos, 100)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %% [markdown]
# # Pruebas mensas

# %%
#y_true2 = [[1,2,3,4,5,1,2], [6,7,8,1,2,3,4], [1,2,3,4,5,8,2]]
#y_pred2 = [[2,5,4,3,7,2,1], [1,2,3,7,8,0,1], [2,5,4,3,7,2,5]]
y_true2 = [1,2,3,4,5,1,2]
y_pred2 = [5,5,4,3,9,4,5]

# %%
def custom_loss2(y_true2, y_pred2):
    campvec = []
    # constantes
    a1 = y_true2[0]

    a2 =y_true2[1]
    
    b1 = y_true2[2]
    
    b2 = y_true2[3]

    d1 = y_true2[4]

    d2 = y_true2[5]

    n = y_true2[5]
    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 5
    y_range_neg = 0
    y_range_pos =5

    y1 = np.linspace(x_range_neg, x_range_pos, 100)
    y2 = np.linspace(y_range_neg, y_range_pos, 100)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = y_pred2[0]

    a22 =y_pred2[1]
    
    b12 = y_pred2[2]
    
    b22 = y_pred2[3]

    d12 = y_pred2[4]

    d22 = y_pred2[5]

    n2 = y_pred2[5]
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        Y2 = ye2[1]

        # definimos cada ODE
        dX2_dt = a12/(1+Y2**n2)-d12*X2+b12
        dY2_dt = a22/(1+X2**n2)-d22*Y2+b12
        return [dX2_dt, dY2_dt]

    y12 = np.linspace(x_range_neg, x_range_pos, 100)
    y22 = np.linspace(y_range_neg, y_range_pos, 100)
    Y12, Y22 = np.meshgrid(y12, y22)
    u2, v2 = np.zeros(Y12.shape), np.zeros(Y22.shape)
    u2, v2 = f2(t1, [Y12, Y22])
    M2 = np.sqrt(np.square(u2) + np.square(v2))
    u2 /= M2
    v2 /= M2
    campvecx = u- u2
    campvecy = v - v2    
    
    
    #loss = tf.reduce_mean(campvectotal)
    return u,v, u2,v2, campvecx, campvecy,Y1,Y2,Y12,Y22,M,M2

# %%
u,v,u2,v2,campvecx,campvecy,Y1,Y2,Y12,Y22,M,M2 = custom_loss2(y_true2,y_pred2)
print(u)
# Out:
# [[ 0.62469505  0.60719189  0.58729543 ... -0.98698699 -0.98731734
#   -0.98763553]
#  [ 0.62395608  0.60621056  0.58602174 ... -0.98742824 -0.98774723
#   -0.98805448]
#  [ 0.62363052  0.60566871  0.58521532 ... -0.98785519 -0.98816326
#   -0.98846   ]
#  ...
#  [ 0.99949256  0.99999861  0.99952127 ... -0.99733525 -0.99738744
#   -0.99743808]
#  [ 0.99987295  0.99987745  0.99875552 ... -0.99716104 -0.99721694
#   -0.99727118]
#  [ 1.          0.99945609  0.99763222 ... -0.9969814  -0.99704113
#   -0.99709909]]

# %%
x_range_neg = 0
x_range_pos = 5
y_range_neg = 0
y_range_pos =5
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
x_range_neg = 0
x_range_pos = 5
y_range_neg = 0
y_range_pos =5
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y12, Y22, u2, v2, M2, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
x_range_neg = 0
x_range_pos = 5
y_range_neg = 0
y_range_pos =5
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y12, Y22, campvecx, campvecy, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
