# %% [markdown]
# # Importamos librerías

# %%
import tensorflow as tf
import pathlib
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from keras.regularizers import l1, l2

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\rafae\AppData\Local\Temp\ipykernel_24412\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # Importamos los datos

# %%
path = '../../../Base de datos/Campo 100 puntos'

# %% [markdown]
# ## Datos de entrenamiento

# %% [markdown]
# ### Datos

# %%
campvectrain = np.load(path + '/campvectrain.npy')

# %%
np.shape(campvectrain)
# Out:
# (7000, 2, 100, 100)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectrain = np.load(path + '/coefcampvectrain.npy')

# %%
np.shape(coefcampvectrain)
# Out:
# (7000, 7)

# %% [markdown]
# ## Datos de prueba

# %% [markdown]
# ### Datos

# %%
campvectest = np.load(path + '/campvectest.npy')

# %%
np.shape(campvectest)
# Out:
# (2000, 2, 100, 100)

# %% [markdown]
# ### Coeficientes

# %%
coefcampvectest = np.load(path + '/coefcampvectest.npy')

# %%
np.shape(coefcampvectest)
# Out:
# (2000, 7)

# %% [markdown]
# ## Datos de validación

# %% [markdown]
# ### Datos

# %%
campvecval = np.load(path + '/campvecval.npy')

# %%
np.shape(campvecval)
# Out:
# (1000, 2, 100, 100)

# %% [markdown]
# ### Coeficienes

# %%
coefcampvecval = np.load(path + '/coefcampvecval.npy')

# %%
np.shape(coefcampvecval)
# Out:
# (1000, 7)

# %% [markdown]
# # Unimos coeficientes con los datos

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((campvectrain, coefcampvectrain))
test_dataset = tf.data.Dataset.from_tensor_slices((campvectest, coefcampvectest))
val_dataset = tf.data.Dataset.from_tensor_slices((campvecval, coefcampvecval))

# %%
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(2, 100, 100), dtype=tf.float64, name=None), TensorSpec(shape=(7,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Mezclar y procesar por lotes los conjuntos de datos

# %%
BATCH_SIZE = 10
SHUFFLE_BUFFER_SIZE = 10

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Creación del modelo

# %%
def custom_activation(x):
    return 10 * tf.nn.sigmoid(x)

# %%
model = Sequential()
model.add(Flatten(input_shape=(2,100,100)))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dropout(0.3))
model.add(Dense(128,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))
model.add(Dense(64,activation = 'relu',kernel_initializer=HeNormal(), kernel_regularizer=l1(0.001)))

model.add(Dense(7, activation= custom_activation))

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(2,100,100)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(7, activation = custom_activation)
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 20000)             0
#
#  batch_normalization_1 (Batc  (None, 20000)            80000
#  hNormalization)
#
#  dense_7 (Dense)             (None, 128)               2560128
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_11 (Dense)            (None, 7)                 455
#
# =================================================================
# Total params: 2,665,671
# Trainable params: 2,625,543
# Non-trainable params: 40,128
# _________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Entrenamos el modelo

# %%
from keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001,clipvalue=100.0)

# %%
model.compile(optimizer=optimizer,
              loss= 'MSE',
              metrics=['accuracy'])

# %%
def scheduler(epoch, lr):
  if epoch < 100:
    return lr
  else:
    return 1e-3 -  9.9e-6** epoch

# %%
val_epochs = 1000

early_stop = tf.keras.callbacks.EarlyStopping( monitor = 'val_loss', patience = 100,verbose = 1, 
                                              restore_best_weights = True)

reduce_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
history = model.fit(train_dataset, validation_data=val_dataset, epochs= val_epochs, callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 7.1039 - accuracy: 0.3443 - val_loss: 5.0050 - val_accuracy: 0.4020 - lr: 0.0010
# Epoch 2/1000
# 700/700 [==============================] - 5s 8ms/step - loss: 5.9080 - accuracy: 0.3870 - val_loss: 4.8543 - val_accuracy: 0.4090 - lr: 0.0010
# Epoch 3/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 5.5389 - accuracy: 0.3926 - val_loss: 4.7731 - val_accuracy: 0.4140 - lr: 0.0010
# Epoch 4/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 5.1964 - accuracy: 0.4049 - val_loss: 3.8441 - val_accuracy: 0.4850 - lr: 0.0010
# Epoch 5/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 5.2657 - accuracy: 0.4020 - val_loss: 5.0492 - val_accuracy: 0.4640 - lr: 0.0010
# Epoch 6/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 4.6164 - accuracy: 0.4494 - val_loss: 3.6320 - val_accuracy: 0.5810 - lr: 0.0010
# Epoch 7/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 4.1024 - accuracy: 0.5026 - val_loss: 2.6344 - val_accuracy: 0.6420 - lr: 0.0010
# Epoch 8/1000
# 700/700 [==============================] - 6s 9ms/step - loss: 3.8377 - accuracy: 0.5170 - val_loss: 2.5840 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 9/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.8074 - accuracy: 0.5179 - val_loss: 2.5111 - val_accuracy: 0.6410 - lr: 0.0010
# Epoch 10/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.7719 - accuracy: 0.5319 - val_loss: 2.5003 - val_accuracy: 0.6680 - lr: 0.0010
# Epoch 11/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.7774 - accuracy: 0.5253 - val_loss: 2.4729 - val_accuracy: 0.6710 - lr: 0.0010
# Epoch 12/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.7008 - accuracy: 0.5241 - val_loss: 2.4504 - val_accuracy: 0.6560 - lr: 0.0010
# Epoch 13/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.6924 - accuracy: 0.5320 - val_loss: 2.4011 - val_accuracy: 0.6880 - lr: 0.0010
# Epoch 14/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.6275 - accuracy: 0.5303 - val_loss: 2.4061 - val_accuracy: 0.6620 - lr: 0.0010
# Epoch 15/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.6312 - accuracy: 0.5436 - val_loss: 2.4664 - val_accuracy: 0.6940 - lr: 0.0010
# Epoch 16/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.6361 - accuracy: 0.5313 - val_loss: 2.3801 - val_accuracy: 0.6640 - lr: 0.0010
# Epoch 17/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.5920 - accuracy: 0.5414 - val_loss: 2.4024 - val_accuracy: 0.6710 - lr: 0.0010
# Epoch 18/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.5993 - accuracy: 0.5399 - val_loss: 2.3256 - val_accuracy: 0.6880 - lr: 0.0010
# Epoch 19/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.6099 - accuracy: 0.5423 - val_loss: 2.3490 - val_accuracy: 0.6610 - lr: 0.0010
# Epoch 20/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.5760 - accuracy: 0.5434 - val_loss: 2.3136 - val_accuracy: 0.6950 - lr: 0.0010
# Epoch 21/1000
# 700/700 [==============================] - 6s 9ms/step - loss: 3.5604 - accuracy: 0.5446 - val_loss: 2.3152 - val_accuracy: 0.6690 - lr: 0.0010
# Epoch 22/1000
# 700/700 [==============================] - 6s 9ms/step - loss: 3.5007 - accuracy: 0.5459 - val_loss: 2.2479 - val_accuracy: 0.6920 - lr: 0.0010
# Epoch 23/1000
# 700/700 [==============================] - 5s 8ms/step - loss: 3.4845 - accuracy: 0.5449 - val_loss: 2.2817 - val_accuracy: 0.6770 - lr: 0.0010
# Epoch 24/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.4446 - accuracy: 0.5514 - val_loss: 2.3236 - val_accuracy: 0.7130 - lr: 0.0010
# Epoch 25/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.4846 - accuracy: 0.5456 - val_loss: 2.2852 - val_accuracy: 0.6940 - lr: 0.0010
# Epoch 26/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.4900 - accuracy: 0.5467 - val_loss: 2.2488 - val_accuracy: 0.6680 - lr: 0.0010
# Epoch 27/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.4654 - accuracy: 0.5493 - val_loss: 2.2644 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 28/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.4780 - accuracy: 0.5471 - val_loss: 2.2356 - val_accuracy: 0.7140 - lr: 0.0010
# Epoch 29/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.3929 - accuracy: 0.5544 - val_loss: 2.1999 - val_accuracy: 0.7210 - lr: 0.0010
# Epoch 30/1000
# 700/700 [==============================] - 5s 8ms/step - loss: 3.3725 - accuracy: 0.5587 - val_loss: 2.1927 - val_accuracy: 0.6970 - lr: 0.0010
# Epoch 31/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.3692 - accuracy: 0.5560 - val_loss: 2.1520 - val_accuracy: 0.7210 - lr: 0.0010
# Epoch 32/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.3673 - accuracy: 0.5524 - val_loss: 2.1724 - val_accuracy: 0.6920 - lr: 0.0010
# Epoch 33/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.3659 - accuracy: 0.5621 - val_loss: 2.1325 - val_accuracy: 0.7020 - lr: 0.0010
# Epoch 34/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.3810 - accuracy: 0.5566 - val_loss: 2.1494 - val_accuracy: 0.7120 - lr: 0.0010
# Epoch 35/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.3374 - accuracy: 0.5577 - val_loss: 2.0726 - val_accuracy: 0.7060 - lr: 0.0010
# Epoch 36/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.2970 - accuracy: 0.5614 - val_loss: 2.0341 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 37/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.2196 - accuracy: 0.5563 - val_loss: 2.0167 - val_accuracy: 0.7230 - lr: 0.0010
# Epoch 38/1000
# 700/700 [==============================] - 5s 8ms/step - loss: 3.2546 - accuracy: 0.5644 - val_loss: 1.9909 - val_accuracy: 0.7120 - lr: 0.0010
# Epoch 39/1000
# 700/700 [==============================] - 5s 8ms/step - loss: 3.1986 - accuracy: 0.5627 - val_loss: 2.0659 - val_accuracy: 0.7130 - lr: 0.0010
# Epoch 40/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.2176 - accuracy: 0.5553 - val_loss: 2.0060 - val_accuracy: 0.7210 - lr: 0.0010
# Epoch 41/1000
# 700/700 [==============================] - 6s 9ms/step - loss: 3.1914 - accuracy: 0.5610 - val_loss: 1.9945 - val_accuracy: 0.7070 - lr: 0.0010
# Epoch 42/1000
# 700/700 [==============================] - 6s 8ms/step - loss: 3.
- val_accuracy: 0.7630 - lr: 0.0010
# Epoch 253: early stopping

# %% [markdown]
# # Analizamos accuracy y loss

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

#epochs_range = range(val_epochs)
epochs_range = range(253)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Guardamos los datos de Accuracy y Loss

# %%
df = pd.DataFrame.from_dict(history.history)
df.to_csv('../../../Gráficas finales/historycampvec100.csv', index=False)

# %% [markdown]
# # Guardamos el modelo

# %%
path_to_save = '../../../Modelos/Modelos 100,200'

# %%
model.save(path_to_save + '/campovectorial100.h5')

# %% [markdown]
# # Importamos el modelo

# %%
new_model = keras.models.load_model('../../../Modelos/Modelos 100,200/campovectorial100.h5', custom_objects={'custom_activation': custom_activation})

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %% [markdown]
# ## Creamos nuevos datos

# %%
import random
from scipy.integrate import solve_ivp

campvec = []
coef = []
contador = 0
for i in range(0, 1):
    # constantes
    a1 = random.randint(0, 10)
    a2 = random.randint(0, 10)
    b1 = random.randint(0, 10)
    b2 = random.randint(0, 10)
    d1 = random.randint(0, 10)
    d2 = random.randint(0, 10)
    n = random.randint(0, 5)

    coef1 = [a1, a2, b1, b2, d1, d2, n]
    coef.append(coef1)

    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        # dX_dt=a1/(1+Y**n)-d1*X+b1
        # dY_dt=a2/(1+X**n)-d2*Y+b2
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 10
    y_range_neg = 0
    y_range_pos =10

    y1 = np.linspace(x_range_neg, x_range_pos, 100)
    y2 = np.linspace(y_range_neg, y_range_pos, 100)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M

    campvecci = np.append([u1], [v1], axis=0)

    campvec = campvecci
    print('--------------------------------------------')
    print(coef1)

    
campvec = np.array(campvec)
coef = np.array(coef)
# Out:
# --------------------------------------------
# [2, 4, 7, 4, 7, 9, 3]

# %%
campvecnone = campvec[None, :]

# %% [markdown]
# ## Predecimos con los datos nuevos

# %%
new_predictions = new_model.predict(campvecnone)
new_predictions = np.round(new_predictions)
new_predictions = np.clip(new_predictions, 0, None)
print(new_predictions)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# [[2. 4. 7. 5. 6. 9. 3.]]

# %% [markdown]
# ## Graficamos con los coeficientes reales

# %%
y1 = np.linspace(0, 10, 100)
y2 = np.linspace(0, 10, 100)
Y1, Y2 = np.meshgrid(y1, y2)
t1 = 0
u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)
NI, NJ = Y1.shape        
u,v = np.array(campvec)[0,:,:], np.array(campvec)[1,:,:]
M = (np.hypot(u,v))
u /= M
v /= M

plt.figure(figsize=(10,10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([0, 10])
plt.ylim([0, 10])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
np.shape(new_predictions)
# Out:
# (1, 7)

# %% [markdown]
# ## Graficamos con los coeficientes predecidos

# %%
a1 = new_predictions[0,0]
a2 = new_predictions[0,1]
b1 = new_predictions[0,2]
b2 = new_predictions[0,3]
d1 = new_predictions[0,4]
d2 = new_predictions[0,5]
n = new_predictions[0,6]
 
def f(t, y):

    # asignar a cada ODE a un elemento de vector
    X = y[0]
    Y = y[1]

    # definimos cada ODE
    dX_dt = a1/(1+Y**n)-d1*X+b1
    dY_dt = a2/(1+X**n)-d2*Y+b1

    return [dX_dt, dY_dt]

x_range_neg = 0
x_range_pos = 10
y_range_neg = 0
y_range_pos = 10

y1 = np.linspace(x_range_neg, x_range_pos, 100)
y2 = np.linspace(y_range_neg, y_range_pos, 100)

Y1, Y2 = np.meshgrid(y1, y2)
    
t1 = 0

u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

NI, NJ = Y1.shape

u1, v1 = f(t1, [Y1, Y2])
u, v = f(t1, [Y1, Y2])
M = (np.hypot(u, v))
u /= M
v /= M
    
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %% [markdown]
# # Pruebas mensas

# %%
#y_true2 = [[1,2,3,4,5,1,2], [6,7,8,1,2,3,4], [1,2,3,4,5,8,2]]
#y_pred2 = [[2,5,4,3,7,2,1], [1,2,3,7,8,0,1], [2,5,4,3,7,2,5]]
y_true2 = [1,2,3,4,5,1,2]
y_pred2 = [5,5,4,3,9,4,5]

# %%
def custom_loss2(y_true2, y_pred2):
    campvec = []
    # constantes
    a1 = y_true2[0]

    a2 =y_true2[1]
    
    b1 = y_true2[2]
    
    b2 = y_true2[3]

    d1 = y_true2[4]

    d2 = y_true2[5]

    n = y_true2[5]
    def f(t, y):

        # asignar a cada ODE a un elemento de vector
        X = y[0]
        Y = y[1]

        # definimos cada ODE
        dX_dt = a1/(1+Y**n)-d1*X+b1
        dY_dt = a2/(1+X**n)-d2*Y+b1

        return [dX_dt, dY_dt]

    x_range_neg = 0
    x_range_pos = 5
    y_range_neg = 0
    y_range_pos =5

    y1 = np.linspace(x_range_neg, x_range_pos, 100)
    y2 = np.linspace(y_range_neg, y_range_pos, 100)

    Y1, Y2 = np.meshgrid(y1, y2)
    
    t1 = 0

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    u1, v1 = f(t1, [Y1, Y2])
    u, v = f(t1, [Y1, Y2])
    M = (np.hypot(u, v))
    u /= M
    v /= M
# ----------------------------------------------------------------------------
    campvec2 = []
    # constantes
    a12 = y_pred2[0]

    a22 =y_pred2[1]
    
    b12 = y_pred2[2]
    
    b22 = y_pred2[3]

    d12 = y_pred2[4]

    d22 = y_pred2[5]

    n2 = y_pred2[5]
    def f2(t2, ye2):

        # asignar a cada ODE a un elemento de vector
        X2 = ye2[0]
        Y2 = ye2[1]

        # definimos cada ODE
        dX2_dt = a12/(1+Y2**n2)-d12*X2+b12
        dY2_dt = a22/(1+X2**n2)-d22*Y2+b12
        return [dX2_dt, dY2_dt]

    y12 = np.linspace(x_range_neg, x_range_pos, 100)
    y22 = np.linspace(y_range_neg, y_range_pos, 100)
    Y12, Y22 = np.meshgrid(y12, y22)
    u2, v2 = np.zeros(Y12.shape), np.zeros(Y22.shape)
    u2, v2 = f2(t1, [Y12, Y22])
    M2 = np.sqrt(np.square(u2) + np.square(v2))
    u2 /= M2
    v2 /= M2
    campvecx = u- u2
    campvecy = v - v2    
    
    
    #loss = tf.reduce_mean(campvectotal)
    return u,v, u2,v2, campvecx, campvecy,Y1,Y2,Y12,Y22,M,M2

# %%
u,v,u2,v2,campvecx,campvecy,Y1,Y2,Y12,Y22,M,M2 = custom_loss2(y_true2,y_pred2)
print(u)
# Out:
# [[ 0.62469505  0.60719189  0.58729543 ... -0.98698699 -0.98731734
#   -0.98763553]
#  [ 0.62395608  0.60621056  0.58602174 ... -0.98742824 -0.98774723
#   -0.98805448]
#  [ 0.62363052  0.60566871  0.58521532 ... -0.98785519 -0.98816326
#   -0.98846   ]
#  ...
#  [ 0.99949256  0.99999861  0.99952127 ... -0.99733525 -0.99738744
#   -0.99743808]
#  [ 0.99987295  0.99987745  0.99875552 ... -0.99716104 -0.99721694
#   -0.99727118]
#  [ 1.          0.99945609  0.99763222 ... -0.9969814  -0.99704113
#   -0.99709909]]

# %%
x_range_neg = 0
x_range_pos = 5
y_range_neg = 0
y_range_pos =5
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y1, Y2, u, v, M, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
x_range_neg = 0
x_range_pos = 5
y_range_neg = 0
y_range_pos =5
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y12, Y22, u2, v2, M2, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')

# %%
x_range_neg = 0
x_range_pos = 5
y_range_neg = 0
y_range_pos =5
plt.figure(figsize=(10, 10))
Q = plt.quiver(Y12, Y22, campvecx, campvecy, angles='xy')
plt.title('Campo vectorial espacio fase Toggle Swich', fontsize=20)
plt.xlim([x_range_neg, x_range_pos])
plt.ylim([y_range_neg, y_range_pos])
plt.xlabel('Concentración X')
plt.ylabel('Concentración Y')
# Out:
# Text(0, 0.5, 'Concentración Y')
