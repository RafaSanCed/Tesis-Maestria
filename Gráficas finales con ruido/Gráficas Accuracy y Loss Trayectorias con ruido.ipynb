# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df200conv = pd.read_csv('History 100,200/historyconvtrayec200.csv')
df200dense = pd.read_csv('History 100,200/historytrayec200.csv')
df100conv = pd.read_csv('History 50,100//historyconvtrayec100.csv')
df100dense =  pd.read_csv('History 50,100/historytrayec100.csv')
df50conv = pd.read_csv('History 20,50/historyconvtrayec50.csv')
df50dense = pd.read_csv('History 20,50/historytrayec50.csv')
df50conv
# Out:
#           loss       mae  val_loss   val_mae        lr
# 0    10.075131  2.362955  8.070551  2.110005  0.001000
# 1     8.292492  2.180618  7.243465  2.037679  0.001000
# 2     7.670430  2.128432  6.852471  1.986747  0.001000
# 3     7.330041  2.078616  6.637064  1.954312  0.001000
# 4     6.962228  2.002820  6.261606  1.879208  0.001000
# ..         ...       ...       ...       ...       ...
# 995   2.724931  1.080495  5.156556  1.465435  0.000018
# 996   2.743655  1.081136  5.159699  1.467276  0.000017
# 997   2.725689  1.080440  5.167643  1.466595  0.000015
# 998   2.715903  1.079305  5.173896  1.467911  0.000013
# 999   2.741469  1.083991  5.180885  1.469923  0.000012
#
# [1000 rows x 5 columns]

# %%
ax = df200conv['val_loss'].plot(kind='line', title='Loss y Val_Loss ruido', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Conv 200')
df200dense['val_loss'].plot(kind='line', ax=ax, label='Densa 200')
df100dense['val_loss'].plot(kind='line', ax=ax, label='Densa 100')
df100conv['val_loss'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_loss'].plot(kind='line', ax=ax, label='Conv 50')
df50dense['val_loss'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = df200conv['val_loss'].plot(kind='line', title='Loss y Val_Loss Redes densas datos ruido', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Conv 200')
df100conv['val_loss'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_loss'].plot(kind='line', ax=ax, label='Conv 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = df200dense['val_loss'].plot(kind='line', title='Loss y Val_Loss Redes Densas', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Densa 200')
df100dense['val_loss'].plot(kind='line', ax=ax, label='Densa 100')
df50dense['val_loss'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %% [markdown]
# # MAE

# %%
ax = df200conv['val_mae'].plot(kind='line', title='Error Absoluto Medio con ruido', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Conv 200')
#df200dense['val_mae'].plot(kind='line', ax=ax, label='Densa 200')
df100dense['val_mae'].plot(kind='line', ax=ax, label='Densa 100')
df100conv['val_mae'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_mae'].plot(kind='line', ax=ax, label='Conv 50')
df50dense['val_mae'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = df200conv['val_mae'].plot(kind='line', title='Error Absoluto Medio Redes Convolucionales con ruido', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Conv 200')
df100conv['val_mae'].plot(kind='line', ax=ax, label='Conv 100')
df50conv['val_mae'].plot(kind='line', ax=ax, label='Conv 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()

# %%
ax = df100dense['val_mae'].plot(kind='line', title='Error Absoluto Medio Redes Densas con ruido', xlabel='Épocas', 
                                ylabel='Péridida en datos de validación', label='Densa 100')
df200dense['val_mae'].plot(kind='line', ax=ax, label='Densa 200')
df50dense['val_mae'].plot(kind='line', ax=ax, label='Densa 50')

# Agrega leyenda y muestra la gráfica
ax.legend()
plt.show()
